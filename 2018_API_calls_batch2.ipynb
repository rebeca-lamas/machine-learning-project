# %%
import pandas as pd
import requests
import json
import time
from pprint import pprint
from config import API_KEY

# %%
data = pd.read_csv('Resources/title_webscraped/titles_2018_batch2.csv')
df =  data.count()
df
# Out:
# title    1000
# dtype: int64

# %%
title_id = []
box_office_list = []
country_list = []
genre_list = []
director_list = []
metascore_list = []
production_list = []
rating_list = []
IMDB_rating_list = [] 
rotten_tomatoes_rating_list = []
runtime_list = []
title_list = []
type_list = []
imdb_votes_list = []

# %%
movies = data['title']
total_movies = len(movies)

# %%
for i in range(total_movies):
    movie = movies[i]
    url = "http://www.omdbapi.com/?i=" + movie + "&apikey=" + API_KEY
    response = (requests.get(url).text)
    response_json = json.loads(response)
    print('-------------------')
    print(f'movie id {movie}')
    print('-------------------')
    pprint(response_json)
    
    try:
        box_office_list.append(response_json['BoxOffice'])
        country_list.append(response_json['Country'])
        genre_list.append(response_json['Genre'])
        director_list.append(response_json['Director'])
        metascore_list.append(response_json['Metascore'])
        production_list.append(response_json['Production'])
        rating_list.append(response_json['Rated'])
        IMDB_rating_list.append(response_json['imdbRating'])
        try:
            if not response_json['Ratings']:
                rotten_tomatoes_rating_list.append('NA')
            elif response_json['Ratings'][0]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][0]['Value'])
            elif response_json['Ratings'][1]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][1]['Value'])
            else:
                rotten_tomatoes_rating_list.append('NA')
        except IndexError:
            rotten_tomatoes_rating_list.append('NA')
        runtime_list.append(response_json['Runtime'])
        title_list.append(response_json['Title'])
        type_list.append(response_json['Type'])
        imdb_votes_list.append(response_json['imdbVotes'])
        title_id.append(response_json['imdbID'])
    except KeyError:
        pass
    time.sleep(1)
# Out:
# -------------------
# movie id tt8192676
# -------------------
# {'Actors': 'Padraic Aubrey, Jon Braver, Eric Michael Cole, David R. Fisher',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tarmac Brothers, Joshua Kerr(co-director), Michael '
#              'Roberts(co-director)',
#  'Genre': 'Adventure, Comedy, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A young brotherhood of mystics set out to stop the an evil priest, '
#          'with the help of a chosen warrior.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOGJhMDdlMDAtMGRiYS00YjZmLTk1ZjgtMTc5MGVhMDViNGQ1XkEyXkFqcGdeQXVyNDUxNjc5NjY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '13 May 2018',
#  'Response': 'True',
#  'Runtime': '55 min',
#  'Title': 'Dragon Kin',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joshua Kerr, Michael Roberts',
#  'Year': '2018',
#  'imdbID': 'tt8192676',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7220318
# -------------------
# {'Actors': 'Tiffany Halstead',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Bob Clark',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Mar 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Drawing Dead',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Bob Clark, Bruce Kilroy',
#  'Year': '2018',
#  'imdbID': 'tt7220318',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2208868
# -------------------
# {'Actors': 'Scott Dickert, Kaleti Williams, Robert Rollins, Grant Landry',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Robert Rollins',
#  'Genre': 'Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Welcome to a land that Elias calls Dream Country - a country where '
#          'it is always turning late in the year. A country where the hills are '
#          'fog and the rivers are mist... where noons go quickly...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODM5MzkyNDUwNF5BMl5BanBnXkFtZTgwNjE4MjA5MzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Sep 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Dream Country',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Christopher Dominguez, Edward Fik, Joseph Guimond, Robert Rollins',
#  'Year': '2018',
#  'imdbID': 'tt2208868',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7296604
# -------------------
# {'Actors': 'Thanh Duy, Dam Phuong Linh, Thanh Tu Nguyen, Anh Tu',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Vietnam',
#  'DVD': 'N/A',
#  'Director': 'Roland Nguyen',
#  'Genre': 'Thriller',
#  'Language': 'Vietnamese',
#  'Metascore': 'N/A',
#  'Plot': 'Following the disappearance of his girlfriend, a young man '
#          'investigates a mysterious figure online who is believed to cause the '
#          "deaths of those who 'friend' him on Facebook.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzE1OTI1YWEtMTExYi00OTI0LThjMWUtMjViZTA5ZWRlMWZmXkEyXkFqcGdeQXVyMjAzMTk4NzU@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '10 Aug 2018',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': 'Dream Man',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2018',
#  'imdbID': 'tt7296604',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5478918
# -------------------
# {'Actors': 'Malcolm McDowell, Iyad Hajjaj, Robin Givens, Fidelia Grace',
#  'Awards': '16 wins & 6 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Iyad Hajjaj, Mahmoud Kamel',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A teenage girl is held captive in the home of a wealthy family. She '
#          "is befriended by the family's young gardener, himself an illegal "
#          'from Mexico. Their friendship carries both of them ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDczMTAyODgtOTdmNC00OWJjLWEwOWMtZmZhMWJmZWU0ODYzXkEyXkFqcGdeQXVyMTk4MjcyNzg@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'}],
#  'Released': '01 Apr 2018',
#  'Response': 'True',
#  'Runtime': '81 min',
#  'Title': 'Dreams I Never Had',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Iyad Hajjaj (story), Lisa Jan Savy (story), Lisa Jan Savy',
#  'Year': '2018',
#  'imdbID': 'tt5478918',
#  'imdbRating': '6.2',
#  'imdbVotes': '75'}
# -------------------
# movie id tt8075928
# -------------------
# {'Actors': 'Greg W. Locke, Ruthellen Cheney, Tariq Triano, Deco Smith',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Greg W. Locke',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Forty-something Sean visits New York City for the first time in an '
#          "attempt to measure the severity of his estranged best friend's "
#          'dwindling mental health.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk4ODhhODctNDdlNi00MTdlLTkyNzQtNWVkYjBlZWQ4OGViXkEyXkFqcGdeQXVyMjM1Nzg3OTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '82 min',
#  'Title': 'Drinking Water',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Greg W. Locke, Greg W. Locke (story), Sean Ezekiel Smith',
#  'Year': '2018',
#  'imdbID': 'tt8075928',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4824222
# -------------------
# {'Actors': 'Shadow C. LaValley, Elizabeth Reinertsen, Meredith J. Hudson, '
#            'Kevin Sutton',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Shanna Becker, Shadow C. LaValley',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'With the recent death of a family member, Will goes for a drive to '
#          'rediscover who he is as a person. While on his journey, Will talks '
#          'about the human experience, that effects everyone in some form or '
#          'another.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Drive',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Shadow C. LaValley',
#  'Year': '2017',
#  'imdbID': 'tt4824222',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5592796
# -------------------
# {'Actors': 'Jason Sudeikis, Lee Pace, Judy Greer, Isabel Arraiza',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'Puerto Rico, UK, USA',
#  'DVD': '16 Aug 2019',
#  'Director': 'Nick Hamm',
#  'Genre': 'Biography, Drama, Thriller',
#  'Language': 'English',
#  'Metascore': '55',
#  'Plot': 'Intense thriller where politics, big business and narcotics collide.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMDFlMzM5YjctZjRlMC00MzAzLWFjODctN2MzMWE3MDBlOGNlXkEyXkFqcGdeQXVyMzQwMTY2Nzk@._V1_SX300.jpg',
#  'Production': 'Variance Films &amp; Universal Pictures Content Group',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '61%'},
#              {'Source': 'Metacritic', 'Value': '55/100'}],
#  'Released': '16 Aug 2019',
#  'Response': 'True',
#  'Runtime': '113 min',
#  'Title': 'Driven',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Colin Bateman',
#  'Year': '2018',
#  'imdbID': 'tt5592796',
#  'imdbRating': '6.2',
#  'imdbVotes': '2,658'}
# -------------------
# movie id tt5240090
# -------------------
# {'Actors': 'Rick Lundgren, Stephen Medvidick, Lorenzo Lamas, Jason James '
#            'Richter',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '30 Nov 2018',
#  'Director': 'Jack Skyyler, Alex Zinzopoulos',
#  'Genre': 'Crime, Drama, Mystery',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A dark drama set on the streets of Las Vegas, following a '
#          'driver/serial killer with multiple personality disorder, and the '
#          'rogue detective hunting him down.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BM2YwNjdkOWUtYmJiOC00MzkzLWIxZDMtYThmODYyYWVhMzQxXkEyXkFqcGdeQXVyNDMwNjU2MzM@._V1_SX300.jpg',
#  'Production': 'Sundance Selects',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '44%'}],
#  'Released': '20 Nov 2018',
#  'Response': 'True',
#  'Runtime': '79 min',
#  'Title': 'Driver',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Gini Graham Scott',
#  'Year': '2018',
#  'imdbID': 'tt5240090',
#  'imdbRating': '4.1',
#  'imdbVotes': '70'}
# -------------------
# movie id tt5596336
# -------------------
# {'Actors': 'Lara Phillips, Jim Freivogel, Yvonne Huff, Renee Domenz',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Joseph Strickland',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A psychological suspense thriller dealing with the dual persona a '
#          'young man possesses and attempts to conceal throughout his ongoing '
#          'sessions with his therapist.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYjk3YjU3ZTYtNjJlYi00NjRkLWE5YTctNDQwYzQ4NWVmM2NmXkEyXkFqcGdeQXVyNjU4OTcyODQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '26 Oct 2017',
#  'Response': 'True',
#  'Runtime': '100 min',
#  'Title': 'Dual Mania',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joseph Strickland',
#  'Year': '2017',
#  'imdbID': 'tt5596336',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6958014
# -------------------
# {'Actors': 'Alia Shawkat, Laia Costa, Mae Whitman, Hong Chau',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '01 May 2018',
#  'Director': 'Miguel Arteta',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'English, Catalan, Spanish',
#  'Metascore': '58',
#  'Plot': 'Two women, who are dissatisfied with the dishonesty they see in '
#          'dating and relationships, decide to make a pact to spend 24 hours '
#          'together hoping to find a new way to create intimacy.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTU4MTMxMTM4NV5BMl5BanBnXkFtZTgwNjAzNjAxNTM@._V1_SX300.jpg',
#  'Production': 'The Orchard',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.2/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '57%'},
#              {'Source': 'Metacritic', 'Value': '58/100'}],
#  'Released': '27 Apr 2018',
#  'Response': 'True',
#  'Runtime': '93 min',
#  'Title': 'Duck Butter',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Miguel Arteta, Alia Shawkat',
#  'Year': '2018',
#  'imdbID': 'tt6958014',
#  'imdbRating': '5.2',
#  'imdbVotes': '2,283'}
# -------------------
# movie id tt4940416
# -------------------
# {'Actors': 'Jim Gaffigan, Zendaya, Lance Lim, Greg Proops',
#  'Awards': '1 win.',
#  'BoxOffice': 'N/A',
#  'Country': 'China, USA, UK',
#  'DVD': '20 Jul 2018',
#  'Director': 'Christopher Jenkins',
#  'Genre': 'Animation, Adventure, Comedy, Family',
#  'Language': 'English, Mandarin',
#  'Metascore': 'N/A',
#  'Plot': 'A bachelor goose must form a bond with two lost ducklings as they '
#          'journey south.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYjljMWMyMDItMTU4NS00OTY4LWI5NTItNjRjNjM2YTU1OWQwXkEyXkFqcGdeQXVyMjEyMzc1Njg@._V1_SX300.jpg',
#  'Production': 'Open Road Films',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.7/10'}],
#  'Released': '20 Jul 2018',
#  'Response': 'True',
#  'Runtime': '91 min',
#  'Title': 'Duck Duck Goose',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Christopher Jenkins (story by), Christopher Jenkins, Rob Muir, '
#            'Scott Atkinson, Tegan West, Ding Ding (Mandarin Script)',
#  'Year': '2018',
#  'imdbID': 'tt4940416',
#  'imdbRating': '5.7',
#  'imdbVotes': '2,623'}
# -------------------
# movie id tt3458510
# -------------------
# {'Actors': 'Lucy Hale, Kathryn Prescott, Alexandra Shipp, Awkwafina',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '20 Apr 2018',
#  'Director': 'Olivia Milch',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A group of teenage girlfriends deal with their impending graduation '
#          'from high school.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk1NjA2ODk2NV5BMl5BanBnXkFtZTgwNjkyMTA0NTM@._V1_SX300.jpg',
#  'Production': 'Netflix',
#  'Rated': 'TV-MA',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.1/10'}],
#  'Released': '20 Apr 2018',
#  'Response': 'True',
#  'Runtime': '97 min',
#  'Title': 'Dude',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Olivia Milch, Olivia Milch (story by), Kendall McKinnon (story by)',
#  'Year': '2018',
#  'imdbID': 'tt3458510',
#  'imdbRating': '5.1',
#  'imdbVotes': '5,497'}
# -------------------
# movie id tt7822680
# -------------------
# {'Actors': 'Piercey Dalton, Jeff Marchelletta, Martin Dorsla, Robert Solomon',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '19 Feb 2019',
#  'Director': 'Thiago Dadalt',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'Gravitas Ventures',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Duke',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Thiago Dadalt, Dru Miller',
#  'Year': '2018',
#  'imdbID': 'tt7822680',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4878482
# -------------------
# {'Actors': 'Danielle Macdonald, Jennifer Aniston, Odeya Rush, Maddie Baillio',
#  'Awards': 'Nominated for 1 Golden Globe. Another 6 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Anne Fletcher',
#  'Genre': 'Comedy, Drama, Musical',
#  'Language': 'English',
#  'Metascore': '53',
#  'Plot': "Willowdean ('Dumplin'), the plus-size teenage daughter of a former "
#          "beauty queen, signs up for her mom's Miss Teen Bluebonnet pageant as "
#          'a protest that escalates when other contestants follow her '
#          'footsteps, revolutionizing the pageant and their small Texas town.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMDMyNzQyMjgtZTM2NS00ZjQwLThjYTMtZDlhOTNhNTMzNTkwXkEyXkFqcGdeQXVyMDA4NzMyOA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#              {'Source': 'Metacritic', 'Value': '53/100'}],
#  'Released': '07 Dec 2018',
#  'Response': 'True',
#  'Runtime': '110 min',
#  'Title': "Dumplin'",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kristin Hahn (screenplay by), Julie Murphy (based on the novel by)',
#  'Year': '2018',
#  'imdbID': 'tt4878482',
#  'imdbRating': '6.6',
#  'imdbVotes': '23,312'}
# -------------------
# movie id tt5358438
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Philip Cornwall',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An agoraphobic man traumatized by his past prepares for the largest '
#          'wind storm in decades.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '21 Oct 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Dusk to Dusk',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Philip Cornwall, Jason W. Gomulinski',
#  'Year': '2016',
#  'imdbID': 'tt5358438',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8431312
# -------------------
# {'Actors': 'Jessica Bishop, Kamille Cruz, Guy Kapulnik, Jessica Nielson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Mo Shirazi',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Three stories about people needing to consume but who are lost as to '
#          'what.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '17 May 2018',
#  'Response': 'True',
#  'Runtime': '71 min',
#  'Title': 'Dusty Simulacra',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Mo Shirazi',
#  'Year': '2018',
#  'imdbID': 'tt8431312',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt9233202
# -------------------
# {'Actors': 'Dwight York',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ian Rans',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzMyMjkzOGUtYWE1Ny00OTBmLTg2NjMtM2I2YjFhMmM2NjI5XkEyXkFqcGdeQXVyNTQyMzQ4MTY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '18 Oct 2018',
#  'Response': 'True',
#  'Runtime': '55 min',
#  'Title': 'Dwight York: Belongs in a Bar',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dwight York',
#  'Year': '2018',
#  'imdbID': 'tt9233202',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7335892
# -------------------
# {'Actors': 'April Bowlby, Kim Director, Abbie Gayle, Mike Faiola',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Sam Irvin',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "A successful married woman's life is put in turmoil when she "
#          'reunites with an old high school friend.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTAyMjI4MWMtYTZjNS00ZWQ2LThiMDUtYTUwZDNlMmE1OWNkXkEyXkFqcGdeQXVyMTU2ODA1MzI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.3/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Homecoming Revenge',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Lindsay Hartley, Jason-Shane Scott',
#  'Year': '2018',
#  'imdbID': 'tt7335892',
#  'imdbRating': '5.3',
#  'imdbVotes': '127'}
# -------------------
# movie id tt7450964
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt11202454
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt4701724
# -------------------
# {'Actors': 'Eddie Redmayne, Tom Hiddleston, Maisie Williams, Timothy Spall',
#  'Awards': '1 win & 10 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, UK, France',
#  'DVD': '22 May 2018',
#  'Director': 'Nick Park',
#  'Genre': 'Animation, Adventure, Comedy, Family, Fantasy, Sport',
#  'Language': 'English',
#  'Metascore': '68',
#  'Plot': 'Set at the dawn of time, when prehistoric creatures and woolly '
#          'mammoths roamed the earth, Early Man tells the story of Dug, along '
#          'with sidekick Hognob as they unite his tribe against a mighty enemy '
#          'Lord Nooth and his Bronze Age City to save their home.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYWMxYWVjNzAtMTY0YS00YWQyLWExMGItMjUxODkwYzQyNzMwXkEyXkFqcGdeQXVyMjMxOTE0ODA@._V1_SX300.jpg',
#  'Production': 'Lionsgate',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '81%'},
#              {'Source': 'Metacritic', 'Value': '68/100'}],
#  'Released': '16 Feb 2018',
#  'Response': 'True',
#  'Runtime': '89 min',
#  'Title': 'Early Man',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Mark Burton (screenplay by), James Higginson (screenplay by), Mark '
#            'Burton (story by), Nick Park (story by)',
#  'Year': '2018',
#  'imdbID': 'tt4701724',
#  'imdbRating': '6.1',
#  'imdbVotes': '17,049'}
# -------------------
# movie id tt8692786
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Craig Singer',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZjRjMGE5OGYtY2Q4My00YzI4LTk4NGEtOGE2Mjc4NmNlMzgxXkEyXkFqcGdeQXVyMTg3MzQxMw@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Nov 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': "Earth's Call",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2018',
#  'imdbID': 'tt8692786',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6870808
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt6082386
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Robert L. Parker III',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Ease the Pain',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Robert L. Parker III',
#  'Year': '2017',
#  'imdbID': 'tt6082386',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3867436
# -------------------
# {'Actors': 'Steve Richard, Tim Maudlin, Joshua Marlowe, Alicia Howell',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Steve Richard',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '27 Nov 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'East Plains: Get Out!',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Steve Richard',
#  'Year': '2014',
#  'imdbID': 'tt3867436',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7575582
# -------------------
# {'Actors': 'Kj Schrock',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Easter Bunny Adventure 2',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'BC Furtney (screenwriter), Holly May Opee',
#  'Year': '2018',
#  'imdbID': 'tt7575582',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt9486594
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt2399430
# -------------------
# {'Actors': 'Joanna Bartling, Ashton Bingham, Skip Bolden, Zack Cole',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Halstan Williams',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When vulnerable artist Tyler Mason has nowhere else to turn, he is '
#          'recruited into an unexpected trio to conduct one of the most '
#          'innovative money counterfeiting schemes to ever hit the market.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODMyNTczNDQ2N15BMl5BanBnXkFtZTgwNzU5NTM5MTE@._V1_SX300.jpg',
#  'Production': 'Butch Williams Studios',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.9/10'}],
#  'Released': '16 Feb 2018',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': 'Easy Money',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2018',
#  'imdbID': 'tt2399430',
#  'imdbRating': '5.9',
#  'imdbVotes': '7'}
# -------------------
# movie id tt8200864
# -------------------
# {'Actors': 'Michael Blackson, California Brougham, Ron Byrd, Yonel Dorelis',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Charles Steven Duran(co-director), La La King(co-director)',
#  'Genre': 'Action',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://ia.media-imdb.com/images/M/MV5BNjYzMDEwNDktZDY4Ni00OWM2LWIxYjUtNDIxOTY2OWZhZDgwXkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_SX300.jpg',
#  'Production': 'Butch Williams Studios',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '06 Feb 2018',
#  'Response': 'True',
#  'Runtime': '64 min',
#  'Title': 'Easy Money',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'La La King, Darien Smith',
#  'Year': '2018',
#  'imdbID': 'tt8200864',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4229864
# -------------------
# {'Actors': 'Brad Carter, Michael Shamus Wiles, Jacqueline Wright',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '06 Mar 2018',
#  'Director': 'Adrian Cruz',
#  'Genre': 'Drama, Horror, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Over the course of one torturous night, a suicidal woman and the '
#          'violent home intruder that saved her life test the limits of human '
#          'endurance and the boundaries of forgiveness.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzY3YzlhOTAtMzFiYi00ZTZjLTlkMWUtOWY1MzIzYzJmYzQ2XkEyXkFqcGdeQXVyNjc1NzI1MDU@._V1_SX300.jpg',
#  'Production': 'Blue Fox Entertainment',
#  'Rated': 'TV-MA',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.5/10'}],
#  'Released': '02 Mar 2018',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': 'Eat Me',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jacqueline Wright, Jacqueline Wright',
#  'Year': '2018',
#  'imdbID': 'tt4229864',
#  'imdbRating': '4.5',
#  'imdbVotes': '180'}
# -------------------
# movie id tt8294444
# -------------------
# {'Actors': 'Michael Ray Williams',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Matthew Ryan Williams',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Thomas begins what is intended to be a short stay at a deceased '
#          "friend's house, in order to clear out some of the belongings. "
#          'However, as he begins a nostalgic trip through childhood memories, '
#          'he starts to suspect that he may not be alone.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjc3NmQxYjktOTdhYi00NTk5LTk5NTAtMzUzYWNiMzg3MmRiXkEyXkFqcGdeQXVyNDMzMTQyMzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Jun 2018',
#  'Response': 'True',
#  'Runtime': '74 min',
#  'Title': 'Echoes',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Will Milosky (story by), Matthew Ryan Williams (story by), Matthew '
#            'Ryan Williams',
#  'Year': '2018',
#  'imdbID': 'tt8294444',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8236588
# -------------------
# {'Actors': 'Trista Robinson, Hannah Race, Paul Chirico, Marshal Hilton',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Brian Avenet-Bradley, Laurence Avenet-Bradley(co-director)',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYjBlZjYxNzEtN2Y0ZS00MGRhLWE2MjgtYmEwZmNjY2Q1ZWE5XkEyXkFqcGdeQXVyMjAxMDMyOQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Echoes of Fear',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Brian Avenet-Bradley',
#  'Year': '2018',
#  'imdbID': 'tt8236588',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8206646
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt7149916
# -------------------
# {'Actors': 'Rockmond Dunbar, Zhu Zhu, Shen Lin, Robert Knepper',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Bobby Roth',
#  'Genre': 'Thriller',
#  'Language': 'English, Chinese',
#  'Metascore': 'N/A',
#  'Plot': 'After being stabbed in the heart by ruthless home invaders, a man is '
#          'left for dead. Now weak, outnumbered, and knife sticking from his '
#          'chest, he attempts to do the impossible: save his wife from these '
#          'murderers before he bleeds to death.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYzM3OGVkOTAtZWQ5Ni00MDUzLTlhYjUtYmU3OTk2YTllZTU2XkEyXkFqcGdeQXVyMTAwNzgxMzQ@._V1_SX300.jpg',
#  'Production': 'Parkside Pictures',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.5/10'}],
#  'Released': '01 Aug 2018',
#  'Response': 'True',
#  'Runtime': '91 min',
#  'Title': 'Edge of Fear',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Scott Barkan, Gregg Zehentner, Daxing Zhang (story)',
#  'Year': '2018',
#  'imdbID': 'tt7149916',
#  'imdbRating': '4.5',
#  'imdbVotes': '1,550'}
# -------------------
# movie id tt6042756
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Joseph Forsberg',
#  'Genre': 'Horror',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'Feeling guilty about her parents death and determined to live up to '
#          'their expectations, Rylee will stop at nothing to become an actress, '
#          'no matter what the cost.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Edge of Insanity',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joseph Forsberg',
#  'Year': '2017',
#  'imdbID': 'tt6042756',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6384998
# -------------------
# {'Actors': 'Michael Marcel, Marem Hassler, Alexandra Peters, Monte Markham',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jeff Houkal',
#  'Genre': 'Drama, Horror, Thriller',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'Stranded deep in the woods, a young married couple is taken in by an '
#          'isolationist family, one that lives off the blood and plunder from '
#          'lost hikers, and they want the couple to stay for the rest of their '
#          'lives.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDI1MTQ4YTEtMzQyZi00MzNiLTg4NWQtZjc3NWI2YjNiMzRmXkEyXkFqcGdeQXVyMzMwMjI2NA@@._V1_SX300.jpg',
#  'Production': 'Indie Rights',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.4/10'}],
#  'Released': '20 Apr 2018',
#  'Response': 'True',
#  'Runtime': '89 min',
#  'Title': 'Edge of Isolation',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jeff Houkal',
#  'Year': '2018',
#  'imdbID': 'tt6384998',
#  'imdbRating': '3.4',
#  'imdbVotes': '230'}
# -------------------
# movie id tt7267616
# -------------------
# {'Actors': 'Noah Alford, Brent Anderson, Megan Dalby, Jonathan Daviss',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Randy Redroad',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A cross country coach leads a team of troubled kids as he battles '
#          'his own crisis of faith.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BM2FjYTcyZGEtNjJiMi00N2FhLTllN2MtMjU1YzI3OThiNWI3XkEyXkFqcGdeQXVyMjIxMTM3Nzk@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.3/10'}],
#  'Released': '05 May 2018',
#  'Response': 'True',
#  'Runtime': '83 min',
#  'Title': 'Edge of the World',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Charla Driver, Colin Holmes, Richard W. Munchkin',
#  'Year': '2018',
#  'imdbID': 'tt7267616',
#  'imdbRating': '4.3',
#  'imdbVotes': '9'}
# -------------------
# movie id tt5326708
# -------------------
# {'Actors': 'Jenna Marie Huffstetler, Stephen Mackenzie Brown, Brice Anthony '
#            'Heller, Kimberly Hester Huffstetler',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Trey Riley',
#  'Genre': 'Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A young couple just graduating high school embarks on the biggest '
#          'step of their life together. With 750 miles between them they '
#          'struggle to hold onto what they once knew and grew to love. ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMWRkNTJhYTgtZGVlZi00NzBmLWJjNDMtYzhmMjFkZGZkZWQ1XkEyXkFqcGdeQXVyMTQxNTkwMjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Education in Love',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Trey Riley',
#  'Year': '2017',
#  'imdbID': 'tt5326708',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7317324
# -------------------
# {'Actors': 'Christina Hendricks, Alysia Reiner, David Alan Basche, Anna Camp',
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '18 Jan 2019',
#  'Director': 'Marianna Palka',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': '74',
#  'Plot': 'Centers on conceptual artist Tina (Reiner), when she introduces her '
#          'eight-month pregnant art school rival (Hendricks) to her '
#          'non-traditional surrogate Kiki (Camp). The truth comes outs and the '
#          'patriarchy fights to hang on.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYTVmOTc3ZWEtZTdjMy00ZGQ4LThlZTgtMjQzZTA3MDBiYjJlXkEyXkFqcGdeQXVyNDI3NDU1Mw@@._V1_SX300.jpg',
#  'Production': 'Gravitas Ventures',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.9/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '100%'},
#              {'Source': 'Metacritic', 'Value': '74/100'}],
#  'Released': '29 Mar 2019',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Egg',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Risa Mickenberg',
#  'Year': '2018',
#  'imdbID': 'tt7317324',
#  'imdbRating': '4.9',
#  'imdbVotes': '533'}
# -------------------
# movie id tt7014006
# -------------------
# {'Actors': 'Elsie Fisher, Josh Hamilton, Emily Robinson, Jake Ryan',
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '25 Sep 2018',
#  'Director': 'Bo Burnham',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': '89',
#  'Plot': 'An introverted teenage girl tries to survive the last week of her '
#          'disastrous eighth grade year before leaving to start high school.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzVlYzgxYjAtYzhhZi00MDc1LTlkZDMtMTRhZWI0MTg5YTRjXkEyXkFqcGdeQXVyNTAzMTY4MDA@._V1_SX300.jpg',
#  'Production': 'A24',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.4/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '99%'},
#              {'Source': 'Metacritic', 'Value': '89/100'}],
#  'Released': '03 Aug 2018',
#  'Response': 'True',
#  'Runtime': '93 min',
#  'Title': 'Eighth Grade',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Bo Burnham',
#  'Year': '2018',
#  'imdbID': 'tt7014006',
#  'imdbRating': '7.4',
#  'imdbVotes': '50,066'}
# -------------------
# movie id tt7246548
# -------------------
# {'Actors': 'Sammi Rotibi, Razaaq Adoti, Jaime Zevallos, Johnny Rey Diaz',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Razaaq Adoti',
#  'Genre': 'N/A',
#  'Language': 'English, Spanish',
#  'Metascore': 'N/A',
#  'Plot': 'While on a road trip through Mexico an unsuspecting couple get '
#          'caught up in a bar fight and find themselves at the mercy of a local '
#          'cartel. Now forced to compete in an underground blood ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'El Africano',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Razaaq Adoti, Ray Horta',
#  'Year': '2018',
#  'imdbID': 'tt7246548',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt9292378
# -------------------
# {'Actors': 'Luis Arellano, Veri Diana Arias, Luis Bañuelos, Grace Becerra',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Karloz Saldana, Karloz Saldana',
#  'Genre': 'N/A',
#  'Language': 'Spanish',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZGQxMGZkMDAtOTY1Ni00NzdjLWFlYTItMmM0MThlNmJlMDIxXkEyXkFqcGdeQXVyNTg1MjQxMjM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Apr 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'El Cartel Del Diablo',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Karloz Saldana',
#  'Year': '2018',
#  'imdbID': 'tt9292378',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7374952
# -------------------
# {'Actors': 'Logan Arevalo, Julian Bray, Adolfo Alvarez, Marco Rodríguez',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ben Hernandez Bray',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': '46',
#  'Plot': 'A pair of twin brothers from East L.A. choose to live their lives '
#          'differently and end up on opposite sides of the law.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYzkyNDJhNDYtODkzMC00NjVmLWI1OWItOWI4ODQwMzZiMWYyXkEyXkFqcGdeQXVyMjM4NTM5NDY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.2/10'},
#              {'Source': 'Metacritic', 'Value': '46/100'}],
#  'Released': '03 May 2019',
#  'Response': 'True',
#  'Runtime': '108 min',
#  'Title': 'El Chicano',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ben Hernandez Bray, Joe Carnahan',
#  'Year': '2018',
#  'imdbID': 'tt7374952',
#  'imdbRating': '5.2',
#  'imdbVotes': '702'}
# -------------------
# movie id tt6836318
# -------------------
# {'Actors': 'Gerardo Zamora, Jose Luis Ruiz, Matthew Cullipher, Angelo '
#            'Paravalos',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'Peru, USA',
#  'DVD': 'N/A',
#  'Director': 'Alejandro Nieto-Polo',
#  'Genre': 'Action, Fantasy',
#  'Language': 'English, Spanish',
#  'Metascore': 'N/A',
#  'Plot': 'A drug lord in New York, named Damian, has created a new drug with '
#          'shocking effects. After various accidental deaths, the DEA and '
#          'police are led on a wild goose chase in the search for this...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZTQ2MWVkZWMtN2Q1NS00ZWQ4LWE2MTctOGYxMDJiMzk4Zjc5XkEyXkFqcGdeQXVyNzQwMTI1MTM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '15 Sep 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'El Cóndor en Nueva York',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jorge Cerna, Alejando Nieto-Polo, Jose Luis Ruiz',
#  'Year': '2018',
#  'imdbID': 'tt6836318',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4375346
# -------------------
# {'Actors': 'Tanner Thomason, Hal Dion, Annakate Chappell, Kate Tumanova',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Eljazz Rakhimbekov',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'El Freeman',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Erik Kjonaas, Eljazz Rakhimbekov',
#  'Year': '2015',
#  'imdbID': 'tt4375346',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4484636
# -------------------
# {'Actors': 'Monte Bezell, José Ramón Rosario, Joel A. Luna, Francesca Van '
#            'Horne',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ali Abouomar, Monte Bezell',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A former boxer, who is now a drug runner, is given a chance to come '
#          'back to the ring.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTdkNzgyMDktMjA4YS00YTYxLTgxNDktYWZkZjQxMzkwNWQ5XkEyXkFqcGdeQXVyMTk3ODA1OTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.7/10'}],
#  'Released': '16 Jan 2018',
#  'Response': 'True',
#  'Runtime': '69 min',
#  'Title': 'El Gallo',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joel A. Luna',
#  'Year': '2018',
#  'imdbID': 'tt4484636',
#  'imdbRating': '5.7',
#  'imdbVotes': '69'}
# -------------------
# movie id tt6804088
# -------------------
# {'Actors': 'Rick Cosnett, Kat Hoyos, Brad McMurray',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Sophie Webb',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '02 Mar 2018',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'El Mirador',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jon Cohen, Sophie Webb',
#  'Year': '2018',
#  'imdbID': 'tt6804088',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt9089852
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt7771900
# -------------------
# {'Actors': 'José María Mendiola, Marco Antonio Garcia, Alejandro Gonzalez, '
#            'James R. Gray',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ricardo Islas',
#  'Genre': 'N/A',
#  'Language': 'Spanish',
#  'Metascore': 'N/A',
#  'Plot': '"Run Fast Or Fly High" brings back slapstick comedy to the 21st '
#          'Century. Fasten your seat belts.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDI2OTY2MGQtODI2ZS00ZTYwLTg5MGEtODRlZWQ0MjU3MWM1XkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '28 Jan 2018',
#  'Response': 'True',
#  'Runtime': '100 min',
#  'Title': 'El Que No Corre, Vuela',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ricardo Islas',
#  'Year': '2018',
#  'imdbID': 'tt7771900',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4969388
# -------------------
# {'Actors': 'Osvaldo Fernandez, Chrystopher Niven, Macarena Montoya, Alejandro '
#            'Zenni',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ricky Gonzalez',
#  'Genre': 'Action',
#  'Language': 'Spanish',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '15 Apr 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'El Sicario',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2016',
#  'imdbID': 'tt4969388',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7093966
# -------------------
# {'Actors': 'Rodriana Jordan, Ansel Carpenter, Michonni Ward, Maxie Jones',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Christopher Santos Pyant',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Election Shuffle is a story about a 12 year old boy named Jeffrey '
#          'Lynn who decides to run for school president along with his friends. '
#          'Suddenly a cyber bully is trying to ruin his campaign ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Dec 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Election Shuffle',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Robert Johnson',
#  'Year': '2018',
#  'imdbID': 'tt7093966',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6850766
# -------------------
# {'Actors': 'Mia Serafino, Zachary Mooren, Erik Griffin, Kyle Howard',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Aaron Fradkin',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '05 Oct 2017',
#  'Response': 'True',
#  'Runtime': '106 min',
#  'Title': 'Electric Love',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Aaron Fradkin, Victoria Fratz',
#  'Year': '2017',
#  'imdbID': 'tt6850766',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6010972
# -------------------
# {'Actors': 'Terry Ray, Kevin Scott Allen',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Larry LaFond, Steve Rosenbaum',
#  'Genre': 'Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Brad and Gary hook up in a motel room after their tenth high school '
#          'reunion in 1983 small town Chillicothe, Ohio. One is so closeted '
#          'that he hides behind an invented a wife, and the other ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Electricity',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Terry Ray',
#  'Year': '2017',
#  'imdbID': 'tt6010972',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt10352596
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt6492262
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'N/A',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'The catalysts that provoked an atrocious event that sparked the '
#          'civil rights movement.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 May 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Element of Fear',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2018',
#  'imdbID': 'tt6492262',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5611404
# -------------------
# {'Actors': 'Jonney Ahmanson, Shaughn Buchholz, Cassi Colvin, Paul De Sousa',
#  'Awards': '5 wins.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Assaf Ben Shetrit',
#  'Genre': 'Comedy, Family, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Elements of Matter is about a famous actress who has a nervous '
#          'breakdown during a junket for a new franchise film. She asks a '
#          "complete stranger (who mistakenly thinks he's rented her ...",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BN2I0MDNmYmItZGYxMS00ZDQ4LTgwNjAtZWYwOTUxODdjZTJjXkEyXkFqcGdeQXVyNTM0MDc1ODE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'TV-MA',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.1/10'}],
#  'Released': '27 Feb 2018',
#  'Response': 'True',
#  'Runtime': '97 min',
#  'Title': 'Elements of Matter',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Assaf Ben Shetrit',
#  'Year': '2018',
#  'imdbID': 'tt5611404',
#  'imdbRating': '4.1',
#  'imdbVotes': '57'}
# -------------------
# movie id tt7125498
# -------------------
# {'Actors': 'Luca Malacrino, Allison Blaize, Lauren Kelly, Aric Coppola',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Alex Hanno',
#  'Genre': 'Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When a fiery young couple attempts to rekindle their relationship '
#          'after three years apart, the highs and lows of their passion leave '
#          'the pair wondering if nostalgia is enough to keep them together.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMDQxNjhkZDktMjU5Ni00OTJjLTg4YzYtZGY1YzMxMGY5YjExXkEyXkFqcGdeQXVyMzMwMjI2NA@@._V1_SX300.jpg',
#  'Production': 'Indie Rights',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.0/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '80%'}],
#  'Released': '07 Dec 2018',
#  'Response': 'True',
#  'Runtime': '91 min',
#  'Title': 'Elephants',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Alex Hanno',
#  'Year': '2018',
#  'imdbID': 'tt7125498',
#  'imdbRating': '6.0',
#  'imdbVotes': '267'}
# -------------------
# movie id tt2719752
# -------------------
# {'Actors': 'Brianna Brown, Alexis Carra, Kit Williamson, Charlotte Marie',
#  'Awards': '1 win & 1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Angela Matemotja',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A day in the life of six people caught in the grips of racism, '
#          'homophobia and body obsession. Centered around a broken elevator, '
#          'fundamental aspects of their lives are forever changed as ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
# ...
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.6/10'}],
#  'Released': '13 Apr 2018',
#  'Response': 'True',
#  'Runtime': '92 min',
#  'Title': 'Marla Mae',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Lisa van Dam-Bates',
#  'Year': '2018',
#  'imdbID': 'tt4809590',
#  'imdbRating': '3.6',
#  'imdbVotes': '93'}
# -------------------
# movie id tt7551724
# -------------------
# {'Actors': 'Amber Tate, Christian Baxter Mott, Jennifer S. New, Matthew '
#            'McCrocklin',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kalyn Andrews',
#  'Genre': 'Drama',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjBkODlkYTEtNTc2Zi00YWRhLWFhNzMtNzY2NjViMDQ2ZDVhXkEyXkFqcGdeQXVyODE3MTUzODA@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Marley',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kalyn Andrews, Jessica Laurie, Christian Baxter Mott',
#  'Year': '2018',
#  'imdbID': 'tt7551724',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4949288
# -------------------
# {'Actors': 'Beth Broderick, Brett Cullen, Sammy Sheik, Alicia Vita Jones',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'Egypt, Kuwait, USA',
#  'DVD': 'N/A',
#  'Director': 'Noor Arnaoot',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A fun, culture-clash, fish-out-of-water wedding comedy involving two '
#          'very different families bought together by marriage, who are forced '
#          'to meet, interact, clash and ultimately find ways to be with one '
#          'another.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '100 min',
#  'Title': 'Marriage: Impossible',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Noor Arnaoot, Noor Arnaoot (story), Loay Elsayed',
#  'Year': '2015',
#  'imdbID': 'tt4949288',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8119788
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt8908288
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt4816366
# -------------------
# {'Actors': 'Patrick D. Green, Cami Marie, Montetré, Jonah Kersey',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Montetré',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Filmed entirely in a single shot, undercover FBI Agent Marty tracks '
#          'down the Cabby Killer in his old hometown, dredging up past feelings '
#          'and relationships - and also forging new ones.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Marty in Transit',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Montetré',
#  'Year': '2015',
#  'imdbID': 'tt4816366',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5360996
# -------------------
# {'Actors': 'Rooney Mara, Joaquin Phoenix, Chiwetel Ejiofor, Tahar Rahim',
#  'Awards': '1 win & 5 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'UK, Australia, USA',
#  'DVD': '19 Apr 2019',
#  'Director': 'Garth Davis',
#  'Genre': 'Biography, Drama',
#  'Language': 'English, Hebrew',
#  'Metascore': '48',
#  'Plot': 'Twelve men heard and spread the message of Jesus. Only one woman '
#          'understood it.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYTVjYmUxZDQtMDU0ZC00MzU0LWIwOTYtYjM1NjFiZmE1ZDBlXkEyXkFqcGdeQXVyODY3Nzc0OTk@._V1_SX300.jpg',
#  'Production': 'IFC Films',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '45%'},
#              {'Source': 'Metacritic', 'Value': '48/100'}],
#  'Released': '16 Mar 2018',
#  'Response': 'True',
#  'Runtime': '120 min',
#  'Title': 'Mary Magdalene',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Helen Edmundson, Philippa Goslett',
#  'Year': '2018',
#  'imdbID': 'tt5360996',
#  'imdbRating': '5.8',
#  'imdbVotes': '6,771'}
# -------------------
# movie id tt5028340
# -------------------
# {'Actors': 'Emily Blunt, Lin-Manuel Miranda, Ben Whishaw, Emily Mortimer',
#  'Awards': 'Nominated for 4 Oscars. Another 18 wins & 90 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, UK',
#  'DVD': 'N/A',
#  'Director': 'Rob Marshall',
#  'Genre': 'Comedy, Family, Fantasy, Musical',
#  'Language': 'English',
#  'Metascore': '66',
#  'Plot': 'Decades after her original visit, the magical nanny returns to help '
#          "the Banks siblings and Michael's children through a difficult time "
#          'in their lives.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjQxNjE3NjYxN15BMl5BanBnXkFtZTgwMTk2NDQ3NjM@._V1_SX300.jpg',
#  'Production': 'Walt Disney Pictures',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.8/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '79%'},
#              {'Source': 'Metacritic', 'Value': '66/100'}],
#  'Released': '19 Dec 2018',
#  'Response': 'True',
#  'Runtime': '130 min',
#  'Title': 'Mary Poppins Returns',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'P.L. Travers (based upon the "Mary Poppins" stories by), David '
#            'Magee (screen story by), Rob Marshall (screen story by), John '
#            'DeLuca (screen story by), David Magee (screenplay by)',
#  'Year': '2018',
#  'imdbID': 'tt5028340',
#  'imdbRating': '6.8',
#  'imdbVotes': '64,106'}
# -------------------
# movie id tt2328900
# -------------------
# {'Actors': 'Angela Bain, Richard Cant, Guy Rhys, Thom Petty',
#  'Awards': 'Nominated for 2 Oscars. Another 5 wins & 19 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'UK, USA',
#  'DVD': 'N/A',
#  'Director': 'Josie Rourke',
#  'Genre': 'Biography, Drama, History',
#  'Language': 'English, French, Scottish Gaelic, Latin',
#  'Metascore': '60',
#  'Plot': "Mary Stuart's attempt to overthrow her cousin Elizabeth I, Queen of "
#          'England, finds her condemned to years of imprisonment before facing '
#          'execution.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDVmOGI4MTMtYmNmNC00MTliLTlkYjQtYmU2N2EyNDk2YTAwXkEyXkFqcGdeQXVyMjM4NTM5NDY@._V1_SX300.jpg',
#  'Production': 'Metrodome',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'},
#              {'Source': 'Metacritic', 'Value': '60/100'}],
#  'Released': '21 Dec 2018',
#  'Response': 'True',
#  'Runtime': '124 min',
#  'Title': 'Mary Queen of Scots',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Beau Willimon (screenplay by), John Guy (based on the book "Queen '
#            'of Scots: The True Life of Mary Stuart" by)',
#  'Year': '2018',
#  'imdbID': 'tt2328900',
#  'imdbRating': '6.3',
#  'imdbVotes': '30,656'}
# -------------------
# movie id tt5247378
# -------------------
# {'Actors': 'Brandon Ferguson, Victoria Fox, Laura Shettleworth, Nick Bailey',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tiffany Nettles',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': "Massacre at Bluff's Ridge",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tiffany Nettles',
#  'Year': '2016',
#  'imdbID': 'tt5247378',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt9027294
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt7108024
# -------------------
# {'Actors': 'Brianna Hope Beaton, Cameron Arnett, B.J. Arnett, Cynthia D. Perry',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Cameron Arnett',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A young girl, growing up in a tumultuous home, discovers that she '
#          'can see what others can not. Will she use it for good or evil?',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTM4M2JiMjItNzI0Ni00ODI5LWFmOGItM2JhZDUyYzAxYTk5XkEyXkFqcGdeQXVyMzM3MzQ3NzM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '15 Feb 2018',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Mattie: The Discovery',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Terri L. Bea Sopher',
#  'Year': '2018',
#  'imdbID': 'tt7108024',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7809198
# -------------------
# {'Actors': 'Aleis Work, Cole Allen, Charlotte Delaney Riggs, Sofia Buntz',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Sofia Martinez',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'May I Be at Peace follows the lives and recoveries of several '
#          'children in an eating disorder hospital.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZDUzNzMzOTktZGNkNS00YjRiLWFiMTktMTIwOTI0MzQyMzk1XkEyXkFqcGdeQXVyNjczNjgwMjI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '04 Nov 2018',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': 'May I Be at Peace',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Sofia Martinez',
#  'Year': '2018',
#  'imdbID': 'tt7809198',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7294234
# -------------------
# {'Actors': 'Rob Mayes, Isabella Blake-Thomas, Daniella Alonso, Kelly Sullivan',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Elizabeth Blake-Thomas',
#  'Genre': 'Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': '"Maybe I\'m Fine" is the story of a young girl, Sam Childs played by '
#          'Isabella Blake-Thomas (from "Once"), who is tasked with helping her '
#          'mother, Denise, divorce her deadbeat musician ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOWFiZGY3NmItODg0Ni00ZTJmLWE0YzUtOTI2N2MzYzlkZTMxXkEyXkFqcGdeQXVyNjc1ODAzODQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Aug 2018',
#  'Response': 'True',
#  'Runtime': '98 min',
#  'Title': "Maybe I'm Fine",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Elizabeth Blake-Thomas, Isabella Blake-Thomas, Miriam Esther '
#            'Goldman, Nathan Carliner Goldman, Casey Greenberg',
#  'Year': '2018',
#  'imdbID': 'tt7294234',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7752258
# -------------------
# {'Actors': "Birgit Ludemann, Selena O'Sullivan, John Paul Medrano, Andres "
#            'Antonio Pérez',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A story about stories. Los Angeles, city of dreams, is home to '
#          'Frankie and Cecelia. Stuck in their lives, stuck in love. But when '
#          "an unfortunate accident rocks their neighborhood, it's not ...",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDg3NGUzYWYtMTY1OS00NDNjLWEwNWUtN2ZmMDdlN2JjNTA3XkEyXkFqcGdeQXVyMjgxMjYyNTY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '15 Mar 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Maybe Not Today',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2018',
#  'imdbID': 'tt7752258',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7206942
# -------------------
# {'Actors': 'Kelsey Thomas, Megan Simon, Rachel DeRouen, Jeff Pearson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Phillip Lybrand',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Ash, Shannon, and Wendy are all late. You know... LATE. As their '
#          'collective anxiety grows, they band together to face their fears, '
#          'confront the potential fathers, and egg a car or two. All part of '
#          "the world's first MAYBE SHOWER.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMmUxZTI4YzgtYmNiOS00MGNkLTkxZGYtOWUzNGJkYmYwNGQxXkEyXkFqcGdeQXVyMjI2MTI0MQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'}],
#  'Released': '14 Jun 2018',
#  'Response': 'True',
#  'Runtime': '81 min',
#  'Title': 'Maybe Shower',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Phillip Lybrand',
#  'Year': '2018',
#  'imdbID': 'tt7206942',
#  'imdbRating': '6.1',
#  'imdbVotes': '25'}
# -------------------
# movie id tt4500922
# -------------------
# {'Actors': "Dylan O'Brien, Ki Hong Lee, Kaya Scodelario, Thomas "
#            'Brodie-Sangster',
#  'Awards': '6 nominations.',
#  'BoxOffice': '$57,074,211',
#  'Country': 'USA',
#  'DVD': '24 Apr 2018',
#  'Director': 'Wes Ball',
#  'Genre': 'Action, Adventure, Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': '50',
#  'Plot': 'Young hero Thomas embarks on a mission to find a cure for a deadly '
#          'disease known as "The Flare".',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTYyNzk3MDc2NF5BMl5BanBnXkFtZTgwMDk3OTM1NDM@._V1_SX300.jpg',
#  'Production': '20th Century Fox',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '43%'},
#              {'Source': 'Metacritic', 'Value': '50/100'}],
#  'Released': '26 Jan 2018',
#  'Response': 'True',
#  'Runtime': '143 min',
#  'Title': 'Maze Runner: The Death Cure',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'T.S. Nowlin (screenplay by), James Dashner (based upon the novel '
#            'by)',
#  'Year': '2018',
#  'imdbID': 'tt4500922',
#  'imdbRating': '6.2',
#  'imdbVotes': '98,780'}
# -------------------
# movie id tt7831092
# -------------------
# {'Actors': 'Stephanie Town, Zachary Vazquez, Evette Young, Kevin Winn',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Anthony Penney',
#  'Genre': 'Biography, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A part documentary, part drama film where real life victims of sex '
#          'crimes act out their stories with documented interviews throughout '
#          'the film.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMGJiMDkyZmMtMjQzMS00NGI3LTgzOTYtNTMxYjc0ZGI1ZjI0XkEyXkFqcGdeQXVyNzk5MTc2ODM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '04 Jul 2018',
#  'Response': 'True',
#  'Runtime': '60 min',
#  'Title': 'Me Too',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Anthony Penney',
#  'Year': '2018',
#  'imdbID': 'tt7831092',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt10203806
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt9037174
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt2431458
# -------------------
# {'Actors': 'Sadie Katz, Peter Alzado, Ase, Suziey Block',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Gregory Rhoades',
#  'Genre': 'Action',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Ian Winter, a jobless ex-con, has left the life of crime with a '
#          'promise that he will get his life in order. But his first job turns '
#          'into a bloodbath. A group of cut-throat African gangsters murder his '
#          "girlfriend. Now Ian's out for blood.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjI2NTg4OTM0N15BMl5BanBnXkFtZTgwOTk1Mzk1MDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Meaning of Violence',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Gerald Rhoades',
#  'Year': '2014',
#  'imdbID': 'tt2431458',
#  'imdbRating': '6.3',
#  'imdbVotes': '11'}

# %%
len(title_list)
# Out:
# 844

# %%
len(title_id)
# Out:
# 844

# %%
# if title_list and title_id are the same length run the cell below. 
# if they are not equal take out 'title_id': title_id

# %%
df = pd.DataFrame({'title_id': title_id, 'title': title_list, 'box_office': box_office_list, 'country': country_list, 
                   'genre': genre_list, 'director': director_list, 'metascore': metascore_list, 'production': production_list, 
                   'rating': rating_list, 'IMDB_rating': IMDB_rating_list, 'rotten_tomatoes_rating': rotten_tomatoes_rating_list, 
                  'runtime': runtime_list, 'type': type_list, 'IMDB_votes': imdb_votes_list})

# %%
df = df.drop_duplicates()
df.head()
# Out:
#     title_id               title box_office       country  \
# 0  tt8192676          Dragon Kin        N/A           USA
# 1  tt7220318        Drawing Dead        N/A           USA
# 2  tt2208868       Dream Country        N/A           USA
# 3  tt7296604           Dream Man        N/A  USA, Vietnam
# 4  tt5478918  Dreams I Never Had        N/A           USA
#
#                         genre  \
# 0  Adventure, Comedy, Fantasy
# 1                         N/A
# 2                     Fantasy
# 3                    Thriller
# 4                       Drama
#
#                                             director metascore production  \
# 0  Tarmac Brothers, Joshua Kerr(co-director), Mic...       N/A        N/A
# 1                                          Bob Clark       N/A        N/A
# 2                                     Robert Rollins       N/A        N/A
# 3                                      Roland Nguyen       N/A        N/A
# 4                         Iyad Hajjaj, Mahmoud Kamel       N/A        N/A
#
#   rating IMDB_rating rotten_tomatoes_rating runtime   type IMDB_votes
# 0    N/A         N/A                     NA  55 min  movie        N/A
# 1    N/A         N/A                     NA     N/A  movie        N/A
# 2    N/A         N/A                     NA     N/A  movie        N/A
# 3    N/A         N/A                     NA  95 min  movie        N/A
# 4    N/A         6.2                     NA  81 min  movie         75

# %%
df.count()
# Out:
# title_id                  844
# title                     844
# box_office                844
# country                   844
# genre                     844
# director                  844
# metascore                 844
# production                844
# rating                    844
# IMDB_rating               844
# rotten_tomatoes_rating    844
# runtime                   844
# type                      844
# IMDB_votes                844
# dtype: int64

# %%
df.to_csv('Resources/data/2018_data_batch_2.csv', index=False)
