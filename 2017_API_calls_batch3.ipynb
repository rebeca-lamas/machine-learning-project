# %%
import pandas as pd
import requests
import json
import time
from pprint import pprint
from config import API_KEY

# %%
data = pd.read_csv('Resources/titles_2017_batch3.csv')
df =  data.count()
df
# Out:
# title    1000
# dtype: int64

# %%
title_id = []
box_office_list = []
country_list = []
genre_list = []
director_list = []
metascore_list = []
production_list = []
rating_list = []
IMDB_rating_list = [] 
rotten_tomatoes_rating_list = []
runtime_list = []
title_list = []
type_list = []
imdb_votes_list = []

# %%
movies = data['title']
total_movies = len(movies)

# %%
for i in range(total_movies):
    movie = movies[i]
    url = "http://www.omdbapi.com/?i=" + movie + "&apikey=" + API_KEY
    response = (requests.get(url).text)
    response_json = json.loads(response)
    print('-------------------')
    print(f'movie id {movie}')
    print('-------------------')
    pprint(response_json)
    
    try:
        box_office_list.append(response_json['BoxOffice'])
        country_list.append(response_json['Country'])
        genre_list.append(response_json['Genre'])
        director_list.append(response_json['Director'])
        metascore_list.append(response_json['Metascore'])
        production_list.append(response_json['Production'])
        rating_list.append(response_json['Rated'])
        IMDB_rating_list.append(response_json['imdbRating'])
        try:
            if not response_json['Ratings']:
                rotten_tomatoes_rating_list.append('NA')
            elif response_json['Ratings'][0]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][0]['Value'])
            elif response_json['Ratings'][1]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][1]['Value'])
            else:
                rotten_tomatoes_rating_list.append('NA')
        except IndexError:
            rotten_tomatoes_rating_list.append('NA')
        runtime_list.append(response_json['Runtime'])
        title_list.append(response_json['Title'])
        type_list.append(response_json['Type'])
        imdb_votes_list.append(response_json['imdbVotes'])
        title_id.append(response_json['imdbID'])
    except KeyError:
        pass
    time.sleep(1)
# Out:
# -------------------
# movie id tt7390046
# -------------------
# {'Actors': 'Shakhbout al Kaabi, Reem Almenhali, Devika Bhise, Ali Brivanlou',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Canada, Haiti, Trinidad and Tobago, United Arab Emirates, UK',
#  'DVD': 'N/A',
#  'Director': 'Miryam Charles, Josephine Decker, Alexis Gambis, Barry J. Gibb, '
#              'Ian Harnarine, Noah Hutton, Demelza Kooij, Jeannette Louie, '
#              'Rachel Mayeri, Sally Warring',
#  'Genre': 'Drama, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A dissection of hybrid identity in ten chapters through the life of '
#          "a chimeric evolving creature 'Mosaic' and confessions by the most "
#          'influentials scientists of our time.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYzE1OGIyZjQtZjMxOS00NzhlLTk1ODctNTNlODFhNjVmZWM4XkEyXkFqcGdeQXVyMjExMzQxMzU@._V1_SX300.jpg',
#  'Production': 'Home Box Office (HBO)',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '13 Oct 2017',
#  'Response': 'True',
#  'Runtime': '98 min',
#  'Title': 'Mosaic',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Miryam Charles, Josephine Decker, Alexis Gambis, Barry J. Gibb, '
#            'Ian Harnarine, Noah Hutton, Demelza Kooij, Chris Lindsay, '
#            'Jeannette Louie, Rachel Mayeri, Sally Warring',
#  'Year': '2017',
#  'imdbID': 'tt7390046',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7767628
# -------------------
# {'Actors': 'William Charles Bresch, Lucas Bush, Patrick Campion, Gilbert '
#            'Cannatella',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Migdalia Etheridge, Ray Etheridge',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A wealthy drug lord offers $2-million to anyone who can spring his '
#          'son "Lenny" from prison. A jail break is attempted...and '
#          'botched...as Lenny works on a chain gang. He is forced to flee ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYTBmYTc0MjQtNjA0ZC00NzFiLTkyZGEtMTU2NjYzYmMxYmE4XkEyXkFqcGdeQXVyMjM0MjM4MTI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Dec 2017',
#  'Response': 'True',
#  'Runtime': '46 min',
#  'Title': 'Mosquitos, Alligators, and Bullets',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ray Etheridge',
#  'Year': '2017',
#  'imdbID': 'tt7767628',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5564932
# -------------------
# {'Actors': 'Christine Marzano, Mitchell Slaggert, Cohen Bratcher, Billy Ray '
#            'Suggs',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Daniel Peddle',
#  'Genre': 'Adventure, Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'In this Southern Gothic coming-of-age tale, an isolated and troubled '
#          'young man, Moss, meets a mysterious and beautiful hiker on the banks '
#          'of the river near his home on his eighteenth ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '81 min',
#  'Title': 'Moss',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Daniel Peddle, Daniel Peddle',
#  'Year': '2016',
#  'imdbID': 'tt5564932',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4866448
# -------------------
# {'Actors': 'Ana Asensio, Natasha Romanova, David Little, Nicholas Tucci',
#  'Awards': '2 wins & 5 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '02 Nov 2017',
#  'Director': 'Ana Asensio',
#  'Genre': 'Drama, Horror, Thriller',
#  'Language': 'Spanish, English',
#  'Metascore': '73',
#  'Plot': 'Most Beautiful Island is a chilling portrait of an undocumented '
#          "young woman's struggle for survival as she finds redemption from a "
#          'tortured past in a dangerous game.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BY2FiYTk1MTEtYjgyMi00MjA5LWJkZjktMTNhZmVkMWI3NWRkXkEyXkFqcGdeQXVyMjE4NzUxNDA@._V1_SX300.jpg',
#  'Production': 'Samuel Goldwyn Films',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.7/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '93%'},
#              {'Source': 'Metacritic', 'Value': '73/100'}],
#  'Released': '03 Nov 2017',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'Most Beautiful Island',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ana Asensio',
#  'Year': '2017',
#  'imdbID': 'tt4866448',
#  'imdbRating': '5.7',
#  'imdbVotes': '2,519'}
# -------------------
# movie id tt5094886
# -------------------
# {'Actors': 'Josue Louis-Charles, Laurel Levey, Suki Sullivan, Danielle Atwood',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Garry Evans, Geary Evans',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODQyMjM5MzgtOGFmOC00ODdiLThhZTItMjQ0MjgwN2RhODY1XkEyXkFqcGdeQXVyNTcyMTc3ODY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '18 Oct 2017',
#  'Response': 'True',
#  'Runtime': '45 min',
#  'Title': 'Mother in Law',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Garry Evans, Geary Evans',
#  'Year': '2017',
#  'imdbID': 'tt5094886',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5109784
# -------------------
# {'Actors': 'Jennifer Lawrence, Javier Bardem, Ed Harris, Michelle Pfeiffer',
#  'Awards': '8 wins & 35 nominations.',
#  'BoxOffice': '$17,297,289',
#  'Country': 'USA',
#  'DVD': '19 Dec 2017',
#  'Director': 'Darren Aronofsky',
#  'Genre': 'Drama, Horror, Mystery',
#  'Language': 'English',
#  'Metascore': '75',
#  'Plot': "A couple's relationship is tested when uninvited guests arrive at "
#          'their home, disrupting their tranquil existence.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzc5ODExODE0MV5BMl5BanBnXkFtZTgwNDkzNDUxMzI@._V1_SX300.jpg',
#  'Production': 'Paramount Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '69%'},
#              {'Source': 'Metacritic', 'Value': '75/100'}],
#  'Released': '15 Sep 2017',
#  'Response': 'True',
#  'Runtime': '121 min',
#  'Title': 'Mother!',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Darren Aronofsky',
#  'Year': '2017',
#  'imdbID': 'tt5109784',
#  'imdbRating': '6.6',
#  'imdbVotes': '169,561'}
# -------------------
# movie id tt9403974
# -------------------
# {'Actors': 'Matthew B. Henry, Jessica Knott, Dakota Shepard, Vincent Volaju',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Brandon Kyle',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZGU0ODhiMWMtZjRhNy00YmU2LTg4YjUtMGU2MmIxZDM1MjhiXkEyXkFqcGdeQXVyMjcyODY1Mjc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '50 min',
#  'Title': "Mother's Keeper",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Brandon Kyle (Writer)',
#  'Year': '2017',
#  'imdbID': 'tt9403974',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6341094
# -------------------
# {'Actors': 'Eric Altman, Eddie Benevich, Dennis Dean, Ron Gallucci',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ryan Cavalline',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Based on the true events that occurred in the Appalachian Mountains, '
#          'Mountain Devil recounts the frightening events of the night Frank '
#          'Peterson and his friend spent the night in a secluded ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjIxNzM4MDYzNF5BMl5BanBnXkFtZTgwNDY1NDg4MDI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.1/10'}],
#  'Released': '17 Jan 2017',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'Mountain Devil',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ryan Cavalline',
#  'Year': '2017',
#  'imdbID': 'tt6341094',
#  'imdbRating': '3.1',
#  'imdbVotes': '73'}
# -------------------
# movie id tt3305388
# -------------------
# {'Actors': 'Barry Corbin, Coby Ryan McLaughlin, Valerie Azlynn, Lin Shaye',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Gary Wheeler',
#  'Genre': 'Drama, Family, Mystery',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A lawyer-turned-preacher living in a small Appalachian town is '
#          'pursued by an eccentric man to represent him in court. Now involved '
#          'in a case that ties into his own small-town life, the former '
#          'attorney agrees to help a man.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjhlMGJjNzctMTY5Ny00ODUyLWFlOWUtMDlkMmQ1ZjRiYzcxXkEyXkFqcGdeQXVyMzU0MTQyNg@@._V1_SX300.jpg',
#  'Production': 'Level Path Productions',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.5/10'}],
#  'Released': '10 Feb 2017',
#  'Response': 'True',
#  'Runtime': '102 min',
#  'Title': 'Mountain Top',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Gary Wheeler, Robert Whitlow',
#  'Year': '2017',
#  'imdbID': 'tt3305388',
#  'imdbRating': '7.5',
#  'imdbVotes': '213'}
# -------------------
# movie id tt6432324
# -------------------
# {'Actors': 'Jerome Smith',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jerome Smith',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjk5YjI3NTQtMDU3MS00ZmY0LTg1NWEtZWNhYmI1NDQ3NGVmL2ltYWdlXkEyXkFqcGdeQXVyMzc4NzU5NzQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '16 Feb 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Movements',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jerome Smith (screenplay)',
#  'Year': '2017',
#  'imdbID': 'tt6432324',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6460858
# -------------------
# {'Actors': 'Macc Dundee',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ian Cranston',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Based on The Novel Trilogy "Be Like That Sometimes" and based on '
#          'Movers: A Rags to Riches Story written by BIZ NOLASTNAME.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTkyYWY3M2ItM2E1NC00NmMzLWFiNzEtZjk1ZGFlNTJiMjQxXkEyXkFqcGdeQXVyMjQxNTQ0NDU@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '9.2/10'}],
#  'Released': '22 Nov 2017',
#  'Response': 'True',
#  'Runtime': '120 min',
#  'Title': 'Movers: A Rags to Riches Story',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Biz Nolastname',
#  'Year': '2017',
#  'imdbID': 'tt6460858',
#  'imdbRating': '9.2',
#  'imdbVotes': '11'}
# -------------------
# movie id tt5266456
# -------------------
# {'Actors': 'T.J. Storm, Calhoun Koenig, Harley Wallen, Michael Alexander',
#  'Awards': '1 win.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '14 Nov 2017',
#  'Director': 'Jerry Hayes, Harley Wallen',
#  'Genre': 'Action, Crime, Drama, Mystery, Thriller',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'Two very different couples are drawn into organized crime, but it '
#          'becomes clear before long that everything and everyone is not what '
#          'they seem.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BN2FhYmJhMzEtMjJjYS00ZjY1LThjMGYtMzgwOWUxZjEwMDViXkEyXkFqcGdeQXVyNDg3NzEyMzY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'}],
#  'Released': '27 Mar 2018',
#  'Response': 'True',
#  'Runtime': '106 min',
#  'Title': 'Moving Parts',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Harley Wallen, Jerry Hayes (additional contribution), Kaiti Wallen '
#            '(additional contributions by), Nancy Oeswein (additional story '
#            'dialogue)',
#  'Year': '2017',
#  'imdbID': 'tt5266456',
#  'imdbRating': '5.4',
#  'imdbVotes': '336'}
# -------------------
# movie id tt4849360
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'John W. Lawson',
#  'Genre': 'Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Oct 2017',
#  'Response': 'True',
#  'Runtime': '94 min',
#  'Title': 'Mower Boy',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'John W. Lawson',
#  'Year': '2017',
#  'imdbID': 'tt4849360',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6737956
# -------------------
# {'Actors': "Lucian D'Stair, Sebastien D'Stair",
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': "Pablo D'Stair",
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Two young brothers strive to create, produce, and market nothing '
#          'short of an Eisner Award winning comic-book series based on the '
#          'notion that their father, when not plodding at his mundane ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMWYwMjE2ZDYtZWQ3MC00MTBjLWE0ZjEtNDFlZmRiMGVhZGYwXkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '9.0/10'}],
#  'Released': '03 Apr 2017',
#  'Response': 'True',
#  'Runtime': '55 min',
#  'Title': 'Mr Pickpocket',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': "Pablo D'Stair",
#  'Year': '2017',
#  'imdbID': 'tt6737956',
#  'imdbRating': '9.0',
#  'imdbVotes': '5'}
# -------------------
# movie id tt6212496
# -------------------
# {'Actors': 'Noël Wells, Nick Thune, Britt Lower, Daniella Pineda',
#  'Awards': '5 wins & 4 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Noël Wells',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': '73',
#  'Plot': 'After a loved one falls ill, 25 year old struggling comedian Emily '
#          'Martin returns to her college town of Austin, Texas and must come to '
#          'terms with her past while staying with her ex-boyfriend and his new '
#          'girlfriend.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZWJjMjdjMWYtMzJmZS00YTNkLTk0NzMtNjNjN2EwMzEyNjdiXkEyXkFqcGdeQXVyMjM4ODc5MzQ@._V1_SX300.jpg',
#  'Production': 'Paladin Films',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '100%'},
#              {'Source': 'Metacritic', 'Value': '73/100'}],
#  'Released': '22 Nov 2017',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Mr. Roosevelt',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Noël Wells',
#  'Year': '2017',
#  'imdbID': 'tt6212496',
#  'imdbRating': '6.2',
#  'imdbVotes': '2,125'}
# -------------------
# movie id tt3135074
# -------------------
# {'Actors': 'Christiane Paul, Francesco Mazzini, Stig Eldred, Michael Rothmann',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Germany, Italy',
#  'DVD': 'N/A',
#  'Director': 'Michael Glover',
#  'Genre': 'Comedy, Music, Musical',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Mr. Rudolpho's Jubilee is a romantic comedy with musical narration "
#          'by Bright Blue Gorilla! It is the story of a world-famous Italian '
#          'fashion designer who becomes disillusioned with his ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzcwMTgxNjYtNmU1OS00ZjFiLTkwMzgtNWJhOTQ1ZTdjZDIxXkEyXkFqcGdeQXVyMzAxNjQ3OA@@._V1_SX300.jpg',
#  'Production': 'Under the Milky Way',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '9.1/10'}],
#  'Released': '14 Jan 2017',
#  'Response': 'True',
#  'Runtime': '110 min',
#  'Title': "Mr. Rudolpho's Jubilee",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Glover, Valeria Anna Ferrario (translation), Mea '
#            'Machrowiak (translation)',
#  'Year': '2017',
#  'imdbID': 'tt3135074',
#  'imdbRating': '9.1',
#  'imdbVotes': '173'}
# -------------------
# movie id tt7174140
# -------------------
# {'Actors': 'Toshiya Agata, Livia Giovara, Rio June, Dan Lopecci',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Hector Abaunza',
#  'Genre': 'N/A',
#  'Language': 'Japanese',
#  'Metascore': 'N/A',
#  'Plot': 'Nearing Setsukos 40th birthday, starts seeing strange appearances in '
#          'the middle of the night, from a misterious lady who eventually we '
#          'find out is her Mom "Mrs. Tomiko" who passed away on ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZGRmNmRkMDItZGIyOC00NTNmLWIwYWYtMmUxMjJkNzBiMmI1XkEyXkFqcGdeQXVyNjM2NjQ3NDc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Sep 2017',
#  'Response': 'True',
#  'Runtime': '47 min',
#  'Title': 'Mrs. Tomiko',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Hector Abaunza, Oriko Ikeda',
#  'Year': '2017',
#  'imdbID': 'tt7174140',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6557458
# -------------------
# {'Actors': 'Winston Allen, Jeremy Herrera, Autumn Ivy, Bo Phillips',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Marcos Vidal',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Meet Adrian Stone, a dual mentally unstable artist who falls in love '
#          'with basic run of the mill girl named Allison Simon. Stone seems to '
#          'have an illusion of love that drives the two set the...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Mar 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Ms. Simon',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Nathan O. Miller, Marcos Vidal',
#  'Year': '2017',
#  'imdbID': 'tt6557458',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7201842
# -------------------
# {'Actors': 'Moriah Allison, Moriah Allison, Brittany Britton, Brittany Britton',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Latasha Wright, Latasha Wright, William E. Martin',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzQ5NmI3ZmQtOWViMy00ZjNjLWE3NTQtZmRmMjU4ZGFhNjA3XkEyXkFqcGdeQXVyMzU2MjI4OTI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '30 Jul 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Ms. Taken',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jake Hopkins (screenwriter), Tenisha Johnson, Kareem McMichael '
#            '(story editor)',
#  'Year': '2017',
#  'imdbID': 'tt7201842',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2396589
# -------------------
# {'Actors': 'Carey Mulligan, Garrett Hedlund, Jonathan Banks, Jason Clarke',
#  'Awards': 'Nominated for 4 Oscars. Another 26 wins & 91 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '17 Nov 2017',
#  'Director': 'Dee Rees',
#  'Genre': 'Drama, War',
#  'Language': 'English',
#  'Metascore': '85',
#  'Plot': 'Two men return home from World War II to work on a farm in rural '
#          'Mississippi, where they struggle to deal with racism and adjusting '
#          'to life after war.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZTg3YTEzNjYtZTY2NS00YjNmLTlhNjUtZTI2M2E5NDI4M2NjXkEyXkFqcGdeQXVyMzI3MDEzMzM@._V1_SX300.jpg',
#  'Production': 'Netflix',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.4/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '97%'},
#              {'Source': 'Metacritic', 'Value': '85/100'}],
#  'Released': '17 Nov 2017',
#  'Response': 'True',
#  'Runtime': '134 min',
#  'Title': 'Mudbound',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Virgil Williams (screenplay by), Dee Rees (screenplay by), Hillary '
#            'Jordan (based on the novel by)',
#  'Year': '2017',
#  'imdbID': 'tt2396589',
#  'imdbRating': '7.4',
#  'imdbVotes': '35,921'}
# -------------------
# movie id tt5835256
# -------------------
# {'Actors': 'Christopher Soren Kelly, Jessica Graham, Sheila Cutchlow, Edmund '
#            'Lupinski',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'David Palamaro',
#  'Genre': 'Thriller',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'Best pals Joan and Michael invite their dearest friends over for a '
#          "cordial dinner to discuss the passing of Joan's husband Neil. But as "
#          'each guest arrives, dark secrets are reveled and murder is '
#          'definitely on the menu.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYzJmMGI3NzQtMGU2MC00M2NiLTg5YjUtNzNlZjlkOWFmMjI5XkEyXkFqcGdeQXVyNTM5MDg5MA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Murder Made Easy',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tim Davis',
#  'Year': '2017',
#  'imdbID': 'tt5835256',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6083146
# -------------------
# {'Actors': 'José Julián, Jeanette Samano, Chelsea Rendon, Catherine Toribio',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Luis Iga',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTgxNmFkNDMtZDY0ZS00NDk2LWI2MmQtMzM1Mjk3NDc2YzBlXkEyXkFqcGdeQXVyMjY0MjA2Mjk@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Murder in the Woods',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Yelyna De Leon',
#  'Year': '2017',
#  'imdbID': 'tt6083146',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5326520
# -------------------
# {'Actors': 'Jade Harlow, Josh Walther, Heather Egeli, Tim Misuradze',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Arthur Egeli',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Based on the Christa Worthington case. An out of work fisherman has '
#          'an affair with a fashion writer wintering on the Cape. She returns '
#          'two years later with his child, and when she is murdered, the '
#          'fisherman is the prime suspect.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjliNzAxMDAtNzQ2NS00NmYxLTg1MzAtMTI3NzQwMWY5MzRiXkEyXkFqcGdeQXVyMTE4NTI5NTA@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'TV-MA',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.6/10'}],
#  'Released': '31 Aug 2017',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': 'Murder on the Cape',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ian Bowater, Arthur Egeli, Heather Egeli',
#  'Year': '2017',
#  'imdbID': 'tt5326520',
#  'imdbRating': '2.6',
#  'imdbVotes': '593'}
# -------------------
# movie id tt3402236
# -------------------
# {'Actors': "Paapa Essiedu, Yassine Zeroual, Asan N'Jie, Michael Rouse",
#  'Awards': '18 nominations.',
#  'BoxOffice': '$101,555,644',
#  'Country': 'Malta, USA',
#  'DVD': '27 Feb 2018',
#  'Director': 'Kenneth Branagh',
#  'Genre': 'Crime, Drama, Mystery',
#  'Language': 'English, French, German, Arabic',
#  'Metascore': '52',
#  'Plot': "When a murder occurs on the train on which he's travelling, "
#          'celebrated detective Hercule Poirot is recruited to solve the case.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTAxNDkxODIyMDZeQTJeQWpwZ15BbWU4MDQ2Mjg4NDIy._V1_SX300.jpg',
#  'Production': '20th Century Fox',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '60%'},
#              {'Source': 'Metacritic', 'Value': '52/100'}],
#  'Released': '10 Nov 2017',
#  'Response': 'True',
#  'Runtime': '114 min',
#  'Title': 'Murder on the Orient Express',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Green (screenplay by), Agatha Christie (based upon the '
#            'novel by)',
#  'Year': '2017',
#  'imdbID': 'tt3402236',
#  'imdbRating': '6.5',
#  'imdbVotes': '187,436'}
# -------------------
# movie id tt6666508
# -------------------
# {'Actors': 'Larry Guernsey',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Larry Guernsey',
#  'Genre': 'Animation, Mystery, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An animated sci-fi murder mystery on a starship featuring an all '
#          'non-human cast!',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '53 min',
#  'Title': 'Murder on the Starship Ergos',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Larry Guernsey (story), Larry Guernsey',
#  'Year': '2017',
#  'imdbID': 'tt6666508',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7147470
# -------------------
# {'Actors': 'William Patrick Coleman, Damario Dargan, Andrew Dubitsky, Paige '
#            'Fockler',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'William Patrick Coleman',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYzYxOTYxMTMtNmY0Ny00NDk0LWFiYzYtMmE2MGQyMWVlYWY4XkEyXkFqcGdeQXVyMjQ3NDExNQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '15 Nov 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Murph and Bern: Street Cops',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'William Patrick Coleman',
#  'Year': '2017',
#  'imdbID': 'tt7147470',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3951206
# -------------------
# {'Actors': 'Riley Egan, Elle Evans, Kate Mansi, Lou Ferrigno Jr.',
#  'Awards': '6 wins & 10 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'John Burr',
#  'Genre': 'Drama, Fantasy, Horror, Romance, Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "A painter's life is forever changed when a mythical and deadly "
#          'spirit from Celtic lore -- a Leannán Sí -- becomes his muse and '
#          'lover.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNWFiOGQwZDAtYTBiMy00YjY3LWI3OGYtMjU5MzM1MTA0ZjA1XkEyXkFqcGdeQXVyMzY4ODk1Nw@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.3/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '13%'}],
#  'Released': '09 Sep 2017',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': 'Muse',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'John Burr, John Burr',
#  'Year': '2017',
#  'imdbID': 'tt3951206',
#  'imdbRating': '5.3',
#  'imdbVotes': '206'}
# -------------------
# movie id tt7275980
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Raphael Cosme',
#  'Genre': 'Adventure, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Drake(Raphael Cosme), a soldier, is tormented by his Father's "
#          "stories on the world's demise passing it to his long-time friend "
#          'Aaron (Aaric Lupo). After the events of the 2014 Los Angeles ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTM0ZTc2ZmQtYmZjNy00N2UxLWJjZmEtYTFjNjYyOGM4MmI4XkEyXkFqcGdeQXVyNzQ2NjMwNjc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.1/10'}],
#  'Released': '04 Jun 2017',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'Mushino',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Raphael Cosme, Chris McGlothlin',
#  'Year': '2017',
#  'imdbID': 'tt7275980',
#  'imdbRating': '5.1',
#  'imdbVotes': '28'}
# -------------------
# movie id tt6589292
# -------------------
# {'Actors': 'Macon Blair, Lee Eddy, John Merriman, Molly Karrasch',
#  'Awards': '2 wins & 2 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Craig Elrod',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "After his girlfriend dumps him at a New Year's Eve party, Bill and "
#          'his friends drive to an off-season beach town to win her back.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzFiZWYyYmUtNTVkZC00OWFlLTk3NjAtNzJjMDAxMmNlYzIwXkEyXkFqcGdeQXVyMTkxMTM0NjA@._V1_SX300.jpg',
#  'Production': 'Pepper Island Films',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.0/10'}],
#  'Released': '02 Jan 2018',
#  'Response': 'True',
#  'Runtime': '86 min',
#  'Title': 'Mustang Island',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Craig Elrod, Nathan Smith',
#  'Year': '2017',
#  'imdbID': 'tt6589292',
#  'imdbRating': '6.0',
#  'imdbVotes': '237'}
# -------------------
# movie id tt3891162
# -------------------
# {'Actors': 'Sam Wickey, Kasha Fauscett, Wesley Juels, Reed Haymons',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Sam Wickey',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'So, is this film gonna be pro flat earth? Or pro round earth?',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Earth Is Flat',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Sam Wickey',
#  'Year': '2015',
#  'imdbID': 'tt3891162',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5826168
# -------------------
# {'Actors': "Samuel A. Gbadebo, La 'Shondra Johnson, Lourgem Famador, Miriam "
#            'Benard',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Granville Bailey',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Jun 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'My Breakthrough',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Samuel Gbadebo, Alexandra Bello (script supervisor)',
#  'Year': '2017',
#  'imdbID': 'tt5826168',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6436270
# -------------------
# {'Actors': 'Maclain Nelson, Jake Van Wagoner, Clare Niederpruem, Lisa Clark',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jake Van Wagoner',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Two estranged brothers try to reconnect at Christmas but there's "
#          "something that one of them can't get past...the other think's he's a "
#          'time traveler.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNGRjYjA0OTctMTZhOC00M2ZlLWI0OTYtZTk1MGNlMmQxMGE3XkEyXkFqcGdeQXVyMjI2MDU2NTk@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.8/10'}],
#  'Released': '23 Nov 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'My Brother the Time Traveler',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Maclain Nelson, Jake Van Wagoner',
#  'Year': '2017',
#  'imdbID': 'tt6436270',
#  'imdbRating': '8.8',
#  'imdbVotes': '18'}
# -------------------
# movie id tt7049622
# -------------------
# {'Actors': 'Melvin Baird, Lavell Brooks, Darrell Dunlap, Jamillah Gonzalez',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Lisa Maydwell',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Twins Byron and Tyron are more alike than different, even though one '
#          'twin is a minister and the other is a small time street hustler.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '13 Sep 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': "My Brother's Shadow",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2017',
#  'imdbID': 'tt7049622',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6659148
# -------------------
# {'Actors': 'Jonathan Gaietto, Ebony Obsidian, Yair Ben-Dor, Alexander Mulzac',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Nelson Moses Lassiter',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOWZlMWEwMTAtYzkzNi00NDYxLTllMDAtNmUwZmM5NGFiZTFiXkEyXkFqcGdeQXVyNjc5NzE0Mjg@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'My Brothers Keeper',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2017',
#  'imdbID': 'tt6659148',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6829190
# -------------------
# {'Actors': 'Giancarlo Iannotta, Antonio Palumbo, Rossella Celati, Mario '
#            "D'Agostino",
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Giancarlo Iannotta',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English, Italian',
#  'Metascore': 'N/A',
#  'Plot': "Two brothers - one American, one Italian, who've never met - take a "
#          'road trip from Rome to the picturesque region of Molise on a journey '
#          'to spread the ashes of their late father in the small town where he '
#          'was born.',
#  'Poster': 'N/A',
#  'Production': 'BBC Worldwide',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '84 min',
#  'Title': 'My Country',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Giancarlo Iannotta',
#  'Year': '2017',
#  'imdbID': 'tt6829190',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4411596
# -------------------
# {'Actors': 'Rachel Weisz, Sam Claflin, Holliday Grainger, Iain Glen',
#  'Awards': '1 win & 4 nominations.',
#  'BoxOffice': '$2,711,003',
#  'Country': 'UK, USA',
#  'DVD': '29 Aug 2017',
#  'Director': 'Roger Michell',
#  'Genre': 'Drama, Mystery, Romance',
#  'Language': 'English, Italian',
#  'Metascore': '63',
#  'Plot': "A young Englishman plots revenge against his late cousin's "
#          'mysterious, beautiful wife, believing her responsible for his death. '
#          'But his feelings become complicated as he finds himself falling '
#          'under the beguiling spell of her charms.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzY0YTFlNjMtNDk5MS00MmIxLWJkNjYtZWQwYzk5NjZkZTc1XkEyXkFqcGdeQXVyNDcxNzU3MTE@._V1_SX300.jpg',
#  'Production': 'Fox Searchlight Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.0/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '76%'},
#              {'Source': 'Metacritic', 'Value': '63/100'}],
#  'Released': '09 Jun 2017',
#  'Response': 'True',
#  'Runtime': '106 min',
#  'Title': 'My Cousin Rachel',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Roger Michell (written for the screen by), Daphne Du Maurier '
#            '(based on the novel by)',
#  'Year': '2017',
#  'imdbID': 'tt4411596',
#  'imdbRating': '6.0',
#  'imdbVotes': '16,234'}
# -------------------
# movie id tt6460276
# -------------------
# {'Actors': 'Lee Benton, Corbin Bernsen, Michael Aaron Carico, Jenn Gotzon '
#            'Chandler',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Waymon Boone',
#  'Genre': 'Comedy, Drama, Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Becca, Adam and their 5-year-old daughter Acie are a perfect family '
#          'until a tragic accident during a 4th of July celebration kills their '
#          'father. Struggling with grief, Becky decides she ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTIxZjRhZjUtMWJhOC00Yjc1LTlhMjMtZTk0MDI0YTc0OWMyXkEyXkFqcGdeQXVyNzc3MDg1NTM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'TV-14',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.9/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '92 min',
#  'Title': "My Daddy's in Heaven",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Waymon Boone, Joseph Nasser, Noelle Nelson',
#  'Year': '2017',
#  'imdbID': 'tt6460276',
#  'imdbRating': '4.9',
#  'imdbVotes': '118'}
# -------------------
# movie id tt5978724
# -------------------
# {'Actors': 'Ellen Page, Kate Mara, Amy Seimetz, Charlie Shotwell',
#  'Awards': '1 win & 2 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'UK, USA',
#  'DVD': '05 Jul 2019',
#  'Director': 'Tali Shalom-Ezer',
#  'Genre': 'Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The daughter of a man on death row falls in love with a woman on the '
#          "opposing side of her family's political cause.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTc2NDM3ZTItNjk5ZS00N2Q2LWFkN2YtMmNlNWI2M2M4N2M0XkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_SX300.jpg',
#  'Production': 'Freestyle Releasing',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '94%'}],
#  'Released': '04 Jul 2019',
#  'Response': 'True',
#  'Runtime': '108 min',
#  'Title': 'My Days of Mercy',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joe Barton (screenplay by)',
#  'Year': '2017',
#  'imdbID': 'tt5978724',
#  'imdbRating': '6.2',
#  'imdbVotes': '1,601'}
# -------------------
# movie id tt6077620
# -------------------
# {'Actors': 'Kelly Heyer, Aija Terauda, Paul Thomas Arnold, Henry Burge',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Derek Estlin Purvis',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYmI3OThjNzMtYWY3OC00MGEyLTljMGItZTQwNTI5OTQ1NWQzL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMTAxNDAyMDI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '05 Feb 2017',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'My Experience',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Luigi Bian (story by: Luigi Bian), Derek Estlin Purvis',
#  'Year': '2017',
#  'imdbID': 'tt6077620',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6371720
# -------------------
# {'Actors': 'Julia Farrell, Dominique Chaison, Steven Maurice',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Hezekiah Condron',
#  'Genre': 'Comedy, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A man leads a gorgeous girl to his house in order to feed his zombie '
#          'father.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '25 Jan 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'My Father',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ange Fassinou',
#  'Year': '2017',
#  'imdbID': 'tt6371720',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2291540
# -------------------
# {'Actors': 'Zachary Davis Brown, Lily Kozub, Ross Lynch, Vincent Kartheiser',
#  'Awards': '1 win & 3 nominations.',
#  'BoxOffice': '$1,306,946',
#  'Country': 'USA',
#  'DVD': '05 Mar 2018',
#  'Director': 'Marc Meyers',
#  'Genre': 'Biography, Drama',
#  'Language': 'English',
#  'Metascore': '68',
#  'Plot': 'A young Jeffrey Dahmer struggles to belong in high school.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BN2UxZDJlYjAtNGQ0OC00MWE4LTkzMjktMDAyNTg2ZTVkZjQ1XkEyXkFqcGdeQXVyMTc2MDc0Nw@@._V1_SX300.jpg',
#  'Production': 'FilmRise',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '87%'},
#              {'Source': 'Metacritic', 'Value': '68/100'}],
#  'Released': '02 Mar 2018',
#  'Response': 'True',
#  'Runtime': '107 min',
#  'Title': 'My Friend Dahmer',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Marc Meyers, John Backderf (based on the book My Friend Dahmer by)',
#  'Year': '2017',
#  'imdbID': 'tt2291540',
#  'imdbRating': '6.2',
#  'imdbVotes': '13,401'}
# -------------------
# movie id tt6354382
# -------------------
# {'Actors': 'Keith Nussbaum, Sofia Lidia, Dawn Bradley, Michelle Dillard',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Julie M. Hale',
#  'Genre': 'Comedy, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Brian has been keeping a secret from his wife and his best friend '
#          "for some time. Trying to live an ordinary life for Brian doesn't "
#          'come easy.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMmM0YTZhYzktMzI3MC00MjlhLTkyY2ItYjVmODAxOWU3MGU5L2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMTU0OTY0OTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '25 Jan 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': "My Husband's a Werewolf",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Julie M. Hale',
#  'Year': '2017',
#  'imdbID': 'tt6354382',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6359708
# -------------------
# {'Actors': 'Johanna Sol, Benjamin Levy, Demorian Lizana, Matondo Kiantandu',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '05 Sep 2017',
#  'Director': 'Matondo Kiantandu',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'My Life for Yours',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Matondo Kiantandu',
#  'Year': '2017',
#  'imdbID': 'tt6359708',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4131800
# -------------------
# {'Actors': 'Uzo Aduba, Ashleigh Ball, Adam Bengis, Emily Blunt',
#  'Awards': '3 wins & 6 nominations.',
#  'BoxOffice': '$21,732,671',
#  'Country': 'USA, Canada',
#  'DVD': '09 Jan 2018',
#  'Director': 'Jayson Thiessen',
#  'Genre': 'Animation, Adventure, Comedy, Drama, Family, Fantasy, Musical',
#  'Language': 'English',
#  'Metascore': '39',
#  'Plot': 'After a dark force conquers Canterlot, the Mane 6 embark on an '
#          'unforgettable journey beyond Equestria where they meet new friends '
#          'and exciting challenges on a quest to use the magic of friendship to '
#          'save their homeland.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMmMxNWNhNjItZjhmMC00ZmViLThlYjItZDk5YTQ1MWZkOGM1XkEyXkFqcGdeQXVyNzY2ODYzOTU@._V1_SX300.jpg',
#  'Production': 'Lionsgate',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '48%'},
#              {'Source': 'Metacritic', 'Value': '39/100'}],
#  'Released': '06 Oct 2017',
#  'Response': 'True',
#  'Runtime': '99 min',
#  'Title': 'My Little Pony: The Movie',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Meghan McCarthy (story by), Joe Ballarini (story by), Meghan '
#            'McCarthy (screenplay by), Rita Hsiao (screenplay by), Michael '
#            'Vogel (screenplay by), Lauren Faust (based on the television '
#            'series created by)',
#  'Year': '2017',
#  'imdbID': 'tt4131800',
#  'imdbRating': '6.1',
#  'imdbVotes': '5,441'}
# -------------------
# movie id tt6684814
# -------------------
# {'Actors': 'Doug Ford',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Doug Ford',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'After two years of trying, New Jersey native Doug Ford was finally '
#          'granted access into and toured North Korea. What he saw will shock '
#          'you.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTViZGFjMTEtNTY0My00ZjFmLThmMzYtZDZhMGQ0NzVkOThhXkEyXkFqcGdeQXVyNTkyNDMwNzI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '12 Apr 2017',
#  'Response': 'True',
#  'Runtime': '65 min',
#  'Title': 'My Long Strange Trip in North Korea',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2017',
#  'imdbID': 'tt6684814',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6858784
# -------------------
# {'Actors': 'Michiel Allen, Calvin Bess, Zachariah Rogers, John Schmedes',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Alton Claude',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '20 Sep 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'My Next Sweet Day',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Alton Claude',
#  'Year': '2017',
#  'imdbID': 'tt6858784',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4662708
# -------------------
# {'Actors': 'Stephon Marbury',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'China',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'Documentary',
#  'Language': 'Mandarin',
#  'Metascore': 'N/A',
#  'Plot': "The documentary will look at the Brooklyn-born point guard's life "
#          'since arriving in China, where he has helped the Beijing Ducks win '
#          'three Chinese Basketball Association championships in ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'A Native of New York in Beijing',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2016',
#  'imdbID': 'tt4662708',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7079474
# -------------------
# {'Actors': 'Charlotte Delaney Riggs, Danny Trevino, Marcelle Purdy, Dakota '
#            'Millett',
#  'Awards': '1 win & 4 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'David N. Reyes',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': '17 year old gets his first car and is on top of the world until he '
#          'becomes convinced that someone is trying to steal it.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNGUxM2Y1MDctZjY4Ny00MDY5LWI4N2YtZmEwMzBhMTc4ZTQ2XkEyXkFqcGdeQXVyNTkzMTkyNzI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '06 Nov 2018',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'My Ranger',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2018',
#  'imdbID': 'tt7079474',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7830724
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt5200168
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Bill Doty',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Revenge is a dish best served by a cold, dead fish. Think twice '
#          "before you flush that innocent goldfish, there's a good chance it "
#          'could come back to haunt you. Literally.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '11 Oct 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'GhoulFish',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Bill Doty',
#  'Year': '2016',
#  'imdbID': 'tt5200168',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5870084
# -------------------
# {'Actors': 'Drew Fuller, Valerie Domínguez, Robin Duran, Maria Conchita Alonso',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'Panama, USA, Argentina',
#  'DVD': 'N/A',
#  'Director': 'Arianne Benedetti',
#  'Genre': 'Drama',
#  'Language': 'Spanish, English',
#  'Metascore': 'N/A',
#  'Plot': 'Two young siblings ended up living on the streets, having nothing '
#          "left but their love. It's a story about survival, second chances and "
#          'second falls.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODlhMTFhYzItN2I0Ny00MWU5LTlhZjktYWVkNzRhYjNlZjVlXkEyXkFqcGdeQXVyNTYzMjkwNjU@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.8/10'}],
#  'Released': '18 Aug 2017',
#  'Response': 'True',
#  'Runtime': '110 min',
# ...
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTAxZjMzMjItYjAzMS00NWQ5LWFkYmItYTYyYmQ0YTk1ZDEzXkEyXkFqcGdeQXVyNjA0OTc5MjU@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '03 Jan 2017',
#  'Response': 'True',
#  'Runtime': '77 min',
#  'Title': 'The Cleanzing of Lake Lanier',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jibril Haynes',
#  'Year': '2016',
#  'imdbID': 'tt5921474',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7746608
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt7791884
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt6246106
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'N/A',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'N/A',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Color of Passion',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2016',
#  'imdbID': 'tt6246106',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3809976
# -------------------
# {'Actors': 'Jenn Gotzon, Mardell Elmer, Juli Tapken, Timothy Paul Taylor',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Chip Rossetti',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Kate Montgomery, an artist/art buyer, is searching for something '
#          'missing in her life. However, when she discovers blind artist, Emily '
#          "Burton, she's forced to re-examine her own twisted past - one "
#          'painting at a time.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTYxMDQ2OTQ2MF5BMl5BanBnXkFtZTgwOTQ3MjM5NDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Colors of Emily',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'M.T. Arnold (screenplay), M.T. Arnold (story), Leo Partible '
#            '(script doctor), Stanna Rae (screenplay), Brooke K. Taylor '
#            '(screenplay), Timothy Paul Taylor (screenplay)',
#  'Year': '2015',
#  'imdbID': 'tt3809976',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5984856
# -------------------
# {'Actors': 'Roger Conners, Nick Earl, Megan King, Rachel Anderson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Conrad Faraj',
#  'Genre': 'Drama, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'In a perfect, violent-free world, a young vagabond must decide '
#          'between human decency or self-interest when it comes to the matter '
#          'of assassinating three people and gifting their corpses to a '
#          'powerful figure full of impossible wishes.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODNmZDM0YWYtMjIwZi00MTA3LWFiZDMtOWYyYTM0NDllZWFhXkEyXkFqcGdeQXVyNDM3Mjc2OA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'}],
#  'Released': '27 Feb 2018',
#  'Response': 'True',
#  'Runtime': '102 min',
#  'Title': 'The Colours of Desire',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Conrad Faraj',
#  'Year': '2017',
#  'imdbID': 'tt5984856',
#  'imdbRating': '6.5',
#  'imdbVotes': '16'}
# -------------------
# movie id tt5445072
# -------------------
# {'Actors': 'Ronrico Albright, Everett Anderson, James A Gleason, Latoya Gray',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Robert L. Parker III',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The Come Up is about a young comedian as a young man who struggles '
#          'to try to make it but the terrible streets kind of get him caught '
#          "up. He's got a few homeboys that he hangs with that try ...",
#  'Poster': 'https://ia.media-imdb.com/images/M/MV5BMzgyZWJjOTctYzM4My00YzRkLTg0ZTgtYjkzOTVhMTY5NDdkXkEyXkFqcGdeQXVyNTIwMjY1NjY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.8/10'}],
#  'Released': '22 Aug 2017',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'The Come Up',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Robert L. Parker III',
#  'Year': '2017',
#  'imdbID': 'tt5445072',
#  'imdbRating': '2.8',
#  'imdbVotes': '8'}
# -------------------
# movie id tt4587582
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Steven Heumann',
#  'Genre': 'Comedy, Crime',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'A team of five con artists sets out to steal the six most valuable '
#          'comic books in history. Davis Pollock is the leader of the group and '
#          'finds himself heavily in debt to a casino owner while...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Comic Con',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Steven Heumann',
#  'Year': '2015',
#  'imdbID': 'tt4587582',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6274746
# -------------------
# {'Actors': 'Julie Schmid, Jaeden Bettencourt, Ken Kamlet',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Alex Rivers',
#  'Genre': 'Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A workaholic father must race across town in order to attend his '
#          "son's recital and save his marriage.",
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Concert',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Alex Rivers',
#  'Year': '2017',
#  'imdbID': 'tt6274746',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3257092
# -------------------
# {'Actors': 'David Blue, Talia Tabin, John M. Keating, Zakareth Ruben',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'America Young',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'On the brink of their beloved single screen independent movie '
#          'theater being shut down forever, a misfit band of theater workers '
#          'face the corporate evil, foreclosure and the unthinkable......',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMmY0NzM3NzgtZmRjMi00NWM1LWJiOWMtNzFiY2ExNzdiYjJmXkEyXkFqcGdeQXVyMjEwODk4NzI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.3/10'}],
#  'Released': '08 Jan 2017',
#  'Response': 'True',
#  'Runtime': '93 min',
#  'Title': 'The Concessionaires Must Die!',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'John M. Keating, Sam McCoy, Sam McCoy, America Young (developed '
#            'by)',
#  'Year': '2017',
#  'imdbID': 'tt3257092',
#  'imdbRating': '7.3',
#  'imdbVotes': '65'}
# -------------------
# movie id tt6161300
# -------------------
# {'Actors': 'Dimitri Tatishvili, Joseph Khvedelidze, Sophia Sebiskveradze, Nato '
#            'Murvanidze',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'Georgia, Estonia, USA',
#  'DVD': 'N/A',
#  'Director': 'Zaza Urushadze',
#  'Genre': 'Drama, Mystery',
#  'Language': 'Georgian, English',
#  'Metascore': 'N/A',
#  'Plot': 'Priest Giorgi, a former Film Director, is sent to serve the small '
#          'parish in the mountain village. To bring villagers closer to church '
#          'he starts showing films there. After the screening of ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZDg4NmEyMDEtZDUxOS00MzcyLWE0MjItNTBkMDZkYjJlZDk3XkEyXkFqcGdeQXVyNjEyNzgxNjk@._V1_SX300.jpg',
#  'Production': 'Uncork&#39;d Entertainment',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '50%'}],
#  'Released': '27 Oct 2017',
#  'Response': 'True',
#  'Runtime': '89 min',
#  'Title': 'The Confession',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Zaza Urushadze',
#  'Year': '2017',
#  'imdbID': 'tt6161300',
#  'imdbRating': '6.2',
#  'imdbVotes': '146'}
# -------------------
# movie id tt6199686
# -------------------
# {'Actors': 'Aaron Wiggins, Tobie Famusipe, Bricine Brown, Shupier Jones',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Mclean Tracey',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '07 Jan 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Confession of a Black Man',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tracey Mclean',
#  'Year': '2017',
#  'imdbID': 'tt6199686',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4273500
# -------------------
# {'Actors': 'Veronica Wylie, Bradley Snedeker, Charlie Bodin, Casper Van Dien',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Marian Yeager',
#  'Genre': 'Comedy, Crime, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "When Natalie Conway's father passes away, she believes she will "
#          'forever be on her own. So when her long lost brother, Luke, returns '
#          "after a twenty-year hiatus she's elated. He's a missing ...",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjM2MjcxNTIwMV5BMl5BanBnXkFtZTgwMTEyMzQ3NjE@._V1_SX300.jpg',
#  'Production': 'Reel Goode Productions',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'}],
#  'Released': '28 Jul 2017',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'The Conway Curve',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Richard Dane Scott, Marian Yeager',
#  'Year': '2017',
#  'imdbID': 'tt4273500',
#  'imdbRating': '6.5',
#  'imdbVotes': '20'}
# -------------------
# movie id tt5655098
# -------------------
# {'Actors': 'Kari White, Ashley Abendschein, Mariah Salazar, Danny Bohnen',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Rod Wess',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "A young woman's corrupted spirit haunts the new residents of the "
#          'apartment she committed suicide in.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Corrupt Half',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Rod Wess',
#  'Year': '2016',
#  'imdbID': 'tt5655098',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5607782
# -------------------
# {'Actors': 'Monica Engesser, Owen Conway, Clint James, Sanford Gibbons',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Robert Conway',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'After the tragic deaths of her husband and daughter, Sarah Doyle '
#          'moves back to her childhood home with her estranged brother, '
#          "Richard. It's not long before Sarah begins to experience ...",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTU2NTU1NTc5M15BMl5BanBnXkFtZTgwOTMyNDAwMTI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.6/10'}],
#  'Released': '07 Feb 2017',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'The Covenant',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Owen Conway, Robert Conway, Christopher R. Smith',
#  'Year': '2017',
#  'imdbID': 'tt5607782',
#  'imdbRating': '5.6',
#  'imdbVotes': '1,630'}
# -------------------
# movie id tt7579788
# -------------------
# {'Actors': 'Terry Bell, Nathanael Card, Rinska Carrasco, Brandon Galatz',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Julian Grant',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A group of online social justice activists venture deep into the '
#          'woods to uncover the truth behind a recent series of gruesome ritual '
#          'murders - and to capture the person responsible. But ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMDk3ZGZjMzUtNzg0OC00OGFjLWI3ZGMtYjMzY2M3ODJkZDc1XkEyXkFqcGdeQXVyMTg0MTI3Mg@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.0/10'}],
#  'Released': '11 Jul 2017',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': 'The Cropsey Incident',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Julian Grant',
#  'Year': '2017',
#  'imdbID': 'tt7579788',
#  'imdbRating': '2.0',
#  'imdbVotes': '55'}
# -------------------
# movie id tt6205996
# -------------------
# {'Actors': 'Angela Durazo, Nathan Schellerup, Malinda Farrington, Danny Winn',
#  'Awards': '3 wins & 5 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '06 Mar 2018',
#  'Director': 'Biray Dalkiran',
#  'Genre': 'Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The nightmare was about a demonic possession. A long time ago, there '
#          'was an evil in a small town and it was jealous of the girl and would '
#          'never let her go, since the devil loved the girl. ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZTAxODE1NWYtOWFlOC00NTUxLWE4NzktZmViN2NkMTBkNzY5XkEyXkFqcGdeQXVyMTI0MTMyNDM@._V1_SX300.jpg',
#  'Production': 'BD America',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.4/10'}],
#  'Released': '06 Mar 2018',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': 'The Crossbreed',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Biray Dalkiran, Safak Güçlü',
#  'Year': '2017',
#  'imdbID': 'tt6205996',
#  'imdbRating': '2.4',
#  'imdbVotes': '273'}
# -------------------
# movie id tt7509426
# -------------------
# {'Actors': 'Consuelo Vega, Bret Grantham, Juliet Lemar, Thomas Boyd',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'India, USA',
#  'DVD': 'N/A',
#  'Director': 'Luis Alvarez, Pradeep Katasani, Eric J. Vasquez, Kavi Raz',
#  'Genre': 'Thriller',
#  'Language': 'English, Hindi, Punjabi',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTk3Nzc2ODItZjk1Ni00ZmU4LTg4MmYtYTRlNTlkOGRlMDY3XkEyXkFqcGdeQXVyMzYwNjI1MDI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '07 Oct 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Crossings',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kavi Raz',
#  'Year': '2017',
#  'imdbID': 'tt7509426',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4181782
# -------------------
# {'Actors': 'Sophie Cookson, Corneliu Ulici, Ada Lupu, Brittany Ashworth',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'UK, Romania, USA',
#  'DVD': '05 Dec 2017',
#  'Director': 'Xavier Gens',
#  'Genre': 'Horror, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When Nicole comes in contact with Father Anton (Corneliu Ulici) more '
#          'and more inexplicable events occur. The pair begin to believe that '
#          'the priest lost the battle with a demon.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTNiYTc2ZDEtODAxMC00NWI3LTlkNTQtNjY4ZTdkN2IxN2FhXkEyXkFqcGdeQXVyNDkzNTM2ODg@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '6%'}],
#  'Released': '06 Oct 2017',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'The Crucifixion',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Chad Hayes, Carey W. Hayes',
#  'Year': '2017',
#  'imdbID': 'tt4181782',
#  'imdbRating': '5.1',
#  'imdbVotes': '6,336'}
# -------------------
# movie id tt9876748
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}

# %%
len(title_list)
# Out:
# 936

# %%
len(title_id)
# Out:
# 936

# %%
# if title_list and title_id are the same length run the cell below. 
# if they are not equal take out 'title_id': title_id

# %%
df = pd.DataFrame({'title_id': title_id, 'title': title_list, 'box_office': box_office_list, 'country': country_list, 
                   'genre': genre_list, 'director': director_list, 'metascore': metascore_list, 'production': production_list, 
                   'rating': rating_list, 'IMDB_rating': IMDB_rating_list, 'rotten_tomatoes_rating': rotten_tomatoes_rating_list, 
                  'runtime': runtime_list, 'type': type_list, 'IMDB_votes': imdb_votes_list})

# %%
df = df.drop_duplicates()
df.head()
# Out:
#     title_id                               title box_office  \
# 0  tt7390046                              Mosaic        N/A
# 1  tt7767628  Mosquitos, Alligators, and Bullets        N/A
# 2  tt5564932                                Moss        N/A
# 3  tt4866448               Most Beautiful Island        N/A
# 4  tt5094886                       Mother in Law        N/A
#
#                                              country  \
# 0  USA, Canada, Haiti, Trinidad and Tobago, Unite...
# 1                                                USA
# 2                                                USA
# 3                                                USA
# 4                                                USA
#
#                        genre  \
# 0              Drama, Sci-Fi
# 1                        N/A
# 2  Adventure, Drama, Romance
# 3    Drama, Horror, Thriller
# 4                      Drama
#
#                                             director metascore  \
# 0  Miryam Charles, Josephine Decker, Alexis Gambi...       N/A
# 1                  Migdalia Etheridge, Ray Etheridge       N/A
# 2                                      Daniel Peddle       N/A
# 3                                        Ana Asensio        73
# 4                           Garry Evans, Geary Evans       N/A
#
#               production rating IMDB_rating rotten_tomatoes_rating runtime  \
# 0  Home Box Office (HBO)    N/A         N/A                     NA  98 min
# 1                    N/A    N/A         N/A                     NA  46 min
# 2                    N/A    N/A         N/A                     NA  81 min
# 3   Samuel Goldwyn Films    N/A         5.7                    93%  80 min
# 4                    N/A    N/A         N/A                     NA  45 min
#
#     type IMDB_votes
# 0  movie        N/A
# 1  movie        N/A
# 2  movie        N/A
# 3  movie      2,519
# 4  movie        N/A

# %%
df.count()
# Out:
# title_id                  936
# title                     936
# box_office                936
# country                   936
# genre                     936
# director                  936
# metascore                 936
# production                936
# rating                    936
# IMDB_rating               936
# rotten_tomatoes_rating    936
# runtime                   936
# type                      936
# IMDB_votes                936
# dtype: int64

# %%
df.to_csv('Resources/2017_data_batch_3.csv', index=False)
