# %%
import pandas as pd
import requests
import json
import time
from pprint import pprint
from config import API_KEY

# %%
data = pd.read_csv('../data/titles_2013_batch2.csv')
df =  data.count()
df
# Out:
# title    1000
# dtype: int64

# %%
title_id = []
box_office_list = []
country_list = []
genre_list = []
director_list = []
metascore_list = []
production_list = []
rating_list = []
IMDB_rating_list = [] 
rotten_tomatoes_rating_list = []
runtime_list = []
title_list = []
type_list = []
imdb_votes_list = []

# %%
movies = data['title']
total_movies = len(movies)

# %%
for i in range(total_movies):
    movie = movies[i]
    url = "http://www.omdbapi.com/?i=" + movie + "&apikey=" + API_KEY
    response = (requests.get(url).text)
    response_json = json.loads(response)
    print('-------------------')
    print(f'movie id {movie}')
    print('-------------------')
    pprint(response_json)
    
    try:
        box_office_list.append(response_json['BoxOffice'])
        country_list.append(response_json['Country'])
        genre_list.append(response_json['Genre'])
        director_list.append(response_json['Director'])
        metascore_list.append(response_json['Metascore'])
        production_list.append(response_json['Production'])
        rating_list.append(response_json['Rated'])
        IMDB_rating_list.append(response_json['imdbRating'])
        try:
            if not response_json['Ratings']:
                rotten_tomatoes_rating_list.append('NA')
            elif response_json['Ratings'][0]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][0]['Value'])
            elif response_json['Ratings'][1]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][1]['Value'])
            else:
                rotten_tomatoes_rating_list.append('NA')
        except IndexError:
            rotten_tomatoes_rating_list.append('NA')
        runtime_list.append(response_json['Runtime'])
        title_list.append(response_json['Title'])
        type_list.append(response_json['Type'])
        imdb_votes_list.append(response_json['imdbVotes'])
        title_id.append(response_json['imdbID'])
    except KeyError:
        pass
    time.sleep(1)
# Out:
# -------------------
# movie id tt2332623
# -------------------
# {'Actors': 'Neil Breen, Klara Landrat, Jennifer Autry, Victoria Viveiros',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Neil Breen',
#  'Genre': 'Drama, Fantasy, Mystery, Romance, Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A computer scientist/novelist reunites with his childhood friend and '
#          'hacks into government databases, while facing the dire and fateful '
#          'consequences of his mystical actions obtained as a child.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzYyMDU3NDg3NV5BMl5BanBnXkFtZTgwODk1ODMxMTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.7/10'}],
#  'Released': '14 Jan 2014',
#  'Response': 'True',
#  'Runtime': '100 min',
#  'Title': 'Fateful Findings',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Neil Breen',
#  'Year': '2013',
#  'imdbID': 'tt2332623',
#  'imdbRating': '4.7',
#  'imdbVotes': '3,639'}
# -------------------
# movie id tt3278650
# -------------------
# {'Actors': 'Brian Wimer, Doug Bari, Boomie Pederson, Raymond Lawrence Kennedy',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Doug Bari',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Gay werewolves Brian and Doug escape from a lycanthrope reservation '
#          'to seek freedom in Maine, the only state with a sanctioned tolerance '
#          'of werewolves. Their journey takes them on a road ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.1/10'}],
#  'Released': '01 Nov 2013',
#  'Response': 'True',
#  'Runtime': '92 min',
#  'Title': 'Faux Paws',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Doug Bari, Doug Bari',
#  'Year': '2013',
#  'imdbID': 'tt3278650',
#  'imdbRating': '8.1',
#  'imdbVotes': '9'}
# -------------------
# movie id tt1971397
# -------------------
# {'Actors': 'Blayne Weaver, Patrick Day, Jeffrey Combs, Christina Rose',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Paul Osborne',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Kip's perfect life is put in jeopardy when the waitress with whom "
#          "he's having a casual fling is accidentally killed in their motel "
#          'room. Desperate, he turns to childhood friend and loser, ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjI2NzU0NzExNF5BMl5BanBnXkFtZTcwMTg0NDExOQ@@._V1_SX300.jpg',
#  'Production': 'Gravitas',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'}],
#  'Released': '05 Apr 2013',
#  'Response': 'True',
#  'Runtime': '102 min',
#  'Title': 'Favor',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Paul Osborne',
#  'Year': '2013',
#  'imdbID': 'tt1971397',
#  'imdbRating': '6.3',
#  'imdbVotes': '798'}
# -------------------
# movie id tt2966192
# -------------------
# {'Actors': 'Eliezer Ortiz, Lance Gideon, Cedric L. Williams, Valeria Zunzun',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Alpheus Joseph',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A desperate man, unemployed, wanting to provide relief to his only '
#          'child, Veronica, who is suffering from brain cancer; unsuccessfully '
#          'embarks into the underground world of drug trafficking.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '114 min',
#  'Title': 'Faze',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Alpheus Joseph (story), Alpheus Joseph',
#  'Year': '2013',
#  'imdbID': 'tt2966192',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7573742
# -------------------
# {'Actors': 'Brooke Austin, Grace Austin, Mitra Avani, Rochelle Baca',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Claudia Damasceno',
#  'Genre': 'Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Feed Me is a story about a young American family who lives in a '
#          'suburban area in Southern California. The father, Jason (Cameron '
#          'Graham), is an ambitious executive who keeps getting ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'NOT RATED',
#  'Ratings': [],
#  'Released': '10 Nov 2013',
#  'Response': 'True',
#  'Runtime': '100 min',
#  'Title': 'Feed Me',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Claudia Damasceno',
#  'Year': '2013',
#  'imdbID': 'tt7573742',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2201772
# -------------------
# {'Actors': 'Dalton Leeb, Anil Margsahayam, Christopher B. Duncan, Abby Miller',
#  'Awards': '1 win & 3 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Will Prescott',
#  'Genre': 'Comedy, Crime, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A house sitter bites off more than he can chew when a dead body '
#          "mysteriously shows up at the estate he's watching.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTA0ODc2MzMxNDFeQTJeQWpwZ15BbWU4MDU3ODE1MzEx._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.6/10'}],
#  'Released': '04 Apr 2013',
#  'Response': 'True',
#  'Runtime': '94 min',
#  'Title': 'Feeding Mr. Baldwin',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Will Prescott',
#  'Year': '2013',
#  'imdbID': 'tt2201772',
#  'imdbRating': '5.6',
#  'imdbVotes': '109'}
# -------------------
# movie id tt2958316
# -------------------
# {'Actors': 'Brendan Robinson, Rock Anthony, Shanley Caswell, Katie Cockrell',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Josh Stolberg',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'After his best friend loses his virginity, socially inept and high '
#          'strung Allan finds himself alone in high school and with no shot of '
#          'getting laid anywhere in sight. But when ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc3MjU0MzczOV5BMl5BanBnXkFtZTgwMjgyMjg2MDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.5/10'}],
#  'Released': '21 Nov 2013',
#  'Response': 'True',
#  'Runtime': '81 min',
#  'Title': 'Feels So Good',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Eric T. Finkel, David Spencer',
#  'Year': '2013',
#  'imdbID': 'tt2958316',
#  'imdbRating': '5.5',
#  'imdbVotes': '208'}
# -------------------
# movie id tt2402603
# -------------------
# {'Actors': 'Jai Courtney, Joel Edgerton, Mark Simpson, Paul Caesar',
#  'Awards': '10 nominations.',
#  'BoxOffice': '$185,429',
#  'Country': 'Australia, USA',
#  'DVD': '10 Feb 2015',
#  'Director': 'Matthew Saville',
#  'Genre': 'Crime, Drama, Thriller',
#  'Language': 'English',
#  'Metascore': '52',
#  'Plot': 'An accident involving a young child sets off a chain of events that '
#          "brings an Australian police officer's world crashing down.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTI3ZTg3ZTYtNjgxYi00ZGE3LTlmYzAtZWNhZTZkMzFkZDQyXkEyXkFqcGdeQXVyMTMxMTY0OTQ@._V1_SX300.jpg',
#  'Production': 'Gravitas Ventures',
#  'Rated': 'TV-MA',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '70%'},
#              {'Source': 'Metacritic', 'Value': '52/100'}],
#  'Released': '28 Aug 2014',
#  'Response': 'True',
#  'Runtime': '105 min',
#  'Title': 'Felony',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joel Edgerton (screenplay)',
#  'Year': '2013',
#  'imdbID': 'tt2402603',
#  'imdbRating': '6.1',
#  'imdbVotes': '4,659'}
# -------------------
# movie id tt3345670
# -------------------
# {'Actors': 'Ermal Mamaqi, Enxhi Cuku, Zamira Kita, Robert Aliaj',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Albania',
#  'DVD': 'N/A',
#  'Director': 'Rudina Vojvoda',
#  'Genre': 'Comedy',
#  'Language': 'Albanian',
#  'Metascore': 'N/A',
#  'Plot': 'An albanian farce/comedy about women and men and their problems',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTY1NzI0MzI0M15BMl5BanBnXkFtZTgwMTYwNDE3MDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.5/10'}],
#  'Released': '15 Nov 2013',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Femrat',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Koloreto Cukali',
#  'Year': '2013',
#  'imdbID': 'tt3345670',
#  'imdbRating': '7.5',
#  'imdbVotes': '340'}
# -------------------
# movie id tt3197696
# -------------------
# {'Actors': 'Srini Kolla, Gopi Sampath, Tanuja Vijay, Balu Perla',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Narayanan Kartha',
#  'Genre': 'Drama, Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The story happens over a weekend in a mid-western US city. Akhil, '
#          'Samir, Betty and Vinod are four Indian professionals living in the '
#          'same house. When Akhil fails to secure a job promotion ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '117 min',
#  'Title': 'Fences',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Narayanan Kartha (story), Narayanan Kartha',
#  'Year': '2013',
#  'imdbID': 'tt3197696',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2737902
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Liza quits her job as a lawyer when she realizes that she's not "
#          'ready to settle down and become a wife and mother like her fiance '
#          'Mitch expects her to. Liza breaks it off with Mitch and ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTY2ODQwMDY4NV5BMl5BanBnXkFtZTgwMTcwMjEwMjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '120 min',
#  'Title': 'Fetching',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Amy Harris',
#  'Year': '2013',
#  'imdbID': 'tt2737902',
#  'imdbRating': '6.2',
#  'imdbVotes': '16'}
# -------------------
# movie id tt2576508
# -------------------
# {'Actors': 'Thurmond Allen Jr., Tiffany Carter, Julie Chapin, Isaiah Charity',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'David L. Powell III',
#  'Genre': 'Crime',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'At the top of his singing career, R&B artist Jamaal has it all, '
#          'cars, homes, jewelry and plenty of women knocking at his door. '
#          "Jamaal's has spent a year on the road touring and tonight, he ...",
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '28 Nov 2013',
#  'Response': 'True',
#  'Runtime': '107 min',
#  'Title': 'Fick-le',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michelle Greene-Wilkinson',
#  'Year': '2013',
#  'imdbID': 'tt2576508',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2378199
# -------------------
# {'Actors': 'Catherine Johnson, Breven Angaelica Warren, Peter Pasco, Fernando '
#            'Gaviria',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'N/A',
#  'DVD': 'N/A',
#  'Director': 'Teal Greyhavens',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjIyNzUzNjIzNF5BMl5BanBnXkFtZTgwMDg2MDg1MzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Fifth Annual',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Mary Helen Phelan (story)',
#  'Year': '2013',
#  'imdbID': 'tt2378199',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3829652
# -------------------
# {'Actors': 'Moreno Brown, Kamal Robinson, Brigid Turner',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kamal Robinson',
#  'Genre': 'Action, Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "FiGHT DANCE SiNG: A Capoeirista's story, is a fun, first of its kind "
#          "'online movie', centered around the action packed fast changing life "
#          'of New York city native Junie Lachman. Junie is ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Sep 2013',
#  'Response': 'True',
#  'Runtime': '107 min',
#  'Title': 'Fight Dance Sing',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kamal Robinson',
#  'Year': '2013',
#  'imdbID': 'tt3829652',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt1776946
# -------------------
# {'Actors': 'Bruce Dern, Kristanna Loken, José María Yazpik, Eddie Allen',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '03 Dec 2013',
#  'Director': 'Farhad Mann',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Two intertwined families, one American, one Mexican, and their fight '
#          'to save three year old illegal Angelina from deportation.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjE2MTA5MzQ0Nl5BMl5BanBnXkFtZTgwNTk4OTIyMDE@._V1_SX300.jpg',
#  'Production': 'Grand Entertainment',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'}],
#  'Released': '08 Sep 2016',
#  'Response': 'True',
#  'Runtime': '87 min',
#  'Title': 'Fighting for Freedom',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Chris Loken (screenplay), Chris Loken',
#  'Year': '2013',
#  'imdbID': 'tt1776946',
#  'imdbRating': '5.8',
#  'imdbVotes': '59'}
# -------------------
# movie id tt3254820
# -------------------
# {'Actors': 'Taylor Cressler, Ricki Duffy, Joshua Duggan, Matthew Duggan',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Joshua Duggan',
#  'Genre': 'Drama, Music',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Two troubled yet polar-opposite young adults, one a straight-edge '
#          'aspiring music producer, the other an absurdist musician with a case '
#          'of drugs, embark on an impromptu road trip to escape ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '102 min',
#  'Title': 'Figure Eight',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joshua Duggan, Joshua Duggan (story), Michael Hartnett',
#  'Year': '2013',
#  'imdbID': 'tt3254820',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt1450321
# -------------------
# {'Actors': 'James McAvoy, Jamie Bell, Eddie Marsan, Imogen Poots',
#  'Awards': '9 wins & 13 nominations.',
#  'BoxOffice': '$23,145',
#  'Country': 'UK, Germany, Sweden, Belgium, USA',
#  'DVD': '12 Aug 2014',
#  'Director': 'Jon S. Baird',
#  'Genre': 'Comedy, Crime, Drama',
#  'Language': 'English, German, Scots',
#  'Metascore': '56',
#  'Plot': 'A corrupt, junkie cop with bipolar disorder attempts to manipulate '
#          'his way through a promotion in order to win back his wife and '
#          'daughter while also fighting his own inner demons.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjE2NTgyMzM0NV5BMl5BanBnXkFtZTgwNzkwNDE1MzE@._V1_SX300.jpg',
#  'Production': 'Magnet Releasing',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '65%'},
#              {'Source': 'Metacritic', 'Value': '56/100'}],
#  'Released': '24 Apr 2014',
#  'Response': 'True',
#  'Runtime': '97 min',
#  'Title': 'Filth',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jon S. Baird, Irvine Welsh (based on the novel by)',
#  'Year': '2013',
#  'imdbID': 'tt1450321',
#  'imdbRating': '7.1',
#  'imdbVotes': '96,291'}
# -------------------
# movie id tt2802312
# -------------------
# {'Actors': 'Craig Brown, Robbie Church, Adrian Davis, J. Andrew Hartman',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Randall Rydell Russell',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Aspiring filmmakers are stalked by a serial killer in a derelict '
#          'apartment building.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.4/10'}],
#  'Released': '02 Jan 2013',
#  'Response': 'True',
#  'Runtime': '71 min',
#  'Title': 'Final Footage',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Randall Rydell Russell',
#  'Year': '2013',
#  'imdbID': 'tt2802312',
#  'imdbRating': '3.4',
#  'imdbVotes': '5'}
# -------------------
# movie id tt1935090
# -------------------
# {'Actors': 'Curtis Colbert, Corinne Fox, Jackie Jones, John Muir IV',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kyle Karges',
#  'Genre': 'Action, Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTMwODkwODIzOF5BMl5BanBnXkFtZTcwNTk4NTI1NQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '14 Feb 2013',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': 'Final Hours',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kyle Karges',
#  'Year': '2013',
#  'imdbID': 'tt1935090',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2698206
# -------------------
# {'Actors': 'Stacey T. Gillespie, Lien Mya Nguyen, Avri Apocalypse, Paul Cecil',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Chase Dudley',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '07 Apr 2013',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Final Offense',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'James Smith',
#  'Year': '2013',
#  'imdbID': 'tt2698206',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2562726
# -------------------
# {'Actors': 'Teri Polo, Chazz Palminteri, Tia Carrere, Lucas Elliot Eberl',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Barbara Stepansky',
#  'Genre': 'Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A wealthy high powered woman suffers a horrible tragedy after which '
#          'she descends into substance abuse,turning her back on her family. '
#          'She later discovers that someone close to her may be behind her '
#          'subsequent abduction and kidnapping.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTY2NjQxNDIyNV5BMl5BanBnXkFtZTgwNDQyNTEwMTE@._V1_SX300.jpg',
#  'Production': 'Victory Angel Films',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.3/10'}],
#  'Released': '16 Dec 2013',
#  'Response': 'True',
#  'Runtime': '91 min',
#  'Title': 'Final Recourse',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Steven Edell, Harvey Fisher, Harvey Fisher (story)',
#  'Year': '2013',
#  'imdbID': 'tt2562726',
#  'imdbRating': '5.3',
#  'imdbVotes': '354'}
# -------------------
# movie id tt2710368
# -------------------
# {'Actors': 'Jah Shams, Mary Grace, Carman, Masashi Nagadoi',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Japan, Argentina, Costa Rica',
#  'DVD': 'N/A',
#  'Director': 'Timothy A. Chey',
#  'Genre': 'Thriller',
#  'Language': 'English, Japanese, Spanish',
#  'Metascore': 'N/A',
#  'Plot': 'A gritty, international tale of four separate stories woven together '
#          'by a common theme: the Rapture.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTAzOTEyNTgzOTdeQTJeQWpwZ15BbWU4MDA1MDI2MjAx._V1_SX300.jpg',
#  'Production': 'River Rain Films',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.7/10'}],
#  'Released': '13 Sep 2013',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Final: The Rapture',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Timothy A. Chey',
#  'Year': '2013',
#  'imdbID': 'tt2710368',
#  'imdbRating': '5.7',
#  'imdbVotes': '1,268'}
# -------------------
# movie id tt2514128
# -------------------
# {'Actors': 'Cranston Johnson, Cornelius Muller, Vonii Bristow, Heavenly Walker',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '11 Aug 2015',
#  'Director': 'Burgess Jenkins',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A community tries to regain its collective faith after the sudden '
#          'death of a well-loved local figure: high school football star Billy '
#          "'Smiley' Cain Jr.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjA5NDQxNjk0Nl5BMl5BanBnXkFtZTgwMTA4NDUzNjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'}],
#  'Released': '04 Jan 2013',
#  'Response': 'True',
#  'Runtime': '89 min',
#  'Title': 'Find a Way',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Cornelius Muller, Thorne Winter (screenplay), Donald James Moore',
#  'Year': '2013',
#  'imdbID': 'tt2514128',
#  'imdbRating': '6.5',
#  'imdbVotes': '25'}
# -------------------
# movie id tt2219868
# -------------------
# {'Actors': 'Timothy Woodward Jr., Richard Bachellor, Robert Covington, '
#            'Katelynn Derengowski',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '06 Jan 2015',
#  'Director': 'Timothy Woodward Jr.',
#  'Genre': 'Action, Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A high stakes poker game. A drug lord. A million dollars. A set of '
#          'ruthless killers who want it all.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTYxMzExOTk2NF5BMl5BanBnXkFtZTcwMTIwMDgwOQ@@._V1_SX300.jpg',
#  'Production': 'HFD Productions',
#  'Rated': 'UNRATED',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.7/10'}],
#  'Released': '04 Apr 2013',
#  'Response': 'True',
#  'Runtime': '74 min',
#  'Title': 'Finders Keepers: The Root of All Evil',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Pia Cook, Todd Gordon',
#  'Year': '2013',
#  'imdbID': 'tt2219868',
#  'imdbRating': '3.7',
#  'imdbVotes': '107'}
# -------------------
# movie id tt2201760
# -------------------
# {'Actors': 'Erik Estrada, Alexander McPherson, Wesley Newman, Christie '
#            'Osterhus',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '03 Feb 2014',
#  'Director': 'Justin Rossbacher',
#  'Genre': 'Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Finding Faith is based on a compilation of actual events that '
#          'Sheriff Mike Brown has investigated through his Internet Crimes '
#          "Against Children task force. In a recent Safe Surfin' ...",
#  'Poster': 'https://ia.media-imdb.com/images/M/MV5BMjA3MDEyNjk3OF5BMl5BanBnXkFtZTgwMzAyNzUxMTE@._V1_SX300.jpg',
#  'Production': 'JC Films',
#  'Rated': 'NOT RATED',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'}],
#  'Released': '15 Jan 2013',
#  'Response': 'True',
#  'Runtime': '104 min',
#  'Title': 'Finding Faith',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2013',
#  'imdbID': 'tt2201760',
#  'imdbRating': '6.3',
#  'imdbVotes': '110'}
# -------------------
# movie id tt2170401
# -------------------
# {'Actors': 'Michael Gordon, Michael Empson, Victoria Mullen, Marjorie '
#            'Budzynski',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Brett Andrew Christiansen, Ryan Webber',
#  'Genre': 'Drama, Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An emotional tale about a man named Noah searching to find himself '
#          'after learning his dad has been diagnosed with terminal cancer. '
#          "After befriending a homeless man, he quits his 'normal' ...",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTgxNDkxMzkyOV5BMl5BanBnXkFtZTcwMTQ0OTExOQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.8/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '123 min',
#  'Title': 'Finding Home',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Brett Andrew Christiansen (screenplay), Ryan Webber (screenplay), '
#            'Ryan Webber',
#  'Year': '2013',
#  'imdbID': 'tt2170401',
#  'imdbRating': '7.8',
#  'imdbVotes': '5'}
# -------------------
# movie id tt2511506
# -------------------
# {'Actors': 'Julio Antonio Alonzo, Joanie Bannister, Steve Corder, Melissa '
#            'Couture',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Carlos Bidó',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'HOPE, set in the year 2011 tells the story of a baby girl who '
#          'survives an abortion procedure, and how her survival touches other '
#          "people's lives 12 years later.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjA5NDQyOTkxOV5BMl5BanBnXkFtZTgwMTYwNDg2MTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Finding Hope',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Carlos Bidó, Raymond Carter Cantrell',
#  'Year': '2013',
#  'imdbID': 'tt2511506',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt1975158
# -------------------
# {'Actors': 'Josh Cooke, Liane Balaban, Barry Bostwick, Lainie Kazan',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Carlo De Rosa',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A self-absorbed writer, stuck in more ways than one, rediscovers '
#          'himself, his offbeat family, and what it means to be happy when he '
#          'meets Joy, a spirited young woman who asks him to write her '
#          'obituary.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTUwNTU5MjYxMF5BMl5BanBnXkFtZTcwMDMwMDE5OA@@._V1_SX300.jpg',
#  'Production': 'Gravitas Ventures',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.3/10'}],
#  'Released': '07 Jun 2013',
#  'Response': 'True',
#  'Runtime': '96 min',
#  'Title': 'Finding Joy',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Shona Tuckman',
#  'Year': '2013',
#  'imdbID': 'tt1975158',
#  'imdbRating': '5.3',
#  'imdbVotes': '344'}
# -------------------
# movie id tt1916766
# -------------------
# {'Actors': "Michael O'Keefe, Catherine Dent, Blake Bashoff, Julie Mond",
#  'Awards': '1 win.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ron Judkins',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A formerly acclaimed graphic novelist goes looking for true '
#          'connection outside of his marriage, and over the fence.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzkwNzg3MzMxMl5BMl5BanBnXkFtZTgwMjk0MzgxMDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.0/10'}],
#  'Released': '25 Oct 2013',
#  'Response': 'True',
#  'Runtime': '96 min',
#  'Title': 'Finding Neighbors',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ron Judkins',
#  'Year': '2013',
#  'imdbID': 'tt1916766',
#  'imdbRating': '6.0',
#  'imdbVotes': '109'}
# -------------------
# movie id tt2294617
# -------------------
# {'Actors': 'Shanna Brock, Jeffery Hall Scotland, Elizabeth Leadon Sonnenfelt, '
#            'Daved Wilkins',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Melissa Cushman Banczak',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When her ex-partner Jack returns from the grave, a novice PI enlists '
#          'the help of a romance novelist and a method actress to help solve '
#          'his murder.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '28 Apr 2013',
#  'Response': 'True',
#  'Runtime': '91 min',
#  'Title': 'Finley Wade',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Melissa Cushman Banczak',
#  'Year': '2013',
#  'imdbID': 'tt2294617',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3062374
# -------------------
# {'Actors': 'Claire Coppi, Tyson Griffard, Michael Holding, Omer Abbas Salem',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ryan Ohm',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A portrait of a lost generation, seen through the mind of Finn, as '
#          'he tries to find a new perspective and escape it. A micro-budget, '
#          'DIY-minded, independent film incorporating elements from mumblecore '
#          'and found footage cinema.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTM0ZjY2OGYtMTQ0MS00ODRmLWJhNTAtZTkzYzkxYTViZDM3XkEyXkFqcGdeQXVyMzY4MTQzNzA@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.1/10'}],
#  'Released': '15 Dec 2013',
#  'Response': 'True',
#  'Runtime': '99 min',
#  'Title': 'Finn & the Sea of Noise',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ryan Ohm',
#  'Year': '2013',
#  'imdbID': 'tt3062374',
#  'imdbRating': '8.1',
#  'imdbVotes': '84'}
# -------------------
# movie id tt2437382
# -------------------
# {'Actors': 'Bo Barrett, Gilbert J. Menchaca, Charles Milano, Amelia Morck',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'J.J. Lask',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Fireflies is the stirring dramatic story of two friends, Hart and '
#          'Johnny to overcome personal demons and escape the monotony of small '
#          'town life for a chance to start living. Johnny has ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Jan 2013',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Fireflies',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Bo Barrett (story), Bo Barrett, Josh Gloer (screenplay), Gilbert '
#            'J. Menchaca, Gilbert J. Menchaca (story)',
#  'Year': '2013',
#  'imdbID': 'tt2437382',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7144878
# -------------------
# {'Actors': 'Jamie Higgs, Ulises Larramendi, Austin Murray, Don Ortolano',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jake M. Allen',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Oct 2013',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'First Love: Breathe Talk to God Listen',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2013',
#  'imdbID': 'tt7144878',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2508258
# -------------------
# {'Actors': 'Brandon Alexander III, Dudley Beene, Lauren Rose Lewis, Michael '
#            'Turchin',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '20 Apr 2015',
#  'Director': 'Charlie Vaughn',
#  'Genre': 'Comedy',
#  'Language': 'English, Middle English',
#  'Metascore': 'N/A',
#  'Plot': 'New girl Cassie (Brandon Alexander III) and outcast Maggie (Dudley '
#          'Beene) are easily the most awkward girls in high school. Together, '
#          'they decide the way to win the hearts of the cute boys ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTgzMzc0MzA4OV5BMl5BanBnXkFtZTgwNjc4NjkwNzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'}],
#  'Released': '27 Jul 2013',
#  'Response': 'True',
#  'Runtime': '100 min',
#  'Title': 'First Period',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Brandon Alexander III',
#  'Year': '2013',
#  'imdbID': 'tt2508258',
#  'imdbRating': '6.2',
#  'imdbVotes': '547'}
# -------------------
# movie id tt2798018
# -------------------
# {'Actors': 'Ronan Barbour, Erica Fan, Florence C.M. Klein, Lily Sun',
#  'Awards': '1 win.',
#  'BoxOffice': 'N/A',
#  'Country': 'China, USA',
#  'DVD': 'N/A',
#  'Director': 'Erica Fan',
#  'Genre': 'Drama',
#  'Language': 'Chinese, English',
#  'Metascore': 'N/A',
#  'Plot': 'Xue and Yu are twin orphaned sisters living in China. One day, Yu is '
#          'adopted away to live in the United States, leaving Xue to live alone '
#          'in China. Growing up a hard life, Xue suffers from ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Aug 2013',
#  'Response': 'True',
#  'Runtime': '110 min',
#  'Title': 'Fish in the Sky',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Erica Fan',
#  'Year': '2013',
#  'imdbID': 'tt2798018',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2186781
# -------------------
# {'Actors': 'Ryan Steele, Reed Luplau, Catherine Miller, Kimiye Corwin',
#  'Awards': '1 win & 2 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '29 Jul 2014',
#  'Director': 'Alan Brown',
#  'Genre': 'Drama, Music, Romance',
#  'Language': 'English',
#  'Metascore': '51',
#  'Plot': 'The coming of age tale of an extraordinarily gifted young dancer '
#          'recently arrived in New York City.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzkzODQ1Mzg4MV5BMl5BanBnXkFtZTgwNzk3NzEyMDE@._V1_SX300.jpg',
#  'Production': 'Paladin',
#  'Rated': 'TV-14',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '55%'},
#              {'Source': 'Metacritic', 'Value': '51/100'}],
#  'Released': '04 Oct 2013',
#  'Response': 'True',
#  'Runtime': '83 min',
#  'Title': 'Five Dances',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Alan Brown',
#  'Year': '2013',
#  'imdbID': 'tt2186781',
#  'imdbRating': '7.1',
#  'imdbVotes': '2,373'}
# -------------------
# movie id tt1536051
# -------------------
# {'Actors': 'Malik Barnhardt, Taryn Manning, Tom Sizemore, Steven Bauer',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kader Ayd',
#  'Genre': 'Drama',
#  'Language': 'English, French',
#  'Metascore': 'N/A',
#  'Plot': 'In this tension-packed thriller, brothers Mike and Tre set out in '
#          'search of better lives, trying to leave their demons behind for '
#          'good. After being released from prison for a crime he ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYWE2NTE3YTgtMzQxMS00OGMxLWI3NGEtNWI2Yzg5NTc1NjExXkEyXkFqcGdeQXVyMTg2MTc1MjM@._V1_SX300.jpg',
#  'Production': 'Entertainment One',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.3/10'}],
#  'Released': '11 Jun 2014',
#  'Response': 'True',
#  'Runtime': '110 min',
#  'Title': 'Five Thirteen',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kader Ayd, Renee Topper',
#  'Year': '2013',
#  'imdbID': 'tt1536051',
#  'imdbRating': '4.3',
#  'imdbVotes': '617'}
# -------------------
# movie id tt2715352
# -------------------
# {'Actors': 'Lakisha May, Reginald L. Barnes, Edgar Moore Jr., Chrystal Stone',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Travis Williams',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "'FLAWED' is a Christian film powered by a story of the desire to be "
#          'better individuals. April Stone (Lakisha May) is trying desperately '
#          'to reconnect with her alcoholic father, Eli (Hal ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ4NDQyODk2NV5BMl5BanBnXkFtZTcwMDgwMjYzOQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Mar 2013',
#  'Response': 'True',
#  'Runtime': '94 min',
#  'Title': 'Flawed',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2013',
#  'imdbID': 'tt2715352',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4047114
# -------------------
# {'Actors': 'Kim Shupe, Jason Hernandez, Gustavo Cologne, Megan Danielle Beamer',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kirk Ferriola',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Bumbling rednecks and vacationing college students must battle the '
#          'coming zombie apocalypse.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.9/10'}],
#  'Released': '05 Oct 2013',
#  'Response': 'True',
#  'Runtime': '108 min',
#  'Title': 'Flesh Eating Bastards',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kirk Ferriola',
#  'Year': '2013',
#  'imdbID': 'tt4047114',
#  'imdbRating': '2.9',
#  'imdbVotes': '8'}
# -------------------
# movie id tt3016652
# -------------------
# {'Actors': 'Todd Chandler, Kyle De Camp, Nona Marie Invie, Jonathan Kaiser',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Todd Chandler',
#  'Genre': 'Drama, Music',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Flood Tide tells the story of a group of artists and musicians who '
#          'create extraordinary boats out of ordinary junk and set out for open '
#          'water.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTExNjEyODY0MzleQTJeQWpwZ15BbWU3MDM5ODUyODk@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '24 Nov 2013',
#  'Response': 'True',
#  'Runtime': '70 min',
#  'Title': 'Flood Tide',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Todd Chandler',
#  'Year': '2013',
#  'imdbID': 'tt3016652',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3110280
# -------------------
# {'Actors': "Serenity Eden Halstead, Michelle L'Halstead",
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Stefanie Halstead',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '17 Aug 2013',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Flowers',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Stefanie Halstead',
#  'Year': '2013',
#  'imdbID': 'tt3110280',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2428196
# -------------------
# {'Actors': 'Patricia Binkley, Brittany Herd, PattiNicole Wheeler, Robert Baker '
#            'Jr.',
#  'Awards': '1 win & 2 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '14 Oct 2013',
#  'Director': 'Sharon Wilharm',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Fannie Fairchild locked up her heart when her beloved George was '
#          'killed in the Great War. But now she faces her own mortality and '
#          'realizes that she has no one to maintain her grave with ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc0NTE3NTcxM15BMl5BanBnXkFtZTgwNzgyNjc0MzE@._V1_SX300.jpg',
#  'Production': 'Mainstreet Productions',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.7/10'}],
#  'Released': '01 Mar 2013',
#  'Response': 'True',
#  'Runtime': '101 min',
#  'Title': 'Flowers for Fannie',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Sharon Wilharm',
#  'Year': '2013',
#  'imdbID': 'tt2428196',
#  'imdbRating': '7.7',
#  'imdbVotes': '23'}
# -------------------
# movie id tt3124738
# -------------------
# {'Actors': 'Mike Mecek, Myles Dabbs, Garrett Palensky, Keith Homan',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jim Fields',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Friendship, love, and acceptance, set in the heartland of America.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjQwOTA4NzQ1OV5BMl5BanBnXkFtZTgwNjMwNTgwMDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.7/10'}],
#  'Released': '12 Jan 2014',
#  'Response': 'True',
#  'Runtime': '100 min',
#  'Title': 'Flyover Country',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jim Fields, Shaun Vetick',
#  'Year': '2013',
#  'imdbID': 'tt3124738',
#  'imdbRating': '7.7',
#  'imdbVotes': '22'}
# -------------------
# movie id tt2716576
# -------------------
# {'Actors': 'Bruce Marchiano, Robert Purdy, Claire Walkington, Tara Ward',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, UK',
#  'DVD': 'N/A',
#  'Director': 'Andrew Walkington',
#  'Genre': 'Drama, Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "For Love's Sake is a faith-based drama based on a true story. After "
#          'the tragic death of her husband, Mary Walker falls into a spiral of '
#          'suicidal depression and subsequently loses custody of...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ1MDY4NzYyMV5BMl5BanBnXkFtZTgwMzUzNTAxMjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.4/10'}],
#  'Released': '17 Jun 2013',
#  'Response': 'True',
#  'Runtime': '93 min',
#  'Title': "For Love's Sake",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Richard Brimblecombe, Andrew Walkington',
#  'Year': '2013',
#  'imdbID': 'tt2716576',
#  'imdbRating': '6.4',
#  'imdbVotes': '18'}
# -------------------
# movie id tt3107374
# -------------------
# {'Actors': 'Christine Bermudez, Harold Boynes, Kenya Cagle, Shaan Davis',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kenya Cagle',
#  'Genre': 'Comedy, Drama, Family',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'Relationships are destroyed when two married best friends engage in '
#          'long term affairs with sisters. After meeting two beautiful women on '
#          'the night before their weddings, two friends decide to keep on going '
#          'side relationships for years.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'For Old Time Sake',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Mack Williams',
#  'Year': '2013',
#  'imdbID': 'tt3107374',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3360838
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'N/A',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'N/A',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'Chronicles several years on the road with the Christian hardcore '
#          'band For Today as the tour, record, shoot music videos, and spend '
#          'time with their friends, families and fans.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjEyMjg5NjMyOF5BMl5BanBnXkFtZTgwOTI5ODE3MDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Apr 2013',
#  'Response': 'True',
#  'Runtime': '82 min',
#  'Title': 'For Today',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2013',
#  'imdbID': 'tt3360838',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2449590
# -------------------
# {'Actors': 'Charlette Speigner, Shariba Rivers, Jerod Haynes, Eugene Parker',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Katherine Nero',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'As Mirai Scott, a civil rights attorney, celebrates her most recent '
#          'court victory on behalf of a wrongly convicted man, she is contacted '
#          'by her father, Rolly Spencer, a former Black Panther...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTczNjY5MDEzMl5BMl5BanBnXkFtZTgwODU4NzAyMDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '9.0/10'}],
#  'Released': '03 Aug 2013',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'For the Cause',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Katherine Nero',
#  'Year': '2013',
#  'imdbID': 'tt2449590',
#  'imdbRating': '9.0',
#  'imdbVotes': '7'}
# -------------------
# movie id tt2324544
# -------------------
# {'Actors': 'Jessica Barrow, Denee Busby, Marla Gibbs, Jackée Harry',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '02 Apr 2013',
#  'Director': 'Clyde Jones, Charles R. Penland(co-director)',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Elston has earned the respect and trust of Randall Trace, his boss '
#          'and mentor. However, Elston reaches a pivotal point in his career '
#          'when, after missing out on a coveted promotion, he falls...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTcyODk1OTI0OV5BMl5BanBnXkFtZTgwNzAyNzA2MDE@._V1_SX300.jpg',
#  'Production': 'Entertainment One',
#  'Rated': 'NOT RATED',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.2/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '91 min',
#  'Title': 'Forbidden Woman',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dan Garcia',
#  'Year': '2013',
#  'imdbID': 'tt2324544',
#  'imdbRating': '4.2',
#  'imdbVotes': '34'}
# -------------------
# movie id tt2611626
# -------------------
# {'Actors': 'Steven Seagal, Ving Rhames, Danny Trejo, Bren Foster',
#  'Awards': '1 win.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '17 Dec 2013',
#  'Director': 'Keoni Waxman',
#  'Genre': 'Action, Crime',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A crime boss sends his top man to kill a prisoner. He gets the wrong '
#          "man and pays the price. 6 months later he's back on his feet. His ex "
#          "boss is now being squeezed out by Ice Man, who's responsible for the "
#          '"wrong man" deal.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQxOTU3OTI5OF5BMl5BanBnXkFtZTgwMTY1OTY3MDE@._V1_SX300.jpg',
#  'Production': 'Anchor Bay Entertainment',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.4/10'}],
#  'Released': '13 Mar 2014',
#  'Response': 'True',
#  'Runtime': '99 min',
#  'Title': 'Force of Execution',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Richard Beattie, Michael Black',
#  'Year': '2013',
#  'imdbID': 'tt2611626',
#  'imdbRating': '4.4',
#  'imdbVotes': '2,829'}
# -------------------
# movie id tt2827192
# -------------------
# {'Actors': "Noël Wells, Matt Mider, Amanda Bauer, Timmy L'Heureux",
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Molly Green, James Leffler',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Sophie and Pete get engaged on their first date, which is a 6-hour '
#          'drive through the desert. And then nothing goes wrong... nothing at '
#          'all.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTU5MjI0ODE0NV5BMl5BanBnXkFtZTcwODgyNjY2OQ@@._V1_SX300.jpg',
#  'Production': 'Mance Media',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.7/10'}],
#  'Released': '01 May 2014',
#  'Response': 'True',
#  'Runtime': '88 min',
#  'Title': 'Forev',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Molly Green, James Leffler, Noël Wells (additional screenplay '
#            'material), Matt Mider (additional screenplay material), Amanda '
#            'Bauer (additional screenplay material)',
#  'Year': '2013',
#  'imdbID': 'tt2827192',
#  'imdbRating': '5.7',
#  'imdbVotes': '273'}
# -------------------
# movie id tt2014225
# -------------------
# {'Actors': 'Charity Farrell, Lili Reinhart, Warren Bryson, David Wetzel',
#  'Awards': '2 wins.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'J.C. Schroder',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Six years after an apocalyptic event killed her family and seemingly '
#          'everyone else on earth, a lone girl on the verge of insanity is '
#          'forced to question everything she has ever known when a ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc5MjE3NDE5NF5BMl5BanBnXkFtZTgwMjc5NDM5MjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.1/10'}],
# ...
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '02 Jun 2015',
#  'Director': 'Joseph Ruben',
#  'Genre': 'Drama, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A reclusive, blind photojournalist lives quietly in a New York '
#          'penthouse, until a smooth but sadistic criminal looking for a hidden '
#          'fortune enters her life.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYTM3MDEwODItOGNkMC00Y2JiLWFhY2EtYmNjMTI0YWM1ZmUzXkEyXkFqcGdeQXVyNzg3NjQyOQ@@._V1_SX300.jpg',
#  'Production': 'The Weinstein Company',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.6/10'}],
#  'Released': '04 Jan 2014',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Blindsided',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'David Loughery',
#  'Year': '2013',
#  'imdbID': 'tt2055709',
#  'imdbRating': '5.6',
#  'imdbVotes': '4,772'}
# -------------------
# movie id tt3320158
# -------------------
# {'Actors': 'Jason Mac, Morgan Ayres, James Harvley, Hunter Bolton',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Matthew Mercier',
#  'Genre': 'Drama, Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'People Not Humans is a dark drama about a young man, Jack Logan, who '
#          'has depression removed from his mind through a genetic engineering '
#          'experiment.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '77 min',
#  'Title': 'People Not Humans',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Matthew Mercier',
#  'Year': '2013',
#  'imdbID': 'tt3320158',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt1854564
# -------------------
# {'Actors': 'Logan Lerman, Alexandra Daddario, Douglas Smith, Leven Rambin',
#  'Awards': '3 wins & 5 nominations.',
#  'BoxOffice': '$68,558,662',
#  'Country': 'USA',
#  'DVD': '17 Dec 2013',
#  'Director': 'Thor Freudenthal',
#  'Genre': 'Adventure, Family, Fantasy, Thriller',
#  'Language': 'English',
#  'Metascore': '39',
#  'Plot': 'In order to restore their dying safe haven, the son of Poseidon and '
#          'his friends embark on a quest to the Sea of Monsters, to find the '
#          'mythical Golden Fleece, all the while trying to stop an ancient evil '
#          'from rising.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYmE4MThmY2UtNDYxOC00YmFkLTg1NGEtMTQ3YTFmZjdhZmRiXkEyXkFqcGdeQXVyNjA3MDQ1NzY@._V1_SX300.jpg',
#  'Production': '20th Century Fox',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '42%'},
#              {'Source': 'Metacritic', 'Value': '39/100'}],
#  'Released': '07 Aug 2013',
#  'Response': 'True',
#  'Runtime': '106 min',
#  'Title': 'Percy Jackson: Sea of Monsters',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Marc Guggenheim (screenplay by), Rick Riordan (based upon the '
#            'novel "Percy Jackson and the Olympians: The Sea of Monsters" '
#            'written by)',
#  'Year': '2013',
#  'imdbID': 'tt1854564',
#  'imdbRating': '5.8',
#  'imdbVotes': '104,750'}
# -------------------
# movie id tt2385169
# -------------------
# {'Actors': 'Roberto Lombardi, Samantha Talbott, Kasey Williams, Rick Zahn',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Chris R. Notarile',
#  'Genre': 'Action, Drama, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The perfect killing machine is reprogrammed to think and feel.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzk5NDQxNjU5OF5BMl5BanBnXkFtZTcwMzYzNzg1OA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '1.8/10'}],
#  'Released': '08 Jul 2014',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'Perfect: Android Rising',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Chris R. Notarile',
#  'Year': '2013',
#  'imdbID': 'tt2385169',
#  'imdbRating': '1.8',
#  'imdbVotes': '326'}
# -------------------
# movie id tt3180138
# -------------------
# {'Actors': 'Joseph Copley, Margret Cromwell',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'John Sanborn',
#  'Genre': 'Comedy, History, Music',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'If you took the musical revolution of John Cage, the radical '
#          'thinking of Marcel Duchamp, and the media anarchy of Nam June Paik, '
#          'and put them in a blender; the result would be PICO (...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '88 min',
#  'Title': 'Performance Indeterminate Cage Opera',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'John Sanborn (story), John Sanborn',
#  'Year': '2013',
#  'imdbID': 'tt3180138',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2719220
# -------------------
# {'Actors': 'Jamie Cahill, Charlotte Cannon, Patrick Falcon, Gabe Harshman',
#  'Awards': '2 wins.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Caleb Noel',
#  'Genre': 'Adventure, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Four seemingly everyday people from different walks of life cross '
#          'paths after receiving a mysterious phone call. They do not know why '
#          'they were called together, but upon meeting their ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '68 min',
#  'Title': 'Persephone',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Patrick Falcon (story), Patrick Falcon, Kevin McAuliffe, Caleb '
#            'Noel (story), Caleb Noel, Sasha Vukovic (story), Sasha Vukovic',
#  'Year': '2013',
#  'imdbID': 'tt2719220',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2260920
# -------------------
# {'Actors': 'Ariana Adili, Peter Beck, Madeline Caleskie, Elizabeth Cohen',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Adam Sotelo',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzQ5ZTkxODMtZTU1OC00ZjdkLWI0YjYtMzhhOTY4YjRkYjIwXkEyXkFqcGdeQXVyMjUxOTAxNzI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.7/10'}],
#  'Released': '07 Nov 2013',
#  'Response': 'True',
#  'Runtime': '74 min',
#  'Title': 'Perseveration',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Adam Sotelo',
#  'Year': '2013',
#  'imdbID': 'tt2260920',
#  'imdbRating': '4.7',
#  'imdbVotes': '39'}
# -------------------
# movie id tt3659066
# -------------------
# {'Actors': "Peter Gabriel, Youssou N'Dour",
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Michael Chapman',
#  'Genre': 'Music',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A concert that was recorded in Athens, Greece, during Peter '
#          "Gabriel's So tour.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ3MzIyODI2NF5BMl5BanBnXkFtZTgwMjA2NjU3NTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.9/10'}],
#  'Released': '16 Sep 2013',
#  'Response': 'True',
#  'Runtime': '177 min',
#  'Title': 'Peter Gabriel: Live in Athens 1987',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2013',
#  'imdbID': 'tt3659066',
#  'imdbRating': '8.9',
#  'imdbVotes': '34'}
# -------------------
# movie id tt2896838
# -------------------
# {'Actors': 'Justin Xavier, Larry Mims, Tara Gulledge, Dinah Sade',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Fred Forte Jr.',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTU4OTc5MTk1OF5BMl5BanBnXkFtZTcwNTQwOTU1OQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '17 Aug 2013',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Petey',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Fred Forte Jr.',
#  'Year': '2013',
#  'imdbID': 'tt2896838',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2366182
# -------------------
# {'Actors': 'Michael Klemp, Gretta Sosine, Charlie Merlo, Gary Conover',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Gerry Davenport',
#  'Genre': 'Drama, Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An endearing and heart touching story about Michael, his '
#          'relationship with his father, his daughter, his wife, and his own '
#          'mortality as he returns home after 25 years. Bitter, '
#          'disappointed,...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'}],
#  'Released': '23 Jun 2013',
#  'Response': 'True',
#  'Runtime': '55 min',
#  'Title': 'Petite Chardonnay',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Gerry Davenport (story), Gerry Davenport',
#  'Year': '2013',
#  'imdbID': 'tt2366182',
#  'imdbRating': '7.0',
#  'imdbVotes': '33'}
# -------------------
# movie id tt1922685
# -------------------
# {'Actors': 'Ed Harris, David Duchovny, William Fichtner, Lance Henriksen',
#  'Awards': 'N/A',
#  'BoxOffice': '$1,000,000',
#  'Country': 'USA',
#  'DVD': '25 Jun 2013',
#  'Director': 'Todd Robinson',
#  'Genre': 'Drama, History, Thriller, War',
#  'Language': 'English',
#  'Metascore': '40',
#  'Plot': 'The haunted Captain of a Soviet submarine holds the fate of the '
#          'world in his hands. Forced to leave his family behind, he is charged '
#          'with leading a covert mission cloaked in mystery.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ0OTA5MDgzM15BMl5BanBnXkFtZTcwMDM3NTU3OQ@@._V1_SX300.jpg',
#  'Production': 'RCR Distribution',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '25%'},
#              {'Source': 'Metacritic', 'Value': '40/100'}],
#  'Released': '01 Mar 2013',
#  'Response': 'True',
#  'Runtime': '98 min',
#  'Title': 'Phantom',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Todd Robinson',
#  'Year': '2013',
#  'imdbID': 'tt1922685',
#  'imdbRating': '5.8',
#  'imdbVotes': '13,005'}
# -------------------
# movie id tt2768874
# -------------------
# {'Actors': 'Delaney Hathaway, J.R.S. Storch, Richard Hackel, Mark S. Esch',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Michael Storch',
#  'Genre': 'Drama, Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Two young teenagers believe their worst issues are within their '
#          'everyday lives and homes, until strange occurrences and mysterious '
#          'deaths begin to terrorize the small neighborhood.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BY2U4MzA1ZTktNmM2YS00MTA4LTg1NjAtNTAzZjc3NzgxMTAwXkEyXkFqcGdeQXVyMjg4MjkyMzQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'NOT RATED',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.1/10'}],
#  'Released': '30 Jun 2013',
#  'Response': 'True',
#  'Runtime': '101 min',
#  'Title': 'Phantom of the Woods',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Cam Clark, Joe Leatherman, J.R.S. Storch, Michael Storch, Ryan '
#            'Woebbeking',
#  'Year': '2013',
#  'imdbID': 'tt2768874',
#  'imdbRating': '4.1',
#  'imdbVotes': '108'}
# -------------------
# movie id tt1512686
# -------------------
# {'Actors': 'Jess Sylvia, Robin Steffen, Shaun Paul Piccinino, Matt Thompson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jason Sanders',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Set in a post-apocalyptic future as survivors of a deadly virus try '
#          'to adapt. Reynolds, a high strung professor, and Sonya, his '
#          'tough-minded assistant, fight to find a cure and take in a ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjA1MjY2MTUzM15BMl5BanBnXkFtZTcwNzUyMTQ1Mw@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'}],
#  'Released': '27 Sep 2013',
#  'Response': 'True',
#  'Runtime': '102 min',
#  'Title': 'Phase Two',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Rickey Bird Jr. (story), Rickey Bird Jr., Bryce Hatch '
#            '(screenplay), Jason Sanders',
#  'Year': '2013',
#  'imdbID': 'tt1512686',
#  'imdbRating': '6.2',
#  'imdbVotes': '16'}
# -------------------
# movie id tt2772984
# -------------------
# {'Actors': 'Jonathan Franzen, Nicole Krauss, Philip Roth',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '24 Nov 2014',
#  'Director': 'William Karel',
#  'Genre': 'Biography',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Explore the life of Pulitzer Prize and National Book Award winning '
#          'novelist Philip Roth, often referred to as the greatest living '
#          'American writer.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTU0OTczODY0OV5BMl5BanBnXkFtZTgwNzE5NzA2MDE@._V1_SX300.jpg',
#  'Production': 'Cinétéve',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '63%'}],
#  'Released': '13 Mar 2013',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Philip Roth: Unmasked',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'William Karel, Livia Manera',
#  'Year': '2013',
#  'imdbID': 'tt2772984',
#  'imdbRating': '7.0',
#  'imdbVotes': '19'}
# -------------------
# movie id tt2431286
# -------------------
# {'Actors': 'Judi Dench, Steve Coogan, Sophie Kennedy Clark, Mare Winningham',
#  'Awards': 'Nominated for 4 Oscars. Another 33 wins & 80 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'UK, USA, France',
#  'DVD': '15 Apr 2014',
#  'Director': 'Stephen Frears',
#  'Genre': 'Biography, Comedy, Drama',
#  'Language': 'English',
#  'Metascore': '77',
#  'Plot': "A world-weary political journalist picks up the story of a woman's "
#          'search for her son, who was taken away from her decades ago after '
#          'she became pregnant and was forced to live in a convent.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjA5ODgyNzcxMV5BMl5BanBnXkFtZTgwMzkzOTYzMDE@._V1_SX300.jpg',
#  'Production': 'The Weinstein Company',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '90%'},
#              {'Source': 'Metacritic', 'Value': '77/100'}],
#  'Released': '27 Nov 2013',
#  'Response': 'True',
#  'Runtime': '98 min',
#  'Title': 'Philomena',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Steve Coogan (screenplay), Jeff Pope (screenplay), Martin Sixsmith '
#            '(book)',
#  'Year': '2013',
#  'imdbID': 'tt2431286',
#  'imdbRating': '7.6',
#  'imdbVotes': '90,174'}
# -------------------
# movie id tt2443986
# -------------------
# {'Actors': 'Brandon Stacy, Eric Frentzel, Keith Black, Jackson Bond Jr.',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Patrick Chapman, Keith Black',
#  'Genre': 'Comedy, Drama, Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Sam, a struggling artist, has one opportunity to impress a dealer '
#          'and his assistant. However, an unexpected visit from his brother, '
#          'Phin, who suffers from frontal lobe damage, pulls all of them all '
#          'into a night of constant delusions.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODEwNDY0MjIyNl5BMl5BanBnXkFtZTcwMDY3NTQ5OQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '30 Mar 2013',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Phin',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Timothy Chapman',
#  'Year': '2013',
#  'imdbID': 'tt2443986',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}

# %%
len(title_list)
# Out:
# 995

# %%
len(title_id)
# Out:
# 995

# %%
# if title_list and title_id are the same length run the cell below. 
# if they are not equal take out 'title_id': title_id

# %%
df = pd.DataFrame({'title_id': title_id, 'title': title_list, 'box_office': box_office_list, 'country': country_list, 
                   'genre': genre_list, 'director': director_list, 'metascore': metascore_list, 'production': production_list, 
                   'rating': rating_list, 'IMDB_rating': IMDB_rating_list, 'rotten_tomatoes_rating': rotten_tomatoes_rating_list, 
                  'runtime': runtime_list, 'type': type_list, 'IMDB_votes': imdb_votes_list})

# %%
df = df.drop_duplicates()
df.head()
# Out:
#     title_id             title box_office country  \
# 0  tt2332623  Fateful Findings        N/A     USA
# 1  tt3278650         Faux Paws        N/A     USA
# 2  tt1971397             Favor        N/A     USA
# 3  tt2966192              Faze        N/A     USA
# 4  tt7573742           Feed Me        N/A     USA
#
#                                                genre           director  \
# 0  Drama, Fantasy, Mystery, Romance, Sci-Fi, Thri...         Neil Breen
# 1                                             Comedy          Doug Bari
# 2                                           Thriller       Paul Osborne
# 3                                              Drama     Alpheus Joseph
# 4                                   Horror, Thriller  Claudia Damasceno
#
#   metascore production     rating IMDB_rating rotten_tomatoes_rating  runtime  \
# 0       N/A        N/A  Not Rated         4.7                     NA  100 min
# 1       N/A        N/A        N/A         8.1                     NA   92 min
# 2       N/A   Gravitas        N/A         6.3                     NA  102 min
# 3       N/A        N/A        N/A         N/A                     NA  114 min
# 4       N/A        N/A  NOT RATED         N/A                     NA  100 min
#
#     type IMDB_votes
# 0  movie      3,639
# 1  movie          9
# 2  movie        798
# 3  movie        N/A
# 4  movie        N/A

# %%
df.count()
# Out:
# title_id                  995
# title                     995
# box_office                995
# country                   995
# genre                     995
# director                  995
# metascore                 995
# production                995
# rating                    995
# IMDB_rating               995
# rotten_tomatoes_rating    995
# runtime                   995
# type                      995
# IMDB_votes                995
# dtype: int64

# %%
df.to_csv('../data/2013_data_batch_2.csv', index=False)
