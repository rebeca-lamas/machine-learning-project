# %%
import pandas as pd
import requests
import json
import time
from pprint import pprint
from config import API_KEY

# %%
data = pd.read_csv('../data/titles_2013_batch3.csv')
df =  data.count()
df
# Out:
# title    1000
# dtype: int64

# %%
title_id = []
box_office_list = []
country_list = []
genre_list = []
director_list = []
metascore_list = []
production_list = []
rating_list = []
IMDB_rating_list = [] 
rotten_tomatoes_rating_list = []
runtime_list = []
title_list = []
type_list = []
imdb_votes_list = []

# %%
movies = data['title']
total_movies = len(movies)

# %%
for i in range(total_movies):
    movie = movies[i]
    url = "http://www.omdbapi.com/?i=" + movie + "&apikey=" + API_KEY
    response = (requests.get(url).text)
    response_json = json.loads(response)
    print('-------------------')
    print(f'movie id {movie}')
    print('-------------------')
    pprint(response_json)
    
    try:
        box_office_list.append(response_json['BoxOffice'])
        country_list.append(response_json['Country'])
        genre_list.append(response_json['Genre'])
        director_list.append(response_json['Director'])
        metascore_list.append(response_json['Metascore'])
        production_list.append(response_json['Production'])
        rating_list.append(response_json['Rated'])
        IMDB_rating_list.append(response_json['imdbRating'])
        try:
            if not response_json['Ratings']:
                rotten_tomatoes_rating_list.append('NA')
            elif response_json['Ratings'][0]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][0]['Value'])
            elif response_json['Ratings'][1]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][1]['Value'])
            else:
                rotten_tomatoes_rating_list.append('NA')
        except IndexError:
            rotten_tomatoes_rating_list.append('NA')
        runtime_list.append(response_json['Runtime'])
        title_list.append(response_json['Title'])
        type_list.append(response_json['Type'])
        imdb_votes_list.append(response_json['imdbVotes'])
        title_id.append(response_json['imdbID'])
    except KeyError:
        pass
    time.sleep(1)
# Out:
# -------------------
# movie id tt2075280
# -------------------
# {'Actors': 'Presley Money, Ian Sinclair, Erica Leerhsen, Matt Moore',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '25 Nov 2014',
#  'Director': 'Jon Keeyes',
#  'Genre': 'Horror, Thriller',
#  'Language': 'French, English',
#  'Metascore': 'N/A',
#  'Plot': 'In 1885, a female doctor helping a group of people with their '
#          'phobias becomes embroiled in a murder mystery surrounding a patient '
#          'that may or may not be a vampire.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTY4ODU1MzE3N15BMl5BanBnXkFtZTgwNzk5ODYxMDE@._V1_SX300.jpg',
#  'Production': 'Gravitas Horror',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.3/10'}],
#  'Released': '01 Sep 2013',
#  'Response': 'True',
#  'Runtime': '91 min',
#  'Title': 'Phobia',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Anne L. Gibson',
#  'Year': '2013',
#  'imdbID': 'tt2075280',
#  'imdbRating': '3.3',
#  'imdbVotes': '175'}
# -------------------
# movie id tt2379460
# -------------------
# {'Actors': 'Christina Marie Karis, Jefferson Moore, Nakia Barney, Sylvia '
#            'Boykin',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jefferson Moore',
#  'Genre': 'Comedy, Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An arrogant young executive is forced to rely on the assistance of a '
#          'grizzled, reclusive farmer to get her home in time for the upcoming '
#          'Easter holiday with her estranged family.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTYzNDMxOTk3OF5BMl5BanBnXkFtZTcwNDczNzA5OA@@._V1_SX300.jpg',
#  'Production': 'Kelly&#39;s Filmworks',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.4/10'}],
#  'Released': '01 Mar 2013',
#  'Response': 'True',
#  'Runtime': '98 min',
#  'Title': 'Pieces of Easter',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jefferson Moore (screenplay), Jefferson Moore (story)',
#  'Year': '2013',
#  'imdbID': 'tt2379460',
#  'imdbRating': '7.4',
#  'imdbVotes': '60'}
# -------------------
# movie id tt1790807
# -------------------
# {'Actors': 'Victor of Aquitaine, Tucker Bennett, Amy Davis, Hannah Levbarg',
#  'Awards': '1 win.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jon Moritsugu',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'After eating rotten meat, a brainless brunette is transformed into a '
#          'dangerous genius in a Doctor Doolittle twist, a '
#          'misanthropic-punk-rock-botanist babe gains power to "talk to '
#          'plants". ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTUwNDY1MjIyOF5BMl5BanBnXkFtZTcwMTg2OTgxNw@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.0/10'}],
#  'Released': '08 Mar 2013',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Pig Death Machine',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Amy Davis, Jon Moritsugu',
#  'Year': '2013',
#  'imdbID': 'tt1790807',
#  'imdbRating': '6.0',
#  'imdbVotes': '17'}
# -------------------
# movie id tt4390190
# -------------------
# {'Actors': 'Marie Caroline Hominal',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Gregg Mann, Liza Mann',
#  'Genre': 'Short',
#  'Language': 'French',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Pink Noise',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2013',
#  'imdbID': 'tt4390190',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3056562
# -------------------
# {'Actors': 'Kaylie Brooke, Cazi Greene, Riley Erin, Austin McMains',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jeff Harris',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjQxNjE2ZDEtNWE4MC00NzBhLTliOTItNDgwMmYzYTgwYTU0L2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNTEzNjM3MzY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '26 Oct 2013',
#  'Response': 'True',
#  'Runtime': '120 min',
#  'Title': "Piper's World",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jeff Harris',
#  'Year': '2013',
#  'imdbID': 'tt3056562',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3739828
# -------------------
# {'Actors': 'Jeffrey Power',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Frankie Symonds',
#  'Genre': 'Comedy, Drama, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A nearly zero- budget romp through the boring, stupid, and profane '
#          'life of Pisspants, a mentally ill, homeless, alcoholic clown. When '
#          'he and his feces- obsessed best friend, Gravy, both ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Nov 2013',
#  'Response': 'True',
#  'Runtime': '93 min',
#  'Title': 'Pisspants',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jeffrey Power, Frankie Symonds',
#  'Year': '2013',
#  'imdbID': 'tt3739828',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2397531
# -------------------
# {'Actors': 'Bailey Bass, Marcus DeAnda, Yesenia Garcia, Bill Heck',
#  'Awards': '4 wins & 4 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '04 Feb 2014',
#  'Director': 'Yen Tan',
#  'Genre': 'Drama, Romance',
#  'Language': 'English, Spanish',
#  'Metascore': 'N/A',
#  'Plot': 'Recovering from an ill-fated affair with a married man, Gabe finds '
#          'solace in the relationship he maintains with his ex-wife and '
#          'daughter. On the other side of town, Ernesto evades life at ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODQwMjA3NjkwOV5BMl5BanBnXkFtZTgwMDUzMTg5MDE@._V1_SX300.jpg',
#  'Production': 'Wolfe Releasing',
#  'Rated': 'NOT RATED',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.0/10'}],
#  'Released': '21 Jan 2013',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'Pit Stop',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'David Lowery, Yen Tan',
#  'Year': '2013',
#  'imdbID': 'tt2397531',
#  'imdbRating': '6.0',
#  'imdbVotes': '1,272'}
# -------------------
# movie id tt1724969
# -------------------
# {'Actors': 'Joni Adahl, Timothy Douglas Perez, Anita Cordell, Kihapiliani Akui',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tony Mendoza',
#  'Genre': 'Drama, Family, Sport',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A young, female college student is forced to compete in a '
#          'underground, high stakes game of horseshoes to win back her tuition '
#          'money.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTc5MjMzNjc1N15BMl5BanBnXkFtZTcwNjEwNDk5Ng@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.9/10'}],
#  'Released': '01 May 2013',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Pitching Hope',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tony Mendoza',
#  'Year': '2013',
#  'imdbID': 'tt1724969',
#  'imdbRating': '7.9',
#  'imdbVotes': '14'}
# -------------------
# movie id tt1738305
# -------------------
# {'Actors': "Robert Bielfelt, Cian Patrick O'Dowd, Brett Buzek, Chelsea "
#            'Breibart',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': "George O'Barts",
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Cole O\'Barts Entertainment proudly presents "Pizza Shop: The '
#          'Movie", written and directed by George O\'Barts. Starring Robert '
#          "Bielfelt, Cian Patrick O'Dowd and Brett Buzek, this raunchy, off...",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTM5ODkxMTIwMl5BMl5BanBnXkFtZTcwMDkzNzA5OA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'UNRATED',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'}],
#  'Released': '06 Jun 2013',
#  'Response': 'True',
#  'Runtime': '97 min',
#  'Title': 'Pizza Shop: The Movie',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': "George O'Barts",
#  'Year': '2013',
#  'imdbID': 'tt1738305',
#  'imdbRating': '6.2',
#  'imdbVotes': '15'}
# -------------------
# movie id tt2709236
# -------------------
# {'Actors': 'Phil Bernardin, Dan Hendrock, Sean T. Grant, Shobit Manchanda',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jordann Riley',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A young woman with a perilous secret puts aside her impending doom '
#          'and dissects her mundane life.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '57 min',
#  'Title': 'Plagued',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jordann Riley',
#  'Year': '2013',
#  'imdbID': 'tt2709236',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt1691917
# -------------------
# {'Actors': 'Dane Cook, Stacy Keach, Brad Garrett, Teri Hatcher',
#  'Awards': '5 nominations.',
#  'BoxOffice': '$71,270,759',
#  'Country': 'USA',
#  'DVD': '19 Nov 2013',
#  'Director': 'Klay Hall',
#  'Genre': 'Animation, Adventure, Comedy, Family',
#  'Language': 'English, Spanish',
#  'Metascore': '39',
#  'Plot': 'A cropdusting plane with a fear of heights lives his dream of '
#          'competing in a famous around-the-world aerial race.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjAwODc5NzYzOF5BMl5BanBnXkFtZTcwNTk4MjEzOQ@@._V1_SX300.jpg',
#  'Production': 'Walt Disney Pictures',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.7/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '26%'},
#              {'Source': 'Metacritic', 'Value': '39/100'}],
#  'Released': '09 Aug 2013',
#  'Response': 'True',
#  'Runtime': '91 min',
#  'Title': 'Planes',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'John Lasseter (original story by), Klay Hall (original story by), '
#            'Jeffrey M. Howard (original story by), Jeffrey M. Howard '
#            '(screenplay by), Roberts Gannaway (additional story material), Jon '
#            'Cryer (additional story material)',
#  'Year': '2013',
#  'imdbID': 'tt1691917',
#  'imdbRating': '5.7',
#  'imdbVotes': '40,696'}
# -------------------
# movie id tt3267466
# -------------------
# {'Actors': 'Cora Clifford',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Cora Clifford',
#  'Genre': 'Animation, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Sarah is a Christian woman who tells the audience about her past, '
#          'her personal life, how she became an alcoholic.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '05 Dec 2013',
#  'Response': 'True',
#  'Runtime': '76 min',
#  'Title': 'Plaster of Paris',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Cora Clifford',
#  'Year': '2013',
#  'imdbID': 'tt3267466',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2040470
# -------------------
# {'Actors': 'Carolina Bartczak, Tyrone Dancy Jr., Mackenzie Davis, Trieste '
#            'Kelly Dunn',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Myles Sorensen',
#  'Genre': 'Comedy, Drama, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'For Charles, video-games are a much needed escape from reality. But '
#          'when virtual vixen Sophia leads him on a mysterious quest through '
#          'the lovelorn lives of six New Yorkers, they will all ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjM1MzI0MTQ2OF5BMl5BanBnXkFtZTcwNDM3MDg4OQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'NOT RATED',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.3/10'}],
#  'Released': '20 Jan 2015',
#  'Response': 'True',
#  'Runtime': '79 min',
#  'Title': "Plato's Reality Machine",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Myles Sorensen',
#  'Year': '2013',
#  'imdbID': 'tt2040470',
#  'imdbRating': '5.3',
#  'imdbVotes': '73'}
# -------------------
# movie id tt1322353
# -------------------
# {'Actors': 'Caroline Bielskis, Jessica Borne, Kevin Carter, Mark Cirillo',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Natasa Prosenc Stearns',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The smartest men in Athens hold a contest to see who can give the '
#          'best speech about love.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '30 Jul 2015',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': "Plato's Symposium",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Wallace Zane',
#  'Year': '2013',
#  'imdbID': 'tt1322353',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2865568
# -------------------
# {'Actors': 'Ron Pucillo, David Alan Graf, Jonathan Erickson Eisley, Ben Seton',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'N/A',
#  'DVD': 'N/A',
#  'Director': 'Ron Pucillo',
#  'Genre': 'Crime',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ2OTE0ODY4Ml5BMl5BanBnXkFtZTcwNTQ5NDg2OQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.7/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Play Hard',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ron Pucillo',
#  'Year': '2013',
#  'imdbID': 'tt2865568',
#  'imdbRating': '7.7',
#  'imdbVotes': '7'}
# -------------------
# movie id tt2481500
# -------------------
# {'Actors': 'Esai Morales, Salli Richardson-Whitfield, Jenifer Lewis, Robert '
#            'Townsend',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Robert Townsend, Elijah Nathaniel Wells(co-director)',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A high school basketball coach tries to turn his team around.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjI4ODg1NDk5Nl5BMl5BanBnXkFtZTgwNDY4Njg4NzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'}],
#  'Released': '16 Jan 2015',
#  'Response': 'True',
#  'Runtime': '84 min',
#  'Title': "Playin' for Love",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michelle Amor, Robert Townsend, Cheryl L. West',
#  'Year': '2013',
#  'imdbID': 'tt2481500',
#  'imdbRating': '7.0',
#  'imdbVotes': '43'}
# -------------------
# movie id tt1137473
# -------------------
# {'Actors': 'Erin Cronican, Helen Green, Jeannie Andresakes, Shay Ansari',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jazzmyn Banks',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A modern-day coming-of-age sex comedy of mistaken identity, "Playing '
#          'Doctor" introduces us to innocent high-school sophomore Heather, a '
#          'future celebrity relationship author. She and her ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.7/10'}],
#  'Released': '23 Jul 2013',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Playing Doctor',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jazzmyn Banks (screenplay & story), Jillian Courtney (story), '
#            'Tamara Pessah (screenplay & story)',
#  'Year': '2013',
#  'imdbID': 'tt1137473',
#  'imdbRating': '7.7',
#  'imdbVotes': '6'}
# -------------------
# movie id tt2400256
# -------------------
# {'Actors': 'Karin Bergquist, Andy Blieden, John Doe, Joe Henry',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '19 May 2014',
#  'Director': 'Archie Borders',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Rocker Pete Jones (legendary "X" front man John Doe) is in trouble. '
#          "He's solo in his personal and professional life and he can't seem to "
#          'finish his long-awaited album. Threatened with ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzMyMzg2MDE5MV5BMl5BanBnXkFtZTcwNzcwNzI0OQ@@._V1_SX300.jpg',
#  'Production': 'Virgil Films',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.9/10'}],
#  'Released': '22 Apr 2014',
#  'Response': 'True',
#  'Runtime': '88 min',
#  'Title': 'Pleased to Meet Me',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Archie Borders, David Henry',
#  'Year': '2013',
#  'imdbID': 'tt2400256',
#  'imdbRating': '6.9',
#  'imdbVotes': '50'}
# -------------------
# movie id tt2091327
# -------------------
# {'Actors': 'Malena Morgan, Christos Vasilopoulos, Kayla Jane, Elle Alexandra',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Zalman King',
#  'Genre': 'Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A wealthy real estate developer takes a young woman from an everyday '
#          'mundane life and shows her a world of decadence and debauchery that '
#          'pushes her sexual limits to the brink.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjE2ODAxODkxNF5BMl5BanBnXkFtZTgwMjQ5NTk0MTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Unrated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.4/10'}],
#  'Released': '05 Sep 2013',
#  'Response': 'True',
#  'Runtime': '99 min',
#  'Title': 'Pleasure or Pain',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Zalman King',
#  'Year': '2013',
#  'imdbID': 'tt2091327',
#  'imdbRating': '4.4',
#  'imdbVotes': '1,991'}
# -------------------
# movie id tt2293288
# -------------------
# {'Actors': 'Cherie Johnson, Bubba Ganter, Tomas Johansson, Deuandra T. Brown',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Deuandra T. Brown',
#  'Genre': 'Fantasy, Horror, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Six friends go on a road trip to Sin City. On the road trip they '
#          'have an encounter with a UFO. Plum takes control of the situation, '
#          'finding herself in the middle of it all with Jack the leader from '
#          'the other planet. Dr. Hollins, Scientists Tara and Landon all try to '
#          'save the world.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjc1Mjc0MzA1OF5BMl5BanBnXkFtZTcwNjk3Mjg5OA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.3/10'}],
#  'Released': '28 Sep 2013',
#  'Response': 'True',
#  'Runtime': '120 min',
#  'Title': 'Plum',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Deuandra T. Brown (story), Deuandra T. Brown, Deuandra T. Brown',
#  'Year': '2013',
#  'imdbID': 'tt2293288',
#  'imdbRating': '5.3',
#  'imdbVotes': '24'}
# -------------------
# movie id tt2226519
# -------------------
# {'Actors': 'Emily Browning, Xavier Samuel, Cam Gigandet, Dawn Olivieri',
#  'Awards': 'N/A',
#  'BoxOffice': '$2,843',
#  'Country': 'USA',
#  'DVD': '15 Oct 2013',
#  'Director': 'Catherine Hardwicke',
#  'Genre': 'Drama, Music, Romance, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A young singer/songwriter, despite being married, becomes involved '
#          'with her new guitarist, who she soon discovers has a dark past and '
#          'may be a danger to her and those close to her.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjQ4MTQ0MTA5Ml5BMl5BanBnXkFtZTgwMzY3MTYwMDE@._V1_SX300.jpg',
#  'Production': 'Millennium Entertainment',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.3/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '33%'}],
#  'Released': '15 Oct 2013',
#  'Response': 'True',
#  'Runtime': '99 min',
#  'Title': 'Plush',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Catherine Hardwicke, Arty Nelson',
#  'Year': '2013',
#  'imdbID': 'tt2226519',
#  'imdbRating': '5.3',
#  'imdbVotes': '3,526'}
# -------------------
# movie id tt3452994
# -------------------
# {'Actors': 'Ephraim Benton, Victoria Bundonis, China L. Colston, Lindsay B. '
#            'Davis',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Sean Sawyer',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Crista De Leon (a gay spoken word artist) loves to write and perform '
#          'for a crowd. She spends her days at her restaurant job and school '
#          "but she can't wait for the sun to go down so she can ...",
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '13 Nov 2013',
#  'Response': 'True',
#  'Runtime': '96 min',
#  'Title': 'Pocket Full of Nickels-Te Adoro',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Sean Sawyer',
#  'Year': '2013',
#  'imdbID': 'tt3452994',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2160331
# -------------------
# {'Actors': 'Alfred Molina, Joanna Scanlan, Mark Somen',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Michael Sporn',
#  'Genre': 'Animation',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A biography of Edgar Allan Poe wraps around four of his most famous '
#          'tales and several of his poems.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '06 Jun 2013',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Poe',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Maxine Fisher',
#  'Year': '2013',
#  'imdbID': 'tt2160331',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2447920
# -------------------
# {'Actors': 'David Fetzer, Jared Shipley, Joshua David McLerran, Eric Fisher',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Conor Long',
#  'Genre': 'Comedy, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Four friends and Graduate students in the physics department of '
#          'their University discover their clean energy machine actually works '
#          'as a crude, rudimentary teleportation device. Through ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTA5MjY3Njk3MTReQTJeQWpwZ15BbWU4MDY4Nzg3NDAx._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.1/10'}],
#  'Released': '14 Aug 2015',
#  'Response': 'True',
#  'Runtime': '94 min',
#  'Title': 'Point B',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'David Gitlin',
#  'Year': '2013',
#  'imdbID': 'tt2447920',
#  'imdbRating': '7.1',
#  'imdbVotes': '13'}
# -------------------
# movie id tt2158695
# -------------------
# {'Actors': 'Karl Jacob, Kate Lyn Sheil, Jennifer Prediger, Larry Mitchell',
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'T. Arthur Cottam(co-director), Karl Jacob(co-director)',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'On the heels of a bitter breakup, 30 year old Dylan travels home to '
#          'Minnesota for a family reunion where he runs into his childhood '
#          'sweetheart. Having not seen each other for 18 years, ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjQ5OTkwNjMzMF5BMl5BanBnXkFtZTcwMDI4NDM0Nw@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.4/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '79 min',
#  'Title': 'Pollywogs',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Karl Jacob, Karl Jacob (story), T. Arthur Cottam (story), Larry '
#            'Mitchell (additional material), Jennifer Prediger (additional '
#            'material), Kate Lyn Sheil (additional material), Gabrielle Penabaz '
#            '(additional material)',
#  'Year': '2013',
#  'imdbID': 'tt2158695',
#  'imdbRating': '6.4',
#  'imdbVotes': '35'}
# -------------------
# movie id tt1712086
# -------------------
# {'Actors': 'Chen Tang, Jonathan Thomson, Marshall Berenson, Herbert Von Schild',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Japan, France, Spain',
#  'DVD': 'N/A',
#  'Director': 'Jesse Barack',
#  'Genre': 'Adventure, Sci-Fi',
#  'Language': 'English, French, Turkish, German',
#  'Metascore': 'N/A',
#  'Plot': 'A young man must cope with involuntary telepathy, a potion-induced '
#          'transformation, teleporting agents and a clone reincarnation, all '
#          'while dodging an evil corporation that wants to harvest his brain '
#          'for knowledge.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTMzMjYxODAwMF5BMl5BanBnXkFtZTcwNDY2OTgxNw@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.8/10'}],
#  'Released': '10 Aug 2013',
#  'Response': 'True',
#  'Runtime': '70 min',
#  'Title': 'Polypore',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jesse Barack, Jesse Barack (original story), Kyle Barry (original '
#            'story)',
#  'Year': '2013',
#  'imdbID': 'tt1712086',
#  'imdbRating': '6.8',
#  'imdbVotes': '66'}
# -------------------
# movie id tt3846882
# -------------------
# {'Actors': 'Cassey Ho',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'Music',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '60 min',
#  'Title': 'Pop Pilates Total Body Workout with Cassey Ho',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2013',
#  'imdbID': 'tt3846882',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2652476
# -------------------
# {'Actors': 'Zhang Qi, Ji Hyun Lee, Anqi Zhang, So-Young Hong',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'South Korea, China, Hong Kong, USA',
#  'DVD': '06 Oct 2014',
#  'Director': 'Dong-hoon Choi, Kim Hyun-Ho, Jazz Boon(co-director), Yong-hwa '
#              'Kim(co-director), Young Kyun Park(co-director), Tae-ra '
#              'Shin(co-director)',
#  'Genre': 'Animation, Family, Sport',
#  'Language': 'Korean, Cantonese, English',
#  'Metascore': 'N/A',
#  'Plot': 'Curious little penguin Pororo and his friends accidentally cause an '
#          'airplane to make an emergency landing in their home of Pororo '
#          'Village. On the airplane are some turtles being shipped to ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjA2NzkzNDMyMl5BMl5BanBnXkFtZTgwMzEyMjEyMjE@._V1_SX300.jpg',
#  'Production': 'Grindstone Entertainment',
#  'Rated': 'G',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.3/10'}],
#  'Released': '25 Jan 2013',
#  'Response': 'True',
#  'Runtime': '78 min',
#  'Title': "The Little Penguin Pororo's Racing Adventure",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Mychal Simka (english version), Harry Glennon (english version), '
#            'Ross Mihalko (english version), Yong-hwa Kim (screenplay), '
#            'Seon-gyeong Gu (character created by: Pororo Hero Heisei), '
#            'Seok-hoon Lee, Genoveva Winsen (english adaptation), Myeong-chan '
#            'Park (comic), Ui Seok Cho',
#  'Year': '2013',
#  'imdbID': 'tt2652476',
#  'imdbRating': '5.3',
#  'imdbVotes': '148'}
# -------------------
# movie id tt4411348
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Greg Mallozzi',
#  'Genre': 'Sport',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '21 Dec 2013',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Portfolio: A Skateboarding Video',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2013',
#  'imdbID': 'tt4411348',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2690160
# -------------------
# {'Actors': 'Brian Krause, Anne McDaniels, Steven Helmkamp, Candice Nunes',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '13 May 2014',
#  'Director': 'Mark L. Lester',
#  'Genre': 'Action, Adventure, Comedy, Fantasy, Horror, Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A small, secluded island off the coast of Belize suddenly finds '
#          "itself terrorized by a deadly predator from the planet's distant "
#          'past when deep sea divers accidentally awaken an ancient evil.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjIwNDIzMTcwOV5BMl5BanBnXkFtZTgwNzkyODY0MTE@._V1_SX300.jpg',
#  'Production': 'Anderson Digital',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.5/10'}],
#  'Released': '10 Jan 2014',
#  'Response': 'True',
#  'Runtime': '81 min',
#  'Title': 'Poseidon Rex',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Rafael Jordan',
#  'Year': '2013',
#  'imdbID': 'tt2690160',
#  'imdbRating': '2.5',
#  'imdbVotes': '1,096'}
# -------------------
# movie id tt2998154
# -------------------
# {'Actors': 'Kimberly Bada, Derrick Brown, Michael Connolly, Chris Dyer-Grugan',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jose Hernandez',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'POSSESSION is a drama/action film in which two powers form a bond to '
#          'seek answers on a deal gone bad. They both agree to rid of those who '
#          'stand in their way and after given what they ask ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTY0NTk3NDk5N15BMl5BanBnXkFtZTcwMjA1MTA4OQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '82 min',
#  'Title': 'Possession',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jose Hernandez',
#  'Year': '2013',
#  'imdbID': 'tt2998154',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2435488
# -------------------
# {'Actors': 'Phil Armenia, Richard Baker, Clay Brocker, Matthew Buri',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'David Colon',
#  'Genre': 'Action, Drama, Western',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A band of ex-confederates looking for the lost gold that had been '
#          'stolen from the Virginia Bank, believes they have the man who knows '
#          "where the bounty is hidden. War hero, Braden Hill's ...",
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '12 Nov 2013',
#  'Response': 'True',
#  'Runtime': '92 min',
#  'Title': 'Possessions',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'David Colon (story), David Colon',
#  'Year': '2013',
#  'imdbID': 'tt2435488',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt1283935
# -------------------
# {'Actors': "Linnea Quigley, Jim O'Rear, Monique Dupree, April Monique Burril",
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Cameron Scott',
#  'Genre': 'Action, Adventure, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNmY3NGZjYTMtZjQ1My00ZTFlLTg0MjUtM2Q5YTM5MDQzY2I0XkEyXkFqcGdeQXVyMzQ0MTgwMA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'}],
#  'Released': '01 Nov 2013',
#  'Response': 'True',
#  'Runtime': '99 min',
#  'Title': 'Post Mortem, America 2021',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Cameron Scott',
#  'Year': '2013',
#  'imdbID': 'tt1283935',
#  'imdbRating': '6.2',
#  'imdbVotes': '37'}
# -------------------
# movie id tt2722898
# -------------------
# {'Actors': 'Crystal Kiser, Adam Barksdale, Justin DeFreece, Zach Malott',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Chloe Lester',
#  'Genre': 'Comedy, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Ryan and Lauren are two bloggers who are mortal enemies online. When '
#          'their best friends decide to marry each other within a month, they '
#          'have to work together to stop their friends from rushing the '
#          'relationship too quickly.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'NOT RATED',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '60 min',
#  'Title': 'Post Pending',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Athena Lester, Athena Lester, Chloe Lester (story), Chloe Lester, '
#            'Chloe Lester, Caleb Pipkin (story), Caleb Pipkin, R.J. Vickers, '
#            'R.J. Vickers',
#  'Year': '2013',
#  'imdbID': 'tt2722898',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2391045
# -------------------
# {'Actors': 'Patrick Fenison, Sheffron Flowers, Preston Francois, Leo Goodwin',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Sean Van Dorn',
#  'Genre': 'Drama, Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Jamal Brown is a high school basketball player who is in a battle '
#          'with finding his way. He has only the final game left of his senior '
#          'year. On the surface Jamal appears to be your typical ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTgwOTg2MjM3MV5BMl5BanBnXkFtZTcwNzA3MzAxOA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.8/10'}],
#  'Released': '05 May 2013',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': 'Post Season',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Sean Van Dorn (story), Sean Van Dorn, Trellis Woods',
#  'Year': '2013',
#  'imdbID': 'tt2391045',
#  'imdbRating': '6.8',
#  'imdbVotes': '5'}
# -------------------
# movie id tt3857214
# -------------------
# {'Actors': 'Nathanel Anderson, Aimee Katherine Dillard, Chris Dillard, Tammy '
#            'Hartline',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jerry Lee Ramsey',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Potrait of Madness',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Candace Krissie, Jerry Lee Ramsey',
#  'Year': '2013',
#  'imdbID': 'tt3857214',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt1914325
# -------------------
# {'Actors': 'Shan Agish, Matt Wray, James Gill, Daniel Martin Berkey',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '06 Oct 2015',
#  'Director': 'Natalie Degennaro',
#  'Genre': 'Horror, Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Jeremy Moore, a computer genius, was brutally mangled by a vicious '
#          'gang. The outcome of this savage act causes Jeremy to become a '
#          'quadriplegic. However, unbeknownst to the young genius, he ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjIwOTgxNTY5OV5BMl5BanBnXkFtZTgwNzQ4MzI4NTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'NOT RATED',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.3/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'Powerplegic',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Natalie Degennaro, Arthur Schurr (story editor)',
#  'Year': '2013',
#  'imdbID': 'tt1914325',
#  'imdbRating': '7.3',
#  'imdbVotes': '63'}
# -------------------
# movie id tt3185256
# -------------------
# {'Actors': 'Shane Skelton',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'N/A',
#  'DVD': 'N/A',
#  'Director': 'Nikki Debbaudt, Samantha Skelton',
#  'Genre': 'Adventure, Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '04 Apr 2013',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Practice Makes Perfect',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2013',
#  'imdbID': 'tt3185256',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2064905
# -------------------
# {'Actors': 'Nick Renaud, Henry Monfries, Gemmenne de la Peña, Hannah Kasulka',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '18 Jun 2013',
#  'Director': 'Yiuwing Lam',
#  'Genre': 'Crime',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'In the Summer before their senior year, three teens tried to execute '
#          'the perfect prank on their bully. Instead, they executed him.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjA0ODQ3MjgwNV5BMl5BanBnXkFtZTcwMjc0MzIyOA@@._V1_SX300.jpg',
#  'Production': 'Image Entertainment',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.5/10'}],
#  'Released': '18 Jun 2013',
#  'Response': 'True',
#  'Runtime': '82 min',
#  'Title': 'Prank',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Yiuwing Lam',
#  'Year': '2013',
#  'imdbID': 'tt2064905',
#  'imdbRating': '3.5',
#  'imdbVotes': '739'}
# -------------------
# movie id tt2427816
# -------------------
# {'Actors': 'Noshir Dalal, Don Simkovich, Jon Lance Duran, Eddie Diaz',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Joaquin F. Palma',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An underground Brotherhood battling the demonic forces that thrive '
#          'in the shadows of society find themselves unwillingly up against an '
#          'evil more powerful than any one of them has ever seen....',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ0MDQ4Nzk2MF5BMl5BanBnXkFtZTgwOTcyMzIwMjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.3/10'}],
#  'Released': '25 Feb 2015',
#  'Response': 'True',
#  'Runtime': '72 min',
#  'Title': 'Prayers in the Dark',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joaquin F. Palma, Alexander Fitchett',
#  'Year': '2013',
#  'imdbID': 'tt2427816',
#  'imdbRating': '3.3',
#  'imdbVotes': '36'}
# -------------------
# movie id tt3451376
# -------------------
# {'Actors': 'Aleks Lara, Eddie González Ibarra, Elsie Sierra, María Espinoza',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Domingo Banda',
#  'Genre': 'Drama',
#  'Language': 'Spanish',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '08 Nov 2013',
#  'Response': 'True',
#  'Runtime': '120 min',
#  'Title': 'Prejuicio',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Eddie González Ibarra',
#  'Year': '2013',
#  'imdbID': 'tt3451376',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2421698
# -------------------
# {'Actors': 'Faith Callaway, Nesey Gallons, Teadora Nikolova, Mariana Templin',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Joe Chang',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'On Halloween weekend, a traveling performance artist and his kid '
#          'sister revisit the childhood hometown where they grew up, '
#          'discovering the things they once remembered are vanishing, and '
#          "things they've kept inside themselves never go away.",
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '18 Apr 2013',
#  'Response': 'True',
#  'Runtime': '83 min',
#  'Title': 'Present',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joe Chang',
#  'Year': '2013',
#  'imdbID': 'tt2421698',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2852122
# -------------------
# {'Actors': 'Wayne Degan, Melissa Dickinson, Sean McCleary, Austin Bell',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Brandon Herron',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': '170 years after a disaster has driven humanity underground, a group '
#          'of four emerge to the surface and seek safe harbor in an unwelcoming '
#          'world.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ3MDMyNzkyNF5BMl5BanBnXkFtZTcwMzEzNjY2OQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'}],
#  'Released': '02 Aug 2013',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Preserve',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Wayne Degan',
#  'Year': '2013',
#  'imdbID': 'tt2852122',
#  'imdbRating': '6.2',
#  'imdbVotes': '12'}
# -------------------
# movie id tt2488478
# -------------------
# {'Actors': 'Joey Capone, James Duval, Dennis Fanning, Mark E. Fletcher',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Brian McGuire',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "A pervert's quest for love.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjM1OTg2MTU1Nl5BMl5BanBnXkFtZTgwMzk5NjMwNzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '88 min',
#  'Title': 'Prevertere',
#  'Type': 'movie',
#  'Website': 'http://www.prevertere.com/',
#  'Writer': 'Brian McGuire',
#  'Year': '2012',
#  'imdbID': 'tt2488478',
#  'imdbRating': '6.1',
#  'imdbVotes': '18'}
# -------------------
# movie id tt2195548
# -------------------
# {'Actors': 'Paul Rudd, Emile Hirsch, Lance LeGault, Joyce Payne',
#  'Awards': '3 wins & 5 nominations.',
#  'BoxOffice': '$204,951',
#  'Country': 'USA',
#  'DVD': '12 Nov 2013',
#  'Director': 'David Gordon Green',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English, German',
#  'Metascore': '73',
#  'Plot': 'Two highway road workers spend the summer of 1988 away from their '
#          'city lives. The isolated landscape becomes a place of misadventure '
#          'as the men find themselves at odds with each other and the women '
#          'they left behind.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQzMzMwNDExMV5BMl5BanBnXkFtZTcwMzE5MjU3OQ@@._V1_SX300.jpg',
#  'Production': 'Magnolia Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.4/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '82%'},
#              {'Source': 'Metacritic', 'Value': '73/100'}],
#  'Released': '19 Sep 2013',
#  'Response': 'True',
#  'Runtime': '94 min',
#  'Title': 'Prince Avalanche',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'David Gordon Green, Hafsteinn Gunnar Sigurðsson (based on the film '
#            '"Either Way")',
#  'Year': '2013',
#  'imdbID': 'tt2195548',
#  'imdbRating': '6.4',
#  'imdbVotes': '18,069'}
# -------------------
# movie id tt1392214
# -------------------
# {'Actors': 'Hugh Jackman, Jake Gyllenhaal, Viola Davis, Maria Bello',
#  'Awards': 'Nominated for 1 Oscar. Another 10 wins & 36 nominations.',
#  'BoxOffice': '$60,962,878',
#  'Country': 'USA',
#  'DVD': '17 Dec 2013',
#  'Director': 'Denis Villeneuve',
#  'Genre': 'Crime, Drama, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': '74',
#  'Plot': "When Keller Dover's daughter and her friend go missing, he takes "
#          'matters into his own hands as the police pursue multiple leads and '
#          'the pressure mounts.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg0NTIzMjQ1NV5BMl5BanBnXkFtZTcwNDc3MzM5OQ@@._V1_SX300.jpg',
#  'Production': 'Warner Bros.',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '80%'},
#              {'Source': 'Metacritic', 'Value': '74/100'}],
#  'Released': '20 Sep 2013',
#  'Response': 'True',
#  'Runtime': '153 min',
#  'Title': 'Prisoners',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Aaron Guzikowski',
#  'Year': '2013',
#  'imdbID': 'tt1392214',
#  'imdbRating': '8.1',
#  'imdbVotes': '549,157'}
# -------------------
# movie id tt0496375
# -------------------
# {'Actors': 'John Rhys-Davies, David Charvet, Carmen Chaplin, Emily Holmes',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Germany',
#  'DVD': '08 Jul 2014',
#  'Director': 'Roger Christian',
#  'Genre': 'Action, Adventure, Horror, Mystery',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A multinational expedition discovers a lost city beneath a pyramid, '
#          'where they must stop the reawakened gods of ancient Egypt from '
#          'initiating the Apocalypse.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMWQyOTk5ZGYtYmUyOC00MDQyLWFjNjUtYjBiYmFiZWZlMTk2XkEyXkFqcGdeQXVyNTc5OTMwOTQ@._V1_SX300.jpg',
#  'Production': 'Phase 4 Films',
#  'Rated': 'TV-14',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.7/10'}],
#  'Released': '08 Jul 2014',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': 'Prisoners of the Sun',
#  'Type': 'movie',
#  'Website': 'http://www.phase4films.com/',
#  'Writer': 'Peter Atkins, Anthony Hickox',
#  'Year': '2013',
#  'imdbID': 'tt0496375',
#  'imdbRating': '3.7',
#  'imdbVotes': '1,141'}
# -------------------
# movie id tt2631318
# -------------------
# {'Actors': 'Ryan Bartlett, Chris Bujold, David Cook, Samantha Creed',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ramsey Eassa',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A Professional Investigator begins to unravel a plot strengthening '
#          'organized crime in Olde Towne City. However, the lines drawn between '
#          'good and evil are not what they seem.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTM2ODEyODE1Ml5BMl5BanBnXkFtZTcwMDEyNDk5OA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '17 Nov 2013',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Private Affairs',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ramsey Eassa',
#  'Year': '2013',
#  'imdbID': 'tt2631318',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2233268
# -------------------
# {'Actors': 'Pierre Adeli, Daniel Berson, Jeffy Branion, Hannah Chodos',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ethan Kogan, Jessica Silvetti',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Jason, a documentary filmmaker, searches for a cult leader who '
#          'claims to be an angel sent by God. Struggling with his own loss of '
#          'faith, Jason falls down a rabbit hole of doubt, distress ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYTY0Y2QxODYtYjM5NS00MGQ3LWFkMzktZjFkYWZlMTE1YTQzL2ltYWdlXkEyXkFqcGdeQXVyNDA3ODc2Mg@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.2/10'}],
#  'Released': '11 Oct 2013',
#  'Response': 'True',
#  'Runtime': '84 min',
#  'Title': 'Problem of Evil',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ethan Kogan, Jessica Silvetti',
#  'Year': '2013',
#  'imdbID': 'tt2233268',
#  'imdbRating': '7.2',
#  'imdbVotes': '122'}
# -------------------
# movie id tt2322176
# -------------------
# {'Actors': 'Derrick Bean, Bonzo, Sumiko Braun, Elf Butner',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '23 Sep 2014',
#  'Director': 'Aaron Champion',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Sam is a movie producer. He is 48years old and still single. Never '
#          'married, but suddenly decides he wants a family. However, even with '
#          'his hope, he has no idea how to build relationships as...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTM1NzA0MzA2MF5BMl5BanBnXkFtZTcwMjUyMjIzOA@@._V1_SX300.jpg',
#  'Production': 'Pathfinder Pictures',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'}],
#  'Released': '10 Oct 2013',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Producer Sam',
#  'Type': 'movie',
#  'Website': 'http://www.pathfinderpictures.com/',
#  'Writer': 'Erika Fraade',
#  'Year': '2013',
#  'imdbID': 'tt2322176',
#  'imdbRating': '6.5',
#  'imdbVotes': '11'}
# -------------------
# ...
#          'decades building.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODUxMDgzMDEwMV5BMl5BanBnXkFtZTcwMTM0MDg0OQ@@._V1_SX300.jpg',
#  'Production': 'Monterey Media',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '93%'},
#              {'Source': 'Metacritic', 'Value': '71/100'}],
#  'Released': '20 Jan 2013',
#  'Response': 'True',
#  'Runtime': '83 min',
#  'Title': 'This Is Martin Bonner',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tara Everhart (additional dialogue written by), Chad Hartigan',
#  'Year': '2013',
#  'imdbID': 'tt1798291',
#  'imdbRating': '6.5',
#  'imdbVotes': '853'}
# -------------------
# movie id tt2409634
# -------------------
# {'Actors': 'Shawn-Caulin Young, Kate Cobb, T.J. Dalrymple, Matthew Florida',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, India',
#  'DVD': '16 Apr 2013',
#  'Director': 'Lisa Arnold',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'After graduation, five friends set out to make a difference in the '
#          'world for God. Their ambitions are high, their passions are strong '
#          'but will they have the courage to fulfill their calling...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTk1MTk5Mjk5OF5BMl5BanBnXkFtZTgwMjg0NzA2MDE@._V1_SX300.jpg',
#  'Production': 'Pure Flix Entertainment',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.6/10'}],
#  'Released': '01 Mar 2013',
#  'Response': 'True',
#  'Runtime': '104 min',
#  'Title': 'This Is Our Time',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Lisa Arnold (story), Lisa Arnold, Andrea Gyertson Nasfell',
#  'Year': '2013',
#  'imdbID': 'tt2409634',
#  'imdbRating': '5.6',
#  'imdbVotes': '407'}
# -------------------
# movie id tt2472956
# -------------------
# {'Actors': 'Christine Bruno, Barry Corbin, Carolyn Gilroy, Ron Hayden',
#  'Awards': '1 win & 1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Josh Barrett, Marc Menchaca',
#  'Genre': 'Drama, Family',
#  'Language': 'English',
#  'Metascore': '59',
#  'Plot': 'Set in the Texas Hill Country, "This Is Where We Live" is a portrait '
#          'of the Sutton family: Diane, while ignoring her own health issues, '
#          'is caregiver to her son August, who has cerebral ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ0MTg4MDgwNl5BMl5BanBnXkFtZTgwNzM5NjQxMDE@._V1_SX300.jpg',
#  'Production': 'Beech Hill Films',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '88%'},
#              {'Source': 'Metacritic', 'Value': '59/100'}],
#  'Released': '09 Mar 2013',
#  'Response': 'True',
#  'Runtime': '92 min',
#  'Title': 'This Is Where We Live',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Josh Barrett (story editor), Marc Menchaca',
#  'Year': '2013',
#  'imdbID': 'tt2472956',
#  'imdbRating': '7.6',
#  'imdbVotes': '51'}
# -------------------
# movie id tt1245492
# -------------------
# {'Actors': 'James Franco, Jonah Hill, Seth Rogen, Jay Baruchel',
#  'Awards': '10 wins & 20 nominations.',
#  'BoxOffice': '$96,200,000',
#  'Country': 'USA',
#  'DVD': '01 Oct 2013',
#  'Director': 'Evan Goldberg, Seth Rogen',
#  'Genre': 'Comedy',
#  'Language': 'English, Spanish',
#  'Metascore': '67',
#  'Plot': "6 Los Angeles celebrities are stuck in James Franco's house after a "
#          'series of devastating events just destroyed the city. Inside, the '
#          'group not only have to face the apocalypse, but themselves.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQxODE3NjM1Ml5BMl5BanBnXkFtZTcwMzkzNjc4OA@@._V1_SX300.jpg',
#  'Production': 'Sony Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '83%'},
#              {'Source': 'Metacritic', 'Value': '67/100'}],
#  'Released': '12 Jun 2013',
#  'Response': 'True',
#  'Runtime': '107 min',
#  'Title': 'This Is the End',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Seth Rogen (screenplay), Evan Goldberg (screenplay), Seth Rogen '
#            '(screen story), Evan Goldberg (screen story), Seth Rogen (short '
#            'film "Jay and Seth vs. The Apocalypse"), Jason Stone (based on the '
#            'short film "Jay and Seth vs. The Apocalypse" by), Evan Goldberg '
#            '(short film "Jay and Seth vs. The Apocalypse")',
#  'Year': '2013',
#  'imdbID': 'tt1245492',
#  'imdbRating': '6.6',
#  'imdbVotes': '368,960'}
# -------------------
# movie id tt2216704
# -------------------
# {'Actors': 'Alexander Cook, Vincent Ernest Siders, Michala Hansen, Paul '
#            'Melendy',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Federico Muchnik',
#  'Genre': 'Crime',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Climb inside the mind of a sociopath; an office worker kills his way '
#          'into management but gets into trouble with his talkative girlfriend '
#          'and a corrupt detective. Jim Collins has decided to ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTgzNzU5Njg4NF5BMl5BanBnXkFtZTcwNTY2MzQyOA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.4/10'}],
#  'Released': '04 Apr 2013',
#  'Response': 'True',
#  'Runtime': '88 min',
#  'Title': 'This Killing Business',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Federico Muchnik',
#  'Year': '2013',
#  'imdbID': 'tt2216704',
#  'imdbRating': '4.4',
#  'imdbVotes': '11'}
# -------------------
# movie id tt3214986
# -------------------
# {'Actors': 'Summer Broyhill, Izzy Pate, Thomas Brown, Chris Collins',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jason A. Brown',
#  'Genre': 'Short, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A woman (Summer Broyhill) spends her life locked in a small white '
#          'room, observed and held by an unseen captor. Her only means of '
#          'escape is a shiny blue pill on the table next to her bed. ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'NOT RATED',
#  'Ratings': [],
#  'Released': '01 Oct 2013',
#  'Response': 'True',
#  'Runtime': '47 min',
#  'Title': 'This Splintered Head',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jason A. Brown, Jason A. Brown',
#  'Year': '2013',
#  'imdbID': 'tt3214986',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2070874
# -------------------
# {'Actors': 'Michael Doneger, Amanda Brooks, Wes Chatham, Ryan Honey',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Michael Doneger',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A listless writer pursues a woman to help him get over his ex '
#          'girlfriend.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ5MTIzMDQzOV5BMl5BanBnXkFtZTcwMDA5NDkyNw@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'}],
#  'Released': '14 Feb 2014',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'This Thing with Sarah',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Doneger (story), Michael Doneger',
#  'Year': '2013',
#  'imdbID': 'tt2070874',
#  'imdbRating': '5.8',
#  'imdbVotes': '376'}
# -------------------
# movie id tt2801060
# -------------------
# {'Actors': 'Katy Brown, David Browning, Ashley Oliver Campos, Ezra Colon',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'John Hardy',
#  'Genre': 'Comedy, History, War',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "If all comedy is watching someone else's pain, then watching Jim "
#          "McManus is a riot. Jim's life is an assortment of modern "
#          'complications: a wife who tries to understand him, two children '
#          'who...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.2/10'}],
#  'Released': '19 Oct 2013',
#  'Response': 'True',
#  'Runtime': '105 min',
#  'Title': 'This World',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'John Hardy, Rick McVey',
#  'Year': '2013',
#  'imdbID': 'tt2801060',
#  'imdbRating': '3.2',
#  'imdbVotes': '5'}
# -------------------
# movie id tt1510990
# -------------------
# {'Actors': 'Elijah Nelson, Daniel Nelson, Ayanna Berkshire, Michael Biesanz',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Phil Bransom',
#  'Genre': 'Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Train Master Jeremiah Wilson has kept a secret for 50 years. A clue '
#          'is hidden along the miniature tracks of his model trains of a long '
#          'lost treasure.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNWE2NTkyODEtMmY5Ni00YjIyLWJhYzgtOTFkOGQ4YWY5NTRiXkEyXkFqcGdeQXVyNjE5NDY2MzM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.8/10'}],
#  'Released': '30 May 2014',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': 'Thomas & the Trainmaster',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Phil Bransom, Steve Coker, Robert Henninger',
#  'Year': '2013',
#  'imdbID': 'tt1510990',
#  'imdbRating': '4.8',
#  'imdbVotes': '6'}
# -------------------
# movie id tt1981115
# -------------------
# {'Actors': 'Chris Hemsworth, Natalie Portman, Tom Hiddleston, Anthony Hopkins',
#  'Awards': '3 wins & 21 nominations.',
#  'BoxOffice': '$206,360,018',
#  'Country': 'USA',
#  'DVD': '25 Feb 2014',
#  'Director': 'Alan Taylor',
#  'Genre': 'Action, Adventure, Fantasy',
#  'Language': 'English',
#  'Metascore': '54',
#  'Plot': 'When the Dark Elves attempt to plunge the universe into darkness, '
#          'Thor must embark on a perilous and personal journey that will '
#          'reunite him with doctor Jane Foster.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQyNzAwOTUxOF5BMl5BanBnXkFtZTcwMTE0OTc5OQ@@._V1_SX300.jpg',
#  'Production': 'Walt Disney Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.9/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '66%'},
#              {'Source': 'Metacritic', 'Value': '54/100'}],
#  'Released': '08 Nov 2013',
#  'Response': 'True',
#  'Runtime': '112 min',
#  'Title': 'Thor: The Dark World',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Christopher L. Yost (screenplay by), Christopher Markus '
#            '(screenplay by), Stephen McFeely (screenplay by), Don Payne (story '
#            'by), Robert Rodat (story by), Stan Lee (based on the Marvel comics '
#            'by), Larry Lieber (based on the Marvel comics by), Jack Kirby '
#            '(based on the Marvel comics by), Walter Simonson (character '
#            'created by: Malekith)',
#  'Year': '2013',
#  'imdbID': 'tt1981115',
#  'imdbRating': '6.9',
#  'imdbVotes': '561,868'}
# -------------------
# movie id tt2848756
# -------------------
# {'Actors': 'Camille Rousseau, G.J. Echternkamp, Morgan Kibby',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'France, USA',
#  'DVD': 'N/A',
#  'Director': 'Eva Husson',
#  'Genre': 'Short, Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Camille and G.J., a couple in their early thirties, have known '
#          'happier times. They decide to take a few days off and go to Death '
#          'Valley. Needless to say, a real adventure for the city ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.8/10'}],
#  'Released': '03 Apr 2013',
#  'Response': 'True',
#  'Runtime': '50 min',
#  'Title': "Those for Whom It's Always Complicated",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Eva Husson, Morgan Kibby, G.J. Echternkamp, Camille Rousseau',
#  'Year': '2013',
#  'imdbID': 'tt2848756',
#  'imdbRating': '6.8',
#  'imdbVotes': '12'}
# -------------------
# movie id tt3408120
# -------------------
# {'Actors': 'Scott Grass, Dave VanSteemburg, Alexander Hauck, David Benner',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Scott Grass',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '06 Apr 2013',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Thou Shall Kill: The Harvest',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Scott Grass, Dave VanSteemburg',
#  'Year': '2013',
#  'imdbID': 'tt3408120',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3123188
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Peter B. Hutton',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMmMwYmQ4YWQtZThlMC00YmVmLTkzODQtZjUwNGI1NDU3YWE4L2ltYWdlXkEyXkFqcGdeQXVyNjc4OTA0Nzk@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.9/10'}],
#  'Released': '01 Sep 2013',
#  'Response': 'True',
#  'Runtime': '47 min',
#  'Title': 'Three Landscapes',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2013',
#  'imdbID': 'tt3123188',
#  'imdbRating': '7.9',
#  'imdbVotes': '24'}
# -------------------
# movie id tt7532938
# -------------------
# {'Actors': 'Rachelle Crowder, Rickey Crowder, Taylor Needham, Devon Dundee',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kevin Rogers',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '21 May 2013',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Three Minutes to Midnight',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Rickey Crowder, Devon Dundee, Taylor Needham (story), Kevin Rogers '
#            '(screenplay)',
#  'Year': '2013',
#  'imdbID': 'tt7532938',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2397607
# -------------------
# {'Actors': 'Perri Pierre, Lauren Francesca, TerriAnn Peters, Vanessa Bontea',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Richie Babitsky',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Richard is a hopeless romantic. That is, he wants romance but he's "
#          'hopeless. Like many single men, he has an inflated opinion of '
#          "himself. He's quite good at overlooking his own flaws, so ...",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDQ4ODY4OTMwMF5BMl5BanBnXkFtZTcwMDkzMTgwOA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'}],
#  'Released': '17 Mar 2013',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Three of One Kind',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Zack Van Eyck',
#  'Year': '2013',
#  'imdbID': 'tt2397607',
#  'imdbRating': '6.1',
#  'imdbVotes': '10'}
# -------------------
# movie id tt3054430
# -------------------
# {'Actors': 'Ava Bogle, Alan Wells, Zoe Moulinge, Jenna Regan',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ashley Beyer',
#  'Genre': 'Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An unseen Intruder stalks and terrorizes an innocent family, '
#          'recording every move on a head-mounted camera. A terrifying cat and '
#          'mouse game ensues as the Intruder removes the father and ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ0ODM0ODE2N15BMl5BanBnXkFtZTgwODkyNTM0MTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '25 Mar 2014',
#  'Response': 'True',
#  'Runtime': '65 min',
#  'Title': 'Through Your Door',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ashley Beyer',
#  'Year': '2013',
#  'imdbID': 'tt3054430',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}

# %%
len(title_list)
# Out:
# 993

# %%
len(title_id)
# Out:
# 993

# %%
# if title_list and title_id are the same length run the cell below. 
# if they are not equal take out 'title_id': title_id

# %%
df = pd.DataFrame({'title_id': title_id, 'title': title_list, 'box_office': box_office_list, 'country': country_list, 
                   'genre': genre_list, 'director': director_list, 'metascore': metascore_list, 'production': production_list, 
                   'rating': rating_list, 'IMDB_rating': IMDB_rating_list, 'rotten_tomatoes_rating': rotten_tomatoes_rating_list, 
                  'runtime': runtime_list, 'type': type_list, 'IMDB_votes': imdb_votes_list})

# %%
df = df.drop_duplicates()
df.head()
# Out:
#     title_id              title box_office country             genre  \
# 0  tt2075280             Phobia        N/A     USA  Horror, Thriller
# 1  tt2379460   Pieces of Easter        N/A     USA    Comedy, Family
# 2  tt1790807  Pig Death Machine        N/A     USA               N/A
# 3  tt4390190         Pink Noise        N/A     USA             Short
# 4  tt3056562      Piper's World        N/A     USA             Drama
#
#                 director metascore             production     rating  \
# 0             Jon Keeyes       N/A        Gravitas Horror  Not Rated
# 1        Jefferson Moore       N/A  Kelly&#39;s Filmworks        N/A
# 2          Jon Moritsugu       N/A                    N/A        N/A
# 3  Gregg Mann, Liza Mann       N/A                    N/A        N/A
# 4            Jeff Harris       N/A                    N/A        N/A
#
#   IMDB_rating rotten_tomatoes_rating  runtime   type IMDB_votes
# 0         3.3                     NA   91 min  movie        175
# 1         7.4                     NA   98 min  movie         60
# 2         6.0                     NA      N/A  movie         17
# 3         N/A                     NA      N/A  movie        N/A
# 4         N/A                     NA  120 min  movie        N/A

# %%
df.count()
# Out:
# title_id                  993
# title                     993
# box_office                993
# country                   993
# genre                     993
# director                  993
# metascore                 993
# production                993
# rating                    993
# IMDB_rating               993
# rotten_tomatoes_rating    993
# runtime                   993
# type                      993
# IMDB_votes                993
# dtype: int64

# %%
df.to_csv('../data/2013_data_batch_3.csv', index=False)
