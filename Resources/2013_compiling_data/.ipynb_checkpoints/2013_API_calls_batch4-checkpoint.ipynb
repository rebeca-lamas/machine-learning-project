# %%
import pandas as pd
import requests
import json
import time
from pprint import pprint
from config import API_KEY

# %%
data = pd.read_csv('../data/titles_2013_batch4.csv')
df =  data.count()
df
# Out:
# title    309
# dtype: int64

# %%
title_id = []
box_office_list = []
country_list = []
genre_list = []
director_list = []
metascore_list = []
production_list = []
rating_list = []
IMDB_rating_list = [] 
rotten_tomatoes_rating_list = []
runtime_list = []
title_list = []
type_list = []
imdb_votes_list = []

# %%
movies = data['title']
total_movies = len(movies)

# %%
for i in range(total_movies):
    movie = movies[i]
    url = "http://www.omdbapi.com/?i=" + movie + "&apikey=" + API_KEY
    response = (requests.get(url).text)
    response_json = json.loads(response)
    print('-------------------')
    print(f'movie id {movie}')
    print('-------------------')
    pprint(response_json)
    
    try:
        box_office_list.append(response_json['BoxOffice'])
        country_list.append(response_json['Country'])
        genre_list.append(response_json['Genre'])
        director_list.append(response_json['Director'])
        metascore_list.append(response_json['Metascore'])
        production_list.append(response_json['Production'])
        rating_list.append(response_json['Rated'])
        IMDB_rating_list.append(response_json['imdbRating'])
        try:
            if not response_json['Ratings']:
                rotten_tomatoes_rating_list.append('NA')
            elif response_json['Ratings'][0]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][0]['Value'])
            elif response_json['Ratings'][1]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][1]['Value'])
            else:
                rotten_tomatoes_rating_list.append('NA')
        except IndexError:
            rotten_tomatoes_rating_list.append('NA')
        runtime_list.append(response_json['Runtime'])
        title_list.append(response_json['Title'])
        type_list.append(response_json['Type'])
        imdb_votes_list.append(response_json['imdbVotes'])
        title_id.append(response_json['imdbID'])
    except KeyError:
        pass
    time.sleep(1)
# Out:
# -------------------
# movie id tt2754340
# -------------------
# {'Actors': 'Stephanie Albon, Annmarie Bahny, Jason John Beebe, London Bush',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Greg Robbins',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'THROUGH A MOTHERS EYES is a story of pain, blood and great loss. It '
#          'is that rare kind of movie that will take you deep into a mothers '
#          'heart...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.6/10'}],
#  'Released': '03 May 2013',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': "Through a Mother's Eyes",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Greg Robbins',
#  'Year': '2013',
#  'imdbID': 'tt2754340',
#  'imdbRating': '5.6',
#  'imdbVotes': '10'}
# -------------------
# movie id tt5615530
# -------------------
# {'Actors': 'Océane Boulais, Elia Downey, Shannon Melvin, Hannah Rivard',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Rebekah Stought',
#  'Genre': 'Action',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'What is your purpose? That is the question facing CIA Agent Joshua '
#          'Winters after tragedy and failure cause him to question why he has '
#          'even been put on this earth. Meanwhile, he is in a race...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDdjN2EyNzYtZThkYy00MzZkLWIzMmMtNDU5NmM4MTJhOGQ4XkEyXkFqcGdeQXVyNjYyODk0NDI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.0/10'}],
#  'Released': '30 May 2013',
#  'Response': 'True',
#  'Runtime': '91 min',
#  'Title': 'Through the Storm',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Caleb Stought',
#  'Year': '2013',
#  'imdbID': 'tt5615530',
#  'imdbRating': '8.0',
#  'imdbVotes': '5'}
# -------------------
# movie id tt1986997
# -------------------
# {'Actors': 'Del Zamora, Ashley Ledbetter, Andrew Shea, Ali Mullin',
#  'Awards': '6 wins & 2 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Gary Hebert',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Rodrigo owns this room. He's the best twelve-step speaker in town. "
#          "Unfortunately everything he says is a lie. Thursday's Speaker is a "
#          'dark comedy dealing with unplanned pregnancy, used car scams, twelve '
#          'step programs, and family.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjI0ODA5NTU5M15BMl5BanBnXkFtZTgwODA2NjQyNTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.7/10'}],
#  'Released': '25 Jun 2015',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': "Thursday's Speaker",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Gary Hebert',
#  'Year': '2013',
#  'imdbID': 'tt1986997',
#  'imdbRating': '7.7',
#  'imdbVotes': '14'}
# -------------------
# movie id tt2866674
# -------------------
# {'Actors': 'Darcel Blue, Jocelyn Bowman, Kathy Bowman, Derell Bryant',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '31 Dec 2013',
#  'Director': 'Albert Johnson',
#  'Genre': 'Drama, Family, Musical',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An ex-pastor, whose church was destroyed during Hurricane Katrina, '
#          'loses his faith and becomes a homeless wanderer. After surviving a '
#          'near death experience, he mysteriously awakens in a church that is '
#          'in desperate need of a pastor.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzU0MzEzOTk2Nl5BMl5BanBnXkFtZTgwODM4NDQ3MDE@._V1_SX300.jpg',
#  'Production': 'Lightyear Entertainment',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.7/10'}],
#  'Released': '31 Dec 2013',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Thy Will Be Done',
#  'Type': 'movie',
#  'Website': 'http://www.parable-entertainment.com/',
#  'Writer': 'Albert Johnson (story), Albert Johnson',
#  'Year': '2013',
#  'imdbID': 'tt2866674',
#  'imdbRating': '6.7',
#  'imdbVotes': '7'}
# -------------------
# movie id tt1758820
# -------------------
# {'Actors': 'Christopher Behrens, Denise Behrens, Scott F. Caswell, Matthew '
#            'Cowell',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Christopher Behrens',
#  'Genre': 'Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Two brothers battle each other for control of their recently '
#          "deceased mother's estate.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTgzMjI5MjUzM15BMl5BanBnXkFtZTcwMTY2MjUwNA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.3/10'}],
#  'Released': '01 Jun 2013',
#  'Response': 'True',
#  'Runtime': '87 min',
#  'Title': 'Tiburon',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Christopher Behrens',
#  'Year': '2013',
#  'imdbID': 'tt1758820',
#  'imdbRating': '8.3',
#  'imdbVotes': '28'}
# -------------------
# movie id tt3304834
# -------------------
# {'Actors': 'Elizabeth Price, Jose Idrovo, Tim Kirkpatrick, Pj Khosroabadi',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tim Kirkpatrick',
#  'Genre': 'Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A beaten woman is held hostage in a closet and must escape before '
#          'she is murdered.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Nov 2013',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Tied Up',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tim Kirkpatrick',
#  'Year': '2013',
#  'imdbID': 'tt3304834',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2411008
# -------------------
# {'Actors': 'Tom Pelphrey, William Hill, Michael Medeiros, Ilvi Dulack',
#  'Awards': '2 wins.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Michael Medeiros',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Two small town women capture a handsome fugitive who breaks into '
#          'their house trying to escape a snowstorm and the law.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTAzNDA5NjI2ODleQTJeQWpwZ15BbWU4MDYzMjY3MTAx._V1_SX300.jpg',
#  'Production': 'Quad Theater',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.8/10'}],
#  'Released': '01 Aug 2013',
#  'Response': 'True',
#  'Runtime': '86 min',
#  'Title': 'Tiger Lily Road',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Medeiros',
#  'Year': '2013',
#  'imdbID': 'tt2411008',
#  'imdbRating': '6.8',
#  'imdbVotes': '32'}
# -------------------
# movie id tt2993348
# -------------------
# {'Actors': 'Laura Busch, Wade Everett, Janet Fogg, Mike Janisch',
#  'Awards': '3 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Phil Holbrook',
#  'Genre': 'Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Paul hasn't connected with his daughter for over 10 years, but when "
#          'their world is turned upside down by an unthinkable act, he has to '
#          "decide what's more important: doing the right thing or setting "
#          'things right?',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzA2ODIxMzk0NV5BMl5BanBnXkFtZTgwOTAwNTgzMzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.6/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '78 min',
#  'Title': 'Tilt',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Julie Keck, Jessica King',
#  'Year': '2013',
#  'imdbID': 'tt2993348',
#  'imdbRating': '4.6',
#  'imdbVotes': '16'}
# -------------------
# movie id tt2574190
# -------------------
# {'Actors': 'AJ Lovelace, Vanessa Arroyo, Glenn Ghirardi, Alexandra Burke',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'AJ Lovelace',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Nate's best friend who is also Claire's boyfriend, Evan, is sent to "
#          'jail for a year under some rather unclear circumstances. This sudden '
#          'absence causes them to reevaluate not only their own...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '07 Jun 2013',
#  'Response': 'True',
#  'Runtime': '53 min',
#  'Title': 'Time',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'AJ Lovelace',
#  'Year': '2013',
#  'imdbID': 'tt2574190',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6330370
# -------------------
# {'Actors': 'Jason Gorze, Martin Houston, Stephanie Leonard, Sam Nakanishi',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Mike Winkler',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The story continues with the next installment in the "Time '
#          'Travelers" trilogy. Four months have passed and the team is still '
#          'trapped in an alternate present. Now, with Frost leading the ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTY2MzIxNmEtZmM5My00Zjk0LWI4NjgtNGVlY2FmOGYwYmI4L2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMzQ4MzIwMDY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '13 Sep 2013',
#  'Response': 'True',
#  'Runtime': '77 min',
#  'Title': 'Time Travelers 2: The Darkness Within',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Mike Winkler',
#  'Year': '2013',
#  'imdbID': 'tt6330370',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3037586
# -------------------
# {'Actors': 'Elizabeth Daily, Melissa McMeekin, Kristi Lynn, Johnny Lee '
#            'Davenport',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ernest Thompson',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Jeremiah Ward, a hot shot New York money manager, turns off the '
#          'highway, straight into his past. In rural New Hampshire, he '
#          'discovers confusing clues and ghostly reminders of not only ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': 'Time and Charges',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ernest Thompson',
#  'Year': '2013',
#  'imdbID': 'tt3037586',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3030714
# -------------------
# {'Actors': 'Jesse Crawford, Jodie Hill, Lelani Mitchem, Amanda Jacobs',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Joe L. Roberts',
#  'Genre': 'Action, Adventure',
#  'Language': 'English, Greek',
#  'Metascore': 'N/A',
#  'Plot': 'In order to find yourself, sometimes you need to figure how to lose '
#          'yourself.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDQ2YzAxZjAtN2FkOS00ZGIxLThjOGItOGI5MTUxM2E1MjQwL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMjI5MjcxNTA@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.0/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': 'Time and Time Again',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joe L. Roberts',
#  'Year': '2013',
#  'imdbID': 'tt3030714',
#  'imdbRating': '8.0',
#  'imdbVotes': '104'}
# -------------------
# movie id tt2209708
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Chris Stokes',
#  'Genre': 'Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "A man's outlook on a woman's time of the month and how to deal with "
#          'her during that time.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg4NjQyNTM3OF5BMl5BanBnXkFtZTcwNjE3MDY5Nw@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.7/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Time of the Month',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Chris Stokes',
#  'Year': '2013',
#  'imdbID': 'tt2209708',
#  'imdbRating': '3.7',
#  'imdbVotes': '6'}
# -------------------
# movie id tt1986998
# -------------------
# {'Actors': 'Joey Dedio, Kelly McGillis, Frankie Faison, Elizabeth Rodriguez',
#  'Awards': '1 win & 5 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '05 Oct 2015',
#  'Director': 'Fro Rojas',
#  'Genre': 'Comedy, Drama, Family',
#  'Language': 'English',
#  'Metascore': '44',
#  'Plot': 'Wild bachelor Ray Ray Dominguez dreams of nothing more than a '
#          'carefree life of indulgence in Miami, but his plans are abruptly '
#          "changed when he becomes the legal guardian of his sister's six "
#          'children.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTM5MDQ3NDExN15BMl5BanBnXkFtZTcwOTg0Njc4OQ@@._V1_SX300.jpg',
#  'Production': 'Tio Papi The Movie LLC.',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '29%'},
#              {'Source': 'Metacritic', 'Value': '44/100'}],
#  'Released': '06 Sep 2013',
#  'Response': 'True',
#  'Runtime': '87 min',
#  'Title': 'Tio Papi',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joey Dedio, Brian Herskowitz',
#  'Year': '2013',
#  'imdbID': 'tt1986998',
#  'imdbRating': '6.3',
#  'imdbVotes': '102'}
# -------------------
# movie id tt8219390
# -------------------
# {'Actors': 'Nathan Shapiro, Olivia de Boutray, Tyler Heathman',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Quiz show in which four players take on a machine in the hope of '
#          'winning its £10,000 jackpot.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZTM2MGM1ZWEtNjQ0Yi00ZDUwLThkNDctOTQyZTYxOGI5MmMxXkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_SX300.jpg',
#  'Production': 'Temple Hill Entertainment',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '60 min',
#  'Title': 'Tipping Point',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2013',
#  'imdbID': 'tt8219390',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3115382
# -------------------
# {'Actors': 'Aimee Cassada, Samuel Benson, Marshall d Walker, Emile Powell',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Johnnie Baker Jr.',
#  'Genre': 'Action, Adventure, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Titan comes from Japan to protect his daughter Alisha. Through his '
#          'investigation he decides to become a crime fighter in the urban '
#          "city's.",
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '99 min',
#  'Title': 'Titan the Urban Samurai',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Johnnie Baker Jr.',
#  'Year': '2013',
#  'imdbID': 'tt3115382',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3303028
# -------------------
# {'Actors': 'Chance McKee, Orion West, Alicia Bucci, Les Best',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Chris Dickerson',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The sole survivor of an attempted group suicide reveals secrets to a '
#          'reporter sent to interview him on the one-year anniversary of the '
#          'incident.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '19 Nov 2013',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'To Become Ghosts',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Chris Dickerson',
#  'Year': '2013',
#  'imdbID': 'tt3303028',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2263468
# -------------------
# {'Actors': 'Trenton Rostedt, Danielle Vasinova, Ronnie Gene Blevins, Timothy '
#            'V. Murphy',
#  'Awards': '1 win.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Vick Wright',
#  'Genre': 'Drama, Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A washed up rock singer makes a deal with a mysterious doctor who '
#          'promises to return his voice to its prime with horrifying '
#          'consequences.',
#  'Poster': 'https://ia.media-imdb.com/images/M/MV5BMTYxOTg4Nzg0NV5BMl5BanBnXkFtZTcwNDg3OTYxOA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'NOT RATED',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.7/10'}],
#  'Released': '17 Aug 2013',
#  'Response': 'True',
#  'Runtime': '107 min',
#  'Title': 'To Hell with a Bullet',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Vick Wright (story & screenplay)',
#  'Year': '2013',
#  'imdbID': 'tt2263468',
#  'imdbRating': '3.7',
#  'imdbVotes': '50'}
# -------------------
# movie id tt2630300
# -------------------
# {'Actors': 'Chuck Pappas, Jessica Cameron, James Cullen Bressack, Jody Barton',
#  'Awards': '4 wins & 3 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '14 Oct 2013',
#  'Director': 'James Cullen Bressack',
#  'Genre': 'Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Joey suspects his girlfriend of two years, Jennifer, is cheating on '
#          'him. He is so convinced that he enlists the help of his cousin '
#          'Steven to create a Video Diary of his attempt to catch her...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTU3NjU4Nzc2NV5BMl5BanBnXkFtZTgwODA2Mzk1MDE@._V1_SX300.jpg',
#  'Production': 'MVD Entertainment Group',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.6/10'}],
#  'Released': '09 Oct 2013',
#  'Response': 'True',
#  'Runtime': '76 min',
#  'Title': 'To Jennifer',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'James Cullen Bressack, Chuck Pappas (additional dialogue)',
#  'Year': '2013',
#  'imdbID': 'tt2630300',
#  'imdbRating': '4.6',
#  'imdbVotes': '524'}
# -------------------
# movie id tt2673714
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "It's local election season in Opa Humpka Florida. The contest for "
#          'Wildlife Termination Executive is heating up. The pythons are eating '
#          'house pets. The unpaid Campaign Interns are working ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '54 min',
#  'Title': 'To Live and Die in Opa Humpka',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Lisa Gottlieb',
#  'Year': '2013',
#  'imdbID': 'tt2673714',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3651654
# -------------------
# {'Actors': 'Lindsay Patterson, Carina Czipoth, Albert Anderson, William Flynn',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Wendy Eaton',
#  'Genre': 'Drama, Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A young stunt player (Lily) of indie films replaces a legendary '
#          'stunt woman in a major film and finds that she is not fitting in. '
#          'Surprisingly though, the top actress (Kate McCloud) reaches...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjc5MDczMzU1N15BMl5BanBnXkFtZTgwNDczNjM3MTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '15 Dec 2013',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'To Pull a Stunt',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Wendy Eaton (screenplay), Lindsay Patterson (additional scenes)',
#  'Year': '2013',
#  'imdbID': 'tt3651654',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2990122
# -------------------
# {'Actors': 'Charis Beth Swartley, Aj Jaques, Maggie Mather, Brendon King',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ryan Lee Taylor',
#  'Genre': 'Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When a suicidal boy meets a purposeless girl.... something changes. '
#          'To The Horizon is an offbeat High School Romance about how two '
#          'people can effect each other in miraculous ways.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '12 Jun 2013',
#  'Response': 'True',
#  'Runtime': '71 min',
#  'Title': 'To the Horizon',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Alexander T. Damle',
#  'Year': '2013',
#  'imdbID': 'tt2990122',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2719488
# -------------------
# {'Actors': 'Jonathan Burris, Margaret Wuertz, Emily Ulrich, Lauren Argo',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Grayson Johnson',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'As her grasp on reality begins to loosen, the very sheltered Sheena '
#          'decides to become homeless on a whim.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'Toast',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Grayson Johnson',
#  'Year': '2013',
#  'imdbID': 'tt2719488',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2974798
# -------------------
# {'Actors': 'Pouran Esrafily',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Pouran Esrafily',
#  'Genre': 'Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Four young men and two young women in their early Twenties spend '
#          'three days sleeping and waking on the Beach with the Sunrise. They '
#          'play together or drift apart alone. A mature solitary ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '94 min',
#  'Title': 'Together Alone',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Pouran Esrafily',
#  'Year': '2013',
#  'imdbID': 'tt2974798',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3245778
# -------------------
# {'Actors': 'Tom Garland, Tom Garland',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Joe Clarke',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Iowa-bred stand up comedian Tom Garland performs his latest stand up '
#          "special in Cedar Rapids, Iowa, and talks about what it's like "
#          "performing in America's Heartland.",
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '18 Jun 2013',
#  'Response': 'True',
#  'Runtime': '65 min',
#  'Title': 'Tom Garland: Unleashed',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2013',
#  'imdbID': 'tt3245778',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5085082
# -------------------
# {'Actors': 'Tony T. Roberts',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Deon Taylor',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'From touring with Kevin Hart, winning BET awards, and starring on '
#          'television, Tony Roberts has done it all in comedy. In his brand-new '
#          "concert film, I'm Different, you'll hear his hilarious...",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjEyNzcwNTc4MF5BMl5BanBnXkFtZTgwNTE0NTk5NjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.5/10'}],
#  'Released': '15 Jan 2013',
#  'Response': 'True',
#  'Runtime': '67 min',
#  'Title': "Tony Roberts: I'm Different",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tony T. Roberts',
#  'Year': '2013',
#  'imdbID': 'tt5085082',
#  'imdbRating': '4.5',
#  'imdbVotes': '12'}
# -------------------
# movie id tt1423636
# -------------------
# {'Actors': 'Mahnoor Baloch, Faran Tahir, Dendrie Taylor, John Heard',
#  'Awards': '3 wins.',
#  'BoxOffice': '$4,881',
#  'Country': 'Pakistan, USA',
#  'DVD': 'N/A',
#  'Director': 'Jeremiah Birnbaum',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': '59',
#  'Plot': 'Two families bond when their teenage sons are killed in an explosion '
#          'at a suburban mall only to discover one of their children is the '
#          'prime suspect.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzgzMzY3NTk4M15BMl5BanBnXkFtZTgwMDkzMTYzMDE@._V1_SX300.jpg',
#  'Production': 'Dada Films',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.9/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '90%'},
#              {'Source': 'Metacritic', 'Value': '59/100'}],
#  'Released': '18 Oct 2013',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'Torn',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Richter (screenplay), Michael Richter (story), Marc Posner '
#            '(story), Jeremiah Birnbaum (story), Michael Richter',
#  'Year': '2013',
#  'imdbID': 'tt1423636',
#  'imdbRating': '5.9',
#  'imdbVotes': '499'}
# -------------------
# movie id tt1663696
# -------------------
# {'Actors': 'Vincent Pastore, Christie Sanford, Lynn Lowry, Ron Millkie',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '27 Jan 2014',
#  'Director': 'Dante Tomaselli',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Members of a religious community try to save the soul of a possessed '
#          'boy and his child cohorts after he escapes from an asylum and starts '
#          'murdering anyone who gets in his way.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjE4MTU4NjI3MF5BMl5BanBnXkFtZTcwODYwMzQ1OA@@._V1_SX300.jpg',
#  'Production': 'Cinedigm',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.9/10'}],
#  'Released': '05 Feb 2015',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Torture Chamber',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dante Tomaselli (screenplay)',
#  'Year': '2013',
#  'imdbID': 'tt1663696',
#  'imdbRating': '2.9',
#  'imdbVotes': '471'}
# -------------------
# movie id tt2861394
# -------------------
# {'Actors': 'Sommer Fox, Sojourner Kincaid-Rolle, Don Margolin, Ashelynne '
#            'McLean',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Virginia Mariposa Dale',
#  'Genre': 'Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A young family buys a rundown old Victorian house with the intention '
#          'of renovating it, only to discover that something evil lurks within.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjE5NzI5NTQ0N15BMl5BanBnXkFtZTgwNDQyMDMwMDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '81 min',
#  'Title': 'Touch of the Devil',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Virginia Mariposa Dale',
#  'Year': '2013',
#  'imdbID': 'tt2861394',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2364949
# -------------------
# {'Actors': 'Rosemarie DeWitt, Amber Wolfe Wollam, Josh Pais, Ellen Page',
#  'Awards': '1 nomination.',
#  'BoxOffice': '$35,966',
#  'Country': 'USA',
#  'DVD': '10 Dec 2013',
#  'Director': 'Lynn Shelton',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': '55',
#  'Plot': 'A massage therapist is unable to do her job when stricken with a '
#          'mysterious and sudden aversion to bodily contact. Meanwhile, her '
#          "uptight brother's floundering dental practice receives new life when "
#          'clients seek out his healing touch.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk2MTI1NTA3Ml5BMl5BanBnXkFtZTcwODY1MzA3OQ@@._V1_SX300.jpg',
#  'Production': 'Magnolia Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.3/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '39%'},
#              {'Source': 'Metacritic', 'Value': '55/100'}],
#  'Released': '16 May 2014',
#  'Response': 'True',
#  'Runtime': '89 min',
#  'Title': 'Touchy Feely',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Lynn Shelton',
#  'Year': '2013',
#  'imdbID': 'tt2364949',
#  'imdbRating': '5.3',
#  'imdbVotes': '3,382'}
# -------------------
# movie id tt2379118
# -------------------
# {'Actors': "Aleksander D'Avignon, Shannon Lark, Erik Cram, Ian Roberts",
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Matt Gibson',
#  'Genre': 'Comedy, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'On September 11, 2001, terrorists attacking the World Trade Center '
#          'rise from the dead as zombies.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTY2MjI2NTY5N15BMl5BanBnXkFtZTcwNjAwMzk0OA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.1/10'}],
#  'Released': '18 Oct 2013',
#  'Response': 'True',
#  'Runtime': '84 min',
#  'Title': 'Towers of Terror',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Matt Gibson',
#  'Year': '2013',
#  'imdbID': 'tt2379118',
#  'imdbRating': '3.1',
#  'imdbVotes': '18'}
# -------------------
# movie id tt2578832
# -------------------
# {'Actors': 'Shannon Plumb, Derek Cianfrance, Cody Cianfrance, Walker '
#            'Cianfrance',
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Shannon Plumb',
#  'Genre': 'Comedy, Drama, Family',
#  'Language': 'English',
#  'Metascore': '56',
#  'Plot': 'Adventurous and bold mother of two, PENELOPE, struggles to strike '
#          'the balance between her artistic aspirations and motherly '
#          'responsibilities in this playful look at modern-day motherhood and '
#          'the difficulties families face everyday.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTYwMDg3MDcxMl5BMl5BanBnXkFtZTgwMzg4NjM4MDE@._V1_SX300.jpg',
#  'Production': 'Cinedigm',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.5/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '67%'},
#              {'Source': 'Metacritic', 'Value': '56/100'}],
#  'Released': '27 Mar 2013',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': 'Towheads',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Shannon Plumb',
#  'Year': '2013',
#  'imdbID': 'tt2578832',
#  'imdbRating': '5.5',
#  'imdbVotes': '98'}
# -------------------
# movie id tt3897880
# -------------------
# {'Actors': 'Karl Fostvedt, Pep Fujas, Sean Pettit',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tyler Hamlet',
#  'Genre': 'Sport',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Every skier knows what it's like to call a few friends, pack up, and "
#          'head out for a trip. Rather than spend another winter chasing '
#          'storms, five of the top pros and their closest pals embark...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTAxNjAxMDEzNDZeQTJeQWpwZ15BbWU4MDg3ODEyNTIx._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.9/10'}],
#  'Released': '06 Sep 2013',
#  'Response': 'True',
#  'Runtime': '55 min',
#  'Title': 'Tracing Skylines',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2013',
#  'imdbID': 'tt3897880',
#  'imdbRating': '5.9',
#  'imdbVotes': '28'}
# -------------------
# movie id tt3075730
# -------------------
# {'Actors': 'Mercedes Vasquez, Juan Carlos Rodriguez, Antonia Marrero, Doreen '
#            'Montalvo',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Juan Carlos Rodriguez',
#  'Genre': 'Crime, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "The inner workings of New York City's Washington Heights' war on "
#          'drugs.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '15 Oct 2013',
#  'Response': 'True',
#  'Runtime': '93 min',
#  'Title': 'Tracked',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Juan Carlos Rodriguez',
#  'Year': '2013',
#  'imdbID': 'tt3075730',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2734456
# -------------------
# {'Actors': 'Page Tudyk, Jordan Witter, Schon Duncan',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Gage Beavers, Nathan Booth(co-director)',
#  'Genre': 'Crime, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'In a surreal turn of events an out of control heroin addict, named '
#          'Stella, (Page Tudyk,) drifts through the desert, without any memory '
#          'of how she came to be stranded. With her life in ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '70 min',
#  'Title': 'Tracks',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Gage Beavers, Nathan Booth',
#  'Year': '2013',
#  'imdbID': 'tt2734456',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2973950
# -------------------
# {'Actors': 'Nick Dubanos, Tiffany Stoker, David Lassiter, Alex Ortiz',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Raymond Deane',
#  'Genre': 'Drama, Romance, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "'Live with your choices. Die with your mistakes.' Traduce Trevor "
#          'Bryant is a ladies man who decides to settle down with his longtime '
#          "girlfriend Emily O'brian. Trevor has one more fling with...",
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '101 min',
#  'Title': 'Traduce',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Raymond Deane',
#  'Year': '2013',
#  'imdbID': 'tt2973950',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3003758
# -------------------
# {'Actors': 'Chaimae Ben Acha, Soufia Issami, Mourade Zeguendi, Driss Roukhe',
#  'Awards': '3 wins & 6 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'Morocco, USA',
#  'DVD': '24 Feb 2015',
#  'Director': 'Sean Gullette',
#  'Genre': 'Drama',
#  'Language': 'Arabic, French, English',
#  'Metascore': 'N/A',
#  'Plot': 'Malika is the leader of the all-female punk rock band Traitors, with '
#          'a strong vision of the world, her hometown of Tangier, and her place '
#          'in it. When she needs money to save her family from...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjI2MTA4MTQ3N15BMl5BanBnXkFtZTgwNTMwOTcwOTE@._V1_SX300.jpg',
#  'Production': 'Film Movement',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '88%'}],
#  'Released': '20 Apr 2014',
#  'Response': 'True',
#  'Runtime': '83 min',
#  'Title': 'Traitors',
#  'Type': 'movie',
#  'Website': 'http://www.filmmovement.com/filmcatalog/index.asp?MerchandiseID=394',
#  'Writer': 'Sean Gullette',
#  'Year': '2013',
#  'imdbID': 'tt3003758',
#  'imdbRating': '6.3',
#  'imdbVotes': '310'}
# -------------------
# movie id tt1924429
# -------------------
# {'Actors': 'James McAvoy, Vincent Cassel, Rosario Dawson, Danny Sapani',
#  'Awards': '3 wins & 3 nominations.',
#  'BoxOffice': '$4,856,227',
#  'Country': 'UK, USA, France',
#  'DVD': '23 Jul 2013',
#  'Director': 'Danny Boyle',
#  'Genre': 'Crime, Drama, Mystery, Thriller',
#  'Language': 'English, French',
#  'Metascore': '61',
#  'Plot': 'An art auctioneer becomes mixed up with a group of criminals '
#          'partners with a hypnotherapist in order to recover a lost painting.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjMzNjU1MTg5NF5BMl5BanBnXkFtZTcwMTExMTcwOQ@@._V1_SX300.jpg',
#  'Production': '20th Century Fox',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.9/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '68%'},
#              {'Source': 'Metacritic', 'Value': '61/100'}],
#  'Released': '27 Mar 2013',
#  'Response': 'True',
#  'Runtime': '101 min',
#  'Title': 'Trance',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joe Ahearne (screenplay), John Hodge (screenplay), Joe Ahearne '
#            '(story)',
#  'Year': '2013',
#  'imdbID': 'tt1924429',
#  'imdbRating': '6.9',
#  'imdbVotes': '106,511'}
# -------------------
# movie id tt3406004
# -------------------
# {'Actors': 'Tobi Hill-Meyer, Chelsea Poe, Dylan Ryan, Courtney Trouble',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Courtney Trouble',
#  'Genre': 'Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Sep 2013',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Trans Grrrls: Revoution Porn Style Now',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Courtney Trouble',
#  'Year': '2013',
#  'imdbID': 'tt3406004',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2806790
# -------------------
# {'Actors': 'Christian Chase, Ernest Romeo, Janyris Cotto, Rose Fiore',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Joshua Nelson',
#  'Genre': 'Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A Vampire with very specific taste becomes entwined with 3 different '
#          'situations where she turns out to be both their savior and their '
#          'demise.',
#  'Poster': 'N/A',
#  'Production': 'Amplified Contrasts Productions',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.0/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '48 min',
#  'Title': 'Transfusion',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joshua Nelson',
#  'Year': '2013',
#  'imdbID': 'tt2806790',
#  'imdbRating': '6.0',
#  'imdbVotes': '9'}
# -------------------
# movie id tt10203762
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt2567376
# -------------------
# {'Actors': 'Chalet Lizette Brannan, Caleb Cornelius, Cameron Hood, Emily '
#            'Sparks',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Matthew Scott King',
#  'Genre': 'Adventure',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'NOT RATED',
#  'Ratings': [],
#  'Released': '01 Jan 2013',
#  'Response': 'True',
#  'Runtime': '70 min',
#  'Title': 'Trapped in Time 3D!',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Matthew Scott King',
#  'Year': '2013',
#  'imdbID': 'tt2567376',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4608696
# -------------------
# {'Actors': 'Brenda Epperson, Victoria Rowell, Cari Urias',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Keith Schoen',
#  'Genre': 'Reality-TV',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Nov 2013',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Trash or Treasure Sizzle Reel',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Keith Schoen',
#  'Year': '2013',
#  'imdbID': 'tt4608696',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2577746
# -------------------
# {'Actors': 'Jamie Boggs, Orlando Eastwood, Sidney Flannery, Stephen McKinney',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Orlando Eastwood',
#  'Genre': 'Horror',
#  'Language': 'English, German',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.2/10'}],
#  'Released': '13 Jan 2013',
#  'Response': 'True',
#  'Runtime': '70 min',
#  'Title': 'Traumatic Possession 3D: The Tape',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Orlando Eastwood',
#  'Year': '2013',
#  'imdbID': 'tt2577746',
#  'imdbRating': '4.2',
#  'imdbVotes': '5'}
# -------------------
# movie id tt3498890
# -------------------
# {'Actors': 'Lino Aquino, Humberto Bocanegra, Jose Cano, Jose Carranza',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Mexico',
#  'DVD': 'N/A',
#  'Director': 'Luis Antonio Rodriguez',
#  'Genre': 'Action, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A story of hope and despair as a group of immigrants are unknowingly '
#          'recorded by one of the members within the group. Witness their '
#          'journey with its twists and turns as they make their way North in '
#          'pursuit of a better life.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '75 min',
#  'Title': 'Trayecto',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Humberto Bocanegra, Luis Antonio Rodriguez',
#  'Year': '2013',
#  'imdbID': 'tt3498890',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2380301
# -------------------
# {'Actors': 'Michael Biehn, Matthew Ziff, Caitlin Keats, Christian J. Meoli',
#  'Awards': '2 wins & 2 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '01 Sep 2015',
#  'Director': 'Travis Romero',
#  'Genre': 'Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An estranged father and son are re-united at a wedding party. '
#          'However, a thunderstorm traps them in a cabin, forcing the family to '
#          'reveal deeper secrets.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTY2MzEzMzA1N15BMl5BanBnXkFtZTgwNjA5NjkzMDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.2/10'}],
#  'Released': '01 Sep 2014',
#  'Response': 'True',
#  'Runtime': '67 min',
#  'Title': 'Treachery',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Travis Romero, Lorraine Ziff (story editor)',
#  'Year': '2013',
#  'imdbID': 'tt2380301',
#  'imdbRating': '3.2',
#  'imdbVotes': '395'}
# -------------------
# movie id tt3763580
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Several members of a family spend a week-end learning all kinds of '
#          'new things about each other and about life. Each, in their own way, '
#          'must come to terms about the illusions that they have about '
#          'themselves and about each other.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '73 min',
#  'Title': 'Treachery',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2013',
#  'imdbID': 'tt3763580',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3210578
# -------------------
# {'Actors': 'Myles MacVane, Allison Martynovych, Charles Mezzadri, Chad '
#            'Schubert',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Mike Quilty',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'You can only tread water for so long before you drown. The lives of '
#          'a former professional surfer and a homeless drifter become entwined '
#          'after a failed suicide attempt. These two lost souls ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '98 min',
#  'Title': 'Treading Water',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Mike Quilty',
#  'Year': '2013',
#  'imdbID': 'tt3210578',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2118760
# -------------------
# {'Actors': 'Veronica Ricci, Nicholas Adam Clark, James Cullen Bressack, Nick '
#            'Waugh',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'M. Kelley, Shawn C. Phillips, Alex Powers, Doug Waugh',
#  'Genre': 'Comedy, Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Mona Screamalot, along with her crazy family, prepares you for six '
#          'short horror films from deep within her trashy treasure chest. This '
#          'anthology features party killers, giant killer babies,...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjY0MjQ1NzAyM15BMl5BanBnXkFtZTcwNzkzMDQwOQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.3/10'}],
#  'Released': '23 Apr 2013',
#  'Response': 'True',
#  'Runtime': '82 min',
#  'Title': 'Treasure Chest of Horrors II',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Shawn C. Phillips (segment), Shawn C. Phillips (segment), Shawn C. '
#            'Phillips (segment), Alex Powers (segment), Doug Waugh (segment), '
#            'Doug Waugh (segment), Doug Waugh (segment)',
#  'Year': '2013',
#  'imdbID': 'tt2118760',
#  'imdbRating': '3.3',
#  'imdbVotes': '49'}
# -------------------
# movie id tt1956684
# -------------------
# {'Actors': 'Robert Milo Andrus, Robert Bear, Jake Bramante, Colton Christensen',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '02 Dec 2013',
#  'Director': 'Andrew Wiest',
#  'Genre': 'Adventure, Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'In this family-friendly adventure, two teens must put their rivalry '
#          'aside and join forces to stop notorious bandits and survive the '
#          'brutal wilderness known as the Treasure State.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQwNTg1NjMwOV5BMl5BanBnXkFtZTgwMDI1NzIxMjE@._V1_SX300.jpg',
#  'Production': 'Good Outlaw Studios',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.6/10'}],
#  'Released': '03 Dec 2013',
#  'Response': 'True',
#  'Runtime': '83 min',
#  'Title': 'Treasure State',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ryan Reed, Andrew Wiest',
#  'Year': '2013',
#  'imdbID': 'tt1956684',
#  'imdbRating': '7.6',
#  'imdbVotes': '57'}
# -------------------
# movie id tt2258054
# -------------------
# {'Actors': 'Ryan T. Husk, Darth Schuhe, Freddy John James, Jakquelyn Sullivan',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tymaine Clay',
#  'Genre': 'Animation, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '08 Aug 2013',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Trek Wars: The Movie',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tymaine Clay, Vasilios Pappas',
#  'Year': '2013',
#  'imdbID': 'tt2258054',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2392504
# -------------------
# {'Actors': 'Keith Goff, Walter Halliburton, Dana Porter, Iris Moore',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Antonio James',
#  'Genre': 'Action, Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Everyone has demons in their closet but when Trey meets the wrong '
#          'love of his life, those demons become reality. And for those closes '
#          'to Trey, his reality is deadly.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjM0MDg5MTkxNF5BMl5BanBnXkFtZTcwMDQ5Mjk0OQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'}],
#  'Released': '04 Jun 2013',
#  'Response': 'True',
#  'Runtime': '91 min',
#  'Title': 'Trey the Movie',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Antonio James',
#  'Year': '2013',
#  'imdbID': 'tt2392504',
#  'imdbRating': '5.8',
#  'imdbVotes': '9'}
# -------------------
# movie id tt4378980
# -------------------
# {'Actors': 'Will Charles, Dominic Daniel, Olande Fleury, Jerry Gonzales',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jody Hart',
#  'Genre': 'War',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
# ...
# movie id tt2568430
# -------------------
# {'Actors': 'Ulas Tuna Astepe, Sergulen Onan Dervisoglu, Zeynep Olcer, Selim '
#            'Can Bilgin',
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'Turkey, USA',
#  'DVD': 'N/A',
#  'Director': 'Deniz Tortum',
#  'Genre': 'Drama',
#  'Language': 'Turkish',
#  'Metascore': 'N/A',
#  'Plot': 'A man falls into the Bosphorus on a snowy night. His son, Mete, '
#          'half-heartedly searches for him in wintered Istanbul. As Mete traces '
#          "through the undercurrents of his father's life, he takes...",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZDcyODI4MjYtNTQ3MC00Nzc0LWFiODQtYzdhNTFmZGJlZjE2XkEyXkFqcGdeQXVyNjU0OTA2ODY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.8/10'}],
#  'Released': '01 Mar 2013',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Zayiat',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Steeve Roso, Deniz Tortum',
#  'Year': '2013',
#  'imdbID': 'tt2568430',
#  'imdbRating': '7.8',
#  'imdbVotes': '19'}
# -------------------
# movie id tt3249418
# -------------------
# {'Actors': 'Michael Chovanes, Samantha Bergeron, Joel Zuiker, Carley Ingold',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'George Foster',
#  'Genre': 'Biography, Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An urban ascetic, haunted by his past, walks a line between pious '
#          'devotion and religious fanaticism while trying to find his place in '
#          'the world.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDcwMzg2OTY2NF5BMl5BanBnXkFtZTgwMzUzMTAxNjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.2/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '105 min',
#  'Title': 'Zealot',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'George Foster',
#  'Year': '2013',
#  'imdbID': 'tt3249418',
#  'imdbRating': '7.2',
#  'imdbVotes': '5'}
# -------------------
# movie id tt2651916
# -------------------
# {'Actors': 'Amy Pietz, Johnny Whitworth, Tracey Fairaway, Kelly Curran',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '11 May 2015',
#  'Director': 'Marita Grabiak',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When Dawn and Kayla reunite for a mother-daughter weekend at a '
#          'popular spa resort, they find themselves fighting for their lives as '
#          'they discover the visiting guru has turned the resort into a cult '
#          'nightmare.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDJhMmYyZWEtMmIyNS00MDg5LTk4OWEtZDA0MzhmNTVmMzlhXkEyXkFqcGdeQXVyMTI2OTM0NzQ@._V1_SX300.jpg',
#  'Production': 'MTI Home Video',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.2/10'}],
#  'Released': '01 Jun 2013',
#  'Response': 'True',
#  'Runtime': '88 min',
#  'Title': 'Zephyr Springs',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kraig Wenman',
#  'Year': '2013',
#  'imdbID': 'tt2651916',
#  'imdbRating': '4.2',
#  'imdbVotes': '358'}
# -------------------
# movie id tt2294965
# -------------------
# {'Actors': 'Sam Eidson, Brock England, Garrett Graham, Anne Gee Byrd',
#  'Awards': '1 win & 1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '22 May 2014',
#  'Director': 'Katie Graham, Andrew Matthews',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': '63',
#  'Plot': 'An overgrown nerd who serves as Game Master of a fantasy board game '
#          'finds his role as leader of the misfits put into jeopardy when a new '
#          'initiate enters the group.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ3MDU4MTI3NV5BMl5BanBnXkFtZTgwMzg5NDYyMDE@._V1_SX300.jpg',
#  'Production': 'Tribeca Film',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '76%'},
#              {'Source': 'Metacritic', 'Value': '63/100'}],
#  'Released': '08 Oct 2013',
#  'Response': 'True',
#  'Runtime': '86 min',
#  'Title': 'Zero Charisma',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Andrew Matthews',
#  'Year': '2013',
#  'imdbID': 'tt2294965',
#  'imdbRating': '6.2',
#  'imdbVotes': '2,384'}
# -------------------
# movie id tt2046166
# -------------------
# {'Actors': 'Mike Simmons, Tabitha Holbert, Chris Kerson, Darrell Crawford',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tim McCann',
#  'Genre': 'Crime, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A vigilante ex-con is determined to clean up his crime-infested '
#          'community. As he avenges the death of his sister, he begins a series '
#          'of actions that may lead to his own destruction.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjA4MDU5OTc2Nl5BMl5BanBnXkFtZTgwMDE0MjkzNzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.7/10'}],
#  'Released': '05 Nov 2013',
#  'Response': 'True',
#  'Runtime': '84 min',
#  'Title': 'Zero in the System',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tim McCann',
#  'Year': '2013',
#  'imdbID': 'tt2046166',
#  'imdbRating': '5.7',
#  'imdbVotes': '42'}
# -------------------
# movie id tt3228818
# -------------------
# {'Actors': 'Cooper Daniels, Ruta Gedmintas, Kadeem Hardison, John Lavelle',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Christopher Kublan',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A family of friends gather on the eve of the Iraq War to perform an '
#          'intervention on Lippy, who is taking his anti-war activism too far. '
#          'The night launches a series of events that forever change the lives '
#          'off all who were there.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.5/10'}],
#  'Released': '21 Nov 2013',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Zerosome',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Christopher Kublan',
#  'Year': '2013',
#  'imdbID': 'tt3228818',
#  'imdbRating': '5.5',
#  'imdbVotes': '11'}
# -------------------
# movie id tt2910188
# -------------------
# {'Actors': 'Ryan Cole, Scotland Thompson, Stacy Deann, Stephen Haydon',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Scotland Thompson',
#  'Genre': 'Comedy, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When Seth gets dumped on his 18 birthday, his best friend Nick tries '
#          'to throw him the best party ever. But everything goes wrong when '
#          'Nick suspects Seth is turning into a zombie after spending the night '
#          'with a prostitute.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ4MjQzMTAzM15BMl5BanBnXkFtZTgwOTg5OTAwMDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.2/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'Zerpes',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Scotland Thompson',
#  'Year': '2013',
#  'imdbID': 'tt2910188',
#  'imdbRating': '7.2',
#  'imdbVotes': '15'}
# -------------------
# movie id tt1916763
# -------------------
# {'Actors': 'Lew Temple, Malcolm McDowell, David Christopher, Sid Haig',
#  'Awards': '1 win & 1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '25 Aug 2014',
#  'Director': 'Jesse Dayton',
#  'Genre': 'Horror, Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'As things are turning around for the city, people must face a '
#          'disaster of epic proportions. They are dealing with the prospect of '
#          "losing the people of New Orleans as they turn into the city's "
#          'walking dead.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjEyMDkxMDIxMF5BMl5BanBnXkFtZTgwOTE2NjM2MDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.2/10'}],
#  'Released': '26 Oct 2013',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Zombex',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jesse Dayton',
#  'Year': '2013',
#  'imdbID': 'tt1916763',
#  'imdbRating': '2.2',
#  'imdbVotes': '582'}
# -------------------
# movie id tt1478478
# -------------------
# {'Actors': 'William Cutting, Kelly Petering, Myles McLane, Trista Robinson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '26 Mar 2013',
#  'Director': 'Ren Blood',
#  'Genre': 'Comedy, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Loser Ed has a lame job, a crappy apartment and no hope of a '
#          'girlfriend. None of this mattered to Ed until he woke up one morning '
#          'to find he had "gone zombie". Being a human loser is bad, ...',
#  'Poster': 'https://ia.media-imdb.com/images/M/MV5BMTUzNTEyMTI5Nl5BMl5BanBnXkFtZTcwMTc5ODc2NQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'NOT RATED',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.2/10'}],
#  'Released': '22 Jan 2013',
#  'Response': 'True',
#  'Runtime': '104 min',
#  'Title': 'Zombie Ed',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ren Blood',
#  'Year': '2013',
#  'imdbID': 'tt1478478',
#  'imdbRating': '2.2',
#  'imdbVotes': '127'}
# -------------------
# movie id tt2446502
# -------------------
# {'Actors': 'Danny Trejo, Martin Copping, Clare Niederpruem, Jade Regier',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '08 Oct 2013',
#  'Director': 'K. King',
#  'Genre': 'Action, Comedy, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When a street drug turns junkies into an army of zombies, a man '
#          'named Hunter finds himself with nothing but a beat-up car and a '
#          'trunk full of guns and booze, until he stumbles across a small band '
#          'of survivors.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTU5Mjg3MzAxNV5BMl5BanBnXkFtZTgwNTk5NTI2MDE@._V1_SX300.jpg',
#  'Production': 'Well Go USA',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.5/10'}],
#  'Released': '08 Oct 2013',
#  'Response': 'True',
#  'Runtime': '93 min',
#  'Title': 'Zombie Hunter',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'K. King, Kurt Knight',
#  'Year': '2013',
#  'imdbID': 'tt2446502',
#  'imdbRating': '3.5',
#  'imdbVotes': '2,430'}
# -------------------
# movie id tt2081438
# -------------------
# {'Actors': 'Christian Boeving, Mike Mitchell, Tara Cardinal, Ivy Corbin',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'Italy, USA, Germany, Canada',
#  'DVD': 'N/A',
#  'Director': 'Luca Boni, Marco Ristori',
#  'Genre': 'Action, Horror, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A team of soldiers who are assembled to help end a zombie outbreak '
#          'in a Romanian town.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTA4OTg3MzE1MzZeQTJeQWpwZ15BbWU3MDQyMjc1OTY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.3/10'}],
#  'Released': '26 Oct 2013',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Apocalypse Z',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Luca Boni, Marco Ristori, Russell Romick',
#  'Year': '2013',
#  'imdbID': 'tt2081438',
#  'imdbRating': '2.3',
#  'imdbVotes': '1,668'}
# -------------------
# movie id tt4267598
# -------------------
# {'Actors': 'Jeff Schrock, Doug Kolbicz, Adam Lorenz',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tommy Brunswick',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '17 Oct 2013',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Zombies of Carnage',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tommy Brunswick',
#  'Year': '2013',
#  'imdbID': 'tt4267598',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3307448
# -------------------
# {'Actors': 'Devin M. Miller, Tiffany Cosey, Tevon Plunkett, Anthony M. Edwards',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Nancy Wilson',
#  'Genre': 'Crime',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Sam, a recently discharged Marine, returns to find his hometown as '
#          'equally devastated as the combat zone he struggled to leave behind.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Zone Three',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Nancy Wilson',
#  'Year': '2013',
#  'imdbID': 'tt3307448',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3125724
# -------------------
# {'Actors': 'Caitlyn Murray, Tyler Hogerty, Rhiannon Saydlowski, Connor McGowan',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Will J. Barker, Alex Clarke',
#  'Genre': 'Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': '[Working Title] is a feature length, humorous, casual teen drama. It '
#          'is about an eighteen year old aspiring screenwriter and producer '
#          'named Blake, who engages in a secret relationship with ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '74 min',
#  'Title': '[Working Title]',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Will J. Barker (story), Will J. Barker, Thomas Breeden, Alec '
#            'Sparks (story), Sarah Vogl (story)',
#  'Year': '2013',
#  'imdbID': 'tt3125724',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt10129116
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt2782834
# -------------------
# {'Actors': 'Justin Long, Art Evans, Juzo Yoshida, Brian Huskey',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '15 Aug 2013',
#  'Director': 'Ryan Perez',
#  'Genre': 'Biography, Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A comedic look at the life of Steve Jobs.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTY1OTUxMzQxOV5BMl5BanBnXkFtZTcwMDU4MDA0OQ@@._V1_SX300.jpg',
#  'Production': 'Funny or Die',
#  'Rated': 'NOT RATED',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.3/10'}],
#  'Released': '15 Apr 2013',
#  'Response': 'True',
#  'Runtime': '79 min',
#  'Title': 'iSteve',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ryan Perez, Danny Jelinek (additional material), Charles Ingram '
#            '(additional material), Anne Rieman (additional material), Nick '
#            'Corirossi (additional material), Allison Hord (additional '
#            'material), Bradly Schulz (additional material)',
#  'Year': '2013',
#  'imdbID': 'tt2782834',
#  'imdbRating': '5.3',
#  'imdbVotes': '1,050'}
# -------------------
# movie id tt2041331
# -------------------
# {'Actors': 'Caitlyn Folley, Ian Duncan, Diana García, Chris Coy',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '14 Jul 2014',
#  'Director': 'Bernard Rose',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Jill's an artist. Adam's a filmmaker. And their love life is off the "
#          "chain. There's no experience too wild, no dare too dangerous -- not "
#          'even when Jill lets Adam strap her to a gurney in ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDU4MDE3MTE4Ml5BMl5BanBnXkFtZTgwODE3MTA2MTE@._V1_SX300.jpg',
#  'Production': 'Well Go USA',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.3/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '33%'}],
#  'Released': '16 May 2014',
#  'Response': 'True',
#  'Runtime': '82 min',
#  'Title': 'sxtape',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Eric Reese',
#  'Year': '2013',
#  'imdbID': 'tt2041331',
#  'imdbRating': '3.3',
#  'imdbVotes': '1,761'}

# %%
len(title_list)
# Out:
# 307

# %%
len(title_id)
# Out:
# 307

# %%
# if title_list and title_id are the same length run the cell below. 
# if they are not equal take out 'title_id': title_id

# %%
df = pd.DataFrame({'title_id': title_id, 'title': title_list, 'box_office': box_office_list, 'country': country_list, 
                   'genre': genre_list, 'director': director_list, 'metascore': metascore_list, 'production': production_list, 
                   'rating': rating_list, 'IMDB_rating': IMDB_rating_list, 'rotten_tomatoes_rating': rotten_tomatoes_rating_list, 
                  'runtime': runtime_list, 'type': type_list, 'IMDB_votes': imdb_votes_list})

# %%
df = df.drop_duplicates()
df.head()
# Out:
#     title_id                    title box_office country  \
# 0  tt2754340  Through a Mother's Eyes        N/A     USA
# 1  tt5615530        Through the Storm        N/A     USA
# 2  tt1986997       Thursday's Speaker        N/A     USA
# 3  tt2866674         Thy Will Be Done        N/A     USA
# 4  tt1758820                  Tiburon        N/A     USA
#
#                     genre             director metascore  \
# 0                   Drama         Greg Robbins       N/A
# 1                  Action      Rebekah Stought       N/A
# 2           Comedy, Drama          Gary Hebert       N/A
# 3  Drama, Family, Musical       Albert Johnson       N/A
# 4         Drama, Thriller  Christopher Behrens       N/A
#
#                 production     rating IMDB_rating rotten_tomatoes_rating  \
# 0                      N/A        N/A         5.6                     NA
# 1                      N/A        N/A         8.0                     NA
# 2                      N/A  Not Rated         7.7                     NA
# 3  Lightyear Entertainment        N/A         6.7                     NA
# 4                      N/A        N/A         8.3                     NA
#
#   runtime   type IMDB_votes
# 0     N/A  movie         10
# 1  91 min  movie          5
# 2  85 min  movie         14
# 3  90 min  movie          7
# 4  87 min  movie         28

# %%
df.count()
# Out:
# title_id                  307
# title                     307
# box_office                307
# country                   307
# genre                     307
# director                  307
# metascore                 307
# production                307
# rating                    307
# IMDB_rating               307
# rotten_tomatoes_rating    307
# runtime                   307
# type                      307
# IMDB_votes                307
# dtype: int64

# %%
df.to_csv('../data/2013_data_batch_4.csv', index=False)
