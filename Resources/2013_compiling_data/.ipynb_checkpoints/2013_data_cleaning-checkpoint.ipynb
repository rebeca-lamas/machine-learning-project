# %%
import pandas as pd

# %%
batch_1 = pd.read_csv('../data/2013_data_batch_1.csv')
batch_2 = pd.read_csv('../data/2013_data_batch_2.csv')
batch_3 = pd.read_csv('../data/2013_data_batch_3.csv')
batch_4 = pd.read_csv('../data/2013_data_batch_4.csv')

# %%
len(batch_1)
# Out:
# 993

# %%
len(batch_2)
# Out:
# 995

# %%
len(batch_3)
# Out:
# 993

# %%
len(batch_4)
# Out:
# 307

# %%
df = pd.DataFrame()

# %%
df = pd.concat([batch_1, batch_2, batch_3, batch_4], ignore_index=True)

# %%
len(df)
# Out:
# 3288

# %%
df.head(100)
# Out:
#      title_id                       title box_office country  \
# 0   tt2346170            #1 Serial Killer        NaN     USA
# 1   tt3120962                          #5        NaN     NaN
# 2   tt2777190                'Til Morning        NaN     USA
# 3   tt2395385                          +1        NaN     USA
# 4   tt2506748                        .357        NaN     USA
# ..        ...                         ...        ...     ...
# 95  tt1813609  A Haunting at Silver Falls        NaN     USA
# 96  tt2417834               A Leading Man        NaN     USA
# 97  tt3017382              A Leap to Take        NaN     USA
# 98  tt3248978            A Letter for Joe        NaN     USA
# 99  tt3104828             A Liar's Belief        NaN     USA
#
#                          genre            director  metascore  \
# 0                       Horror        Stanley Yung        NaN
# 1   Biography, Comedy, Fantasy         Ricky Bardy        NaN
# 2       Drama, Family, Fantasy       Brendan Russo        NaN
# 3     Horror, Sci-Fi, Thriller      Dennis Iliadis       60.0
# 4                Action, Drama         Brian Skiba        NaN
# ..                         ...                 ...        ...
# 95            Horror, Thriller       Brett Donowho        NaN
# 96                       Drama      Steven J. Kung        NaN
# 97                       Drama         Rob Nilsson        NaN
# 98                      Family           De Miller        NaN
# 99      Drama, Family, Mystery  Benedict A. Dorsey        NaN
#
#                production     rating  IMDB_rating rotten_tomatoes_rating  \
# 0        Indican Pictures        NaN          5.9                    NaN
# 1                     NaN        NaN          NaN                    NaN
# 2                     NaN        NaN          8.6                    NaN
# 3               IFC Films  Not Rated          5.5                    82%
# 4                     NaN  Not Rated          5.0                    NaN
# ..                    ...        ...          ...                    ...
# 95  Inception Media Group  Not Rated          4.8                    NaN
# 96            Mance Media  NOT RATED          6.7                    NaN
# 97                    NaN        NaN          NaN                    NaN
# 98                    NaN  NOT RATED          5.6                    NaN
# 99                    NaN        NaN          NaN                    NaN
#
#       runtime   type IMDB_votes
# 0      87 min  movie         37
# 1   1 h 8 min  movie        NaN
# 2      57 min  movie          7
# 3      96 min  movie      7,481
# 4      97 min  movie         55
# ..        ...    ...        ...
# 95     96 min  movie      2,620
# 96     96 min  movie         40
# 97        NaN  movie        NaN
# 98     96 min  movie         12
# 99     94 min  movie        NaN
#
# [100 rows x 14 columns]

# %%
total = len(df.country.unique())
unique = df.country.unique()
for i in range (total):
    print(unique[i])
# Out:
# USA
# nan
# USA, UK
# Puerto Rico, USA
# USA, UK, Japan, Hungary
# Colombia, USA
# Sri Lanka, USA
# USA, Sweden, Denmark
# USA, Russia, Hungary
# USA, Spain
# USA, UK, Austria, Norway, Switzerland
# UK, USA, Canada
# UK, USA
# USA, Australia, Canada
# Canada, USA
# USA, Indonesia
# Spain, USA, UK, France
# Antarctica, USA
# Australia, USA
# USA, Russia
# Italy, USA
# Austria, USA
# Ireland, USA
# Bahamas, USA
# India, USA, Germany, France
# Germany, USA
# USA, Singapore
# USA, Greece
# Russia, USA
# USA, Cameroon
# France, USA
# USA, France
# Sweden, USA
# Mexico, USA, Colombia
# USA, Philippines
# UK, USA, Sweden
# USA, Mexico
# UK, USA, France
# USA, Australia
# Switzerland, USA
# France, USA, Belgium
# Romania, USA
# India, USA
# India, United Arab Emirates, USA
# USA, Canada
# USA, South Korea
# El Salvador, USA
# India, France, Germany, USA, Canada
# Iceland, USA
# Venezuela, USA
# USA, Serbia and Montenegro, Switzerland, Sweden, Russia, Poland, Netherlands, Lithuania, Italy, Israel, Hungary, Germany, France, Estonia, Denmark, Czech Republic, Croatia, Bulgaria, Belgium, Austria
# USA, India, Canada
# USA, France, Belarus
# USA, France, Japan
# Thailand, USA
# Brazil, USA
# USA, Guatemala
# Spain, USA
# France, Belgium, Germany, Spain, Luxembourg, USA
# USA, Albania
# UK, Germany, Sweden, Belgium, USA
# USA, Japan, Argentina, Costa Rica
# China, USA
# Netherlands, USA, Czech Republic
# U.S. Virgin Islands, USA
# Taiwan, USA
# USA, Japan, Spain, UK
# USA, Germany
# USA, Bulgaria
# USA, Italy
# UK
# USA, Czech Republic
# USA, South Africa, Germany
# Australia, Philippines, USA
# USA, South Korea, Denmark, France, Switzerland
# Japan, USA
# Israel, USA
# Romania, Republic of Macedonia, USA, Greece, Albania
# Serbia, Hungary, USA
# USA, UK, France
# West Germany, USA
# Indonesia, USA
# Ireland, UK, USA
# USA, Switzerland
# USA, Pakistan
# USA, Colombia, Venezuela, Ecuador
# USA, India
# USA, Belgium, Bulgaria
# USA, Peru
# USA, Spain, Italy
# USA, France, Canada
# Canada, USA, Germany
# France, USA, Canada, Morocco, Senegal
# Mexico, USA
# USA, Mexico, Japan, Ireland, Indonesia, French Polynesia
# Bulgaria, Ireland, USA
# Chile, USA
# South Korea, USA
# USA, China, Hong Kong
# Jordan, Qatar, USA
# Cameroon, USA
# USA, France, Italy, Swaziland, Monaco, Switzerland
# Nigeria, USA
# Germany, Belgium, USA, France
# USA, Thailand
# USA, Armenia
# USA, Nigeria
# USA, Taiwan
# USA, Argentina
# USA, Belgium
# USA, Colombia
# Denmark, Germany, Belgium, UK, France, Sweden, USA
# USA, South Africa
# Denmark, France, USA, Sweden, Belgium
# USA, Hungary
# USA, India, France
# USA, Israel, Jordan
# Norway, USA
# USA, Japan, France, Spain
# South Korea, China, Hong Kong, USA
# Sri Lanka, USA, New Zealand
# UK, Germany, USA
# USA, Japan
# USA, UK, Australia
# Czech Republic, USA
# Pakistan, USA
# Germany, USA, France, UK
# USA, Canada, Bahamas, Australia
# USA, United Arab Emirates, UK
# USA, Cuba, Mexico
# Ethiopia, USA, Mexico, Italy, Egypt
# Spain, South Korea, USA
# USA, Belize
# Argentina, USA, France
# USA, UK, France, Germany, Japan
# Poland, USA
# Israel, Germany, Poland, Luxembourg, Belgium, France, USA
# USA, Russia, UK
# UK, New Zealand, USA
# Hong Kong, USA
# USA, India, Belgium
# USA, South Africa, Lesotho
# Italy, Germany, USA, Japan
# USA, Spain, Chile, Peru
# USA, New Zealand
# Canada, Australia, USA
# UK, USA, Australia
# USA, Germany, Canada, UK
# USA, Romania
# France, Switzerland, USA
# UK, Belgium, USA
# Ireland, USA, UK
# USA, Afghanistan, France, Belgium, Canada
# USA, Ukraine
# USA, Denmark, UK
# USA, France, Canada, Belgium
# UK, USA, Spain, Slovenia, Japan, Italy, France, Chile, Canada, Bulgaria
# USA, Switzerland, China
# UK, USA, Japan
# UK, Romania, France, USA
# USA, Ireland, Czech Republic, Poland
# Belgium, USA, UK, Germany, Italy
# Morocco, USA
# USA, Italy, Hungary
# USA, Israel, Palestine
# Switzerland, UK, USA
# USA, Canada, Indonesia
# USA, Netherlands, France
# Malaysia, USA
# USA, China
# UK, Australia, USA
# Romania, Hungary, Canada, USA
# Lithuania, USA
# Puerto Rico, USA, UK
# USA, Canada, Australia
# USA, UK, Malta
# France, Russia, USA, Belgium, Angola, Portugal
# Turkey, USA
# Italy, USA, Germany, Canada

# %%
df.country = df.country.str.lower()

# %%
df = df[df['country'].str.contains("usa", na=False)]

# %%
total = len(df.country.unique())
unique = df.country.unique()
for i in range (total):
    print(unique[i])
# Out:
# usa
# usa, uk
# puerto rico, usa
# usa, uk, japan, hungary
# colombia, usa
# sri lanka, usa
# usa, sweden, denmark
# usa, russia, hungary
# usa, spain
# usa, uk, austria, norway, switzerland
# uk, usa, canada
# uk, usa
# usa, australia, canada
# canada, usa
# usa, indonesia
# spain, usa, uk, france
# antarctica, usa
# australia, usa
# usa, russia
# italy, usa
# austria, usa
# ireland, usa
# bahamas, usa
# india, usa, germany, france
# germany, usa
# usa, singapore
# usa, greece
# russia, usa
# usa, cameroon
# france, usa
# usa, france
# sweden, usa
# mexico, usa, colombia
# usa, philippines
# uk, usa, sweden
# usa, mexico
# uk, usa, france
# usa, australia
# switzerland, usa
# france, usa, belgium
# romania, usa
# india, usa
# india, united arab emirates, usa
# usa, canada
# usa, south korea
# el salvador, usa
# india, france, germany, usa, canada
# iceland, usa
# venezuela, usa
# usa, serbia and montenegro, switzerland, sweden, russia, poland, netherlands, lithuania, italy, israel, hungary, germany, france, estonia, denmark, czech republic, croatia, bulgaria, belgium, austria
# usa, india, canada
# usa, france, belarus
# usa, france, japan
# thailand, usa
# brazil, usa
# usa, guatemala
# spain, usa
# france, belgium, germany, spain, luxembourg, usa
# usa, albania
# uk, germany, sweden, belgium, usa
# usa, japan, argentina, costa rica
# china, usa
# netherlands, usa, czech republic
# u.s. virgin islands, usa
# taiwan, usa
# usa, japan, spain, uk
# usa, germany
# usa, bulgaria
# usa, italy
# usa, czech republic
# usa, south africa, germany
# australia, philippines, usa
# usa, south korea, denmark, france, switzerland
# japan, usa
# israel, usa
# romania, republic of macedonia, usa, greece, albania
# serbia, hungary, usa
# usa, uk, france
# west germany, usa
# indonesia, usa
# ireland, uk, usa
# usa, switzerland
# usa, pakistan
# usa, colombia, venezuela, ecuador
# usa, india
# usa, belgium, bulgaria
# usa, peru
# usa, spain, italy
# usa, france, canada
# canada, usa, germany
# france, usa, canada, morocco, senegal
# mexico, usa
# usa, mexico, japan, ireland, indonesia, french polynesia
# bulgaria, ireland, usa
# chile, usa
# south korea, usa
# usa, china, hong kong
# jordan, qatar, usa
# cameroon, usa
# usa, france, italy, swaziland, monaco, switzerland
# nigeria, usa
# germany, belgium, usa, france
# usa, thailand
# usa, armenia
# usa, nigeria
# usa, taiwan
# usa, argentina
# usa, belgium
# usa, colombia
# denmark, germany, belgium, uk, france, sweden, usa
# usa, south africa
# denmark, france, usa, sweden, belgium
# usa, hungary
# usa, india, france
# usa, israel, jordan
# norway, usa
# usa, japan, france, spain
# south korea, china, hong kong, usa
# sri lanka, usa, new zealand
# uk, germany, usa
# usa, japan
# usa, uk, australia
# czech republic, usa
# pakistan, usa
# germany, usa, france, uk
# usa, canada, bahamas, australia
# usa, united arab emirates, uk
# usa, cuba, mexico
# ethiopia, usa, mexico, italy, egypt
# spain, south korea, usa
# usa, belize
# argentina, usa, france
# usa, uk, france, germany, japan
# poland, usa
# israel, germany, poland, luxembourg, belgium, france, usa
# usa, russia, uk
# uk, new zealand, usa
# hong kong, usa
# usa, india, belgium
# usa, south africa, lesotho
# italy, germany, usa, japan
# usa, spain, chile, peru
# usa, new zealand
# canada, australia, usa
# uk, usa, australia
# usa, germany, canada, uk
# usa, romania
# france, switzerland, usa
# uk, belgium, usa
# ireland, usa, uk
# usa, afghanistan, france, belgium, canada
# usa, ukraine
# usa, denmark, uk
# usa, france, canada, belgium
# uk, usa, spain, slovenia, japan, italy, france, chile, canada, bulgaria
# usa, switzerland, china
# uk, usa, japan
# uk, romania, france, usa
# usa, ireland, czech republic, poland
# belgium, usa, uk, germany, italy
# morocco, usa
# usa, italy, hungary
# usa, israel, palestine
# switzerland, uk, usa
# usa, canada, indonesia
# usa, netherlands, france
# malaysia, usa
# usa, china
# uk, australia, usa
# romania, hungary, canada, usa
# lithuania, usa
# puerto rico, usa, uk
# usa, canada, australia
# usa, uk, malta
# france, russia, usa, belgium, angola, portugal
# turkey, usa
# italy, usa, germany, canada

# %%
len(df)
# Out:
# 3207

# %%
df = df[df.box_office.notnull()]

# %%
len(df)
# Out:
# 260

# %%
# drop min number of non-NA values
df = df.dropna(thresh=7)
df.head(100)
# Out:
#        title_id                           title    box_office  \
# 12    tt2024544                12 Years a Slave   $50,628,650
# 22    tt1272878                          2 Guns   $73,500,000
# 29    tt1711425                       21 & Over   $25,675,765
# 40    tt0453562                              42   $95,001,343
# 43    tt1335975                        47 Ronin   $20,518,224
# ...         ...                             ...           ...
# 1324  tt2147728             I Used to Be Darker       $21,964
# 1330  tt1618432  I'm in Love with a Church Girl    $2,380,405
# 1339  tt2024432                  Identity Thief  $134,455,175
# 1357  tt0409379                       In Secret      $308,227
# 1361  tt2294677                   In a World...    $2,041,184
#
#                       country                      genre  \
# 12                    usa, uk  Biography, Drama, History
# 22                        usa   Action, Comedy, Thriller
# 29                        usa                     Comedy
# 40                        usa    Biography, Drama, Sport
# 43    usa, uk, japan, hungary     Action, Drama, Fantasy
# ...                       ...                        ...
# 1324                      usa               Drama, Music
# 1330                      usa      Crime, Drama, Romance
# 1339                      usa       Comedy, Crime, Drama
# 1357     serbia, hungary, usa     Crime, Drama, Thriller
# 1361                      usa                     Comedy
#
#                     director  metascore             production     rating  \
# 12             Steve McQueen       96.0        Fox Searchlight          R
# 22         Baltasar Kormákur       55.0     Universal Pictures          R
# 29    Jon Lucas, Scott Moore       34.0       Relativity Media          R
# 40           Brian Helgeland       62.0  Warner Bros. Pictures      PG-13
# 43               Carl Rinsch       28.0     Universal Pictures      PG-13
# ...                      ...        ...                    ...        ...
# 1324     Matthew Porterfield       69.0       Strand Releasing  Not Rated
# 1330              Steve Race       23.0     High Top Releasing         PG
# 1339             Seth Gordon       35.0     Universal Pictures          R
# 1357        Charlie Stratton       47.0   Roadside Attractions          R
# 1361               Lake Bell       79.0   Roadside Attractions          R
#
#       IMDB_rating rotten_tomatoes_rating  runtime   type IMDB_votes
# 12            8.1                    95%  134 min  movie    597,190
# 22            6.7                    64%  109 min  movie    185,722
# 29            5.8                    26%   93 min  movie     69,943
# 40            7.5                    80%  128 min  movie     79,660
# 43            6.2                    16%  128 min  movie    139,967
# ...           ...                    ...      ...    ...        ...
# 1324          5.6                    81%   89 min  movie        882
# 1330          4.4                     6%  118 min  movie      1,623
# 1339          5.7                    19%  111 min  movie    118,454
# 1357          6.1                    41%  107 min  movie      7,239
# 1361          6.7                    92%   93 min  movie     29,788
#
# [100 rows x 14 columns]

# %%
len(df)
# Out:
# 260

# %%
df.to_csv('../data/cleaned_2013_data.csv', index=False)

# %%
train = df[['title', 'box_office', 'country', 'genre', 'production', 'rating', 'runtime']]
train.head()
# Out:
#                title   box_office                  country  \
# 12  12 Years a Slave  $50,628,650                  usa, uk
# 22            2 Guns  $73,500,000                      usa
# 29         21 & Over  $25,675,765                      usa
# 40                42  $95,001,343                      usa
# 43          47 Ronin  $20,518,224  usa, uk, japan, hungary
#
#                         genre             production rating  runtime
# 12  Biography, Drama, History        Fox Searchlight      R  134 min
# 22   Action, Comedy, Thriller     Universal Pictures      R  109 min
# 29                     Comedy       Relativity Media      R   93 min
# 40    Biography, Drama, Sport  Warner Bros. Pictures  PG-13  128 min
# 43     Action, Drama, Fantasy     Universal Pictures  PG-13  128 min

# %%
train = train.reset_index(drop = True)
train.head()
# Out:
#               title   box_office                  country  \
# 0  12 Years a Slave  $50,628,650                  usa, uk
# 1            2 Guns  $73,500,000                      usa
# 2         21 & Over  $25,675,765                      usa
# 3                42  $95,001,343                      usa
# 4          47 Ronin  $20,518,224  usa, uk, japan, hungary
#
#                        genre             production rating  runtime
# 0  Biography, Drama, History        Fox Searchlight      R  134 min
# 1   Action, Comedy, Thriller     Universal Pictures      R  109 min
# 2                     Comedy       Relativity Media      R   93 min
# 3    Biography, Drama, Sport  Warner Bros. Pictures  PG-13  128 min
# 4     Action, Drama, Fantasy     Universal Pictures  PG-13  128 min

# %%
train['country'] = train['country'].str.count(',')
train['country'] = train['country'] + 1
train.head()
# Out:
#               title   box_office  country                      genre  \
# 0  12 Years a Slave  $50,628,650        2  Biography, Drama, History
# 1            2 Guns  $73,500,000        1   Action, Comedy, Thriller
# 2         21 & Over  $25,675,765        1                     Comedy
# 3                42  $95,001,343        1    Biography, Drama, Sport
# 4          47 Ronin  $20,518,224        4     Action, Drama, Fantasy
#
#               production rating  runtime
# 0        Fox Searchlight      R  134 min
# 1     Universal Pictures      R  109 min
# 2       Relativity Media      R   93 min
# 3  Warner Bros. Pictures  PG-13  128 min
# 4     Universal Pictures  PG-13  128 min

# %%
train['genre'] = train['genre'].str.count(',')
train['genre'] = train['genre'] + 1
train.head()
# Out:
#               title   box_office  country  genre             production  \
# 0  12 Years a Slave  $50,628,650        2      3        Fox Searchlight
# 1            2 Guns  $73,500,000        1      3     Universal Pictures
# 2         21 & Over  $25,675,765        1      1       Relativity Media
# 3                42  $95,001,343        1      3  Warner Bros. Pictures
# 4          47 Ronin  $20,518,224        4      3     Universal Pictures
#
#   rating  runtime
# 0      R  134 min
# 1      R  109 min
# 2      R   93 min
# 3  PG-13  128 min
# 4  PG-13  128 min

# %%
train['rating'].value_counts()
# Out:
# R            124
# PG-13         77
# PG            23
# Not Rated     18
# Unrated        4
# TV-MA          2
# NOT RATED      1
# G              1
# Name: rating, dtype: int64

# %%
train['rating'] = train['rating'].str.replace('Not Rated', 'Unrated')
train.head()
# Out:
#               title   box_office  country  genre             production  \
# 0  12 Years a Slave  $50,628,650        2      3        Fox Searchlight
# 1            2 Guns  $73,500,000        1      3     Universal Pictures
# 2         21 & Over  $25,675,765        1      1       Relativity Media
# 3                42  $95,001,343        1      3  Warner Bros. Pictures
# 4          47 Ronin  $20,518,224        4      3     Universal Pictures
#
#   rating  runtime
# 0      R  134 min
# 1      R  109 min
# 2      R   93 min
# 3  PG-13  128 min
# 4  PG-13  128 min

# %%
train['rating'] = train['rating'].fillna('Unrated')

# %%
train['rating'].value_counts()
# Out:
# R            124
# PG-13         77
# Unrated       32
# PG            23
# TV-MA          2
# NOT RATED      1
# G              1
# Name: rating, dtype: int64

# %%
train['runtime'] = train['runtime'].astype(str)

# %%
train['runtime'] = train['runtime'].apply(lambda x: x.replace(' min',''))
train.head()
# Out:
#               title   box_office  country  genre             production  \
# 0  12 Years a Slave  $50,628,650        2      3        Fox Searchlight
# 1            2 Guns  $73,500,000        1      3     Universal Pictures
# 2         21 & Over  $25,675,765        1      1       Relativity Media
# 3                42  $95,001,343        1      3  Warner Bros. Pictures
# 4          47 Ronin  $20,518,224        4      3     Universal Pictures
#
#   rating runtime
# 0      R     134
# 1      R     109
# 2      R      93
# 3  PG-13     128
# 4  PG-13     128

# %%
train['runtime'] = train['runtime'].apply(lambda x: x.replace('nan','0'))
train.head()
# Out:
#               title   box_office  country  genre             production  \
# 0  12 Years a Slave  $50,628,650        2      3        Fox Searchlight
# 1            2 Guns  $73,500,000        1      3     Universal Pictures
# 2         21 & Over  $25,675,765        1      1       Relativity Media
# 3                42  $95,001,343        1      3  Warner Bros. Pictures
# 4          47 Ronin  $20,518,224        4      3     Universal Pictures
#
#   rating runtime
# 0      R     134
# 1      R     109
# 2      R      93
# 3  PG-13     128
# 4  PG-13     128

# %%
train['runtime'] = train['runtime'].astype(int)

# %%
train.production.value_counts()
# Out:
# Warner Bros. Pictures     14
# IFC Films                 12
# Sony Pictures             11
# 20th Century Fox          11
# Walt Disney Pictures      10
#                           ..
# Paramount                  1
# DreamWorks Animation       1
# Paramount Pictures/MGM     1
# Hightop Releasing          1
# FilmBuff                   1
# Name: production, Length: 92, dtype: int64

# %%
train['production'] = train['production'].fillna('NaN')

# %%
train['box_office'] = train['box_office'].apply(lambda x: x.replace('$',''))
train.head()
# Out:
#               title  box_office  country  genre             production rating  \
# 0  12 Years a Slave  50,628,650        2      3        Fox Searchlight      R
# 1            2 Guns  73,500,000        1      3     Universal Pictures      R
# 2         21 & Over  25,675,765        1      1       Relativity Media      R
# 3                42  95,001,343        1      3  Warner Bros. Pictures  PG-13
# 4          47 Ronin  20,518,224        4      3     Universal Pictures  PG-13
#
#    runtime
# 0      134
# 1      109
# 2       93
# 3      128
# 4      128

# %%
train['box_office'] = train['box_office'].apply(lambda x: x.replace(',',''))
train.head()
# Out:
#               title box_office  country  genre             production rating  \
# 0  12 Years a Slave   50628650        2      3        Fox Searchlight      R
# 1            2 Guns   73500000        1      3     Universal Pictures      R
# 2         21 & Over   25675765        1      1       Relativity Media      R
# 3                42   95001343        1      3  Warner Bros. Pictures  PG-13
# 4          47 Ronin   20518224        4      3     Universal Pictures  PG-13
#
#    runtime
# 0      134
# 1      109
# 2       93
# 3      128
# 4      128

# %%
train['box_office'] = train['box_office'].astype(int)
train.head()
# Out:
#               title  box_office  country  genre             production rating  \
# 0  12 Years a Slave    50628650        2      3        Fox Searchlight      R
# 1            2 Guns    73500000        1      3     Universal Pictures      R
# 2         21 & Over    25675765        1      1       Relativity Media      R
# 3                42    95001343        1      3  Warner Bros. Pictures  PG-13
# 4          47 Ronin    20518224        4      3     Universal Pictures  PG-13
#
#    runtime
# 0      134
# 1      109
# 2       93
# 3      128
# 4      128

# %%
train.dtypes
# Out:
# title         object
# box_office     int32
# country        int64
# genre          int64
# production    object
# rating        object
# runtime        int32
# dtype: object

# %%
train.dtypes
# Out:
# title         object
# box_office     int32
# country        int64
# genre          int64
# production    object
# rating        object
# runtime        int32
# dtype: object

# %%
train['year'] = 2013

# %%
train.to_csv('../data/train_data_2013.csv', index=False)

# %%
train = train.sort_values(by=['box_office'], ascending=False)

# %%
train.head()
# Out:
#                                title  box_office  country  genre  \
# 105                       Iron Man 3   408992272        1      3
# 75                            Frozen   400736600        1      6
# 60                   Despicable Me 2   368049635        3      6
# 212  The Hunger Games: Catching Fire   336663349        1      4
# 126                     Man of Steel   291021565        2      3
#
#                 production rating  runtime  year
# 105   Walt Disney Pictures  PG-13      130  2013
# 75    Walt Disney Pictures     PG      102  2013
# 60      Universal Pictures     PG       98  2013
# 212        Lionsgate Films  PG-13      146  2013
# 126  Warner Bros. Pictures  PG-13      143  2013

# %%
train.iloc[:20, 1]=1

# %%
train.head()
# Out:
#                                title  box_office  country  genre  \
# 105                       Iron Man 3           1        1      3
# 75                            Frozen           1        1      6
# 60                   Despicable Me 2           1        3      6
# 212  The Hunger Games: Catching Fire           1        1      4
# 126                     Man of Steel           1        2      3
#
#                 production rating  runtime  year
# 105   Walt Disney Pictures  PG-13      130  2013
# 75    Walt Disney Pictures     PG      102  2013
# 60      Universal Pictures     PG       98  2013
# 212        Lionsgate Films  PG-13      146  2013
# 126  Warner Bros. Pictures  PG-13      143  2013

# %%
train.iloc[20:,1]=0

# %%
train.head()
# Out:
#                                title  box_office  country  genre  \
# 105                       Iron Man 3           1        1      3
# 75                            Frozen           1        1      6
# 60                   Despicable Me 2           1        3      6
# 212  The Hunger Games: Catching Fire           1        1      4
# 126                     Man of Steel           1        2      3
#
#                 production rating  runtime  year
# 105   Walt Disney Pictures  PG-13      130  2013
# 75    Walt Disney Pictures     PG      102  2013
# 60      Universal Pictures     PG       98  2013
# 212        Lionsgate Films  PG-13      146  2013
# 126  Warner Bros. Pictures  PG-13      143  2013

# %%
train.to_csv('../data/train.log_data_2013.csv', index=False)
