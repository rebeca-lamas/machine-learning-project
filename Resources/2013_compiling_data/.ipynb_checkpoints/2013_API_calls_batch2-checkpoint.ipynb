# %%
import pandas as pd
import requests
import json
import time
from pprint import pprint
from config import API_KEY

# %%
data = pd.read_csv('../data/titles_2013_batch2.csv')
df =  data.count()
df
# Out:
# title    1000
# dtype: int64

# %%
title_id = []
box_office_list = []
country_list = []
genre_list = []
director_list = []
metascore_list = []
production_list = []
rating_list = []
IMDB_rating_list = [] 
rotten_tomatoes_rating_list = []
runtime_list = []
title_list = []
type_list = []
imdb_votes_list = []

# %%
movies = data['title']
total_movies = len(movies)

# %%
for i in range(total_movies):
    movie = movies[i]
    url = "http://www.omdbapi.com/?i=" + movie + "&apikey=" + API_KEY
    response = (requests.get(url).text)
    response_json = json.loads(response)
    print('-------------------')
    print(f'movie id {movie}')
    print('-------------------')
    pprint(response_json)
    
    try:
        box_office_list.append(response_json['BoxOffice'])
        country_list.append(response_json['Country'])
        genre_list.append(response_json['Genre'])
        director_list.append(response_json['Director'])
        metascore_list.append(response_json['Metascore'])
        production_list.append(response_json['Production'])
        rating_list.append(response_json['Rated'])
        IMDB_rating_list.append(response_json['imdbRating'])
        try:
            if not response_json['Ratings']:
                rotten_tomatoes_rating_list.append('NA')
            elif response_json['Ratings'][0]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][0]['Value'])
            elif response_json['Ratings'][1]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][1]['Value'])
            else:
                rotten_tomatoes_rating_list.append('NA')
        except IndexError:
            rotten_tomatoes_rating_list.append('NA')
        runtime_list.append(response_json['Runtime'])
        title_list.append(response_json['Title'])
        type_list.append(response_json['Type'])
        imdb_votes_list.append(response_json['imdbVotes'])
        title_id.append(response_json['imdbID'])
    except KeyError:
        pass
    time.sleep(1)
# Out:
# -------------------
# movie id tt2075318
# -------------------
# {'Actors': 'Madeline Zima, Joel David Moore, Abraham Benrubi, Logan Agayan',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Stuart Acher',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'English',
#  'Metascore': '43',
#  'Plot': 'Stuck in a traffic jam after a one night stand a guy and girl '
#          'recount the night before through flashbacks.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTY2NTQ0MDE4MV5BMl5BanBnXkFtZTgwNjQwNDM1MDE@._V1_SX300.jpg',
#  'Production': 'Stuck Productions LLC',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '60%'},
#              {'Source': 'Metacritic', 'Value': '43/100'}],
#  'Released': '10 Oct 2014',
#  'Response': 'True',
#  'Runtime': '83 min',
#  'Title': '#Stuck',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Stuart Acher, Neil Pollner (story by), Dena Waxman (story by)',
#  'Year': '2014',
#  'imdbID': 'tt2075318',
#  'imdbRating': '5.6',
#  'imdbVotes': '1,020'}
# -------------------
# movie id tt2477324
# -------------------
# {'Actors': 'Katelynn Tonguis, Jeremy Schuetze, Emily Lawrence, Scott Stawicki',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jeffrey Coghlan',
#  'Genre': 'Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': '#iKllr',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'I. Nonymous',
#  'Year': '2014',
#  'imdbID': 'tt2477324',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2106284
# -------------------
# {'Actors': 'Ross Patterson, Jessie Wiseman, Seth Grossman, Lauren Aboulafia',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Seth Grossman',
#  'Genre': 'Action, Adventure, Comedy, Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When Ross is diagnosed with terminal brain cancer and given six '
#          'weeks to live, his newly engaged older brother Seth offers to spend '
#          'his $50,000 wedding fund on a final trip of a lifetime. ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTY3OTI0NjY0Ml5BMl5BanBnXkFtZTgwMjUzNjQ2MDE@._V1_SX300.jpg',
#  'Production': 'FilmBuff',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.8/10'}],
#  'Released': '14 Jan 2014',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': '$50K and a Call Girl: A Love Story',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Seth Grossman, Ross Patterson',
#  'Year': '2014',
#  'imdbID': 'tt2106284',
#  'imdbRating': '6.8',
#  'imdbVotes': '1,826'}
# -------------------
# movie id tt5135646
# -------------------
# {'Actors': 'Phillip Cohen',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Hans Hernke, Randy Kent',
#  'Genre': 'Short, Comedy, Family',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'Santa comes to visit a home on Christmas Eve but has a craving for '
#          'something other then Milk with his cookies!',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '75 min',
#  'Title': "'Twas The Night Before Christmas",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Hans Hernke (story), Hans Hernke',
#  'Year': '2014',
#  'imdbID': 'tt5135646',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4533680
# -------------------
# {'Actors': 'Michael Kinzer, Ulrich Jungblut, Heike Zwetz, Isabelle Stolzenburg',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'Germany, New Zealand, Austria, USA',
#  'DVD': 'N/A',
#  'Director': 'Niko Kühnel',
#  'Genre': 'Comedy, Crime, Drama',
#  'Language': 'German',
#  'Metascore': 'N/A',
#  'Plot': 'Two shady guys in dark suits. A mysterious girl out of nowhere. A '
#          'gloomy figure in a parking garage. All of them looking for the same '
#          'thing: A black folder from New York. And all of them ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Sep 2014',
#  'Response': 'True',
#  'Runtime': '89 min',
#  'Title': '...and the Rest is History',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Niko Kühnel',
#  'Year': '2014',
#  'imdbID': 'tt4533680',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2388856
# -------------------
# {'Actors': 'Lexi Giovagnoli, Justin Ray, Rae Latt, Poonam Basu',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '29 Jul 2014',
#  'Director': 'Adam Deyoe',
#  'Genre': 'Drama, Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When a seventeen-year old aspiring dancer is uprooted mid-semester '
#          'of her senior year, she finds herself in a small East Coast high '
#          'school where her heart will be divided between two boys, ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjIzMzcxODYzOV5BMl5BanBnXkFtZTgwNjE0NTg0MDE@._V1_SX300.jpg',
#  'Production': 'WARNER BROTHERS PICTURES',
#  'Rated': 'G',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.8/10'}],
#  'Released': '21 Jan 2014',
#  'Response': 'True',
#  'Runtime': '89 min',
#  'Title': '1 Chance 2 Dance',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jake Helgren (screenplay), Elizabeth Snoderly (story)',
#  'Year': '2014',
#  'imdbID': 'tt2388856',
#  'imdbRating': '4.8',
#  'imdbVotes': '499'}
# -------------------
# movie id tt2134170
# -------------------
# {'Actors': 'Jena Malone, JT Alexander, Damon Alexander, Joe Mantegna',
#  'Awards': '1 win.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Michael C. Martin',
#  'Genre': 'Crime, Thriller',
#  'Language': 'English',
#  'Metascore': '37',
#  'Plot': 'A story about two lifelong criminals who maneuver through the shady '
#          'underbelly of Los Angeles in search of wealth, love and redemption.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjQyNTIyNDU0Ml5BMl5BanBnXkFtZTgwNjA1NDkxNjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Unrated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.7/10'},
#              {'Source': 'Metacritic', 'Value': '37/100'}],
#  'Released': '24 Jul 2015',
#  'Response': 'True',
#  'Runtime': '91 min',
#  'Title': '10 Cent Pistol',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael C. Martin',
#  'Year': '2014',
#  'imdbID': 'tt2134170',
#  'imdbRating': '4.7',
#  'imdbVotes': '434'}
# -------------------
# movie id tt2402917
# -------------------
# {'Actors': 'Elodie Yung, Janet Montgomery, Billy Campbell, Chelsey Crisp',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Gil Junger',
#  'Genre': 'Comedy, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Two teens unexpectedly fall in love, just before they are about to '
#          'kill themselves.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTJjYjg0MTMtMjYwZC00YTM2LWFkMWEtYjBiNmM5YWZjODlmL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMzg3MjA0NjM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.9/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '10 Things I Hate About Life',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jeanette Issa, Gil Junger, Tim McGrath',
#  'Year': '2014',
#  'imdbID': 'tt2402917',
#  'imdbRating': '6.9',
#  'imdbVotes': '22'}
# -------------------
# movie id tt3530690
# -------------------
# {'Actors': 'John Schneider, Peter Wingfield, James Harvey Ward, Kim Myers',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '03 Nov 2015',
#  'Director': 'Eric Small',
#  'Genre': 'Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Ten thousand days ago, Comet 23 struck Earth with the magnitude of '
#          'all the nuclear weapons in the world sending the planet into a deep '
#          'freeze. Now, 27 years in the future, those who survived are locked '
#          'in an epic battle of life or death.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk5OTQ4NDI1MV5BMl5BanBnXkFtZTgwODg2NTU5MjE@._V1_SX300.jpg',
#  'Production': 'Bahr Productions',
#  'Rated': 'TV-PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.7/10'}],
#  'Released': '23 Nov 2014',
#  'Response': 'True',
#  'Runtime': '91 min',
#  'Title': '10,000 Days',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Eric Small',
#  'Year': '2014',
#  'imdbID': 'tt3530690',
#  'imdbRating': '2.7',
#  'imdbVotes': '595'}
# -------------------
# movie id tt3488056
# -------------------
# {'Actors': 'Cameron Richardson, Henry Ian Cusick, Malcolm Barrett, Jeffrey '
#            'Jones',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'David Gidali',
#  'Genre': 'Drama, Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Los Angeles is about to be hit by a devastating earthquake, and time '
#          'is running out to save the city from imminent danger.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTM4MWEyMzUtODFiNC00OGVjLWEzNTItY2E1YmYyNmNmZjZlXkEyXkFqcGdeQXVyNDE5MTU2MDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.5/10'}],
#  'Released': '11 Oct 2014',
#  'Response': 'True',
#  'Runtime': '88 min',
#  'Title': '10.0 Earthquake',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'J. Greg Abbott (additional dialogue), Alex Greenfield, Nancy '
#            'Leopardi',
#  'Year': '2014',
#  'imdbID': 'tt3488056',
#  'imdbRating': '3.5',
#  'imdbVotes': '1,487'}
# -------------------
# movie id tt3627828
# -------------------
# {'Actors': 'Amy Sanders, Stan Harrington, Alexis Arriaga, Lina Bubisa',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Stan Harrington',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A neighborhood in the Hollywood Hills is terrorized by a group of '
#          'self-described modern day vampires who then collide with a disgraced '
#          'LAPD Detective and his rebellious teenage daughter.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTU0ODQ0MDgzMV5BMl5BanBnXkFtZTgwMDI5MTE0MjE@._V1_SX300.jpg',
#  'Production': 'Xristos Productions',
#  'Rated': 'NOT RATED',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.3/10'}],
#  'Released': '01 May 2014',
#  'Response': 'True',
#  'Runtime': '78 min',
#  'Title': '101: Modern Los Angeles Vampires',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Stan Harrington',
#  'Year': '2014',
#  'imdbID': 'tt3627828',
#  'imdbRating': '4.3',
#  'imdbVotes': '11'}
# -------------------
# movie id tt3073898
# -------------------
# {'Actors': 'Bruce Davison, Erin Cahill, Kate Vernon, Ryan Carlberg',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '15 Sep 2014',
#  'Director': 'David Rountree',
#  'Genre': 'Comedy, Romance, Sport',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "With baseball being the last thing on these player's minds, and "
#          'dealing with one of the longest losing streaks in college history, '
#          'the team of misfits comes to the realization that the ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk4OTYzMzk0MV5BMl5BanBnXkFtZTgwNzg4NDA0MjE@._V1_SX300.jpg',
#  'Production': 'Freestyle Releasing',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.3/10'}],
#  'Released': '12 Sep 2014',
#  'Response': 'True',
#  'Runtime': '118 min',
#  'Title': '108 Stitches',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Josh Blue (additional material), Jake Katofsky (head writer), Jeff '
#            'Katofsky (contributing writer), David Rountree (head writer)',
#  'Year': '2014',
#  'imdbID': 'tt3073898',
#  'imdbRating': '4.3',
#  'imdbVotes': '117'}
# -------------------
# movie id tt3187586
# -------------------
# {'Actors': 'Austin Michael Coleman, Jennifer Bhagwandin, Martin De Boer, '
#            'Jeremiah Flemming',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Netherlands',
#  'DVD': 'N/A',
#  'Director': 'Janusz Madej',
#  'Genre': 'Crime, Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Retired US Marine awakes in a hotel room in Amsterdam. His '
#          'girlfriend is nowhere to be found. A mysterious note sends him in '
#          'search of her, on a journey through the shady streets of Amsterdam, '
#          "only to discover the secret of '11.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTkzMzgxNzY0Ml5BMl5BanBnXkFtZTgwMDY3NjY5MDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'}],
#  'Released': '11 Nov 2014',
#  'Response': 'True',
#  'Runtime': '87 min',
#  'Title': '11',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Janusz Madej',
#  'Year': '2014',
#  'imdbID': 'tt3187586',
#  'imdbRating': '6.2',
#  'imdbVotes': '5'}
# -------------------
# movie id tt2818632
# -------------------
# {'Actors': 'David Carter-T, Lance Charnow, Elizabeth Colunga, Mick Green',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Dan Brown Jr.',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'This all-American couple moves into their first apartment together. '
#          'What is first considered the deal of a lifetime quickly turns into a '
#          'curse that they could have never imagined.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjAyNjIxNTMyNl5BMl5BanBnXkFtZTgwMDU1NDAxMDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'}],
#  'Released': '31 Jan 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '1108',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dan Brown Jr.',
#  'Year': '2014',
#  'imdbID': 'tt2818632',
#  'imdbRating': '6.2',
#  'imdbVotes': '8'}
# -------------------
# movie id tt3579698
# -------------------
# {'Actors': 'Reginald VelJohnson, Vincent Giovagnoli, Grainne McDermott, Lexi '
#            'Giovagnoli',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Charlie Vaughn',
#  'Genre': 'Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'After being assigned to an animal rescue shelter as part of his '
#          'community service by his probation officer, a troubled teenager is '
#          'forced to get into the spirit of the holidays when he is recruited '
#          'to help find homes for twelve unwanted dogs before Christmas.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTc1MmEzNGItYzMzYi00ZDI4LThkNjMtNDA1YWUxMGNlYjNhL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMjc2MDE1MzQ@._V1_SX300.jpg',
#  'Production': 'Marvista Entertainment',
#  'Rated': 'UNRATED',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.1/10'}],
#  'Released': '28 Nov 2014',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': '12 Dog Days Till Christmas',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jake Helgren (screenplay), Bret Kofford (screenplay), Bret Kofford '
#            '(story), Elizabeth Snoderly (story)',
#  'Year': '2014',
#  'imdbID': 'tt3579698',
#  'imdbRating': '5.1',
#  'imdbVotes': '265'}
# -------------------
# movie id tt4386156
# -------------------
# {'Actors': 'Marcus Alexander, Cate Allen, James Bellis, Armand Belluccio',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'J. Cameron Keenum',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "12 Til Dusk is the story of a young father and husband who's trying "
#          'to make amends for his dark past. When the safety of his family is '
#          'threatened, he is unwillingly thrust back into the ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '03 Oct 2014',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': '12 Til Dusk',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'J. Cameron Keenum',
#  'Year': '2014',
#  'imdbID': 'tt4386156',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3977920
# -------------------
# {'Actors': 'Aleiszja Maeva, Kai Nonamay, Jeremiah Sanchez, Christopher '
#            'Stephens',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Raven Low Clouds',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A couple travels to see the reunion concert of Led Zeppelin and '
#          'discover more about themselves, and life, as they spend the nigh '
#          'together.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '18 Jul 2014',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': '12/10/07: A Dogme 95 film',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Raven Low Clouds',
#  'Year': '2014',
#  'imdbID': 'tt3977920',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3168890
# -------------------
# {'Actors': "Jason Winn 'J.B. Destiny' Bareford, Bill McLaughlin, Seth "
#            'Gontkovic, Gabe DeRose-Elbaum',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'D. Max Walters',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'In 1753 along a lake shore in western Pennsylvania, a group of '
#          'inhabitants became stark raving lunatics and murdered one another '
#          "for no apparent reason. 260 years later, it's happening again.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc3NjExODk5MF5BMl5BanBnXkFtZTgwMzE5OTIyMDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Apr 2015',
#  'Response': 'True',
#  'Runtime': '75 min',
#  'Title': '13 Score',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Christian Bareford (original story), Christian Bareford, James '
#            "'Doc' Herrmann, James 'Doc' Herrmann, Jennifer Walters, Jennifer "
#            'Walters',
#  'Year': '2014',
#  'imdbID': 'tt3168890',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2059171
# -------------------
# {'Actors': 'Mark Webber, Devon Graye, Tom Bower, Rutina Wesley',
#  'Awards': '3 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '16 Jun 2014',
#  'Director': 'Daniel Stamm',
#  'Genre': 'Horror, Thriller',
#  'Language': 'English',
#  'Metascore': '44',
#  'Plot': 'A cryptic phone call sets off a dangerous game of risks for Elliot, '
#          'a down-on-his luck salesman. The game promises increasing rewards '
#          'for completing 13 tasks, each more sinister than the last.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzA0NDIwNjI3OF5BMl5BanBnXkFtZTgwMDMzNzE0MTE@._V1_SX300.jpg',
#  'Production': 'Radius-TWC',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '65%'},
#              {'Source': 'Metacritic', 'Value': '44/100'}],
#  'Released': '11 Apr 2014',
#  'Response': 'True',
#  'Runtime': '93 min',
#  'Title': '13 Sins',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'David Birke (screenplay by), Daniel Stamm (screenplay by), '
#            'Chookiat Sakveerakul (source Material: "13: Game of Death" by), '
#            'Eakasit Thairaat (source material: "13: Game of Death" by)',
#  'Year': '2014',
#  'imdbID': 'tt2059171',
#  'imdbRating': '6.3',
#  'imdbVotes': '30,391'}
# -------------------
# movie id tt4104212
# -------------------
# {'Actors': 'Emily Dennis, Michael Wetherbee, Johanna Anttila, Liam Wildes',
#  'Awards': '7 wins & 5 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Joseph Villapaz',
#  'Genre': 'Drama, Romance, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A diverse cast of characters deals with life changing issues in a '
#          'variety of stories tied together by the location they all pass '
#          'through.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc5OTk2OTQ4OF5BMl5BanBnXkFtZTgwODUxODIzNTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.2/10'}],
#  'Released': '19 Oct 2014',
#  'Response': 'True',
#  'Runtime': '54 min',
#  'Title': '14 Days',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joseph Villapaz (screenplay)',
#  'Year': '2014',
#  'imdbID': 'tt4104212',
#  'imdbRating': '7.2',
#  'imdbVotes': '15'}
# -------------------
# movie id tt3387980
# -------------------
# {'Actors': 'Steve Bryant, Dori Cagle, Chase Dudley, Vergena Fields',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Chase Dudley',
#  'Genre': 'Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An interracial couple faces the struggles of racist family members.',
#  'Poster': 'https://ia.media-imdb.com/images/M/MV5BYWVkOTIzZDItZDYyMS00MTE4LTk3MmEtMzM1YTJhMDcxNjk3L2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMTY4OTI0MDk@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.5/10'}],
#  'Released': '24 Jan 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '14/88',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'James William Smith',
#  'Year': '2014',
#  'imdbID': 'tt3387980',
#  'imdbRating': '8.5',
#  'imdbVotes': '6'}
# -------------------
# movie id tt1212054
# -------------------
# {'Actors': 'Aubrey Reynolds, Shona Kay, Brad Johnson, Mason D. Davis',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '02 Dec 2014',
#  'Director': 'Brian Brough',
#  'Genre': 'Adventure',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A modern day adventure about the search for special stones touched '
#          'by the hand of the Lord and brought to the Americas.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTY0ODUxNzAyOF5BMl5BanBnXkFtZTgwMTQ1MDE1MjE@._V1_SX300.jpg',
#  'Production': 'Candlelight Media Group',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.9/10'}],
#  'Released': '01 Oct 2014',
#  'Response': 'True',
#  'Runtime': '93 min',
#  'Title': '16 Stones',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Brittany Wiscombe (screenplay)',
#  'Year': '2014',
#  'imdbID': 'tt1212054',
#  'imdbRating': '4.9',
#  'imdbVotes': '64'}
# -------------------
# movie id tt3044904
# -------------------
# {'Actors': 'Leland B. Martin, Charles Wilson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Derrick Hammond',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'This is a Danish series focusing on the second Schleswig War; one of '
#          'the the most traumatic events in the modern history of Denmark.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDMyMDIwZTQtNDUwMi00ZTdhLWJhODAtYmFiYmM5ZjE4MjVhXkEyXkFqcGdeQXVyNzkyNjQxODU@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '12 Oct 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '1864',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Derrick Hammond (story), Zadia Ife, Devon Starshooterz (story)',
#  'Year': '2014',
#  'imdbID': 'tt3044904',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3959542
# -------------------
# {'Actors': "Bob Fanucchi, Greg Ingram, Dennis O'Neill",
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'William Booth',
#  'Genre': 'Action, Adventure, Western',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'In 1870, a gunfighter with a rattlesnake temper, Cletus Lebow, is '
#          'hell-bent on gunning down Judge White to seek out his own personal '
#          'revenge. He tracks down the Judge on the road to Jerome ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '77 min',
#  'Title': '1870 Texas',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'William Booth, David Edwin Read',
#  'Year': '2014',
#  'imdbID': 'tt3959542',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2431420
# -------------------
# {'Actors': 'Sarah Clark, Bobby Bracamontez, Natalie Wilemon, Scott K. Butler',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Edward St. Joseph',
#  'Genre': 'Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjA5NDcyNDg4Nl5BMl5BanBnXkFtZTcwMDE3MDA2OA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '21 Nov 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '2 & Twenty-Six *Reprise*',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Edward St. Joseph (script writer)',
#  'Year': '2014',
#  'imdbID': 'tt2431420',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2731970
# -------------------
# {'Actors': 'Marcela Macias, Michele Hicks, Dee Wallace, Ivan Shaw',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '13 Oct 2015',
#  'Director': 'Stanley Yung',
#  'Genre': 'Horror, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A young couple moves into their perfect home, but when they '
#          'discovered that they will soon become parents, things begin to fall '
#          'apart.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTUxNDA4NTk4MV5BMl5BanBnXkFtZTcwMjA1Nzg0OQ@@._V1_SX300.jpg',
#  'Production': 'Plus Entertainment Inc.',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.8/10'}],
#  'Released': '05 Sep 2014',
#  'Response': 'True',
#  'Runtime': '91 min',
#  'Title': '2 Bedroom 1 Bath',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Stanley Yung, Stanley Yung',
#  'Year': '2014',
#  'imdbID': 'tt2731970',
#  'imdbRating': '3.8',
#  'imdbVotes': '299'}
# -------------------
# movie id tt2516610
# -------------------
# {'Actors': 'Danny Trejo, Kinga Philipps, Frank Krueger, Tiffany Adams',
#  'Awards': '3 wins & 6 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '18 Mar 2014',
#  'Director': 'Marc Clebanoff',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Below the streets of New York is a dark and dangerous world hidden '
#          'in the shadows of abandoned subway tunnels and miles of forgotten '
#          'infrastructure. When a young documentary filmmaker goes ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjM1MDc5MjY3Nl5BMl5BanBnXkFtZTgwNTA4OTYxMjE@._V1_SX300.jpg',
#  'Production': 'Odyssey Motion Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.6/10'}],
#  'Released': '21 Jan 2016',
#  'Response': 'True',
#  'Runtime': '91 min',
#  'Title': '20 Ft Below: The Darkness Descending',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Frank Krueger',
#  'Year': '2014',
#  'imdbID': 'tt2516610',
#  'imdbRating': '2.6',
#  'imdbVotes': '525'}
# -------------------
# movie id tt4181324
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Brian J. Leitten',
#  'Genre': 'Sport',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The 2013 Gold Rush Expedition Race features an international field '
#          'of 56 elite athletes tackling a grueling 275-mile course through the '
#          'California wilderness as they test their limits in the toughest '
#          'competition in North America.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '68 min',
#  'Title': '2013 Gold Rush Expedition Race',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Adam Willke (script writer)',
#  'Year': '2013',
#  'imdbID': 'tt4181324',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4591668
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'N/A',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'N/A',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'Compilation of the best Short Films on Fly fishing in 2014. All '
#          'Aspect of Fly Fishing are covered from Alaska Salmon to Florida '
#          'Tarpon.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjM4Mzk0NTMxMF5BMl5BanBnXkFtZTgwMTA4NDcyNTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Jan 2014',
#  'Response': 'True',
#  'Runtime': '78 min',
#  'Title': '2014 Fly Fishing Film Tour',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2014',
#  'imdbID': 'tt4591668',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4113790
# -------------------
# {'Actors': 'Borkety Boyefio, Massiel Checo, Gary Davis, Divendre Hernandez',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Gary Davis',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'While trying to control the balance of power, a young and very '
#          'beautiful ex-soldier is saved by a handsome fisherman and his '
#          'teenage companion. Trouble arises when she overstays her welcome...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODU1OTAwZWQtMzQxMi00N2QwLThkYTUtOTZmMjM3NDVmMzM0XkEyXkFqcGdeQXVyNTAwNDI0NTU@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '2053 Two Girls, a Dragon & a Fisherman',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Gary Davis (screenplay), Chin Li (story)',
#  'Year': '2014',
#  'imdbID': 'tt4113790',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2979366
# -------------------
# {'Actors': 'Max Hambleton, Whitney Rose Pynn, Mickey River, Eduardo Roman',
#  'Awards': '6 wins.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kathleen Behun',
#  'Genre': 'Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Three filmmakers embark on a paranormal challenge by barricading '
#          'themselves in a house so haunted, no one has been able to live in '
#          'for more than 21 days.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk0MjQ2MDI1Nl5BMl5BanBnXkFtZTgwNDAzMDEwMDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'TV-MA',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.5/10'}],
#  'Released': '25 Oct 2014',
#  'Response': 'True',
#  'Runtime': '89 min',
#  'Title': '21 Days',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kathleen Behun',
#  'Year': '2014',
#  'imdbID': 'tt2979366',
#  'imdbRating': '4.5',
#  'imdbVotes': '459'}
# -------------------
# movie id tt3004572
# -------------------
# {'Actors': 'Revon Yousif, Karan Beaty, Don Joseph Chase, Joseph a Davis',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kyle Misak',
#  'Genre': 'Action, Adventure, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Three friends exploring an abandoned facility discover a device that '
#          'holds information about the future. Upon finding the device, they '
#          'must learn how to use it while also striving to keep it out of the '
#          'wrong hands.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BM2M0ODQ0NDYtMGUzNi00MDdjLWI0MzYtY2RjYTdlYjk5NDFiXkEyXkFqcGdeQXVyMzM2OTQwMDY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.0/10'}],
#  'Released': '23 Feb 2014',
#  'Response': 'True',
#  'Runtime': '56 min',
#  'Title': '2101',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Clayton Seager (lead writer)',
#  'Year': '2014',
#  'imdbID': 'tt3004572',
#  'imdbRating': '4.0',
#  'imdbVotes': '69'}
# -------------------
# movie id tt4010308
# -------------------
# {'Actors': 'Bill Baughman, Caleb Baughman, Chris Baughman, Cheryl Berkler',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Mark Thoma',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An opening type-on warning summary followed by talking heads '
#          'describing events leading up to civilization collapse. The main '
#          'narrator of the film then tells how she will go out and search for '
#          'survivors and document their comments on video.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMGQyNTBlOTktZTBiOC00MjAyLTk0MDAtOGMyYjI2MzY5YjE5XkEyXkFqcGdeQXVyNTA0NzUyNDQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.8/10'}],
#  'Released': '03 Sep 2014',
#  'Response': 'True',
#  'Runtime': '97 min',
#  'Title': '22 After',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Mark Thoma',
#  'Year': '2014',
#  'imdbID': 'tt4010308',
#  'imdbRating': '7.8',
#  'imdbVotes': '12'}
# -------------------
# movie id tt2294449
# -------------------
# {'Actors': 'Jonah Hill, Channing Tatum, Peter Stormare, Wyatt Russell',
#  'Awards': '7 wins & 24 nominations.',
#  'BoxOffice': '$154,295,930',
#  'Country': 'USA',
#  'DVD': '18 Nov 2014',
#  'Director': 'Phil Lord, Christopher Miller',
#  'Genre': 'Action, Comedy, Crime',
#  'Language': 'English',
#  'Metascore': '71',
#  'Plot': 'After making their way through high school (twice), big changes are '
#          'in store for officers Schmidt and Jenko when they go deep undercover '
#          'at a local college.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTcwNzAxMDU1M15BMl5BanBnXkFtZTgwNDE2NTU1MTE@._V1_SX300.jpg',
#  'Production': 'Sony Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '84%'},
#              {'Source': 'Metacritic', 'Value': '71/100'}],
#  'Released': '13 Jun 2014',
#  'Response': 'True',
#  'Runtime': '112 min',
#  'Title': '22 Jump Street',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Bacall (screenplay), Oren Uziel (screenplay), Rodney '
#            'Rothman (screenplay), Michael Bacall (story), Jonah Hill (story), '
#            'Patrick Hasburgh (television series "21 Jump Street"), Stephen J. '
#            'Cannell (television series "21 Jump Street")',
#  'Year': '2014',
#  'imdbID': 'tt2294449',
#  'imdbRating': '7.0',
#  'imdbVotes': '329,222'}
# -------------------
# movie id tt2304459
# -------------------
# {'Actors': 'Stephen Lang, Alexa PenaVega, Mark Hapka, Max Adler',
#  'Awards': '1 win.',
#  'BoxOffice': '$485,128',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Dylan Baker',
#  'Genre': 'Drama, Family, Sport',
#  'Language': 'English',
#  'Metascore': '45',
#  'Plot': 'When a high school football star is suddenly stricken with '
#          'irreversible total blindness, he must decide whether to live a safe '
#          'handicapped life or bravely return to the life he once knew and the '
#          'sport he still loves.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTYwNjIxOTc4NF5BMl5BanBnXkFtZTgwMTI0MDA5MjE@._V1_SX300.jpg',
#  'Production': 'Ocean Avenue Entertainment',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '36%'},
#              {'Source': 'Metacritic', 'Value': '45/100'}],
#  'Released': '24 Oct 2014',
#  'Response': 'True',
#  'Runtime': '98 min',
#  'Title': '23 Blast',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Bram Hoover, Toni Hoover',
#  'Year': '2014',
#  'imdbID': 'tt2304459',
#  'imdbRating': '6.5',
#  'imdbVotes': '1,618'}
# -------------------
# movie id tt3773506
# -------------------
# {'Actors': 'Leonardo Black, Tone Capone, Nelson J. Davis, Nneka Davis',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jarrell Crump',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Scandalous Relationships,Corrupt Politics,and Revenge is only the '
#          'beginning in this treacherous drama. No one is safe from what lies '
#          'beneath these hard streets.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjk0NjIwMjg4NF5BMl5BanBnXkFtZTgwMzQxOTc5MTE@._V1_SX300.jpg',
#  'Production': 'Alyze Elyse Films',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.5/10'}],
#  'Released': '25 Jul 2014',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': '24 Hours Movie',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Alyze Elyse',
#  'Year': '2014',
#  'imdbID': 'tt3773506',
#  'imdbRating': '5.5',
#  'imdbVotes': '41'}
# -------------------
# movie id tt2172934
# -------------------
# {'Actors': 'Kevin Costner, Amber Heard, Hailee Steinfeld, Connie Nielsen',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, France, Serbia',
#  'DVD': '20 May 2014',
#  'Director': 'McG',
#  'Genre': 'Action, Drama, Thriller',
#  'Language': 'English, French, German, Serbian',
#  'Metascore': '40',
#  'Plot': 'A dying CIA agent trying to reconnect with his estranged daughter is '
#          'offered an experimental drug that could save his life in exchange '
#          'for one last assignment.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzM0MjE0Nzg1N15BMl5BanBnXkFtZTgwODA4ODE4MDE@._V1_SX300.jpg',
#  'Production': 'Relativity Media',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '27%'},
#              {'Source': 'Metacritic', 'Value': '40/100'}],
#  'Released': '21 Feb 2014',
#  'Response': 'True',
#  'Runtime': '117 min',
#  'Title': '3 Days to Kill',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Adi Hasak (screenplay), Luc Besson (screenplay), Luc Besson '
#            '(story)',
#  'Year': '2014',
#  'imdbID': 'tt2172934',
#  'imdbRating': '6.2',
#  'imdbVotes': '83,305'}
# -------------------
# movie id tt2123884
# -------------------
# {'Actors': 'Wes Bentley, Vincent Piazza, Amber Tamblyn',
#  'Awards': 'N/A',
#  'BoxOffice': '$1,279',
#  'Country': 'USA',
#  'DVD': '31 Mar 2015',
#  'Director': 'Gabriel Cowan',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'THE BIG CHILL meets THE GRADUATE. What could have been? What might '
#          'have been? Reunions can be exciting, frustrating, exhilarating, '
#          'nostalgic, one life given over to practicality while ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDM2MjMyMTQ3M15BMl5BanBnXkFtZTgwMDg3OTQxNDE@._V1_SX300.jpg',
#  'Production': 'Monterey Media Inc.',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.3/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '40%'}],
#  'Released': '04 Jan 2014',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': '3 Nights in the Desert',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Adam Chanzit (screenplay)',
#  'Year': '2014',
#  'imdbID': 'tt2123884',
#  'imdbRating': '5.3',
#  'imdbVotes': '1,414'}
# -------------------
# movie id tt4078822
# -------------------
# {'Actors': 'Gregory Lewis, Alan Manzo, Paul Manzo',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Gregory Lewis',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Three homeless men use unconventional methods to panhandle their way '
#          'out of poverty.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '77 min',
#  'Title': '3 Rodents',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Gregory Lewis',
#  'Year': '2014',
#  'imdbID': 'tt4078822',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3743206
# -------------------
# {'Actors': 'Linnea Quigley, Brinke Stevens, Michelle Bauer, Orel De La Mota',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '10 Feb 2015',
#  'Director': 'David DeCoteau',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'ALEXIS, SYLVIA and ELLEN are a trio of legendary scream queens. '
#          'After the head of a motion picture studio invites them out to a very '
#          'special screening in exchange for the possibility of a ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ1NzYzNjM4Nl5BMl5BanBnXkFtZTgwNTI0NjE0NDE@._V1_SX300.jpg',
#  'Production': 'Rapid Heart Pictures',
#  'Rated': 'Unrated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.3/10'}],
#  'Released': '31 Oct 2014',
#  'Response': 'True',
#  'Runtime': '75 min',
#  'Title': '3 Scream Queens',
#  'Type': 'movie',
#  'Website': 'http://www.rapidheart.com/',
#  'Writer': 'Matthew Jason Walsh (screenplay by)',
#  'Year': '2014',
#  'imdbID': 'tt3743206',
#  'imdbRating': '5.3',
#  'imdbVotes': '46'}
# -------------------
# movie id tt3174226
# -------------------
# {'Actors': 'Kristine DeBell, Lisa London, Helene Udy, Eric Diedrich',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '01 Jan 2014',
#  'Director': 'David DeCoteau',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When three best friends from college reunite for their 25th year '
#          'reunion, revenge becomes the order of day.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTU0MzAyOTQzNF5BMl5BanBnXkFtZTgwODkyMjU5MDE@._V1_SX300.jpg',
#  'Production': 'RAPID HEART PICTURES LLC',
#  'Rated': 'NOT RATED',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.4/10'}],
#  'Released': '01 Jan 2014',
#  'Response': 'True',
#  'Runtime': '75 min',
#  'Title': '3 Wicked Witches',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Harvey Shaiman (screenplay)',
#  'Year': '2014',
#  'imdbID': 'tt3174226',
#  'imdbRating': '4.4',
#  'imdbVotes': '30'}
# -------------------
# movie id tt3120560
# -------------------
# {'Actors': 'Robin Andre, Kim Argetsinger, Dante Basco, Dion Basco',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Shedrack Anderson III',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Jimmy and Steven are best friends. They are complete opposites. They '
#          'share everything, a house, bills, friends, and eventually... A '
#          'girlfriend. Steven has been dating Michelle for two years...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '143 min',
#  'Title': "3's a Couple",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dion Basco',
#  'Year': '2014',
#  'imdbID': 'tt3120560',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt1740719
# -------------------
# {'Actors': 'G. Gotham Smith, Jessica Tessier, Russell Rinker, Danni Lang',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'G. Gotham Smith',
#  'Genre': 'Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Three guys, stuck in a life rut, run out of gas in the middle of the '
#          'desert, where they meet magic burros, Shoshone Ghosts, '
#          'fire-breathing zebras, and Hot Spring Chick (a girl with recurring '
#          'relationship problems).',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTY1OTE3NzAyMV5BMl5BanBnXkFtZTcwMTY3MDU3Nw@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.3/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '86 min',
#  'Title': '3.14...',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Sergei Kudriavtsev (story), G. Gotham Smith (story), G. Gotham '
#            'Smith',
#  'Year': '2014',
#  'imdbID': 'tt1740719',
#  'imdbRating': '5.3',
#  'imdbVotes': '15'}
# -------------------
# movie id tt4040616
# -------------------
# {'Actors': 'Ayemere Caleb, Kenneth DeLozier, Desmond Elliot, Vivica A. Fox',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Robert Peters',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Akpos wins a 30-day holiday for two to Atlanta, Georgia. He takes '
#          'his cousin (Richard), an IT specialist on the all-expense paid trip. '
#          'Akpos flings his unique personality, showing-off his ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTI5ZTc4MmUtMDc2MS00NWU3LWEyNWYtMzE3OGUzMTIzZTNmXkEyXkFqcGdeQXVyNjczNjUwOTQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.3/10'}],
#  'Released': '30 Oct 2014',
#  'Response': 'True',
#  'Runtime': '111 min',
#  'Title': '30 Days in Atlanta',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2014',
#  'imdbID': 'tt4040616',
#  'imdbRating': '7.3',
#  'imdbVotes': '87'}
# -------------------
# movie id tt1253863
# -------------------
# {'Actors': 'Sullivan Stapleton, Eva Green, Lena Headey, Hans Matheson',
#  'Awards': '2 wins & 7 nominations.',
#  'BoxOffice': '$91,024,535',
#  'Country': 'USA',
#  'DVD': '24 Jun 2014',
#  'Director': 'Noam Murro',
#  'Genre': 'Action, Drama',
#  'Language': 'English',
#  'Metascore': '48',
#  'Plot': 'Greek general Themistokles leads the charge against invading Persian '
#          'forces led by mortal-turned-god Xerxes and Artemisia, vengeful '
#          'commander of the Persian navy.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTEwNTU2MjAwMDdeQTJeQWpwZ15BbWU3MDk2Njc2Njk@._V1_SX300.jpg',
#  'Production': 'Warner Bros. Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '45%'},
#              {'Source': 'Metacritic', 'Value': '48/100'}],
#  'Released': '07 Mar 2014',
#  'Response': 'True',
#  'Runtime': '102 min',
#  'Title': '300: Rise of an Empire',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Zack Snyder (screenplay), Kurt Johnstad (screenplay), Frank Miller '
#            '(graphic novel "Xerxes")',
#  'Year': '2014',
#  'imdbID': 'tt1253863',
#  'imdbRating': '6.2',
#  'imdbVotes': '269,785'}
# -------------------
# movie id tt2357144
# -------------------
# {'Actors': 'Tricia Helfer, Scottie Thompson, Scott Wolf, Kate Nauta',
#  'Awards': '7 wins & 1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '29 Sep 2015',
#  'Director': 'Randall Batinkoff',
#  'Genre': 'Mystery, Romance, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A rocker makes a pact to kill himself on his 37th birthday. 12 weeks '
#          'before the release of his final album and the end of his life, he '
#          'meets and falls in love with a woman who has a dark secret of her '
#          'own.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTEzMTIxODM5NzheQTJeQWpwZ15BbWU4MDA0ODExNDIx._V1_SX300.jpg',
#  'Production': 'Gravitas Ventures',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'}],
#  'Released': '08 Aug 2014',
#  'Response': 'True',
#  'Runtime': '94 min',
#  'Title': '37',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Randall Batinkoff, Jesse Stratton',
#  'Year': '2014',
#  'imdbID': 'tt2357144',
#  'imdbRating': '6.3',
#  'imdbVotes': '126'}
# -------------------
# movie id tt2475352
# -------------------
# {'Actors': 'Paul Alexandro, Marina Vidal, Julio Lousav, Giselle Torres',
#  'Awards': '10 wins & 7 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'David Jaure Rosenbaum',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Based on real life events drama of the homeless situation during the '
#          'late 2000s US recession.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTg4MDc0MTE4NF5BMl5BanBnXkFtZTgwNDY5NzgxNzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'NOT RATED',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.1/10'}],
#  'Released': '16 Nov 2015',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': '3:13 Three Thirteen',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'David Jaure Rosenbaum, David Jaure Rosenbaum',
#  'Year': '2014',
#  'imdbID': 'tt2475352',
#  'imdbRating': '8.1',
#  'imdbVotes': '37'}
# -------------------
# movie id tt3740162
# -------------------
# {'Actors': 'Maytal Angel, Catherine Corcoran, Sarah Hartshorne, Rick Kariolic',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Rick Kariolic',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
# ...
#  'Released': '19 Aug 2014',
#  'Response': 'True',
#  'Runtime': '120 min',
#  'Title': 'Streets of Hope',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Skin Mead',
#  'Year': '2014',
#  'imdbID': 'tt1954442',
#  'imdbRating': '5.4',
#  'imdbVotes': '109'}
# -------------------
# movie id tt3135062
# -------------------
# {'Actors': 'Dara Davey, Natasha Timpani, Simon Scott, Sam Brittan',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jason Hawkins',
#  'Genre': 'Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'It started with an act of terrorism: a dirty bomb -a radioactive '
#          'attack on American soil that completely devastated the American '
#          'mid-west and left millions dead or dying. Immediately our ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.0/10'}],
#  'Released': '15 Feb 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Finding Oblivion',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jason Hawkins',
#  'Year': '2014',
#  'imdbID': 'tt3135062',
#  'imdbRating': '4.0',
#  'imdbVotes': '8'}
# -------------------
# movie id tt3851970
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Douglas Farra',
#  'Genre': 'Action, Comedy, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The electronic blueprints for human modification have come up '
#          'missing and now two competing villains are on the hunt to retrieve '
#          'it.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '120 min',
#  'Title': 'Finding the Truth',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Douglas Farra',
#  'Year': '2014',
#  'imdbID': 'tt3851970',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3966718
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Johnnie Hargrave',
#  'Genre': 'Drama, Family, Music',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A son looks for his father after fifty five years at his ill '
#          "mother's request.",
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '143 min',
#  'Title': 'Fine Line',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Johnnie Hargrave',
#  'Year': '2014',
#  'imdbID': 'tt3966718',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3765586
# -------------------
# {'Actors': "Christian Saslo, Austin Behl, Alicia Dolberry, Xavier 'Zaytoven' "
#            'Dotson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Curtis Franklin',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When local business man name Terrence TJ Coleman get locked up on '
#          'scam charges, his employees decide to run operations still using his '
#          'schemes to line their pockets until they are Finessed ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzM2MDg5ODIwNV5BMl5BanBnXkFtZTgwNTI1Mzk2MjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.9/10'}],
#  'Released': '01 Dec 2014',
#  'Response': 'True',
#  'Runtime': '94 min',
#  'Title': 'Finesse',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Sareta Cheathem, Curtis Franklin',
#  'Year': '2014',
#  'imdbID': 'tt3765586',
#  'imdbRating': '8.9',
#  'imdbVotes': '7'}
# -------------------
# movie id tt3979950
# -------------------
# {'Actors': 'Gabriel Baxley, Debra Carlsen, Jerry Chesser, Tripp Courtney',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Christopher Forbes',
#  'Genre': 'War',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Nov 2014',
#  'Response': 'True',
#  'Runtime': '114 min',
#  'Title': 'Firetrail',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Christopher Forbes, Lydia Hawke',
#  'Year': '2014',
#  'imdbID': 'tt3979950',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2441402
# -------------------
# {'Actors': 'Lamman Rucker, Lisa Arrindell, David Mann, Elise Neal',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Arthur Muhammad',
#  'Genre': 'Comedy, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'VERNON RICHARDSON and IMANI TOWNSEND meet unexpectedly at a cozy '
#          "Jazz club, unpretentious, and unaware, they're a match made for "
#          'heaven on a popular internet dating website. They fall in ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTM5MjUzNTc5Nl5BMl5BanBnXkFtZTcwOTA1NTM1OQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.8/10'}],
#  'Released': '20 Jun 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'First Impression',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': "Regis Le'Bron",
#  'Year': '2014',
#  'imdbID': 'tt2441402',
#  'imdbRating': '7.8',
#  'imdbVotes': '20'}
# -------------------
# movie id tt3649204
# -------------------
# {'Actors': 'Jackie Biddle, Raymond Biddle, Zach Biddle, Richard Erhardt',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Raymond Biddle',
#  'Genre': 'Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '16 Mar 2014',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'First Spaceship to Venus -Revisioned',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Raymond Biddle',
#  'Year': '2014',
#  'imdbID': 'tt3649204',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3480782
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Bill Thomason',
#  'Genre': 'Adventure',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 May 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Dawn of a New Season',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Bill Thomason',
#  'Year': '2014',
#  'imdbID': 'tt3480782',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3469718
# -------------------
# {'Actors': 'Abdiwali Farrah, Eric Godon, Abdikhadir Hassan, Idil Ibrahim',
#  'Awards': '3 wins & 3 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Kenya, Somalia',
#  'DVD': 'N/A',
#  'Director': 'Cutter Hodierne',
#  'Genre': 'Thriller',
#  'Language': 'Somali, English, French',
#  'Metascore': '65',
#  'Plot': 'A drama the follows a Somali who opts in on a piracy mission but '
#          'then tries to extricate himself from the events.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTUwODQ0MzIwNF5BMl5BanBnXkFtZTgwMjE4MzM3MjE@._V1_SX300.jpg',
#  'Production': 'Pirate Films LLC.',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.4/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '65%'},
#              {'Source': 'Metacritic', 'Value': '65/100'}],
#  'Released': '17 Jan 2014',
#  'Response': 'True',
#  'Runtime': '109 min',
#  'Title': 'Fishing Without Nets',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Cutter Hodierne, John Hibey, Cutter Hodierne (story), John Hibey '
#            '(story), David Burkman (story), Sam Cohan (screenplay)',
#  'Year': '2014',
#  'imdbID': 'tt3469718',
#  'imdbRating': '6.4',
#  'imdbVotes': '178'}
# -------------------
# movie id tt2825774
# -------------------
# {'Actors': 'Jino Kang, Douglas Olsson, Katherine Celio, Artem Mishin',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jino Kang, Tony Urgo',
#  'Genre': 'Action, Adventure',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Retired assassin, Jack Lee, walked away from his violent past to '
#          "raise his dead brother's daughter, Jaime, as his own. When crime "
#          'lord Banducci kidnaps Jaime for a payback, Jack brings his ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQyNDA3ODcyOV5BMl5BanBnXkFtZTgwMTU3NjY5MDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.1/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '101 min',
#  'Title': 'Fist 2 Fist 2: Weapon of Choice',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jino Kang, Jino Kang, Tony Urgo',
#  'Year': '2014',
#  'imdbID': 'tt2825774',
#  'imdbRating': '4.1',
#  'imdbVotes': '83'}
# -------------------
# movie id tt2646956
# -------------------
# {'Actors': 'Josh Thomson, JuJu Chan, Ellary Porterfield, Daniel Whyte',
#  'Awards': '6 wins & 8 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, China',
#  'DVD': 'N/A',
#  'Director': 'Antony Szeto',
#  'Genre': 'Action',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Damon, an MMA fighter retires and goes to China to meet his new '
#          'love, Meili. But things take an immediate turn when he inadvertently '
#          'takes a package sought by an underground arms dealer. Now he must '
#          'fight to save himself and his loved one.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYTkwYjU3MGItNWVhNi00ZGQxLWE4OGYtY2UxYmIxY2Q5M2ZhXkEyXkFqcGdeQXVyMjA0MDM1MTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.2/10'}],
#  'Released': '27 May 2015',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': 'Fist of the Dragon',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Justin Fox',
#  'Year': '2014',
#  'imdbID': 'tt2646956',
#  'imdbRating': '5.2',
#  'imdbVotes': '56'}
# -------------------
# movie id tt3334636
# -------------------
# {'Actors': 'Pontea Banayan, Michael Chase, Lily Cunningham, Brian Gilbert',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Lily Cunningham',
#  'Genre': 'Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Autumn and Blake, Blake and Autumn, For the past four summers, this '
#          "on-again, off-again couple has Camp Kahlua's heads spinning. Will "
#          "they? Won't they? Their last night, filled with kisses ...",
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '25 Jan 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Five Hours',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Lily Cunningham',
#  'Year': '2014',
#  'imdbID': 'tt3334636',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2361602
# -------------------
# {'Actors': "James 'Primo' Grant, John Diaz, Wanda Nobles Colon, Jasmine Burgos",
#  'Awards': '3 wins & 3 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '31 Aug 2015',
#  'Director': 'Keith Miller',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': '76',
#  'Plot': 'A member of the notorious Bloods since he was 12 years old - both in '
#          'the film and in real life - Primo takes John, the son of his slain '
#          'mentor, under his wing, versing him in the code of ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTUzMzA1ODMxNV5BMl5BanBnXkFtZTgwMDE3OTU5NTE@._V1_SX300.jpg',
#  'Production': 'Xlrator Media',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '75%'},
#              {'Source': 'Metacritic', 'Value': '76/100'}],
#  'Released': '17 Apr 2014',
#  'Response': 'True',
#  'Runtime': '83 min',
#  'Title': 'Five Star',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Keith Miller',
#  'Year': '2014',
#  'imdbID': 'tt2361602',
#  'imdbRating': '5.4',
#  'imdbVotes': '530'}
# -------------------
# movie id tt2629802
# -------------------
# {'Actors': 'Miles Snow, Lilly Nelson, Katie Carpenter, Carrie Jones',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Christine Parker',
#  'Genre': 'Adventure, Comedy, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "A filmmaker's guide to surviving the apocalypse",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk5Mjk1ODkwN15BMl5BanBnXkFtZTgwMzgyNjk4NDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.8/10'}],
#  'Released': '01 Dec 2014',
#  'Response': 'True',
#  'Runtime': '106 min',
#  'Title': 'Fix It in Post',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Bill Mulligan, Christine Parker',
#  'Year': '2014',
#  'imdbID': 'tt2629802',
#  'imdbRating': '6.8',
#  'imdbVotes': '12'}
# -------------------
# movie id tt3102924
# -------------------
# {'Actors': 'Christopher Judge, Tom Sizemore, Elle LaMont, Donny Boaz',
#  'Awards': '1 win & 5 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Amir Valinia',
#  'Genre': 'Drama, Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'John Rotit is a happy, content man with a loving wife. Hours later, '
#          "he's a rock star shooting up heroin. And after that...he's something "
#          'far more sinister. John unwillingly flashes between ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc0MTQ0NjA1Nl5BMl5BanBnXkFtZTgwODM3NTM0NzE@._V1_SX300.jpg',
#  'Production': 'AV1 Productions',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.8/10'}],
#  'Released': '06 Oct 2016',
#  'Response': 'True',
#  'Runtime': '101 min',
#  'Title': 'Alternate Realities',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Andrew M. Henderson',
#  'Year': '2015',
#  'imdbID': 'tt3102924',
#  'imdbRating': '4.8',
#  'imdbVotes': '154'}
# -------------------
# movie id tt1975159
# -------------------
# {'Actors': 'Ryan Kwanten, Amy Smart, Leslie Bibb, Jamie Chung',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'Japan, USA',
#  'DVD': '12 Apr 2016',
#  'Director': 'Takashi Shimizu',
#  'Genre': 'Horror, Mystery, Sci-Fi, Thriller',
#  'Language': 'English, Japanese',
#  'Metascore': 'N/A',
#  'Plot': 'Flight 7500 departs Los Angeles International Airport bound for '
#          'Tokyo. As the overnight flight makes its way over the Pacific Ocean '
#          'during its ten-hour course, the passengers encounter what appears to '
#          'be a supernatural force in the cabin.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjQxMTk2MDUxMV5BMl5BanBnXkFtZTgwNzU0MTI4NzE@._V1_SX300.jpg',
#  'Production': 'Pinema',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.8/10'}],
#  'Released': '12 Apr 2016',
#  'Response': 'True',
#  'Runtime': '97 min',
#  'Title': 'Flight 7500',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Craig Rosenberg',
#  'Year': '2014',
#  'imdbID': 'tt1975159',
#  'imdbRating': '4.8',
#  'imdbVotes': '13,994'}
# -------------------
# movie id tt2368533
# -------------------
# {'Actors': 'Rebecca Atkinson, Jody Marriott Bar-Lev, Crispian Belfrage, Kacey '
#            'Clarke',
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'UK, USA',
#  'DVD': 'N/A',
#  'Director': 'Raffaello Degruttola',
#  'Genre': 'Comedy, Crime, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The misadventures of an Indian film director as he attempts to make '
#          'the leap from Bollywood to Hollywood.',
#  'Poster': 'https://ia.media-imdb.com/images/M/MV5BMTk2NDgwNTYxNV5BMl5BanBnXkFtZTgwMjg1NTA3MTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'NOT RATED',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.1/10'}],
#  'Released': '15 May 2014',
#  'Response': 'True',
#  'Runtime': '120 min',
#  'Title': 'Flim: The Movie',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Raffaello Degruttola',
#  'Year': '2014',
#  'imdbID': 'tt2368533',
#  'imdbRating': '7.1',
#  'imdbVotes': '31'}

# %%
len(title_list)
# Out:
# 996

# %%
len(title_id)
# Out:
# 996

# %%
# if title_list and title_id are the same length run the cell below. 
# if they are not equal take out 'title_id': title_id

# %%
df = pd.DataFrame({'title_id': title_id, 'title': title_list, 'box_office': box_office_list, 'country': country_list, 
                   'genre': genre_list, 'director': director_list, 'metascore': metascore_list, 'production': production_list, 
                   'rating': rating_list, 'IMDB_rating': IMDB_rating_list, 'rotten_tomatoes_rating': rotten_tomatoes_rating_list, 
                  'runtime': runtime_list, 'type': type_list, 'IMDB_votes': imdb_votes_list})

# %%
df = df.drop_duplicates()
df.head()
# Out:
#     title_id                               title box_office  \
# 0  tt2075318                              #Stuck        N/A
# 1  tt2477324                              #iKllr        N/A
# 2  tt2106284  $50K and a Call Girl: A Love Story        N/A
# 3  tt5135646    'Twas The Night Before Christmas        N/A
# 4  tt4533680          ...and the Rest is History        N/A
#
#                               country  \
# 0                                 USA
# 1                                 USA
# 2                                 USA
# 3                                 USA
# 4  Germany, New Zealand, Austria, USA
#
#                                        genre                 director  \
# 0                     Comedy, Drama, Romance             Stuart Acher
# 1                           Horror, Thriller          Jeffrey Coghlan
# 2  Action, Adventure, Comedy, Drama, Romance            Seth Grossman
# 3                      Short, Comedy, Family  Hans Hernke, Randy Kent
# 4                       Comedy, Crime, Drama              Niko Kühnel
#
#   metascore             production rating IMDB_rating rotten_tomatoes_rating  \
# 0        43  Stuck Productions LLC    N/A         5.6                    60%
# 1       N/A                    N/A    N/A         N/A                     NA
# 2       N/A               FilmBuff      R         6.8                     NA
# 3       N/A                    N/A    N/A         N/A                     NA
# 4       N/A                    N/A    N/A         N/A                     NA
#
#   runtime   type IMDB_votes
# 0  83 min  movie      1,020
# 1  95 min  movie        N/A
# 2  90 min  movie      1,826
# 3  75 min  movie        N/A
# 4  89 min  movie        N/A

# %%
df.count()
# Out:
# title_id                  996
# title                     996
# box_office                996
# country                   996
# genre                     996
# director                  996
# metascore                 996
# production                996
# rating                    996
# IMDB_rating               996
# rotten_tomatoes_rating    996
# runtime                   996
# type                      996
# IMDB_votes                996
# dtype: int64

# %%
df.to_csv('../data/2013_data_batch_2.csv', index=False)
