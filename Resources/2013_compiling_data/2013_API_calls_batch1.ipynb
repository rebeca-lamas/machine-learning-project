# %%
import pandas as pd
import requests
import json
import time
from pprint import pprint
from config import API_KEY

# %%
data = pd.read_csv('../data/titles_2013_batch1.csv')
df =  data.count()
df
# Out:
# title    1000
# dtype: int64

# %%
title_id = []
box_office_list = []
country_list = []
genre_list = []
director_list = []
metascore_list = []
production_list = []
rating_list = []
IMDB_rating_list = [] 
rotten_tomatoes_rating_list = []
runtime_list = []
title_list = []
type_list = []
imdb_votes_list = []

# %%
movies = data['title']
total_movies = len(movies)

# %%
for i in range(total_movies):
    movie = movies[i]
    url = "http://www.omdbapi.com/?i=" + movie + "&apikey=" + API_KEY
    response = (requests.get(url).text)
    response_json = json.loads(response)
    print('-------------------')
    print(f'movie id {movie}')
    print('-------------------')
    pprint(response_json)
    
    try:
        box_office_list.append(response_json['BoxOffice'])
        country_list.append(response_json['Country'])
        genre_list.append(response_json['Genre'])
        director_list.append(response_json['Director'])
        metascore_list.append(response_json['Metascore'])
        production_list.append(response_json['Production'])
        rating_list.append(response_json['Rated'])
        IMDB_rating_list.append(response_json['imdbRating'])
        try:
            if not response_json['Ratings']:
                rotten_tomatoes_rating_list.append('NA')
            elif response_json['Ratings'][0]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][0]['Value'])
            elif response_json['Ratings'][1]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][1]['Value'])
            else:
                rotten_tomatoes_rating_list.append('NA')
        except IndexError:
            rotten_tomatoes_rating_list.append('NA')
        runtime_list.append(response_json['Runtime'])
        title_list.append(response_json['Title'])
        type_list.append(response_json['Type'])
        imdb_votes_list.append(response_json['imdbVotes'])
        title_id.append(response_json['imdbID'])
    except KeyError:
        pass
    time.sleep(1)
# Out:
# -------------------
# movie id tt2346170
# -------------------
# {'Actors': 'Jason Tobin, Eugenia Yuan, Tzi Ma, Shoshana Bush',
#  'Awards': '1 win.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '23 Jun 2015',
#  'Director': 'Stanley Yung',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Years of seething rage against the racism he's experienced, combined "
#          'with his idolization of Ted Bundy, has left Eddy has one goal: to '
#          'become the greatest serial killer in history. Because ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODk3NjU5NzU4N15BMl5BanBnXkFtZTgwODQwMDk4NTE@._V1_SX300.jpg',
#  'Production': 'Indican Pictures',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.9/10'}],
#  'Released': '04 May 2013',
#  'Response': 'True',
#  'Runtime': '87 min',
#  'Title': '#1 Serial Killer',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Koji Steven Sakai',
#  'Year': '2013',
#  'imdbID': 'tt2346170',
#  'imdbRating': '5.9',
#  'imdbVotes': '37'}
# -------------------
# movie id tt3120962
# -------------------
# {'Actors': 'Ricky Bardy, Justin Bardy',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'N/A',
#  'DVD': 'N/A',
#  'Director': 'Ricky Bardy',
#  'Genre': 'Biography, Comedy, Fantasy',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': '#5 is a film about the creative process of making a film. Like all '
#          'great films it starts with the beginning...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ2MDg0ODAwMV5BMl5BanBnXkFtZTgwNTQ1NjkxMDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '1 h 8 min',
#  'Title': '#5',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ricky Bardy',
#  'Year': '2013',
#  'imdbID': 'tt3120962',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2777190
# -------------------
# {'Actors': 'Adam Wylie, Juliette Danielle, Nick Feld, Rhiannon West',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Brendan Russo',
#  'Genre': 'Drama, Family, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "A dark modern twist on the Peter Pan legend, 'TIL MORNING chronicles "
#          'the life of a former Royal Navy captain who has lost everything, and '
#          "examines what turns a good man into one of literature's greatest "
#          'villains.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.6/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '57 min',
#  'Title': "'Til Morning",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Brendan Russo',
#  'Year': '2013',
#  'imdbID': 'tt2777190',
#  'imdbRating': '8.6',
#  'imdbVotes': '7'}
# -------------------
# movie id tt2395385
# -------------------
# {'Actors': 'Rhys Wakefield, Logan Miller, Ashley Hinshaw, Natalie Hall',
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '14 Jan 2014',
#  'Director': 'Dennis Iliadis',
#  'Genre': 'Horror, Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': '60',
#  'Plot': 'Three college friends hit the biggest party of the year, where a '
#          'mysterious phenomenon disrupts the night, quickly descending into a '
#          'chaos that challenges their friendships - and whether they can stay '
#          'alive.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQwOTA5Mzc3Ml5BMl5BanBnXkFtZTgwOTkxODAxMDE@._V1_SX300.jpg',
#  'Production': 'IFC Films',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.5/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '82%'},
#              {'Source': 'Metacritic', 'Value': '60/100'}],
#  'Released': '24 Oct 2013',
#  'Response': 'True',
#  'Runtime': '96 min',
#  'Title': '+1',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dennis Iliadis (story by), Bill Gullo (screenplay by)',
#  'Year': '2013',
#  'imdbID': 'tt2395385',
#  'imdbRating': '5.5',
#  'imdbVotes': '7,481'}
# -------------------
# movie id tt2506748
# -------------------
# {'Actors': 'Laurie Love, Fred Williamson, Brian Ames, William Katt',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Brian Skiba',
#  'Genre': 'Action, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'On her wedding night, Jade wakes up holding the hand of her dead '
#          'husband after she narrowly survived a murder attempt by the criminal '
#          'family she fled from only weeks before. After pawning ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzgwMzg3OTIxNV5BMl5BanBnXkFtZTgwOTY4ODI1MTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.0/10'}],
#  'Released': '06 Apr 2013',
#  'Response': 'True',
#  'Runtime': '97 min',
#  'Title': '.357',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Brian Skiba',
#  'Year': '2013',
#  'imdbID': 'tt2506748',
#  'imdbRating': '5.0',
#  'imdbVotes': '55'}
# -------------------
# movie id tt3118542
# -------------------
# {'Actors': 'Cameron Brexler, Bones McCoy Castano, Matty Castano, James Hollis '
#            'III',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '21 Oct 2014',
#  'Director': 'Matty Castano',
#  'Genre': 'Comedy, Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When Bobby accidentally kills his wife before a get together at '
#          'their home, he stops at nothing to hide the evidence from the '
#          'arriving guests, even if it means murder.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjY0MDYzNTc5Ml5BMl5BanBnXkFtZTgwNDM0NDMyMTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.8/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '83 min',
#  'Title': '1 Dead Party',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Matty Castano (story), Matty Castano, Jordan Vazcones',
#  'Year': '2013',
#  'imdbID': 'tt3118542',
#  'imdbRating': '4.8',
#  'imdbVotes': '29'}
# -------------------
# movie id tt3226634
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Paul Pescador',
#  'Genre': 'Animation, Biography, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': '1-9 is a collection of nine short experimental films that were '
#          'created over the course of three years . Each film focuses on the '
#          're-staging of personal and physical trauma through ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '77 min',
#  'Title': '1-9',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Paul Pescador',
#  'Year': '2013',
#  'imdbID': 'tt3226634',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt1993391
# -------------------
# {'Actors': 'Tammin Sursok, Virginia Williams, Chris Marquette, Jesse Bradford',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '07 Jul 2014',
#  'Director': 'Leslie Greif',
#  'Genre': 'Comedy, Romance',
#  'Language': 'English',
#  'Metascore': '1',
#  'Plot': 'A screw ball sex comedy following two couples and their ten rules to '
#          'a happy healthy and open relationship.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTM5NTQyMDU2MV5BMl5BanBnXkFtZTgwNjQ5ODMyMTE@._V1_SX300.jpg',
#  'Production': 'Screen Media Films',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '0%'},
#              {'Source': 'Metacritic', 'Value': '1/100'}],
#  'Released': '04 Apr 2014',
#  'Response': 'True',
#  'Runtime': '94 min',
#  'Title': '10 Rules for Sleeping Around',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Leslie Greif, Adam Freeman (dialogue)',
#  'Year': '2013',
#  'imdbID': 'tt1993391',
#  'imdbRating': '3.6',
#  'imdbVotes': '2,679'}
# -------------------
# movie id tt2538128
# -------------------
# {'Actors': 'Jeff Fahey, Sara Malakul Lane, Marc Ewins, John Rhys-Davies',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '11 Jun 2013',
#  'Director': 'R.D. Braunstein',
#  'Genre': 'Action, Adventure, Drama, Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When a chain of volcanic eruptions rips through Europe, the enormous '
#          'ash cloud blocks out the sun, plunging the continent into a new ice '
#          'age. An American couple must find their kids and get them out of '
#          'Paris before it freezes over.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTkyODc2MTMzNF5BMl5BanBnXkFtZTcwNTUzNjE1OQ@@._V1_SX300.jpg',
#  'Production': 'WARNER BROTHERS PICTURES',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.4/10'}],
#  'Released': '13 Apr 2013',
#  'Response': 'True',
#  'Runtime': '89 min',
#  'Title': '100 Degrees Below Zero',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'H. Perry Horton (screenplay), Richard Schenkman (screenplay)',
#  'Year': '2013',
#  'imdbID': 'tt2538128',
#  'imdbRating': '2.4',
#  'imdbVotes': '1,849'}
# -------------------
# movie id tt3529392
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'N/A',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'N/A',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'The film is presented in a dream like structure with no distracting '
#          'titles letting the visual imagery speak freely to your surfing soul '
#          'and wanderlust. With over two hours of epic surf ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjI3NzY2NDc0OV5BMl5BanBnXkFtZTgwOTI2NjAyMTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Jun 2013',
#  'Response': 'True',
#  'Runtime': '133 min',
#  'Title': '1000 Waves to Surfing Glory',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2013',
#  'imdbID': 'tt3529392',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4008940
# -------------------
# {'Actors': 'Avery Ardovino, Deedee Corradini, Brenna Ellis, Sarah Hendrickson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'N/A',
#  'DVD': 'N/A',
#  'Director': 'Cara Perlman',
#  'Genre': 'N/A',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': "Women's ski jumping will compete in the Olympics for the first time "
#          'ever in the 2014 Games in Sochi. 110% is the story of how they got '
#          'there.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzQ3OTE2MDcwOV5BMl5BanBnXkFtZTgwOTQ4MTAwMTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Mar 2013',
#  'Response': 'True',
#  'Runtime': '59 min',
#  'Title': '110%',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2013',
#  'imdbID': 'tt4008940',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2317524
# -------------------
# {'Actors': 'Randy Orton, Tom Stevens, Brian Markinson, Venus Terzo',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '04 Jun 2013',
#  'Director': 'Roel Reiné',
#  'Genre': 'Action, Adventure, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "A man's kidnapped paramedic Nick's wife, forcing him on phone to "
#          'play a "game of death" with 12 rounds, directing Nick to different '
#          'locations.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZDdmMDM2MDYtYjhjMi00Mzg4LTljYTktOGVmNTM5ZDgyNjNjXkEyXkFqcGdeQXVyNDA4OTExNDU@._V1_SX300.jpg',
#  'Production': 'Twentieth Century Fox Home Entertainment',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.3/10'}],
#  'Released': '04 Jun 2013',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': '12 Rounds 2: Reloaded',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'David Benullo',
#  'Year': '2013',
#  'imdbID': 'tt2317524',
#  'imdbRating': '5.3',
#  'imdbVotes': '5,034'}
# -------------------
# movie id tt2024544
# -------------------
# {'Actors': 'Chiwetel Ejiofor, Dwight Henry, Dickie Gravois, Bryan Batt',
#  'Awards': 'Won 3 Oscars. Another 237 wins & 333 nominations.',
#  'BoxOffice': '$50,628,650',
#  'Country': 'USA, UK',
#  'DVD': '04 Mar 2014',
#  'Director': 'Steve McQueen',
#  'Genre': 'Biography, Drama, History',
#  'Language': 'English',
#  'Metascore': '96',
#  'Plot': 'In the antebellum United States, Solomon Northup, a free black man '
#          'from upstate New York, is abducted and sold into slavery.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjExMTEzODkyN15BMl5BanBnXkFtZTcwNTU4NTc4OQ@@._V1_SX300.jpg',
#  'Production': 'Fox Searchlight',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '95%'},
#              {'Source': 'Metacritic', 'Value': '96/100'}],
#  'Released': '08 Nov 2013',
#  'Response': 'True',
#  'Runtime': '134 min',
#  'Title': '12 Years a Slave',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'John Ridley (screenplay by), Solomon Northup (based on "Twelve '
#            'Years a Slave" by)',
#  'Year': '2013',
#  'imdbID': 'tt2024544',
#  'imdbRating': '8.1',
#  'imdbVotes': '597,190'}
# -------------------
# movie id tt3331274
# -------------------
# {'Actors': 'Terry Rice, Destiny Bennett, Doug Stanhope, Shiloh Lindsey',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Terry Rice',
#  'Genre': 'Drama',
#  'Language': 'German, English',
#  'Metascore': 'N/A',
#  'Plot': "A chilling look into the last thirteen days of one man's existence.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYzRiYWJmYmYtOTg0OC00NTU1LWE5ZGItMmQ0OTVlOTM1OTAyXkEyXkFqcGdeQXVyNDgwNDk2MDc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.0/10'}],
#  'Released': '16 Nov 2013',
#  'Response': 'True',
#  'Runtime': '87 min',
#  'Title': '13, 195, 6 und 1',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2013',
#  'imdbID': 'tt3331274',
#  'imdbRating': '8.0',
#  'imdbVotes': '7'}
# -------------------
# movie id tt2991516
# -------------------
# {'Actors': 'Trae Ireland, Erin Coker, Jody Barton, Nihilist Gelo',
#  'Awards': '1 win.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '01 Oct 2013',
#  'Director': 'James Cullen Bressack',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'For millennia, calendars have added an extra day every four years. '
#          'In doing so, they violated the ancient Mayan calendar. Now we are in '
#          'the 13th month of the 13th year of the new millennium...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjM2MTY1ODc5MV5BMl5BanBnXkFtZTgwMTg3ODc0MDE@._V1_SX300.jpg',
#  'Production': 'WARNER BROTHERS PICTURES',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.3/10'}],
#  'Released': '01 Oct 2013',
#  'Response': 'True',
#  'Runtime': '86 min',
#  'Title': '13/13/13',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'James Cullen Bressack',
#  'Year': '2013',
#  'imdbID': 'tt2991516',
#  'imdbRating': '3.3',
#  'imdbVotes': '1,535'}
# -------------------
# movie id tt2431686
# -------------------
# {'Actors': 'Ben Faigus, Alex Schemmer, Peter Paull, K. Harrison Sweeney',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Aaron Fradkin',
#  'Genre': 'Adventure, Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Ben, a 25 year-old with anxiety and OCD, still living with his Mom, '
#          'is forced to embark on a road trip with his only friend Richardson, '
#          'an unambitious model. They are asked to drive to Salt...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTU0Mzc3ODk5N15BMl5BanBnXkFtZTgwODgzODY0MjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.5/10'}],
#  'Released': '27 Apr 2013',
#  'Response': 'True',
#  'Runtime': '81 min',
#  'Title': '15 North',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Aaron Fradkin',
#  'Year': '2013',
#  'imdbID': 'tt2431686',
#  'imdbRating': '7.5',
#  'imdbVotes': '15'}
# -------------------
# movie id tt3328724
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Patrick Dahl',
#  'Genre': 'Sport',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "17 Seconds' is a unique project that doesn't just document the "
#          'Stanley Cup win, but tells the story from an inside vantage point, '
#          'something not usually captured in sports films. The access ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.8/10'}],
#  'Released': '30 Oct 2013',
#  'Response': 'True',
#  'Runtime': '53 min',
#  'Title': '17 Seconds',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2013',
#  'imdbID': 'tt3328724',
#  'imdbRating': '6.8',
#  'imdbVotes': '27'}
# -------------------
# movie id tt10476634
# -------------------
# {'Actors': 'Megan Dewitt, Paula Lopez, Mark McIntire, Cj Ward',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Curtis Stone',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'During a recent remodel of The Yellow House crews discovered the '
#          'remains of a little girl and a super 8 movie camera with the footage '
#          'still inside. The footage has been released to the media by '
#          'Summerland police. This is their footage.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYjA4MWVjYjEtMTE2Yy00ZmMzLWJkYTgtMmUwYTNlYmM1NjdlXkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.0/10'}],
#  'Released': '24 Nov 2013',
#  'Response': 'True',
#  'Runtime': '52 min',
#  'Title': '1972 Yellow House',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2013',
#  'imdbID': 'tt10476634',
#  'imdbRating': '4.0',
#  'imdbVotes': '6'}
# -------------------
# movie id tt2388621
# -------------------
# {'Actors': 'Bokeem Woodbine, Ruby Dee, La La Anthony, Sharon Leal',
#  'Awards': '4 wins & 4 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '01 Mar 2016',
#  'Director': 'Tommy Oliver',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A father struggles to protect his daughter from the reality of her '
#          "mother's drug addiction.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjExODYyNzQ1NF5BMl5BanBnXkFtZTgwMTQ3MzgxODE@._V1_SX300.jpg',
#  'Production': 'LionsGate Entertainment',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '78%'}],
#  'Released': '27 Oct 2013',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': '1982',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tommy Oliver',
#  'Year': '2013',
#  'imdbID': 'tt2388621',
#  'imdbRating': '7.0',
#  'imdbVotes': '249'}
# -------------------
# movie id tt3982302
# -------------------
# {'Actors': 'Rick Ayers, Remi Barron, Matthew Bourdet, Richard Goeb',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jason William Power',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '26 May 2013',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '1989',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jason William Power',
#  'Year': '2013',
#  'imdbID': 'tt3982302',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4322094
# -------------------
# {'Actors': 'Jeff Blim, Denise Donovan, Pat Rourke, Lauren Lopez',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Brian Holden',
#  'Genre': 'Comedy, Musical',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A sketch show with a bit of Pop-Nostalgia, featuring that classic '
#          'boy-band, 3Ever. There are enough laughs as a Fruit-by-the-Foot is '
#          'long (approximately 90 minutes). So grab your Skip-It, ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.8/10'}],
#  'Released': '06 Dec 2013',
#  'Response': 'True',
#  'Runtime': '120 min',
#  'Title': '1Night 2Last 3Ever',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jeff Blim (segment), Denise Donovan (segment), Nick Gage '
#            '(segment), Brian Holden (segment), Lauren Lopez (segment), Pat '
#            'Rourke (segment), Meredith Stepien (segment), Daniel Strauss '
#            '(segment), Joe Walker (segment)',
#  'Year': '2013',
#  'imdbID': 'tt4322094',
#  'imdbRating': '4.8',
#  'imdbVotes': '5'}
# -------------------
# movie id tt2378390
# -------------------
# {'Actors': 'Jill Andre, Katherine Bailess, I. Elijah Baughman, Jordi Caballero',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Michael J. Hach, Neil Kinsella',
#  'Genre': 'Action',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A drug addict scrambles to track down $8 million of heroin while '
#          "pursued by the city's rival mob bosses.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTkxNjMxMjcyMV5BMl5BanBnXkFtZTcwOTcyOTI5OA@@._V1_SX300.jpg',
#  'Production': 'Pit Bulls and Shotguns',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.6/10'}],
#  'Released': '01 Jan 2014',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': '2 Dead 2 Kill',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael J. Hach, Roland Zaleski (writing supervisor)',
#  'Year': '2013',
#  'imdbID': 'tt2378390',
#  'imdbRating': '5.6',
#  'imdbVotes': '12'}
# -------------------
# movie id tt1272878
# -------------------
# {'Actors': 'Denzel Washington, Mark Wahlberg, Paula Patton, Edward James Olmos',
#  'Awards': '3 wins.',
#  'BoxOffice': '$73,500,000',
#  'Country': 'USA',
#  'DVD': '19 Nov 2013',
#  'Director': 'Baltasar Kormákur',
#  'Genre': 'Action, Comedy, Thriller',
#  'Language': 'English, Spanish',
#  'Metascore': '55',
#  'Plot': 'Two hardened criminals get into trouble with the US border patrol '
#          'after meeting with a Mexican drug lord, and then revelations start '
#          'to unfold.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTQ5MTgzNDg4OF5BMl5BanBnXkFtZTcwMjAyODEzOQ@@._V1_SX300.jpg',
#  'Production': 'Universal Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.7/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '64%'},
#              {'Source': 'Metacritic', 'Value': '55/100'}],
#  'Released': '02 Aug 2013',
#  'Response': 'True',
#  'Runtime': '109 min',
#  'Title': '2 Guns',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Blake Masters (screenplay by), Steven Grant (based on the Boom! '
#            'Studios graphic novels by)',
#  'Year': '2013',
#  'imdbID': 'tt1272878',
#  'imdbRating': '6.7',
#  'imdbVotes': '185,722'}
# -------------------
# movie id tt3509408
# -------------------
# {'Actors': 'Emily Anderson, Blake Applegate, Heather Applegate, Phillip '
#            'Applegate',
#  'Awards': '1 win.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Caleb Johnson',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Jessica's true love, Tom, starts appearing to her after his death. "
#          'Terrified and confused, Jess seeks out an explanation for these '
#          'haunting attacks and discovers that the key to her ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTUwMDE0OTAyNV5BMl5BanBnXkFtZTgwMDI1OTM2MzE@._V1_SX300.jpg',
#  'Production': 'Son Films',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.0/10'}],
#  'Released': '02 Apr 2013',
#  'Response': 'True',
#  'Runtime': '108 min',
#  'Title': '2 to Tangle',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jeff Johnson',
#  'Year': '2013',
#  'imdbID': 'tt3509408',
#  'imdbRating': '6.0',
#  'imdbVotes': '35'}
# -------------------
# movie id tt2082155
# -------------------
# {'Actors': 'Lin-Manuel Miranda, Jaime Camil, Dayanara Torres, Monica Steuer',
#  'Awards': '1 win.',
#  'BoxOffice': 'N/A',
#  'Country': 'Puerto Rico, USA',
#  'DVD': 'N/A',
#  'Director': 'Bruno Irizarry',
#  'Genre': 'Comedy, Romance',
#  'Language': 'Spanish, English',
#  'Metascore': 'N/A',
#  'Plot': 'Raul, a Puerto Rican born in New York, meets Maria, a young Puerto '
#          'Rican woman visiting NY, one night. Struck by love at first sight, '
#          'he travels to Puerto Rico in search of this beautiful girl.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ2Mjc0MTU1OV5BMl5BanBnXkFtZTgwNTg4ODYxMDE@._V1_SX300.jpg',
#  'Production': 'Vanguardia Films',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.2/10'}],
#  'Released': '12 Sep 2013',
#  'Response': 'True',
#  'Runtime': '98 min',
#  'Title': 'Looking for Maria Sanchez',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Bruno Irizarry',
#  'Year': '2013',
#  'imdbID': 'tt2082155',
#  'imdbRating': '7.2',
#  'imdbVotes': '360'}
# -------------------
# movie id tt4149040
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Brian J. Leitten',
#  'Genre': 'Sport',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The 2012 Gold Rush Expedition Race features an international field '
#          'of 50 elite athletes tackling a grueling 275-mile course through the '
#          'California wilderness as they test their limits in the toughest '
#          'competition in North America.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '04 May 2013',
#  'Response': 'True',
#  'Runtime': '68 min',
#  'Title': '2012 Gold Rush Expedition Race',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2013',
#  'imdbID': 'tt4149040',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2697322
# -------------------
# {'Actors': 'Jake Bonnan, Leo Aranda, Becca Klee, Nick Shupryt',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ken Potocki',
#  'Genre': 'Action, Adventure, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The year is 2013. The President of the United States resigns, as the '
#          'country faces the lack of a political leader. A German militia '
#          'solider, Adolf Hitler, travels to the country, and ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '19 May 2013',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '2013: Holocaust',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ken Potocki',
#  'Year': '2013',
#  'imdbID': 'tt2697322',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2243215
# -------------------
# {'Actors': 'Clarence Wethern, Bethany Ford, Sam Landman, Scot Moore',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Dave Ash, Paul von Stoetzel',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A computer programmer becomes increasingly disillusioned while '
#          'working on a project to replicate human intelligence using a map of '
#          'the human genome.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZjgxMjRlZjgtMDJkOC00ZDBjLWE1MzMtYThmZDhhODUwZWNlXkEyXkFqcGdeQXVyMzczOTYyMTI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.4/10'}],
#  'Released': '03 Oct 2013',
#  'Response': 'True',
#  'Runtime': '87 min',
#  'Title': '2021',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dave Ash, Michael Lent (story editor)',
#  'Year': '2013',
#  'imdbID': 'tt2243215',
#  'imdbRating': '6.4',
#  'imdbVotes': '14'}
# -------------------
# movie id tt2965278
# -------------------
# {'Actors': 'Pearce Blair, Borkety Boyefio, Mike Guzman, Steve Hawkes',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Gary Davis',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.2/10'}],
#  'Released': '13 May 2013',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '2057: Return to Zombie Island',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2013',
#  'imdbID': 'tt2965278',
#  'imdbRating': '3.2',
#  'imdbVotes': '21'}
# -------------------
# movie id tt1711425
# -------------------
# {'Actors': 'Miles Teller, Skylar Astin, Justin Chon, Sarah Wright',
#  'Awards': '1 win & 1 nomination.',
#  'BoxOffice': '$25,675,765',
#  'Country': 'USA',
#  'DVD': '18 Jun 2013',
#  'Director': 'Jon Lucas, Scott Moore',
#  'Genre': 'Comedy',
#  'Language': 'English, Spanish',
#  'Metascore': '34',
#  'Plot': 'The night before his big medical school interview, a promising '
#          'student celebrates his 21st birthday with his two best friends.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjI0NTExOTI0N15BMl5BanBnXkFtZTcwMDA0ODE3OA@@._V1_SX300.jpg',
#  'Production': 'Relativity Media',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '26%'},
#              {'Source': 'Metacritic', 'Value': '34/100'}],
#  'Released': '01 Mar 2013',
#  'Response': 'True',
#  'Runtime': '93 min',
#  'Title': '21 & Over',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jon Lucas, Scott Moore',
#  'Year': '2013',
#  'imdbID': 'tt1711425',
#  'imdbRating': '5.8',
#  'imdbVotes': '69,943'}
# -------------------
# movie id tt2640806
# -------------------
# {'Actors': 'Mitch Berisha, Luan Bexheti, Vanessa Bontea, Fabrizio Brienza',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Vincent Shkreli',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An ensemble piece focusing on characters who manage to strive '
#          'vigorously at the height of the 21st Century.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '10 Oct 2013',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '21st Century',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Vincent Shkreli',
#  'Year': '2013',
#  'imdbID': 'tt2640806',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2082156
# -------------------
# {'Actors': 'Adam Wingard, Simon Barrett, Caroline White, Sophia Takal',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '26 May 2014',
#  'Director': 'Joe Swanberg',
#  'Genre': 'Crime, Drama, Thriller',
#  'Language': 'English',
#  'Metascore': '42',
#  'Plot': 'In this sexy thriller a photographer who specializes in erotic photo '
#          'shoots is suspected of murder when one of his models is found dead. '
#          "Starring the creators of 'You're Next.'",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc2ODU2ODkyOF5BMl5BanBnXkFtZTgwMjk1MDM4MDE@._V1_SX300.jpg',
#  'Production': 'IFC Midnight',
#  'Rated': 'Unrated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '35%'},
#              {'Source': 'Metacritic', 'Value': '42/100'}],
#  'Released': '24 Jan 2014',
#  'Response': 'True',
#  'Runtime': '77 min',
#  'Title': '24 Exposures',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joe Swanberg',
#  'Year': '2013',
#  'imdbID': 'tt2082156',
#  'imdbRating': '4.1',
#  'imdbVotes': '511'}
# -------------------
# movie id tt2622420
# -------------------
# {'Actors': 'Malinda Williams, Keith Robinson, Eva Marcille, Angell Conwell',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '18 Mar 2013',
#  'Director': 'Fred Thomas Jr.',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The greatest feeling in the world is when you learn to love! Follow '
#          'the stories of seven everyday people as they experience laughter, '
#          'life and matters of the heart. The all-star cast will ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc5MzI3NzcwOF5BMl5BanBnXkFtZTgwODE3NzA2MDE@._V1_SX300.jpg',
#  'Production': 'Swirl Films',
#  'Rated': 'NOT RATED',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.6/10'}],
#  'Released': '19 Mar 2013',
#  'Response': 'True',
#  'Runtime': '98 min',
#  'Title': '24 Hour Love',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Donald Welch',
#  'Year': '2013',
#  'imdbID': 'tt2622420',
#  'imdbRating': '3.6',
#  'imdbVotes': '94'}
# -------------------
# movie id tt2782918
# -------------------
# {'Actors': 'Beth Alemu, Lori Bedsole, Carolyn Brown, Justice Codrington',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Derek Lewis Gray',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A terminally ill man fights to make peace with his estranged family.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk3NTM1NzY0NV5BMl5BanBnXkFtZTcwNjc1NjEzOQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '18 Jan 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '25 Years',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Derek Lewis Gray',
#  'Year': '2013',
#  'imdbID': 'tt2782918',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt1825784
# -------------------
# {'Actors': 'J.K. Simmons, Tim Allen, Scott Caan, Basil Hoffman',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '12 Aug 2013',
#  'Director': 'Michelle Schumacher',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': '9',
#  'Plot': "Follow actor J Kimball as he researches what it's like to be old for "
#          'a role in an upcoming movie. When he meets the residents at The '
#          'Coconuts convalescent home, he quickly discovers that ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTgxNjIzNzcxM15BMl5BanBnXkFtZTcwNjAxMjE0OQ@@._V1_SX300.jpg',
#  'Production': 'Gravitas Adventuras',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.3/10'},
#              {'Source': 'Metacritic', 'Value': '9/100'}],
#  'Released': '22 May 2013',
#  'Response': 'True',
#  'Runtime': '81 min',
#  'Title': '3 Geezers!',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Randle Schumacher, Eric Radzan, Tony Cummings',
#  'Year': '2013',
#  'imdbID': 'tt1825784',
#  'imdbRating': '3.3',
#  'imdbVotes': '657'}
# -------------------
# movie id tt2980480
# -------------------
# {'Actors': 'Christian Swacker, Terissa Kelton, Harper Graham, Daniel Cano',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'James Christopher',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Nick was always kind of a dirt-bag with women. Then he falls in love '
#          'with Michelle. But before he can have a chance with her, he must get '
#          'her three letters of recommendation and face the full fury of his '
#          'chauvinistic past.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjM1ODk0NTY3MF5BMl5BanBnXkFtZTcwNDYzMTA3OQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'}],
#  'Released': '27 Oct 2013',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': '3 References',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'James Christopher (story), James Christopher, Chris Copple (story)',
#  'Year': '2013',
#  'imdbID': 'tt2980480',
#  'imdbRating': '6.5',
#  'imdbVotes': '6'}
# -------------------
# movie id tt2939698
# -------------------
# {'Actors': "Marcus Acosta, Francisc Daniel Albu, Sahba Ataei, Dexter O'Keith "
#            'Benton',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Keith Allen Hayes, Walter Hendrix III',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk3MTg5NTYxMF5BMl5BanBnXkFtZTgwNzM0NjcwMDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '31 Aug 2013',
#  'Response': 'True',
#  'Runtime': '50 min',
#  'Title': '30 Day Itch',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Keith Allen Hayes, Walter Hendrix III',
#  'Year': '2013',
#  'imdbID': 'tt2939698',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2417650
# -------------------
# {'Actors': 'Ashley Martin, Austin Michael Scott, Heidi Kramer, Pickles Moss',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '11 Feb 2013',
#  'Director': 'Craig Moss',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'After a stint in a psychiatric hospital, a young woman returns to '
#          'the house where her father killed the entire cast of The Artist '
#          'during his exorcism.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODg1MTc2NDAwMF5BMl5BanBnXkFtZTcwNjcxMjg3OA@@._V1_SX300.jpg',
#  'Production': 'Twentieth Century Fox Home Entertainment',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.5/10'}],
#  'Released': '15 Jan 2013',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': '30 Nights of Paranormal Activity with the Devil Inside the Girl '
#           'with the Dragon Tattoo',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Craig Moss',
#  'Year': '2013',
#  'imdbID': 'tt2417650',
#  'imdbRating': '2.5',
#  'imdbVotes': '3,425'}
# -------------------
# movie id tt2186663
# -------------------
# {'Actors': 'Franky G, Jeffrey De Serrano, Donna McKechnie, Jaime Tirelli',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '10 Nov 2014',
#  'Director': 'Eddy Duran',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': '19',
#  'Plot': 'When New York Police Headquarters is confronted with the horror of a '
#          'serial murderer loose on the streets of Manhattan. Oblivious to the '
#          'danger, a group of hip students from all over the ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTM5MzE1NzE4OF5BMl5BanBnXkFtZTcwNjk4NjI0OA@@._V1_SX300.jpg',
#  'Production': 'Active Fox Productions',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.8/10'},
#              {'Source': 'Metacritic', 'Value': '19/100'}],
#  'Released': '06 Sep 2013',
#  'Response': 'True',
#  'Runtime': '81 min',
#  'Title': '36 Saints',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jeffrey De Serrano, Joey Dedio',
#  'Year': '2013',
#  'imdbID': 'tt2186663',
#  'imdbRating': '2.8',
#  'imdbVotes': '268'}
# -------------------
# movie id tt2759766
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Crochet sculptures, a gun embedded in a teapot, a 700 lb. shotgun '
#          'shack and more intriguing works represent the future of American '
#          'craft.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTA5MTY1NzI2NjNeQTJeQWpwZ15BbWU4MDY5ODcwNjAx._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'TV-PG',
#  'Ratings': [],
#  'Released': '01 Jan 2013',
#  'Response': 'True',
#  'Runtime': '52 min',
#  'Title': '40 Under 40',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2013',
#  'imdbID': 'tt2759766',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt0453562
# -------------------
# {'Actors': 'Chadwick Boseman, Harrison Ford, Nicole Beharie, Christopher '
#            'Meloni',
#  'Awards': '3 wins & 19 nominations.',
#  'BoxOffice': '$95,001,343',
#  'Country': 'USA',
#  'DVD': '16 Jul 2013',
#  'Director': 'Brian Helgeland',
#  'Genre': 'Biography, Drama, Sport',
#  'Language': 'English',
#  'Metascore': '62',
#  'Plot': 'In 1947, Jackie Robinson becomes the first African-American to play '
#          'in Major League Baseball in the modern era when he was signed by the '
#          'Brooklyn Dodgers and faces considerable racism in the process.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQwMDU4MDI3MV5BMl5BanBnXkFtZTcwMjU1NDgyOQ@@._V1_SX300.jpg',
#  'Production': 'Warner Bros. Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.5/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '80%'},
#              {'Source': 'Metacritic', 'Value': '62/100'}],
#  'Released': '12 Apr 2013',
#  'Response': 'True',
#  'Runtime': '128 min',
#  'Title': '42',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Brian Helgeland',
#  'Year': '2013',
#  'imdbID': 'tt0453562',
#  'imdbRating': '7.5',
#  'imdbVotes': '79,660'}
# -------------------
# movie id tt2652182
# -------------------
# {'Actors': 'Vincent DeFilippo, Danielle Lozeau, Tracey Dukes, Michael '
#            'Rosenthal',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Lucas Lee Graham',
#  'Genre': 'Short, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '30 Jun 2013',
#  'Response': 'True',
#  'Runtime': '45 min',
#  'Title': '45 Days',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Greg Monson',
#  'Year': '2013',
#  'imdbID': 'tt2652182',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2387385
# -------------------
# {'Actors': 'Liza Burns, Jason Thompson, Fran Austin, Johnnie Brannon',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Juli Jackson',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Charlie, an artist who seeks a connection between her work and her '
#          "estranged father's music, teams up with Louie, an obsessive record "
#          'collector from Memphis, and together they begin an ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTM2NTc2NjUwNF5BMl5BanBnXkFtZTcwNTAwNTA3OA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.3/10'}],
#  'Released': '30 Mar 2012',
#  'Response': 'True',
#  'Runtime': '97 min',
#  'Title': '45RPM',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Juli Jackson',
#  'Year': '2013',
#  'imdbID': 'tt2387385',
#  'imdbRating': '8.3',
#  'imdbVotes': '78'}
# -------------------
# movie id tt1335975
# -------------------
# {'Actors': 'Keanu Reeves, Hiroyuki Sanada, Ko Shibasaki, Tadanobu Asano',
#  'Awards': '5 nominations.',
#  'BoxOffice': '$20,518,224',
#  'Country': 'USA, UK, Japan, Hungary',
#  'DVD': '01 Apr 2014',
#  'Director': 'Carl Rinsch',
#  'Genre': 'Action, Drama, Fantasy',
#  'Language': 'English, Japanese',
#  'Metascore': '28',
#  'Plot': 'A band of samurai set out to avenge the death and dishonor of their '
#          'master at the hands of a ruthless shogun.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc0MjE2NzE0OV5BMl5BanBnXkFtZTgwNTU5MjE1MDE@._V1_SX300.jpg',
#  'Production': 'Universal Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '16%'},
#              {'Source': 'Metacritic', 'Value': '28/100'}],
#  'Released': '25 Dec 2013',
#  'Response': 'True',
#  'Runtime': '128 min',
#  'Title': '47 Ronin',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Chris Morgan (screenplay), Hossein Amini (screenplay), Chris '
#            'Morgan (screen story by), Walter Hamada (screen story by)',
#  'Year': '2013',
#  'imdbID': 'tt1335975',
#  'imdbRating': '6.2',
#  'imdbVotes': '139,967'}
# -------------------
# movie id tt2261547
# -------------------
# {'Actors': 'Tom Sizemore, Kimberlin Brown, Musetta Vander, Dan Hewitt Owens',
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Theo Davies',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A lifelong womanizer gets a taste of his own medicine.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjMwNjE5NDIwM15BMl5BanBnXkFtZTcwMzI1MjM4OQ@@._V1_SX300.jpg',
#  'Production': '905 Productions',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'}],
#  'Released': '15 Jan 2014',
#  'Response': 'True',
#  'Runtime': '97 min',
#  'Title': '5 Hour Friends',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ron Jackson',
#  'Year': '2013',
#  'imdbID': 'tt2261547',
#  'imdbRating': '6.1',
#  'imdbVotes': '66'}
# -------------------
# movie id tt3072686
# -------------------
# {'Actors': 'Michael Alan, Barron Brantley, Angel Brunson, Porsha Ferguson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Anthony Singleton',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDZiNzc1YWItM2JmYy00MjgxLTk0NTMtMmQxN2ZjZGFkMjU1XkEyXkFqcGdeQXVyMzAyNDMxMDQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '03 Aug 2013',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '5 People',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Anthony Singleton',
#  'Year': '2013',
#  'imdbID': 'tt3072686',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3252324
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tommy Singleton',
#  'Genre': 'Comedy, Drama, Thriller',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': '5 People are held hostage wondering if they will ever see the light '
#          'of day again. All with different personalities. One has a hidden '
#          'secret. At the end of the day, can a comic, a preacher, ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '87 min',
#  'Title': '5 People',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2013',
#  'imdbID': 'tt3252324',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3685372
# -------------------
# {'Actors': 'Noelle Moralas, Jonathan Mullins, Michael Depore, Lisa Garrett',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Shawn Raynor',
#  'Genre': 'Comedy, Drama, Musical',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "A seasonal story about a young woman's struggle (Jennifer) to find "
#          'her true path in life. Along the way she goes through many wild and '
#          'sometimes dangerous situations. Set in modern day ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTcwMTQ0NjY1MF5BMl5BanBnXkFtZTgwMDY1NDUwMjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'NOT RATED',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.7/10'}],
#  'Released': '19 Nov 2013',
#  'Response': 'True',
#  'Runtime': '115 min',
#  'Title': '5 Seasons: The Movie',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Shawn Raynor, Shawn Raynor',
#  'Year': '2013',
#  'imdbID': 'tt3685372',
#  'imdbRating': '8.7',
#  'imdbVotes': '17'}
# -------------------
# movie id tt1737795
# -------------------
# {'Actors': 'Kristina Anapau, Samaire Armstrong, Steve Bacic, Lynn Blackburn',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Brett Donowho',
#  'Genre': 'Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'How far would you go to save your soul? Noah is haunted by this very '
#          'question when a shadowy stranger offers him a disturbing choice: '
#          'kill or be killed.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjMxMTEzNTkzMl5BMl5BanBnXkFtZTgwODIxNTA2MDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.4/10'}],
#  'Released': '06 Aug 2013',
#  'Response': 'True',
#  'Runtime': '79 min',
#  'Title': '5 Souls',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Colet Abedi (screenplay)',
#  'Year': '2013',
#  'imdbID': 'tt1737795',
#  'imdbRating': '3.4',
#  'imdbVotes': '252'}
# -------------------
# movie id tt2518848
# -------------------
# {'Actors': 'Casper Van Dien, Michael Beach, Sarah Lieving, Bryan Head',
#  'Awards': 'N/A',
# ...
#              {'Source': 'Rotten Tomatoes', 'Value': '55%'},
#              {'Source': 'Metacritic', 'Value': '58/100'}],
#  'Released': '09 Apr 2014',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Fading Gigolo',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'John Turturro',
#  'Year': '2013',
#  'imdbID': 'tt2258345',
#  'imdbRating': '6.2',
#  'imdbVotes': '22,851'}
# -------------------
# movie id tt2917290
# -------------------
# {'Actors': 'Alonso Airaldi, Julie Darnel, Jon Durot, Nana Ghana',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'David Paul',
#  'Genre': 'Drama, Fantasy, Music',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "The surreal tale of a twin and his brother's journey through life's "
#          "trials and tribulations based on their true life's experiences. It "
#          'is also the story of the unique friendship of three ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.2/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '75 min',
#  'Title': 'Faith Street Corner Tavern',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'David Paul',
#  'Year': '2013',
#  'imdbID': 'tt2917290',
#  'imdbRating': '5.2',
#  'imdbVotes': '6'}
# -------------------
# movie id tt3078950
# -------------------
# {'Actors': 'Andrea Anderson, Catherine Brewton, Mike Breyer, Blaise Brooks',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'Comedy, Drama, Mystery',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Welcome to a world of mystery and evil. A merry-go-round circus of '
#          'beautiful clowns and fools.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjE3Mzg0MTAxNF5BMl5BanBnXkFtZTgwODQ1NTEyMDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '66 min',
#  'Title': 'Fake',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2013',
#  'imdbID': 'tt3078950',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2964630
# -------------------
# {'Actors': 'Allejandro Delomasso, Gabriela Stern',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Adam Taylor',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "A probe into the depths of consciousness and sadness - one woman's "
#          'journey into the turbulence of pain and the struggle to feel and '
#          'understand.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '91 min',
#  'Title': 'Fall from Paradise',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'John DeFazio',
#  'Year': '2013',
#  'imdbID': 'tt2964630',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3225656
# -------------------
# {'Actors': 'Davis Aguila, Young-Charles Alexander, Deborah B, Timothy Kane '
#            'Benner',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kenny Latimer',
#  'Genre': 'Drama, Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Falling Backwards tells the story of a father trying to save his son '
#          'from drug addiction. When every positive turn ends up at a dead end, '
#          'his limits are tested and he is forced to go to the extreme to '
#          'rescue his only child from himself.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.0/10'}],
#  'Released': '01 Mar 2013',
#  'Response': 'True',
#  'Runtime': '118 min',
#  'Title': 'Falling Backwards',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kenny Latimer',
#  'Year': '2013',
#  'imdbID': 'tt3225656',
#  'imdbRating': '8.0',
#  'imdbVotes': '5'}
# -------------------
# movie id tt2355565
# -------------------
# {'Actors': 'Adanze Eke, Chijindu Kelechi Eke, Uzoma Eke, Ikechukwu Eziefule',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Chijindu Kelechi Eke',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'There are recent news about some men murdering their wives. What '
#          'could possibly drive a man to murder the woman he supposedly loves? '
#          'This story is about deceptions and rage in relationships...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjIyMjg0NzMwOF5BMl5BanBnXkFtZTcwNzUyNDg4OA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '14 Feb 2013',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'False Engagement',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Chijindu Kelechi Eke',
#  'Year': '2013',
#  'imdbID': 'tt2355565',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2836378
# -------------------
# {'Actors': 'Scott BeLew, Malique Biggs, Wendi Brown, Sam Gelff',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Taylor Hayden',
#  'Genre': 'Mystery',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'False Memory. At the end of the day you are who you believe you are.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjMwMDY0MjA3MV5BMl5BanBnXkFtZTgwNzk5NzA2MDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '24 Jan 2013',
#  'Response': 'True',
#  'Runtime': '119 min',
#  'Title': 'False Memory',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2013',
#  'imdbID': 'tt2836378',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3293380
# -------------------
# {'Actors': 'Elijah Burns, David Sumner, Dillon John Dailidonis, Dean McGregor',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Justin Verley',
#  'Genre': 'Comedy, Drama, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Three boys trapping and cannibalistic, bath salts-related conflict '
#          'after school one weekend.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.9/10'}],
#  'Released': '01 Nov 2013',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'Falseland',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Josh Evangelista, Jonathan Gemme, Jerrick Ignacio, Justin Verley',
#  'Year': '2013',
#  'imdbID': 'tt3293380',
#  'imdbRating': '6.9',
#  'imdbVotes': '9'}
# -------------------
# movie id tt1821426
# -------------------
# {'Actors': 'Kristin Chenoweth, Matthew Modine, Olesya Rulin, Joey King',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '23 Apr 2013',
#  'Director': 'Benjamin Epps',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': '35',
#  'Plot': 'When her family misses her jump roping competition, a 16-year-old '
#          'girl and her siblings hold their parents hostage, hoping to correct '
#          'their unsatisfying behavior.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg2MTAwNTE0M15BMl5BanBnXkFtZTcwMjEwMDgwOQ@@._V1_SX300.jpg',
#  'Production': 'Arc Entertainment',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '36%'},
#              {'Source': 'Metacritic', 'Value': '35/100'}],
#  'Released': '29 Mar 2013',
#  'Response': 'True',
#  'Runtime': '105 min',
#  'Title': 'Family Weekend',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Matt K. Turner',
#  'Year': '2013',
#  'imdbID': 'tt1821426',
#  'imdbRating': '6.3',
#  'imdbVotes': '6,451'}
# -------------------
# movie id tt3376876
# -------------------
# {'Actors': 'Danny Zetwo, Cheyenne Hess, Moses Cantu, Patrick Bigham',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Trent Duncan',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Director Russell, head of a secret government agency, is in search '
#          'of the Necronomicon and makes a deal with Freddy Krueger to find the '
#          'book and release its powers by spilling the blood of ...',
#  'Poster': 'https://ia.media-imdb.com/images/M/MV5BZmZkNDg1YWUtYjgzOC00OTJkLTllOWItZDcxOWY1ZGEyYWQwXkEyXkFqcGdeQXVyMzYzNzc1NjY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'}],
#  'Released': '30 Oct 2013',
#  'Response': 'True',
#  'Runtime': '50 min',
#  'Title': 'Fan Film Saga Part 1: Icons of Horror',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Trent Duncan',
#  'Year': '2013',
#  'imdbID': 'tt3376876',
#  'imdbRating': '6.6',
#  'imdbVotes': '20'}
# -------------------
# movie id tt5339746
# -------------------
# {'Actors': 'Strangely Doesburg, Jared Knapp, David Lyon, Shelly Lyon',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Micah Knapp',
#  'Genre': 'Short, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A young, traveling salesman, whose mode of transportation is a '
#          'flying vacuum cleaner, must go to Hell to save his parents when they '
#          'are kidnapped by the Devil himself.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '30 Jun 2013',
#  'Response': 'True',
#  'Runtime': '40 min',
#  'Title': 'Fantastic Stan Goes to Hell',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jared Knapp, Micah Knapp',
#  'Year': '2013',
#  'imdbID': 'tt5339746',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt1709657
# -------------------
# {'Actors': 'Johnny Sneed, Jolyn Janis, Julie Mintz, Jesse Bernstein',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Cory Van Dyke',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Carter Frazier looks to salvage his foundering life by finding a '
#          "famous lost work of art that's gone missing in far away Marfa, "
#          'Texas.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjE0NzU5OTEzN15BMl5BanBnXkFtZTcwNTE2Mjg2OA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.1/10'}],
#  'Released': '25 Feb 2013',
#  'Response': 'True',
#  'Runtime': '86 min',
#  'Title': 'Far Marfa',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Cory Van Dyke',
#  'Year': '2013',
#  'imdbID': 'tt1709657',
#  'imdbRating': '8.1',
#  'imdbVotes': '76'}
# -------------------
# movie id tt2396485
# -------------------
# {'Actors': 'Raymond Lee, Nikohl Boosheri, George Basil, Julie Lake',
#  'Awards': '5 wins & 3 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Meera Menon',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'FARAH GOES BANG is a road-trip comedy centered on Farah Mahtab, a '
#          'woman in her twenties who tries to lose her virginity while '
#          'campaigning across America for presidential candidate John ...',
#  'Poster': 'https://ia.media-imdb.com/images/M/MV5BMTkwMTQ5NTUyNV5BMl5BanBnXkFtZTgwMzAzMzgyMTE@._V1_SX300.jpg',
#  'Production': 'Seed&amp;Spark',
#  'Rated': 'NOT RATED',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.3/10'}],
#  'Released': '01 Apr 2013',
#  'Response': 'True',
#  'Runtime': '92 min',
#  'Title': 'Farah Goes Bang',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Laura Goode, Meera Menon',
#  'Year': '2013',
#  'imdbID': 'tt2396485',
#  'imdbRating': '7.3',
#  'imdbVotes': '57'}
# -------------------
# movie id tt3198316
# -------------------
# {'Actors': 'Vince Allen, Stephen Quire, Jack Quire, Marcus Folmar',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Vince Allen, Marcus Folmar',
#  'Genre': 'Animation, Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '27 Aug 2013',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Fart of Darkness',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Branyon Davis',
#  'Year': '2013',
#  'imdbID': 'tt3198316',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2597098
# -------------------
# {'Actors': 'Mel Rodriguez, Ashley Lauren, Jason Dugre, Charlene Amoia',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '15 Dec 2015',
#  'Director': 'Mark Phinney',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Ken is a man that won't change his ways. Addicted to food, and bad "
#          'health in general, he is headed on a one way path to an early grave. '
#          'Despite help from his friends, he does what he wants,...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjYyNDkyODI3Ml5BMl5BanBnXkFtZTgwOTcxOTEyNzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.4/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '60%'}],
#  'Released': '25 Apr 2014',
#  'Response': 'True',
#  'Runtime': '91 min',
#  'Title': 'Fat',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Mark Phinney',
#  'Year': '2013',
#  'imdbID': 'tt2597098',
#  'imdbRating': '7.4',
#  'imdbVotes': '87'}
# -------------------
# movie id tt2672902
# -------------------
# {'Actors': 'Courtney Lee Simpson, Daryl E. Hall, Callie Dowd, Andrew Austin',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Daryl E. Hall',
#  'Genre': 'N/A',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.9/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Fat Boys',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Daryl E. Hall',
#  'Year': '2013',
#  'imdbID': 'tt2672902',
#  'imdbRating': '7.9',
#  'imdbVotes': '13'}
# -------------------
# movie id tt2380342
# -------------------
# {'Actors': "Priscilla Barnes, Marlene Mc'Cohen, Shawn C. Phillips, Cuyle "
#            'Carvin',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Dennis Devine',
#  'Genre': 'Comedy, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'This movie is a documentary about fat people.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDg3OTQzNTg1Nl5BMl5BanBnXkFtZTgwNzU3NjkyNDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.9/10'}],
#  'Released': '24 Dec 2013',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Fat Planet',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Brandon Benz, Dennis Devine, Keith Parker',
#  'Year': '2013',
#  'imdbID': 'tt2380342',
#  'imdbRating': '2.9',
#  'imdbVotes': '17'}
# -------------------
# movie id tt7604928
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kourosh Parsi',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNmM4YjMxZmUtMGVmOC00ODBmLWFkMjMtYzg4MGUyNmFhMWVhXkEyXkFqcGdeQXVyMzU3ODQ4NTc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Aug 2013',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Fatal Mind',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kourosh Parsi',
#  'Year': '2013',
#  'imdbID': 'tt7604928',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7608054
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kourosh Parsi',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Aug 2013',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Fatal Mind',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kourosh Parsi',
#  'Year': '2013',
#  'imdbID': 'tt7608054',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}

# %%
len(title_list)
# Out:
# 993

# %%
len(title_id)
# Out:
# 993

# %%
# if title_list and title_id are the same length run the cell below. 
# if they are not equal take out 'title_id': title_id

# %%
df = pd.DataFrame({'title_id': title_id, 'title': title_list, 'box_office': box_office_list, 'country': country_list, 
                   'genre': genre_list, 'director': director_list, 'metascore': metascore_list, 'production': production_list, 
                   'rating': rating_list, 'IMDB_rating': IMDB_rating_list, 'rotten_tomatoes_rating': rotten_tomatoes_rating_list, 
                  'runtime': runtime_list, 'type': type_list, 'IMDB_votes': imdb_votes_list})

# %%
df = df.drop_duplicates()
df.head()
# Out:
#     title_id             title box_office country                       genre  \
# 0  tt2346170  #1 Serial Killer        N/A     USA                      Horror
# 1  tt3120962                #5        N/A     N/A  Biography, Comedy, Fantasy
# 2  tt2777190      'Til Morning        N/A     USA      Drama, Family, Fantasy
# 3  tt2395385                +1        N/A     USA    Horror, Sci-Fi, Thriller
# 4  tt2506748              .357        N/A     USA               Action, Drama
#
#          director metascore        production     rating IMDB_rating  \
# 0    Stanley Yung       N/A  Indican Pictures        N/A         5.9
# 1     Ricky Bardy       N/A               N/A        N/A         N/A
# 2   Brendan Russo       N/A               N/A        N/A         8.6
# 3  Dennis Iliadis        60         IFC Films  Not Rated         5.5
# 4     Brian Skiba       N/A               N/A  Not Rated         5.0
#
#   rotten_tomatoes_rating    runtime   type IMDB_votes
# 0                     NA     87 min  movie         37
# 1                     NA  1 h 8 min  movie        N/A
# 2                     NA     57 min  movie          7
# 3                    82%     96 min  movie      7,481
# 4                     NA     97 min  movie         55

# %%
df.count()
# Out:
# title_id                  993
# title                     993
# box_office                993
# country                   993
# genre                     993
# director                  993
# metascore                 993
# production                993
# rating                    993
# IMDB_rating               993
# rotten_tomatoes_rating    993
# runtime                   993
# type                      993
# IMDB_votes                993
# dtype: int64

# %%
df.to_csv('../data/2013_data_batch_1.csv', index=False)
