# %%
import pandas as pd
import requests
import json
import time
from pprint import pprint
from config import API_KEY

# %%
data = pd.read_csv('../title_webscraped/titles_2017_batch2.csv')
df =  data.count()
df
# Out:
# title    1000
# dtype: int64

# %%
title_id = []
box_office_list = []
country_list = []
genre_list = []
director_list = []
metascore_list = []
production_list = []
rating_list = []
IMDB_rating_list = [] 
rotten_tomatoes_rating_list = []
runtime_list = []
title_list = []
type_list = []
imdb_votes_list = []

# %%
movies = data['title']
total_movies = len(movies)

# %%
for i in range(total_movies):
    movie = movies[i]
    url = "http://www.omdbapi.com/?i=" + movie + "&apikey=" + API_KEY
    response = (requests.get(url).text)
    response_json = json.loads(response)
    print('-------------------')
    print(f'movie id {movie}')
    print('-------------------')
    pprint(response_json)
    
    try:
        box_office_list.append(response_json['BoxOffice'])
        country_list.append(response_json['Country'])
        genre_list.append(response_json['Genre'])
        director_list.append(response_json['Director'])
        metascore_list.append(response_json['Metascore'])
        production_list.append(response_json['Production'])
        rating_list.append(response_json['Rated'])
        IMDB_rating_list.append(response_json['imdbRating'])
        try:
            if not response_json['Ratings']:
                rotten_tomatoes_rating_list.append('NA')
            elif response_json['Ratings'][0]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][0]['Value'])
            elif response_json['Ratings'][1]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][1]['Value'])
            else:
                rotten_tomatoes_rating_list.append('NA')
        except IndexError:
            rotten_tomatoes_rating_list.append('NA')
        runtime_list.append(response_json['Runtime'])
        title_list.append(response_json['Title'])
        type_list.append(response_json['Type'])
        imdb_votes_list.append(response_json['imdbVotes'])
        title_id.append(response_json['imdbID'])
    except KeyError:
        pass
    time.sleep(3)
# Out:
# -------------------
# movie id tt7953946
# -------------------
# {'Actors': "Maureen O'Hara",
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Lois Weber',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "More women worked in film's first 20 years than anytime since. Many "
#          'have been cut from film history, their contributions lost to time. '
#          'This collection highlights the contributions of 14 important women '
#          "directors of cinema's early years.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYzI3ZjViZDgtMTIzZi00ZjUxLWIyNWItM2NiMTY3NDk2M2IyXkEyXkFqcGdeQXVyMjkzNjA4MA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '04 May 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Early Women Filmmakers',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Maya Deren, Germaine Dulac, Lois Weber',
#  'Year': '2017',
#  'imdbID': 'tt7953946',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8667692
# -------------------
# {'Actors': 'Erin Alexis, Rachel Benezra, James DeLorean, Michael J. Gutierrez',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'James DeLorean',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTFlYzJkZDMtOGRiNC00MmZjLWIyNjUtMmYyNGVkOWMzNzAwXkEyXkFqcGdeQXVyNDY4NzE2NTY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '65 min',
#  'Title': 'Earworm: The Musical LIVE!',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'James DeLorean',
#  'Year': '2017',
#  'imdbID': 'tt8667692',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6082386
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Robert L. Parker III',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Ease the Pain',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Robert L. Parker III',
#  'Year': '2017',
#  'imdbID': 'tt6082386',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6408946
# -------------------
# {'Actors': 'Danni DanDan Gadigan, William Mcnamara, Bill Oberst Jr., Kj '
#            'Schrock',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Evan Tramel',
#  'Genre': 'Animation',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The Easter Bunny looking for the best Easter Egg, on his way to find '
#          'it, he runs into friends and they tell him different fables.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNWNkZmRiYzUtNzIzZi00OTUwLWExNWYtMGUzNjU2MzQ1YzQwXkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.3/10'}],
#  'Released': '17 Feb 2017',
#  'Response': 'True',
#  'Runtime': '74 min',
#  'Title': 'Easter Bunny Adventure',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Evan Tramel',
#  'Year': '2017',
#  'imdbID': 'tt6408946',
#  'imdbRating': '3.3',
#  'imdbVotes': '40'}
# -------------------
# movie id tt9486076
# -------------------
# {'Actors': 'Scott Michael Dunn, Diane Ferranti, Nathan Shaw, Brandon Shaw',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Seth Ferranti',
#  'Genre': 'Action, Comedy, Crime',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Santa Claus Crack Dealer bucks on Scraggy Hustler, but Easter Bunny '
#          'Assassin takes care of the contract.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjZlNjRkMzYtYWNhZS00ZGI5LWIxZTEtM2UwNmI0NmE1Y2FiXkEyXkFqcGdeQXVyNjgzOTM0ODM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '28 Oct 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Easter Bunny Assassin: Chapter 2 - Santa Claus Crack Dealer',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Seth Ferranti',
#  'Year': '2017',
#  'imdbID': 'tt9486076',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5067958
# -------------------
# {'Actors': 'Caroline Dhavernas, McCaleb Burnett, Elizabeth Marvel, Charlie '
#            'Hofheimer',
#  'Awards': '4 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '19 Sep 2017',
#  'Director': 'Adam Keleman',
#  'Genre': 'Comedy, Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Sherry, a self-destructive makeup saleswoman, hopes a new man and '
#          'business venture will provide her a fresh start. After her plans are '
#          'foiled, she takes control of her life in a dramatic turn of events.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYWM2YWJmMjItZDY4ZS00ZmU1LWE5ZTQtZWRmMmE1NDJhY2UxXkEyXkFqcGdeQXVyNjQ1NDUxODE@._V1_SX300.jpg',
#  'Production': 'Gravitas Ventures',
#  'Rated': 'TV-14',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.8/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '78%'}],
#  'Released': '19 Sep 2017',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'Easy Living',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Adam Keleman',
#  'Year': '2017',
#  'imdbID': 'tt5067958',
#  'imdbRating': '4.8',
#  'imdbVotes': '323'}
# -------------------
# movie id tt8936904
# -------------------
# {'Actors': 'Carrin Sherman',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'The Existentialist',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Eaters of the Dead is a near-future dystopian tale that explores the '
#          'fate of several individuals in a world running out of food and where '
#          'the rich have seized power and now harvest the poor...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYWM0NzdhN2ItMGU0Zi00MDQ2LWI5MWUtNzNiZjg1MDM3NjVlXkEyXkFqcGdeQXVyOTAyNDgzODY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '60 min',
#  'Title': 'Eaters of the Dead',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Szymczyk',
#  'Year': '2017',
#  'imdbID': 'tt8936904',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7348194
# -------------------
# {'Actors': 'Gary Teague, Glenn Franklin, Joe Atinsky, Leah Rose Fisher',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Stephen Andrew Missick',
#  'Genre': 'History',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'In the Fourth Century, the pilgrim Egeria travels to the east and '
#          'learns about the further acts of the apostles Thomas and Thaddeus.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZDNjNTM4MmYtMGI2Ni00NDZhLWIwZGEtMGFhNGZlODE1ZTc0XkEyXkFqcGdeQXVyODAxOTAxOTU@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '12 Oct 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Egeria: The Letter of the Christ',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Stephen Andrew Missick',
#  'Year': '2017',
#  'imdbID': 'tt7348194',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2364690
# -------------------
# {'Actors': 'Jeff Argubright, Carissa Becker, Chloe Francis, Kate Horn',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Andy Koontz',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The unassuming town of Briar Creek seems to be keeping a nasty '
#          'secret... On a cross country trip home a young couple, Mike and Beth '
#          'make a late night stop in this little town, only to ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTM1NTg3MTM4Nl5BMl5BanBnXkFtZTcwODM1Mjg1OA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'NOT RATED',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.0/10'}],
#  'Released': '10 Jun 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Ekimmu: The Dead Lust',
#  'Type': 'movie',
#  'Website': 'http://ekimmuthedeadlust.com/ekimmue.html',
#  'Writer': 'Andy Koontz',
#  'Year': '2014',
#  'imdbID': 'tt2364690',
#  'imdbRating': '6.0',
#  'imdbVotes': '16'}
# -------------------
# movie id tt3255590
# -------------------
# {'Actors': 'Dax Shepard, Kurtwood Smith, Luke Grimes, Emilio Rivera',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '08 Dec 2017',
#  'Director': 'David E. Talbert',
#  'Genre': 'Comedy, Crime, Western',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Eric comes to El Camino looking for his unknown dad. He's harassed, "
#          'hit and jailed by a drunk local cop, who later shoots at a liquor '
#          'mart with Eric +4 inside. The sheriff and deputy then shoot up the '
#          "place, answering each other's fire.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODk3MzY0MDkyM15BMl5BanBnXkFtZTgwNzUxNzMyNDM@._V1_SX300.jpg',
#  'Production': 'Netflix',
#  'Rated': 'TV-MA',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '40%'}],
#  'Released': '08 Dec 2017',
#  'Response': 'True',
#  'Runtime': '89 min',
#  'Title': 'El Camino Christmas',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Theodore Melfi, Christopher Wehner',
#  'Year': '2017',
#  'imdbID': 'tt3255590',
#  'imdbRating': '5.6',
#  'imdbVotes': '6,342'}
# -------------------
# movie id tt2705058
# -------------------
# {'Actors': 'Victor Lara, Carlos Ramirez-Sorroza, Ruben Hernandez-Romero, '
#            'Otoniel Hernandez-Juarez',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Mexico',
#  'DVD': 'N/A',
#  'Director': 'Eva Benedikt',
#  'Genre': 'Comedy',
#  'Language': 'Spanish',
#  'Metascore': 'N/A',
#  'Plot': "In the Mexican town of Oaxaca, Adalberto's wife, Rosario, slams the "
#          'door on their twenty-year marriage and leaves to live with her '
#          'sister in Australia. The day of her departure, her ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTgzNDA3ODgwNF5BMl5BanBnXkFtZTcwODE0NzcxOQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': 'El Ganador',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Eva Benedikt',
#  'Year': '2014',
#  'imdbID': 'tt2705058',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8566570
# -------------------
# {'Actors': 'Francisca Aronsson, Pierina Carcelén, Dayron Farfán, Julie Freundt',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Peru',
#  'DVD': 'N/A',
#  'Director': 'Alex Hidalgo',
#  'Genre': 'N/A',
#  'Language': 'Spanish',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZTkyZGNlNzEtOGRkNS00NzUxLTkxYmMtZjMyMjkzMWVjMDA2XkEyXkFqcGdeQXVyNjc2NzI2MDU@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '18 May 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'El Gran Criollo',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Alex Hidalgo',
#  'Year': '2017',
#  'imdbID': 'tt8566570',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7315760
# -------------------
# {'Actors': 'Javier Flores, Manelly Zepeda, Yvonne Guerrero, Pietro Rotondi',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Alex Serlof',
#  'Genre': 'Drama',
#  'Language': 'Spanish, English',
#  'Metascore': 'N/A',
#  'Plot': 'A Mexican Immigrant arrives to the United States to chase the '
#          'American dream.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOWY0M2ZkMDktZDU2Ni00MjhlLWIyMzItNTFhN2VlZWU5NzJiXkEyXkFqcGdeQXVyNTMwNTQwNTI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '28 Aug 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'El Sueño Americano',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Alex Serlof',
#  'Year': '2017',
#  'imdbID': 'tt7315760',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7285912
# -------------------
# {'Actors': 'Ramiro Huerta, Ramiro Huerta, Odilon Montanez, Lucy Serrano',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Lucy Serrano',
#  'Genre': 'N/A',
#  'Language': 'Spanish',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BY2IwZjdhMjItMGIwYS00MzU1LThmMDYtMTUyMTA0NWE5YWI1XkEyXkFqcGdeQXVyNjkzNDIxNTc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '06 Aug 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'El Ultimo Psiquico',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Odilon Montanez',
#  'Year': '2017',
#  'imdbID': 'tt7285912',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7345616
# -------------------
# {'Actors': 'José Miguel Escobar',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'El Salvador, USA',
#  'DVD': 'N/A',
#  'Director': 'Victor Ruano',
#  'Genre': 'Drama',
#  'Language': 'Spanish',
#  'Metascore': 'N/A',
#  'Plot': 'Filmed in stunning black and white, this immersive dive into the '
#          'lives of the people of Quelepa, El Salvador, is a tour de force of '
#          'experimentation along the lines of the work of Mexican ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjJjM2JlNTQtNTFlNi00NzZmLTg0NGMtODhmODNjYzJjNGMyXkEyXkFqcGdeQXVyMTExMTIxNTc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Jan 2017',
#  'Response': 'True',
#  'Runtime': '75 min',
#  'Title': 'El puma de Quelepa',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Victor Ruano, Carlos Ulloa (character)',
#  'Year': '2017',
#  'imdbID': 'tt7345616',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4914592
# -------------------
# {'Actors': 'Hayley McLaughlin, Kaye L. Morris, Maria Volk, David Hanson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Benjamin Mattingly',
#  'Genre': 'Adventure, Drama, Music',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When the woman Bryan has always loved invites him to attend America! '
#          'Music Festival, he and his best friend road trip from Portland to '
#          'Las Vegas in pursuit of love and adventure in the ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOGI3YWE4OWYtMzM3OC00OWYyLWIzMTctNTZkZThlNGQzY2JmL2ltYWdlXkEyXkFqcGdeQXVyMzY0OTA1NjI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '75 min',
#  'Title': 'Electric Heart',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Benjamin Mattingly',
#  'Year': '2017',
#  'imdbID': 'tt4914592',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt9891882
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt3168640
# -------------------
# {'Actors': 'Ari Schneider, Ryan Barton-Grimley, Toni Charline, Christinna '
#            'Chauncey',
#  'Awards': '13 wins & 3 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ryan Barton-Grimley',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Lawrence Shaw is a run of the mill guy who just can't get accepted "
#          "for being who he is. He's not straight enough for his job where he "
#          'sells testosterone fueled ad campaigns to beer ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTA1MTMzNDE1MzVeQTJeQWpwZ15BbWU4MDMzNTE4Njcx._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.0/10'}],
#  'Released': '19 Mar 2016',
#  'Response': 'True',
#  'Runtime': '87 min',
#  'Title': "Elijah's Ashes",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ryan Barton-Grimley, Ryan Barton-Grimley, Ari Schneider',
#  'Year': '2016',
#  'imdbID': 'tt3168640',
#  'imdbRating': '8.0',
#  'imdbVotes': '6'}
# -------------------
# movie id tt8885304
# -------------------
# {'Actors': 'Kevin Babuik, Chris Basso, Jacob James, Shane Klemick',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jacob James',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Eliminate is about a teen named Jerome who is kidnapped in his sleep '
#          'by a group of hooded men, and needs to get away from them and kill '
#          'all of the hooded men before they can kidnap anyone again.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '60 min',
#  'Title': 'Eliminate',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jacob James',
#  'Year': '2017',
#  'imdbID': 'tt8885304',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5010982
# -------------------
# {'Actors': 'Jason Lee Boyson, Shawn Brooks, Mike Dell, Allison Gregory',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Mark Cantu',
#  'Genre': 'Action',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'After a fateful mission two years ago that left eight Special Forces '
#          'soldiers dead, newly promoted Naval Investigator Abbey Vaughn makes '
#          'it her personal mission to find the man responsible:...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzU4ZjQ0YTUtNGQwYi00ZWFlLTg5ZWUtOGQyMjMyOGEwYTgyXkEyXkFqcGdeQXVyNjEyMTc3MDU@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.4/10'}],
#  'Released': '01 Feb 2017',
#  'Response': 'True',
#  'Runtime': '92 min',
#  'Title': 'Elite',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Mark Cantu, Jason Scarbrough',
#  'Year': '2017',
#  'imdbID': 'tt5010982',
#  'imdbRating': '4.4',
#  'imdbVotes': '279'}
# -------------------
# movie id tt4730786
# -------------------
# {'Actors': 'Jackie Geary, Jamison Haase, Kristen Miller, Mike Rock',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Gregory Fitzsimmons',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': "Eliza Sherman's Revenge",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Gregory Fitzsimmons',
#  'Year': '2016',
#  'imdbID': 'tt4730786',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5881892
# -------------------
# {'Actors': 'Anna Schafer, Ryan Vincent, Adewale Akinnuoye-Agbaje, Kathleen '
#            'Quinlan',
#  'Awards': '2 wins & 2 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Vincent Sabella',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': '48',
#  'Plot': 'A young woman, recently released from a mental hospital, is coping '
#          'with ongoing episodes of schizophrenia.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZmJmOWJiNDMtNWIyYS00NTkzLThlYzAtODdlN2RjYTUwYzhhXkEyXkFqcGdeQXVyMzgxNzk4NA@@._V1_SX300.jpg',
#  'Production': 'Global Digital Releasing',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '58%'},
#              {'Source': 'Metacritic', 'Value': '48/100'}],
#  'Released': '16 Feb 2017',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': 'Elizabeth Blue',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Vincent Sabella, Alfred D. Huffington',
#  'Year': '2017',
#  'imdbID': 'tt5881892',
#  'imdbRating': '5.8',
#  'imdbVotes': '62'}
# -------------------
# movie id tt3158830
# -------------------
# {'Actors': 'Cassandra Sechler, Jay Sosnicki, Craig Jacobson, Rachel Toups',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Craig Jacobson',
#  'Genre': 'Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTYyMjAxODIxN15BMl5BanBnXkFtZTgwNzg5ODUyMDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Elliot',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Craig Jacobson',
#  'Year': '2014',
#  'imdbID': 'tt3158830',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7847702
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'Australia, USA',
#  'DVD': 'N/A',
#  'Director': 'Daniel Callaghan',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "This is my take of the Mallane footage. If you're not aware of what "
#          "this is. It's an Australian manslaughter case from 2014. A father "
#          'and son were camping, when they were accosted and ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYzMyOTI2ZDItNDc5ZS00NTU1LWFlMTktNDM4NzNmMzY3ZTEzXkEyXkFqcGdeQXVyNTkzMTk4MA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '65 min',
#  'Title': "Elliott Mallane's Murder",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2017',
#  'imdbID': 'tt7847702',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6023004
# -------------------
# {'Actors': 'Nick Vergara, Nikki Borges, Brian Teague Williams, Rob Bradford',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Patrick James Lynch',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'After bombing their LA debut at the Troubadour, a band battles '
#          'demons, exes and excesses at an afterparty in the Hollywood Hills on '
#          'the eve of their first west coast tour.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': 'Elsewhere',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Nick Vergara',
#  'Year': '2017',
#  'imdbID': 'tt6023004',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4393036
# -------------------
# {'Actors': 'Rachael Perrell Fosket, Michael Draper, Sonya Davis, Brian '
#            'Sutherland',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ryan Graves',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A young married couple struggles to stay together after the husband '
#          'suffers a crisis of faith.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTM2MjA3NTY4MF5BMl5BanBnXkFtZTgwMjA5NjExNzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.0/10'}],
#  'Released': '27 Jan 2017',
#  'Response': 'True',
#  'Runtime': '83 min',
#  'Title': 'Emily',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kelly McCrillis (story by), Ryan Graves (story by), Ryan Graves',
#  'Year': '2017',
#  'imdbID': 'tt4393036',
#  'imdbRating': '8.0',
#  'imdbVotes': '7'}
# -------------------
# movie id tt2340142
# -------------------
# {'Actors': 'Eric Roberts, Lena Olin, Vernon Wells, Wes Studi',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Rob Walker',
#  'Genre': 'Crime, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'In desperate times your only hope is the courage and resilience in '
#          'your heart.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYWExZWIyZDEtNDE1NC00N2ZlLWFkMjktOGVlOGFjNzg4OTAwXkEyXkFqcGdeQXVyMjIxMjkwMjg@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '16 Jun 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Empire of the Heart',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Marlene Mendoza, Rob Walker',
#  'Year': '2017',
#  'imdbID': 'tt2340142',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3826818
# -------------------
# {'Actors': 'Aries Marvin Uzzle, Ryan Adcock, Olivia Anjenette, Bradley Nnadi',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Charles Farmer',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Ciara Charles is a carefree young woman who constantly finds herself '
#          'jobless and in foolish predicaments through her neglectful antics. '
#          'Ciara lives with her best friend Juelz, a flamboyant ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Employee of the Year',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Charles Farmer',
#  'Year': '2015',
#  'imdbID': 'tt3826818',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6582734
# -------------------
# {'Actors': "Mickey O'Sullivan, Blaine Childers, Richard Cotovsky, Charin "
#            'Alvarez',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'Mexico, USA',
#  'DVD': 'N/A',
#  'Director': 'Tadeo Garcia',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Set against the background of a broken U.S. immigration system, En '
#          'Algun Lugar is a love story between two young men, Abel & Diego. '
#          "When tragedy strikes and Diego's immigration status is ...",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYzgyMjYyYjYtM2NlZi00MDVkLWE4ZTAtMGYzMDI0ZTg0Mzg0XkEyXkFqcGdeQXVyMTk5NTQ5MjA@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '120 min',
#  'Title': 'En Algun Lugar',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tadeo Garcia',
#  'Year': '2017',
#  'imdbID': 'tt6582734',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6144092
# -------------------
# {'Actors': 'Fernando Cardona, Gilberto Jimenez, Abel Perez, Genoel Ramírez',
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jim McKay',
#  'Genre': 'Drama',
#  'Language': 'Spanish',
#  'Metascore': '87',
#  'Plot': 'A group of undocumented Mexican immigrants work long hours six days '
#          'a week, and then savor their day of rest on Sundays on the soccer '
#          'fields of Brooklyn.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDVlMWNmZTEtMmVmZi00YzkyLTk3NzQtOWQ1MzBiNDA5MDFmXkEyXkFqcGdeQXVyMTg5MDEyNw@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.5/10'},
#              {'Source': 'Metacritic', 'Value': '87/100'}],
#  'Released': '08 Jun 2018',
#  'Response': 'True',
#  'Runtime': '92 min',
#  'Title': 'En el Séptimo Día',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jim McKay',
#  'Year': '2017',
#  'imdbID': 'tt6144092',
#  'imdbRating': '7.5',
#  'imdbVotes': '86'}
# -------------------
# movie id tt6063320
# -------------------
# {'Actors': 'Micah Obregon, Devin Beck, Justin Morgan Brown, Taylor Secor',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Gavin Cody Wegener',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNGNlZWE2ZjAtNzY4Ny00MmIxLTgxZDItMjIwNDRiNTYwYmZmXkEyXkFqcGdeQXVyMjg5NTg1NzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Encore',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Gavin Cody Wegener',
#  'Year': '2017',
#  'imdbID': 'tt6063320',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4111958
# -------------------
# {'Actors': 'Blaise Miller, Kyle Sing, Claire Gordon-Harper, Paul Dillon',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Joselito Seldera',
#  'Genre': 'Crime, Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Faced with losing his daughter, a widower attempts to cover up an '
#          'accidental death, only to come face to face with his darkest '
#          'ambitions for revenge.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjgxMzc5ZDMtZmM0OC00YzdlLWE4OTYtY2Q4OTk3NjNlNzY5XkEyXkFqcGdeQXVyMTY1OTgzNg@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.1/10'}],
#  'Released': '21 Mar 2017',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': 'End of Fall',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joselito Seldera (story), Joselito Seldera, Joselito Seldera',
#  'Year': '2017',
#  'imdbID': 'tt4111958',
#  'imdbRating': '7.1',
#  'imdbVotes': '31'}
# -------------------
# movie id tt6517902
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Mehmet Guney',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '18 Aug 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': "Enduring: A Mother's Story",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Mehmet Guney',
#  'Year': '2017',
#  'imdbID': 'tt6517902',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7304330
# -------------------
# {'Actors': 'Katherine Flannery, Suzanna Akins, Maria Luna, Michael St. Germain',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jon Sanhueza',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYTNiY2FlODItNjQ5My00ZDhmLTk3NTgtZDY5Y2U3ZTA5MDY0XkEyXkFqcGdeQXVyMTI2OTE2NDA@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Engagement',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jon Sanhueza',
#  'Year': '2017',
#  'imdbID': 'tt7304330',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6957366
# -------------------
# {'Actors': 'Charles Irving Beale, Krystal Joy Brown, Emrhys Cooper, Tamela '
#            "D'Amico",
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'David Vendette',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Englishman In LA is a coming-of-man story about a naive British '
#          'writer navigating Hollywood when his romantic British novel is '
#          'threatened to be turned into a cheesy action film.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOGE3NjNiMTYtYWVkNy00YzE5LWE4YTMtMTVjYWFkMWU2NmM1XkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'}],
#  'Released': '12 Mar 2017',
#  'Response': 'True',
#  'Runtime': '45 min',
#  'Title': 'Englishman in L.A: The Movie',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Cameron Moir',
#  'Year': '2017',
#  'imdbID': 'tt6957366',
#  'imdbRating': '6.1',
#  'imdbVotes': '8'}
# -------------------
# movie id tt7374964
# -------------------
# {'Actors': 'Tori Davis, Julian Lazare, Nick Smerkanich, Scout Tafoya',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Scout Tafoya',
#  'Genre': 'Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Not long ago the people of an unnamed country were involved in a '
#          'civil war. After the armistice, both sides noticed hundreds of '
#          'bodies unaccounted for. Looking through their land, there was...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BM2QxZDQ5OGMtZTE2Zi00YjQ3LTk0MTUtNmQzYzBjOTUwOTY5XkEyXkFqcGdeQXVyMjUxNzczNzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.7/10'}],
#  'Released': '14 Sep 2017',
#  'Response': 'True',
#  'Runtime': '76 min',
#  'Title': 'Enjoy Your Trip to Hell',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Julian Lazare, Scout Tafoya',
#  'Year': '2017',
#  'imdbID': 'tt7374964',
#  'imdbRating': '6.7',
#  'imdbVotes': '16'}
# -------------------
# movie id tt7889632
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt6888362
# -------------------
# {'Actors': 'Christopher Heard, Maggie Alexander',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Mark Lewis',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': '"Enthusiastic Sinners" is the saga of a married cop, a small town '
#          'widow and their 24 hour lust story that turns into a love story.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNGYwZDBkZjAtYzc5Zi00N2EwLTg5ODItZDQ2YWQyNzQ1MmNlXkEyXkFqcGdeQXVyNjMxMDA3Ng@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': 'Enthusiastic Sinners',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Mark Lewis',
#  'Year': '2017',
#  'imdbID': 'tt6888362',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8630496
# -------------------
# {'Actors': 'Nicole Adarve, Sofia Alvarez, Daniela Alvira, Imani Armand',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Emily Kogan',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjM0NmExNjYtNmNiZC00YjY3LWFjNTItNGNiODQ0MTdhODgzXkEyXkFqcGdeQXVyMjY0MTU1MTI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '22 May 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Entity',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Hailey Jacobson, Anthony Manda',
#  'Year': '2017',
#  'imdbID': 'tt8630496',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4513110
# -------------------
# {'Actors': 'Anny Rosario, Kyle Williams, Nicole Harbeck',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Gabriel Anderson',
#  'Genre': 'Drama, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A brilliant, but hermetic and hard-living woman discovers an '
#          'anomalous cosmic force that projects the end of the universe to be a '
#          'mere two weeks away. The terminal diagnosis for all ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Entropy',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Gabriel Anderson, Jennifer Anderson',
#  'Year': '2016',
#  'imdbID': 'tt4513110',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6494556
# -------------------
# {'Actors': 'Tamiko Robinson Steele, Steve Cardenas, Christina Fuentes, Michael '
#            'Hutter',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Rashaad Santiago',
#  'Genre': 'Adventure',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A research group makes a curious discovery that may lead to the '
#          'fountain of youth. Meanwhile, an ancient Native American fable sends '
#          'an ominous warning that those who disrespect nature will...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMGNjYzk0NzEtZmMxOC00MmM3LTg3OTAtMTY2OWY1YjhkMmYxXkEyXkFqcGdeQXVyMjIyODQ3MTA@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.2/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '83 min',
#  'Title': 'Beast of the Water',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Rick Prince, Thomas Horton (additional dialogue), Lee Bateman '
#            '(additional dialogue)',
#  'Year': '2017',
#  'imdbID': 'tt6494556',
#  'imdbRating': '3.2',
#  'imdbVotes': '64'}
# -------------------
# movie id tt6598272
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt5181748
# -------------------
# {'Actors': 'Tom Beaver, Iris Wheatley',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tom Beaver',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A conflicted young woman discovers inspiration, love and her own '
#          'capacity for dissident thought while nurturing an obsessive interest '
#          'in George Orwell.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNWQ5OTUzMmUtNGFiYi00NTY5LWFmNTQtYTcxN2Q1NTE3NmYxXkEyXkFqcGdeQXVyMzc5NDExMQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '25 Mar 2017',
#  'Response': 'True',
#  'Runtime': '60 min',
#  'Title': 'Eric Blair and I',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tom Beaver',
#  'Year': '2017',
#  'imdbID': 'tt5181748',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6960770
# -------------------
# {'Actors': 'Wade McCollum, Valerie Vigoda',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'David Horn',
#  'Genre': 'Musical',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://ia.media-imdb.com/images/M/MV5BNzY3MGNjNmMtMDdlZi00Y2UzLTliZGYtMTE0MTAyZTRhZDI3XkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '07 Jun 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Ernest Shackleton Loves Me',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joe DiPietro',
#  'Year': '2017',
#  'imdbID': 'tt6960770',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3910416
# -------------------
# {'Actors': 'Alex Miller, Grant Liffmann, Brianna Kellum, Kevin Caliber',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Only Now Existing',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A socially and politically frustrated young man with a troubled past '
#          'vents his frustrations through a social networking website and '
#          'unwittingly sparks a revolutionary social movement.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzVlYjQ3MDgtNTkyOS00YmVmLWE1NGUtNWUwMTQ3Y2Y2MGJhXkEyXkFqcGdeQXVyMjE4NzEzMzQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.3/10'}],
#  'Released': '22 Mar 2017',
#  'Response': 'True',
#  'Runtime': '106 min',
#  'Title': 'Escape Artist',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Only Now Existing',
#  'Year': '2017',
#  'imdbID': 'tt3910416',
#  'imdbRating': '8.3',
#  'imdbVotes': '783'}
# -------------------
# movie id tt5159414
# -------------------
# {'Actors': 'Evan Williams, Annabelle Stephenson, Elisabeth Hower, Dan J. '
#            'Johnson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Will Wernick',
#  'Genre': 'Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Six friends test their intelligence when an escape room they '
#          'participate in takes a dark and twisted turn.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNmIyZDIxZGUtNmRmZC00ZjMyLTlkNzgtZGQxOGMyZjQ4OWJkXkEyXkFqcGdeQXVyMjA1MzQyNDE@._V1_SX300.jpg',
#  'Production': 'Global Genesis Group',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.2/10'}],
#  'Released': '29 Sep 2017',
#  'Response': 'True',
#  'Runtime': '81 min',
#  'Title': 'Escape Room',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Will Wernick (story by), Noah Dorsey (story by), Noah Dorsey',
#  'Year': '2017',
#  'imdbID': 'tt5159414',
#  'imdbRating': '4.2',
#  'imdbVotes': '7,028'}
# -------------------
# movie id tt5748392
# -------------------
# {'Actors': 'Skeet Ulrich, Sean Young, Christine Donlon, Randy Wayne',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '17 Oct 2017',
#  'Director': 'Peter Dukes',
#  'Genre': 'Horror',
#  'Language': 'Arabic, English',
#  'Metascore': 'N/A',
#  'Plot': 'Four friends who partake in a popular Los Angeles escape room, owned '
#          'by Brice (Ulrich), find themselves stuck with a demonically '
#          'possessed killer. Sean Young plays the keeper of a box ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZDEzNzk1NDYtN2Y5Mi00MjlkLWI0OTAtNjk0Zjk4MDY4NmRhXkEyXkFqcGdeQXVyNTYzMjkwNjU@._V1_SX300.jpg',
#  'Production': 'Lionsgate',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.3/10'}],
#  'Released': '01 Sep 2017',
#  'Response': 'True',
#  'Runtime': '86 min',
#  'Title': 'Escape Room',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Peter Dukes',
#  'Year': '2017',
#  'imdbID': 'tt5748392',
#  'imdbRating': '4.3',
#  'imdbVotes': '2,364'}
# -------------------
# movie id tt7254232
# -------------------
# {'Actors': 'Sarah Nicklin, Karli Kaiser, Erik Moody, Michael Slefinger',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Matthew Chilelli(co-director), Ben DeLoose(co-director)',
#  'Genre': 'Horror, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A psychological and supernatural horror film following two sets of '
#          'roommates experiencing mysterious events while battling their own '
#          'personal demons.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMDc1ZTQ1ZDQtYTAwYi00ZWJjLWJkMzItZDAyMzk1ZTQyMmMxXkEyXkFqcGdeQXVyNTA3NDQ0NDk@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.6/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '100 min',
#  'Title': 'Escape the Dark',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Matthew Chilelli, Ben DeLoose',
#  'Year': '2017',
#  'imdbID': 'tt7254232',
#  'imdbRating': '7.6',
#  'imdbVotes': '7'}
# -------------------
# movie id tt6295224
# -------------------
# {'Actors': 'Gerren Hall, Helen Brehm, Cameron Britt, Natalie Grant',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Nathan Cooper',
#  'Genre': 'Action, Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOGMzZDVlMTYtMzkwMy00ODJkLWE0M2ItY2RjN2E5MjFlNjFlL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjYzNjU3NTA@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '27 Jan 2017',
#  'Response': 'True',
#  'Runtime': '48 min',
#  'Title': 'Espionage',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Mark Barahura, Shayne Cole, Nathan Cooper',
#  'Year': '2017',
#  'imdbID': 'tt6295224',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3652142
# -------------------
# {'Actors': 'Sean Astin, Saïd Taghmaoui, Chasty Ballesteros, Joseph Gatt',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Rob Gordon Bralver',
#  'Genre': 'Action, Comedy',
#  'Language': 'English, Spanish, French',
#  'Metascore': 'N/A',
#  'Plot': 'In a reality TV show created by the U.S. government about spies, '
#          'audiences go on fake undercover missions, but fact cannot be easily '
#          'distinguished from fiction.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTYzZGQ4ZjctNTZlOC00M2IxLTg4MjEtODE2ZGViZTM3NWQzXkEyXkFqcGdeQXVyNTM0MDc1ODE@._V1_SX300.jpg',
#  'Production': 'O.S.S. Cinema Wing',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'}],
#  'Released': '24 Oct 2017',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': 'Espionage Tonight',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Rob Gordon Bralver',
#  'Year': '2017',
#  'imdbID': 'tt3652142',
#  'imdbRating': '5.8',
#  'imdbVotes': '623'}
# -------------------
# movie id tt7131466
# -------------------
# {'Actors': 'Laura Döbrösi, Kinga Vecsei',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'Hungary, USA',
#  'DVD': 'N/A',
#  'Director': 'Máté Boegi',
#  'Genre': 'Drama, Fantasy, Mystery, Thriller',
#  'Language': 'Hungarian',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYjQyNjRmNmUtZTg4MS00YzcyLWI0MDQtMzIxYmRjZDYzODg4XkEyXkFqcGdeQXVyMjAwMjk0MzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '07 May 2017',
#  'Response': 'True',
#  'Runtime': '89 min',
#  'Title': 'Eszter',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Máté Boegi, Árpád Hermán',
#  'Year': '2017',
#  'imdbID': 'tt7131466',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6509308
# -------------------
# {'Actors': 'Chassie Allen, Eddie Armstrong, Sheryl Armstrong, Derrick Barrett',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Corey Dinkins',
#  'Genre': 'Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOWY0NjVjMTgtNDg2NC00NWI0LWE4YmItMGVkZDE4Mzc0YWUxXkEyXkFqcGdeQXVyNjkxMTk1NjI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '04 Feb 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Eternity',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Cheryl Clay',
#  'Year': '2017',
#  'imdbID': 'tt6509308',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6649282
# -------------------
# {'Actors': 'Maria Hojas, Rob McNeil',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Amanda Sayeg',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "The phases of a young woman's relationship unfold, as experienced "
#          'from the perspective of one room.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMDA3YmZkOTEtYThiMi00MGE2LTk1NTMtZWQzZjU1NmI3NDlhXkEyXkFqcGdeQXVyNjEwNDAyOTc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '10 Mar 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Everglow',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Max Lukach, Amanda Sayeg',
#  'Year': '2017',
#  'imdbID': 'tt6649282',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3605266
# -------------------
# {'Actors': 'Julia Garner, Joseph Cross, C.S. Lee, Jillian Mayer',
#  'Awards': '4 wins.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Pete Ohs, Andrea Sisson',
#  'Genre': 'Fantasy, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A guy, a girl, and a robothead hike across a desert planet in search '
#          'of a mythical lake.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYzQyNmRmOGQtZmZkMC00NjkxLThiMjgtMDkyZGQxNDc4ZjVjXkEyXkFqcGdeQXVyNDc3MzAwNjI@._V1_SX300.jpg',
#  'Production': 'Manali Pictures',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.5/10'}],
#  'Released': '21 Jun 2017',
#  'Response': 'True',
#  'Runtime': '91 min',
#  'Title': 'Everything Beautiful Is Far Away',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Pete Ohs',
#  'Year': '2017',
#  'imdbID': 'tt3605266',
#  'imdbRating': '5.5',
#  'imdbVotes': '696'}
# -------------------
# movie id tt6416112
# -------------------
# {'Actors': 'Shane Willimon, Maredith Walker, Shama Mrema',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jason Waggoner',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Geeky, Sylvia Marconi is an actuarial specialist at a big insurance '
#          'company who finds data anomalies in a data-mining project. When she '
#          'confronts her boss, Ms. Dryver, with the irregularity...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '29 Jun 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Everything Happens at Once',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jason Waggoner',
#  'Year': '2017',
#  'imdbID': 'tt6416112',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7493854
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
# ...
# movie id tt8898254
# -------------------
# {'Actors': 'Kenneth Palmore, Jason Newport, Nathyl Snipes, Wade Carson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Adwoa Daniels, Wade Carson(co-director)',
#  'Genre': 'Action, Crime, Drama, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Adwoa owns a very exclusive hair salon that charges thousands of '
#          'dollars to schedule an appointment. When clients start disappearing '
#          'the police start to question recent murders in the area.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '52 min',
#  'Title': 'Money Is Our Goal',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Adwoa Daniels (story), Adwoa Daniels',
#  'Year': '2017',
#  'imdbID': 'tt8898254',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6584092
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Daniel Barach',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Money vs. Meaning',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Daniel Barach',
#  'Year': '2017',
#  'imdbID': 'tt6584092',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5745336
# -------------------
# {'Actors': 'Nick Costello, Renee Domenz, Paul D. Morgan, Charles E Tiedje',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tommy Jackson',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A woman is forced to find strength and independence when her '
#          'subconscious releases a dark entity named Monica.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZjc5MzdkOGEtNTMzMy00NzkyLWIxMDctZDJjNTQwMzliODI3XkEyXkFqcGdeQXVyNjA0MDcyNjg@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Aug 2017',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Monica',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tommy Jackson',
#  'Year': '2017',
#  'imdbID': 'tt5745336',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7255374
# -------------------
# {'Actors': 'Don Carlos, Justin Celani, Tim Christie, Chris Douglas',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ian Messenger',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An exploration of what happens when human curiosity and animal rage '
#          'collide. This low-budget, high-concept thriller presents a different '
#          'kind of antagonist, and the same ...',
#  'Poster': 'https://ia.media-imdb.com/images/M/MV5BMTg1MDlmN2QtMDI2OC00YzlkLWE2YjctNjE2MzI2NGZiZmE5XkEyXkFqcGdeQXVyODE1NTU0NDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.0/10'}],
#  'Released': '10 Oct 2017',
#  'Response': 'True',
#  'Runtime': '76 min',
#  'Title': 'Monkey Farm',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ian Messenger',
#  'Year': '2017',
#  'imdbID': 'tt7255374',
#  'imdbRating': '4.0',
#  'imdbVotes': '65'}
# -------------------
# movie id tt9837530
# -------------------
# {'Actors': 'Robbie Daymond, Joe Dixon, Richard Farrell, Brownie Hansen',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Felix Ip, Paul Wang',
#  'Genre': 'Adventure',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A zoo monkey in Sichuan travels to NYC to rescue his human friend '
#          'from a trio of nefarious kidnappers, only to realize the Demon King '
#          'is behind it all. With the help of Baji the pig, he learns to '
#          'channel the power of the Monkey King.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYmUzN2Y0YjctYjc1NS00ZjQ1LTkxNDktYzM4MjY5NDlkNTcwXkEyXkFqcGdeQXVyMjAzMjQ4NDc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '03 Mar 2018',
#  'Response': 'True',
#  'Runtime': '77 min',
#  'Title': 'Monkey King Reloaded',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Aaron Mendelsohn',
#  'Year': '2017',
#  'imdbID': 'tt9837530',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7437764
# -------------------
# {'Actors': 'Lindsay Fritts, Mary Buss, Patrick Dean, Mason Giles',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Cait Brasel, Jacob Burns, John Burton, Laron M. Chapman, Mickey '
#              'Reece',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An anthology film consisting of five different directors filming '
#          'five different segments throughout one single day in the life of '
#          'protagonist Molly.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNGY0ZDgzNzktYzJhZC00MWRjLTgwNTktNzIxYjA3NTFlZmZiXkEyXkFqcGdeQXVyMjMxOTQ0NjY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Dec 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Mono',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Cait Brasel, Jacob Burns, John Burton, Laron M. Chapman, Mickey '
#            'Reece',
#  'Year': '2017',
#  'imdbID': 'tt7437764',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2894010
# -------------------
# {'Actors': 'Joe Fishel, Tiffany Sander McKenzie, Alex Russo, Christopher Mele',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Cayce Mell',
#  'Genre': 'Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Kate, Mick and Ben go on an adventure to find the creature in the '
#          'Monongahela river.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTU5NzUyNDY2Ml5BMl5BanBnXkFtZTcwNzgzMTI2OQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Monongahela',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Cayce Mell',
#  'Year': '2015',
#  'imdbID': 'tt2894010',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5840738
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Colombia',
#  'DVD': 'N/A',
#  'Director': 'Famor Botero',
#  'Genre': 'Comedy',
#  'Language': 'Spanish',
#  'Metascore': 'N/A',
#  'Plot': 'Romantic comedy about a Colombian girl working in the United States '
#          'who has to return to her native Colombia to deal with unresolved '
#          'business from her boss, there she is confronted with her real '
#          'identity and falls in love with a stranger.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Feb 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'La Película Que No tiene Nombre',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Enrique Suarez',
#  'Year': '2017',
#  'imdbID': 'tt5840738',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6494542
# -------------------
# {'Actors': 'Matt Tatroe',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jaysen P. Buterin, Daniel B. Iske, Patrick Rea, Sean van '
#              'Leijenhorst',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Two friends hide in an old theater to escape ravenous hordes of '
#          'vampires, zombies and werewolves.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYjA5ZjAwMzUtMmY1Yi00MDMyLWI5MDEtOWY0NDQ0YjJiOTg4XkEyXkFqcGdeQXVyMjg1MTU1NjI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.2/10'}],
#  'Released': '01 Mar 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Monster X',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jaysen P. Buterin, Daniel B. Iske, Patrick Rea, Sean van '
#            'Leijenhorst (segment)',
#  'Year': '2017',
#  'imdbID': 'tt6494542',
#  'imdbRating': '4.2',
#  'imdbVotes': '32'}
# -------------------
# movie id tt4387114
# -------------------
# {'Actors': "Jim O'Rear",
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Monsters Among Men',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2016',
#  'imdbID': 'tt4387114',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2574326
# -------------------
# {'Actors': 'Mark A. Pierce, DawnMarie Ferrara, Amy Argyle, Maria Olsen',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Mark A. Pierce',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "In the 1830's emigrants from Salem, Massachusetts fled their satanic "
#          'legacy and came to settle in LaSalle County,Illinois. They brought '
#          'along with them some of their more unpleasant, ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODM4MjgyNjYxMF5BMl5BanBnXkFtZTgwNDc2NjU1NTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '31 Oct 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Moon Creek Cemetery',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2016',
#  'imdbID': 'tt2574326',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7575784
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt4218340
# -------------------
# {'Actors': 'Dennis North, Mike Kraft, Tracee Mae Miller, Megan Messmer',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kevin Carrico',
#  'Genre': 'Adventure, Music, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'In the future, a band of misfits uncover the saga of an infamous '
#          'rock star. Their journey takes them deep into the legend surrounding '
#          "the destruction of mankind's first colony on the Moon. They wonder, "
#          "can rock 'n' roll save the world?",
#  'Poster': 'https://ia.media-imdb.com/images/M/MV5BYmFhYzViYzMtNGY4OS00NzNkLWE2MmYtNTJkYTA4NWM4MTFiXkEyXkFqcGdeQXVyMjcxNDI5Mw@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '15 Jan 2017',
#  'Response': 'True',
#  'Runtime': '118 min',
#  'Title': 'Moon Rock City',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kevin Carrico (screenplay), Kevin Carrico (story), Chris Messina '
#            '(screenplay)',
#  'Year': '2017',
#  'imdbID': 'tt4218340',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7090112
# -------------------
# {'Actors': 'Eric Farkas, Jean Hejduk, Gregory Irving, Janet Jay',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Robert Kotabish',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The McKenzie Cousins have a sure fire way to make endless amounts of '
#          'cash. The girls want in on the action.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'NOT RATED',
#  'Ratings': [],
#  'Released': '01 Jul 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Moon Shine Vixens',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Robert Kotabish, Brandy Williams',
#  'Year': '2017',
#  'imdbID': 'tt7090112',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6759432
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt3705822
# -------------------
# {'Actors': 'Tarick Salmaci, Niki Spiridakos, Sarah Butler, Damon Dayoub',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Robert Dyke',
#  'Genre': 'Action, Adventure, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A long forgotten ancient spacecraft discovered on Earth. '
#          'Investigations carried out by Scout transport her to the moon '
#          'whereupon she meets the impressive machines preserving the wisdom of '
#          'that long lost civilization.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODg3Mjc2ODQtMjNlOS00ZTM5LWFhOGYtNWVjYjM0MWViMGY2XkEyXkFqcGdeQXVyNzcxOTU5MDc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.0/10'}],
#  'Released': '07 Feb 2017',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': 'Moontrap: Target Earth',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Robert Dyke (screenplay), Tex Ragsdale (screenplay), Tex Ragsdale',
#  'Year': '2017',
#  'imdbID': 'tt3705822',
#  'imdbRating': '5.0',
#  'imdbVotes': '3,351'}
# -------------------
# movie id tt7390114
# -------------------
# {'Actors': 'Jonathan Daniel Miles, Bjorn Anderson, Riley Irvine, Annabeth Kerr',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Michelle Leigh',
#  'Genre': 'Comedy, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A young gay man finds how to love himself and accept love from '
#          'another, despite the disapproval of his father.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYWU0YjIyMTQtZDVlZi00Y2ZkLWEwOGEtMDgxZGU0NjBlNjZiXkEyXkFqcGdeQXVyNzg1MDIwOTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Apr 2017',
#  'Response': 'True',
#  'Runtime': '107 min',
#  'Title': 'More Than Only',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2017',
#  'imdbID': 'tt7390114',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6584146
# -------------------
# {'Actors': 'Ole Becker, Vicki Broach, Ross Durand, Charlie Field',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Paul Hendry, Bob Hasse(co-director)',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Someone once said, "It is a truth universally acknowledged that a '
#          'single man should never be allowed to house-sit." And Mormon Dog '
#          'Story illustrates why in a farcical buddy comedy that ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYWFjNzBmODQtMzhmYy00OTk3LWI1M2ItY2M1ODQ5MzNkZGYyXkEyXkFqcGdeQXVyMjAzMjYxMjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '81 min',
#  'Title': 'Mormon Dog Story',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Bob Hasse, Paul Hendry',
#  'Year': '2017',
#  'imdbID': 'tt6584146',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4765868
# -------------------
# {'Actors': 'Kit Bateman, Eric Berggren, Erin Blaisdell, Steven Briggs',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '28 Mar 2017',
#  'Director': 'Christopher James Miller',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'MORTUARY MASSACRE is a gruesome Horror Anthology that centers around '
#          "Detective Giger's (Todd Brown) debriefing of several mysterious "
#          'deaths, all taking place on Halloween night. The local ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjcxNzMxMzM1OF5BMl5BanBnXkFtZTgwOTk0NDA4MDI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'}],
#  'Released': '28 Mar 2017',
#  'Response': 'True',
#  'Runtime': '83 min',
#  'Title': 'Mortuary Massacre',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Erin Blaisdell (screenplay), Mark McGarrey (story), Christopher '
#            'James Miller (screenplay), Kyle Morris (story), Sean Stearley '
#            '(story)',
#  'Year': '2017',
#  'imdbID': 'tt4765868',
#  'imdbRating': '5.4',
#  'imdbVotes': '21'}

# %%
len(title_list)
# Out:
# 949

# %%
len(title_id)
# Out:
# 949

# %%
# if title_list and title_id are the same length run the cell below. 
# if they are not equal take out 'title_id': title_id

# %%
df = pd.DataFrame({'title_id': title_id, 'title': title_list, 'box_office': box_office_list, 'country': country_list, 
                   'genre': genre_list, 'director': director_list, 'metascore': metascore_list, 'production': production_list, 
                   'rating': rating_list, 'IMDB_rating': IMDB_rating_list, 'rotten_tomatoes_rating': rotten_tomatoes_rating_list, 
                  'runtime': runtime_list, 'type': type_list, 'IMDB_votes': imdb_votes_list})

# %%
df = df.drop_duplicates()
df.head()
# Out:
#     title_id                                              title box_office  \
# 0  tt7953946                             Early Women Filmmakers        N/A
# 1  tt8667692                         Earworm: The Musical LIVE!        N/A
# 2  tt6082386                                      Ease the Pain        N/A
# 3  tt6408946                             Easter Bunny Adventure        N/A
# 4  tt9486076  Easter Bunny Assassin: Chapter 2 - Santa Claus...        N/A
#
#   country                  genre              director metascore production  \
# 0     USA                    N/A            Lois Weber       N/A        N/A
# 1     USA                    N/A        James DeLorean       N/A        N/A
# 2     USA               Thriller  Robert L. Parker III       N/A        N/A
# 3     USA              Animation           Evan Tramel       N/A        N/A
# 4     USA  Action, Comedy, Crime         Seth Ferranti       N/A        N/A
#
#   rating IMDB_rating rotten_tomatoes_rating runtime   type IMDB_votes
# 0    N/A         N/A                     NA     N/A  movie        N/A
# 1    N/A         N/A                     NA  65 min  movie        N/A
# 2    N/A         N/A                     NA     N/A  movie        N/A
# 3    N/A         3.3                     NA  74 min  movie         40
# 4    N/A         N/A                     NA     N/A  movie        N/A

# %%
df.count()
# Out:
# title_id                  949
# title                     949
# box_office                949
# country                   949
# genre                     949
# director                  949
# metascore                 949
# production                949
# rating                    949
# IMDB_rating               949
# rotten_tomatoes_rating    949
# runtime                   949
# type                      949
# IMDB_votes                949
# dtype: int64

# %%
df.to_csv('../data/2017_data_batch_2.csv', index=False)
