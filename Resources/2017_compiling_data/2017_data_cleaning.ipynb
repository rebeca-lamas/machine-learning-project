# %%
import pandas as pd

# %%
batch_1 = pd.read_csv('../data/2017_data_batch_1.csv')
batch_2 = pd.read_csv('../data/2017_data_batch_2.csv')
batch_3 = pd.read_csv('../data/2017_data_batch_3.csv')
batch_4 = pd.read_csv('../data/2017_data_batch_4.csv')

# %%
len(batch_1)
# Out:
# 959

# %%
len(batch_2)
# Out:
# 949

# %%
len(batch_3)
# Out:
# 936

# %%
len(batch_4)
# Out:
# 805

# %%
df = pd.DataFrame()

# %%
df = pd.concat([batch_1, batch_2, batch_3, batch_4], ignore_index=True)

# %%
len(df)
# Out:
# 3649

# %%
df.head(100)
# Out:
#      title_id                                  title   box_office  \
# 0   tt6856592                              #Captured          NaN
# 1   tt6479626                       #CoEdConfessions          NaN
# 2   tt6119504                           #REALITYHIGH          NaN
# 3   tt5654204                        #Slaughterhouse          NaN
# 4   tt6046566                               #humbled          NaN
# 5   tt6359426                       #murderchallenge          NaN
# 6   tt6608094                                      &          NaN
# 7   tt0326716                                5-25-77          NaN
# 8   tt4685428                                 1 Buck          NaN
# 9   tt2184233                          1 Mile to You          NaN
# 10  tt6235650                                  10/31          NaN
# 11  tt6105714                             100 Blocks          NaN
# 12  tt5760674                         1040 Not So EZ          NaN
# 13  tt5143226                           12 Feet Deep          NaN
# 14  tt5544754                         12 Pound Balls          NaN
# 15  tt3396208                           12 Round Gun          NaN
# 16  tt5193216                            13 Chambers          NaN
# 17  tt6544454                           13 Minuteman          NaN
# 18  tt7385874                                18 Days          NaN
# 19  tt6214928                                   1922          NaN
# 20  tt5748356                                   1948          NaN
# 21  tt7732524                                   1993          NaN
# 22  tt7003386                                2 Lanes          NaN
# 23  tt3752610                        2 Years of Love          NaN
# 24  tt5475468                               20 Weeks          NaN
# 25  tt4762592                            200 Degrees          NaN
# 26  tt6864870                              200 Miles          NaN
# 27  tt5157616                                   2016          NaN
# 28  tt6361966   2016 Dancing Dolls a Christmas Story          NaN
# 29  tt6528348                   21st Century America          NaN
# ..        ...                                    ...          ...
# 70  tt6802896                              A Ciambra          NaN
# 71  tt4943620                A Closer Walk with Thee          NaN
# 72  tt5704912                      A Cowgirl's Story          NaN
# 73  tt2636186                  A Crack in Everything          NaN
# 74  tt5922124                     A Crooked Somebody          NaN
# 75  tt4385852           A Curry on an American Plate          NaN
# 76  tt3499358                         A Demon Within          NaN
# 77  tt6982394                     A Descent to Grace          NaN
# 78  tt6700004                         A Devil's Wind          NaN
# 79  tt4955992                      The Different Sun          NaN
# 80  tt1753383                        A Dog's Purpose  $64,304,940
# 81  tt6315010                    A Doggone Hollywood          NaN
# 82  tt6364638                         Winter Wedding          NaN
# 83  tt4817008              A Fancy Piece of Homicide          NaN
# 84  tt4151002                         A Feast of Man          NaN
# 85  tt8096860             A Feminist Christmas Carol          NaN
# 86  tt8070082            A First Time for Everything          NaN
# 87  tt5460552                      A Flush of Hearts          NaN
# 88  tt7476494                   A Frozen Christmas 2          NaN
# 89  tt6265828                          A Ghost Story   $1,594,798
# 90  tt5126730                                Haunted          NaN
# 91  tt5228262  A Happening of Monumental Proportions          NaN
# 92  tt6151110                A Journey Through Pines          NaN
# 93  tt3583390                    A Lack of Furniture          NaN
# 94  tt5766746                 A Long Time for Lovers          NaN
# 95  tt3760544                      A Loss of Shadows          NaN
# 96  tt2959606                 A Lotus 'Til Reckoning          NaN
# 97  tt7262820                       A Lover Betrayed          NaN
# 98  tt7690328                      A Meowy Christmas          NaN
# 99  tt4286432                       A Mermaid's Tale          NaN
#
#                                         country  \
# 0                                           USA
# 1                                           USA
# 2                                           USA
# 3                                           USA
# 4                                           USA
# 5                                           USA
# 6                                           USA
# 7                                           USA
# 8                                           USA
# 9                                           USA
# 10                                          USA
# 11                                          USA
# 12                                          USA
# 13                                          USA
# 14                                          USA
# 15                                          USA
# 16                                          USA
# 17                                          USA
# 18                                          USA
# 19                                          USA
# 20                                          USA
# 21                                          USA
# 22                                          USA
# 23                                          USA
# 24                                          USA
# 25                                          USA
# 26                                          USA
# 27                                          USA
# 28                                          USA
# 29                                          USA
# ..                                          ...
# 70  Italy, Brazil, Germany, France, Sweden, USA
# 71                                          USA
# 72                                          USA
# 73                                          USA
# 74                                          USA
# 75                                          USA
# 76                                          USA
# 77                                          USA
# 78                                          USA
# 79                                          USA
# 80                                   USA, India
# 81                                          USA
# 82                                          USA
# 83                                          USA
# 84                                          USA
# 85                                          USA
# 86                                          USA
# 87                                          USA
# 88                                          USA
# 89                                          USA
# 90                                          USA
# 91                                      USA, UK
# 92                                          USA
# 93                                          USA
# 94                                          USA
# 95                                          USA
# 96                                          USA
# 97                                          USA
# 98                                          USA
# 99                                          USA
#
#                                         genre  \
# 0                                    Thriller
# 1                             Comedy, Romance
# 2                      Comedy, Drama, Romance
# 3                              Action, Horror
# 4                                         NaN
# 5                                      Horror
# 6                                         NaN
# 7                               Comedy, Drama
# 8                             Drama, Thriller
# 9                       Drama, Romance, Sport
# 10                                     Horror
# 11                                      Drama
# 12                                      Drama
# 13                           Horror, Thriller
# 14                                     Comedy
# 15                               Drama, Sport
# 16                     Drama, Fantasy, Horror
# 17                              Action, Drama
# 18                                        NaN
# 19    Crime, Drama, Horror, Mystery, Thriller
# 20                                        NaN
# 21                                     Horror
# 22                                    Mystery
# 23                            Comedy, Romance
# 24                             Drama, Romance
# 25                                   Thriller
# 26                                      Drama
# 27                                     Horror
# 28                                     Family
# 29                                      Drama
# ..                                        ...
# 70                               Crime, Drama
# 71                              Drama, Horror
# 72                                     Family
# 73                                      Drama
# 74                            Drama, Thriller
# 75                                     Comedy
# 76                     Drama, Horror, Romance
# 77                                        NaN
# 78                                     Horror
# 79                                      Drama
# 80  Adventure, Comedy, Drama, Family, Fantasy
# 81                                     Family
# 82                                    Romance
# 83                   Crime, Mystery, Thriller
# 84                              Comedy, Drama
# 85                                     Comedy
# 86                                      Drama
# 87                               Crime, Drama
# 88                                  Animation
# 89                    Drama, Fantasy, Romance
# 90                          Mystery, Thriller
# 91                              Comedy, Drama
# 92                                      Drama
# 93                                    Romance
# 94                              Comedy, Drama
# 95                                   Thriller
# 96                                      Drama
# 97                                   Thriller
# 98                             Comedy, Family
# 99                   Adventure, Drama, Family
#
#                                              director  metascore  \
# 0                                         Joe Homokay        NaN
# 1   William Cardoza, Guillermo Gomez, Rachael Hada...        NaN
# 2                                    Fernando Lebrija        NaN
# 3                                       Dino Maglaris        NaN
# 4                                   Russell Max Simon        NaN
# 5                                    Michael Bilinski        NaN
# 6                                    Cedric van Eenoo        NaN
# 7                                Patrick Read Johnson        NaN
# 8                                       Fabien Dufils        NaN
# 9                                         Leif Tilden        NaN
# 10  Brett DeJager, Rocky Gray, Zane Hershberger, J...        NaN
# 11                                   Diaunte Thompson        NaN
# 12                                       David Nguyen        NaN
# 13                                     Matt Eskandari        NaN
# 14                                     Zachary Madson        NaN
# 15                                          Sam Upton        NaN
# 16  Jessica Aceti, Megumi Arai, Lindy Boustedt, Cl...        NaN
# 17                                       Chaz Feldman        NaN
# 18                                     Rafael Ragland        NaN
# 19                                       Zak Hilditch       70.0
# 20                                        Ken Sibanda        NaN
# 21                                        Elle Millie        NaN
# 22                                         Villa Mane        NaN
# 23                                       Thadd Turner        NaN
# 24                                   Leena Pendharkar        NaN
# 25                                   Giorgio Serafini        NaN
# 26                                       Sam Bathrick        NaN
# 27                               Gary Anthony Sturgis        NaN
# 28                                                NaN        NaN
# 29                                                NaN        NaN
# ..                                                ...        ...
# 70                                   Jonas Carpignano       70.0
# 71                       John C. Clark, Brie Williams        NaN
# 72                                  Timothy Armstrong        NaN
# 73                                Varushka Franceschi        NaN
# 74                                       Trevor White       74.0
# 75                                        San Banarje        NaN
# 76                        Ayush Banker, Justin LaReau        NaN
# 77                                   Daniel Kesselman        NaN
# 78                                         Bill Zebub        NaN
# 79                                          Reed Tang        NaN
# 80                                    Lasse Hallström       43.0
# 81                                       Jim Wynorski        NaN
# 82                                       Jake Helgren        NaN
# 83                                     Joseph Varhola        NaN
# 84                                     Caroline Golum        NaN
# 85                                                NaN        NaN
# 86                                  Reginald Flemming        NaN
# 87                                          Matt Mudd        NaN
# 88                                     Arleen Tamaray        NaN
# 89                                       David Lowery       84.0
# 90                                        Mahum Jamal        NaN
# 91                                         Judy Greer       35.0
# 92                                      Jimmy Andrews        NaN
# 93                                   Eric Neal Allred        NaN
# 94                                    David McElfresh        NaN
# 95              Jack Walker-Pearson, Patrick Scherrer        NaN
# 96                                    David McElfresh        NaN
# 97                                          Jeff Hare        NaN
# 98                                    Steve Rudzinski        NaN
# 99                                      Dustin Rikert        NaN
#
#                     production     rating  IMDB_rating rotten_tomatoes_rating  \
# 0                          NaN        NaN          6.1                    NaN
# 1                          NaN        NaN          NaN                    NaN
# 2                          NaN      TV-14          5.2                    NaN
# 3                          NaN        NaN          7.5                    NaN
# 4                          NaN        NaN          NaN                    NaN
# 5                          NaN    UNRATED          NaN                    NaN
# 6                          NaN        NaN          NaN                    NaN
# 7                          NaN        NaN          6.1                    NaN
# 8            Gravitas Ventures      TV-MA          6.0                    NaN
# 9            Gravitas Ventures      TV-14          6.3                    NaN
# 10                         NaN        NaN          6.6                    NaN
# 11                         NaN        NaN          8.5                    NaN
# 12                         NaN        NaN          NaN                    NaN
# 13                         NaN  Not Rated          5.6                    NaN
# 14                         NaN      TV-MA          4.0                    NaN
# 15                         NaN      TV-MA          4.6                    NaN
# 16                         NaN        NaN          NaN                    NaN
# 17                         NaN        NaN          NaN                    NaN
# 18                         NaN        NaN          NaN                    NaN
# 19                     Netflix      TV-MA          6.3                    90%
# 20                         NaN        NaN          NaN                    NaN
# 21                         NaN        NaN          3.8                    NaN
# 22                         NaN        NaN          3.9                    NaN
# 23                         NaN    UNRATED          4.3                    NaN
# 24  Uncork&#39;d Entertainment        NaN          5.0                    NaN
# 25                         NaN      TV-14          4.4                    NaN
# 26                         NaN        NaN          7.8                    NaN
# 27                         NaN        NaN          7.1                    NaN
# 28                         NaN        NaN          NaN                    NaN
# 29                         NaN        NaN          NaN                    NaN
# ..                         ...        ...          ...                    ...
# 70                   IFC Films    Unrated          6.9                    89%
# 71                         NaN        NaN          3.9                    NaN
# 72                 Rodeo Films         PG          5.3                    NaN
# 73                         NaN        NaN          5.3                    NaN
# 74                         NaN          R          6.2                    NaN
# 75                         NaN        NaN          NaN                    NaN
# 76                         NaN      TV-14          3.3                    NaN
# 77                         NaN        NaN          8.6                    NaN
# 78                         NaN    UNRATED          NaN                    NaN
# 79                         NaN        NaN          NaN                    NaN
# 80        Amblin Entertainment         PG          7.1                    35%
# 81                         NaN      TV-PG          3.8                    NaN
# 82                         NaN    Unrated          5.0                    NaN
# 83                         NaN        NaN          5.0                    NaN
# 84                         NaN  Not Rated          4.8                    NaN
# 85                         NaN        NaN          NaN                    NaN
# 86                         NaN        NaN          NaN                    NaN
# 87                         NaN        NaN          NaN                    NaN
# 88                         NaN      TV-Y7          2.8                    NaN
# 89             Ideaman Studios          R          6.8                    91%
# 90                         NaN        NaN          NaN                    NaN
# 91                         NaN          R          4.6                    NaN
# 92                         NaN        NaN          6.1                    NaN
# 93                         NaN        NaN          NaN                    NaN
# 94                         NaN        NaN          NaN                    NaN
# 95                         NaN        NaN          NaN                    NaN
# 96                         NaN        NaN          8.9                    NaN
# 97                         NaN  Not Rated          5.8                    NaN
# 98                         NaN        NaN          5.7                    NaN
# 99   Lighthouse Pictures, Inc.          G          4.8                    NaN
#
#     runtime   type IMDB_votes
# 0    81 min  movie      1,101
# 1    61 min  movie        NaN
# 2    99 min  movie      4,800
# 3       NaN  movie         24
# 4    76 min  movie        NaN
# 5       NaN  movie        NaN
# 6       NaN  movie        NaN
# 7   113 min  movie        299
# 8    90 min  movie      2,304
# 9   104 min  movie      2,000
# 10      NaN  movie         93
# 11   87 min  movie         11
# 12   90 min  movie        NaN
# 13   85 min  movie     11,102
# 14   80 min  movie        137
# 15   92 min  movie        172
# 16   73 min  movie        NaN
# 17      NaN  movie        NaN
# 18   92 min  movie        NaN
# 19  102 min  movie     42,125
# 20      NaN  movie        NaN
# 21   73 min  movie          5
# 22   56 min  movie         10
# 23   88 min  movie        111
# 24   90 min  movie        137
# 25   91 min  movie        447
# 26   50 min  movie          6
# 27      NaN  movie         36
# 28      NaN  movie        NaN
# 29   90 min  movie        NaN
# ..      ...    ...        ...
# 70  118 min  movie      1,816
# 71   90 min  movie        126
# 72   98 min  movie        434
# 73   90 min  movie         13
# 74  102 min  movie        625
# 75      NaN  movie        NaN
# 76   91 min  movie        558
# 77   78 min  movie          7
# 78      NaN  movie        NaN
# 79      NaN  movie        NaN
# 80  100 min  movie     58,759
# 81   84 min  movie         18
# 82   90 min  movie        290
# 83  100 min  movie         51
# 84   82 min  movie         11
# 85      NaN  movie        NaN
# 86   49 min  movie        NaN
# 87      NaN  movie        NaN
# 88   70 min  movie         20
# 89   92 min  movie     50,702
# 90      NaN  movie        NaN
# 91   81 min  movie        554
# 92  115 min  movie         10
# 93      NaN  movie        NaN
# 94   75 min  movie        NaN
# 95      NaN  movie        NaN
# 96  111 min  movie          8
# 97   90 min  movie        130
# 98   60 min  movie         35
# 99   92 min  movie        329
#
# [100 rows x 14 columns]

# %%
df = df[df.box_office.notnull()]

# %%
len(df)
# Out:
# 195

# %%
df.to_csv('../data/compiled_2017_data.csv', index=False)
