# %%
import pandas as pd
import requests
import json
import time
from pprint import pprint
from config import API_KEY

# %%
data = pd.read_csv('../title_webscraped/titles_2017_batch1.csv')
df =  data.count()
df
# Out:
# title    1000
# dtype: int64

# %%
title_id = []
box_office_list = []
country_list = []
genre_list = []
director_list = []
metascore_list = []
production_list = []
rating_list = []
IMDB_rating_list = [] 
rotten_tomatoes_rating_list = []
runtime_list = []
title_list = []
type_list = []
imdb_votes_list = []

# %%
movies = data['title']
total_movies = len(movies)

# %%
for i in range(total_movies):
    movie = movies[i]
    url = "http://www.omdbapi.com/?i=" + movie + "&apikey=" + API_KEY
    response = (requests.get(url).text)
    response_json = json.loads(response)
    print('-------------------')
    print(f'movie id {movie}')
    print('-------------------')
    pprint(response_json)
    
    try:
        box_office_list.append(response_json['BoxOffice'])
        country_list.append(response_json['Country'])
        genre_list.append(response_json['Genre'])
        director_list.append(response_json['Director'])
        metascore_list.append(response_json['Metascore'])
        production_list.append(response_json['Production'])
        rating_list.append(response_json['Rated'])
        IMDB_rating_list.append(response_json['imdbRating'])
        try:
            if not response_json['Ratings']:
                rotten_tomatoes_rating_list.append('NA')
            elif response_json['Ratings'][0]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][0]['Value'])
            elif response_json['Ratings'][1]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][1]['Value'])
            else:
                rotten_tomatoes_rating_list.append('NA')
        except IndexError:
            rotten_tomatoes_rating_list.append('NA')
        runtime_list.append(response_json['Runtime'])
        title_list.append(response_json['Title'])
        type_list.append(response_json['Type'])
        imdb_votes_list.append(response_json['imdbVotes'])
        title_id.append(response_json['imdbID'])
    except KeyError:
        pass
    time.sleep(1)
# Out:
# -------------------
# movie id tt6856592
# -------------------
# {'Actors': 'Lizze Gordon, Gabrielle Romanello, Megan Medellin, Charlie Ian',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Joe Homokay',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A group of privileged high school kids run an illicit chat room '
#          'where they livestream their drug fueled sex parties to paying '
#          "viewers on the internet. Little do they know there's a murderous "
#          'zealot on a mission to rid the internet of sin.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZDBmYTEwZWMtNzc2OC00N2M5LWJmNGEtNDI5OTZiM2RmMDJkXkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'}],
#  'Released': '05 Sep 2017',
#  'Response': 'True',
#  'Runtime': '81 min',
#  'Title': '#Captured',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Lizze Gordon',
#  'Year': '2017',
#  'imdbID': 'tt6856592',
#  'imdbRating': '6.1',
#  'imdbVotes': '1,101'}
# -------------------
# movie id tt6479626
# -------------------
# {'Actors': 'Nicole Anderson, Bruna Brito, Janine Bunag, Chance Aaron Conley',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'William Cardoza, Guillermo Gomez, Rachael Hadassah, Djordje '
#              'Mladenovic, Kent Palzes',
#  'Genre': 'Comedy, Romance',
#  'Language': 'English, English',
#  'Metascore': 'N/A',
#  'Plot': 'A mystical and rebellious "Jewish goth girl" named Wednesday gathers '
#          'together with her college friends to create a plan to destroy the '
#          'normalcy of McDonaldization of dating when little ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODJmNzY1MTgtZjkyNC00YjQ2LTliODItMzc1Nzg5YWRlNjk1L2ltYWdlXkEyXkFqcGdeQXVyNzE5Njg1OTk@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '26 Jan 2017',
#  'Response': 'True',
#  'Runtime': '61 min',
#  'Title': '#CoEdConfessions',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Rachael Hadassah, Eric Utomo, Adina Pernell',
#  'Year': '2017',
#  'imdbID': 'tt6479626',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6119504
# -------------------
# {'Actors': 'Nesta Cooper, Keith Powers, Alicia Sanz, Jake Borelli',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Fernando Lebrija',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'High-achieving high-school senior Dani Barnes dreams of getting into '
#          "UC Davis, the world's top veterinary school. Then a glamorous new "
#          'friend draws her into a Southern California scene that threatens '
#          "everything she's worked for.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDU3Mzk0ODAtMzI0Ni00YTUzLWIyNDctMDE3OTE3OTk4OWE2XkEyXkFqcGdeQXVyNTM0MDc1ODE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'TV-14',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.2/10'}],
#  'Released': '08 Sep 2017',
#  'Response': 'True',
#  'Runtime': '99 min',
#  'Title': '#REALITYHIGH',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Brandon Broussard, Hudson Obayuwana, Jana Savage',
#  'Year': '2017',
#  'imdbID': 'tt6119504',
#  'imdbRating': '5.2',
#  'imdbVotes': '4,800'}
# -------------------
# movie id tt5654204
# -------------------
# {'Actors': 'Nicholas Saenz, Shayla Bagir, Karina Clark, David Harrod Jr.',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Dino Maglaris',
#  'Genre': 'Action, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A romantic spring getaway turns sinister when unexpected visitors '
#          'join the party in a high-tech house that no one can escape.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNGNhZTk5M2MtMzUzYy00NmZkLTljZmItZTU5MDU4Y2M0N2I4XkEyXkFqcGdeQXVyMjM1NTY3Njk@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.5/10'}],
#  'Released': '01 Jul 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '#Slaughterhouse',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Scott McGuire',
#  'Year': '2017',
#  'imdbID': 'tt5654204',
#  'imdbRating': '7.5',
#  'imdbVotes': '24'}
# -------------------
# movie id tt6046566
# -------------------
# {'Actors': 'Coleman Gladis, Kaelan Denali Dickinson, Diego F. Salinas, '
#            'Katherine Folk-Sullivan',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Russell Max Simon',
#  'Genre': 'N/A',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'Art. Ambition. Community Theatre. An idealistic young theatre '
#          'director leads her vagabond cast & crew through the pitfalls of a '
#          'fledging indie production, navigating relationships, egos, ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTM3MzQwZmItYTU5NS00ZGNlLTkxYmEtNzZlNDdmYjBiODc2XkEyXkFqcGdeQXVyNTUzNDE0NjI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '76 min',
#  'Title': '#humbled',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Russell Max Simon',
#  'Year': '2016',
#  'imdbID': 'tt6046566',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6359426
# -------------------
# {'Actors': 'Shane Ryan, Jenna Renee, Vex X. Starskream, Louis Galdo',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Michael Bilinski',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A group of filmmakers attempt to debunk a series if viral videos '
#          'featuring a masked assailant murdering women in a wooded area that '
#          'have spawned a dangerous Internet challenge.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYjgzMmM2MDgtYTI3YS00MGQ5LThiZjktYzVmOTAwMjNlMTQxL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNzA2NjY1NDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'UNRATED',
#  'Ratings': [],
#  'Released': '31 Oct 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '#murderchallenge',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Bilinski',
#  'Year': '2017',
#  'imdbID': 'tt6359426',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6608094
# -------------------
# {'Actors': 'Julien Ravetto',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Cedric van Eenoo',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '03 Mar 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '&',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2017',
#  'imdbID': 'tt6608094',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt0326716
# -------------------
# {'Actors': 'John Francis Daley, Austin Pendleton, Colleen Camp, Neil Flynn',
#  'Awards': '2 wins.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Patrick Read Johnson',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Alienated, hopeful-filmmaker Pat Johnson's epic story growing up in "
#          'rural Illinois, falling in love, and becoming the first fan of the '
#          'movie that changed everything.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjAxOTQyMzk2M15BMl5BanBnXkFtZTcwNzQ2NzI4Nw@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'}],
#  'Released': '25 May 2017',
#  'Response': 'True',
#  'Runtime': '113 min',
#  'Title': '5-25-77',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Patrick Read Johnson',
#  'Year': '2017',
#  'imdbID': 'tt0326716',
#  'imdbRating': '6.1',
#  'imdbVotes': '299'}
# -------------------
# movie id tt4685428
# -------------------
# {'Actors': 'John Freeman, Katie Ryan, Cassi Colvin, Will Green',
#  'Awards': '28 wins & 10 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '22 Sep 2017',
#  'Director': 'Fabien Dufils',
#  'Genre': 'Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Shifting from one pocket to another, from one man's drama to "
#          "another, a lowly dollar bill, 'one buck' takes us on an odyssey "
#          'through the heart of a forgotten town in Louisiana.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BY2Q5YzI2NGMtNWE0Yy00YWMzLTg5NDMtODNhNzQ5MTYwOTg0XkEyXkFqcGdeQXVyNDUyMzM5NDc@._V1_SX300.jpg',
#  'Production': 'Gravitas Ventures',
#  'Rated': 'TV-MA',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.0/10'}],
#  'Released': '22 Sep 2017',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': '1 Buck',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Fabien Dufils',
#  'Year': '2017',
#  'imdbID': 'tt4685428',
#  'imdbRating': '6.0',
#  'imdbVotes': '2,304'}
# -------------------
# movie id tt2184233
# -------------------
# {'Actors': 'Graham Rogers, Tim Roth, Justin McCammom, Ty Parker',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Leif Tilden',
#  'Genre': 'Drama, Romance, Sport',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "After a teenager's friends die in an accident, he finds running "
#          'allows him to remember them perfectly. Running, however, also brings '
#          'him notoriety. He is caught between keeping the past alive and '
#          'making new memories in the present.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjQ4NDE0MzQ3Ml5BMl5BanBnXkFtZTgwMTY4MzY1MTI@._V1_SX300.jpg',
#  'Production': 'Gravitas Ventures',
#  'Rated': 'TV-14',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'}],
#  'Released': '07 Apr 2017',
#  'Response': 'True',
#  'Runtime': '104 min',
#  'Title': '1 Mile to You',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jeremy Jackson (novel), Marc Novak',
#  'Year': '2017',
#  'imdbID': 'tt2184233',
#  'imdbRating': '6.3',
#  'imdbVotes': '2,000'}
# -------------------
# movie id tt6235650
# -------------------
# {'Actors': 'Hanleigh Baker, Chad Bruns, Barry Clifton, Greg Fallon',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Brett DeJager, Rocky Gray, Zane Hershberger, John William Holt, '
#              'Hunter Johnson, Justin M. Seaman',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'This is an anthology film consisting of 5 horror tales from 5 '
#          'different writers.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYzAxMjJmZGMtOGZhOC00MDJhLWEyNmMtNDk2MGUxOTkxODEwXkEyXkFqcGdeQXVyNTUzNzUwNzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'}],
#  'Released': '01 Oct 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '10/31',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': "Brett DeJager (The Halloween Blizzard of '91), Rocky Gray ('The "
#            "Samhain Slasher' segment), Zane Hershberger ('Trespassers' "
#            "segment), Justin M. Seaman ('The Old Hag' segment), Jason Turner "
#            '(Killing The Dance)',
#  'Year': '2017',
#  'imdbID': 'tt6235650',
#  'imdbRating': '6.6',
#  'imdbVotes': '93'}
# -------------------
# movie id tt6105714
# -------------------
# {'Actors': 'Sara Anders, Mitch Costanza, Tina Gilton, Don Hardwick',
#  'Awards': '1 win & 2 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Diaunte Thompson',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When a young man tries to escape the cycle of violence and leave the '
#          'streets behind, he finds himself at a crossroads as unexpected '
#          'events change his plans.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYTgwYjE3OWItOGE3My00ZmQ1LWE3ZDUtZTlhMzYxMGIwNDdkXkEyXkFqcGdeQXVyMjU5NTY0MjM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.5/10'}],
#  'Released': '15 Jun 2017',
#  'Response': 'True',
#  'Runtime': '87 min',
#  'Title': '100 Blocks',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Arthur Walls',
#  'Year': '2017',
#  'imdbID': 'tt6105714',
#  'imdbRating': '8.5',
#  'imdbVotes': '11'}
# -------------------
# movie id tt5760674
# -------------------
# {'Actors': 'Timeca M. Seretti, Woody Wilson Hall, Quinton Simpson, Jesse '
#            'Marshall',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'David Nguyen',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A Ponzi scheme turns out bad as an Army sergeant and his buddies try '
#          'to make it rich by outsmarting the government, the law and their own '
#          'hometown.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTRkYTNkMjQtMjg3ZS00ODY1LTk5YTAtZjZmMWI1NWY5NTY5XkEyXkFqcGdeQXVyNTg4MDk4MDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '15 Apr 2017',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': '1040 Not So EZ',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Andre Hillard',
#  'Year': '2017',
#  'imdbID': 'tt5760674',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5143226
# -------------------
# {'Actors': 'Nora-Jane Noone, Alexandra Park, Diane Farr, Tobin Bell',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Matt Eskandari',
#  'Genre': 'Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Inspired by true events, two sisters are trapped under the '
#          'fiberglass cover of an Olympic sized public pool and must brave the '
#          'cold and each other to survive the harrowing night.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOWM5ZWFmZTItMGVhMC00MGQwLTgzYzktOTIxMGY4YWVkZjYxXkEyXkFqcGdeQXVyMzk3OTY0OA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.6/10'}],
#  'Released': '20 Jun 2017',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': '12 Feet Deep',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Matt Eskandari, Michael Hultquist',
#  'Year': '2017',
#  'imdbID': 'tt5143226',
#  'imdbRating': '5.6',
#  'imdbVotes': '11,102'}
# -------------------
# movie id tt5544754
# -------------------
# {'Actors': 'Jessica Kozak, Jake Head, Nick Hardcastle, Burke Brown',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Zachary Madson',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "It takes BALLS to win. At least that's what the local bowling clubs "
#          'in idyllic Warroad, Minnesota used to say, before Emily came along. '
#          'Now that she has returned to resurrect her name on ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQzNzczODMtMTkzMS00ZDY1LTliNGMtNmVmZjk3ODFkZGZhXkEyXkFqcGdeQXVyMTk2NzgyNg@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'TV-MA',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.0/10'}],
#  'Released': '16 May 2017',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': '12 Pound Balls',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Zachary Madson',
#  'Year': '2017',
#  'imdbID': 'tt5544754',
#  'imdbRating': '4.0',
#  'imdbVotes': '137'}
# -------------------
# movie id tt3396208
# -------------------
# {'Actors': 'Mark Boone Junior, Kate Vernon, Cassi Thomson, Jared Abrahamson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Sam Upton',
#  'Genre': 'Drama, Sport',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A washed up, alcoholic ex-prizefighter makes a comeback to boxing '
#          'after his top heavyweight contender son is wrongfully blinded in the '
#          'ring.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDg4OTc5MDgwMV5BMl5BanBnXkFtZTgwMTMxMTE5NzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'TV-MA',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.6/10'}],
#  'Released': '16 Nov 2018',
#  'Response': 'True',
#  'Runtime': '92 min',
#  'Title': '12 Round Gun',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Sam Upton',
#  'Year': '2017',
#  'imdbID': 'tt3396208',
#  'imdbRating': '4.6',
#  'imdbVotes': '172'}
# -------------------
# movie id tt5193216
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jessica Aceti, Megumi Arai, Lindy Boustedt, Claire Buss, Gisella '
#              'Bustillos, Nancy Chang, Dayna Hanson, Kat Larson, Wynter Rhys, '
#              'Norma Jean Straw',
#  'Genre': 'Drama, Fantasy, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': '13 female filmmakers explore themes of the uncanny, the '
#          'supernatural, and the sublime in a series of 13 short films '
#          'featuring a killer twin, an interdimensional time traveler, a doomed '
#          '...',
#  'Poster': 'https://ia.media-imdb.com/images/M/MV5BMzRlODYxMmQtNDExMi00NjQxLWFhOTAtM2NkOGNkZDQ4YjIzXkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '73 min',
#  'Title': '13 Chambers',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2017',
#  'imdbID': 'tt5193216',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6544454
# -------------------
# {'Actors': 'Tony Devon, Susan Glover, Myke Michaels, Jason Knight',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Chaz Feldman',
#  'Genre': 'Action, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An ex-sports agent finds solace in scamming professional athletes.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZTJmODM3NjMtY2Y3Mi00ZWM3LWExMjYtNGJkYWE0ODI5MWE4XkEyXkFqcGdeQXVyMjk2MzM1MTI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Aug 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '13 Minuteman',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Chaz Feldman',
#  'Year': '2017',
#  'imdbID': 'tt6544454',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7626918
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt6821990
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt7385874
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Rafael Ragland',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "A man who's lives another life in his coma for 18 Days",
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '92 min',
#  'Title': '18 Days',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2017',
#  'imdbID': 'tt7385874',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6214928
# -------------------
# {'Actors': 'Thomas Jane, Molly Parker, Dylan Schmid, Kaitlyn Bernard',
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '20 Oct 2017',
#  'Director': 'Zak Hilditch',
#  'Genre': 'Crime, Drama, Horror, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': '70',
#  'Plot': 'A simple yet proud farmer in the year 1922 conspires to murder his '
#          'wife for financial gain, convincing his teenage son to assist. But '
#          'their actions have unintended consequences.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYTFmYmJkM2YtYzFjNS00NGI2LThiOWMtNGVhZDZiOGI0NDBhXkEyXkFqcGdeQXVyNjU1OTMzNDU@._V1_SX300.jpg',
#  'Production': 'Netflix',
#  'Rated': 'TV-MA',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '90%'},
#              {'Source': 'Metacritic', 'Value': '70/100'}],
#  'Released': '20 Oct 2017',
#  'Response': 'True',
#  'Runtime': '102 min',
#  'Title': '1922',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Stephen King (novel), Zak Hilditch (screenplay)',
#  'Year': '2017',
#  'imdbID': 'tt6214928',
#  'imdbRating': '6.3',
#  'imdbVotes': '42,125'}
# -------------------
# movie id tt5748356
# -------------------
# {'Actors': "Jeanne Bella O'Brien, Kar Logan",
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ken Sibanda',
#  'Genre': 'N/A',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'The South African National Party comes into power in 1948 and '
#          'embarks on a Nazi policy of segregated Apartheid. A cafe owner, Tony '
#          'Mzila, is caught up in the new laws.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '25 Dec 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '1948',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ken Sibanda',
#  'Year': '2016',
#  'imdbID': 'tt5748356',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7732524
# -------------------
# {'Actors': 'Thomas Webb, Kaden Christie, Ella Garland, Lola Kraft',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Elle Millie',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'In 1993 a time of radical movies and music Chuck and his family live '
#          'an old house where everything is good he has a camera and many '
#          'tapes. He thought feels something is off with the house ...',
#  'Poster': 'https://ia.media-imdb.com/images/M/MV5BYjYzNjk0ZmMtNjc0YS00YzFiLTk4Y2YtMTEyYTA2Y2RmMTQ0XkEyXkFqcGdeQXVyNjY5MjQ4OTc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.8/10'}],
#  'Released': '16 Oct 2017',
#  'Response': 'True',
#  'Runtime': '73 min',
#  'Title': '1993',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Yuki Matsui',
#  'Year': '2017',
#  'imdbID': 'tt7732524',
#  'imdbRating': '3.8',
#  'imdbVotes': '5'}
# -------------------
# movie id tt7003386
# -------------------
# {'Actors': 'Villa Mane, Randy Scott, Kila Simone',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Villa Mane',
#  'Genre': 'Mystery',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': '2 sci-fi stories By Villain TV that take place in urban Alabama.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BY2RhZTQyZTctMTY4ZC00NjAzLTgyZjAtZGQxYmRlMjMwODkwXkEyXkFqcGdeQXVyNDczNjUyNDU@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.9/10'}],
#  'Released': '14 Feb 2017',
#  'Response': 'True',
#  'Runtime': '56 min',
#  'Title': '2 Lanes',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Villa Mane',
#  'Year': '2017',
#  'imdbID': 'tt7003386',
#  'imdbRating': '3.9',
#  'imdbVotes': '10'}
# -------------------
# movie id tt3752610
# -------------------
# {'Actors': 'Ryan Merriman, Kayla Ewell, Sarah Minnich, Catharine E. Jones',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Thadd Turner',
#  'Genre': 'Comedy, Romance',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': "Samantha a popular 'Dear Abby' radio show host feels her biological "
#          'clock ticking and is ready to start a family - if only she could '
#          'convince her out of work husband John.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNmQwNzc3ZTEtZjFjYi00NzAyLTgzYmUtNzYyZmMzYjgxYjc0XkEyXkFqcGdeQXVyMzE5NTM0Nw@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'UNRATED',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.3/10'}],
#  'Released': '24 Jan 2017',
#  'Response': 'True',
#  'Runtime': '88 min',
#  'Title': '2 Years of Love',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Lenny Mesi (story by), Lenny Mesi, Nicole Rayburn (story)',
#  'Year': '2017',
#  'imdbID': 'tt3752610',
#  'imdbRating': '4.3',
#  'imdbVotes': '111'}
# -------------------
# movie id tt5475468
# -------------------
# {'Actors': 'Richard Riehle, Michelle Krusiec, Jocelin Donahue, Amir Arison',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '13 Apr 2018',
#  'Director': 'Leena Pendharkar',
#  'Genre': 'Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A couple must decide on how to move forward when their baby is '
#          'diagnosed with a serious health condition at the 20 week scan.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYWFlNzg2YzItNzNmNC00ZmE0LWI3NTUtYWZhYzA1MDg2ZTlmXkEyXkFqcGdeQXVyMzkzNDMxNQ@@._V1_SX300.jpg',
#  'Production': 'Uncork&#39;d Entertainment',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.0/10'}],
#  'Released': '19 Jun 2017',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': '20 Weeks',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Leena Pendharkar',
#  'Year': '2017',
#  'imdbID': 'tt5475468',
#  'imdbRating': '5.0',
#  'imdbVotes': '137'}
# -------------------
# movie id tt4762592
# -------------------
# {'Actors': 'Eric Balfour, Larry Wade Carrell, Kristin Cochell, Joe Grisaffi',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Giorgio Serafini',
#  'Genre': 'Thriller',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'Ryan Hinds awakes inside a sealed industrial kiln. He is sent '
#          'challenges by a voice with no face, pushed to the limits of human '
#          'endurance as the temperature within the kiln begins to rise.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTdiNGZhZGQtMDU5MS00NjVmLWExYzYtYTQ3MjdmNTRiYTExXkEyXkFqcGdeQXVyNDg3MTQxOTg@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'TV-14',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.4/10'}],
#  'Released': '06 Jun 2017',
#  'Response': 'True',
#  'Runtime': '91 min',
#  'Title': '200 Degrees',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Garry Charles',
#  'Year': '2017',
#  'imdbID': 'tt4762592',
#  'imdbRating': '4.4',
#  'imdbVotes': '447'}
# -------------------
# movie id tt6864870
# -------------------
# {'Actors': 'Eric Gelber, Tani Gelber',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Sam Bathrick',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': '200 Miles is the inspiring story of ultra-marathoner, Eric Gelber, '
#          "who attempted to run a record 200 miles around New York's Central "
#          'Park to raise awareness and $1 million dollars for the Multiple '
#          'Myeloma Research Foundation (MMRF).',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZWYwMGEwM2ItNjlhNi00Mjg2LWI4NjctMTYzMWYyYmE5MGZjXkEyXkFqcGdeQXVyMTkyNDM5OTA@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.8/10'}],
#  'Released': '26 Apr 2017',
#  'Response': 'True',
#  'Runtime': '50 min',
#  'Title': '200 Miles',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2017',
#  'imdbID': 'tt6864870',
#  'imdbRating': '7.8',
#  'imdbVotes': '6'}
# -------------------
# movie id tt5157616
# -------------------
# {'Actors': 'K.D. Aubert, Miguel A. Núñez Jr., Denyce Lawton, Ernest Pierce',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Gary Anthony Sturgis',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'In 2016 a Zombie outbreak has occurred around the globe and now a '
#          'group of people must work together to survive the Zombie rampage.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjE0NzE0MjYxNF5BMl5BanBnXkFtZTgwMDM0NjkxNzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.1/10'}],
#  'Released': '06 Jan 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '2016',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Gary Anthony Sturgis',
#  'Year': '2016',
#  'imdbID': 'tt5157616',
#  'imdbRating': '7.1',
#  'imdbVotes': '36'}
# -------------------
# movie id tt6361966
# -------------------
# {'Actors': 'Amanda LaCount, Wallace Demarria, Alectra Taniece Cox',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '2016 Dancing Dolls a Christmas Story',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Charon Aldredge',
#  'Year': '2016',
#  'imdbID': 'tt6361966',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7820982
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt6528348
# -------------------
# {'Actors': 'Elva Coronado, Emely Brumet, Miles Tucker, Blanca Vargas',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'Drama',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'A look at several ordinary high school students as they slowly find '
#          'their way into adulthood.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BM2U2NWFjZjItOGZiZC00Njg2LTgyNGItOTM0Y2QzZGZjYzc0XkEyXkFqcGdeQXVyNDE1Mjg1MTI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '17 Dec 2017',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': '21st Century America',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2017',
#  'imdbID': 'tt6528348',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5442456
# -------------------
# {'Actors': 'Ethan Hawke, Qing Xu, Paul Anderson, Rutger Hauer',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'South Africa, China, USA',
#  'DVD': '06 Feb 2018',
#  'Director': 'Brian Smrz',
#  'Genre': 'Action, Sci-Fi, Thriller',
#  'Language': 'English, Chinese',
#  'Metascore': '37',
#  'Plot': 'An assassin seeks redemption after being given a second chance at '
#          'life.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjAyNjY0MjU1NF5BMl5BanBnXkFtZTgwMjAwNDMwNDI@._V1_SX300.jpg',
#  'Production': 'Saban Films',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.7/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '52%'},
#              {'Source': 'Metacritic', 'Value': '37/100'}],
#  'Released': '26 Jan 2018',
#  'Response': 'True',
#  'Runtime': '93 min',
#  'Title': '24 Hours to Live',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ron Mita, Jim McClain, Zach Dean',
#  'Year': '2017',
#  'imdbID': 'tt5442456',
#  'imdbRating': '5.7',
#  'imdbVotes': '11,016'}
# -------------------
# movie id tt6748368
# -------------------
# {'Actors': 'Evan Kyle Bennett',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Rhondak Bennett',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZWNiOTBjZjktMDI2MS00MWM1LWJmZjItOTk0NmM3ZjA2ZDA0XkEyXkFqcGdeQXVyNDcwNDU0MDI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '25 Apr 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '287G Black Latina',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2017',
#  'imdbID': 'tt6748368',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5119720
# -------------------
# {'Actors': 'Brett Tribe, Erica Lies, Anne Frances, Ed Pope',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Matt Thornton',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Adam is approaching the age of 30 - yet he's still delivering pizzas "
#          "in the suburbs. Will he continue on a path that's comfortable or "
#          'choose to make a few changes in his life.',
#  'Poster': 'https://ia.media-imdb.com/images/M/MV5BOTU0ZDliYTItOWM1Yi00NzQxLWE1MDMtYzgzZWIzMTgzYjIyXkEyXkFqcGdeQXVyMjc1MjI5ODk@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': '29 Light Years',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Matt Thornton (story)',
#  'Year': '2015',
#  'imdbID': 'tt5119720',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5670648
# -------------------
# {'Actors': 'Marizo Siller, John Snedden, Ivvan Pignon, Taylor Alden Thompson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ivvan Pignon',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The day in the life of a pot dealer searching for answers after his '
#          'long time girlfriend leaves him.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjhhMWIzMzEtNTY4MC00NTYwLTkxNDAtZTgxZDUxZDAxZjU3XkEyXkFqcGdeQXVyNjY2MzAyNzI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': '29 or: The Day a Girl Broke Up with a Boy',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ivvan Pignon',
#  'Year': '2017',
#  'imdbID': 'tt5670648',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt1131724
# -------------------
# {'Actors': 'Michiel Huisman, Teresa Palmer, Sam Reid, John Waters',
#  'Awards': '1 win & 2 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'Australia, USA',
#  'DVD': '30 Jun 2017',
#  'Director': 'Paul Currie',
#  'Genre': 'Drama, Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "A man's life is derailed when an ominous pattern of events repeats "
#          'itself in exactly the same manner every day, ending at precisely '
#          '2:22 p.m.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZTNlOGE0YzUtZmU2Yi00M2RkLWJkNjQtODlmZThmYmYzNWI2XkEyXkFqcGdeQXVyNDQ0MTYzMDA@._V1_SX300.jpg',
#  'Production': 'Magnolia Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '22%'}],
#  'Released': '30 Jun 2017',
#  'Response': 'True',
#  'Runtime': '98 min',
#  'Title': '2:22',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Todd Stein (story by), Todd Stein (screenplay by), Nathan Parker '
#            '(screenplay by)',
#  'Year': '2017',
#  'imdbID': 'tt1131724',
#  'imdbRating': '5.8',
#  'imdbVotes': '17,328'}
# -------------------
# movie id tt5618160
# -------------------
# {'Actors': 'Todd Bruno, Aniela McGuinness, Mike Stanley, Jim Adams',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Lou Simon',
#  'Genre': 'Horror, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A man and a woman kidnap her rapist in order to extract a '
#          'confession, come hell or - hell.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTViOGFjMjQtMGIwMC00ZDRjLWFjODUtMWZlMDdlNWM1NTJjXkEyXkFqcGdeQXVyMjQ0MzU0NDc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.2/10'}],
#  'Released': '07 Aug 2018',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': '3',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Lou Simon',
#  'Year': '2018',
#  'imdbID': 'tt5618160',
#  'imdbRating': '4.2',
#  'imdbVotes': '183'}
# -------------------
# movie id tt7271958
# -------------------
# {'Actors': 'Nathan Martinez, Jordan Tanner, Luke Fowler, Mark Gibbons',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Aaron Martinez',
#  'Genre': 'Drama, Mystery, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An apocalyptic survivor searches for his daughter in the Terlingua '
#          'desert while two caseworkers, holed up in a bunker, watch and record '
#          'his every move.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMDViNTVkMGQtMDQ5My00ZTE5LTk0MTktYmUzNDUyZmIxNTdiXkEyXkFqcGdeQXVyODI2OTM3MjY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '108 min',
#  'Title': '3 Days on the Cross',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Aaron Martinez',
#  'Year': '2017',
#  'imdbID': 'tt7271958',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7423004
# -------------------
# {'Actors': 'Todd Anthony Manaigo, Kimberly Ann Parker, Nhadya Salomon, Katie '
#            'Sawhill',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Corey L. Branch',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Dan and Heather Winslow are faced with the biggest challenge in '
#          'their marriage when life throws them a second curve ball. After Dan '
#          'ask Heather for a divorce and she receives life changing ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOThjZTRiZjctZWIxYi00ZGU4LTk3NTctMDQ5NTM0MWFmYjBiXkEyXkFqcGdeQXVyNzA3MzkzMTY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': '30 Day Promise',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Corey L. Branch',
#  'Year': '2017',
#  'imdbID': 'tt7423004',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3421318
# -------------------
# {'Actors': 'Robert Cannon, Brenda Vaccaro, Justin Lee, Mark Gagliardi',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Robert Cannon',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When his wife dies giving birth to their first child, a man starts '
#          'playing tennis in an effort to hold onto her memory. He neglects his '
#          'newborn daughter and focuses on winning tennis ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjE0MTk0ODQ5M15BMl5BanBnXkFtZTgwOTY4OTE5MDE@._V1_SX300.jpg',
#  'Production': 'Indie Rights',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '103 min',
#  'Title': '30-Love',
#  'Type': 'movie',
#  'Website': 'http://30-lovefilm.com/',
#  'Writer': 'Robert Cannon, Robert Cannon, Ira Heffler, Ira Heffler',
#  'Year': '2015',
#  'imdbID': 'tt3421318',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4346510
# -------------------
# {'Actors': 'Sanna Haynes, Kwajalyn Brown, Jordan Rice, Maria Liatis',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Sanna Haynes',
#  'Genre': 'Comedy',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'A documentary filmmaker investigates an open call day at a modeling '
#          'agency and meets several characters along the way.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '34 Inches',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Sanna Haynes',
#  'Year': '2016',
#  'imdbID': 'tt4346510',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6057540
# -------------------
# {'Actors': 'Gillian Clark, Richard Collins, Jennifer Croutch, Rob Fletcher',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Canada',
#  'DVD': 'N/A',
#  'Director': 'Pierre St-Jacques',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "A couple in love is a violent thing - I'm going to shape you, and "
#          "you're going to shape me. In 36 Steps on a Curved Road, we follow a "
#          'couple over a 40 year period. While we witness their ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMGIxNmNjNTktMzBlNy00ZjA3LTlkZTUtYjBiYWM1YjgyNDc5XkEyXkFqcGdeQXVyNjg0NjIwNTQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '08 Aug 2017',
#  'Response': 'True',
#  'Runtime': '83 min',
#  'Title': '36 Steps on a Curved Road',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Pierre St-Jacques',
#  'Year': '2017',
#  'imdbID': 'tt6057540',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2595708
# -------------------
# {'Actors': 'Lorena Bernal, Carlo Mendez',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Argentina',
#  'DVD': 'N/A',
#  'Director': 'Martin DeLuca',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When politics become redemption, the past will begin to reveal the '
#          'future. The perfect place to get away with murder, is home.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYTBlYjQyNmYtOTY3My00YTBhLThhMWUtMWRhZmZkNTkzODRiXkEyXkFqcGdeQXVyMTQ3MTIyMjQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '07 Jul 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '44 at Melrose',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Martin DeLuca',
#  'Year': '2017',
#  'imdbID': 'tt2595708',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2932536
# -------------------
# {'Actors': 'Mandy Moore, Claire Holt, Chris Johnson, Yani Gellman',
#  'Awards': '1 nomination.',
#  'BoxOffice': '$44,305,642',
#  'Country': 'UK, USA',
#  'DVD': '26 Sep 2017',
#  'Director': 'Johannes Roberts',
#  'Genre': 'Adventure, Drama, Horror, Thriller',
#  'Language': 'English, Spanish',
#  'Metascore': '52',
#  'Plot': 'Two sisters vacationing in Mexico are trapped in a shark cage at the '
#          'bottom of the ocean. With less than an hour of oxygen left and great '
#          'white sharks circling nearby, they must fight to survive.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYTcyMDRiNDQtODRkMy00YjU0LWEwYTEtMzk3NzIzODYzMjU2XkEyXkFqcGdeQXVyMTk5MzE1MTY@._V1_SX300.jpg',
#  'Production': 'Entertainment Studios Motion Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '54%'},
#              {'Source': 'Metacritic', 'Value': '52/100'}],
#  'Released': '16 Jun 2017',
#  'Response': 'True',
#  'Runtime': '89 min',
#  'Title': '47 Meters Down',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Johannes Roberts, Ernest Riera',
#  'Year': '2017',
#  'imdbID': 'tt2932536',
#  'imdbRating': '5.6',
#  'imdbVotes': '43,319'}
# -------------------
# movie id tt7086446
# -------------------
# {'Actors': 'Randy Austin, Marcus Bagwell, Kerry Cahill, Mickey Gilley',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'John Schneider',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'On the eve before Halloween, four escaped murderers head to the '
#          "woods with a hostage they didn't count on. With an inept posse "
#          'searching in the wrong area they will be lucky if they live ...',
#  'Poster': 'https://ia.media-imdb.com/images/M/MV5BNGFmNmRjZWMtOWJkYi00MWY3LThhNGMtNWU3MTQ2ZjU4MGFlXkEyXkFqcGdeQXVyMzYwNDY5MzA@._V1_SX300.jpg',
#  'Production': 'Maven Entertainment',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.1/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '4: GO',
#  'Type': 'movie',
#  'Website': 'https://www.facebook.com/fourtoGOmovie/',
#  'Writer': 'John Schneider',
#  'Year': '2017',
#  'imdbID': 'tt7086446',
#  'imdbRating': '8.1',
#  'imdbVotes': '24'}
# -------------------
# movie id tt5660236
# -------------------
# {'Actors': 'Kristina Michélle, Larry Poole, CG Thomas, Jay Jee',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Marcus Clemons',
#  'Genre': 'Horror, Mystery, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'After accepting a lucrative offer, a crew of space scavengers must '
#          'transport a prisoner to an unknown planets facility, but they soon '
#          'find themselves in a dilemma when the prisoner escapes and his true '
#          'identity revealed.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '31 Oct 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '5 Nights with Savannah',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Marcus Clemons',
#  'Year': '2016',
#  'imdbID': 'tt5660236',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3165632
# -------------------
# {'Actors': 'Morgan Lariah, Manu Intiraymi, Doug Jones, Marina Sirtis',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '28 Jan 2019',
#  'Director': 'Scotty Baker',
#  'Genre': 'Sci-Fi, Thriller',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'Five crew members are forced into an escape pod built for four after '
#          'their starship is destroyed. Just as rescue seems imminent, an alien '
#          'creature boards their craft and attacks them.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzhlMTUwZDktOTcyNC00NTM1LTgyMmEtNjg2YjFmY2FlMTAwXkEyXkFqcGdeQXVyMjA0NjEyMDM@._V1_SX300.jpg',
#  'Production': 'Epic Pictures',
#  'Rated': 'TV-14',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.1/10'}],
#  'Released': '13 Dec 2017',
#  'Response': 'True',
#  'Runtime': '89 min',
#  'Title': '5th Passenger',
#  'Type': 'movie',
#  'Website': 'http://www.5thpassenger.com/',
#  'Writer': 'Scotty Baker, Morgan Lariah, David Henri Martin',
#  'Year': '2017',
#  'imdbID': 'tt3165632',
#  'imdbRating': '3.1',
#  'imdbVotes': '1,414'}
# -------------------
# movie id tt5503688
# -------------------
# {'Actors': 'Josh Hartnett, Mira Sorvino, Sarah Dumont, Kale Culley',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '14 Nov 2017',
#  'Director': 'Scott Waugh',
#  'Genre': 'Adventure, Biography, Drama, Sport, Thriller',
#  'Language': 'English',
#  'Metascore': '40',
#  'Plot': 'An adrenaline seeking snowboarder gets lost in a massive winter '
#          'storm in the back country of the High Sierras where he is pushed to '
#          'the limits of human endurance and forced to battle his own personal '
#          'demons as he fights for survival...."',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTUwMzAxNTU2NV5BMl5BanBnXkFtZTgwOTU5MzUyMzI@._V1_SX300.jpg',
#  'Production': 'Dune Entertainment',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.7/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '22%'},
#              {'Source': 'Metacritic', 'Value': '40/100'}],
#  'Released': '13 Oct 2017',
#  'Response': 'True',
#  'Runtime': '98 min',
#  'Title': 'Fathom Premieres 6 Below: Miracle on the Mountain',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Madison Turner, Eric LeMarque (book), Davin Seay (book)',
#  'Year': '2017',
#  'imdbID': 'tt5503688',
#  'imdbRating': '5.7',
#  'imdbVotes': '5,390'}
# -------------------
# movie id tt5562832
# -------------------
# {'Actors': 'Jennifer Lafleur, Travis Swartz, Lisa King Hawkes, Sara Lynch',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Gregory Bayne',
#  'Genre': 'Comedy',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'Hidden in the pages of the self-help book "6 Dynamic Laws for '
#          'Success (In Life, Love and Money)", an ex-used car salesman '
#          'discovers a coded message purportedly revealing the location of 2.4 '
#          'million dollars from a robbery gone bad.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '6 Dynamic Laws for Success in Life, Love & Money',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Gregory Bayne',
#  'Year': '2017',
#  'imdbID': 'tt5562832',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6258256
# -------------------
# {'Actors': 'Anita Farmer Bergman, Angela Duggins, Sam Cullingworth, Michelle '
#            'Poole',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'William Lee',
#  'Genre': 'Action',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When Islamic Terrorists hired by Russians set off dirty bombs around '
#          "the world, a deadly virus transforms the bulk of the world's "
#          'population into the living dead. Zakariah Stone (William ...',
# ...
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Hayward Winston Suggs',
#  'Year': '2016',
#  'imdbID': 'tt4425580',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4952044
# -------------------
# {'Actors': 'Patrick Fabian, Tanya Clarke, Desmin Borges, Travis Schuldt',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Henry Barrial',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': '44',
#  'Plot': 'Skidding into middle-age, a stay-at-home dad must drive for an '
#          'Uber-like rideshare company (DriverX) to help support his working '
#          'wife and two young daughters. But low pay and wild LA nights put an '
#          'even greater strain on his marriage.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYjc4YmU5ZGEtNDkyOS00NzNlLTk3Y2MtMjE3MTJjMjI0MGJhXkEyXkFqcGdeQXVyODY3Nzc0OTk@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Unrated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.5/10'},
#              {'Source': 'Metacritic', 'Value': '44/100'}],
#  'Released': '30 Nov 2018',
#  'Response': 'True',
#  'Runtime': '98 min',
#  'Title': 'DriverX',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Henry Barrial',
#  'Year': '2017',
#  'imdbID': 'tt4952044',
#  'imdbRating': '5.5',
#  'imdbVotes': '499'}
# -------------------
# movie id tt8119090
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Matchstick Productions - the powerhouse that brought you '
#          'award-winning classics like CLAIM, THE WAY I SEE IT, and DAYS OF MY '
#          'YOUTH - is proud to introduce the funniest, most action-packed ...',
#  'Poster': 'N/A',
#  'Production': 'Matchstick Productions',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Jun 2017',
#  'Response': 'True',
#  'Runtime': '57 min',
#  'Title': 'Drop Everything',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2017',
#  'imdbID': 'tt8119090',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5832678
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'James Leon, Zaskia Morgan',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '23 Sep 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Dropping Like Flies',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'James Leon',
#  'Year': '2016',
#  'imdbID': 'tt5832678',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt1379178
# -------------------
# {'Actors': 'Mary Katherine Murphy, Danny Vinson, Peter Holden, Kyle Weir',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Scott William Alvarez',
#  'Genre': 'Crime, Drama, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A mentally-ill psychiatrist, refusing to take her medications while '
#          'on leave for the death of her daughter, returns to work with her '
#          'police detective ex-husband on a serial-torturer case.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Drowning',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Aric Hornig, Robert A. Walker',
#  'Year': '2014',
#  'imdbID': 'tt1379178',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt9050904
# -------------------
# {'Actors': 'Coral Carrillo, Shianne Gobin, Israel Marshall, Dave Mathers',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jason Valdovinos',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Jason and Emily have just moved out on their own for the first time '
#          'and everything seems to be going just fine, but when Jason gets '
#          'fired from his warehouse job things start to flip upside ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYmYwMTM0NjEtODM3NS00M2M0LTk3MDQtMjZkOTVjNWQ3NjQ4XkEyXkFqcGdeQXVyNjc2ODM0NDM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '126 min',
#  'Title': 'Drug Addiction',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2017',
#  'imdbID': 'tt9050904',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6066590
# -------------------
# {'Actors': 'Kathy Corpus, Ben Stobber, Allie Sparks, Lindsey Cruz',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Dick Smartwell',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMDM4NGQ2ZjUtMTE2OS00MDZhLTlhMjUtNDFmOWYyNWYzZTRjXkEyXkFqcGdeQXVyNDU3Mzg0MA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '10 Mar 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Drug Z',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'C.W. Jonson',
#  'Year': '2017',
#  'imdbID': 'tt6066590',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7975716
# -------------------
# {'Actors': 'Kristen Murphy, Kate Silcox, George Harvey Dabling, Eric Jolley',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Lynne Van Dam',
#  'Genre': 'Mystery',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A private eye on a routine case discovers there is a much deeper '
#          "evil lurking below the surface. Former maverick cop Frankie O'Malley "
#          'discovers one of her street informants dead on a park ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMGM1YWY3NjYtM2Q0MC00M2E3LTlmNDMtMGVhY2E5ZjEzZTIxXkEyXkFqcGdeQXVyMTk5MjM2Mzg@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '29 Aug 2017',
#  'Response': 'True',
#  'Runtime': '110 min',
#  'Title': 'Drury Lane',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Lynne Van Dam',
#  'Year': '2017',
#  'imdbID': 'tt7975716',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6158072
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt7131104
# -------------------
# {'Actors': 'Dante Botti, Jerry Botti, Marco Botti, Tom Galinski',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'John Theissen II',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Jacob, a kid with a tragic past is forced to move in with his uncle. '
#          'Jacob attends a new school where he struggles to fit in until he '
#          'meets Damien. Damien helps Jacob find his true passion through Music '
#          'and Friendship.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMmIzNzhjNDMtNDc1Zi00YmYwLWE4ZjUtZmU4OWFjOWViZjkxXkEyXkFqcGdeQXVyNjU5ODAzMjc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '09 Jun 2017',
#  'Response': 'True',
#  'Runtime': '58 min',
#  'Title': 'Duet',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dante Botti, Isaac Wong',
#  'Year': '2017',
#  'imdbID': 'tt7131104',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7007222
# -------------------
# {'Actors': 'Alexa Adams, Jonathan Brutt, Carolyn Connors, Jonathan Fisher',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jacob Ryan Vince Sziraky',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Dulcy and Red is the story of Donald Richmond, the most successful '
#          'article author at Pretension literary magazine. Despite his immense '
#          'success, Donald is not happy with his life, so every ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTYwMmE1YmItMjFlMS00M2FhLTgyOGMtODkwMmViNjgwMzQzXkEyXkFqcGdeQXVyNjIzMjcyMTg@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '20 Apr 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Dulcy and Red',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jacob Ryan Vince Sziraky',
#  'Year': '2017',
#  'imdbID': 'tt7007222',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5013056
# -------------------
# {'Actors': 'Fionn Whitehead, Damien Bonnard, Aneurin Barnard, Lee Armstrong',
#  'Awards': 'Won 3 Oscars. Another 51 wins & 197 nominations.',
#  'BoxOffice': '$188,042,171',
#  'Country': 'UK, Netherlands, France, USA',
#  'DVD': '19 Dec 2017',
#  'Director': 'Christopher Nolan',
#  'Genre': 'Action, Drama, History, Thriller, War',
#  'Language': 'English, French, German',
#  'Metascore': '94',
#  'Plot': 'Allied soldiers from Belgium, the British Empire, and France are '
#          'surrounded by the German Army, and evacuated during a fierce battle '
#          'in World War II.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BN2YyZjQ0NTEtNzU5MS00NGZkLTg0MTEtYzJmMWY3MWRhZjM2XkEyXkFqcGdeQXVyMDA4NzMyOA@@._V1_SX300.jpg',
#  'Production': 'Warner Bros. Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.9/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '93%'},
#              {'Source': 'Metacritic', 'Value': '94/100'}],
#  'Released': '21 Jul 2017',
#  'Response': 'True',
#  'Runtime': '106 min',
#  'Title': 'Dunkirk',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Christopher Nolan',
#  'Year': '2017',
#  'imdbID': 'tt5013056',
#  'imdbRating': '7.9',
#  'imdbVotes': '489,845'}
# -------------------
# movie id tt8526506
# -------------------
# {'Actors': 'Dana Brown',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '16 Oct 2018',
#  'Director': 'Dana Brown',
#  'Genre': 'Action',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Dana Brown Films, in association with SCORE International and BCII, '
#          'is proud to announce this new feature documentary film on the '
#          'legendary SCORE Baja 1000. This 18-month project, written ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDBjNGU0YTUtMDI3Ny00MTg4LWE1ZTUtNGRlY2EyNTNhNzdjXkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_SX300.jpg',
#  'Production': 'Magnet Releasing',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.2/10'}],
#  'Released': '06 Dec 2017',
#  'Response': 'True',
#  'Runtime': '98 min',
#  'Title': 'Dust 2 Glory',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dana Brown',
#  'Year': '2017',
#  'imdbID': 'tt8526506',
#  'imdbRating': '5.2',
#  'imdbVotes': '18'}
# -------------------
# movie id tt7288728
# -------------------
# {'Actors': 'Dustin Britton, Ed Kent, Steve Lanham, Davif Merlin',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Dustin Britton',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '04 Jan 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Dustins Dojo Road Trip',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dustin Britton',
#  'Year': '2017',
#  'imdbID': 'tt7288728',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7476506
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Dreamy calm music for sleep; meditation; yoga; or relaxing.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDg2ODM3ZTUtM2JhMS00NDBjLWE1YTQtZDI5MzRkNjZlZDQyXkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '28 Sep 2017',
#  'Response': 'True',
#  'Runtime': '120 min',
#  'Title': 'E-Motion',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2017',
#  'imdbID': 'tt7476506',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7066600
# -------------------
# {'Actors': 'Jennifer Purcell, Andrew Ravani, Alex Wilson, Angela Knapp',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kyle Audiss',
#  'Genre': 'Crime, Drama, Horror, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A young woman gets murdered and comes back as a ghost. She then '
#          'teams up with a forensic photographer (Who use to be an old high '
#          'school fling) to not just solve her murder, but to rescue her '
#          'sister, who was kidnapped by the murderer.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZDI2MmViYTEtZmY5Mi00ZTZmLTk3MDAtNzZiMWM1ZGMxNmU3XkEyXkFqcGdeQXVyNjYyNjMxODg@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '52 min',
#  'Title': 'E.V.P.',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kyle Audiss (story), Kyle Audiss',
#  'Year': '2017',
#  'imdbID': 'tt7066600',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4172498
# -------------------
# {'Actors': 'Josh Elliott Pickel, Marcia Aime, Robert Arensen, Audra Balewski',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Joseph Ciminera',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'E-19 Virus is a 2014 American apocalyptic film directed by Joe '
#          'Ciminera. Three teens are taken in by Scientist who injects them '
#          'with an experimental drug. The teens experience extra ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZThiMzU4ZTgtOTc5My00MWE4LWIwY2EtYjcxODY2ZjYzMWRmXkEyXkFqcGdeQXVyNzMzMjU5NDY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.7/10'}],
#  'Released': '16 Jun 2017',
#  'Response': 'True',
#  'Runtime': '88 min',
#  'Title': 'E19 Virus',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joseph Ciminera',
#  'Year': '2017',
#  'imdbID': 'tt4172498',
#  'imdbRating': '4.7',
#  'imdbVotes': '165'}
# -------------------
# movie id tt6317920
# -------------------
# {'Actors': 'Aaron Stielstra, David Lambert, Daniel Ryan Espy, Trevor Grosso',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Aaron Stielstra',
#  'Genre': 'Comedy, Music',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The climb of 90s punk band The Football Moms to the top becomes a '
#          'chronicle of abuse, betrayal, and unhygienic, nihilistic music. But '
#          'will singer Cozy Deathbed survive all of this, and ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjFiZDQ5MDItOWY4NS00MDVmLWE4YWMtYjVkYWRjYmEzNDRiL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMTc0NTU4Mg@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '02 Mar 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'EXCRETION: The Shocking True Story of the Football Moms',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Aaron Stielstra',
#  'Year': '2017',
#  'imdbID': 'tt6317920',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5893526
# -------------------
# {'Actors': 'Michael Reed, Lily Warpinski, Martyn G. Krouse, Patrick Penta',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Patrick Penta',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Two foundering musicians in the early stage of their careers meet '
#          'and form an unlikely alliance.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjkzYTUxNzgtM2QyNS00YmQzLTlhMTgtZDZiMmFiODE3MGQ0XkEyXkFqcGdeQXVyNTIwODkzNjc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '62 min',
#  'Title': 'Early Music',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Patrick Penta',
#  'Year': '2016',
#  'imdbID': 'tt5893526',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}

# %%
len(title_list)
# Out:
# 959

# %%
len(title_id)
# Out:
# 959

# %%
# if title_list and title_id are the same length run the cell below. 
# if they are not equal take out 'title_id': title_id

# %%
df = pd.DataFrame({'title_id': title_id, 'title': title_list, 'box_office': box_office_list, 'country': country_list, 
                   'genre': genre_list, 'director': director_list, 'metascore': metascore_list, 'production': production_list, 
                   'rating': rating_list, 'IMDB_rating': IMDB_rating_list, 'rotten_tomatoes_rating': rotten_tomatoes_rating_list, 
                  'runtime': runtime_list, 'type': type_list, 'IMDB_votes': imdb_votes_list})

# %%
df = df.drop_duplicates()
df.head()
# Out:
#     title_id             title box_office country                   genre  \
# 0  tt6856592         #Captured        N/A     USA                Thriller
# 1  tt6479626  #CoEdConfessions        N/A     USA         Comedy, Romance
# 2  tt6119504      #REALITYHIGH        N/A     USA  Comedy, Drama, Romance
# 3  tt5654204   #Slaughterhouse        N/A     USA          Action, Horror
# 4  tt6046566          #humbled        N/A     USA                     N/A
#
#                                             director metascore production  \
# 0                                        Joe Homokay       N/A        N/A
# 1  William Cardoza, Guillermo Gomez, Rachael Hada...       N/A        N/A
# 2                                   Fernando Lebrija       N/A        N/A
# 3                                      Dino Maglaris       N/A        N/A
# 4                                  Russell Max Simon       N/A        N/A
#
#   rating IMDB_rating rotten_tomatoes_rating runtime   type IMDB_votes
# 0    N/A         6.1                     NA  81 min  movie      1,101
# 1    N/A         N/A                     NA  61 min  movie        N/A
# 2  TV-14         5.2                     NA  99 min  movie      4,800
# 3    N/A         7.5                     NA     N/A  movie         24
# 4    N/A         N/A                     NA  76 min  movie        N/A

# %%
df.count()
# Out:
# title_id                  959
# title                     959
# box_office                959
# country                   959
# genre                     959
# director                  959
# metascore                 959
# production                959
# rating                    959
# IMDB_rating               959
# rotten_tomatoes_rating    959
# runtime                   959
# type                      959
# IMDB_votes                959
# dtype: int64

# %%
df.to_csv('../data/2017_data_batch_1.csv', index=False)
