# %%
import pandas as pd

# %%
batch_1 = pd.read_csv('../data/2015_data_batch_1.csv')
batch_2 = pd.read_csv('../data/2015_data_batch_2.csv')
batch_3 = pd.read_csv('../data/2015_data_batch_3.csv')
batch_4 = pd.read_csv('../data/2015_data_batch_4.csv')

# %%
len(batch_1)
# Out:
# 999

# %%
len(batch_2)
# Out:
# 978

# %%
len(batch_3)
# Out:
# 979

# %%
len(batch_4)
# Out:
# 401

# %%
df = pd.DataFrame()

# %%
df = pd.concat([batch_1, batch_2, batch_3, batch_4], ignore_index=True)

# %%
len(df)
# Out:
# 3357

# %%
df.head(100)
# Out:
#      title_id                                       title box_office country  \
# 0   tt4470336                                  #50Fathers        NaN     USA
# 1   tt5460468                                     #Enough        NaN     USA
# 2   tt3526286                                     #Horror        NaN     USA
# 3   tt2538204                               #Lucky Number        NaN     USA
# 4   tt5466780                                  #Standards        NaN     USA
# ..        ...                                         ...        ...     ...
# 95  tt3247646  A Ghost and the Boy with A Box on His Head        NaN     USA
# 96  tt3954294                                A Gift Horse        NaN     USA
# 97  tt3507138                           A Girl Like Grace        NaN     USA
# 98  tt2523832                             A Girl Like Her        NaN     USA
# 99  tt4991434                     A Harlequin in Darkness        NaN     USA
#
#                                       genre                director  \
# 0                                    Comedy     Joddy Eric Matthews
# 1                                     Drama        Miranda Ferguson
# 2   Crime, Drama, Horror, Mystery, Thriller            Tara Subkoff
# 3                                    Comedy  Brendan Gabriel Murphy
# 4                                     Drama            Melanie Page
# ..                                      ...                     ...
# 95                         Adventure, Drama             Philip Blue
# 96                                   Family             Teddy Smith
# 97                                    Drama               Ty Hodges
# 98                                    Drama            Amy S. Weber
# 99                                 Thriller           Michael Mason
#
#     metascore              production     rating  IMDB_rating  \
# 0         NaN                     NaN        NaN          NaN
# 1         NaN                     NaN        NaN          NaN
# 2        42.0                     NaN  Not Rated          3.0
# 3         NaN                     NaN      TV-14          5.0
# 4         NaN                     NaN        NaN          NaN
# ..        ...                     ...        ...          ...
# 95        NaN                     NaN        NaN          NaN
# 96        NaN  Leverage Entertainment       TV-G          5.1
# 97        NaN           GVN Releasing      PG-13          5.9
# 98       54.0      Parkside Releasing      PG-13          7.0
# 99        NaN                     NaN        NaN          NaN
#
#    rotten_tomatoes_rating  runtime   type IMDB_votes
# 0                     NaN  132 min  movie        NaN
# 1                     NaN      NaN  movie        NaN
# 2                     NaN  101 min  movie      3,218
# 3                     NaN   80 min  movie        435
# 4                     NaN   50 min  movie        NaN
# ..                    ...      ...    ...        ...
# 95                    NaN   73 min  movie        NaN
# 96                    NaN   83 min  movie        141
# 97                    NaN   93 min  movie        429
# 98                    65%   91 min  movie      6,502
# 99                    NaN      NaN  movie        NaN
#
# [100 rows x 14 columns]

# %%
total = len(df.country.unique())
unique = df.country.unique()
for i in range (total):
    print(unique[i])
# Out:
# USA
# Iran, USA
# Mexico, USA
# Canada, USA
# Australia, Guyana, USA
# nan
# Australia, Canada, USA
# Israel, USA
# Canada, USA, India, Vietnam
# USA, Italy
# Romania, USA, Ukraine
# China, USA
# USA, UK
# UK, USA
# Italy, Spain, USA, UK, Sweden
# USA, Bosnia and Herzegovina, Croatia, Italy, Switzerland
# Peru, USA
# USA, Canada
# USA, Hong Kong
# Guatemala, USA
# Germany, USA
# Switzerland, USA
# France, USA
# France
# Germany, Ukraine, USA
# Spain, USA
# USA, France, Germany
# Taiwan, USA
# USA, Colombia
# USA, Trinidad and Tobago
# China, UK, USA
# USA, Cameroon
# USA, Mexico
# Hungary, USA, Russia, Romania
# USA, Dominican Republic
# India, Hong Kong, Indonesia, Philippines, Singapore, USA, United Arab Emirates
# USA, France, Belgium
# United Arab Emirates, USA, Switzerland
# Australia, USA
# USA, France
# Cyprus, Greece, USA, Serbia
# Lebanon, USA
# Germany, India, USA
# India, USA
# Czech Republic, USA
# France, Malta, USA
# USA, UK, Spain, Italy, France
# Albania, USA
# South Africa, USA
# Hong Kong, China, USA
# Czech Republic, UK, USA, Russia
# USA, Germany, Brazil
# UK, Australia, USA
# South Korea, Thailand, USA
# USA, UK, France
# Netherlands, USA
# New Zealand, USA
# Germany, USA, South Africa, Norway, Italy, Hong Kong, Brazil, Australia
# USA, Turkey, Italy, India
# Germany
# Mexico, India, USA, Argentina, Spain
# USA, Cambodia
# Italy
# UK, Germany, USA
# Austria, USA
# USA, Japan
# Poland, USA
# USA, Indonesia
# UK, USA, Iceland
# Spain, USA, Hungary, France
# USA, UK, Canada
# USA, Germany, UK
# Italy, USA
# USA, Argentina
# USA, India
# Canada, France, USA
# USA, Germany
# USA, New Zealand
# USA, Ghana
# USA, Australia
# USA, UK, Canada, Iceland, Norway
# USA, China, Japan, Canada, United Arab Emirates
# USA, China
# Tanzania, USA
# USA, Myanmar
# USA, Cuba
# USA, South Korea
# Colombia, USA
# Russia, USA, China
# Thailand, USA
# USA, Russia
# USA, UK, Germany
# USA, Hong Kong, China
# Thailand, USA, Indonesia
# USA, Brazil, Canada
# Denmark, USA
# Nepal
# USA, Australia, Spain
# Canada, UK, USA
# Bahamas, USA
# Belgium, USA, Netherlands
# Japan, USA
# Netherlands, Belgium, UK, USA
# USA, Chile, Israel
# South Korea, USA, Japan
# Ethiopia, USA
# Hong Kong, USA, Cambodia, Indonesia, Kenya, Malaysia, Myanmar, Tanzania, Thailand
# UK, France, USA
# USA, Czech Republic, Bolivia, United Arab Emirates, South Africa
# UK, Germany, Canada, Australia, USA
# Norway, France, Denmark, USA
# Australia, USA, South Africa
# USA, Switzerland
# Italy, France, USA, Germany, Qatar
# USA, Canada, Iraq, United Arab Emirates
# USA, China, Hong Kong, Austria
# Pakistan, USA
# Austria, USA, Australia, Guadeloupe, Italy
# South Korea, USA
# USA, Chile
# USA, Morocco, Spain, UK
# Serbia, USA
# Bolivia, USA, Argentina, Mexico
# USA, Canada, Brazil, France, Philippines, Singapore, UK, Germany
# USA, Spain, Peru
# Canada, Nigeria, USA
# Germany, Belgium, Luxembourg, Ireland, USA
# USA, Liberia
# USA, Nigeria
# USA, UK, Australia
# India, UK, USA
# Germany, Greece, USA
# USA, China, Canada
# Canada
# China, Germany, USA, Austria, Italy, Canada
# Singapore, USA
# Spain, USA, Rwanda
# USA, Morocco
# USA, Spain
# Thailand, UK, Germany, France, Malaysia, South Korea, Mexico, USA, Norway
# Haiti, USA
# Spain, Canada, USA
# Portugal, USA
# Canada, USA, UK
# Singapore, USA, Philippines
# Ireland, Canada, UK, USA
# Bosnia and Herzegovina, USA
# Colombia
# USA, UK, Spain, South Korea
# Hong Kong, Spain, USA
# South Korea, China, USA
# Brazil, USA
# Hong Kong, USA
# USA, UK, France, Hungary, Germany
# Japan, Poland, USA
# USA, Philippines, UK
# USA, Canada, UK, France, Hungary, Belgium
# UK, USA, Germany, Denmark, Belgium, Japan
# Germany, USA, Poland
# USA, Hungary
# USA, Australia, China
# USA, UK, Morocco
# USA, Spain, UK, France
# UK, USA, Ireland
# Venezuela, USA
# UK, USA, Hungary
# Ecuador, USA
# Puerto Rico, USA
# USA, Poland
# USA, Hong Kong, Taiwan
# Mexico, Italy, USA
# Sweden, USA, UK
# USA, South Korea, Australia
# Sweden, USA
# France, USA, United Arab Emirates, Spain, India
# USA, Germany, Austria
# USA, Thailand
# USA, Singapore
# USA, Spain, France, UK
# Philippines
# USA, Colombia, Iran, Kenya, Germany, Romania, Spain, China, UK, Greece, South Africa, Portugal, United Arab Emirates, India, Brazil, Philippines, Italy, Norway, Malaysia, France, Singapore, Indonesia, Bolivia, Bulgaria, Sudan
# Canada, New Zealand, USA
# UK, Canada, USA
# Canada, India, USA
# USA, Haiti
# USA, Egypt
# USA, Bahamas, Canada
# Iceland, Switzerland, USA
# China, Hong Kong, USA

# %%
df.country = df.country.str.lower()

# %%
df = df[df['country'].str.contains("usa", na=False)]

# %%
total = len(df.country.unique())
unique = df.country.unique()
for i in range (total):
    print(unique[i])
# Out:
# usa
# iran, usa
# mexico, usa
# canada, usa
# australia, guyana, usa
# australia, canada, usa
# israel, usa
# canada, usa, india, vietnam
# usa, italy
# romania, usa, ukraine
# china, usa
# usa, uk
# uk, usa
# italy, spain, usa, uk, sweden
# usa, bosnia and herzegovina, croatia, italy, switzerland
# peru, usa
# usa, canada
# usa, hong kong
# guatemala, usa
# germany, usa
# switzerland, usa
# france, usa
# germany, ukraine, usa
# spain, usa
# usa, france, germany
# taiwan, usa
# usa, colombia
# usa, trinidad and tobago
# china, uk, usa
# usa, cameroon
# usa, mexico
# hungary, usa, russia, romania
# usa, dominican republic
# india, hong kong, indonesia, philippines, singapore, usa, united arab emirates
# usa, france, belgium
# united arab emirates, usa, switzerland
# australia, usa
# usa, france
# cyprus, greece, usa, serbia
# lebanon, usa
# germany, india, usa
# india, usa
# czech republic, usa
# france, malta, usa
# usa, uk, spain, italy, france
# albania, usa
# south africa, usa
# hong kong, china, usa
# czech republic, uk, usa, russia
# usa, germany, brazil
# uk, australia, usa
# south korea, thailand, usa
# usa, uk, france
# netherlands, usa
# new zealand, usa
# germany, usa, south africa, norway, italy, hong kong, brazil, australia
# usa, turkey, italy, india
# mexico, india, usa, argentina, spain
# usa, cambodia
# uk, germany, usa
# austria, usa
# usa, japan
# poland, usa
# usa, indonesia
# uk, usa, iceland
# spain, usa, hungary, france
# usa, uk, canada
# usa, germany, uk
# italy, usa
# usa, argentina
# usa, india
# canada, france, usa
# usa, germany
# usa, new zealand
# usa, ghana
# usa, australia
# usa, uk, canada, iceland, norway
# usa, china, japan, canada, united arab emirates
# usa, china
# tanzania, usa
# usa, myanmar
# usa, cuba
# usa, south korea
# colombia, usa
# russia, usa, china
# thailand, usa
# usa, russia
# usa, uk, germany
# usa, hong kong, china
# thailand, usa, indonesia
# usa, brazil, canada
# denmark, usa
# usa, australia, spain
# canada, uk, usa
# bahamas, usa
# belgium, usa, netherlands
# japan, usa
# netherlands, belgium, uk, usa
# usa, chile, israel
# south korea, usa, japan
# ethiopia, usa
# hong kong, usa, cambodia, indonesia, kenya, malaysia, myanmar, tanzania, thailand
# uk, france, usa
# usa, czech republic, bolivia, united arab emirates, south africa
# uk, germany, canada, australia, usa
# norway, france, denmark, usa
# australia, usa, south africa
# usa, switzerland
# italy, france, usa, germany, qatar
# usa, canada, iraq, united arab emirates
# usa, china, hong kong, austria
# pakistan, usa
# austria, usa, australia, guadeloupe, italy
# south korea, usa
# usa, chile
# usa, morocco, spain, uk
# serbia, usa
# bolivia, usa, argentina, mexico
# usa, canada, brazil, france, philippines, singapore, uk, germany
# usa, spain, peru
# canada, nigeria, usa
# germany, belgium, luxembourg, ireland, usa
# usa, liberia
# usa, nigeria
# usa, uk, australia
# india, uk, usa
# germany, greece, usa
# usa, china, canada
# china, germany, usa, austria, italy, canada
# singapore, usa
# spain, usa, rwanda
# usa, morocco
# usa, spain
# thailand, uk, germany, france, malaysia, south korea, mexico, usa, norway
# haiti, usa
# spain, canada, usa
# portugal, usa
# canada, usa, uk
# singapore, usa, philippines
# ireland, canada, uk, usa
# bosnia and herzegovina, usa
# usa, uk, spain, south korea
# hong kong, spain, usa
# south korea, china, usa
# brazil, usa
# hong kong, usa
# usa, uk, france, hungary, germany
# japan, poland, usa
# usa, philippines, uk
# usa, canada, uk, france, hungary, belgium
# uk, usa, germany, denmark, belgium, japan
# germany, usa, poland
# usa, hungary
# usa, australia, china
# usa, uk, morocco
# usa, spain, uk, france
# uk, usa, ireland
# venezuela, usa
# uk, usa, hungary
# ecuador, usa
# puerto rico, usa
# usa, poland
# usa, hong kong, taiwan
# mexico, italy, usa
# sweden, usa, uk
# usa, south korea, australia
# sweden, usa
# france, usa, united arab emirates, spain, india
# usa, germany, austria
# usa, thailand
# usa, singapore
# usa, spain, france, uk
# usa, colombia, iran, kenya, germany, romania, spain, china, uk, greece, south africa, portugal, united arab emirates, india, brazil, philippines, italy, norway, malaysia, france, singapore, indonesia, bolivia, bulgaria, sudan
# canada, new zealand, usa
# uk, canada, usa
# canada, india, usa
# usa, haiti
# usa, egypt
# usa, bahamas, canada
# iceland, switzerland, usa
# china, hong kong, usa

# %%
len(df)
# Out:
# 3339

# %%
df = df[df.box_office.notnull()]

# %%
len(df)
# Out:
# 171

# %%
# drop min number of non-NA values
df = df.dropna(thresh=7)
df.head(100)
# Out:
#        title_id                        title   box_office      country  \
# 35    tt4158624                3 Generations      $66,371          usa
# 65    tt2611160              A Beautiful Now       $1,504          usa
# 129   tt1135989  A Tale of Love and Darkness     $569,381  israel, usa
# 138   tt1178665          A Walk in the Woods  $19,189,413          usa
# 220   tt1243974                        Aloha  $15,669,178          usa
# ...         ...                          ...          ...          ...
# 1810  tt3045616                    Mortdecai   $6,847,536      uk, usa
# 1822  tt3168230                   Mr. Holmes  $14,173,994      uk, usa
# 1824  tt2091935                    Mr. Right      $25,369          usa
# 1825  tt3812348                    Mr. Right      $25,369          usa
# 1833  tt3719896              My All-American   $1,365,000          usa
#
#                                                  genre         director  \
# 35                                               Drama      Gaby Dellal
# 65                                Comedy, Drama, Music   Daniela Amavia
# 129   Biography, Drama, History, Mystery, Romance, War  Natalie Portman
# 138                Adventure, Biography, Comedy, Drama       Ken Kwapis
# 220                             Comedy, Drama, Romance    Cameron Crowe
# ...                                                ...              ...
# 1810           Action, Comedy, Crime, Mystery, Romance      David Koepp
# 1822                                    Drama, Mystery      Bill Condon
# 1824                           Action, Comedy, Romance     Paco Cabezas
# 1825                                            Comedy     Roger Melvin
# 1833                           Biography, Drama, Sport     Angelo Pizzo
#
#       metascore             production     rating  IMDB_rating  \
# 35         47.0  The Weinstein Company      PG-13          5.9
# 65          NaN       Unified Pictures          R          5.7
# 129        55.0            Focus World      PG-13          6.0
# 138        51.0   Broad Green Pictures          R          6.3
# 220        40.0          Sony Pictures      PG-13          5.4
# ...         ...                    ...        ...          ...
# 1810       27.0         Liongate Films          R          5.5
# 1822       67.0   Roadside Attractions         PG          6.9
# 1824       52.0    Circle of Confusion          R          6.3
# 1825        NaN    Circle of Confusion  Not Rated          3.0
# 1833       34.0                 Aviron         PG          7.1
#
#      rotten_tomatoes_rating  runtime   type IMDB_votes
# 35                      32%   92 min  movie      5,250
# 65                      NaN   90 min  movie         27
# 129                     70%   95 min  movie      3,185
# 138                     47%  104 min  movie     22,701
# 220                     20%  105 min  movie     57,595
# ...                     ...      ...    ...        ...
# 1810                    12%  107 min  movie     63,025
# 1822                    89%  104 min  movie     59,208
# 1824                    44%   95 min  movie     44,078
# 1825                    44%   79 min  movie        273
# 1833                    32%  118 min  movie      5,288
#
# [100 rows x 14 columns]

# %%
len(df)
# Out:
# 171

# %%
df.to_csv('../data/cleaned_2015_data.csv', index=False)

# %%
train = df[['title', 'box_office', 'country', 'genre', 'production', 'rating', 'runtime']]
train.head()
# Out:
#                            title   box_office      country  \
# 35                 3 Generations      $66,371          usa
# 65               A Beautiful Now       $1,504          usa
# 129  A Tale of Love and Darkness     $569,381  israel, usa
# 138          A Walk in the Woods  $19,189,413          usa
# 220                        Aloha  $15,669,178          usa
#
#                                                 genre             production  \
# 35                                              Drama  The Weinstein Company
# 65                               Comedy, Drama, Music       Unified Pictures
# 129  Biography, Drama, History, Mystery, Romance, War            Focus World
# 138               Adventure, Biography, Comedy, Drama   Broad Green Pictures
# 220                            Comedy, Drama, Romance          Sony Pictures
#
#     rating  runtime
# 35   PG-13   92 min
# 65       R   90 min
# 129  PG-13   95 min
# 138      R  104 min
# 220  PG-13  105 min

# %%
train = train.reset_index(drop = True)
train.head()
# Out:
#                          title   box_office      country  \
# 0                3 Generations      $66,371          usa
# 1              A Beautiful Now       $1,504          usa
# 2  A Tale of Love and Darkness     $569,381  israel, usa
# 3          A Walk in the Woods  $19,189,413          usa
# 4                        Aloha  $15,669,178          usa
#
#                                               genre             production  \
# 0                                             Drama  The Weinstein Company
# 1                              Comedy, Drama, Music       Unified Pictures
# 2  Biography, Drama, History, Mystery, Romance, War            Focus World
# 3               Adventure, Biography, Comedy, Drama   Broad Green Pictures
# 4                            Comedy, Drama, Romance          Sony Pictures
#
#   rating  runtime
# 0  PG-13   92 min
# 1      R   90 min
# 2  PG-13   95 min
# 3      R  104 min
# 4  PG-13  105 min

# %%
train['country'] = train['country'].str.count(',')
train['country'] = train['country'] + 1
train.head()
# Out:
#                          title   box_office  country  \
# 0                3 Generations      $66,371        1
# 1              A Beautiful Now       $1,504        1
# 2  A Tale of Love and Darkness     $569,381        2
# 3          A Walk in the Woods  $19,189,413        1
# 4                        Aloha  $15,669,178        1
#
#                                               genre             production  \
# 0                                             Drama  The Weinstein Company
# 1                              Comedy, Drama, Music       Unified Pictures
# 2  Biography, Drama, History, Mystery, Romance, War            Focus World
# 3               Adventure, Biography, Comedy, Drama   Broad Green Pictures
# 4                            Comedy, Drama, Romance          Sony Pictures
#
#   rating  runtime
# 0  PG-13   92 min
# 1      R   90 min
# 2  PG-13   95 min
# 3      R  104 min
# 4  PG-13  105 min

# %%
train['genre'] = train['genre'].str.count(',')
train['genre'] = train['genre'] + 1
train.head()
# Out:
#                          title   box_office  country  genre  \
# 0                3 Generations      $66,371        1      1
# 1              A Beautiful Now       $1,504        1      3
# 2  A Tale of Love and Darkness     $569,381        2      6
# 3          A Walk in the Woods  $19,189,413        1      4
# 4                        Aloha  $15,669,178        1      3
#
#               production rating  runtime
# 0  The Weinstein Company  PG-13   92 min
# 1       Unified Pictures      R   90 min
# 2            Focus World  PG-13   95 min
# 3   Broad Green Pictures      R  104 min
# 4          Sony Pictures  PG-13  105 min

# %%
train['rating'].value_counts()
# Out:
# R            71
# PG-13        49
# PG           22
# Not Rated    16
# G             2
# Unrated       1
# TV-MA         1
# Name: rating, dtype: int64

# %%
train['rating'] = train['rating'].str.replace('Not Rated', 'Unrated')
train.head()
# Out:
#                          title   box_office  country  genre  \
# 0                3 Generations      $66,371        1      1
# 1              A Beautiful Now       $1,504        1      3
# 2  A Tale of Love and Darkness     $569,381        2      6
# 3          A Walk in the Woods  $19,189,413        1      4
# 4                        Aloha  $15,669,178        1      3
#
#               production rating  runtime
# 0  The Weinstein Company  PG-13   92 min
# 1       Unified Pictures      R   90 min
# 2            Focus World  PG-13   95 min
# 3   Broad Green Pictures      R  104 min
# 4          Sony Pictures  PG-13  105 min

# %%
train['rating'] = train['rating'].fillna('Unrated')

# %%
train['rating'].value_counts()
# Out:
# R          71
# PG-13      49
# Unrated    26
# PG         22
# G           2
# TV-MA       1
# Name: rating, dtype: int64

# %%
train['runtime'] = train['runtime'].astype(str)

# %%
train['runtime'] = train['runtime'].apply(lambda x: x.replace(' min',''))
train.head()
# Out:
#                          title   box_office  country  genre  \
# 0                3 Generations      $66,371        1      1
# 1              A Beautiful Now       $1,504        1      3
# 2  A Tale of Love and Darkness     $569,381        2      6
# 3          A Walk in the Woods  $19,189,413        1      4
# 4                        Aloha  $15,669,178        1      3
#
#               production rating runtime
# 0  The Weinstein Company  PG-13      92
# 1       Unified Pictures      R      90
# 2            Focus World  PG-13      95
# 3   Broad Green Pictures      R     104
# 4          Sony Pictures  PG-13     105

# %%
train['runtime'] = train['runtime'].apply(lambda x: x.replace('nan','0'))
train.head()
# Out:
#                          title   box_office  country  genre  \
# 0                3 Generations      $66,371        1      1
# 1              A Beautiful Now       $1,504        1      3
# 2  A Tale of Love and Darkness     $569,381        2      6
# 3          A Walk in the Woods  $19,189,413        1      4
# 4                        Aloha  $15,669,178        1      3
#
#               production rating runtime
# 0  The Weinstein Company  PG-13      92
# 1       Unified Pictures      R      90
# 2            Focus World  PG-13      95
# 3   Broad Green Pictures      R     104
# 4          Sony Pictures  PG-13     105

# %%
train['runtime'] = train['runtime'].astype(int)

# %%
train.production.value_counts()
# Out:
# Universal Pictures             14
# 20th Century Fox               11
# Sony Pictures                  10
# Warner Bros. Pictures           9
# The Weinstein Company           6
#                                ..
# DreamWorks Animation            1
# Sony Pictures Entertainment     1
# Waypoint Entertainment          1
# Play Now Enterprise             1
# Fox Searchlight                 1
# Name: production, Length: 81, dtype: int64

# %%
train['production'] = train['production'].fillna('NaN')

# %%
train['box_office'] = train['box_office'].apply(lambda x: x.replace('$',''))
train.head()
# Out:
#                          title  box_office  country  genre  \
# 0                3 Generations      66,371        1      1
# 1              A Beautiful Now       1,504        1      3
# 2  A Tale of Love and Darkness     569,381        2      6
# 3          A Walk in the Woods  19,189,413        1      4
# 4                        Aloha  15,669,178        1      3
#
#               production rating  runtime
# 0  The Weinstein Company  PG-13       92
# 1       Unified Pictures      R       90
# 2            Focus World  PG-13       95
# 3   Broad Green Pictures      R      104
# 4          Sony Pictures  PG-13      105

# %%
train['box_office'] = train['box_office'].apply(lambda x: x.replace(',',''))
train.head()
# Out:
#                          title box_office  country  genre  \
# 0                3 Generations      66371        1      1
# 1              A Beautiful Now       1504        1      3
# 2  A Tale of Love and Darkness     569381        2      6
# 3          A Walk in the Woods   19189413        1      4
# 4                        Aloha   15669178        1      3
#
#               production rating  runtime
# 0  The Weinstein Company  PG-13       92
# 1       Unified Pictures      R       90
# 2            Focus World  PG-13       95
# 3   Broad Green Pictures      R      104
# 4          Sony Pictures  PG-13      105

# %%
train['box_office'] = train['box_office'].astype(int)
train.head()
# Out:
#                          title  box_office  country  genre  \
# 0                3 Generations       66371        1      1
# 1              A Beautiful Now        1504        1      3
# 2  A Tale of Love and Darkness      569381        2      6
# 3          A Walk in the Woods    19189413        1      4
# 4                        Aloha    15669178        1      3
#
#               production rating  runtime
# 0  The Weinstein Company  PG-13       92
# 1       Unified Pictures      R       90
# 2            Focus World  PG-13       95
# 3   Broad Green Pictures      R      104
# 4          Sony Pictures  PG-13      105

# %%
train.dtypes
# Out:
# title         object
# box_office     int32
# country        int64
# genre          int64
# production    object
# rating        object
# runtime        int32
# dtype: object

# %%
train.dtypes
# Out:
# title         object
# box_office     int32
# country        int64
# genre          int64
# production    object
# rating        object
# runtime        int32
# dtype: object

# %%
train['year'] = 2015

# %%
train.to_csv('../data/train_data_2015.csv', index=False)

# %%
train = train.sort_values(by=['box_office'], ascending=False)

# %%
train.head()
# Out:
#                                           title  box_office  country  genre  \
# 122  Star Wars: Episode VII - The Force Awakens   936658640        1      3
# 75                               Jurassic World   528757749        1      3
# 9                       Avengers: Age of Ultron   429113729        1      3
# 53                                      Furious   316986481        1      1
# 54                                    Furious 7   316986481        5      3
#
#                production   rating  runtime  year
# 122  Walt Disney Pictures    PG-13      138  2015
# 75     Universal Pictures    PG-13      124  2015
# 9    Walt Disney Pictures    PG-13      141  2015
# 53     Universal Pictures  Unrated        0  2015
# 54     Universal Pictures    PG-13      137  2015

# %%
train.iloc[:20, 1]=1

# %%
train.head()
# Out:
#                                           title  box_office  country  genre  \
# 122  Star Wars: Episode VII - The Force Awakens           1        1      3
# 75                               Jurassic World           1        1      3
# 9                       Avengers: Age of Ultron           1        1      3
# 53                                      Furious           1        1      1
# 54                                    Furious 7           1        5      3
#
#                production   rating  runtime  year
# 122  Walt Disney Pictures    PG-13      138  2015
# 75     Universal Pictures    PG-13      124  2015
# 9    Walt Disney Pictures    PG-13      141  2015
# 53     Universal Pictures  Unrated        0  2015
# 54     Universal Pictures    PG-13      137  2015

# %%
train.iloc[20:,1]=0

# %%
train.head()
# Out:
#                                           title  box_office  country  genre  \
# 122  Star Wars: Episode VII - The Force Awakens           1        1      3
# 75                               Jurassic World           1        1      3
# 9                       Avengers: Age of Ultron           1        1      3
# 53                                      Furious           1        1      1
# 54                                    Furious 7           1        5      3
#
#                production   rating  runtime  year
# 122  Walt Disney Pictures    PG-13      138  2015
# 75     Universal Pictures    PG-13      124  2015
# 9    Walt Disney Pictures    PG-13      141  2015
# 53     Universal Pictures  Unrated        0  2015
# 54     Universal Pictures    PG-13      137  2015

# %%
train.to_csv('../data/train.log_data_2015.csv', index=False)
