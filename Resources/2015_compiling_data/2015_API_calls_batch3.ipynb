# %%
import pandas as pd
import requests
import json
import time
from pprint import pprint
from config import API_KEY

# %%
data = pd.read_csv('../data/titles_2015_batch3.csv')
df =  data.count()
df
# Out:
# title    1000
# dtype: int64

# %%
title_id = []
box_office_list = []
country_list = []
genre_list = []
director_list = []
metascore_list = []
production_list = []
rating_list = []
IMDB_rating_list = [] 
rotten_tomatoes_rating_list = []
runtime_list = []
title_list = []
type_list = []
imdb_votes_list = []

# %%
movies = data['title']
total_movies = len(movies)

# %%
for i in range(total_movies):
    movie = movies[i]
    url = "http://www.omdbapi.com/?i=" + movie + "&apikey=" + API_KEY
    response = (requests.get(url).text)
    response_json = json.loads(response)
    print('-------------------')
    print(f'movie id {movie}')
    print('-------------------')
    pprint(response_json)
    
    try:
        box_office_list.append(response_json['BoxOffice'])
        country_list.append(response_json['Country'])
        genre_list.append(response_json['Genre'])
        director_list.append(response_json['Director'])
        metascore_list.append(response_json['Metascore'])
        production_list.append(response_json['Production'])
        rating_list.append(response_json['Rated'])
        IMDB_rating_list.append(response_json['imdbRating'])
        try:
            if not response_json['Ratings']:
                rotten_tomatoes_rating_list.append('NA')
            elif response_json['Ratings'][0]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][0]['Value'])
            elif response_json['Ratings'][1]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][1]['Value'])
            else:
                rotten_tomatoes_rating_list.append('NA')
        except IndexError:
            rotten_tomatoes_rating_list.append('NA')
        runtime_list.append(response_json['Runtime'])
        title_list.append(response_json['Title'])
        type_list.append(response_json['Type'])
        imdb_votes_list.append(response_json['imdbVotes'])
        title_id.append(response_json['imdbID'])
    except KeyError:
        pass
    time.sleep(1)
# Out:
# -------------------
# movie id tt4914072
# -------------------
# {'Actors': 'Scott Shaw',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Scott Shaw',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Outside Through the Labyrinth. A Scott Shaw Zen Mind Ride.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc5MTExMjc4OF5BMl5BanBnXkFtZTgwNTA4NDAwNzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '03 Jul 2015',
#  'Response': 'True',
#  'Runtime': '53 min',
#  'Title': 'Outside Through the Labyrinth',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2015',
#  'imdbID': 'tt4914072',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3032288
# -------------------
# {'Actors': 'Tanna Frederick, James Denton, Stephanie Fredricks, Cathy Arden',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Henry Jaglom',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Maggie Chase, now a passionate theater actress, must follow her mind '
#          'or heart when she falls for a slick television star.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjEyMzI3NDEyOF5BMl5BanBnXkFtZTgwNzI3ODU4NzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.6/10'}],
#  'Released': '05 Dec 2015',
#  'Response': 'True',
#  'Runtime': '105 min',
#  'Title': 'Ovation',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Henry Jaglom, Ron Vignone',
#  'Year': '2015',
#  'imdbID': 'tt3032288',
#  'imdbRating': '5.6',
#  'imdbVotes': '17'}
# -------------------
# movie id tt3118034
# -------------------
# {'Actors': 'Kareem Ghuneim, Christian Thorne, Chadsworth Garza, Maye Hunta',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'D.J. Yarotsky',
#  'Genre': 'Comedy, Drama, Music, Mystery',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Join Brian as he tries to prove that his former best friend and punk '
#          "rock band-mate's death was anything but an accident. Filled with "
#          'humor, social commentary, and mystery, its script has ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc4NTI1MDY2MV5BMl5BanBnXkFtZTgwODg0OTg4NjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.7/10'}],
#  'Released': '01 Nov 2016',
#  'Response': 'True',
#  'Runtime': '112 min',
#  'Title': 'Overdose: Death of a Punk Rocker',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'D.J. Yarotsky',
#  'Year': '2016',
#  'imdbID': 'tt3118034',
#  'imdbRating': '7.7',
#  'imdbVotes': '9'}
# -------------------
# movie id tt2363325
# -------------------
# {'Actors': 'Patience Ozokwor, Nonso Diobi, Linda Obasi, Fred Noyo',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Nigeria',
#  'DVD': 'N/A',
#  'Director': 'Aunna Fu, Linda Obasi',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A Nigerian born woman knows nothing of her birthplace until she '
#          'meets a recently emigrated medical student, with whom she learns '
#          'that culture is a force difficult to escape, even Overseas.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc5OTQ4Mjc1MF5BMl5BanBnXkFtZTcwMjA0MTI2OA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '20 Jun 2015',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': 'Overseas',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Aunna Fu',
#  'Year': '2015',
#  'imdbID': 'tt2363325',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3084904
# -------------------
# {'Actors': "Sonja O'Hara, Hassan Johnson, Rutanya Alda, Jaspal Binning",
#  'Awards': '5 wins & 1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '11 Apr 2017',
#  'Director': 'Matt Ott',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A quirky Brooklyn actress tries The Method to approach an Off '
#          'Broadway role and is drawn into the shady world of egg donation '
#          'clinics and the characters who populate them.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQxMTE3MTA2NV5BMl5BanBnXkFtZTgwNzk2MTM5MDE@._V1_SX300.jpg',
#  'Production': 'Random Media',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.2/10'}],
#  'Released': '19 Apr 2015',
#  'Response': 'True',
#  'Runtime': '86 min',
#  'Title': 'Ovum',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': "Sonja O'Hara",
#  'Year': '2015',
#  'imdbID': 'tt3084904',
#  'imdbRating': '8.2',
#  'imdbVotes': '87'}
# -------------------
# movie id tt2149087
# -------------------
# {'Actors': 'Jason Lopez, Treva Etienne, Phillipe Simon, G. Larry Butler',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Cedric Godin',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'After returning from Iraq, young military veteran Jason struggles to '
#          'adjust to civilian life. In search of his childhood friend, he '
#          'spirals deeper into depression.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTMyOTcxOTI2NV5BMl5BanBnXkFtZTcwOTY4MTMyNw@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.5/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '77 min',
#  'Title': 'P.T.S.D',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Cedric Godin',
#  'Year': '2012',
#  'imdbID': 'tt2149087',
#  'imdbRating': '7.5',
#  'imdbVotes': '15'}
# -------------------
# movie id tt6357878
# -------------------
# {'Actors': 'Amedeo Falgitore, Frank Goldsmith, Barry Greco, John Mathews',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Shadow',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Ten people from different backgrounds and ethnicities vent their '
#          'frustrations on how they believe they are being suppressed by '
#          'society and laws of government. First individually to a ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYTkzZGQxNTgtYTYwYy00MjE0LTgzMTktMWIwMjk5ZDcwNDIwL2ltYWdlXkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '13 Nov 2015',
#  'Response': 'True',
#  'Runtime': '115 min',
#  'Title': 'POV',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Frank Orefice Jr.',
#  'Year': '2015',
#  'imdbID': 'tt6357878',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5009334
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Cynthia Y.H. Derosier',
#  'Genre': 'History',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Pa'a Ke Aupuni is a unique 60-minute handdrawn, animated film that "
#          'gets straight to the point. It zooms in on key facts explaining how '
#          'the Hawaiian Kingdom came to be, how it evolved to ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '31 Jul 2015',
#  'Response': 'True',
#  'Runtime': '63 min',
#  'Title': "Pa'a Ke Aupuni",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kehaunani Abad',
#  'Year': '2015',
#  'imdbID': 'tt5009334',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5178824
# -------------------
# {'Actors': 'Jason Carter, Everette Dalton, Rayshawn Gordon, Big Greene',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kenneth l Hobbs',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '03 Aug 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Packman the Movie the Weedmans Diary',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kenneth l Hobbs (creator)',
#  'Year': '2015',
#  'imdbID': 'tt5178824',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4911496
# -------------------
# {'Actors': 'Pamela Jessup, Isobelle Mincus, Jerry Quinton',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Don Macy',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Ariella thought she just landed the perfect job transcribing tech '
#          'code. But when she starts to realize that there is more going on '
#          'then just copying series of numbers, the power behind the numbers '
#          'want to silence her.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Pages of the Code',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Don Macy',
#  'Year': '2015',
#  'imdbID': 'tt4911496',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3090208
# -------------------
# {'Actors': 'Daniel Girace, David Francis Calderazzo, Kim Parshley, Sid '
#            "O'Connell",
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Steve Rahaman',
#  'Genre': 'Action',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Will Donner, is released from prison after serving a 5 year '
#          'sentence. He tries to rebuild his life and home but is a witness to '
#          'a horrible crime. When the killer pushes him to the edge, Will has '
#          'no choice but to push back.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg4NTA5ODQ1Ml5BMl5BanBnXkFtZTgwODEzMDkyMDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'UNRATED',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.5/10'}],
#  'Released': '24 Apr 2015',
#  'Response': 'True',
#  'Runtime': '98 min',
#  'Title': 'Pain',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Steve Rahaman',
#  'Year': '2015',
#  'imdbID': 'tt3090208',
#  'imdbRating': '7.5',
#  'imdbVotes': '15'}
# -------------------
# movie id tt2006809
# -------------------
# {'Actors': 'Chris Staviski, Ivet Corvea, Elissa Dowling, Jessica Sonneborn',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Chris Staviski',
#  'Genre': 'Drama, Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'How far would you go to feel - anything.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDY3NzE3MTUyNV5BMl5BanBnXkFtZTcwMDkzNzQ0OA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.7/10'}],
#  'Released': '20 Jan 2015',
#  'Response': 'True',
#  'Runtime': '100 min',
#  'Title': 'Pain Is Beautiful',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Chris Staviski (story), Lee Woodford',
#  'Year': '2015',
#  'imdbID': 'tt2006809',
#  'imdbRating': '5.7',
#  'imdbVotes': '33'}
# -------------------
# movie id tt3310618
# -------------------
# {'Actors': 'Steve Moua, Nancy Vang, Gideon Xiong, Agnes Mayasari',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Seng Yang',
#  'Genre': 'Romance',
#  'Language': 'Hmong, English',
#  'Metascore': 'N/A',
#  'Plot': "A love triangle between two good friends Nraug Hli Xiong aka 'X', "
#          'Tou Lee and a fictional dream girl, Nkauj Hnub Xiong. X is every '
#          "woman's dream man. He's successful, intelligent and beyond...",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ1NjAyOTE3OV5BMl5BanBnXkFtZTgwNzg1Mzk1MDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.3/10'}],
#  'Released': '14 Nov 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Paj Ntaub - The Rose Cloth',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Gideon Xiong, Seng Yang',
#  'Year': '2015',
#  'imdbID': 'tt3310618',
#  'imdbRating': '7.3',
#  'imdbVotes': '6'}
# -------------------
# movie id tt3744264
# -------------------
# {'Actors': 'Jackson Rathbone, Sung Kang, Michelle Chen, Henry Ian Cusick',
#  'Awards': '7 wins & 5 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'China, USA',
#  'DVD': 'N/A',
#  'Director': 'Jonathan Hua Lang Lim',
#  'Genre': 'Drama, Fantasy, Mystery',
#  'Language': 'English',
#  'Metascore': '38',
#  'Plot': 'A young doctor wakes up from a car accident and discovers she is '
#          "married to another man and living a life she can't remember. Her "
#          'search for the truth to her past life will lead her to question '
#          'everyone around her and her entire existence.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMDM3ZTY2ZGYtYjRkOC00MGM1LWE2ODMtZmJlMDFjM2FiODQxXkEyXkFqcGdeQXVyMzc0MDcxMA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.8/10'},
#              {'Source': 'Metacritic', 'Value': '38/100'}],
#  'Released': '29 Apr 2016',
#  'Response': 'True',
#  'Runtime': '92 min',
#  'Title': 'Pali Road',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Doc Pedrolie, Victoria Arch',
#  'Year': '2015',
#  'imdbID': 'tt3744264',
#  'imdbRating': '7.8',
#  'imdbVotes': '5,610'}
# -------------------
# movie id tt2111382
# -------------------
# {'Actors': 'Luke Campbell, Erica Gately, Matt Green, Robert Christopher '
#            'Henderson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Joey Moran',
#  'Genre': 'Comedy, Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An inexperienced psychopath is trained to be a legendary masked '
#          'killer, by the would be victim who outsmarted him.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTgzNDk5MzQ3Nl5BMl5BanBnXkFtZTcwMTk2NjYxOQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '19 Dec 2013',
#  'Response': 'True',
#  'Runtime': '87 min',
#  'Title': 'Pals',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joey Moran',
#  'Year': '2013',
#  'imdbID': 'tt2111382',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3332064
# -------------------
# {'Actors': 'Hugh Jackman, Levi Miller, Garrett Hedlund, Rooney Mara',
#  'Awards': '8 nominations.',
#  'BoxOffice': '$35,914,825',
#  'Country': 'USA, UK, Australia',
#  'DVD': '22 Dec 2015',
#  'Director': 'Joe Wright',
#  'Genre': 'Adventure, Comedy, Family, Fantasy',
#  'Language': 'English',
#  'Metascore': '36',
#  'Plot': 'Twelve-year-old orphan Peter is spirited away to the magical world '
#          'of Neverland, where he finds both fun and danger, and ultimately '
#          'discovers his destiny -- to become the hero who will be for ever '
#          'known as Peter Pan.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzk2MDg5MDczMl5BMl5BanBnXkFtZTgwNTE2NjYyNjE@._V1_SX300.jpg',
#  'Production': 'Warner Bros.',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.7/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '27%'},
#              {'Source': 'Metacritic', 'Value': '36/100'}],
#  'Released': '09 Oct 2015',
#  'Response': 'True',
#  'Runtime': '111 min',
#  'Title': 'Pan',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jason Fuchs, J.M. Barrie (characters)',
#  'Year': '2015',
#  'imdbID': 'tt3332064',
#  'imdbRating': '5.7',
#  'imdbVotes': '57,043'}
# -------------------
# movie id tt4224482
# -------------------
# {'Actors': 'Sylvia Kleoniki, Max Hambleton, Matt DeNoto, Brock Wilbur',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Aaron Keene',
#  'Genre': 'Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A loner who is allergic to the sun hacks into webcams with an app he '
#          'created called Panopticon.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYThhYzZkYmItZTg5Yi00ODQ2LWI3OTgtMmQ4ODZiYWY1MjFkXkEyXkFqcGdeQXVyMTg3ODM2ODI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.8/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '86 min',
#  'Title': 'Panopticon',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Aaron Keene',
#  'Year': '2015',
#  'imdbID': 'tt4224482',
#  'imdbRating': '6.8',
#  'imdbVotes': '20'}
# -------------------
# movie id tt5143270
# -------------------
# {'Actors': 'Joe DeBartolo, Ali McGarel, Steve Christopher, Heather Jane Farr',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Michael Ramova',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Riley Rey feeds her interest in cryptozoology with a steady stream '
#          'of video uploads and the help of her older sister, Rebecca, who '
#          'plans to be the next hit cinematographer. With a YouTube ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMWExNWJmMTUtMjEyZS00Njg0LWE3ODgtYWE5NTE3MjhlMmRmXkEyXkFqcGdeQXVyMTczMDU2Mjc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.9/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '68 min',
#  'Title': 'Panteon Woods',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Ramova',
#  'Year': '2015',
#  'imdbID': 'tt5143270',
#  'imdbRating': '2.9',
#  'imdbVotes': '50'}
# -------------------
# movie id tt2749282
# -------------------
# {'Actors': 'Giovanni Ribisi, Joely Richardson, Adrian Sparks, Minka Kelly',
#  'Awards': '2 wins.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Canada',
#  'DVD': 'N/A',
#  'Director': 'Bob Yari',
#  'Genre': 'Biography, Drama',
#  'Language': 'English',
#  'Metascore': '37',
#  'Plot': 'In 1959, a young journalist ventures to Havana, Cuba to meet his '
#          'idol, the legendary Ernest Hemingway who helped him find his '
#          'literary voice, while the Cuban Revolution comes to a boil around '
#          'them.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjA5OTMzNTY4Nl5BMl5BanBnXkFtZTgwNTc5ODkzODE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'},
#              {'Source': 'Metacritic', 'Value': '37/100'}],
#  'Released': '29 Apr 2016',
#  'Response': 'True',
#  'Runtime': '110 min',
#  'Title': 'Papa Hemingway in Cuba',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Denne Bart Petitclerc',
#  'Year': '2015',
#  'imdbID': 'tt2749282',
#  'imdbRating': '6.3',
#  'imdbVotes': '1,261'}
# -------------------
# movie id tt3622592
# -------------------
# {'Actors': 'Nat Wolff, Cara Delevingne, Austin Abrams, Justice Smith',
#  'Awards': '4 wins & 3 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '20 Oct 2015',
#  'Director': 'Jake Schreier',
#  'Genre': 'Comedy, Drama, Mystery, Romance',
#  'Language': 'English',
#  'Metascore': '56',
#  'Plot': "After an all-night adventure, Quentin's lifelong crush, Margo, "
#          'disappears, leaving behind clues that Quentin and his friends follow '
#          'on the journey of a lifetime.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjE2ODQxODMwOF5BMl5BanBnXkFtZTgwNDY5NjY3NDE@._V1_SX300.jpg',
#  'Production': '20th Century Fox',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '57%'},
#              {'Source': 'Metacritic', 'Value': '56/100'}],
#  'Released': '24 Jul 2015',
#  'Response': 'True',
#  'Runtime': '109 min',
#  'Title': 'Paper Towns',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Scott Neustadter (screenplay by), Michael H. Weber (screenplay '
#            'by), John Green (based on the book by)',
#  'Year': '2015',
#  'imdbID': 'tt3622592',
#  'imdbRating': '6.3',
#  'imdbVotes': '90,379'}
# -------------------
# movie id tt3304688
# -------------------
# {'Actors': 'Adam Bowers, Dreama Walker, Colin Contreary, Genevieve Jones',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Adam Bowers',
#  'Genre': 'Comedy, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "A pizza cook who's never left his college town meets the woman of "
#          "his dreams before finding out there's a huge roadblock to them being "
#          'together.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.6/10'}],
#  'Released': '30 Oct 2015',
#  'Response': 'True',
#  'Runtime': '79 min',
#  'Title': 'Paperback',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Adam Bowers',
#  'Year': '2015',
#  'imdbID': 'tt3304688',
#  'imdbRating': '8.6',
#  'imdbVotes': '12'}
# -------------------
# movie id tt5210510
# -------------------
# {'Actors': 'Armando Lamberti, Brian May',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Armando Lamberti',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '21 Oct 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Paradigm Shrift',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2015',
#  'imdbID': 'tt5210510',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2391630
# -------------------
# {'Actors': 'Yolonda Williams, Michael W. Green, Tammy Thomas, Sheran Goodspeed '
#            'Keyton',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Arthur Muhammad, Thomas Tammy',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A sassy, no nonsense madam runs a "coloreds only" brothel in '
#          'Dallas,Tx in the late 1950s. While she and her house of tricks '
#          'service their regular customers, they run into some very peculiar...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDc3MDg5NjIyNV5BMl5BanBnXkFtZTgwNzA4MjE3NDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Paradise House',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tammy Thomas',
#  'Year': '2015',
#  'imdbID': 'tt2391630',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5116940
# -------------------
# {'Actors': 'Mark Carter, Sage Cattabriga-Alosa, Angel Collinson, Johnny '
#            'Collinson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Blake Campbell, Steve Jones, Todd Jones, Teton Gravity Research',
#  'Genre': 'Sport',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "From the award-winning filmmaking crew that brought you 2014's "
#          'Almost Ablaze, comes the story of one weird winter and the people '
#          'who celebrate it... Paradise Waits - a ski and snowboard film.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTc1OTEyNDA5Ml5BMl5BanBnXkFtZTgwODU2MzkwNzE@._V1_SX300.jpg',
#  'Production': 'Teton Gravity Research',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'}],
#  'Released': '01 Oct 2015',
#  'Response': 'True',
#  'Runtime': '69 min',
#  'Title': 'Paradise Waits',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2015',
#  'imdbID': 'tt5116940',
#  'imdbRating': '6.1',
#  'imdbVotes': '41'}
# -------------------
# movie id tt3858478
# -------------------
# {'Actors': 'Aidan Bouquin, Avery Bouquin, Edward James Fagan, Tom Harney',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Nick Morgulis',
#  'Genre': 'Drama, Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Inspired by true events. A struggling oyster fisherman helps care '
#          "for his friend's two young kids and finds himself fighting for the "
#          "family he didn't know that he needed.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzA5MjQyOGMtMTk4ZS00NzE3LTgwZWItMjY4NzdkMmI5ODAzXkEyXkFqcGdeQXVyNjExMjU2MTc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.6/10'}],
#  'Released': '11 Apr 2015',
#  'Response': 'True',
#  'Runtime': '113 min',
#  'Title': 'Paradise, FL',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Evan Mattson (storyline editor), Tony Stopperan, Tony Stopperan',
#  'Year': '2015',
#  'imdbID': 'tt3858478',
#  'imdbRating': '3.6',
#  'imdbVotes': '28'}
# -------------------
# movie id tt2253090
# -------------------
# {'Actors': 'Jeff Bosley, Elgin Cahill, Andrew Hunter, Shale Le Page',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Meredith Mantik',
#  'Genre': 'Western',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Modern-day filmmakers Cameron and Bernadette come to the West with '
#          'hopes to restore the Western genre. First, they need the perfect '
#          "cowboy. Enter Wayne, who's exactly what they wanted and more.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjM2MDE1MTMxOV5BMl5BanBnXkFtZTcwMDQwNjM0OQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 May 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Parallax',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Meredith Mantik',
#  'Year': '2013',
#  'imdbID': 'tt2253090',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2319216
# -------------------
# {'Actors': 'Michael Kelberg, Robb Stech, Mary Sarah Agliotta, Frank Vince',
#  'Awards': '2 wins & 8 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Graham Nolte',
#  'Genre': 'Comedy, Drama, History',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Set in 1987, Parallax is the story of a man who tries to create an '
#          'alternate vision for the Internet, but isolates himself throughout '
#          'the process.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDUyOTY3MzI4Nl5BMl5BanBnXkFtZTgwNjk2MTQ1MzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.4/10'}],
#  'Released': '01 Jan 2015',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'Parallax',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Graham Nolte',
#  'Year': '2015',
#  'imdbID': 'tt2319216',
#  'imdbRating': '7.4',
#  'imdbVotes': '11'}
# -------------------
# movie id tt4263774
# -------------------
# {'Actors': 'Terence Cranendonk, Liz DuChez, Richard Portnow, Amy Cates',
#  'Awards': '7 wins & 3 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Keith Nickoson, John Turk',
#  'Genre': 'Drama, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A brilliant mathematician travels through time and space in search '
#          'of the knowledge that would allow him to control his life and alter '
#          'the events of his past. What he discovers is that he ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTcxNjA0MDkxMF5BMl5BanBnXkFtZTgwNDc1Nzk5NjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.4/10'}],
#  'Released': '10 Feb 2015',
#  'Response': 'True',
#  'Runtime': '91 min',
#  'Title': 'Parallel',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Keith Nickoson',
#  'Year': '2015',
#  'imdbID': 'tt4263774',
#  'imdbRating': '6.4',
#  'imdbVotes': '59'}
# -------------------
# movie id tt3479316
# -------------------
# {'Actors': 'Mark Hapka, Jessica Rothe, Eric Jungmann, Constance Wu',
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Christopher Leone',
#  'Genre': 'Action, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A mysterious building is the gateway to infinite parallel Earths.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTY4ODM3MjUxMl5BMl5BanBnXkFtZTgwNTY5NTIxNTE@._V1_SX300.jpg',
#  'Production': 'Fox',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'}],
#  'Released': '01 Mar 2015',
#  'Response': 'True',
#  'Runtime': '83 min',
#  'Title': 'Parallels',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Laura Harkcom (story), Christopher Leone (story), Christopher '
#            'Leone (teleplay)',
#  'Year': '2015',
#  'imdbID': 'tt3479316',
#  'imdbRating': '6.1',
#  'imdbVotes': '13,035'}
# -------------------
# movie id tt2473510
# -------------------
# {'Actors': 'Chris J. Murray, Brit Shaw, Ivy George, Dan Gill',
#  'Awards': '1 win & 4 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '12 Jan 2016',
#  'Director': 'Gregory Plotkin',
#  'Genre': 'Horror, Mystery, Thriller',
#  'Language': 'English, German, Ukrainian',
#  'Metascore': '30',
#  'Plot': 'Using a special camera that can see spirits, a family must protect '
#          'their daughter from an evil entity with a sinister plan.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjQxMjE5OTA3OF5BMl5BanBnXkFtZTgwMDAxNTg4NjE@._V1_SX300.jpg',
#  'Production': 'Paramount Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '14%'},
#              {'Source': 'Metacritic', 'Value': '30/100'}],
#  'Released': '23 Oct 2015',
#  'Response': 'True',
#  'Runtime': '88 min',
#  'Title': 'Paranormal Activity: The Ghost Dimension',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jason Pagan (screenplay), Andrew Deutschman (screenplay), Adam '
#            'Robitel (screenplay), Gavin Heffernan (screenplay), Brantley '
#            'Aufill (story), Jason Pagan (story), Andrew Deutschman (story), '
#            'Oren Peli (based on the film "Paranormal Activity")',
#  'Year': '2015',
#  'imdbID': 'tt2473510',
#  'imdbRating': '4.6',
#  'imdbVotes': '23,194'}
# -------------------
# movie id tt4117444
# -------------------
# {'Actors': 'Santiago Cirilo, David Chandler, Matthew Broadrick, Kevin R. '
#            'Sexton',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kevin R. Sexton',
#  'Genre': 'Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Dalton, GA is the battleground for good vs. evil in this third '
#          'installment in the Paranormal Chasers saga. Dread Drake and his '
#          'coven have come to wreak havoc on this sleepy little town and ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Paranormal Chasers Legend of the Black Cross',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kevin R. Sexton',
#  'Year': '2015',
#  'imdbID': 'tt4117444',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3959084
# -------------------
# {'Actors': 'Colie Knoke, Josef Niznik, Grace LaFleur, Ted V. Mikels',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ted V. Mikels',
#  'Genre': 'Drama, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Two loves are separated by a tragic accident but death cannot keep '
#          'them apart. This is a haunting tale of love, life, death, and the '
#          'intervention of the dead.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjM4ODEzMzY5OF5BMl5BanBnXkFtZTgwNTMwNzY2OTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'NOT RATED',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.3/10'}],
#  'Released': '01 May 2015',
#  'Response': 'True',
#  'Runtime': '102 min',
#  'Title': 'Paranormal Extremes: Text Messages from the Dead',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ted V. Mikels (screenplay), Cory Udler (screenplay)',
#  'Year': '2015',
#  'imdbID': 'tt3959084',
#  'imdbRating': '2.3',
#  'imdbVotes': '79'}
# -------------------
# movie id tt6607232
# -------------------
# {'Actors': 'Carter Aakhus, Nicholas Erickson, Cat Barrett, Andrew Nosal',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Andrew Nosal',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Nov 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Paranormal Squad',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Andrew Nosal',
#  'Year': '2015',
#  'imdbID': 'tt6607232',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt11589692
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt3043252
# -------------------
# {'Actors': 'Tannishtha Chatterjee, Radhika Apte, Lehar Khan, Surveen Chawla',
#  'Awards': '9 wins & 4 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'India, UK, USA',
#  'DVD': '09 Aug 2016',
#  'Director': 'Leena Yadav',
#  'Genre': 'Drama',
#  'Language': 'Hindi, English',
#  'Metascore': '67',
#  'Plot': 'In the arid landscape of Rajashthan, four women navigate their way '
#          'through personal and cultural difficulties.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjgzNTFlNmItZGViNC00MWFkLWE4MDItOWNiZGU1NmMwMWMzXkEyXkFqcGdeQXVyMTExNDQ2MTI@._V1_SX300.jpg',
#  'Production': 'Shivalaya Entertainment',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.5/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '86%'},
#              {'Source': 'Metacritic', 'Value': '67/100'}],
#  'Released': '17 Jun 2016',
#  'Response': 'True',
#  'Runtime': '116 min',
#  'Title': 'Parched',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Supratik Sen (dialogue), Leena Yadav',
#  'Year': '2015',
#  'imdbID': 'tt3043252',
#  'imdbRating': '7.5',
#  'imdbVotes': '4,316'}
# -------------------
# movie id tt2370110
# -------------------
# {'Actors': 'Tanya R. Barnes, Mary Birdsong, Megan Boundy, Jace Downs',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Hannah Rosner',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A team of scrappy indie filmmakers must find their lost film print '
#          'before its premiere at the Sundance Film Festival.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.9/10'}],
#  'Released': '01 Apr 2015',
#  'Response': 'True',
#  'Runtime': '86 min',
#  'Title': 'Park City',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Hannah Rosner, Julia Turner, Julia Turner (screenplay)',
#  'Year': '2015',
#  'imdbID': 'tt2370110',
#  'imdbRating': '7.9',
#  'imdbVotes': '15'}
# -------------------
# movie id tt3155242
# -------------------
# {'Actors': 'Vincent Cassel, Florence Mezzara, Esther Blaser-Tokarev, Charlotte '
#            'Miller',
#  'Awards': '2 wins & 14 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'Australia, USA',
#  'DVD': '08 Dec 2015',
#  'Director': 'Ariel Kleiman',
#  'Genre': 'Drama, Thriller',
#  'Language': 'English',
#  'Metascore': '50',
#  'Plot': 'Alexander, a boy who has been raised in a sequestered commune, finds '
#          'that his increasing unwillingness to fall in line puts him on a '
#          "collision course with Gregori, the society's charismatic and "
#          'domineering leader.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODUwMDI4NDgyOF5BMl5BanBnXkFtZTgwODIyNDU3NjE@._V1_SX300.jpg',
#  'Production': 'Well Go USA',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '57%'},
#              {'Source': 'Metacritic', 'Value': '50/100'}],
#  'Released': '02 Oct 2015',
#  'Response': 'True',
#  'Runtime': '94 min',
#  'Title': 'Partisan',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ariel Kleiman, Sarah Cyngler',
#  'Year': '2015',
#  'imdbID': 'tt3155242',
#  'imdbRating': '5.8',
#  'imdbVotes': '3,703'}
# -------------------
# movie id tt8286178
# -------------------
# {'Actors': 'Krysten Kiyoko, Else Johnson, David Murray, Kevin J. Ford',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Alessio Di Zio',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Four creative and sexually confused high school seniors are forced '
#          'to deal with their sense of isolation while attending a booze-soaked '
#          'party in New York City.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZjg0NWJmYzctMWNkMy00OGZlLTk5NTEtM2NiOThkMDY0N2U3XkEyXkFqcGdeQXVyMzA0ODYwNzU@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.4/10'}],
#  'Released': '08 Apr 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Party Talk',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Alessio Di Zio',
#  'Year': '2015',
#  'imdbID': 'tt8286178',
#  'imdbRating': '8.4',
#  'imdbVotes': '11'}
# -------------------
# movie id tt2572030
# -------------------
# {'Actors': 'Cameron Palatas, Dalpre Grayer, Alexandria DeBerry, Colby French',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Malcolm Goodwin',
#  'Genre': 'Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The story of Steve Bellafiore, a 17-year-old high school senior who '
#          'decides to run for Congress in order to protect the faith that he so '
#          'loves.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTgwMzU0MjY5Ml5BMl5BanBnXkFtZTgwOTM4OTI5MjE@._V1_SX300.jpg',
#  'Production': 'DigiNext',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'}],
#  'Released': '06 Feb 2015',
#  'Response': 'True',
#  'Runtime': '112 min',
#  'Title': 'Pass the Light',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Victor Hawks',
#  'Year': '2015',
#  'imdbID': 'tt2572030',
#  'imdbRating': '6.2',
#  'imdbVotes': '86'}
# -------------------
# movie id tt5465388
# -------------------
# {'Actors': 'Chad Giovanni, Mallory Rose, Caitlin Cardile, Madeline Lewis',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jared Kasanofsky, Constance Nam',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Three young adults are reunited for their first high school reunion '
#          'forcing them to crossroads on an unexpected path of self discovery.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '72 min',
#  'Title': 'Past Crossroads',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jared Kasanofsky, Constance Nam',
#  'Year': '2015',
#  'imdbID': 'tt5465388',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3399888
# -------------------
# {'Actors': 'Damion Lee, James Argiro, Natalie Neilson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Robert Fritz',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A girl who does grave rubbings has to come to terms with living in '
#          'present.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTgzNjY5OTMwOV5BMl5BanBnXkFtZTgwMzI5OTk1MjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '91 min',
#  'Title': 'Past Tense',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Robert Fritz',
#  'Year': '2013',
#  'imdbID': 'tt3399888',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4929720
# -------------------
# {'Actors': 'Tory Stolper, Tracey Fairaway, Maria Blasucci, James Phelps',
#  'Awards': '8 wins.',
#  'BoxOffice': 'N/A',
#  'Country': 'Canada, USA',
#  'DVD': 'N/A',
#  'Director': 'Tyler MacIntyre',
#  'Genre': 'Comedy, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A bombastic throw-back horror-comedy that follows three young women '
#          'who go out partying one night and find themselves Frankensteined '
#          'together in one body. Now they must put aside their ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjA4MDg1MjE3N15BMl5BanBnXkFtZTgwMjc4NTUwNzE@._V1_SX300.jpg',
#  'Production': 'Infinite Lives Entertainment',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'}],
#  'Released': '06 Jun 2017',
#  'Response': 'True',
#  'Runtime': '86 min',
#  'Title': 'Patchwork',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Chris Lee Hill, Tyler MacIntyre',
#  'Year': '2015',
#  'imdbID': 'tt4929720',
#  'imdbRating': '5.8',
#  'imdbVotes': '1,377'}
# -------------------
# movie id tt3300442
# -------------------
# {'Actors': 'Jacob York, Charlie David, Chris Salvatore, Britten Tillinghast',
#  'Awards': '9 wins & 7 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Matt Riddlehoover',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Four years into his first stable relationship, a man finds out that '
#          "he is pregnant with his partner's baby.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNWQ3ZDBlZDgtMmFlZi00NWNhLWI0MTItZDYwYWE1MmZkMzJlXkEyXkFqcGdeQXVyNjEwOTIyNA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'NOT RATED',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'}],
#  'Released': '24 Nov 2015',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Paternity Leave',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Matt Riddlehoover, Dustin Tittle',
#  'Year': '2015',
#  'imdbID': 'tt3300442',
#  'imdbRating': '6.5',
#  'imdbVotes': '1,244'}
# -------------------
# movie id tt3274704
# -------------------
# {'Actors': 'Victoria Pratt, Barbie Castro, Casper Van Dien, Richard Burgi',
#  'Awards': '3 wins.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Casper Van Dien',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "In an effort to uncover the truth behind her patient's nightmares, a "
#          'psychiatrist suggests hypnosis without realizing the deadly '
#          'consequences.',
#  'Poster': 'https://ia.media-imdb.com/images/M/MV5BMzA0NzUzMDI0OF5BMl5BanBnXkFtZTgwNTAzOTE3MjE@._V1_SX300.jpg',
#  'Production': 'Concord Films',
#  'Rated': 'UNRATED',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.8/10'}],
#  'Released': '13 Jan 2015',
#  'Response': 'True',
#  'Runtime': '89 min',
#  'Title': 'Patient Killer',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Bryan Dick, Brian D. Young',
#  'Year': '2015',
#  'imdbID': 'tt3274704',
#  'imdbRating': '4.8',
#  'imdbVotes': '275'}
# -------------------
# movie id tt2504514
# -------------------
# {'Actors': 'Marisa Brown, Barney Fitzpatrick, Brian Gallagher, Anthony Lawton',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Sean McGarry',
#  'Genre': 'Drama, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A Technophobe angling correspondent, Patric, occupies an off-kilter '
#          'reality counting raindrops with his family of cats. As social media '
#          'threatens his career, a dark and thrilling flirtation with a Swiss '
#          'model begins.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ1NDYyNDcwMl5BMl5BanBnXkFtZTcwMjA5NTI4OQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '110 min',
#  'Title': 'Patric',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Sean McGarry',
#  'Year': '2015',
#  'imdbID': 'tt2504514',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4901222
# -------------------
# {'Actors': 'Jonita Doda, Raj Kakra, Navdeep Kaler, Mani Maan',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Naresh s Garg',
#  'Genre': 'Action',
#  'Language': 'Punjabi',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjg2Zjc5NzgtZTk2Yi00MjUwLTk2YWUtMzM2ZmE5NGIyYTg5XkEyXkFqcGdeQXVyNDUzMjk2NjQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '9.2/10'}],
#  'Released': '17 Apr 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Patta Patta Singhan Da Vairi',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2015',
#  'imdbID': 'tt4901222',
#  'imdbRating': '9.2',
#  'imdbVotes': '12'}
# -------------------
# movie id tt3450650
# -------------------
# {'Actors': 'Kevin James, Raini Rodriguez, Neal McDonough, Daniella Alonso',
#  'Awards': '1 win & 9 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '21 Jul 2015',
#  'Director': 'Andy Fickman',
#  'Genre': 'Action, Comedy, Crime, Family',
#  'Language': 'English',
#  'Metascore': '13',
#  'Plot': 'After six years of keeping our malls safe, Paul Blart has earned a '
#          'well-deserved vacation. He heads to Las Vegas with his teenage '
#          'daughter before she heads off to college. But safety never takes a '
#          'holiday and when duty calls, Blart answers.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTkwMjkxNDQ1MV5BMl5BanBnXkFtZTgwNDQwODIxNTE@._V1_SX300.jpg',
#  'Production': 'Sony Pictures',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.4/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '5%'},
#              {'Source': 'Metacritic', 'Value': '13/100'}],
#  'Released': '17 Apr 2015',
#  'Response': 'True',
#  'Runtime': '94 min',
#  'Title': 'Paul Blart: Mall Cop 2',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kevin James, Nick Bakay, Kevin James (characters), Nick Bakay '
#            '(characters)',
#  'Year': '2015',
#  'imdbID': 'tt3450650',
#  'imdbRating': '4.4',
#  'imdbVotes': '32,174'}
# -------------------
# movie id tt3052982
# -------------------
# {'Actors': 'Bryant Mainord, Alder Rye Fletcher, Rebecca Barker',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Bryant Mainord',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '122 min',
#  'Title': 'Paul and Bryant Summon a Demon',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Bryant Mainord',
#  'Year': '2015',
#  'imdbID': 'tt3052982',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4351934
# -------------------
# {'Actors': 'Daniel Andries, Michael Christopher, Mike Christopher, Rob '
#            'Christopher',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Rob Christopher',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The year is 1995. Two college roommates, Dylan and Rob, are making a '
#          'movie called "Crueler Than Truth" with a group of their friends in '
#          "Colorado and Chicago. During the shoot Dylan stumbles upon Rob's "
#          'diary and secretly begins to read it.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ4NDc5NDU5OF5BMl5BanBnXkFtZTgwNDg0Mzk2NDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.6/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '78 min',
#  'Title': 'Pause of the Clock',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Rob Christopher',
#  'Year': '2015',
#  'imdbID': 'tt4351934',
#  'imdbRating': '7.6',
#  'imdbVotes': '5'}
# -------------------
# movie id tt3733778
# -------------------
# {'Actors': 'Nicolas Cage, Sarah Wayne Callies, Veronica Ferres, Lyriq Bent',
#  'Awards': '1 win & 2 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Uli Edel',
#  'Genre': 'Drama, Horror, Mystery, Thriller',
#  'Language': 'English, Spanish, Chinese, Scottish Gaelic',
#  'Metascore': '23',
#  'Plot': 'A professor frantically searches for his son who was abducted during '
#          'a Halloween carnival.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzY3MTc3NzQ1Nl5BMl5BanBnXkFtZTgwNjk2MDE3NjE@._V1_SX300.jpg',
#  'Production': 'Voltage Films',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.2/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '10%'},
#              {'Source': 'Metacritic', 'Value': '23/100'}],
#  'Released': '25 Sep 2015',
#  'Response': 'True',
#  'Runtime': '94 min',
#  'Title': 'Pay the Ghost',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tim Lebbon (novel), Dan Kay (screenplay)',
#  'Year': '2015',
#  'imdbID': 'tt3733778',
#  'imdbRating': '5.2',
#  'imdbVotes': '14,689'}
# -------------------
# ...
#  'Genre': 'Horror, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Led by a madly enthusiastic director, a team of amateur filmmakers '
#          'hole up in a former undercover DOD research facility to make a film '
#          'about a dream researcher who disappeared while in the midst of a '
#          'secret neurological experiment.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk0NTI0NjgyNF5BMl5BanBnXkFtZTgwNjQ2Njk2MTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'}],
#  'Released': '27 Mar 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Shells',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Max Finneran',
#  'Year': '2015',
#  'imdbID': 'tt2081394',
#  'imdbRating': '5.8',
#  'imdbVotes': '21'}
# -------------------
# movie id tt3400058
# -------------------
# {'Actors': 'Michael Paré, Lauren Alexandra, Rachel G. Whittle, John Fallon',
#  'Awards': '1 win.',
#  'BoxOffice': 'N/A',
#  'Country': 'Canada, USA',
#  'DVD': 'N/A',
#  'Director': 'John Fallon',
#  'Genre': 'Drama, Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A homeless man named Thomas (Michael Pare) finds shelter for the '
#          'night within a lavish abandoned two-story house. He eventually '
#          "discovers that he is not alone and the premises won't let him leave.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjMwNzk0MzUyOF5BMl5BanBnXkFtZTgwMjE5NTIzMDI@._V1_SX300.jpg',
#  'Production': 'Screen Media Films',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.8/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '41%'}],
#  'Released': '28 Aug 2015',
#  'Response': 'True',
#  'Runtime': '76 min',
#  'Title': 'The Shelter',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'John Fallon (story), John Fallon, John Fallon',
#  'Year': '2015',
#  'imdbID': 'tt3400058',
#  'imdbRating': '3.8',
#  'imdbVotes': '261'}
# -------------------
# movie id tt3211226
# -------------------
# {'Actors': 'John Woodley, Gina Tarrou, Mark Mumm, Natalie Vazquez',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Leo Kayembe',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Two mall cops find the women of their dreams. There's only one catch "
#          "- they're shoplifters.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjEwNTEyMzEwOV5BMl5BanBnXkFtZTgwNjc0MDQ4MDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '04 Nov 2015',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'The Shopping Affair',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Leo Kayembe (screenplay), Leo Kayembe (story), Leo Kayembe, '
#            'Charity Lynn (story)',
#  'Year': '2015',
#  'imdbID': 'tt3211226',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5326626
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'Drama, Mystery',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': "'The Shrink' is a powerful drama that revolves around an unusual "
#          "Saturday appointment at Dr. Andre Collins' (Lamar Staples) office "
#          "when the tables are turned on the doctor. The 'patient' ...",
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '67 min',
#  'Title': 'The Shrink',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2015',
#  'imdbID': 'tt5326626',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt1853481
# -------------------
# {'Actors': 'Yankie Grant, Phil Nichols, Shelley Boozer, Michael Raabe',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Phil Nichols',
#  'Genre': 'Horror',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': "A modern retelling of Mary Shelley's Frankenstein.",
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '31 Oct 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Sick and Twisted Tale of Frankenstein',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Melissa L. Nichols, Phil Nichols, Mary Shelley (certain '
#            'characters)',
#  'Year': '2015',
#  'imdbID': 'tt1853481',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4524446
# -------------------
# {'Actors': 'David Colacci, Isaac Keys, Jamaal Khalil, Escalante Lundy',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'D.A. Bullock',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'THE SICKLE SACRED GROUND DEMANDS SACRIFICE... There is an evil in '
#          'the land... A boy and his teacher struggle to cope with a new world '
#          'around them that calls into question their definitions ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '83 min',
#  'Title': 'The Sickle',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'D.A. Bullock',
#  'Year': '2015',
#  'imdbID': 'tt4524446',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3249034
# -------------------
# {'Actors': 'Kirk Bovill, Potsch Boyd, Connie Cooper, Doug Dezzani',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Doug Dezzani',
#  'Genre': 'Drama, Mystery, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'On Feb 11th 2013, Mia Hollingworth and her boyfriend went searching '
#          "for the truth behind her mother's alien abduction. After three days "
#          'of searching, they were never heard from again. This is the document '
#          'of their journey.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTU2NTE2ODEyNl5BMl5BanBnXkFtZTgwMzI5ODQ2NzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.2/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '81 min',
#  'Title': 'The Sighting',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Doug Dezzani',
#  'Year': '2015',
#  'imdbID': 'tt3249034',
#  'imdbRating': '4.2',
#  'imdbVotes': '89'}
# -------------------
# movie id tt3126162
# -------------------
# {'Actors': 'Lindsay Reynolds, Eric Calderon, Christopher Robert Gray, Sabina '
#            'Leigh',
#  'Awards': '1 win & 2 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Evgueni Mlodik',
#  'Genre': 'Drama, Horror, Musical',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'On a rainy night, a dead body is fished out of a lake and brought to '
#          'a local morgue. The details of who she is or what happened to her '
#          'are unknown. What drove the girl to such a grisly fate?',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQzOTczMTc0NV5BMl5BanBnXkFtZTgwNDE5ODMzMDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.8/10'}],
#  'Released': '17 Jan 2015',
#  'Response': 'True',
#  'Runtime': '50 min',
#  'Title': 'The Silver Moonlight',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Evgueni Mlodik (screenplay)',
#  'Year': '2015',
#  'imdbID': 'tt3126162',
#  'imdbRating': '7.8',
#  'imdbVotes': '17'}
# -------------------
# movie id tt3605262
# -------------------
# {'Actors': 'Isaiah Washington, Lisa Arrindell, Salli Richardson-Whitfield, C. '
#            'Thomas Howell',
#  'Awards': '1 win.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Paul D. Hannah',
#  'Genre': 'Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Rose Ricard has a gift, she can see into your soul. She can discern '
#          'the truth from a lie and sometimes, she can perceive the very '
#          'thoughts before they are formed in your mind. She uses ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzE2MTYwODEwM15BMl5BanBnXkFtZTgwNTI2OTg5NjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.6/10'}],
#  'Released': '13 Oct 2015',
#  'Response': 'True',
#  'Runtime': '109 min',
#  'Title': 'The Sin Seer',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Paul D. Hannah (story), Paul D. Hannah',
#  'Year': '2015',
#  'imdbID': 'tt3605262',
#  'imdbRating': '3.6',
#  'imdbVotes': '232'}
# -------------------
# movie id tt3072376
# -------------------
# {'Actors': 'Eve Plumb, Lisa Hammer, Lisa Ferber, Levi Wilson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Lisa Hammer',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Three eccentric heiresses who live with their butler.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Sisters Plotz',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Lisa Ferber (creator), Lisa Ferber (story), Lisa Hammer (story)',
#  'Year': '2015',
#  'imdbID': 'tt3072376',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3783422
# -------------------
# {'Actors': 'Anna Callegari, Sam Reece, Elyse Brandau, Lily Du',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Brandon Bassham',
#  'Genre': 'Comedy, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Best friends Lucy, Eva, Ashley, Beth and Margot have a sleepover '
#          'like any other - until murder joins the party. A tale of friendship, '
#          'betrayal, madness, and the search for some decent dick.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ3MzU4NDQ5Ml5BMl5BanBnXkFtZTgwODE5NzI4NjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'NOT RATED',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.2/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '82 min',
#  'Title': 'The Slashening',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Brandon Bassham (story by), Reynard Alli (story by), Brandon '
#            'Bassham',
#  'Year': '2015',
#  'imdbID': 'tt3783422',
#  'imdbRating': '4.2',
#  'imdbVotes': '143'}
# -------------------
# movie id tt4887346
# -------------------
# {'Actors': "Jessica Willis, Jay Bowdy, Summer Ayala, D'nel Hunter",
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '29 Oct 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The SocialPath',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2015',
#  'imdbID': 'tt4887346',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3781922
# -------------------
# {'Actors': 'Frances Reagan James, Brad Kilmer, Jeremy Kovach, Ray La Rochelle',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tamas Birinyi',
#  'Genre': 'Mystery',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '12 May 2015',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': 'The Song',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tamas Birinyi',
#  'Year': '2015',
#  'imdbID': 'tt3781922',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt1235203
# -------------------
# {'Actors': 'Sergio Togliatti, John Gross, Siobhan Togliatti, Paul Supplee',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Elanor Togliatti',
#  'Genre': 'Adventure, Drama, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Omar Ney is a 200-year-old sorcerer doing good works for humanity. '
#          'He is powerful; but can he fend off great challenges to his purpose '
#          'here and meet his destiny before his time on earth runs out?',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjA1ODQ0OTE3OF5BMl5BanBnXkFtZTgwODM2NzYxNzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.0/10'}],
#  'Released': '30 Oct 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Sorcerer',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2015',
#  'imdbID': 'tt1235203',
#  'imdbRating': '6.0',
#  'imdbVotes': '5'}
# -------------------
# movie id tt5509842
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Elanor Togliatti',
#  'Genre': 'Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A sorcerer and his band of redeemed ghosts battle a corrupted priest '
#          'and a media mogul for the souls of a mother and her son.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '99 min',
#  'Title': 'The Sorcerer',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2015',
#  'imdbID': 'tt5509842',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3113688
# -------------------
# {'Actors': 'Ben Felix Mironer, Alison Woods, Daniel David Stewart, Kevin P. '
#            'Farley',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Christopher Broe, Basil Mironer',
#  'Genre': 'Comedy, Family, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Bart Bagelszby is tired of being ignored by the girl of his dreams. '
#          'Now, he has a master plan that will transform himself and his '
#          'awkward group of friends, from choir nerds to rock gods. ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '93 min',
#  'Title': 'The Sound of Magic',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Christopher Broe, Garrett Lander, Basil Mironer, Eugene Mironer '
#            '(story)',
#  'Year': '2015',
#  'imdbID': 'tt3113688',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5086548
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Basil Mironer',
#  'Genre': 'Comedy, Family, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Bart Bagelszby is tired of being ignored by the girl of his dreams. '
#          'Now, he has a master plan that will transform himself and his '
#          'awkward group of friends, from choir nerds to rock gods. ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '93 min',
#  'Title': 'The Sound of Magic Soundtrack',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2015',
#  'imdbID': 'tt5086548',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt1894622
# -------------------
# {'Actors': 'Kristos Andrews, Santiago Douglas, Felix Delgado, Anthony Aquilino',
#  'Awards': '2 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Gregori J. Martin',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': '19-year-old Robert Areizaga Jr. was murdered in White Plains, New '
#          'York at a party in the Fall of 2010 by a vicious gang. Based on the '
#          'true story.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQxOTI5NjQ3M15BMl5BanBnXkFtZTcwMTk4OTM0Nw@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.5/10'}],
#  'Released': '21 Apr 2015',
#  'Response': 'True',
#  'Runtime': '100 min',
#  'Title': 'The Southside',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Gregori J. Martin (screenplay)',
#  'Year': '2015',
#  'imdbID': 'tt1894622',
#  'imdbRating': '8.5',
#  'imdbVotes': '19'}

# %%
len(title_list)
# Out:
# 979

# %%
len(title_id)
# Out:
# 979

# %%
# if title_list and title_id are the same length run the cell below. 
# if they are not equal take out 'title_id': title_id

# %%
df = pd.DataFrame({'title_id': title_id, 'title': title_list, 'box_office': box_office_list, 'country': country_list, 
                   'genre': genre_list, 'director': director_list, 'metascore': metascore_list, 'production': production_list, 
                   'rating': rating_list, 'IMDB_rating': IMDB_rating_list, 'rotten_tomatoes_rating': rotten_tomatoes_rating_list, 
                  'runtime': runtime_list, 'type': type_list, 'IMDB_votes': imdb_votes_list})

# %%
df = df.drop_duplicates()
df.head()
# Out:
#     title_id                             title box_office       country  \
# 0  tt4914072     Outside Through the Labyrinth        N/A           USA
# 1  tt3032288                           Ovation        N/A           USA
# 2  tt3118034  Overdose: Death of a Punk Rocker        N/A           USA
# 3  tt2363325                          Overseas        N/A  USA, Nigeria
# 4  tt3084904                              Ovum        N/A           USA
#
#                            genre               director metascore  \
# 0                          Drama             Scott Shaw       N/A
# 1                  Comedy, Drama           Henry Jaglom       N/A
# 2  Comedy, Drama, Music, Mystery          D.J. Yarotsky       N/A
# 3                          Drama  Aunna Fu, Linda Obasi       N/A
# 4                  Comedy, Drama               Matt Ott       N/A
#
#      production     rating IMDB_rating rotten_tomatoes_rating  runtime   type  \
# 0           N/A        N/A         N/A                     NA   53 min  movie
# 1           N/A          R         5.6                     NA  105 min  movie
# 2           N/A        N/A         7.7                     NA  112 min  movie
# 3           N/A        N/A         N/A                     NA   95 min  movie
# 4  Random Media  Not Rated         8.2                     NA   86 min  movie
#
#   IMDB_votes
# 0        N/A
# 1         17
# 2          9
# 3        N/A
# 4         87

# %%
df.count()
# Out:
# title_id                  979
# title                     979
# box_office                979
# country                   979
# genre                     979
# director                  979
# metascore                 979
# production                979
# rating                    979
# IMDB_rating               979
# rotten_tomatoes_rating    979
# runtime                   979
# type                      979
# IMDB_votes                979
# dtype: int64

# %%
df.to_csv('../data/2015_data_batch_3.csv', index=False)
