# %%
import pandas as pd
import requests
import json
import time
from pprint import pprint
from config import API_KEY

# %%
data = pd.read_csv('../data/titles_2015_batch2.csv')
df =  data.count()
df
# Out:
# title    1000
# dtype: int64

# %%
title_id = []
box_office_list = []
country_list = []
genre_list = []
director_list = []
metascore_list = []
production_list = []
rating_list = []
IMDB_rating_list = [] 
rotten_tomatoes_rating_list = []
runtime_list = []
title_list = []
type_list = []
imdb_votes_list = []

# %%
movies = data['title']
total_movies = len(movies)

# %%
for i in range(total_movies):
    movie = movies[i]
    url = "http://www.omdbapi.com/?i=" + movie + "&apikey=" + API_KEY
    response = (requests.get(url).text)
    response_json = json.loads(response)
    print('-------------------')
    print(f'movie id {movie}')
    print('-------------------')
    pprint(response_json)
    
    try:
        box_office_list.append(response_json['BoxOffice'])
        country_list.append(response_json['Country'])
        genre_list.append(response_json['Genre'])
        director_list.append(response_json['Director'])
        metascore_list.append(response_json['Metascore'])
        production_list.append(response_json['Production'])
        rating_list.append(response_json['Rated'])
        IMDB_rating_list.append(response_json['imdbRating'])
        try:
            if not response_json['Ratings']:
                rotten_tomatoes_rating_list.append('NA')
            elif response_json['Ratings'][0]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][0]['Value'])
            elif response_json['Ratings'][1]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][1]['Value'])
            else:
                rotten_tomatoes_rating_list.append('NA')
        except IndexError:
            rotten_tomatoes_rating_list.append('NA')
        runtime_list.append(response_json['Runtime'])
        title_list.append(response_json['Title'])
        type_list.append(response_json['Type'])
        imdb_votes_list.append(response_json['imdbVotes'])
        title_id.append(response_json['imdbID'])
    except KeyError:
        pass
    time.sleep(1)
# Out:
# -------------------
# movie id tt3784230
# -------------------
# {'Actors': 'Douglas Smith, David Arquette, Annika Noelle, James Moses Black',
#  'Awards': '2 wins.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Sandy Tung',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Evan White is unjustly accused of selling marijuana and cocaine and '
#          'being threatened with up to 28 years in jail by an ambitious Federal '
#          'prosecutor.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTMzMTYxNTU2OV5BMl5BanBnXkFtZTgwMTE4NTY0NjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.3/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': "Evan's Crime",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dale Rosenbloom, David Assael, Sandy Tung',
#  'Year': '2015',
#  'imdbID': 'tt3784230',
#  'imdbRating': '5.3',
#  'imdbVotes': '110'}
# -------------------
# movie id tt8929768
# -------------------
# {'Actors': 'Estrella Almada Cervantes, Victor Hugo',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'N/A',
#  'Language': 'Spanish',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '24 Jan 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Evangelista Sin Credencial',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2015',
#  'imdbID': 'tt8929768',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3362234
# -------------------
# {'Actors': 'Patrick Hickman, Ryan Feeley, Nate Lyles, Gina Martino',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Dimitri Voutsinos',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'In the wake of a girl gone missing, the archaic feeling of obsession '
#          'turns the people of a suburban neighborhood into deeply disturbed '
#          'versions of their normal selves.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '86 min',
#  'Title': 'Eventide',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ryan Feeley (concept), Nate Lyles (story), Dimitri Voutsinos, Mike '
#            'Voutsinos (contributing writer)',
#  'Year': '2014',
#  'imdbID': 'tt3362234',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2250418
# -------------------
# {'Actors': 'N/A',
#  'Awards': '1 win.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Fernando A. Mico',
#  'Genre': 'Action, Crime, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Elite assassin Miko returns to complete one last mission.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjEzNTg0NjQ2Ml5BMl5BanBnXkFtZTgwNzI5NDY1MzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Ever After: Resurrection',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2015',
#  'imdbID': 'tt2250418',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2719848
# -------------------
# {'Actors': 'Jason Clarke, Ang Phula Sherpa, Thomas M. Wright, Martin Henderson',
#  'Awards': '1 win & 8 nominations.',
#  'BoxOffice': '$46,529,055',
#  'Country': 'UK, USA, Iceland',
#  'DVD': '19 Jan 2016',
#  'Director': 'Baltasar Kormákur',
#  'Genre': 'Action, Adventure, Biography, Drama, Thriller',
#  'Language': 'English, Russian',
#  'Metascore': '64',
#  'Plot': 'The story of New Zealand\'s Robert "Rob" Edwin Hall, who on May 10, '
#          '1996, together with Scott Fischer, teamed up on a joint expedition '
#          'to ascend Mount Everest.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTNmMzM0ZTktZWY3Yy00ODViLTllZDgtODcwM2QyM2E2YTU2L2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SX300.jpg',
#  'Production': 'Universal Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '73%'},
#              {'Source': 'Metacritic', 'Value': '64/100'}],
#  'Released': '25 Sep 2015',
#  'Response': 'True',
#  'Runtime': '121 min',
#  'Title': 'Everest',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'William Nicholson (screenplay), Simon Beaufoy (screenplay)',
#  'Year': '2015',
#  'imdbID': 'tt2719848',
#  'imdbRating': '7.1',
#  'imdbVotes': '185,872'}
# -------------------
# movie id tt3537212
# -------------------
# {'Actors': 'Alessandra Spoletini, Allison Schuette, Jonathan Schneider, '
#            'Michael Schneider',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '27 Sep 2016',
#  'Director': 'Antoine McKnight',
#  'Genre': 'Drama, Horror, Mystery',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Skylar is witness to the aftermath of a murder, but the killer '
#          "doesn't come after her. Instead, he torments her by testing her will "
#          'to survive.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjMzMTQ5OTMxOF5BMl5BanBnXkFtZTgwMjIzMDc0NTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.4/10'}],
#  'Released': '23 May 2016',
#  'Response': 'True',
#  'Runtime': '114 min',
#  'Title': 'Everto',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Antoine McKnight (story), Antoine McKnight, Jackie Miller',
#  'Year': '2015',
#  'imdbID': 'tt3537212',
#  'imdbRating': '4.4',
#  'imdbVotes': '33'}
# -------------------
# movie id tt4863580
# -------------------
# {'Actors': 'Chuckee, Thomas Mikal Ford, Emmbre Perry',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Emmbre Perry',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Emmbre Perry accomplished playwright and brother of Tyler Perry '
#          'continues the Family tradition of entertainment with an inspiring '
#          'Urban piece starring himself as the character Papa Willy, ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTU5NDY2MzAxMF5BMl5BanBnXkFtZTgwOTg1MTQzNzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'NOT RATED',
#  'Ratings': [],
#  'Released': '11 Nov 2015',
#  'Response': 'True',
#  'Runtime': '89 min',
#  'Title': 'Every Family Has Problems',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Emmbre Perry',
#  'Year': '2015',
#  'imdbID': 'tt4863580',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4401704
# -------------------
# {'Actors': 'Aaron Yoo, Brittany Ishibashi, Brandon Soo Hoo, Victoria Park',
#  'Awards': '1 win & 1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Wesley Chan, Philip Wang',
#  'Genre': 'Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The Department of Emotional Integrity (DEI) documents all '
#          "relationship activity. A 'relationship score' is given to keep "
#          'people accountable for their choices. The score is public for all '
#          'to...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ2OTA2MjA3Nl5BMl5BanBnXkFtZTgwMDc2NjIwODE@._V1_SX300.jpg',
#  'Production': 'Wong Fu Productions',
#  'Rated': 'Unrated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'}],
#  'Released': '03 Jun 2015',
#  'Response': 'True',
#  'Runtime': '99 min',
#  'Title': 'Everything Before Us',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Wesley Chan, Chris Dinh, Philip Wang',
#  'Year': '2015',
#  'imdbID': 'tt4401704',
#  'imdbRating': '7.0',
#  'imdbVotes': '947'}
# -------------------
# movie id tt5297660
# -------------------
# {'Actors': 'Jamie Ball, Weston Lee Ball, Christine Castro, Maria Chavez',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'John Chris Lopez',
#  'Genre': 'Drama, Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A photographer and four twenty-somethings are terrorized by the same '
#          'mysterious psychopath.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '103 min',
#  'Title': 'Everything You Know is Backwards',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'John Chris Lopez',
#  'Year': '2015',
#  'imdbID': 'tt5297660',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt1964608
# -------------------
# {'Actors': 'Talia Wray, Natalie Thomas, Alexandra Turshen, Simon MacLean',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Roni Ezra',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'New York City. The first night of fall. Three women seek love in '
#          'three very different ways. Sasha (21) is an impulsive young woman '
#          'consumed by a volatile relationship with a passionate ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzNlNDgwMjktNWI1Yi00YzVhLWIzNjYtYzk2MTY4Y2VhYmJmXkEyXkFqcGdeQXVyMTc5NDE3OTM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '100 min',
#  'Title': "Everything's Gonna Be Pink",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Christina Pastor',
#  'Year': '2015',
#  'imdbID': 'tt1964608',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4817640
# -------------------
# {'Actors': 'Sonny Carl Davis, John Patrick Jordan, Robin Sydney, Amy Paffrath',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '25 Aug 2015',
#  'Director': 'Charles Band',
#  'Genre': 'Comedy, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "When Rabbit escapes Evil Bong's evil world, he opens a bowling "
#          'alley, and decides to have a celebration with friends. Little does '
#          "Rabbit know that not only is Evil Bong on his trail, he's ...",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTgyODEzNjAwOV5BMl5BanBnXkFtZTgwMTQxMzEyNjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.9/10'}],
#  'Released': '20 Apr 2015',
#  'Response': 'True',
#  'Runtime': '53 min',
#  'Title': 'Evil Bong 420',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Charles Band (original story), Kent Roudebush',
#  'Year': '2015',
#  'imdbID': 'tt4817640',
#  'imdbRating': '3.9',
#  'imdbVotes': '198'}
# -------------------
# movie id tt4786796
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Anthony Jones',
#  'Genre': 'History',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'NOT RATED',
#  'Ratings': [],
#  'Released': '01 Apr 2015',
#  'Response': 'True',
#  'Runtime': '140 min',
#  'Title': 'Evil Law',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Anthony Jones',
#  'Year': '2015',
#  'imdbID': 'tt4786796',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4469210
# -------------------
# {'Actors': 'Emily Kathleen',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Emily Kathleen',
#  'Genre': 'Comedy, Talk-Show',
#  'Language': 'Spanish',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '04 May 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Evil Undoings',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Emily Kathleen',
#  'Year': '2015',
#  'imdbID': 'tt4469210',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3910688
# -------------------
# {'Actors': 'Michael Paré, Heather Fogarty, Michael J Long',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Johnny Kearns',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Scream for Me',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Pia Cook',
#  'Year': '2015',
#  'imdbID': 'tt3910688',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6002234
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': '0010x0010',
#  'Genre': 'N/A',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjBhY2Q0MjUtZDI3Zi00YjY2LTljZmEtNzExODk4MGJmMmRlXkEyXkFqcGdeQXVyNjg0OTUyMDY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '14 Jul 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Evolution of the Mind',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2015',
#  'imdbID': 'tt6002234',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2004216
# -------------------
# {'Actors': 'Leon, Chris Spencer, Shari Headley, Darrin Dewitt Henson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '13 Apr 2015',
#  'Director': 'Troy Byer',
#  'Genre': 'Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Three women kidnap their exes and hold them hostage until they get '
#          'the answers they think they need in order for their hearts to be '
#          'free.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzg3NDY1MDgwM15BMl5BanBnXkFtZTcwMjg5NzQ4Ng@@._V1_SX300.jpg',
#  'Production': 'LionsGate Entertainment',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'}],
#  'Released': '04 Apr 2015',
#  'Response': 'True',
#  'Runtime': '86 min',
#  'Title': 'I Really Hate My Ex',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Troy Byer',
#  'Year': '2015',
#  'imdbID': 'tt2004216',
#  'imdbRating': '6.5',
#  'imdbVotes': '41'}
# -------------------
# movie id tt3468698
# -------------------
# {'Actors': 'Bethany Orr, Mary Loveless, Wes McGee, Sheresade Poblet',
#  'Awards': '2 wins & 1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Patrick Kennelly',
#  'Genre': 'Drama, Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Obsessed with her sexy roommate, Jill violently imprisons Jennifer '
#          'in their apartment in a twisted attempt to bring them closer '
#          'together.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNmQ2MjQxMzItNjg5MC00ZTY0LWFkYTYtMDBlZTE4NjQ4NmNjXkEyXkFqcGdeQXVyMjExOTAxOTA@._V1_SX300.jpg',
#  'Production': 'Midnight Releasing',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.7/10'}],
#  'Released': '13 Mar 2015',
#  'Response': 'True',
#  'Runtime': '103 min',
#  'Title': 'Excess Flesh',
#  'Type': 'movie',
#  'Website': 'http://www.excessfleshmovie.com/',
#  'Writer': 'Sigrid Gilmer, Sigrid Gilmer, Patrick Kennelly, Patrick Kennelly',
#  'Year': '2015',
#  'imdbID': 'tt3468698',
#  'imdbRating': '3.7',
#  'imdbVotes': '669'}
# -------------------
# movie id tt1945044
# -------------------
# {'Actors': 'Stephen Lang, Kevin Chapman, Kelly Blatz, Brittany Curran',
#  'Awards': '3 wins.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Marcus Nispel',
#  'Genre': 'Horror, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A group of teenagers accidentally release an evil spirit that starts '
#          'to possess them one by one.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODA3NjAxMTIzN15BMl5BanBnXkFtZTgwODY0MDM1NTE@._V1_SX300.jpg',
#  'Production': 'Viva Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.5/10'}],
#  'Released': '01 Jan 2015',
#  'Response': 'True',
#  'Runtime': '91 min',
#  'Title': 'Exeter',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kirsten Elms, Kirsten Elms, Marcus Nispel (story)',
#  'Year': '2015',
#  'imdbID': 'tt1945044',
#  'imdbRating': '4.5',
#  'imdbVotes': '5,239'}
# -------------------
# movie id tt4423726
# -------------------
# {'Actors': 'John Sims, Larry Fleming, Matt Jones, David E. McMahon',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Wayland Strickland',
#  'Genre': 'Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'At the dawn of the 23rd Century - twenty years before the historic '
#          'five year Starfleet mission began. The United Earth Space Probe '
#          'Agency ordered the "Trailblazer" missions. A lone ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Oct 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Exeter Trek',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'John Sims',
#  'Year': '2015',
#  'imdbID': 'tt4423726',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5108996
# -------------------
# {'Actors': 'Armando Lamberti, Amanda Leigh, Brian May',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Armando Lamberti',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A chamber drama about love, loss and the work of art.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzkzNDkwMjA2NV5BMl5BanBnXkFtZTgwNDY4NTUwNzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '26 Oct 2015',
#  'Response': 'True',
#  'Runtime': '78 min',
#  'Title': 'Exhibition Day',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Armando Lamberti, Brian May',
#  'Year': '2015',
#  'imdbID': 'tt5108996',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4807008
# -------------------
# {'Actors': 'Ted Trent, Wendy Shapero, Antonio St. James, Cooper Shaw',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Dan Steadman',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Alec Harney goes home for Christmas ready to confront various issues '
#          "he has with his small-town family members. But it turns out, he's "
#          'the problem.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzExMjg5NzgwN15BMl5BanBnXkFtZTgwMzE5ODIxNjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '05 Nov 2015',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': 'Expect Delays',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dan Steadman',
#  'Year': '2015',
#  'imdbID': 'tt4807008',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3726704
# -------------------
# {'Actors': 'John Palladino, Anthony Edwards, Jim Gaffigan, Peter Sarsgaard',
#  'Awards': '2 wins & 4 nominations.',
#  'BoxOffice': '$155,075',
#  'Country': 'USA',
#  'DVD': '05 Jan 2016',
#  'Director': 'Michael Almereyda',
#  'Genre': 'Biography, Drama, History',
#  'Language': 'English',
#  'Metascore': '81',
#  'Plot': 'In 1961, famed social psychologist Stanley Milgram conducted a '
#          "series of radical behavior experiments that tested ordinary humans' "
#          'willingness to obey authority.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTA4NzYwMDI0NF5BMl5BanBnXkFtZTgwNTgzNDczNjE@._V1_SX300.jpg',
#  'Production': 'Magnolia Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '85%'},
#              {'Source': 'Metacritic', 'Value': '81/100'}],
#  'Released': '16 Oct 2015',
#  'Response': 'True',
#  'Runtime': '98 min',
#  'Title': 'Experimenter',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Almereyda',
#  'Year': '2015',
#  'imdbID': 'tt3726704',
#  'imdbRating': '6.6',
#  'imdbVotes': '16,480'}
# -------------------
# movie id tt4533604
# -------------------
# {'Actors': 'Colten Dietz, Steve Bundy, Joe Strongbear, Amber Rothe',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Colten Dietz',
#  'Genre': 'Drama, Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'We follow Sheriff Deputy Eric Weston in the wake of a Apocalypse as '
#          'he struggles to survive the undead known as lurkers and put the '
#          'pieces together to find his wife.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZjQ2NDExZTUtYjM3NC00M2UwLWI4ZjMtMDk2NDVlYzMyOTdhXkEyXkFqcGdeQXVyNTE3OTcwNTc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.0/10'}],
#  'Released': '29 May 2015',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Exposure',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Colten Dietz',
#  'Year': '2015',
#  'imdbID': 'tt4533604',
#  'imdbRating': '4.0',
#  'imdbVotes': '30'}
# -------------------
# movie id tt3467412
# -------------------
# {'Actors': 'Matthew Fox, Jeffrey Donovan, Quinn McColgan, Clara Lago',
#  'Awards': '1 win & 3 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'Spain, USA, Hungary, France',
#  'DVD': '01 Sep 2015',
#  'Director': 'Miguel Ángel Vivas',
#  'Genre': 'Drama, Horror, Sci-Fi',
#  'Language': 'English',
#  'Metascore': '46',
#  'Plot': 'And suddenly, overnight, the world came to a halt. Two men, two '
#          'survivors, one kid, and hatred that separates them. A place '
#          'forgotten by everyone, including the creatures that inhabit the '
#          'Earth... until now.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTYzMzIyMTQ3N15BMl5BanBnXkFtZTgwNTMzNTAwNjE@._V1_SX300.jpg',
#  'Production': 'Vertical Entertainment',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '20%'},
#              {'Source': 'Metacritic', 'Value': '46/100'}],
#  'Released': '31 Jul 2015',
#  'Response': 'True',
#  'Runtime': '112 min',
#  'Title': 'Extinction',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Alberto Marini, Miguel Ángel Vivas, Juan de Dios Garduño (novel)',
#  'Year': '2015',
#  'imdbID': 'tt3467412',
#  'imdbRating': '5.8',
#  'imdbVotes': '15,031'}
# -------------------
# movie id tt3304610
# -------------------
# {'Actors': 'Medalion Rahimi, Caitlin Custer, Brian Majestic, Tim Kirkpatrick',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '23 Feb 2016',
#  'Director': 'Tim Kirkpatrick',
#  'Genre': 'Action, Crime, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An Extraction Specialist and his team will go to extreme lengths to '
#          "protect hard working American's against the unknown enemies that "
#          "live within it's borders, but while maintaining the highest level of "
#          'security to protect their families who are unaware of their true '
#          'identities.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTcxMzg3OTEyMV5BMl5BanBnXkFtZTgwNDgwMTA5MjE@._V1_SX300.jpg',
#  'Production': 'Lionsgate Premiere',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '6%'}],
#  'Released': '31 Dec 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Extraction',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jennifer Grossman (script editor), Tim Kirkpatrick',
#  'Year': '2015',
#  'imdbID': 'tt3304610',
#  'imdbRating': '5.1',
#  'imdbVotes': '16'}
# -------------------
# movie id tt4382872
# -------------------
# {'Actors': 'Bruce Willis, Kellan Lutz, Gina Carano, D.B. Sweeney',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, UK, Canada',
#  'DVD': '23 Feb 2016',
#  'Director': 'Steven C. Miller',
#  'Genre': 'Action, Thriller',
#  'Language': 'English',
#  'Metascore': '25',
#  'Plot': 'A former CIA operative is kidnapped by a group of terrorists. When '
#          'his son learns there is no plan for his father to be saved, he '
#          'launches his own rescue operation.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTAzNjU4MzYwNDdeQTJeQWpwZ15BbWU4MDg3NTEzMjcx._V1_SX300.jpg',
#  'Production': 'Lionsgate Premiere',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '6%'},
#              {'Source': 'Metacritic', 'Value': '25/100'}],
#  'Released': '18 Dec 2015',
#  'Response': 'True',
#  'Runtime': '82 min',
#  'Title': 'Extraction',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Max Adams, Umair Aleem',
#  'Year': '2015',
#  'imdbID': 'tt4382872',
#  'imdbRating': '4.1',
#  'imdbVotes': '9,002'}
# -------------------
# movie id tt4041022
# -------------------
# {'Actors': 'Sasha Jackson, Kabby Borders, Justine Wachsberger, Berna Roberts',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Leigh Scott',
#  'Genre': 'Comedy',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'When a group of sorority girls is threatened with eviction from '
#          'their house, they launch a daring plan to turn it into a strip club. '
#          'To succeed, they will have to defeat the university, rival '
#          'sororities, and their boyfriends in this racy, sexy comedy.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQzMTM3NDE3Nl5BMl5BanBnXkFtZTgwMzgyNTA1NTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Extracurricular Activities',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Waldo Salt, Leigh Scott (screenplay)',
#  'Year': '2015',
#  'imdbID': 'tt4041022',
#  'imdbRating': '5.8',
#  'imdbVotes': '9'}
# -------------------
# movie id tt3900610
# -------------------
# {'Actors': "Allegra Nova, Kevin J. O'Connor, Kimberly Hester Huffstetler, "
#            'Gabriel Manak',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Michaux Muanda',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A story about Michael White, an American soldier who came home to '
#          'his daughter Julia and wife Jacky White...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Extreme the Movie',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michaux Muanda',
#  'Year': '2015',
#  'imdbID': 'tt3900610',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt1276953
# -------------------
# {'Actors': 'Mark Donnell, Ian Reed Kesler, Aaron Kissinger, Kim Woods',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Craig Richards',
#  'Genre': 'Comedy, Crime, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Chip Douglas is a washed-out alcoholic car salesman at a used car '
#          'lot. With the endless availability of information over the Internet, '
#          'customers can now get any information about any car ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ4Nzc1OTQ3OF5BMl5BanBnXkFtZTcwNzQwMzA3NQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'}],
#  'Released': '30 Jan 2015',
#  'Response': 'True',
#  'Runtime': '92 min',
#  'Title': 'Extremely Used Cars: There Is No Hope',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Mark Donnell',
#  'Year': '2015',
#  'imdbID': 'tt1276953',
#  'imdbRating': '6.3',
#  'imdbVotes': '27'}
# -------------------
# movie id tt4126038
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Divine Femininity',
#  'Genre': 'Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg5MDgyMzQzMV5BMl5BanBnXkFtZTgwNzE4NDExMzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '14 Oct 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Eyes of the Moon',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2015',
#  'imdbID': 'tt4126038',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3498620
# -------------------
# {'Actors': 'Naphatia St Pierre, Ransom Pugh, Abigail White, Kristine Renee '
#            'Farley',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'James Treakle',
#  'Genre': 'Drama, Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The fraudulent author of an alien abduction memoir and a skeptic '
#          'with a supernatural secret join forces to fight a UFO cult.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMDFkNjI1YTQtNTMzZS00N2Q1LWEwZDctMzdlODFkYTA4YTk2XkEyXkFqcGdeQXVyMjIxOTY4MTA@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'NOT RATED',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.2/10'}],
#  'Released': '24 Apr 2015',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': "Ezekiel's Landing",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Adam Bailey, Charles Baker, James Treakle',
#  'Year': '2015',
#  'imdbID': 'tt3498620',
#  'imdbRating': '8.2',
#  'imdbVotes': '11'}
# -------------------
# movie id tt4917826
# -------------------
# {'Actors': 'Richard Powers',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Richard Powers',
#  'Genre': 'Horror, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Featuring practical effects, an electronic score, and alien horrors, '
#          "'Facsimile' is a love letter to creature features and midnight "
#          "movies of the '80s.",
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'Facsimile',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Richard Powers',
#  'Year': '2015',
#  'imdbID': 'tt4917826',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4321284
# -------------------
# {'Actors': 'Elvin Bautista, Tyeson Bell, Christine Brandao, Joseph Goncalves',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Joseph Goncalves',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '57 min',
#  'Title': 'Faith Under Fire',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joseph Goncalves',
#  'Year': '2015',
#  'imdbID': 'tt4321284',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt1322393
# -------------------
# {'Actors': 'Kevin Downes, David A.R. White, Stephen Baldwin, Candace Cameron '
#            'Bure',
#  'Awards': '1 win.',
#  'BoxOffice': '$975,344',
#  'Country': 'USA',
#  'DVD': '13 Oct 2015',
#  'Director': 'Carey Scott',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': '20',
#  'Plot': 'Two men embark on a trip to the Vietnam Veterans Memorial guided by '
#          'the letters their fathers wrote while serving in the war.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjI4NjM0NzUyMV5BMl5BanBnXkFtZTgwNzQ1NTAwNTE@._V1_SX300.jpg',
#  'Production': 'Pure Flix',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '10%'},
#              {'Source': 'Metacritic', 'Value': '20/100'}],
#  'Released': '01 Jul 2015',
#  'Response': 'True',
#  'Runtime': '96 min',
#  'Title': 'Faith of Our Fathers',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kevin Downes, Carey Scott (screenwriter), Harold Uhl (screenplay), '
#            'David A.R. White',
#  'Year': '2015',
#  'imdbID': 'tt1322393',
#  'imdbRating': '3.6',
#  'imdbVotes': '564'}
# -------------------
# movie id tt4500956
# -------------------
# {'Actors': 'Char Sidney, Sabrina Culver, Tamara Goodwin, Jacqueline Murphy',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jacopo Manfren',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Set amongst a tapestry of fairy tale excess, Michael is reared and '
#          'mentored by an African American maid, Annie Mae. Michael is caught '
#          'in a triangle of lies and deception by dysfunctional, quirky, '
#          'upscale family and friends.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Fake',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Alton Lowder, Lynne Newton',
#  'Year': '2015',
#  'imdbID': 'tt4500956',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5175568
# -------------------
# {'Actors': 'Sue Ellen Randolph',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Sue Ellen Randolph',
#  'Genre': 'Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'In a world where mortals exist lives one guy who can see the world '
#          'for what it really is. His name is Zayn and he sees both the mortals '
#          "and the immortals. His friend Chloe's Dad is a ...",
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Aug 2015',
#  'Response': 'True',
#  'Runtime': '83 min',
#  'Title': 'Fallen Weeping',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2015',
#  'imdbID': 'tt5175568',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt10973970
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt4241982
# -------------------
# {'Actors': "Marshawn Lynch, Teresa Navarro, Brian Perry, Lee O'Brian",
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Mario Bobino',
#  'Genre': 'Biography',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Family First the Marshawn Lynch Story',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Damon A. Hart',
#  'Year': '2015',
#  'imdbID': 'tt4241982',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3152364
# -------------------
# {'Actors': 'Vishal Vaidya, Jaya Prasad, Jai Ahuja, Rahul Nalamasu',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Pari Mathur',
#  'Genre': 'Comedy, Drama, Family, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A group of Indian-American teens get dragged to a family party and '
#          'plan to sneak out once they realize they all have tickets to the '
#          'same local concert.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjQxMjM2MTc1Ml5BMl5BanBnXkFtZTgwMDEzMDI5NjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Unrated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.3/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '52 min',
#  'Title': 'Family Party',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Pari Mathur, Pari Mathur',
#  'Year': '2015',
#  'imdbID': 'tt3152364',
#  'imdbRating': '5.3',
#  'imdbVotes': '29'}
# -------------------
# movie id tt1700807
# -------------------
# {'Actors': 'Steven Joseph Adams, Leeann Aubuchon, Forris Day Jr., Martin '
#            'DuPlessis',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Geno McGahee',
#  'Genre': 'Horror, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTMxNzk0NDIxNV5BMl5BanBnXkFtZTcwMDA4ODQzNA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.8/10'}],
#  'Released': '18 Jul 2015',
#  'Response': 'True',
#  'Runtime': '111 min',
#  'Title': 'Family Secret',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Geno McGahee (story), Geno McGahee',
#  'Year': '2015',
#  'imdbID': 'tt1700807',
#  'imdbRating': '4.8',
#  'imdbVotes': '34'}
# -------------------
# movie id tt3808108
# -------------------
# {'Actors': 'Hope Anderson, Karen Anderson, Sharli Birdow, Marsha Bolden',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Karen Anderson',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Written by Karen Anderson, the movie is a dramedy that tells the '
#          'story of an African American family that do not like each other, but '
#          'is forced into having a family reunion by one of the ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQzNDAyNzI0Ml5BMl5BanBnXkFtZTgwNTkyOTE3MjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '11 Apr 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Family Tree',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Karen Anderson',
#  'Year': '2015',
#  'imdbID': 'tt3808108',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5040282
# -------------------
# {'Actors': 'Lauren Abbott, James Bell, Terence Lee Cover, Sheri Darling',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Nathan Rumler',
#  'Genre': 'Comedy, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Dick and Suzy become infected with an unknown virus. They soon '
#          'discover that they have a new found taste for blood. The problem is, '
#          'they only seem to be able to suck blood out of their victims '
#          'crotches.',
#  'Poster': 'https://ia.media-imdb.com/images/M/MV5BYWU4MDU5MDctODQzMC00NTczLWFkZTctMTlmMTg4MDQ5Y2U0XkEyXkFqcGdeQXVyNDkwNTA0ODQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'}],
#  'Released': '25 Sep 2015',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Fangboner',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Nathan Rumler',
#  'Year': '2015',
#  'imdbID': 'tt5040282',
#  'imdbRating': '5.4',
#  'imdbVotes': '43'}
# -------------------
# movie id tt5243688
# -------------------
# {'Actors': 'Katherine Author, Audio Diva, Jack Hume, Nicky McQueen',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jack Foster',
#  'Genre': 'Animation',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '84 min',
#  'Title': 'Fantasmes Erotiques de Femmes',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jack Foster',
#  'Year': '2015',
#  'imdbID': 'tt5243688',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt1502712
# -------------------
# {'Actors': 'Miles Teller, Michael B. Jordan, Kate Mara, Jamie Bell',
#  'Awards': '8 wins & 4 nominations.',
#  'BoxOffice': '$49,179,296',
#  'Country': 'USA, Germany, UK',
#  'DVD': '15 Dec 2015',
#  'Director': 'Josh Trank',
#  'Genre': 'Action, Adventure, Drama, Sci-Fi',
#  'Language': 'English',
#  'Metascore': '27',
#  'Plot': 'Four young outsiders teleport to an alternate and dangerous universe '
#          'which alters their physical form in shocking ways. The four must '
#          'learn to harness their new abilities and work together to save Earth '
#          'from a former friend turned enemy.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk0OTMyMDA0OF5BMl5BanBnXkFtZTgwMzY5NTkzNTE@._V1_SX300.jpg',
#  'Production': '20th Century Fox',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.3/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '9%'},
#              {'Source': 'Metacritic', 'Value': '27/100'}],
#  'Released': '07 Aug 2015',
#  'Response': 'True',
#  'Runtime': '100 min',
#  'Title': 'Fantastic Four',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jeremy Slater (screenplay), Simon Kinberg (screenplay), Josh Trank '
#            '(screenplay), Stan Lee (Marvel comic book), Jack Kirby (Marvel '
#            'comic book)',
#  'Year': '2015',
#  'imdbID': 'tt1502712',
#  'imdbRating': '4.3',
#  'imdbVotes': '143,661'}
# -------------------
# movie id tt4514084
# -------------------
# {'Actors': 'Brandi Wethington, Abbey Hunt, Chris Overson, Marcella Hower',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Justin Hunt',
#  'Genre': 'Action, Crime, Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An intelligent single mother makes one wrong choice and falls into '
#          'the dark world of Meth abuse. The distance between her and the young '
#          'daughter she loves so much grows greater until she is forced to '
#          'choose: her daughter or the drug.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjU0OTU0MTk4M15BMl5BanBnXkFtZTgwMDg2MjM5NDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.1/10'}],
#  'Released': '01 Oct 2015',
#  'Response': 'True',
#  'Runtime': '117 min',
#  'Title': 'Far Too Far',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Justin Hunt (story), Justin Hunt',
#  'Year': '2015',
#  'imdbID': 'tt4514084',
#  'imdbRating': '8.1',
#  'imdbVotes': '87'}
# -------------------
# movie id tt2935476
# -------------------
# {'Actors': 'Carey Mulligan, Matthias Schoenaerts, Tilly Vosburgh, Mark Wingett',
#  'Awards': '2 wins & 11 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'UK, USA',
#  'DVD': '04 Aug 2015',
#  'Director': 'Thomas Vinterberg',
#  'Genre': 'Drama, Romance',
#  'Language': 'English',
#  'Metascore': '71',
#  'Plot': 'In Victorian England, the independent and headstrong Bathsheba '
#          'Everdene attracts three very different suitors: Gabriel Oak, a sheep '
#          'farmer; Frank Troy, a reckless Sergeant; and William Boldwood, a '
#          'prosperous and mature bachelor.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzI4NzUwNDgwN15BMl5BanBnXkFtZTgwNTI3MjMwNTE@._V1_SX300.jpg',
#  'Production': '20th Century Fox',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '85%'},
#              {'Source': 'Metacritic', 'Value': '71/100'}],
#  'Released': '22 May 2015',
#  'Response': 'True',
#  'Runtime': '119 min',
#  'Title': 'Far from the Madding Crowd',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Thomas Hardy (based on the novel by), David Nicholls (screenplay '
#            'by)',
#  'Year': '2015',
#  'imdbID': 'tt2935476',
#  'imdbRating': '7.1',
#  'imdbVotes': '42,344'}
# -------------------
# movie id tt4669574
# -------------------
# {'Actors': 'Chris Gallo, Alex Hollingshead, Justin Carmical, Kaylyn Dicksion',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kaylyn Dicksion',
#  'Genre': 'Action, Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'MarzGurl Productions presents "Saraba/Farewell, FamiKamen Rider," '
#          'the thrilling conclusion to the story authored by the late Justin '
#          'Carmical. After a massive fight in Canada, the FamiKamen ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '15 Apr 2015',
#  'Response': 'True',
#  'Runtime': '120 min',
#  'Title': 'Farewell, FamiKamen Rider',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kaylyn Dicksion, Joshua Saucedo',
#  'Year': '2015',
#  'imdbID': 'tt4669574',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4863224
# -------------------
# {'Actors': 'Aki Aleong, Jayden Besana, Jordan Besana, Keziah Mae Tuazon',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Aki Aleong',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Aug 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Faster Than the Speed of Light',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Steven Zuckerman',
#  'Year': '2015',
#  'imdbID': 'tt4863224',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5155744
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'Action, Fantasy, Thriller',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': "Just another story about a guy meeting a girl. Only she's dangerous. "
#          "And he's about to be famous.",
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'Faster, More Blood',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2015',
#  'imdbID': 'tt5155744',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4472664
# -------------------
# {'Actors': 'Lori Morkunas Jones, Kristin Naomi Garcia, Mark Anthony Cox, '
#            'Gerren Hall',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Wister Gaetan',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Fates of Ambition',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Wister Gaetan',
#  'Year': '2015',
#  'imdbID': 'tt4472664',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2582502
# -------------------
# {'Actors': 'Russell Crowe, Amanda Seyfried, Aaron Paul, Diane Kruger',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'Italy, USA',
#  'DVD': '09 Aug 2016',
#  'Director': 'Gabriele Muccino',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': '31',
#  'Plot': 'A Pulitzer-winning writer grapples with being a widower and father '
#          'after a mental breakdown, while, 27 years later, his grown daughter '
#          'struggles to forge connections of her own.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzgwMDgwMzE2Nl5BMl5BanBnXkFtZTgwNzk0OTgxOTE@._V1_SX300.jpg',
#  'Production': 'Voltage Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '28%'},
#              {'Source': 'Metacritic', 'Value': '31/100'}],
#  'Released': '08 Jul 2016',
#  'Response': 'True',
#  'Runtime': '116 min',
#  'Title': 'Fathers & Daughters',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Brad Desch',
#  'Year': '2015',
#  'imdbID': 'tt2582502',
#  'imdbRating': '7.1',
#  'imdbVotes': '21,918'}
# -------------------
# movie id tt5206388
# -------------------
# {'Actors': 'McKenzie Abney, Lilli Allen, David G. Baker, Faith Dianne Baker',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Joseph Aguon Drake',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'It is a night of terror as the local teens struggle to stay alive in '
#          'the sleepy town of Fearsville. They soon discover that fear has a '
#          'town of its own.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOGMzOTIyYTMtZGNlYi00MjBhLWIyMmYtZmUyYTdmYmI2M2QxXkEyXkFqcGdeQXVyMzQ2NjQ4Njc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.2/10'}],
#  'Released': '23 Oct 2015',
#  'Response': 'True',
#  'Runtime': '75 min',
#  'Title': 'Fearsville',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joseph Aguon Drake',
#  'Year': '2015',
#  'imdbID': 'tt5206388',
#  'imdbRating': '5.2',
#  'imdbVotes': '12'}
# -------------------
# movie id tt4248926
# -------------------
# {'Actors': 'Josef Cannon, Pete Kasper, Jenn Perkins Stephens, G. Reilly',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Josef Cannon',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The story of an aging baseball player, Sebastian Goode (Josef '
#          'Cannon) attempting to become the 1st African American to qualify for '
#          'The Tour de France in its 111 year history.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '22 Jul 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Feeling Goode',
#  'Type': 'movie',
#  'Website': 'N/A',
# ...
# -------------------
# movie id tt5088686
# -------------------
# {'Actors': 'Celia Hemken',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Celia Hemken',
#  'Genre': 'Animation, Drama, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Orange Peel sells her body to be a singer and famous.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '25 Sep 2015',
#  'Response': 'True',
#  'Runtime': '103 min',
#  'Title': 'Orange Peel',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Celia Hemken',
#  'Year': '2015',
#  'imdbID': 'tt5088686',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5807402
# -------------------
# {'Actors': 'Zachary Levine, Jenna Sperling',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Carina Teoh',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '05 Nov 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Oreo Therapy',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2015',
#  'imdbID': 'tt5807402',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3506046
# -------------------
# {'Actors': 'David Maldonado, Jennifer Rogers, Neal Kodinsky, Elsa Marquez',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'R. Clay Ayers',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A suburban couple struggles to make ends meet with their restaurant '
#          'when they unexpectedly find a briefcase full of cash. Against their '
#          'better judgement, they decide to use the money to ...',
#  'Poster': 'https://ia.media-imdb.com/images/M/MV5BNDI0MTY5MDI3Ml5BMl5BanBnXkFtZTgwNDEzNTQ0MzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '28 Jul 2015',
#  'Response': 'True',
#  'Runtime': '100 min',
#  'Title': 'Organizatsiya',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'R. Clay Ayers',
#  'Year': '2015',
#  'imdbID': 'tt3506046',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2342266
# -------------------
# {'Actors': 'David Arquette, Lily Cole, Goran Kostic, Maren Lord',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Asiel Norton',
#  'Genre': 'Action, Drama, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'In a desolate, future world, after civilization has collapsed, a '
#          'wanderer fights to save a virgin mother from a powerful magician '
#          "and, with her, searches for a mythical city containing the world's "
#          'last survivors.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjE1OWI1ZmQtMzhmMi00Yzc5LTlkMjItMDE0ZWMzNTg4Y2E5XkEyXkFqcGdeQXVyMzIwMjMzMjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'TV-MA',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'}],
#  'Released': '01 Aug 2015',
#  'Response': 'True',
#  'Runtime': '110 min',
#  'Title': 'Orion',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Asiel Norton',
#  'Year': '2015',
#  'imdbID': 'tt2342266',
#  'imdbRating': '6.2',
#  'imdbVotes': '39'}
# -------------------
# movie id tt4305086
# -------------------
# {'Actors': 'Julitta Pourciau, Katelyn Merricks, Scott Frank, Tsvetalina '
#            'Pourciau',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'J.Q. Gwynn',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Osveta Brutalis: A Reckoning',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'J.Q. Gwynn',
#  'Year': '2015',
#  'imdbID': 'tt4305086',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3184312
# -------------------
# {'Actors': 'Tory Devon Smith, Allison Marie Volk, Briggon Snow, Peter Nikkos',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Mikael Kreuzriegler',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Othello',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Colin Martin, Allison Marie Volk',
#  'Year': '2015',
#  'imdbID': 'tt3184312',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4308714
# -------------------
# {'Actors': 'Lauren Lakis, Mercedes Manning, Lianna Liew, Melanie Friedrich',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Matthew T. Price',
#  'Genre': 'Comedy, Horror, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A team of programmers develop a revolutionary new dating app called '
#          'Other Halves. On the night before the app is set to launch, they '
#          'discover it causes strange side effects: users lose all ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ3OTc3NDgzNl5BMl5BanBnXkFtZTgwOTI1NjM4NTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.4/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Other Halves',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Matthew T. Price, Kelly Morr',
#  'Year': '2015',
#  'imdbID': 'tt4308714',
#  'imdbRating': '3.4',
#  'imdbVotes': '228'}
# -------------------
# movie id tt2927046
# -------------------
# {'Actors': 'Toshiko Onizawa, Natia Dune, Ilya Slovesnik, Ludovic Coutaud',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jeremy Carr',
#  'Genre': 'Drama, Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A reclusive tour guide becomes an unlikely vigilante when the dark '
#          'underbelly of New York City is revealed through his dreams.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '102 min',
#  'Title': 'Other Madnesses',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jeremy Carr',
#  'Year': '2014',
#  'imdbID': 'tt2927046',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2805814
# -------------------
# {'Actors': 'Diane Marshall-Green, Chad Michael Murray, Michael Mosley, '
#            'Alexandra Breckenridge',
#  'Awards': '2 wins.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Liz Hinlein',
#  'Genre': 'Drama, Romance',
#  'Language': 'English',
#  'Metascore': '25',
#  'Plot': 'A filmmaker, reeling from the death of her famous father, falls down '
#          'the rabbit hole of a charismatic homeless man who becomes the '
#          'subject of her latest documentary and her new love interest.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzMyNjg0NDY5N15BMl5BanBnXkFtZTgwMzgzNDkxMjE@._V1_SX300.jpg',
#  'Production': 'OPC Film',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '17%'},
#              {'Source': 'Metacritic', 'Value': '25/100'}],
#  'Released': '25 Dec 2015',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': "Other People's Children",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Adrienne Harris, Adrienne Harris',
#  'Year': '2015',
#  'imdbID': 'tt2805814',
#  'imdbRating': '6.6',
#  'imdbVotes': '55'}
# -------------------
# movie id tt5149854
# -------------------
# {'Actors': 'Catie Carlton, David Bonderoff, Chayenne Espinal, Adriel Irizarry',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Mark Rotondo',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Five friends go away for a long weekend where all of their '
#          'relationships are pushed to their breaking points.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '79 min',
#  'Title': "Other People's Lives",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Mark Rotondo, Miranda Ruoff (story)',
#  'Year': '2015',
#  'imdbID': 'tt5149854',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3824596
# -------------------
# {'Actors': 'Sean Patrick Flaherty, Maximiliano Miranda, Elizabeth Sandoz',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Samuel J. Gilliam Jr.',
#  'Genre': 'Horror',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'A Supernatural horror comedy which takes you for a ride into the '
#          'wacky world of ghost mediums that get a treat of the real thing.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjExNjIwNDk4NV5BMl5BanBnXkFtZTgwOTU0ODc2MzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Apr 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Otherworldly',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Curtis Melroe',
#  'Year': '2015',
#  'imdbID': 'tt3824596',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4317662
# -------------------
# {'Actors': 'Richard Tyson, Pamela Finney, Anthony Snow, Natasha Dee Davis',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Franklyn Cole Jr.',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A young man loses his sole source of support and is coerced into a '
#          'partnership with a notorious drug lord. When the partnership '
#          'deteriorates, lines in the sand are drawn, in blood. Who will '
#          'survive?',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '12 Oct 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Our Apartment',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Franklyn Cole Jr.',
#  'Year': '2015',
#  'imdbID': 'tt4317662',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt1018765
# -------------------
# {'Actors': 'Sandra Bullock, Billy Bob Thornton, Anthony Mackie, Joaquim de '
#            'Almeida',
#  'Awards': '2 nominations.',
#  'BoxOffice': '$4,895,965',
#  'Country': 'USA',
#  'DVD': '02 Feb 2016',
#  'Director': 'David Gordon Green',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English, Spanish',
#  'Metascore': '53',
#  'Plot': 'A battle-hardened American political consultant is sent to help '
#          're-elect a controversial president in Bolivia, where she must '
#          'compete with a long-term rival working for another candidate.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg5MDUwMDQwM15BMl5BanBnXkFtZTgwNTczMjU3NjE@._V1_SX300.jpg',
#  'Production': 'Warner Bros. Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '36%'},
#              {'Source': 'Metacritic', 'Value': '53/100'}],
#  'Released': '30 Oct 2015',
#  'Response': 'True',
#  'Runtime': '107 min',
#  'Title': 'Our Brand Is Crisis',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Rachel Boynton (suggested by the documentary), Peter Straughan '
#            '(screenplay)',
#  'Year': '2015',
#  'imdbID': 'tt1018765',
#  'imdbRating': '6.1',
#  'imdbVotes': '19,555'}
# -------------------
# movie id tt8589748
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt5137964
# -------------------
# {'Actors': 'Craig Ahrens, Aakash Ahuja, Chriss Anglin, Gregory Baron',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Obed Jean Baptiste',
#  'Genre': 'Drama, Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'After their previous Nanny quit, Amy and Nathan parents hire a new '
#          'Nanny for them. The new nanny is preaching to them about Islam and '
#          'trying to convert them.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjA4NTE4NDExMF5BMl5BanBnXkFtZTgwNDMxNjU3ODE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '62 min',
#  'Title': 'Our New Nanny',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Obed Jean Baptiste, Shadrac Jean Baptiste',
#  'Year': '2015',
#  'imdbID': 'tt5137964',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5742210
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'Drama',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': "After Chris and his friend's graduate from high school, he plans to "
#          "leave town and escape the legacy of his father's criminal past. When "
#          'his car breaks down and puts his dreams in jeopardy,...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '86 min',
#  'Title': 'Our Time: Rough Cut',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2015',
#  'imdbID': 'tt5742210',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4283078
# -------------------
# {'Actors': 'Amanda Odeh, Andrew Odeh',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Andrew Odeh',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "'Our Tokyo' is a feature-length piece that explores the realities of "
#          'modern-day Japan - at once seeking to remove clichés, while painting '
#          'an honest portrait of this unique and vibrant nation.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '79 min',
#  'Title': 'Our Tokyo',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Andrew Odeh',
#  'Year': '2014',
#  'imdbID': 'tt4283078',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3922764
# -------------------
# {'Actors': 'Bishop Blay, Zenobia Taylor, Duke Murphy Dennis, Rodney Rogers '
#            'Beckley',
#  'Awards': '2 wins & 2 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Liberia',
#  'DVD': 'N/A',
#  'Director': 'Takeshi Fukunaga',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A struggling Liberian rubber plantation worker risks everything to '
#          'discover a new life as a Yellow Cab driver in New York City.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg4MDkzNDM3MF5BMl5BanBnXkFtZTgwMzEyODMyNzE@._V1_SX300.jpg',
#  'Production': 'Imperfect Films',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.0/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '100%'}],
#  'Released': '13 Nov 2015',
#  'Response': 'True',
#  'Runtime': '87 min',
#  'Title': 'Out of My Hand',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Takeshi Fukunaga, Donari Braxton',
#  'Year': '2015',
#  'imdbID': 'tt3922764',
#  'imdbRating': '6.0',
#  'imdbVotes': '115'}
# -------------------
# movie id tt4608724
# -------------------
# {'Actors': 'Sylvi Alli, Robin Coomer, Luka Dziubyna, Andrew Gurevich',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Antero Alli',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A young man emerges from a near-death experience with a disturbing '
#          "psychic talent that leads him to Reno, Nevada where he's hired as a "
#          'Mentalist. Thirty years later, a documentary filmmaker interviews '
#          'him about his unusual career.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '23 Jul 2015',
#  'Response': 'True',
#  'Runtime': '105 min',
#  'Title': 'Out of the Woods',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Antero Alli (screenplay)',
#  'Year': '2015',
#  'imdbID': 'tt4608724',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}

# %%
len(title_list)
# Out:
# 978

# %%
len(title_id)
# Out:
# 978

# %%
# if title_list and title_id are the same length run the cell below. 
# if they are not equal take out 'title_id': title_id

# %%
df = pd.DataFrame({'title_id': title_id, 'title': title_list, 'box_office': box_office_list, 'country': country_list, 
                   'genre': genre_list, 'director': director_list, 'metascore': metascore_list, 'production': production_list, 
                   'rating': rating_list, 'IMDB_rating': IMDB_rating_list, 'rotten_tomatoes_rating': rotten_tomatoes_rating_list, 
                  'runtime': runtime_list, 'type': type_list, 'IMDB_votes': imdb_votes_list})

# %%
df = df.drop_duplicates()
df.head()
# Out:
#     title_id                       title   box_office           country  \
# 0  tt3784230                Evan's Crime          N/A               USA
# 1  tt8929768  Evangelista Sin Credencial          N/A               USA
# 2  tt3362234                    Eventide          N/A               USA
# 3  tt2250418    Ever After: Resurrection          N/A               USA
# 4  tt2719848                     Everest  $46,529,055  UK, USA, Iceland
#
#                                            genre           director metascore  \
# 0                                          Drama         Sandy Tung       N/A
# 1                                            N/A                N/A       N/A
# 2                                          Drama  Dimitri Voutsinos       N/A
# 3                           Action, Crime, Drama   Fernando A. Mico       N/A
# 4  Action, Adventure, Biography, Drama, Thriller  Baltasar Kormákur        64
#
#            production     rating IMDB_rating rotten_tomatoes_rating  runtime  \
# 0                 N/A  Not Rated         5.3                     NA   95 min
# 1                 N/A        N/A         N/A                     NA      N/A
# 2                 N/A        N/A         N/A                     NA   86 min
# 3                 N/A        N/A         N/A                     NA   90 min
# 4  Universal Pictures      PG-13         7.1                    73%  121 min
#
#     type IMDB_votes
# 0  movie        110
# 1  movie        N/A
# 2  movie        N/A
# 3  movie        N/A
# 4  movie    185,872

# %%
df.count()
# Out:
# title_id                  978
# title                     978
# box_office                978
# country                   978
# genre                     978
# director                  978
# metascore                 978
# production                978
# rating                    978
# IMDB_rating               978
# rotten_tomatoes_rating    978
# runtime                   978
# type                      978
# IMDB_votes                978
# dtype: int64

# %%
df.to_csv('../data/2015_data_batch_2.csv', index=False)
