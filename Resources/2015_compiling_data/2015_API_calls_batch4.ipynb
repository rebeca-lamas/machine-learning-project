# %%
import pandas as pd
import requests
import json
import time
from pprint import pprint
from config import API_KEY

# %%
data = pd.read_csv('../data/titles_2015_batch4.csv')
df =  data.count()
df
# Out:
# title    1000
# dtype: int64

# %%
title_id = []
box_office_list = []
country_list = []
genre_list = []
director_list = []
metascore_list = []
production_list = []
rating_list = []
IMDB_rating_list = [] 
rotten_tomatoes_rating_list = []
runtime_list = []
title_list = []
type_list = []
imdb_votes_list = []

# %%
movies = data['title']
total_movies = len(movies)

# %%
for i in range(total_movies):
    movie = movies[i]
    url = "http://www.omdbapi.com/?i=" + movie + "&apikey=" + API_KEY
    response = (requests.get(url).text)
    response_json = json.loads(response)
    print('-------------------')
    print(f'movie id {movie}')
    print('-------------------')
    pprint(response_json)
    
    try:
        box_office_list.append(response_json['BoxOffice'])
        country_list.append(response_json['Country'])
        genre_list.append(response_json['Genre'])
        director_list.append(response_json['Director'])
        metascore_list.append(response_json['Metascore'])
        production_list.append(response_json['Production'])
        rating_list.append(response_json['Rated'])
        IMDB_rating_list.append(response_json['imdbRating'])
        try:
            if not response_json['Ratings']:
                rotten_tomatoes_rating_list.append('NA')
            elif response_json['Ratings'][0]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][0]['Value'])
            elif response_json['Ratings'][1]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][1]['Value'])
            else:
                rotten_tomatoes_rating_list.append('NA')
        except IndexError:
            rotten_tomatoes_rating_list.append('NA')
        runtime_list.append(response_json['Runtime'])
        title_list.append(response_json['Title'])
        type_list.append(response_json['Type'])
        imdb_votes_list.append(response_json['imdbVotes'])
        title_id.append(response_json['imdbID'])
    except KeyError:
        pass
    time.sleep(1)
# Out:
# -------------------
# movie id tt10985348
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt6540984
# -------------------
# {'Actors': 'Sheryl Lee, Paris Berelc, Kennedy Lea Slocum, Corey Fogelmanis',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Danny J. Boyle',
#  'Genre': 'Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Samantha is a serious journalist, both for the school paper and for '
#          "the yearbook, but she's just as serious about her friends, Nate, "
#          'Gillian, and Rudy, all of whom are vying with her for a full-ride '
#          'local scholarship to college.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMGIzY2YzMTctYWVmNy00MDY3LWE1ZjItYjFkYjliZmFkMzA4XkEyXkFqcGdeQXVyMjM4MTAwNzQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Unrated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.0/10'}],
#  'Released': '16 Jan 2018',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': '#SquadGoals',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Caron Tschampion',
#  'Year': '2018',
#  'imdbID': 'tt6540984',
#  'imdbRating': '4.0',
#  'imdbVotes': '346'}
# -------------------
# movie id tt3743246
# -------------------
# {'Actors': 'Samuel Smith, Khalimah Gaston, Jason Barkley, Vanessa Fant',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Mark K. Buddington',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '#Victoria',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Mark K. Buddington',
#  'Year': '2014',
#  'imdbID': 'tt3743246',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6871174
# -------------------
# {'Actors': 'Erik Brevik, Paige Von Bank, Jareth Spirio, Greg Farinelli',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tino Duvick',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMmRkYTVkMWItNGNmMy00MWJkLThjN2YtOGRlM2I4ZmRmZTlkXkEyXkFqcGdeQXVyMjIzNTE3Nw@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '#truehomies',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tino Duvick',
#  'Year': '2018',
#  'imdbID': 'tt6871174',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6877520
# -------------------
# {'Actors': 'Liz Clare, Dustin Fitzsimons, Bettina Devin, Mark Wilson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Maggie VandenBerghe',
#  'Genre': 'Adventure, Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Two girl friends from San Francisco set out on a Hawaiian '
#          'car-camping excursion in search of adventure, Instagram likes, and '
#          'the meaning of life. Along the way disaster ensues, their ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzJhNzYzZWEtZTBlZC00ZThjLWEyNjMtN2YyYzQ3YTUxNDI5XkEyXkFqcGdeQXVyNTIyMjc3MDc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '76 min',
#  'Title': '#wanderlust',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Christina Storozkova (story), Maggie VandenBerghe',
#  'Year': '2017',
#  'imdbID': 'tt6877520',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt9025208
# -------------------
# {'Actors': 'Dahiana Castro, Daphne Danielle, Arush Dayal, Richie Dupkin',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Menelek Lumumba',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Mike Anderson is a senior at the quintessential New-England liberal '
#          'arts school, Frost College. And Mike is eight weeks away from '
#          'graduation. On this particular day he has his ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNmQzZDhhZDgtZDMxYi00MTliLTg1MWYtOTk1N2Y1OTY4MTU4XkEyXkFqcGdeQXVyNzcyMjU0Mg@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.9/10'}],
#  'Released': '02 Aug 2018',
#  'Response': 'True',
#  'Runtime': '92 min',
#  'Title': '1 Angry Black Man',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Menelek Lumumba',
#  'Year': '2018',
#  'imdbID': 'tt9025208',
#  'imdbRating': '7.9',
#  'imdbVotes': '9'}
# -------------------
# movie id tt7856404
# -------------------
# {'Actors': 'Patrick Campion, Bill Carter, J. Mark Emerson, Johny Fontaine',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Migdalia Etheridge, Ray Etheridge',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A low budget but slick "who done it" involving the murder of a '
#          'wealthy businessman. The long list of suspects includes the family '
#          'butler, their shady attorney, and an assortment of greedy ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZDUwODNlZWYtN2Y3Ny00M2UzLTk1MjQtMmYwN2Q5NjY4NGUxXkEyXkFqcGdeQXVyMjM0MjM4MTI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '02 Jan 2018',
#  'Response': 'True',
#  'Runtime': '50 min',
#  'Title': '1 Dead man, 6 Suspects, $65 Million',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ray Etheridge',
#  'Year': '2018',
#  'imdbID': 'tt7856404',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3445702
# -------------------
# {'Actors': 'Lindsey Shaw, Judd Nelson, Dendrie Taylor, Veronnica Avila',
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '17 Jul 2018',
#  'Director': 'Jeremy Phillips',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Maybe pregnant, 20 years old Lissa revises her life.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BY2Q0OWYxMjAtMWNlZS00ZWVmLThiZmMtOThjOTA0ZDdkMzk4XkEyXkFqcGdeQXVyNzY1ODU1OTk@._V1_SX300.jpg',
#  'Production': 'Gravitas Ventures',
#  'Rated': 'TV-MA',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.3/10'}],
#  'Released': '07 Jul 2018',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': '1/1',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jeremy Phillips',
#  'Year': '2018',
#  'imdbID': 'tt3445702',
#  'imdbRating': '7.3',
#  'imdbVotes': '2,354'}
# -------------------
# movie id tt7374492
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Joshua Bermel',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A group of friends go to an island to detox together, not realizing '
#          'the struggles and problems they will have to face once there.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Apr 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '10-56',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Bermel Joshua, Matthew J. Lannon',
#  'Year': '2018',
#  'imdbID': 'tt7374492',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt9869744
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt8364714
# -------------------
# {'Actors': 'Randall Dixon, Jennifer Bainbridge',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Randall Dixon',
#  'Genre': 'Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Three parallel versions of the same man (a Scientist, a Spy, and an '
#          'Artist) shift into each others lives at the whim of a mysterious '
#          'intelligence.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNmVkMDRmMmItZTJhOS00MzNjLWE3OWEtMTdjOTZlZDFmMDU2XkEyXkFqcGdeQXVyMjMxODEzODg@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '105 min',
#  'Title': '11 Henrys',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Randall Dixon',
#  'Year': '2018',
#  'imdbID': 'tt8364714',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7549092
# -------------------
# {'Actors': 'Kahlil Boursii, Tank Kelly, Jeffrey M. Morris, Kandy Pierre',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Hannibal King',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N.Y.P.D. Detective James Morris hunts his younger brother a Federal '
#          "Black Panther Party Member who has compromised Morris's "
#          "Partner/Lover Detective Ralphie Valdez's undercover status.111 is...",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDU2OTJmYTgtMDM0Ny00ZDZkLTg4OGItNzJiNDBiM2FjOTk0XkEyXkFqcGdeQXVyNDk3NTgyNzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '10 Oct 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '111: The Sunriser',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Hannibal King',
#  'Year': '2018',
#  'imdbID': 'tt7549092',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt1413492
# -------------------
# {'Actors': 'Chris Hemsworth, Michael Shannon, Michael Peña, Navid Negahban',
#  'Awards': '3 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '01 May 2018',
#  'Director': 'Nicolai Fuglsig',
#  'Genre': 'Action, Drama, History, War',
#  'Language': 'English, Dari, Russian, Spanish, Uzbek',
#  'Metascore': '54',
#  'Plot': '12 Strong tells the story of the first Special Forces team deployed '
#          'to Afghanistan after 9/11; under the leadership of a new captain, '
#          'the team must work with an Afghan warlord to take down the Taliban.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTEzMjk3NzkxMV5BMl5BanBnXkFtZTgwNjY2NDczNDM@._V1_SX300.jpg',
#  'Production': 'Warner Bros. Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '51%'},
#              {'Source': 'Metacritic', 'Value': '54/100'}],
#  'Released': '19 Jan 2018',
#  'Response': 'True',
#  'Runtime': '130 min',
#  'Title': '12 Strong',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ted Tally, Peter Craig, Doug Stanton (based on the book,  "Horse '
#            'Soldiers" by)',
#  'Year': '2018',
#  'imdbID': 'tt1413492',
#  'imdbRating': '6.5',
#  'imdbVotes': '56,044'}
# -------------------
# movie id tt7476438
# -------------------
# {'Actors': 'Zach Dulin, Kodi Saint Angelo, Neville Archambault, Chelsea '
#            'Edmundson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '27 Jul 2018',
#  'Director': 'Seth Fuller(co-director), Scott Hussion(co-director)',
#  'Genre': 'Crime, Drama, Horror, Thriller',
#  'Language': 'English',
#  'Metascore': '25',
#  'Plot': 'When a family of five rent a beautiful house for their summer '
#          'vacation, the price seems too good to be true.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk4ODY4MTg1Nl5BMl5BanBnXkFtZTgwODUzNDk2NTM@._V1_SX300.jpg',
#  'Production': 'Gravitas Ventures',
#  'Rated': 'TV-MA',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.5/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '22%'},
#              {'Source': 'Metacritic', 'Value': '25/100'}],
#  'Released': '27 Jul 2018',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': '14 Cameras',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Victor Zarcoff',
#  'Year': '2018',
#  'imdbID': 'tt7476438',
#  'imdbRating': '4.5',
#  'imdbVotes': '1,926'}
# -------------------
# movie id tt6411590
# -------------------
# {'Actors': 'Cory Michael Smith, Virginia Madsen, Michael Chiklis, Jamie Chung',
#  'Awards': '5 wins & 9 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '18 Dec 2018',
#  'Director': 'Yen Tan',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': '71',
#  'Plot': 'A closeted young man goes home for the holidays and struggles to '
#          'reveal his dire circumstances to his conservative family.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzM2YjQ2M2MtY2EyMy00YmI0LTk2NWQtZTA2ZTA1OGY4ODhjXkEyXkFqcGdeQXVyMjQ3MTMzNDU@._V1_SX300.jpg',
#  'Production': 'Wolfe Releasing',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.9/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '95%'},
#              {'Source': 'Metacritic', 'Value': '71/100'}],
#  'Released': '14 Dec 2018',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': '1985',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Hutch (story by), Yen Tan (screenplay), Yen Tan (story by)',
#  'Year': '2018',
#  'imdbID': 'tt6411590',
#  'imdbRating': '6.9',
#  'imdbVotes': '1,259'}
# -------------------
# movie id tt7153134
# -------------------
# {'Actors': 'Denise Richards, Val Kilmer, Dominique Swain, Tom Berenger',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Iran',
#  'DVD': 'N/A',
#  'Director': 'Ali Atshani, Sam Khoze',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Tucker and Hamid are going to be grandfathers for the first time, '
#          'but only if they can come together long enough to save their '
#          'first-born grandchild.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMmM1ZjIyMmQtYTQxOC00YTEzLTgyZGQtMTU5NTQ4NDA5ZTIzXkEyXkFqcGdeQXVyMjYzNjYyNTU@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.3/10'}],
#  'Released': '18 Feb 2019',
#  'Response': 'True',
#  'Runtime': '79 min',
#  'Title': '1st Born',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Sam Khoze, Tarek Zohdy, Ali Atshani (story by), Mahdi Alimirzaee',
#  'Year': '2018',
#  'imdbID': 'tt7153134',
#  'imdbRating': '3.3',
#  'imdbVotes': '121'}
# -------------------
# movie id tt8142044
# -------------------
# {'Actors': 'Hayley Lovitt, Jason MacDonald, Teddy Cole, Brook Todd',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Raymond Wood',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Student filmmakers uncover occult rituals tied to an abandoned '
#          'warehouse, then gradually realize the horror is closer than they '
#          'think.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjNjMmI4ODQtM2E1YS00YmRmLWI1ZGYtY2Y3M2NkMjExOGUyXkEyXkFqcGdeQXVyMTE0ODg0NDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.3/10'}],
#  'Released': '22 Feb 2019',
#  'Response': 'True',
#  'Runtime': '97 min',
#  'Title': '1st Summoning',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Chris Piner',
#  'Year': '2018',
#  'imdbID': 'tt8142044',
#  'imdbRating': '3.3',
#  'imdbVotes': '622'}
# -------------------
# movie id tt4189646
# -------------------
# {'Actors': 'Josh Hunt, Andrew DeCarlo, Katherine Stewart, Elizabeth Grace',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Katherine Stewart',
#  'Genre': 'Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'In this modern setting for the Shakespeare classic, two small-town '
#          'boys head to the big city looking for adventure and romance. But '
#          'when they both fall for the same girl, friends become rivals.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYjFkZjQ2YmQtYmY2Ni00ZmIxLWEwMGQtMjA3ZmE2NDVhZDEzXkEyXkFqcGdeQXVyMjM3MDM2ODc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.3/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '99 min',
#  'Title': '2 Gentlemen of Verona',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Katherine Stewart',
#  'Year': '2018',
#  'imdbID': 'tt4189646',
#  'imdbRating': '2.3',
#  'imdbVotes': '26'}
# -------------------
# movie id tt7246752
# -------------------
# {'Actors': 'Bella Podaras, Emma Kennedy, Jamal Akakpo, Vadim Brunnell',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Max Decker',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '15 Jan 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '2 Live & Die in LA',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Justin Sardis',
#  'Year': '2018',
#  'imdbID': 'tt7246752',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8493776
# -------------------
# {'Actors': 'Sarah Mitchell, Travis Delgado, Caitlin Aase, Melissa DuPrey',
#  'Awards': '5 wins & 1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Laura Madalinski',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': '2 in the Bush: A Love Story is an unconventional romantic comedy '
#          'about dungeons, a fish named Archimedes, and the many forms that '
#          'love takes.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjBjMTE1MmYtZGM0YS00ZjkwLTljODItM2E2Mzc2NGIxYjk3XkEyXkFqcGdeQXVyOTAyMTg2MzY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.5/10'}],
#  'Released': '26 Oct 2018',
#  'Response': 'True',
#  'Runtime': '97 min',
#  'Title': '2 in the Bush: A Love Story',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kelly Haas, Laura Madalinski',
#  'Year': '2018',
#  'imdbID': 'tt8493776',
#  'imdbRating': '3.5',
#  'imdbVotes': '114'}
# -------------------
# movie id tt1458902
# -------------------
# {'Actors': 'Dean Cain, Stormi Maya, Stefanie Bloom, Devin Fuller',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, China',
#  'DVD': 'N/A',
#  'Director': 'Princeton Holt',
#  'Genre': 'Drama, Fantasy, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A family man struggling to hold it all together discovers a hidden '
#          'parlor that offers a solution...sexbots.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjJiMmJiZTgtOWEyZS00NjQ1LWFhYmQtZDAyOGQwMmUxZTM5XkEyXkFqcGdeQXVyMjY5ODU3OA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.3/10'}],
#  'Released': '14 Jan 2020',
#  'Response': 'True',
#  'Runtime': '104 min',
#  'Title': '2050',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Brian Ackley',
#  'Year': '2018',
#  'imdbID': 'tt1458902',
#  'imdbRating': '5.3',
#  'imdbVotes': '148'}
# -------------------
# movie id tt7382590
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt4976192
# -------------------
# {'Actors': 'Nicolas Cage, Sophie Skelton, Michael Rainey Jr., Dwayne Cameron',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Bulgaria',
#  'DVD': '10 Jul 2018',
#  'Director': 'York Alec Shackleton',
#  'Genre': 'Action, Crime, Drama',
#  'Language': 'English',
#  'Metascore': '21',
#  'Plot': 'While on a routine patrol, an aging cop, his partner and their '
#          'ride-along get caught in a standoff with a band of former '
#          'mercenaries robbing a bank.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTkxNjA0MjMzNF5BMl5BanBnXkFtZTgwNTM2NzczNTM@._V1_SX300.jpg',
#  'Production': 'Momentum Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.4/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '5%'},
#              {'Source': 'Metacritic', 'Value': '21/100'}],
#  'Released': '08 Jun 2018',
#  'Response': 'True',
#  'Runtime': '86 min',
#  'Title': '211',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'York Alec Shackleton (based on a screenplay by), John Rebus '
#            '(screenplay by)',
#  'Year': '2018',
#  'imdbID': 'tt4976192',
#  'imdbRating': '4.4',
#  'imdbVotes': '5,916'}
# -------------------
# movie id tt7280898
# -------------------
# {'Actors': 'Anders Danielsen Lie, Jonas Strand Gravli, Jon Øigarden, Maria '
#            'Bock',
#  'Awards': '2 wins & 3 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'Norway, Iceland, USA',
#  'DVD': '10 Oct 2018',
#  'Director': 'Paul Greengrass',
#  'Genre': 'Crime, Drama, History, Thriller',
#  'Language': 'English, Norwegian',
#  'Metascore': '69',
#  'Plot': "A three-part story of Norway's worst terrorist attack in which over "
#          'seventy people were killed. 22 July looks at the disaster itself, '
#          "the survivors, Norway's political system and the lawyers who worked "
#          'on this horrific case.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNGY2MmQ0YTYtNjRjOS00ZjBhLThlMDMtN2FiY2ZjODhmNzU2XkEyXkFqcGdeQXVyOTA5NzQ0MDQ@._V1_SX300.jpg',
#  'Production': 'Netflix',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.7/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '80%'},
#              {'Source': 'Metacritic', 'Value': '69/100'}],
#  'Released': '10 Oct 2018',
#  'Response': 'True',
#  'Runtime': '143 min',
#  'Title': '22 July',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Paul Greengrass, Åsne Seierstad (based upon the book "One of Us" '
#            'by)',
#  'Year': '2018',
#  'imdbID': 'tt7280898',
#  'imdbRating': '6.7',
#  'imdbVotes': '22,248'}
# -------------------
# movie id tt5985346
# -------------------
# {'Actors': 'Michele Baldwin, Shivantha Wijesinha, Rachel Johanson, Soleidy '
#            'Mendez',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Bela Attila Kovacs',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '17 Jul 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '25 Cents to Paradise',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Bela Attila Kovacs',
#  'Year': '2017',
#  'imdbID': 'tt5985346',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6368508
# -------------------
# {'Actors': 'Murphy Patrick Martin, Diana Cristina Solis, Hayley Ambriz, Kaden '
#            'Cole',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Alex Magaña',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': '29 year-old Barnaby is jobless, broke, his girlfriend left him and '
#          "he's living out of his car. Luckily for him, fate intervenes and he "
#          'is reacquainted with Madison, an old friend. As she helps him turn '
#          'his life around, romance brews.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZjFmY2Q4ZTgtOGEzMi00MWU2LTgwZGItNjE2OWQ5YzMxODA3XkEyXkFqcGdeQXVyNDQ2MjQ2Mjk@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.8/10'}],
#  'Released': '11 Mar 2018',
#  'Response': 'True',
#  'Runtime': '100 min',
#  'Title': '29 to Life',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Alex Magaña',
#  'Year': '2018',
#  'imdbID': 'tt6368508',
#  'imdbRating': '4.8',
#  'imdbVotes': '248'}
# -------------------
# movie id tt8096334
# -------------------
# {'Actors': 'Carla Mays, Cassandra Leavell, Taylor Adams, April Cottrill',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'David L. Walker',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYzdlYjhhMDctZDRkNC00YTFjLTg5MGYtZWVhMjdjMTQ5YjkzXkEyXkFqcGdeQXVyMzM3Nzc3Mjk@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '25 Feb 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '3 The Movie',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'David L. Walker',
#  'Year': '2018',
#  'imdbID': 'tt8096334',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7316576
# -------------------
# {'Actors': 'Carrie Preston, Rob Benedict, Rusty Schwimmer, Marielle Scott',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '05 Mar 2019',
#  'Director': 'Caitlin Koller',
#  'Genre': 'Comedy, Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When five college pals return to rural Wisconsin for their estranged '
#          "friend's funeral, what begins as an uneasy reunion becomes a "
#          'terrifying fight for survival.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzg4MThmYjgtYTQxOC00YzIzLTk5OGUtZWY5YTRjODNiOWVjXkEyXkFqcGdeQXVyMDk2NTYzMw@@._V1_SX300.jpg',
#  'Production': 'Film Camp Productions',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.2/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '80%'}],
#  'Released': '05 Mar 2019',
#  'Response': 'True',
#  'Runtime': '84 min',
#  'Title': '30 Miles from Nowhere',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Seana Kofoed',
#  'Year': '2018',
#  'imdbID': 'tt7316576',
#  'imdbRating': '4.2',
#  'imdbVotes': '598'}
# -------------------
# movie id tt6149464
# -------------------
# {'Actors': "Katie Walder, Patrick Fabian, Jenny O'Hara, Alan Rachins",
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tom Metz III',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '30 Nights',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Johnny Giacalone, Mandy Kaplan, Tom Metz III',
#  'Year': '2017',
#  'imdbID': 'tt6149464',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7357104
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt5815216
# -------------------
# {'Actors': 'Elias Peraza, Amara Overmyer',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jeremiah Carbajal',
#  'Genre': 'Drama, Romance, Thriller',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': "After so many years of dating in the late 1900's, Lily Chagsteen "
#          '(Amara Overmyer) and Ben Chagsteen (Elias Peraza) get a letter from '
#          'a "mysterious" woman in Paris, France stating that she ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTY2OTNkYTMtOThkNC00NTk4LWExMzItNzFmZTZlZDc4OGZjXkEyXkFqcGdeQXVyNjI2NTc2NjQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '37',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jeremiah Carbajal',
#  'Year': '2018',
#  'imdbID': 'tt5815216',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8280720
# -------------------
# {'Actors': 'Summer Knowles, Leigh Takata, Heather Danner, Jay Bronson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Logan Bennett, Leigh Takata',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A stripper, janitor and lawyer are found dead in a shopping mall and '
#          'a crazed religious fanatic is behind it all. Find out why and how '
#          'this went down in 3X.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNmE5MDNiM2YtNmRjZi00Mjg4LTg5M2ItNWNmOTZjNmRmOWE0XkEyXkFqcGdeQXVyNjM1NjY0OTk@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '24 Jul 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '3X',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Leigh Takata',
#  'Year': '2018',
#  'imdbID': 'tt8280720',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8618438
# -------------------
# {'Actors': 'Suzanne Stokes, Patrick Lescarbeau, Tracy Lix, Sahara Ale',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Paul Magby',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': '4 different films of horror starting with 2 parts of The Hitchhiker '
#          'who is a man who is out to teach all the bad girls a lesson. Then a '
#          'spy gets caught and her boss sets out to make sure it...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTI4NmMwY2UtN2E4ZC00ZDU3LWFkNTItNTEyNzQ0YzI0MmFjXkEyXkFqcGdeQXVyOTExMjkyNTY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Nov 2018',
#  'Response': 'True',
#  'Runtime': '45 min',
#  'Title': '4 Films of Horror',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2018',
#  'imdbID': 'tt8618438',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8210754
# -------------------
# {'Actors': 'Alexei Afonin, Brittany Horn, Brad Napp, Allison Pittman',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jimmy Andrews',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Amelia (29) and Finnegan (60) find each other through an unexpected '
#          'phone call. The two fall in love before ever meeting in person. When '
#          'their first "face-to-face" encounter doesn\'t go as ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZGYwNDdhODMtY2Y1Yy00NWM4LTgxY2ItNGYwZWYxMWYxYjAzXkEyXkFqcGdeQXVyNjkyODM2NjA@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.5/10'}],
#  'Released': '01 Sep 2018',
#  'Response': 'True',
#  'Runtime': '97 min',
#  'Title': '4 Phone Calls from Amelia',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jimmy Andrews (screenwriter)',
#  'Year': '2018',
#  'imdbID': 'tt8210754',
#  'imdbRating': '3.5',
#  'imdbVotes': '8'}
# -------------------
# movie id tt5946668
# -------------------
# {'Actors': 'Jamie Bernadette, Vanessa Reynolds, Stacey Danger, Justine '
#            'Wachsberger',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '03 Apr 2018',
#  'Director': 'Dylan Reynolds',
#  'Genre': 'Action, Horror',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'A group of five women go camping in the woods to celebrate a '
#          "friend's birthday over 4/20 weekend. But when they cross the turf of "
#          'an illegal marijuana grow operation they must struggle to survive '
#          'the living nightmare.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZjI5ZjJmZTktYjhjYi00YjQ0LTliNjYtM2M1MGViYzQ2Y2UwXkEyXkFqcGdeQXVyNzQ0MjM4NDM@._V1_SX300.jpg',
#  'Production': 'The Hike Productions',
#  'Rated': 'TV-MA',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.7/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '57%'}],
#  'Released': '03 Apr 2018',
#  'Response': 'True',
#  'Runtime': '84 min',
#  'Title': '4/20 Massacre',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dylan Reynolds',
#  'Year': '2018',
#  'imdbID': 'tt5946668',
#  'imdbRating': '3.7',
#  'imdbVotes': '482'}
# -------------------
# movie id tt9331072
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt8696294
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt7160774
# -------------------
# {'Actors': 'Mike Sutton, Mark Lyons, Eleri Ever, Kylie Balish',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Chris Matrone',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A Drifter wakes up in the backseat of a 1986 Lincoln town car, with '
#          'no memory of the events prior. The Driver, an Old Man, tells him '
#          'that he has a debt to pay, and the only way to pay it is to go '
#          'through 5 Doors.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOWY5NjcxNGYtODg1ZS00ZGZhLThmOGMtMDExMzQ5MWUzYTFjXkEyXkFqcGdeQXVyNTAyNTk2MTM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '5 Doors',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Chris Matrone',
#  'Year': '2018',
#  'imdbID': 'tt7160774',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt1971310
# -------------------
# {'Actors': 'Nargis Fakhri, Rajkummar Rao, Bo Derek, Candy Clark',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, India, Canada',
#  'DVD': 'N/A',
#  'Director': 'Namrata Singh Gujral',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An American journalist travels to India to cover Bollywood weddings, '
#          'only to uncover a mosaic of cultural clashes, transgender tangles '
#          'and lost loves with her travels culminating at a destination where '
#          'the only journey is the one within.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMmIxMWNjZGMtNzVmYi00MmIwLWFlNzQtMDhjMTJiYjQ2NjE1XkEyXkFqcGdeQXVyMTE4NTI5NTA@._V1_SX300.jpg',
#  'Production': 'UniGlobe Entertainment',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.2/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '17%'}],
#  'Released': '26 Oct 2018',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': '5 Weddings',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Denise Cruz-Castino (screenplay), Andy Glickman (screenplay), '
#            'Namrata Singh Gujral',
#  'Year': '2018',
#  'imdbID': 'tt1971310',
#  'imdbRating': '3.2',
#  'imdbVotes': '322'}
# -------------------
# movie id tt6881446
# -------------------
# {'Actors': 'Lydia Hearst, Phil Abrams, Erin Siu, Casey Dolkas',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Marc Martinez',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When Robert Stone is kidnapped and held hostage, his only chance of '
#          'survival is to engage in a campaign of psychological warfare against '
#          'his captors.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZTQ4ZmE4ZWQtOTg2OC00ZjBiLWI5OTUtMjdlYjRjZDllNmQyXkEyXkFqcGdeQXVyMTk0Nzc1NjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '11 Jun 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '50K',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Andrew Costello',
#  'Year': '2018',
#  'imdbID': 'tt6881446',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7491968
# -------------------
# {'Actors': 'Sam Schneider, Arielle Uppaluri, Gabrielle Sherman, Carlos Alfredo '
#            'Jr.',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Fred Grant',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'After witnessing a strange event, a young couple departs on a '
#          'camping trip outside Area 51 hoping to find answers.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYTFlZWE2ODYtYzY3NC00MTNlLWIzMWUtNGYxNTNjYmNkN2M3XkEyXkFqcGdeQXVyMjM2OTAxNg@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.4/10'}],
#  'Released': '10 Apr 2018',
#  'Response': 'True',
#  'Runtime': '76 min',
#  'Title': '51 Nevada',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Fred Grant',
#  'Year': '2018',
#  'imdbID': 'tt7491968',
#  'imdbRating': '3.4',
#  'imdbVotes': '177'}
# -------------------
# movie id tt6129694
# -------------------
# {'Actors': 'Charles Clark, Trena Penson, Erick Perkins, Joshua Nickel',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kimberley T. Zulkowski',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '53206: Milwaukee',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Stephen Gregory Curtis, Alan Zulkowski, Kimberley T. Zulkowski',
#  'Year': '2017',
#  'imdbID': 'tt6129694',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt1326219
# -------------------
# {'Actors': "Angelo Ashmon, Jason 'Kulayd' Clayton, Forty Da Great, Ayanna "
#            'Fullilove',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Dionciel Armstrong',
#  'Genre': 'Action, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Five.K.One, two best friends has to chose between life in the '
#          'streets and loyalty when they are indicted with the help of an '
#          'informant that causes everyone to be a suspect to the Boss.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjIyNTkwMDM1OF5BMl5BanBnXkFtZTcwMjIzMTYwMw@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.5/10'}],
#  'Released': '19 Jan 2010',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Five K One',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dionciel Armstrong',
#  'Year': '2010',
#  'imdbID': 'tt1326219',
#  'imdbRating': '4.5',
#  'imdbVotes': '27'}
# -------------------
# movie id tt6142496
# -------------------
# {'Actors': 'Abbi Jacobson, Dave Franco, Charlotte Carel, Madeline Carel',
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '06 Apr 2018',
#  'Director': 'Marja-Lewis Ryan',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': '66',
#  'Plot': 'A woman (Jacobson) learns her brother (Franco) has relapsed on '
#          'heroin.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTY1MjgyODM5NF5BMl5BanBnXkFtZTgwNTk2NzIwNTM@._V1_SX300.jpg',
#  'Production': 'Netflix',
#  'Rated': 'TV-MA',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '86%'},
#              {'Source': 'Metacritic', 'Value': '66/100'}],
#  'Released': '06 Apr 2018',
#  'Response': 'True',
#  'Runtime': '74 min',
#  'Title': '6 Balloons',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Marja-Lewis Ryan',
#  'Year': '2018',
#  'imdbID': 'tt6142496',
#  'imdbRating': '5.8',
#  'imdbVotes': '3,119'}
# -------------------
# movie id tt1884378
# -------------------
# {'Actors': 'Emmanuelle Chriqui, Austin Pendleton, Al Sapienza, Akiva Schaffer',
#  'Awards': '1 win.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Gabriel Judet-Weinshel',
#  'Genre': 'Mystery, Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A detective investigates a murder, only to find that the victim '
#          'is... himself. Soon, he discovers multiple versions of himself, not '
#          'all of them friendly.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODZmODQ4ZjQtMDEzZC00MWJlLTg4MzItMjE0ZTFmNzY2ODZjXkEyXkFqcGdeQXVyNTI0MTcwNg@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'TV-14',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.3/10'}],
#  'Released': '03 Mar 2018',
#  'Response': 'True',
#  'Runtime': '75 min',
#  'Title': '7 Splinters in Time',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Gabriel Judet-Weinshel',
#  'Year': '2018',
#  'imdbID': 'tt1884378',
#  'imdbRating': '3.3',
#  'imdbVotes': '452'}
# -------------------
# movie id tt7567278
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt8128970
# -------------------
# {'Actors': 'Paul Antonie, Karina Bonnefil, Lela Elam, Daimion Johnson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Keith C. Wade',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The party was supposed to start at 7:02 pm. It was election night '
#          '2008. The first African- American President of the United Stated was '
#          'to be elected...but K.D, had other plans for the night...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYzMxY2RhZjUtMGI5NC00NTJmLWFjNzktYzZhMDQxNDY3ZTc5XkEyXkFqcGdeQXVyMTQ4OTA5Mzc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.6/10'}],
#  'Released': '27 Mar 2018',
#  'Response': 'True',
#  'Runtime': '74 min',
#  'Title': '7:02 Only the Righteous',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Keith C. Wade',
#  'Year': '2018',
#  'imdbID': 'tt8128970',
#  'imdbRating': '5.6',
#  'imdbVotes': '8'}
# -------------------
# movie id tt6704038
# -------------------
# {'Actors': 'Anatoliy Bystrikov, Marshall Ever, Jon Firman, Anita Foster',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '09 Apr 2019',
#  'Director': 'Alexander Shell',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Addicted to Heroin and tormented by children, 8 Ball the clown tries '
#          "to end his life and the torment, but he's just not able to, so he "
#          'tracks down the kids who have been calling and calling...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BM2Q2ODQ2NDAtMTljZi00NTNlLWE1ZjktMTMxNTgzZGVjNzhjXkEyXkFqcGdeQXVyNzQ1ODkzMjI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.8/10'}],
#  'Released': '01 Sep 2018',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': '8 Ball Clown',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kristine Shell, Mark Shell',
#  'Year': '2018',
#  'imdbID': 'tt6704038',
#  'imdbRating': '2.8',
#  'imdbVotes': '55'}
# -------------------
# movie id tt7407874
# -------------------
# {'Actors': 'Jason James Richter, Tim DeZarn, Elizabeth De Razzo, Erica Duke',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Chris Gehrt, Joe Hackett, Joe Taylor',
#  'Genre': 'N/A',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'One area code. Five stories. One party.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNWQxOTBkNjMtZGU5NC00YTk2LTgzZTEtYTdjNWUyOTYwZTE1XkEyXkFqcGdeQXVyMTE2NTA4ODE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '31 Oct 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '818',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Chris Gehrt, Jessica Greer, Joe Hackett, Tatum Shank, Joe Taylor',
#  'Year': '2018',
#  'imdbID': 'tt7407874',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4945640
# -------------------
# {'Actors': 'Michael Smith, Al Dales, Javier Badillo, David C. Jones',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'Canada, USA',
#  'DVD': 'N/A',
#  'Director': 'Christoph Kositza',
#  'Genre': 'Action, Crime, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A vigilante hijacks a police car and prowls the streets of Los '
#          'Angeles disguised as a cop, serving his own brand of street justice.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjcxNDk3MzEyMF5BMl5BanBnXkFtZTgwOTcxMjY4NjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '05 Jun 2016',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': 'L.A. Beat',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Christoph Kositza',
#  'Year': '2016',
#  'imdbID': 'tt4945640',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt11395612
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt2201211
# -------------------
# {'Actors': 'J.K. Simmons, Keanu Wilson, Julian Atocani Sanchez, Noel Gugliemi',
#  'Awards': '5 wins & 2 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Australia',
#  'DVD': '05 Feb 2019',
#  'Director': 'Cameron Nugent',
#  'Genre': 'Comedy, Drama, Family',
#  'Language': 'English, Spanish',
#  'Metascore': 'N/A',
#  'Plot': 'A Hispanic family find hope in their extraordinary son named '
#          'Sailboat when a personal gesture awakens a global desire. Armed with '
#          'a "little guitar", Sailboat leads an offbeat cast into the '
#          'miraculous story of the greatest secret never told.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNGM2NzJlNTMtYjlmMy00ZGM4LTg5ZWMtZWVlM2UyZWJhNDYxXkEyXkFqcGdeQXVyNDA1NDA2NTk@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.8/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '80%'}],
#  'Released': '06 May 2019',
#  'Response': 'True',
#  'Runtime': '92 min',
#  'Title': 'A Boy Called Sailboat',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Cameron Nugent',
#  'Year': '2018',
#  'imdbID': 'tt2201211',
#  'imdbRating': '6.8',
#  'imdbVotes': '674'}
# -------------------
# movie id tt6905402
# -------------------
# {'Actors': 'Omari Hardwick, Meagan Good, Jay Ellis, Dijon Talton',
#  'Awards': '1 win & 2 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Qasim Basir',
#  'Genre': 'Romance',
#  'Language': 'English',
#  'Metascore': '65',
#  'Plot': 'On the night of the 2016 Presidential election, Cass, an L.A. club '
#          'promoter, takes a thrilling and emotional journey with Frida, a '
#          'Midwestern visitor. She challenges him to revisit his broken dreams '
#          '- while he pushes her to discover hers.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc4MjcxNTYzMF5BMl5BanBnXkFtZTgwNDg0ODcwNjM@._V1_SX300.jpg',
#  'Production': 'Samuel Goldwyn Films',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.7/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '86%'},
#              {'Source': 'Metacritic', 'Value': '65/100'}],
#  'Released': '14 Sep 2018',
#  'Response': 'True',
#  'Runtime': '89 min',
#  'Title': 'A Boy. A Girl. A Dream.',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Qasim Basir, Samantha Tanner',
#  'Year': '2018',
#  'imdbID': 'tt6905402',
#  'imdbRating': '4.7',
#  'imdbVotes': '287'}
# -------------------
# movie id tt6884380
# -------------------
# {'Actors': 'Tyne Daly, Elisabeth Henry-Macari, James Marsters, Shershah Mizan',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Patrick Wang',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': '91',
#  'Plot': 'After 40 years of running their community arts space, The Bread '
#          'Factory, Dorothea and Greta are suddenly fighting for survival when '
#          'a celebrity couple--performance artists from China--come ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMDBkNzI1ODAtNjAwOC00ODk1LTlhNmMtYTVlNjAxZjY3MTI4XkEyXkFqcGdeQXVyMjM0MTk0MA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.2/10'},
#              {'Source': 'Metacritic', 'Value': '91/100'}],
#  'Released': '26 Oct 2018',
#  'Response': 'True',
#  'Runtime': '122 min',
#  'Title': 'A Bread Factory, Part One',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Patrick Wang',
#  'Year': '2018',
#  'imdbID': 'tt6884380',
#  'imdbRating': '7.2',
#  'imdbVotes': '114'}
# -------------------
# movie id tt6887540
# -------------------
# {'Actors': 'Tyne Daly, Wayne Fugate, Isabela Quines, Phil Helm',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Patrick Wang',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': '91',
#  'Plot': 'At The Bread Factory, they rehearse the Greek play, Hecuba. But the '
#          'real theatrics are outside the theater where the town has been '
#          'invaded by bizarre tourists and mysterious tech start-up ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg2NmEzMTYtMmUzMy00NmQ3LThkOGItMzg4M2Q1MDkxODE0XkEyXkFqcGdeQXVyMjM0MTk0MA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'},
#              {'Source': 'Metacritic', 'Value': '91/100'}],
#  'Released': '26 Oct 2018',
#  'Response': 'True',
#  'Runtime': '120 min',
#  'Title': 'A Bread Factory, Part Two',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Patrick Wang',
#  'Year': '2018',
#  'imdbID': 'tt6887540',
#  'imdbRating': '7.0',
#  'imdbVotes': '148'}
# -------------------
# movie id tt2368535
# -------------------
# {'Actors': 'Stephanie Kuroda, Brandi Taylor, Tracy Hanayo Okubo, Paul Johnson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jon Brekke',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
# ...
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.9/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '76%'},
#              {'Source': 'Metacritic', 'Value': '67/100'}],
#  'Released': '04 Apr 2018',
#  'Response': 'True',
#  'Runtime': '114 min',
#  'Title': "Don't Worry, He Won't Get Far on Foot",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'John Callahan (based on the book by), John Callahan (story by), '
#            'Gus Van Sant (story by), Jack Gibson (story by), William Andrew '
#            'Eatman (story by), Gus Van Sant (screenplay by)',
#  'Year': '2018',
#  'imdbID': 'tt6288124',
#  'imdbRating': '6.9',
#  'imdbVotes': '16,990'}
# -------------------
# movie id tt7087210
# -------------------
# {'Actors': 'Michael Agee, Adam Bartley, Jamie Bell, Chris Browning',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '22 Feb 2019',
#  'Director': 'Tim Sutton',
#  'Genre': 'Drama, Thriller',
#  'Language': 'English',
#  'Metascore': '53',
#  'Plot': 'Two men prepare to compete in a legendary bare-knuckle fight where '
#          'the winner gets a $100,000 prize.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTgxNjk0NDY2NF5BMl5BanBnXkFtZTgwNTIzMDcyNzM@._V1_SX300.jpg',
#  'Production': 'IFC Films',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.3/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '38%'},
#              {'Source': 'Metacritic', 'Value': '53/100'}],
#  'Released': '15 Feb 2019',
#  'Response': 'True',
#  'Runtime': '101 min',
#  'Title': 'Donnybrook',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Frank Bill (based on the novel by), Tim Sutton',
#  'Year': '2018',
#  'imdbID': 'tt7087210',
#  'imdbRating': '5.3',
#  'imdbVotes': '1,037'}
# -------------------
# movie id tt7909440
# -------------------
# {'Actors': 'Ian Fleming',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, UK',
#  'DVD': 'N/A',
#  'Director': 'Raphaello',
#  'Genre': 'Horror',
#  'Language': 'English, Scots, Klingon',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTI1ZjM4NjQtMGNkNC00YzI4LWE3NGItNjU2M2QxNTlmNTFlXkEyXkFqcGdeQXVyMzcwMjQzMw@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '18 Jan 2018',
#  'Response': 'True',
#  'Runtime': '66 min',
#  'Title': 'Door Knob',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Keith Barrows (creator), Kristal McKerrington (head writer)',
#  'Year': '2018',
#  'imdbID': 'tt7909440',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8098546
# -------------------
# {'Actors': 'Wasabi Mizuta, Megumi Ohara, Yumi Kakazu, Subaru Kimura',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'South Korea, Japan, France, Hong Kong, USA, Belgium, Brazil, '
#             'Mexico',
#  'DVD': 'N/A',
#  'Director': 'Seung-wan Ryoo, Kazuaki Imai',
#  'Genre': 'Animation, Adventure, Comedy, Family, Fantasy, Sci-Fi',
#  'Language': 'Japanese, Korean',
#  'Metascore': 'N/A',
#  'Plot': 'In the story, Doraemon, Nobita, Shizuka, Gian, and Suneo set out on '
#          'an adventure in the Caribbean Sea. Nobita is the captain of a ship '
#          'and fights his enemies on board. Shizuka gets ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMDc0MjI0OGMtYTg1ZC00NDE1LTgzMzktNWIwY2RmYzJjNWE3XkEyXkFqcGdeQXVyMjUxNjcxMjU@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'}],
#  'Released': '10 Feb 2019',
#  'Response': 'True',
#  'Runtime': '108 min',
#  'Title': "Doraemon the Movie: Nobita's Treasure Island",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Sung-bo Shim, Seung-wan Ryoo (screenplay), Young Kyun Park '
#            '(screenplay), Fujio F. Fujiko (character created by: Doraemon), '
#            'Kazuaki Imai (segment)',
#  'Year': '2018',
#  'imdbID': 'tt8098546',
#  'imdbRating': '6.6',
#  'imdbVotes': '315'}
# -------------------
# movie id tt4823486
# -------------------
# {'Actors': 'Julian Jay Burton, Tom Hagale, Bernadette Chapman, Perry Ball',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Julian Jay Burton',
#  'Genre': 'Crime, Drama, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Detective Jordan Long is drawn in by government secrets as he '
#          'investigates murders tied to late CIA Agent, Nigel Goodman.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYmFhOGMzYzQtYzU5Ny00NDI1LWFiYTctN2M3M2Q0MmEwZjE0XkEyXkFqcGdeQXVyMjkwOTE0NTI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'TV-14',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.9/10'}],
#  'Released': '01 Apr 2019',
#  'Response': 'True',
#  'Runtime': '96 min',
#  'Title': 'Dormant',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Julian Jay Burton (screenplay)',
#  'Year': '2019',
#  'imdbID': 'tt4823486',
#  'imdbRating': '4.9',
#  'imdbVotes': '32'}
# -------------------
# movie id tt5200130
# -------------------
# {'Actors': 'Dezmond Peterson, Matthew Wilks, Shba Cochrane, Leah Kraynak',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Dezmond Peterson',
#  'Genre': 'Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A story of two best friends whose friendship is put to the test by '
#          'unexpected love. Is their friendship strong enough to pass the test?',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Double Betrayal',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dezmond Peterson',
#  'Year': '2016',
#  'imdbID': 'tt5200130',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6181262
# -------------------
# {'Actors': 'Jennifer Jarrett, Katharine Phillips Moser, Christopher Showerman, '
#            'Phillip Daniel',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Thomas D. Moser',
#  'Genre': 'Crime',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When a team of scientists on the verge of a medical breakthrough are '
#          'mysteriously murdered, two agents must protect the remaining '
#          'survivor while trying to unravel the plot behind the assassinations.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzkxM2I3YjgtY2EzOS00OTY2LWFmNzQtY2RiNzY5NjgwMDcwXkEyXkFqcGdeQXVyMDU2NDc4NA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Nov 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Double Blind',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Thomas D. Moser, Rana Rines',
#  'Year': '2017',
#  'imdbID': 'tt6181262',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6163094
# -------------------
# {'Actors': 'Kyle Cooper, Lyndsey Doolen, Joe Hartzler, Melissa Hunter',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Austyn Jeffs',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "A couple's failing relationship is put into perspective when their "
#          'mountain cabin accidentally gets double booked by a much happier '
#          'couple.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Jan 2017',
#  'Response': 'True',
#  'Runtime': '107 min',
#  'Title': 'Double Eagle Ranch',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Austyn Jeffs',
#  'Year': '2017',
#  'imdbID': 'tt6163094',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8205654
# -------------------
# {'Actors': 'Kiara Burns, Kendall Devin Bell, Ricardo Blayde Diaz, Youlanda '
#            'Burnett',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ametra Self',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Akeya Griffin steals the heart of three men, two of which she finds '
#          'herself in an unwanted and toxic relationship. She must become '
#          'mature to discern the difference between adoration, infatuation and '
#          'domination.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMWFiNDMxYWItYTI3MC00Zjg4LWI2MjYtMjIwYmNiMDAzNDM4XkEyXkFqcGdeQXVyMjAxNzI5MzM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '13 Jun 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Double Fatal',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ametra Self',
#  'Year': '2018',
#  'imdbID': 'tt8205654',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8012734
# -------------------
# {'Actors': 'Paul Foster, Mike Greca, Martina Karra, Anastassia Krainik',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Fernando Castro Sanguino',
#  'Genre': 'Drama, Mystery, Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Somewhere in New York City, a mysterious duo has targeted Frank due '
#          'to his web searches, and want to test on him a new device that, if '
#          'it works, could change humans forever.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODM4YTRmZWQtM2Y3MC00ZGYxLWE0ZTgtZTIxMTFkYjBiNTIyXkEyXkFqcGdeQXVyODA1NzIxODI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '62 min',
#  'Title': 'Double Riddle',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Fernando Castro Sanguino',
#  'Year': '2018',
#  'imdbID': 'tt8012734',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5076150
# -------------------
# {'Actors': 'Will McFadden, Sarah Butler, Jamie Hector, Melora Walters',
#  'Awards': '5 wins & 7 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Will McFadden',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "When a black baby is born to white parents, a family's life is torn "
#          'apart as secrets are revealed, their love is tested and the legacy '
#          'of racism in America hits home.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYzM5ZDBhZmQtNzIzNS00ZWZhLWFiMWQtYmEyZDA4YjlhODFlXkEyXkFqcGdeQXVyMTY4NzI0Mzc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.8/10'}],
#  'Released': '12 Jun 2018',
#  'Response': 'True',
#  'Runtime': '86 min',
#  'Title': 'Doubting Thomas',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joseph Campbell (Story by), Will McFadden',
#  'Year': '2018',
#  'imdbID': 'tt5076150',
#  'imdbRating': '4.8',
#  'imdbVotes': '128'}
# -------------------
# movie id tt10462212
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt4791276
# -------------------
# {'Actors': 'Alexander Raye Pimentel, Zachary Greene, Nicholas Winand, Jeron '
#            'Pierce',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Alexander Raye Pimentel',
#  'Genre': 'Action, War',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Four soldiers trapped behind enemy lines must confront their fears '
#          'and desires while finding a way back to their battalion.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjQyZDZhMmYtZDFmNy00NWNjLWFmZGMtYWI5OTgzNzYxYjg0XkEyXkFqcGdeQXVyODg3MzY5MjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'}],
#  'Released': '04 Dec 2018',
#  'Response': 'True',
#  'Runtime': '70 min',
#  'Title': 'Down River',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Alexander Raye Pimentel, Howard Sackler (earlier screenplay)',
#  'Year': '2018',
#  'imdbID': 'tt4791276',
#  'imdbRating': '6.3',
#  'imdbVotes': '885'}
# -------------------
# movie id tt2372251
# -------------------
# {'Actors': 'AnnaSophia Robb, Uma Thurman, Isabelle Fuhrman, Victoria Moroles',
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'Spain, USA',
#  'DVD': '16 Oct 2018',
#  'Director': 'Rodrigo Cortés',
#  'Genre': 'Drama, Fantasy, Horror, Thriller',
#  'Language': 'English',
#  'Metascore': '56',
#  'Plot': 'A troubled teen named Kit Gordy is forced to join the exclusive '
#          'Blackwood Boarding School, just to find herself trapped by dark '
#          'forces around its mysterious headmistress, Madame Duret.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTY4ODg5MjMwNl5BMl5BanBnXkFtZTgwMDgyNzY1NTM@._V1_SX300.jpg',
#  'Production': 'Summit Entertainment',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '50%'},
#              {'Source': 'Metacritic', 'Value': '56/100'}],
#  'Released': '17 Aug 2018',
#  'Response': 'True',
#  'Runtime': '96 min',
#  'Title': 'Down a Dark Hall',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Goldbach (screenplay by), Chris Sparling (screenplay by), '
#            'Lois Duncan (based on the novel by)',
#  'Year': '2018',
#  'imdbID': 'tt2372251',
#  'imdbRating': '5.1',
#  'imdbVotes': '10,205'}
# -------------------
# movie id tt4427022
# -------------------
# {'Actors': 'Chris Schulz, Geoff James, Emily Landham, Carter Kinsella',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Christopher Flippo',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'In a small rural town, two friends examine their lives, '
#          'relationships, and futures.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '20 Aug 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Down and Yonder',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Christopher Flippo',
#  'Year': '2016',
#  'imdbID': 'tt4427022',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8257624
# -------------------
# {'Actors': 'Karissa Strain, Katie Strain, Yves Bright, Angie Everhart',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Buz Wallick',
#  'Genre': 'Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Abandoning the yoga business she shares with her twin sister, '
#          'Celeste sets out to forge her own identity, but her plans are '
#          'derailed when her desperate twin stops at nothing to bring her home.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZGRiY2QzN2UtOGMxNS00MDNiLTg1ZGItODUzOGMxYjI5MDkzXkEyXkFqcGdeQXVyNTk0NzE2OTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.9/10'}],
#  'Released': '12 Apr 2018',
#  'Response': 'True',
#  'Runtime': '86 min',
#  'Title': 'Downward Twin',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Julian Broudy',
#  'Year': '2018',
#  'imdbID': 'tt8257624',
#  'imdbRating': '4.9',
#  'imdbVotes': '52'}
# -------------------
# movie id tt8809630
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt6491178
# -------------------
# {'Actors': 'Mel Gibson, Vince Vaughn, Tory Kittles, Michael Jai White',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'Canada, USA',
#  'DVD': '30 Apr 2019',
#  'Director': 'S. Craig Zahler',
#  'Genre': 'Action, Crime, Drama, Thriller',
#  'Language': 'English',
#  'Metascore': '60',
#  'Plot': 'Once two overzealous cops get suspended from the force, they must '
#          'delve into the criminal underworld to get their proper compensation.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjE1MTk5NDQ5Ml5BMl5BanBnXkFtZTgwODUxNzg0NzM@._V1_SX300.jpg',
#  'Production': 'Summit Entertainment',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '75%'},
#              {'Source': 'Metacritic', 'Value': '60/100'}],
#  'Released': '22 Mar 2019',
#  'Response': 'True',
#  'Runtime': '159 min',
#  'Title': 'Dragged Across Concrete',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'S. Craig Zahler',
#  'Year': '2018',
#  'imdbID': 'tt6491178',
#  'imdbRating': '7.0',
#  'imdbVotes': '24,553'}

# %%
len(title_list)
# Out:
# 864

# %%
len(title_id)
# Out:
# 864

# %%
# if title_list and title_id are the same length run the cell below. 
# if they are not equal take out 'title_id': title_id

# %%
df = pd.DataFrame({'title_id': title_id, 'title': title_list, 'box_office': box_office_list, 'country': country_list, 
                   'genre': genre_list, 'director': director_list, 'metascore': metascore_list, 'production': production_list, 
                   'rating': rating_list, 'IMDB_rating': IMDB_rating_list, 'rotten_tomatoes_rating': rotten_tomatoes_rating_list, 
                  'runtime': runtime_list, 'type': type_list, 'IMDB_votes': imdb_votes_list})

# %%
df = df.drop_duplicates()
df.head()
# Out:
#     title_id              title box_office country                     genre  \
# 0  tt6540984        #SquadGoals        N/A     USA           Drama, Thriller
# 1  tt3743246          #Victoria        N/A     USA                     Drama
# 2  tt6871174        #truehomies        N/A     USA                       N/A
# 3  tt6877520        #wanderlust        N/A     USA  Adventure, Comedy, Drama
# 4  tt9025208  1 Angry Black Man        N/A     USA                       N/A
#
#               director metascore production   rating IMDB_rating  \
# 0       Danny J. Boyle       N/A        N/A  Unrated         4.0
# 1   Mark K. Buddington       N/A        N/A      N/A         N/A
# 2          Tino Duvick       N/A        N/A      N/A         N/A
# 3  Maggie VandenBerghe       N/A        N/A      N/A         N/A
# 4      Menelek Lumumba       N/A        N/A        R         7.9
#
#   rotten_tomatoes_rating runtime   type IMDB_votes
# 0                     NA  90 min  movie        346
# 1                     NA     N/A  movie        N/A
# 2                     NA     N/A  movie        N/A
# 3                     NA  76 min  movie        N/A
# 4                     NA  92 min  movie          9

# %%
df.count()
# Out:
# title_id                  864
# title                     864
# box_office                864
# country                   864
# genre                     864
# director                  864
# metascore                 864
# production                864
# rating                    864
# IMDB_rating               864
# rotten_tomatoes_rating    864
# runtime                   864
# type                      864
# IMDB_votes                864
# dtype: int64

# %%
df.to_csv('../data/2015_data_batch_4.csv', index=False)
