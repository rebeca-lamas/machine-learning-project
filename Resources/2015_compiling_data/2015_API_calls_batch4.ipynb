# %%
import pandas as pd
import requests
import json
import time
from pprint import pprint
from config import API_KEY

# %%
data = pd.read_csv('../data/titles_2015_batch4.csv')
df =  data.count()
df
# Out:
# title    404
# dtype: int64

# %%
title_id = []
box_office_list = []
country_list = []
genre_list = []
director_list = []
metascore_list = []
production_list = []
rating_list = []
IMDB_rating_list = [] 
rotten_tomatoes_rating_list = []
runtime_list = []
title_list = []
type_list = []
imdb_votes_list = []

# %%
movies = data['title']
total_movies = len(movies)

# %%
for i in range(total_movies):
    movie = movies[i]
    url = "http://www.omdbapi.com/?i=" + movie + "&apikey=" + API_KEY
    response = (requests.get(url).text)
    response_json = json.loads(response)
    print('-------------------')
    print(f'movie id {movie}')
    print('-------------------')
    pprint(response_json)
    
    try:
        box_office_list.append(response_json['BoxOffice'])
        country_list.append(response_json['Country'])
        genre_list.append(response_json['Genre'])
        director_list.append(response_json['Director'])
        metascore_list.append(response_json['Metascore'])
        production_list.append(response_json['Production'])
        rating_list.append(response_json['Rated'])
        IMDB_rating_list.append(response_json['imdbRating'])
        try:
            if not response_json['Ratings']:
                rotten_tomatoes_rating_list.append('NA')
            elif response_json['Ratings'][0]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][0]['Value'])
            elif response_json['Ratings'][1]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][1]['Value'])
            else:
                rotten_tomatoes_rating_list.append('NA')
        except IndexError:
            rotten_tomatoes_rating_list.append('NA')
        runtime_list.append(response_json['Runtime'])
        title_list.append(response_json['Title'])
        type_list.append(response_json['Type'])
        imdb_votes_list.append(response_json['imdbVotes'])
        title_id.append(response_json['imdbID'])
    except KeyError:
        pass
    time.sleep(1)
# Out:
# -------------------
# movie id tt4181400
# -------------------
# {'Actors': 'Valenzia Algarin, Stacy Allen, Christopher Atkins, Alan Bagh',
#  'Awards': '4 wins & 3 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Nancy Criss, Josh Hodgins',
#  'Genre': 'Drama, Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A family faces difficult, life changing decisions when trouble '
#          'strikes a close friend and her family.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTUwNDA0MjYzM15BMl5BanBnXkFtZTgwMzQ4NDEzNDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.3/10'}],
#  'Released': '05 Apr 2016',
#  'Response': 'True',
#  'Runtime': '92 min',
#  'Title': 'The Sparrows: Nesting',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kevin Alan Kent, Kenneth Lemm',
#  'Year': '2015',
#  'imdbID': 'tt4181400',
#  'imdbRating': '5.3',
#  'imdbVotes': '90'}
# -------------------
# movie id tt3675676
# -------------------
# {'Actors': 'Monica Dogra, Rahsaan Noor, Kal Parekh, Sorab Wadia',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, India',
#  'DVD': 'N/A',
#  'Director': 'Raghav Murali',
#  'Genre': 'Comedy, Crime, Drama',
#  'Language': 'English, Hindi',
#  'Metascore': 'N/A',
#  'Plot': 'The Spectacular Jihad of Taz Rahim, starring Monica Dogra (Aamir '
#          "Khan's Dhobi Ghat) and Rahsaan Islam (Bengali film Simanaheen), is a "
#          'hip-hop themed English and Hindi language Bollywood ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYjgxMjhkN2ItNzJkYi00MzZhLThiOGUtZDBiOTBhMGQ3MTA1XkEyXkFqcGdeQXVyNDU2MjA3MTk@._V1_SX300.jpg',
#  'Production': 'Ziryab Films',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.9/10'}],
#  'Released': '29 May 2015',
#  'Response': 'True',
#  'Runtime': '128 min',
#  'Title': 'The Spectacular Jihad of Taz Rahim',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ria Mahtab, Raghav Murali, Rahsaan Noor',
#  'Year': '2015',
#  'imdbID': 'tt3675676',
#  'imdbRating': '6.9',
#  'imdbVotes': '11'}
# -------------------
# movie id tt3266322
# -------------------
# {'Actors': 'Lesley Ann Warren, Joanna Going, Zak Henri, Bill Sage',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Michael Robertson Moore',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The Sphere and the Labyrinth is the story of Jordana Fitzgerald, an '
#          'unsuccessful architect whose plans have left no mark on the '
#          'landscape and who has invested her hopes in her handsome, ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZGQ5MzNkZDQtNDA3Zi00NWEwLWJiNDctYWMwMjkwNGI5YzJlL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNzg5OTk2OA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': 'The Sphere and the Labyrinth',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Robertson Moore (screenplay), Michael Robertson Moore',
#  'Year': '2015',
#  'imdbID': 'tt3266322',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2279373
# -------------------
# {'Actors': 'Antonio Banderas, Eric Bauza, Tim Conway, Eddie Deezen',
#  'Awards': '1 win & 9 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, South Korea, Australia',
#  'DVD': '02 Jun 2015',
#  'Director': 'Paul Tibbitt, Mike Mitchell',
#  'Genre': 'Animation, Adventure, Comedy, Family, Fantasy',
#  'Language': 'English',
#  'Metascore': '62',
#  'Plot': 'When a diabolical pirate above the sea steals the secret Krabby '
#          'Patty formula, SpongeBob and his nemesis Plankton must team up in '
#          'order to get it back.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjYyNDczNTE0MF5BMl5BanBnXkFtZTgwNjkzNDYxMzE@._V1_SX300.jpg',
#  'Production': 'Paramount Pictures',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.0/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '81%'},
#              {'Source': 'Metacritic', 'Value': '62/100'}],
#  'Released': '06 Feb 2015',
#  'Response': 'True',
#  'Runtime': '92 min',
#  'Title': 'The SpongeBob Movie: Sponge Out of Water',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Glenn Berger (screenplay), Jonathan Aibel (screenplay), Stephen '
#            'Hillenburg (story), Paul Tibbitt (story), Stephen Hillenburg '
#            '(series "SpongeBob SquarePants"), Vincent Waller (creative '
#            'supervision)',
#  'Year': '2015',
#  'imdbID': 'tt2279373',
#  'imdbRating': '6.0',
#  'imdbVotes': '45,235'}
# -------------------
# movie id tt1238846
# -------------------
# {'Actors': 'Darby Stanchfield, Brett Rice, Tony Lewis Centore, Christine Blair',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Harold Reitman, Bernard Salzmann',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "When Rachel Lehrer (Darby Stanchfield of ABC's hit TV show "
#          '"Scandal"), a young girl challenged with undiagnosed Asperger\'s '
#          'Syndrome (ASD), leaves her overprotective parents for the freedom '
#          '...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTUwNjQ5Nzk0Nl5BMl5BanBnXkFtZTgwODgyMzc5NjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'}],
#  'Released': '06 Oct 2015',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'The Square Root of 2',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Harold Reitman (creator)',
#  'Year': '2015',
#  'imdbID': 'tt1238846',
#  'imdbRating': '7.0',
#  'imdbVotes': '6'}
# -------------------
# movie id tt3248600
# -------------------
# {'Actors': 'Katherine LaNasa, Jeremy Sumpter, Christopher McDonald, Jason '
#            'Dohring',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '08 Jun 2015',
#  'Director': 'Terry Jastrow',
#  'Genre': 'Comedy, Drama, Sport',
#  'Language': 'English',
#  'Metascore': '26',
#  'Plot': 'A humble young man with uncommon skills from a small southern town '
#          'gets caught up in high stakes golf matches between big-time gamblers '
#          'until the game becomes life and death.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTYyNjMwNjM2Ml5BMl5BanBnXkFtZTgwNTMyMDA5NDE@._V1_SX300.jpg',
#  'Production': 'Arc Entertainment',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '15%'},
#              {'Source': 'Metacritic', 'Value': '26/100'}],
#  'Released': '17 Apr 2015',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': 'The Squeeze',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Terry Jastrow, Terry Jastrow',
#  'Year': '2015',
#  'imdbID': 'tt3248600',
#  'imdbRating': '5.4',
#  'imdbVotes': '500'}
# -------------------
# movie id tt0420293
# -------------------
# {'Actors': 'Billy Crudup, Michael Angarano, Moises Arias, Nicholas Braun',
#  'Awards': '4 wins & 3 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '17 Nov 2015',
#  'Director': 'Kyle Patrick Alvarez',
#  'Genre': 'Biography, Drama, History, Thriller',
#  'Language': 'English',
#  'Metascore': '67',
#  'Plot': 'In 1971, twenty-four male students are selected to take on randomly '
#          'assigned roles of prisoners and guards in a mock prison situated in '
#          'the basement of the Stanford psychology building.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTUyNDIyMTA4NV5BMl5BanBnXkFtZTgwODM2MDMxNjE@._V1_SX300.jpg',
#  'Production': 'IFC Films',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.9/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '84%'},
#              {'Source': 'Metacritic', 'Value': '67/100'}],
#  'Released': '17 Jul 2015',
#  'Response': 'True',
#  'Runtime': '122 min',
#  'Title': 'The Stanford Prison Experiment',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tim Talbott, Philip Zimbardo (based on the book "The Lucifer '
#            'Effect")',
#  'Year': '2015',
#  'imdbID': 'tt0420293',
#  'imdbRating': '6.9',
#  'imdbVotes': '33,985'}
# -------------------
# movie id tt6035344
# -------------------
# {'Actors': 'Tim Jacobson, Cora Mitre, Michelle Juliet Garrett, Wilfredo '
#            'Hidalgo',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Brigette Wagner',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Stars That Shine at Night',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Yesenia Ramirez',
#  'Year': '2015',
#  'imdbID': 'tt6035344',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3478772
# -------------------
# {'Actors': 'Dave Leon, Patrick Saxe, Danny Ward, Fred Anderson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'Sweden, USA',
#  'DVD': 'N/A',
#  'Director': 'Stephanie Ohlsson',
#  'Genre': 'Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Three friend\'s video documented holidays in Stockholm of "Party, '
#          'Drugs and Swedish Girls" get interrupted by a serial killer.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Jan 2015',
#  'Response': 'True',
#  'Runtime': '73 min',
#  'Title': 'The Stockholm Bloodbath',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dave Leon, Stephanie Ohlsson',
#  'Year': '2015',
#  'imdbID': 'tt3478772',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4161414
# -------------------
# {'Actors': 'Victor Cruz, April L. Hernandez, Luis Antonio Ramos, Liza '
#            'Colón-Zayas',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Victor Cruz',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Where dreams go on back order.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODQyNDM0Njg3NV5BMl5BanBnXkFtZTgwNzUwNDMzNzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '84 min',
#  'Title': 'The Stockroom',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Victor Cruz',
#  'Year': '2015',
#  'imdbID': 'tt4161414',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5341670
# -------------------
# {'Actors': 'Darin Branham, Devyn Damsen, Aslan Irizarry, Ej Irizarry',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Taylor J. Irizarry, Ej Irizarry',
#  'Genre': 'Adventure, Comedy, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjE3Mzc0MDE2OF5BMl5BanBnXkFtZTgwMzEzNTQ3NzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '9.8/10'}],
#  'Released': '25 Oct 2015',
#  'Response': 'True',
#  'Runtime': '55 min',
#  'Title': 'The Stones of Okella',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Sabri Irizarry (screenplay), Man e Kerr',
#  'Year': '2015',
#  'imdbID': 'tt5341670',
#  'imdbRating': '9.8',
#  'imdbVotes': '25'}
# -------------------
# movie id tt4669180
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The first step in looking for love, is right out the front door.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '104 min',
#  'Title': 'The Stoop',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joe Lemieux',
#  'Year': '2015',
#  'imdbID': 'tt4669180',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5117328
# -------------------
# {'Actors': 'Alicia Cortes, Robert J. Escandon, Cameron Rabie',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Robert J. Escandon',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Two private eyes trapped in a house they can't leave, hunted by a "
#          "mob they can't see, with a girl that can't make up her mind.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjA3NTEyNDY3Ml5BMl5BanBnXkFtZTgwNzQ2NDAyNzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '52 min',
#  'Title': 'The Stranded',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Robert J. Escandon',
#  'Year': '2015',
#  'imdbID': 'tt5117328',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4097336
# -------------------
# {'Actors': 'Kevin Jackson, Jennifer Prediger, Michole Briana White',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Nancy Andrews',
#  'Genre': 'Animation, Drama, Musical, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Dr. Sheri Myes survives the bombing of her home by protesters, but '
#          'is changed forever by this traumatic experience. Isolated by her '
#          'obsessions, she functions in a reality of her own ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTgxNzA1NjQxNV5BMl5BanBnXkFtZTgwMjc3NzM5NTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.9/10'}],
#  'Released': '21 Jan 2015',
#  'Response': 'True',
#  'Runtime': '76 min',
#  'Title': 'The Strange Eyes of Dr. Myes',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Nancy Andrews, Jennifer Reeder',
#  'Year': '2015',
#  'imdbID': 'tt4097336',
#  'imdbRating': '5.9',
#  'imdbVotes': '29'}
# -------------------
# movie id tt4094144
# -------------------
# {'Actors': 'Lisa Banes, Ashly Burch, Paul Chamberlain, Nancy Fong',
#  'Awards': '2 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '15 Dec 2015',
#  'Director': 'Kenny Riches',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': '39',
#  'Plot': 'The Strongest Man is a Miami-centric comedy about an anxiety-ridden '
#          'Cuban man, who fancies himself the strongest man in the world. In a '
#          'quest to recover his most beloved possession, a stolen bicycle, he '
#          'finds and loses so much more.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjMyNjI1MTQyOV5BMl5BanBnXkFtZTgwOTQwNjkwNDE@._V1_SX300.jpg',
#  'Production': 'FilmBuff',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '22%'},
#              {'Source': 'Metacritic', 'Value': '39/100'}],
#  'Released': '25 Jan 2015',
#  'Response': 'True',
#  'Runtime': '99 min',
#  'Title': 'The Strongest Man',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kenny Riches',
#  'Year': '2015',
#  'imdbID': 'tt4094144',
#  'imdbRating': '6.1',
#  'imdbVotes': '158'}
# -------------------
# movie id tt3217994
# -------------------
# {'Actors': 'Emilie de Ravin, Dylan Wittrock, Paul Eiding, Nancy Travis',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Eric Bilitch',
#  'Genre': 'Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Despite a returning Marine's mundane reality, his haunting wartime "
#          'past shepherds him into a magical and destructive new existence to '
#          'expose his ultimate truth.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjA5NDQ0MzI2OV5BMl5BanBnXkFtZTgwODQ4NDk2NzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Unrated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'}],
#  'Released': '12 Jan 2016',
#  'Response': 'True',
#  'Runtime': '109 min',
#  'Title': 'The Submarine Kid',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Eric Bilitch, Finn Wittrock',
#  'Year': '2015',
#  'imdbID': 'tt3217994',
#  'imdbRating': '5.8',
#  'imdbVotes': '738'}
# -------------------
# movie id tt4806856
# -------------------
# {'Actors': 'Derrick Andrews, Jude Baremore, Joshua Blackmon, Cloyse Caruthers',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Bj Lewis',
#  'Genre': 'Action',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When a fairly routine extraction mission goes belly up, Deadshot and '
#          'Harley Quinn must figure a way to salvage things before their heads '
#          'are literally blown off! (This non-profit fanfilm is not affiliated '
#          'or endorsed by DC Comics)',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '15 Dec 2015',
#  'Response': 'True',
#  'Runtime': '45 min',
#  'Title': 'The Suicide Squad: A Typical Tuesday',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Bj Lewis',
#  'Year': '2015',
#  'imdbID': 'tt4806856',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4459162
# -------------------
# {'Actors': 'Jason Bond, Marco Dapper, Martin Elias, Reynaldo Gallegos',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Charles Murray',
#  'Genre': 'Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A grieving widow summons her dead husband back from the grave with '
#          'disastrous results.',
#  'Poster': 'N/A',
#  'Production': 'Parkside Pictures',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'}],
#  'Released': '06 Jun 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Summoning',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Scott Mullen',
#  'Year': '2015',
#  'imdbID': 'tt4459162',
#  'imdbRating': '6.1',
#  'imdbVotes': '30'}
# -------------------
# movie id tt4651382
# -------------------
# {'Actors': 'Mao Gou Chen, Zhi Qing He',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'China, USA',
#  'DVD': 'N/A',
#  'Director': 'Heart Fensch',
#  'Genre': 'Animation, Adventure, Comedy',
#  'Language': 'Chinese',
#  'Metascore': 'N/A',
#  'Plot': 'The SUNSHINE KID is the story of a young man who tries to balance '
#          'the hard realities of his life with his feelings for the MATERIAL '
#          'GIRL and at the same time uphold traditional Confucian ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'The Sunshine Kid',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Heart Fensch',
#  'Year': '2015',
#  'imdbID': 'tt4651382',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3581788
# -------------------
# {'Actors': 'Harry Hains, Michael Redford Carney, Nicholas McDonald, Kyle '
#            'Patrick Darling',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '31 Aug 2015',
#  'Director': 'Michael J. Saul',
#  'Genre': 'Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The struggle of a young man to slowly create his own sense of '
#          'family.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjAxMTU0NTgzMl5BMl5BanBnXkFtZTgwMzk2MTk0NzE@._V1_SX300.jpg',
#  'Production': 'eOne',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.5/10'}],
#  'Released': '27 Jun 2015',
#  'Response': 'True',
#  'Runtime': '79 min',
#  'Title': 'The Surface',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael J. Saul',
#  'Year': '2015',
#  'imdbID': 'tt3581788',
#  'imdbRating': '5.5',
#  'imdbVotes': '162'}
# -------------------
# movie id tt5839202
# -------------------
# {'Actors': 'Jacob Kyle Young',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Langxi Ge',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '20 Apr 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Survivor',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Langxi Ge',
#  'Year': '2015',
#  'imdbID': 'tt5839202',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4649162
# -------------------
# {'Actors': 'Tyler Burke, Gary David Keast, Mark Laursen, Michael Rivers',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jordon Foss',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'JR, a young thief questioning his destination in life, chases the '
#          'dream of pulling off the big heist.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '27 Apr 2015',
#  'Response': 'True',
#  'Runtime': '50 min',
#  'Title': 'The Take',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tyler Burke, Jordon Foss, Jim LaRocco',
#  'Year': '2015',
#  'imdbID': 'tt4649162',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4285136
# -------------------
# {'Actors': 'Camille Grenier, Babak Mehrabi, Adela Holgado Fornés, April '
#            'Deutschle',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Babak Mehrabi',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A small party in San Francisco goes terribly wrong when an '
#          'unexpected guest shows up after a long disappearance. During the '
#          'party each characters secrets are revealed.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTU5MTc1ODYyN15BMl5BanBnXkFtZTgwOTYyMDMwNTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '60 min',
#  'Title': 'The Tale of Allen Grey',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Babak Mehrabi',
#  'Year': '2015',
#  'imdbID': 'tt4285136',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7070022
# -------------------
# {'Actors': 'Danny Bass, Jesse DiFranco, Jonathan Elihu Klein, John Kolar',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jonathan Elihu Klein',
#  'Genre': 'Action, Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Follows the story of a dishonest 20 year old boy named Anthony. '
#          'Anthony is given an opportunity in which he is able to portray '
#          'himself as a vigilante named "The Sparrow". Trouble befalls ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOWI1MjE2YjctZGY3OS00OTM5LTlhYzAtYzE0MGFiNmFmZTVlXkEyXkFqcGdeQXVyNzc3NTE5Nzg@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.6/10'}],
#  'Released': '15 Aug 2015',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'The Tale of the Sparrow',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jonathan Elihu Klein',
#  'Year': '2015',
#  'imdbID': 'tt7070022',
#  'imdbRating': '8.6',
#  'imdbVotes': '14'}
# -------------------
# movie id tt5168908
# -------------------
# {'Actors': 'Lamont Henderson, Athena Estrada, Mikey Rosales, Aisling Miller',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Lamont Henderson, Mikey Rosales',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'In a dangerous threshold of Nerdiness and Netflix, Six Teenagers who '
#          'have been deprived of friends, love and bullies, will band together '
#          'and Ditch School but when they are faced with ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '27 Nov 2015',
#  'Response': 'True',
#  'Runtime': '62 min',
#  'Title': 'The Teenage Six Chapter 1: Into the Fire',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Lamont Henderson (lead writer), Mikey Rosales (lead scripter)',
#  'Year': '2015',
#  'imdbID': 'tt5168908',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt1090693
# -------------------
# {'Actors': 'Wes Tank, Haley Chamberlain, Alex Barbatsis, Alisa Mattson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jason P. Schumacher',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The Telephone Game is an indie drama/ comedy about the chaos of '
#          'trying to put a play together and about a relationship that develops '
#          'amidst that chaos, between Marco the director, and ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDgxMjM0Mzg5Nl5BMl5BanBnXkFtZTcwMjYxNTQyNA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'}],
#  'Released': '01 Mar 2015',
#  'Response': 'True',
#  'Runtime': '93 min',
#  'Title': 'The Telephone Game',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jason P. Schumacher (story), Wes Tank (play)',
#  'Year': '2015',
#  'imdbID': 'tt1090693',
#  'imdbRating': '5.8',
#  'imdbVotes': '12'}
# -------------------
# movie id tt2069961
# -------------------
# {'Actors': 'Leilani Galvan, Russell Gustave Ochoa, Helena Stoddard, Diane '
#            'Perella',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'France, USA, United Arab Emirates, Spain, India',
#  'DVD': 'N/A',
#  'Director': 'Andrew Shapter',
#  'Genre': 'Crime, Mystery, Romance, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The story of the disappearance of Francis, a beautiful young bank '
#          'teller missing since her car was found submerged in a river in 1974. '
#          'She has become the subject of myth and legend, and the town and '
#          'townspeople have never been the same.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjE4MTg3MjMzOF5BMl5BanBnXkFtZTgwMDAzMzgyMTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.9/10'}],
#  'Released': '01 Nov 2015',
#  'Response': 'True',
#  'Runtime': '82 min',
#  'Title': 'The Teller and the Truth',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Patty Moynahan, Nevie Owens, Andrew Shapter, Andrew Shapter',
#  'Year': '2015',
#  'imdbID': 'tt2069961',
#  'imdbRating': '5.9',
#  'imdbVotes': '32'}
# -------------------
# movie id tt3105978
# -------------------
# {'Actors': 'Joel DeVisser, Chandler Darby, Emmy Argo, Allen Daniel',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Joel DeVisser',
#  'Genre': 'Action, Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A team of undercover police officers stumble upon a human '
#          'trafficking ring while investigating a case about a new illicit '
#          'drug.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Thin Line',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joel DeVisser',
#  'Year': '2015',
#  'imdbID': 'tt3105978',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2597668
# -------------------
# {'Actors': 'Elizabeth Williams Grayson, Edd Robinson, Doug Nydick, Neill '
#            'Fleeman',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Neill Fleeman',
#  'Genre': 'Drama, Musical, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Katie Gordon met Tom Nichols while playing in summer stock at the '
#          'Red Bridge Playhouse in Connecticut. Twelve years later, Katie, by '
#          'then a well-known actress, made her play for Tom. They ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc1NTAzMTUyNl5BMl5BanBnXkFtZTcwNTYxNDk5OA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '50 min',
#  'Title': 'The Third Act',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Neill Fleeman',
#  'Year': '2012',
#  'imdbID': 'tt2597668',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6645792
# -------------------
# {'Actors': 'Jim Miles, Jordan Linscombe, Nate Vogt, Tanner Vanbebber',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '11 Aug 2015',
#  'Director': 'Rob Stennett, Andrew Harmon(co-director)',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The Thorn is a visually dynamic and heart-stirring theatrical '
#          'portrayal of the life, death and resurrection of Jesus Christ. Not '
#          'your average Passion play, The Thorn combines martial arts, ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTU1NmYxNmUtOTc4OS00YmRlLThkZWMtZTMzNjI1N2E5ZmE2XkEyXkFqcGdeQXVyNzM3NzIyOTA@._V1_SX300.jpg',
#  'Production': 'Porch Swing Entertainment',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '92 min',
#  'Title': 'The Thorn',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'John Bolin, Andrew Harmon (additional material), Rob Stennett',
#  'Year': '2015',
#  'imdbID': 'tt6645792',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4247740
# -------------------
# {'Actors': 'Vanessa Elgrichi, Allan Goldberg, Jason Aaron Goldberg, Jill Klopp',
#  'Awards': '7 wins.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jason Aaron Goldberg',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The Dunn family struggles to regain their balance and composure '
#          'after the middle and only male child has been severely injured in '
#          'Iraq. The fog of war hits home in this touching and often humorous '
#          'portrait of perseverance.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjEyNzk4ODI4NF5BMl5BanBnXkFtZTgwMzMzMDIyNDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.8/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '88 min',
#  'Title': 'The Three Es',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jason Aaron Goldberg',
#  'Year': '2015',
#  'imdbID': 'tt4247740',
#  'imdbRating': '7.8',
#  'imdbVotes': '25'}
# -------------------
# movie id tt2836138
# -------------------
# {'Actors': 'Bryce Cone, Scot Purkeypile, Kiran Shah, Will Wreggelsworth',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Timothy Alan Richardson',
#  'Genre': 'Adventure, Comedy, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Bobo Buggins, a neurotic Throbbit, joins a throng of Dweebs led by '
#          'Randolf the Wizard to help them regain their technological treasures '
#          'trapped beneath Silicon Mountain and guarded by a mighty Drag Queen.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjMxNTExNzgzOV5BMl5BanBnXkFtZTgwNTU5OTc3NTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.7/10'}],
#  'Released': '24 Jul 2015',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': 'The Throbbit',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'David Boyer, Michael Kouroubetes, Timothy Alan Richardson',
#  'Year': '2015',
#  'imdbID': 'tt2836138',
#  'imdbRating': '7.7',
#  'imdbVotes': '30'}
# -------------------
# movie id tt4076980
# -------------------
# {'Actors': 'Peter Brooke, James Caan, Noel Clarke, Kevin Dillon',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tony Bui',
#  'Genre': 'Action, Comedy, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Notorious hacker Drew Reynolds is captured by the C.I.A. and given a '
#          'proposition, work for them, or spend the rest of his life in prison. '
#          'Agreeing on the condition that he can form his own ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDgyMzA0MDc1Nl5BMl5BanBnXkFtZTgwMTk4OTM2NzE@._V1_SX300.jpg',
#  'Production': 'Sony Pictures Entertainment',
#  'Rated': 'Unrated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.5/10'}],
#  'Released': '30 Jan 2015',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'The Throwaways',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Arlen Ross, Don Handfield',
#  'Year': '2015',
#  'imdbID': 'tt4076980',
#  'imdbRating': '4.5',
#  'imdbVotes': '1,113'}
# -------------------
# movie id tt3289376
# -------------------
# {'Actors': 'Damaris Cruz, Veronica Viruet Simpson, Diana Laura, Wil J. Jackson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Johnston Blakley, Damaris Cruz',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Ticket Box',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Damaris Cruz, Ivey Singer',
#  'Year': '2015',
#  'imdbID': 'tt3289376',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2215673
# -------------------
# {'Actors': 'James Ransone, Elisa Lasowski, Mark Caven, William Gaunt',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '06 Oct 2015',
#  'Director': "Anthony O'Brien",
#  'Genre': 'Action, Adventure, Drama, Western',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'In the wild west, two brothers embark on a journey to collect a '
#          'bounty in a desperate attempt to save their home: but what they find '
#          'along the way is more than they bargained for.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg5NjczMzA3Nl5BMl5BanBnXkFtZTgwODgyNjU1MzE@._V1_SX300.jpg',
#  'Production': 'Ana Media',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'}],
#  'Released': '27 Feb 2015',
#  'Response': 'True',
#  'Runtime': '81 min',
#  'Title': 'The Timber',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': "Steve Allrich, Anthony O'Brien, Colin Ossiander",
#  'Year': '2015',
#  'imdbID': 'tt2215673',
#  'imdbRating': '5.4',
#  'imdbVotes': '1,513'}
# -------------------
# movie id tt4239106
# -------------------
# {'Actors': 'Ekaterina Skurikhina, Klara Hascakova, Sam Adegoke, Julian de '
#            'Gainza',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'UK, USA',
#  'DVD': 'N/A',
#  'Director': 'Klara Hascakova',
#  'Genre': 'Drama',
#  'Language': 'French, Russian, Slovak, English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjI1ODA2MTYwNV5BMl5BanBnXkFtZTgwNDgwNTUwNTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Total Princess',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Klara Hascakova, Samira Larouci',
#  'Year': '2015',
#  'imdbID': 'tt4239106',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4842840
# -------------------
# {'Actors': 'Josh Ayala, Monty Cole, Kate Elias, Austin Mansfield',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Dylan Blount, Jacob Goldberg',
#  'Genre': 'Adventure, Comedy, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Sandy Qule just couldn't get it right. Thony can't tell what's right "
#          "or wrong. Dusty's Lioness has gnawed through the bars. Calhoun "
#          "Cormiconne's growing hair in odd places. Grady O. Grady's...",
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '197 min',
#  'Title': 'The Townie',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dylan Blount, Jacob Goldberg',
#  'Year': '2015',
#  'imdbID': 'tt4842840',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3775918
# -------------------
# {'Actors': 'Bre Blair, Clarence Gilyard Jr., Sam Trammell, Mike Doyle',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Brett Levner',
#  'Genre': 'Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When a woman from the suburbs crosses paths with a sexually '
#          'exploited teenage girl working the streets of Las Vegas, the two '
#          'strike up an unlikely friendship which blossoms into a '
#          'mother-daughter relationship that saves both their lives.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTczNTA2MzYzM15BMl5BanBnXkFtZTgwMjI2MDIxMzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'The Track',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Matthew J. McCue',
#  'Year': '2015',
#  'imdbID': 'tt3775918',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3652766
# -------------------
# {'Actors': 'Göktug Alpasar, Aysen Batigün, Yusuf Bütünley, Arda Armando Denk',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ersen Denk',
#  'Genre': 'Drama, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A family moves into a house where some terrible things happened 70 '
#          "years ago. When they find out about the happenings, it's already too "
#          'late.. because there is NO WAY BACK..',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZDc4MGM0OWEtOTkxZC00ZTZkLWIxNjEtNzI4ZjIzNDY5OTA0XkEyXkFqcGdeQXVyNjUxNTI5MDU@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.2/10'}],
#  'Released': '13 Feb 2015',
#  'Response': 'True',
#  'Runtime': '103 min',
#  'Title': 'The Tragedy',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ersen Denk',
#  'Year': '2015',
#  'imdbID': 'tt3652766',
#  'imdbRating': '5.2',
#  'imdbVotes': '108'}
# -------------------
# movie id tt4459758
# -------------------
# {'Actors': 'Jeff Blim, Rachael Soglin, Jaime Lyn Beatty, Lauren Lopez',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Nick Lang',
#  'Genre': 'Comedy, Musical, Western',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Join our All-American family as they journey down the The Trail to '
#          'Oregon! The Trail to Oregon is an original musical produced by '
#          'Starkid Productions and was performed in Chicago in the ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BY2RjNjQ0Y2UtYjc5Ny00NzNiLTgxODEtNDViNTQwNTJjNWQxXkEyXkFqcGdeQXVyNjU4MTU3MzI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.4/10'}],
#  'Released': '14 Feb 2015',
#  'Response': 'True',
#  'Runtime': '120 min',
#  'Title': 'The Trail to Oregon!',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jeff Blim (book), Nick Lang (book), Matt Lang (book), Brian Holden '
#            '(additional writing)',
#  'Year': '2015',
#  'imdbID': 'tt4459758',
#  'imdbRating': '8.4',
#  'imdbVotes': '89'}
# -------------------
# movie id tt3059880
# -------------------
# {'Actors': 'Jeremy Anderson, Maurice Antonio, Sarah Avery, Rodney Billings',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Alison Mills Newman',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The Bible talks about older women teaching younger women....so how '
#          'about an older widow trully devoted to God and struggling to resist '
#          'lonliness,and mourning,and wanting to live life,and be...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.0/10'}],
#  'Released': '16 Dec 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Tree Widow',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Alison Mills Newman',
#  'Year': '2015',
#  'imdbID': 'tt3059880',
#  'imdbRating': '8.0',
#  'imdbVotes': '5'}
# -------------------
# movie id tt2159690
# -------------------
# {'Actors': 'John F. Carroll, Bridget Farias, Andrew Brett, David McCullars',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'John F. Carroll',
#  'Genre': 'Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjAyNTY3OTEwMl5BMl5BanBnXkFtZTcwMjgzMjQ4Nw@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.1/10'}],
#  'Released': '12 Sep 2015',
#  'Response': 'True',
#  'Runtime': '75 min',
#  'Title': 'The Trials of Darksmoke',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'John F. Carroll',
#  'Year': '2015',
#  'imdbID': 'tt2159690',
#  'imdbRating': '3.1',
#  'imdbVotes': '7'}
# -------------------
# movie id tt5642732
# -------------------
# {'Actors': 'David Baker, Elizabeth Ford, Gernard Tavel',
#  'Awards': 'N/A',
#  'BoxOffice': '$1,580,106',
#  'Country': 'USA',
#  'DVD': '02 Feb 2016',
#  'Director': 'Norman Alston',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Two individuals from different economical and social backgrounds '
#          'must figure out what they have in common to survive a threat that '
#          'have placed them in the woods.',
#  'Poster': 'N/A',
#  'Production': 'Sony Pictures',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Rotten Tomatoes', 'Value': '62%'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '76 min',
#  'Title': 'The Truth',
#  'Type': 'movie',
#  'Website': 'http://sonyclassics.com/truth/',
#  'Writer': 'Norman Alston (story), Norman Alston',
#  'Year': '2015',
#  'imdbID': 'tt5642732',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2604642
# -------------------
# {'Actors': 'Robert Miano, Jennifer Day, Natalie Alexander, Ilia Yordanov',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jeff Hathcock',
#  'Genre': 'Crime, Drama, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A young woman awakes on a casting directors couch next to a lifeless '
#          'body with no recollection of the events that transpired the evening '
#          'before. This classic Film Noir tale set in modern ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc2MTM3ODM2Nl5BMl5BanBnXkFtZTcwNzgyOTI5OA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.5/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '91 min',
#  'Title': 'The Two Pamelas',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jeff Hathcock',
#  'Year': '2015',
#  'imdbID': 'tt2604642',
#  'imdbRating': '8.5',
#  'imdbVotes': '131'}
# -------------------
# movie id tt4384148
# -------------------
# {'Actors': 'Dee Flowered, Lucy Plenty',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Andrew N. Shearer',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A pair of mad doctors conduct a "sexperiment" on the viewer by '
#          'showing a series of bizarre movies featuring lesbian zombies and '
#          'video vixens.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ5OTAyNzIxNF5BMl5BanBnXkFtZTgwODIwMzY3NDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'TV-MA',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.0/10'}],
#  'Released': '05 Jan 2015',
#  'Response': 'True',
#  'Runtime': '104 min',
#  'Title': 'The Underground Sinema',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dee Flowered, Andrew N. Shearer',
#  'Year': '2015',
#  'imdbID': 'tt4384148',
#  'imdbRating': '2.0',
#  'imdbVotes': '5'}
# -------------------
# movie id tt4096810
# -------------------
# {'Actors': 'Riley Yeary, Angelina Masciopinto, Kaleb Miller, Scott Novotny',
#  'Awards': '2 wins.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tristan James Jensen',
#  'Genre': 'Adventure, Drama, Mystery',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A girl moves with her father to Stillwater, Minnesota for the '
#          'summer. She meets two misfit kids and together they seek to give a '
#          'ghost closure as something dark festers between the lines.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZGNlMDJiZTAtODc4MC00ZTVjLTk0ZTEtY2Y1Nzk3ZWFmMjhjXkEyXkFqcGdeQXVyMzMzMzczMDY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.6/10'}],
#  'Released': '10 Apr 2015',
#  'Response': 'True',
#  'Runtime': '60 min',
#  'Title': 'The Unearthing',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tristan James Jensen (story), Tristan James Jensen',
#  'Year': '2015',
#  'imdbID': 'tt4096810',
#  'imdbRating': '7.6',
#  'imdbVotes': '444'}
# -------------------
# movie id tt4936428
# -------------------
# {'Actors': 'Khrys Styles, Chris Hoffman, Yosiah Johnson, Yolanda Crutchfield',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Antoine Baptiste, Terri L. Bea Sopher',
#  'Genre': 'Crime, Drama, Mystery',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "A notable business man's daughter is found dead in their home. A "
#          'homicide detective has the difficult task of sorting through three '
#          'female suspects only to discover that the victim is terrifying them.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '07 Jul 2015',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'The Unfortunate Faces of Portia Dupree',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Terri L. Bea Sopher',
#  'Year': '2015',
#  'imdbID': 'tt4936428',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3628704
# -------------------
# {'Actors': 'Tony Moran, Lloyd Kaufman, Debbie Rochon, Arthur Hiou',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, UK',
#  'DVD': 'N/A',
#  'Director': 'Paul M McAlarney',
#  'Genre': 'Action, Adventure, Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNWM5NTgyMzUtYmY3Ny00Zjc2LWI4ZGYtMWRmZGMxZGY5MzNkXkEyXkFqcGdeQXVyMzY0MzE3Nzc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'}],
#  'Released': '01 Jan 2015',
#  'Response': 'True',
#  'Runtime': '101 min',
#  'Title': 'The Ungovernable Force',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Paul M McAlarney',
#  'Year': '2015',
#  'imdbID': 'tt3628704',
#  'imdbRating': '6.5',
#  'imdbVotes': '15'}
# -------------------
# movie id tt4945490
# -------------------
# {'Actors': 'Joseph Piccuirro, Edmicelly Pena, Adam DeCarlo, Kristen Lynn '
#            'Raccone',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Brian Ruppert',
#  'Genre': 'Comedy, Drama, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "A recently jilted millennial's friends throw him a going away party. "
#          'After his sassy ex-girlfriend shows up, the group of friends find '
#          'themsleves in a struggle for their very lives.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '73 min',
#  'Title': 'The Uninvited Guest',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Brian Ruppert',
#  'Year': '2015',
#  'imdbID': 'tt4945490',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5726656
# -------------------
# {'Actors': 'Tina Gilton, Alani Simone, Barbara Bowman, Jasmine Charmaine',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTQxMjk3MDgtZTFmYS00M2ZjLTgyYWUtZmQzOTg1OGRmMGU1XkEyXkFqcGdeQXVyNTc0NDc2NDg@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '02 Mar 2015',
#  'Response': 'True',
#  'Runtime': '61 min',
#  'Title': 'The Unnamed',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Elva NelsonHayes',
#  'Year': '2015',
#  'imdbID': 'tt5726656',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4076916
# -------------------
# {'Actors': 'Zack Gold, Jason Tobias, Bennett Viso, Bob Turton',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'Denmark, USA',
#  'DVD': 'N/A',
#  'Director': 'Thomas Jakobsen',
#  'Genre': 'Drama, Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
# ...
#  'imdbID': 'tt2974902',
#  'imdbRating': '5.5',
#  'imdbVotes': '97'}
# -------------------
# movie id tt4007328
# -------------------
# {'Actors': 'Pirooz Kalayeh, Brad Warner, Hannah Pierce, Charles Currier',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Pirooz Kalayeh',
#  'Genre': 'Action, Comedy, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A struggling film company documents the onset of a zombie outbreak '
#          'to gets hits and pays their rent.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQyMjY2OTI4M15BMl5BanBnXkFtZTgwMzQ4ODk3MjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '71 min',
#  'Title': 'Zombie Bounty Hunter M.D.',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Pirooz Kalayeh',
#  'Year': '2014',
#  'imdbID': 'tt4007328',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3598130
# -------------------
# {'Actors': 'Matthew Cheney, Alan Gilman, Reggie Provencher, Carly Becker',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '29 Sep 2015',
#  'Director': 'Jamie Sharps',
#  'Genre': 'Action, Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Directed by Independent filmmaker Jamie Sharps(Tucker's Crossing), "
#          'this thrill a minute action/comedy simultaneously pokes fun at the '
#          'zombie genre and pays homage to the spaghetti western ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZmJiMWIyMGMtZDU4NC00OWE3LWFhMmYtODlkYzVmYTBlYzUwXkEyXkFqcGdeQXVyMTM2NTMyNTY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.9/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '78 min',
#  'Title': 'Zombie Boy',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jamie Sharps',
#  'Year': '2015',
#  'imdbID': 'tt3598130',
#  'imdbRating': '5.9',
#  'imdbVotes': '41'}
# -------------------
# movie id tt4218250
# -------------------
# {'Actors': "Bransen Sands Koehler, Benni Harper, Janae' Werner, Estevan Muñoz",
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Montetré',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An effeminate fan of vintage science fiction action thrillers '
#          'discovers a story in which Martian Cats land on Earth and inflict '
#          'horror upon the town. He sets off on his own superhero mission to '
#          'save the town.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjE1ODE4NzQ0MF5BMl5BanBnXkFtZTgwMDE5NjY5NTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'NOT RATED',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.5/10'}],
#  'Released': '01 May 2015',
#  'Response': 'True',
#  'Runtime': '97 min',
#  'Title': 'Zombie Cats from Mars',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ryan Cloutier',
#  'Year': '2015',
#  'imdbID': 'tt4218250',
#  'imdbRating': '3.5',
#  'imdbVotes': '86'}
# -------------------
# movie id tt4949418
# -------------------
# {'Actors': 'Jerry Cappy, Karim Elkholy, Johnathan Maldonado, Matthew E. '
#            'Maldonado',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Marvin Suarez',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': '8 months prior to the Zombie Pandemic, a family is stalked by a '
#          'demonic presence which influences them to do things out of their '
#          'character. We soon realize that this demonic influence the creation '
#          'of the Zombie pandemic.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODIyOTAwODY1MV5BMl5BanBnXkFtZTgwMzUwNzM2NjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'}],
#  'Released': '31 Oct 2015',
#  'Response': 'True',
#  'Runtime': '50 min',
#  'Title': 'The Case Files',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Marvin Suarez',
#  'Year': '2015',
#  'imdbID': 'tt4949418',
#  'imdbRating': '7.0',
#  'imdbVotes': '8'}
# -------------------
# movie id tt4991308
# -------------------
# {'Actors': 'Michelle Ammons, Natalie Curfman, Patrick Dailey, Madeline '
#            'DeCourcey',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jera Sky, Brandon Weaver',
#  'Genre': 'Comedy, Crime, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A zombie paired up with a human on SWAT investigate a domestic '
#          'disturbance where one wife is threatening to cut off the other '
#          "wife's boob for cheating.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc4MTcwMTM2NV5BMl5BanBnXkFtZTgwOTAyOTU2NzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '59 min',
#  'Title': 'Zombie Cop',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michelle Ammons, Natalie Curfman, Patrick Dailey, Madeline '
#            'DeCourcey, Jera Sky (story), Jera Sky, Brandon Weaver (story), '
#            'Brandon Weaver',
#  'Year': '2015',
#  'imdbID': 'tt4991308',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3247924
# -------------------
# {'Actors': 'Cindy Olson Angland, Barbara Berosik, Amber Nicole Buus, Heather '
#            'Captain Dahlquist',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Creep Creepersin, Ries Dahlquist',
#  'Genre': 'Comedy, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "A group of friends are walled up in they're own house during a "
#          'zombie apocalypse. Low on weaponry, the team must bond together, and '
#          'escape the house for any help they can get.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk4NzU1MDc2NV5BMl5BanBnXkFtZTgwMjc0OTI5NDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.3/10'}],
#  'Released': '19 Mar 2015',
#  'Response': 'True',
#  'Runtime': '55 min',
#  'Title': 'Zombie Dollz',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Creep Creepersin, Ries Dahlquist',
#  'Year': '2015',
#  'imdbID': 'tt3247924',
#  'imdbRating': '3.3',
#  'imdbVotes': '20'}
# -------------------
# movie id tt2099797
# -------------------
# {'Actors': 'Manuel Abberra, Kevin Bean, Brian J. Cano, Phat Man Dee',
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Blair Murphy',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Actor Eric Roberts stops an interview to recount a horrific '
#          "nightmare he'd experienced earlier in the day. We enter the "
#          'nightmare.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk4NDU2MDAzMF5BMl5BanBnXkFtZTcwNjI5NDE2OA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.0/10'}],
#  'Released': '01 Oct 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Zombie Dream',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Blair Murphy',
#  'Year': '2015',
#  'imdbID': 'tt2099797',
#  'imdbRating': '3.0',
#  'imdbVotes': '27'}
# -------------------
# movie id tt2908090
# -------------------
# {'Actors': 'Billy Zane, Dee Wallace, Mischa Barton, Felissa Rose',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '03 Feb 2015',
#  'Director': 'B. Harrison Smith',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A young militia is all that stands between a coming dead horde and '
#          'their rural town decimated by the fracking industry.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ1NTY0ODI1M15BMl5BanBnXkFtZTgwNDY4OTA4MzE@._V1_SX300.jpg',
#  'Production': 'Class of 85',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.8/10'}],
#  'Released': '11 Feb 2016',
#  'Response': 'True',
#  'Runtime': '104 min',
#  'Title': "ZK: Elephant's Graveyard",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'David Agnew Penn (original story), B. Harrison Smith (original '
#            'story), B. Harrison Smith (screenplay)',
#  'Year': '2015',
#  'imdbID': 'tt2908090',
#  'imdbRating': '2.8',
#  'imdbVotes': '394'}
# -------------------
# movie id tt5002524
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Mark Burman',
#  'Genre': 'Horror, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '30 Dec 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Zombie Safari',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2015',
#  'imdbID': 'tt5002524',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3108954
# -------------------
# {'Actors': 'Cheyenne Adamson, Danielle Ackerman, Christian Ackerman, Scott '
#            'Ranf',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Christian Ackerman',
#  'Genre': 'Action, Horror, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A new type of radio waves are causing the dead to rise.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNWZhMmVmYjctMGI1ZC00MjAxLTg3YTItN2RhNjAwYzg0ZDdiL2ltYWdlXkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.4/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '60 min',
#  'Title': 'Zombies of the Living Dead',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Christian Ackerman (story), Christian Ackerman',
#  'Year': '2015',
#  'imdbID': 'tt3108954',
#  'imdbRating': '2.4',
#  'imdbVotes': '20'}
# -------------------
# movie id tt3717324
# -------------------
# {'Actors': 'Bill Oberst Jr., Kevin Allen-Bicknell, José María Angorrilla, Roy '
#            'Aralios',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jesse Baget, Adrián Cardona, Rafa Dengrá, Luke Guidici, Phil '
#              'Haine, Peter Horn, Jared Marshall, Cameron McCulloch, David '
#              "Muñoz, Adam O'Brien, Zachary Ramelan, Paul Shrimpton, Vedran "
#              'Marjanovic Wekster, Tommy Woodard',
#  'Genre': 'Comedy, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'There is nowhere to hide...nowhere to run...the Zombie Apocalypse '
#          'has come, and our world now belongs to the dead! From Ireland, '
#          'Canada, Australia, Europe and all over the U.S., the ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjIyMTk2MTYxNV5BMl5BanBnXkFtZTgwMDA2Mzc4MzE@._V1_SX300.jpg',
#  'Production': 'Ruthless Pictures',
#  'Rated': 'Unrated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.4/10'}],
#  'Released': '26 Dec 2017',
#  'Response': 'True',
#  'Runtime': '100 min',
#  'Title': 'Zombieworld',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Stefania Moscato (segment), Peter Horn (segment), Jared Marshall '
#            '(segment), David Muñoz (by), Adrián Cardona (by), Vedran '
#            'Marjanovic Wekster (by), Jonathan Brown (segment), Tommy Woodard '
#            '(segment), Cameron McCulloch (segment), Zachary Ramelan (segment), '
#            'Raven Cousens (segment), Paul Shrimpton (segment), Graham Taylor '
#            '(segment), Alex Chandon (segment), Luke Guidici (segment), Adam '
#            "O'Brien (segment), David Muñoz, José María Angorrilla (story), Eva "
#            'Ayats (story), Adrián Cardona (story), Rafa Dengrá (story), David '
#            'Muñoz (story)',
#  'Year': '2015',
#  'imdbID': 'tt3717324',
#  'imdbRating': '3.4',
#  'imdbVotes': '788'}
# -------------------
# movie id tt3400150
# -------------------
# {'Actors': 'Gene Rush, Cisco Davis Jr., Soni Aralynn, Lyon Beckwith',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Cisco Davis Jr.',
#  'Genre': 'Action',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'How Zordon became what he is and how he obtained the power coins as '
#          'well as hidden secrets that have changed the lives of humanity '
#          'forever.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjMxMDcwOTI3NF5BMl5BanBnXkFtZTgwODk2NjQyNTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'}],
#  'Released': '01 Jun 2015',
#  'Response': 'True',
#  'Runtime': '50 min',
#  'Title': 'Zordon of Eltar',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Cisco Davis Jr.',
#  'Year': '2015',
#  'imdbID': 'tt3400150',
#  'imdbRating': '7.0',
#  'imdbVotes': '70'}
# -------------------
# movie id tt4276050
# -------------------
# {'Actors': 'Max Reiner, Alex Green, Lynne Morrow',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Michele Gold',
#  'Genre': 'Drama, Fantasy, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'angel in the waiting room: Filmed with a vibrant, multicultural, '
#          'talented cast of charming animals and compassionate animal lovers in '
#          'sun drenched Sonoma County in 21 days, without a crew ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'angel in the waiting room',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michele Gold (story), Michele Gold',
#  'Year': '2015',
#  'imdbID': 'tt4276050',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3868518
# -------------------
# {'Actors': 'Christopher Barnes, Hector Dez, Elizabeth Elise Gonzalez, Angel '
#            'Hererra',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ruben Trejo',
#  'Genre': 'Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'While helping the CIA to develop a deadly computer virus, a computer '
#          'engineer finds himself as the target of an assassination.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzk2MzgxMzcwNV5BMl5BanBnXkFtZTgwMjc5NzUyNDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '15 Apr 2015',
#  'Response': 'True',
#  'Runtime': '57 min',
#  'Title': 'e-Virus',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ruben Trejo',
#  'Year': '2015',
#  'imdbID': 'tt3868518',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2949196
# -------------------
# {'Actors': 'Jeremiah Watkins, Sarah Power, Christopher Mena, Elaine Partnow',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '11 Aug 2015',
#  'Director': 'Franck Khalfoun',
#  'Genre': 'Horror, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "A young online app reviewer's latest assignment mysteriously "
#          'improves his life, but also starts to tear him apart.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZmVjM2VjYWQtNTFjNC00NzYzLWJmOTMtMmQ3MmM2ODc3NWM0L2ltYWdlXkEyXkFqcGdeQXVyNzIzMTc2Mw@@._V1_SX300.jpg',
#  'Production': 'Xlrator Media',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.5/10'}],
#  'Released': '03 Jul 2015',
#  'Response': 'True',
#  'Runtime': '97 min',
#  'Title': 'I Lived',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Franck Khalfoun, Franck Khalfoun (idea), Brian Breiter (idea)',
#  'Year': '2015',
#  'imdbID': 'tt2949196',
#  'imdbRating': '4.5',
#  'imdbVotes': '721'}
# -------------------
# movie id tt4932592
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Jan 2015',
#  'Response': 'True',
#  'Runtime': '48 min',
#  'Title': 'modular maniacs',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2015',
#  'imdbID': 'tt4932592',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}

# %%
len(title_list)
# Out:
# 401

# %%
len(title_id)
# Out:
# 401

# %%
# if title_list and title_id are the same length run the cell below. 
# if they are not equal take out 'title_id': title_id

# %%
df = pd.DataFrame({'title_id': title_id, 'title': title_list, 'box_office': box_office_list, 'country': country_list, 
                   'genre': genre_list, 'director': director_list, 'metascore': metascore_list, 'production': production_list, 
                   'rating': rating_list, 'IMDB_rating': IMDB_rating_list, 'rotten_tomatoes_rating': rotten_tomatoes_rating_list, 
                  'runtime': runtime_list, 'type': type_list, 'IMDB_votes': imdb_votes_list})

# %%
df = df.drop_duplicates()
df.head()
# Out:
#     title_id                                     title box_office  \
# 0  tt4181400                     The Sparrows: Nesting        N/A
# 1  tt3675676        The Spectacular Jihad of Taz Rahim        N/A
# 2  tt3266322              The Sphere and the Labyrinth        N/A
# 3  tt2279373  The SpongeBob Movie: Sponge Out of Water        N/A
# 4  tt1238846                      The Square Root of 2        N/A
#
#                        country                                          genre  \
# 0                          USA                                  Drama, Family
# 1                   USA, India                           Comedy, Crime, Drama
# 2                          USA                                          Drama
# 3  USA, South Korea, Australia  Animation, Adventure, Comedy, Family, Fantasy
# 4                          USA                                          Drama
#
#                            director metascore          production     rating  \
# 0         Nancy Criss, Josh Hodgins       N/A                 N/A  Not Rated
# 1                     Raghav Murali       N/A        Ziryab Films        N/A
# 2           Michael Robertson Moore       N/A                 N/A        N/A
# 3       Paul Tibbitt, Mike Mitchell        62  Paramount Pictures         PG
# 4  Harold Reitman, Bernard Salzmann       N/A                 N/A         PG
#
#   IMDB_rating rotten_tomatoes_rating  runtime   type IMDB_votes
# 0         5.3                     NA   92 min  movie         90
# 1         6.9                     NA  128 min  movie         11
# 2         N/A                     NA   85 min  movie        N/A
# 3         6.0                    81%   92 min  movie     45,235
# 4         7.0                     NA   90 min  movie          6

# %%
df.count()
# Out:
# title_id                  401
# title                     401
# box_office                401
# country                   401
# genre                     401
# director                  401
# metascore                 401
# production                401
# rating                    401
# IMDB_rating               401
# rotten_tomatoes_rating    401
# runtime                   401
# type                      401
# IMDB_votes                401
# dtype: int64

# %%
df.to_csv('../data/2015_data_batch_4.csv', index=False)
