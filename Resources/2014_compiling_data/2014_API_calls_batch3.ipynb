# %%
import pandas as pd
import requests
import json
import time
from pprint import pprint
from config import API_KEY

# %%
data = pd.read_csv('../data/titles_2014_batch3.csv')
df =  data.count()
df
# Out:
# title    1000
# dtype: int64

# %%
title_id = []
box_office_list = []
country_list = []
genre_list = []
director_list = []
metascore_list = []
production_list = []
rating_list = []
IMDB_rating_list = [] 
rotten_tomatoes_rating_list = []
runtime_list = []
title_list = []
type_list = []
imdb_votes_list = []

# %%
movies = data['title']
total_movies = len(movies)

# %%
for i in range(total_movies):
    movie = movies[i]
    url = "http://www.omdbapi.com/?i=" + movie + "&apikey=" + API_KEY
    response = (requests.get(url).text)
    response_json = json.loads(response)
    print('-------------------')
    print(f'movie id {movie}')
    print('-------------------')
    pprint(response_json)
    
    try:
        box_office_list.append(response_json['BoxOffice'])
        country_list.append(response_json['Country'])
        genre_list.append(response_json['Genre'])
        director_list.append(response_json['Director'])
        metascore_list.append(response_json['Metascore'])
        production_list.append(response_json['Production'])
        rating_list.append(response_json['Rated'])
        IMDB_rating_list.append(response_json['imdbRating'])
        try:
            if not response_json['Ratings']:
                rotten_tomatoes_rating_list.append('NA')
            elif response_json['Ratings'][0]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][0]['Value'])
            elif response_json['Ratings'][1]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][1]['Value'])
            else:
                rotten_tomatoes_rating_list.append('NA')
        except IndexError:
            rotten_tomatoes_rating_list.append('NA')
        runtime_list.append(response_json['Runtime'])
        title_list.append(response_json['Title'])
        type_list.append(response_json['Type'])
        imdb_votes_list.append(response_json['imdbVotes'])
        title_id.append(response_json['imdbID'])
    except (JSONDecodeError, KeyError):
        pass
    time.sleep(1)
# Out:
# -------------------
# movie id tt3562494
# -------------------
# {'Actors': 'Bill Gobin, Lexie Gobin, Lilly Gobin, Oto Gomes',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Stephen Stix Josey',
#  'Genre': 'Action',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '11 Nov 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Primal Instinct',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Bill Gobin, Stephen Stix Josey',
#  'Year': '2014',
#  'imdbID': 'tt3562494',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3861432
# -------------------
# {'Actors': 'Megan Abbana, Sabrina Alanis, Savannah Alanis, Andiana '
#            'Anderl-Wiggins',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ian Wallace',
#  'Genre': 'Comedy, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Princess Daisy is a coming of age story about Daisy, a young woman '
#          'who grew up in Davis, California and then moved to New York to '
#          'pursue an acting career. When Daisy gets into financial ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjIwOTAxNzE2OV5BMl5BanBnXkFtZTgwMDk0MTQzMjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.6/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '92 min',
#  'Title': 'Princess Daisy',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jennifer Provenza',
#  'Year': '2014',
#  'imdbID': 'tt3861432',
#  'imdbRating': '2.6',
#  'imdbVotes': '5'}
# -------------------
# movie id tt3591752
# -------------------
# {'Actors': 'McKoy Musser, Ilie Sturhan, Lance Barnett, Sharmita Bhattacharya',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kennedy J. Baruch',
#  'Genre': 'Drama, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Princess in Another Castle is a feature film, set in 1996, about a '
#          'lonely eight year old girl, Danni, whose grades continue to slip as '
#          'she copes with life in a broken home by escaping into ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Princess in Another Castle',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kennedy J. Baruch',
#  'Year': '2014',
#  'imdbID': 'tt3591752',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3103412
# -------------------
# {'Actors': 'Hal Ozsan, Nicholle Tom, Tom Sizemore, Judd Nelson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '02 Jun 2015',
#  'Director': 'LazRael Lison',
#  'Genre': 'Horror, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A series of cryptic phone messages and visions haunt a writer while '
#          'he struggles to finish a novel. As they increase in intensity, he '
#          'loses his grip on reality, eventually obsessing over an...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjA3NjU3MjU4MF5BMl5BanBnXkFtZTgwMjY4OTYzNTE@._V1_SX300.jpg',
#  'Production': 'Arc Entertainment',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.7/10'}],
#  'Released': '01 May 2015',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': 'Private Number',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'LazRael Lison',
#  'Year': '2014',
#  'imdbID': 'tt3103412',
#  'imdbRating': '4.7',
#  'imdbVotes': '926'}
# -------------------
# movie id tt2240046
# -------------------
# {'Actors': 'Roddy Piper, Jim Duggan, Matt Hardy, Reby Sky',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Cody Knotts',
#  'Genre': 'Action, Comedy, Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Famous Wrestlers are pitted against hordes of undead when they '
#          'unknowingly walk into a death trap.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk5MzI0MjU4NV5BMl5BanBnXkFtZTcwNDkwMjE0OQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.6/10'}],
#  'Released': '28 Mar 2014',
#  'Response': 'True',
#  'Runtime': '88 min',
#  'Title': 'Pro Wrestlers vs Zombies',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Cody Knotts',
#  'Year': '2014',
#  'imdbID': 'tt2240046',
#  'imdbRating': '3.6',
#  'imdbVotes': '405'}
# -------------------
# movie id tt3717684
# -------------------
# {'Actors': 'Michael Artis, Ralph Bowsher IV, Tenesia Crook, Mark A. Cummings',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Joy Millana',
#  'Genre': 'Crime, Drama, Mystery',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Four Independent filmmakers venture to a small country town for a '
#          'film festival and a promising meeting with a movie executive when '
#          'they are tossed in jail for a heinous crime, but no one remembers '
#          'the events from that night.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc5NTMxMjQ0Ml5BMl5BanBnXkFtZTgwNjQ3NTc2NTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'}],
#  'Released': '21 Jun 2014',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': 'Profiled',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Mark A. Cummings',
#  'Year': '2014',
#  'imdbID': 'tt3717684',
#  'imdbRating': '6.5',
#  'imdbVotes': '15'}
# -------------------
# movie id tt2570812
# -------------------
# {'Actors': 'Theo Allyn, Molly Alphabet, John Amplas, Abe Anderson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Gab Cody(co-director), Sam Turich(co-director)',
#  'Genre': 'Comedy, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A zany trio of urbanite couples fumble through love and heartbreak '
#          'on the night of the annual Lawrenceville progressive dinner in and '
#          'around the hipster-est neighborhood in Pittsburgh.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc0NTQ4NjQ4Ml5BMl5BanBnXkFtZTcwODg0NDM5OA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.6/10'}],
#  'Released': '09 Jul 2014',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': 'Progression',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Gab Cody, Sam Turich',
#  'Year': '2014',
#  'imdbID': 'tt2570812',
#  'imdbRating': '8.6',
#  'imdbVotes': '33'}
# -------------------
# movie id tt3396022
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ryan Edward Shuler',
#  'Genre': 'Action, Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Project AvC',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ryan Edward Shuler',
#  'Year': '2014',
#  'imdbID': 'tt3396022',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4017972
# -------------------
# {'Actors': 'Bianca Coca, Katherine Cordes, Sean Coyle, Rory Eggleston',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'London Homer-Wambeam',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An introverted AI software designer falls in love with a girl '
#          'claiming to be a robot running his software.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '12 Sep 2014',
#  'Response': 'True',
#  'Runtime': '93 min',
#  'Title': 'Project Cora',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'London Homer-Wambeam, London Homer-Wambeam',
#  'Year': '2014',
#  'imdbID': 'tt4017972',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2641066
# -------------------
# {'Actors': 'David Rosen, Trent Fewkes, Tommie Vegas, Jason Morciglio',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Alex Colonna, Chad Clinton Freeman',
#  'Genre': 'Biography, Comedy, Crime, Horror, Music',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Go behind the scenes of the infamous duo MC Randumb & Jewish Dave '
#          'for the most controversial rapumentary ever made. A look at '
#          "America's lust for violence and fame.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMWU4YzQ2ZGMtOWY3Ni00YWY5LTg0ZDktM2ZlOGIwNWQ1ODg1XkEyXkFqcGdeQXVyMjM1MjEwODU@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.6/10'}],
#  'Released': '08 Nov 2014',
#  'Response': 'True',
#  'Runtime': '70 min',
#  'Title': 'Project M',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Alex Colonna, Chad Clinton Freeman, David Rosen',
#  'Year': '2014',
#  'imdbID': 'tt2641066',
#  'imdbRating': '5.6',
#  'imdbVotes': '29'}
# -------------------
# movie id tt3725382
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'N/A',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Jun 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Project SuperHuman',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2014',
#  'imdbID': 'tt3725382',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3478160
# -------------------
# {'Actors': 'Austin Bellach, Jenifer Coté, Judith Gray, Dylan Hardaway',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Miles Levin',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A feature length film, made entirely by high school students, '
#          'Project: User is the story of Adam, a teen math prodigy, who '
#          'grapples with an abusive father, and an eccentric best friend, ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'}],
#  'Released': '26 Jul 2014',
#  'Response': 'True',
#  'Runtime': '73 min',
#  'Title': 'Project: User',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Miles Levin (story), Miles Levin',
#  'Year': '2014',
#  'imdbID': 'tt3478160',
#  'imdbRating': '7.0',
#  'imdbVotes': '8'}
# -------------------
# movie id tt3422314
# -------------------
# {'Actors': 'Pantelis Kodogiannis, Kassandra Voyagis, Giancarlo Giannini, Paul '
#            'Freeman',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Greece, UK',
#  'DVD': 'N/A',
#  'Director': 'Coerte Voorhees, John Voorhees',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Two Athenian attorneys pursue litigation for the return of the '
#          'Parthenon Marbles. As the bronze statue of Athena Promakhos used to '
#          'stand guard in front of the Parthenon, both must find the courage to '
#          'stand in defense of what they love.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BM2VhY2M5ZTItYmVmNi00YmRkLTg4ZGYtYTc4ZTQxYWY4Njk5XkEyXkFqcGdeQXVyNDcyNTM3NzI@._V1_SX300.jpg',
#  'Production': 'FilmBoy Pictures',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'}],
#  'Released': '20 Sep 2016',
#  'Response': 'True',
#  'Runtime': '91 min',
#  'Title': 'The First Line',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Coerte Voorhees, John Voorhees',
#  'Year': '2014',
#  'imdbID': 'tt3422314',
#  'imdbRating': '5.4',
#  'imdbVotes': '183'}
# -------------------
# movie id tt3499966
# -------------------
# {'Actors': 'Ia Villatuya, Michelle Laurent, Nicole Maxali, Roberto Divina',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '22 Jul 2014',
#  'Director': 'Ron Santiano',
#  'Genre': 'Action, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Eve's life is forever altered when her parents vanish without a "
#          'trace after being attacked by supernatural agents. Growing up on the '
#          'streets, Eve learns the art of self reliance. When s ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODdhNjhlZTgtMzhiMy00MTVjLWEyMTgtMjdhMzQ4NmRmZGE2XkEyXkFqcGdeQXVyMjEyNzk3MjE@._V1_SX300.jpg',
#  'Production': 'MVD Entertainment Group',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.4/10'}],
#  'Released': '22 Jul 2014',
#  'Response': 'True',
#  'Runtime': '77 min',
#  'Title': 'Prophecy of Eve',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2014',
#  'imdbID': 'tt3499966',
#  'imdbRating': '3.4',
#  'imdbVotes': '28'}
# -------------------
# movie id tt3479564
# -------------------
# {'Actors': 'April Hollingsworth, Shayla Love, Nic Wolfe, Davien Harlis',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Deronte Smith',
#  'Genre': 'Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The rumored daughter of Sarah Good, the first witch to be tried and '
#          'hung during the Salem Witch trials, lives and commands the spirit '
#          'world at her fingertips. Irene, as she is known, must ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzg5OTkzNzAwNV5BMl5BanBnXkFtZTgwMDEyNjUwMTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.7/10'}],
#  'Released': '03 Mar 2014',
#  'Response': 'True',
#  'Runtime': '93 min',
#  'Title': 'Prosper',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Deronte Smith',
#  'Year': '2014',
#  'imdbID': 'tt3479564',
#  'imdbRating': '8.7',
#  'imdbVotes': '909'}
# -------------------
# movie id tt3529986
# -------------------
# {'Actors': 'Sami Allison, Blakeley Burger, Ryan Case, Natalie Cummins',
#  'Awards': '4 wins & 1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Bulgaria',
#  'DVD': 'N/A',
#  'Director': 'Thomas Southerland',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'After winning second place in a play writing contest, Bulgarian '
#          'Krasimira Stanimirova travels to the rolling hills of Kentucky for '
#          "the premiere of her dark, Communist-era autobiographical play 'Black "
#          "Coat.'",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTgyNzg2Nzg0MV5BMl5BanBnXkFtZTgwMjYxMzk3MTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.9/10'}],
#  'Released': '27 Jul 2014',
#  'Response': 'True',
#  'Runtime': '89 min',
#  'Title': 'Proud Citizen',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Thomas Southerland, Thomas Southerland (story), Katerina '
#            'Stoykova-Klemer, Katerina Stoykova-Klemer (story)',
#  'Year': '2014',
#  'imdbID': 'tt3529986',
#  'imdbRating': '7.9',
#  'imdbVotes': '16'}
# -------------------
# movie id tt4191112
# -------------------
# {'Actors': 'Matthew Saulnier, Guyviaud Joseph, Michael Lasry, Morgan Vasquez',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Daniel Saulnier',
#  'Genre': 'Crime, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Tim Kilburn returns to his hometown, The Highlands, after eight '
#          'years to find the town in turmoil. An old arch-rival, Spike, has '
#          'turned the town upside down with his gang and wrecked ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': 'Proving Ground',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Daniel Saulnier',
#  'Year': '2014',
#  'imdbID': 'tt4191112',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3997542
# -------------------
# {'Actors': 'Rachid Sow, Larry Bernal, Kashif Sheikh, Omar Scanu',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Farrukh Sheikh',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A tale finally put all together, as we watch 3 acts and 3 different '
#          "people's lives affected by real durgs and fake drugs created by the "
#          'devil and government to destroy the poulation and bring hell to '
#          'earth at last.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTJiNWEwODEtYTNhMi00NzkyLWFlOTEtMDNkYTAzMGIzNWNiXkEyXkFqcGdeQXVyNTc3NTc4NzM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '31 Oct 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Pseudoie',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Farrukh Sheikh, Kashif Sheikh',
#  'Year': '2014',
#  'imdbID': 'tt3997542',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3195788
# -------------------
# {'Actors': 'Claude Reid, Elena Chernyakova',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Claude Reid',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "When Michael, Jennifer's Jealous roommate is able to convince her "
#          'that her boyfriend is cheating on her she makes her first kill and '
#          'they go on a killing rampage.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '31 Dec 2014',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Psychotic',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Claude Reid',
#  'Year': '2014',
#  'imdbID': 'tt3195788',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2677336
# -------------------
# {'Actors': 'Derek Young, Adam Ginsberg, John Rutland, Denise Greenfield',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, UK, Canada',
#  'DVD': 'N/A',
#  'Director': 'Derek Young',
#  'Genre': 'Drama, Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'David Coleman spends his whole life looking to fit in. He is '
#          'constantly bullied and screwed over by his so called friends. He '
#          'finally has the family he had always wanted when his foster mom...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.5/10'}],
#  'Released': '01 Mar 2014',
#  'Response': 'True',
#  'Runtime': '126 min',
#  'Title': 'Psychotic State',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'William Pattison (book), William Pattison, Derek Young (story), '
#            'Derek Young, Derek Young',
#  'Year': '2014',
#  'imdbID': 'tt2677336',
#  'imdbRating': '5.5',
#  'imdbVotes': '21'}
# -------------------
# movie id tt3578506
# -------------------
# {'Actors': 'Hal Schneider, Jenny Keto, Brooke Marie Friesen, Dashiell Smith',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Daniel Doggett, Stewart Doggett',
#  'Genre': 'Drama, Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A family vacations at a cabin in the woods only to be terrorized by '
#          'a band of masked psychopaths.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.5/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '76 min',
#  'Title': 'Psympatico',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Daniel Doggett, Daniel Doggett (story), Stewart Doggett, Stewart '
#            'Doggett (story)',
#  'Year': '2014',
#  'imdbID': 'tt3578506',
#  'imdbRating': '3.5',
#  'imdbVotes': '12'}
# -------------------
# movie id tt2982658
# -------------------
# {'Actors': 'Catherine Chen, Sumiko Braun, Lee Broda, J.P. Giuliotti',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Chi Chi Yang',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Pu Pu Platter is a fun slapstick comedy,full of love,laughter and '
#          'bitterness. It tells the story of Two very different individuals '
#          'that come together and forced to face reality, while realizing love '
#          "sometimes isn't enough.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjA0MjkwMDgxN15BMl5BanBnXkFtZTgwNzMxMDU5MTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Pu Pu Platter',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'James Egan, Chi Chi Yang',
#  'Year': '2015',
#  'imdbID': 'tt2982658',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4273284
# -------------------
# {'Actors': 'Ryan Alshon, Don Benavidez, Stephan Garcia, Pete Quintana',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'John Quintana',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '25 Jun 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Pueblo Colorado: What is Home',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': "Kaitlyn O'Day, John Quintana",
#  'Year': '2014',
#  'imdbID': 'tt4273284',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3562112
# -------------------
# {'Actors': 'Saintanor S. Camilus, Adeline Julceus, Hubermann Saintil, Régine '
#            'Philippe',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Saintanor S. Camilus',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Puissance De La Foi (The Power of Faith): story of a young-married '
#          'couple, husband Oscar faces terminal cancer disease and given only 3 '
#          "months to live. With his life at stakes, family's worries; will "
#          'Oscar faith in God save him?',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '29 Mar 2014',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Puissance De La Foi',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Saintanor S. Camilus, Rodly Madeus',
#  'Year': '2014',
#  'imdbID': 'tt3562112',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3458316
# -------------------
# {'Actors': 'Kayode Akinbayo, Genesis Alana, Tembi Anoh, Keith Birtwell',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Matt Lillard',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Mike is a Nigerian living in diaspora and trying to keep his head '
#          'above water. As fate would have it, he loses his job and this is '
#          'only the beginning as far as his stream of bad luck goes. ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '23 Jan 2014',
#  'Response': 'True',
#  'Runtime': '84 min',
#  'Title': 'Punch Rolla',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Akin Durosimi',
#  'Year': '2014',
#  'imdbID': 'tt3458316',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2431032
# -------------------
# {'Actors': 'Raleigh Jackson Jones, James V. Roy, Valeriy Garkalin, Art Hall',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Moshe Khusid',
#  'Genre': 'Animation, Drama, Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "'Purim: The Lot' tells the dramatic story of the Jewish rebellion "
#          'against Persian persecution as described in the Old Testament Book '
#          'of Esther. Led by Esther, the Jewish queen of Persia, ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjMwMTExMjA4NF5BMl5BanBnXkFtZTgwMzE1NDA5NTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.3/10'}],
#  'Released': '01 Oct 2014',
#  'Response': 'True',
#  'Runtime': '65 min',
#  'Title': 'Purim: The Lot',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Alexander Khusid, Moshe Khusid (story), Moshe Khusid',
#  'Year': '2014',
#  'imdbID': 'tt2431032',
#  'imdbRating': '7.3',
#  'imdbVotes': '11'}
# -------------------
# movie id tt3687402
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Pyg',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2014',
#  'imdbID': 'tt3687402',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5194848
# -------------------
# {'Actors': 'Andrew L. McClain, Spencer McClain, Aliina Gibby, Hadlei Beck',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Andrew L. McClain',
#  'Genre': 'Action',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Shortly after Ace Queens' assassination, David Anderson has gone "
#          "missing. While in his absence, Chalkface's army enters Alpinoma and "
#          'takes control of it. The citizens of Alpinoma go through...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Mar 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Q.L.U.E: The Forgotten Man Part Two',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Peter Kemp, Andrew L. McClain, Spencer McClain',
#  'Year': '2014',
#  'imdbID': 'tt5194848',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3263758
# -------------------
# {'Actors': "Carrie Gemmell, David Goodfellow, Shauna Henry, Kevin 'ohGr' "
#            'Ogilvie',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Chris Alexander',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Vampire Irina is reborn as a "vampiric" plague, a force of nature '
#          'whose destiny is to lay waste to a fever dream vision of the Wild '
#          'West.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ2MzM1MDE5N15BMl5BanBnXkFtZTgwNTAxMDgyMTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.4/10'}],
#  'Released': '04 Apr 2014',
#  'Response': 'True',
#  'Runtime': '78 min',
#  'Title': 'Queen of Blood',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Chris Alexander',
#  'Year': '2014',
#  'imdbID': 'tt3263758',
#  'imdbRating': '4.4',
#  'imdbVotes': '55'}
# -------------------
# movie id tt5676142
# -------------------
# {'Actors': 'Loren Lott, Jade Benson, Jamal Fuller, Devonte Hammond',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Christopher Kendrick',
#  'Genre': 'Crime, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Tina is in trouble after committing a deceitful act. She asks her '
#          'friend Neicy for help. Neicy agrees to help her friend get enough '
#          'money to pay off her debt. Neicy meets Lee at a bar and ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzgwNTlkNTctODBmZi00YTFmLWI1OTQtNTAzMTkyMTViMzI3XkEyXkFqcGdeQXVyNDk1MDY1ODA@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '06 Aug 2017',
#  'Response': 'True',
#  'Runtime': '45 min',
#  'Title': 'Quick Trip',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Christopher Kendrick',
#  'Year': '2014',
#  'imdbID': 'tt5676142',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3959574
# -------------------
# {'Actors': 'Rebecca Morris, Bryan Marshall, Lauren Fortuna, Caleb Burress',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Paul Schattel',
#  'Genre': 'Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When a recently divorced woman returns to the Appalachian mountains '
#          'of her youth, she learns that her brilliant but troubled brother is '
#          'implicated in an act of radical Eco-terrorism. As her...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODE3Nzk3MTM2OV5BMl5BanBnXkFtZTgwMTI5NTU3NDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '93 min',
#  'Title': 'Quiet River',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Rebecca Morris (story), Paul Schattel (story), Paul Schattel',
#  'Year': '2014',
#  'imdbID': 'tt3959574',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4020142
# -------------------
# {'Actors': 'Justin Bryant Rapp, Sam Valentine, Ken Calkins',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kevin Kisling',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Lost in the woods after a roadside breakdown, Colin and June slowly '
#          'lose sight of their old lives and revert to a more primal state of '
#          'living. Their idyll is disrupted, however, when an older man '
#          'stumbles into their life.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '21 Jul 2014',
#  'Response': 'True',
#  'Runtime': '88 min',
#  'Title': 'Quivera',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'J.R. Frazier, Kevin Kisling',
#  'Year': '2014',
#  'imdbID': 'tt4020142',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4073086
# -------------------
# {'Actors': 'Shae Ashe, Joshua Basilla, Stephanie Berardi, Kara Bu',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'Musical',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Sep 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Radio Disney Philadelphia',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2014',
#  'imdbID': 'tt4073086',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2412568
# -------------------
# {'Actors': 'Michael Koch, David Leo Schultz, Mel Fair, Carson Aune',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '07 Jul 2014',
#  'Director': 'David Leo Schultz',
#  'Genre': 'Biography, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Based on the life of Rich Mullins, a musical prodigy who rose to '
#          'Christian music fame and fortune only to walk away and live on a '
#          'Navajo reservation. An artistic genius, raised on a tree ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTYzNjg2MTAzM15BMl5BanBnXkFtZTgwNDEyODc3MTE@._V1_SX300.jpg',
#  'Production': 'Millenium Entertainment',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.7/10'}],
#  'Released': '09 Jan 2014',
#  'Response': 'True',
#  'Runtime': '137 min',
#  'Title': 'Ragamuffin',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'David Holechek (additional story), Dave Mullins (story '
#            'consultant), Ashleigh Philips (screenplay), David Leo Schultz '
#            '(screenplay), David Leo Schultz (story)',
#  'Year': '2014',
#  'imdbID': 'tt2412568',
#  'imdbRating': '6.7',
#  'imdbVotes': '1,039'}
# -------------------
# movie id tt3042540
# -------------------
# {'Actors': 'Lauren Baldwin, Jessica Bassuk, Tony Cicchetti, Chelsea Cook',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Mark Pirro',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Some teens will go to great lengths to avoid being disturbed. For '
#          'Raven, being disturbed comes naturally.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '22 Dec 2014',
#  'Response': 'True',
#  'Runtime': '104 min',
#  'Title': 'Rage of Innocence',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Mark Pirro',
#  'Year': '2014',
#  'imdbID': 'tt3042540',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3187718
# -------------------
# {'Actors': 'Gita Adhikari, Basanta Bhatta, Cait Brasel, Rocken Byanjankar',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, India',
#  'DVD': 'N/A',
#  'Director': 'Bhupendra Bhattarai',
#  'Genre': 'Drama',
#  'Language': 'English, Nepali, Hindi',
#  'Metascore': 'N/A',
#  'Plot': 'After his long-time girlfriend dumps him and marries some other guy, '
#          'Raghav finds himself compelled to move on and start a new '
#          'relationship.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTgyMTk5NjI5N15BMl5BanBnXkFtZTgwNzgyMDkyMDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.4/10'}],
#  'Released': '30 Jun 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Raghav',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Bhupendra Bhattarai, Shibir Pokharel, Prabin Chandra Subedi',
#  'Year': '2014',
#  'imdbID': 'tt3187718',
#  'imdbRating': '7.4',
#  'imdbVotes': '22'}
# -------------------
# movie id tt2350852
# -------------------
# {'Actors': 'Monty Geer, Leore Hayon, Michael Hudson, Hassan Mahmoud',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '28 Mar 2017',
#  'Director': 'Mitchell Altieri',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When a group of friends come across an abandoned house in the barren '
#          'desert, what follows is a terrifying tale of evil possession causing '
#          'the friends to slowly turn against each other.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzE2MzAxOTM2M15BMl5BanBnXkFtZTgwNjE2OTkyMTE@._V1_SX300.jpg',
#  'Production': 'Helios Productions',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.8/10'}],
#  'Released': '18 Aug 2014',
#  'Response': 'True',
#  'Runtime': '76 min',
#  'Title': 'Raised by Wolves',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Mitchell Altieri (story), Mitchell Altieri, Phil Flores, Cory '
#            'Knauf',
#  'Year': '2014',
#  'imdbID': 'tt2350852',
#  'imdbRating': '3.8',
#  'imdbVotes': '290'}
# -------------------
# movie id tt3373496
# -------------------
# {'Actors': 'Alexander Randazzo, Rebecca Nelsen, Alec Morrisette, Aaron Henry',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Cheryl Berner, Alexander Randazzo',
#  'Genre': 'Action, Adventure, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A boy learns of his dragon past; a girl has known of hers for years. '
#          'They combine their faith, courage, and love to overcome an evil '
#          'slayer who seeks to bring an end to dragon heritage, forever.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTUzNzM3NjY3N15BMl5BanBnXkFtZTgwNDYxNDcxMzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'}],
#  'Released': '20 Jun 2014',
#  'Response': 'True',
#  'Runtime': '119 min',
#  'Title': 'Raising Dragons',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Bryan Davis, Blake Deuser, Alexander Randazzo, Shannan Randazzo',
#  'Year': '2014',
#  'imdbID': 'tt3373496',
#  'imdbRating': '6.6',
#  'imdbVotes': '8'}
# -------------------
# movie id tt4120186
# -------------------
# {'Actors': 'Jose Calvo, Jonathan Eckmann, Jack Flake, Mark Flake',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Mark Flake',
#  'Genre': 'Horror, Western',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '13 Sep 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Rancho Mysterio',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Mark Flake',
#  'Year': '2014',
#  'imdbID': 'tt4120186',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3331986
# -------------------
# {'Actors': 'Elise Neal, Wood Harris, Eric Lane, Devin Wesley',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Parris Reaves',
#  'Genre': 'Crime',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A distraught and loving Wife must make a life or death decision '
#          'after discovering that her real estate mogul Husband has been '
#          'kidnapped by a group of ruthless street thugs. Instead of ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '25 Jun 2014',
#  'Response': 'True',
#  'Runtime': '89 min',
#  'Title': 'Ransum Games',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'William Pierce, Devin Wesley',
#  'Year': '2014',
#  'imdbID': 'tt3331986',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2077828
# -------------------
# {'Actors': 'Blair Besten, Jacqueline Buda, Dagmar Edwards, Janet Lopez',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Richard Lowry',
#  'Genre': 'Action, Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When an apocalyptic event strikes, a group of people caught on the '
#          'outside of civilization must take a perilous journey to find refuge.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTkzODcwOTA0N15BMl5BanBnXkFtZTcwMDcwNDk5Ng@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.2/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': 'Rapture',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Richard Lowry',
#  'Year': '2014',
#  'imdbID': 'tt2077828',
#  'imdbRating': '5.2',
#  'imdbVotes': '53'}
# -------------------
# movie id tt2558700
# -------------------
# {'Actors': 'Karl Pidhajny, Jules Sceiro',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Robert Manrique',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An insomnia plagued loner becomes increasingly obsessed with an '
#          'elusive rat that he believes has invaded his home.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTEzMTYyODEwNTdeQTJeQWpwZ15BbWU3MDEwMDg3ODg@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.1/10'}],
#  'Released': '06 Jun 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Rat Catching',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Robert Manrique',
#  'Year': '2014',
#  'imdbID': 'tt2558700',
#  'imdbRating': '5.1',
#  'imdbVotes': '10'}
# -------------------
# movie id tt2097315
# -------------------
# {'Actors': 'Kristen Martha Brown, Brad Goodman, David Cascadden, Ron Sorci',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'David Eblen',
#  'Genre': 'Drama, Horror, Mystery',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Something evil has come to Portland Oregon. Bodies, horribly '
#          'mutilated, are being discovered around town. It is near midnight '
#          'when Eden Sullivan is drawn out of bed, lured by a siren call ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTU0Nzc0NDUyMl5BMl5BanBnXkFtZTcwMzgyNTY3Nw@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.2/10'}],
#  'Released': '01 Aug 2014',
#  'Response': 'True',
#  'Runtime': '109 min',
#  'Title': "Ravana's Game",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'David Eblen, David L. Eblen',
#  'Year': '2014',
#  'imdbID': 'tt2097315',
#  'imdbRating': '5.2',
#  'imdbVotes': '5'}
# -------------------
# movie id tt3173562
# -------------------
# {'Actors': 'Jim Duggan, Mike Walker, Mark Colombo, Ashley Nicole Deem',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Mark Colombo',
#  'Genre': 'Action, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Luke and Greta are siblings that were raised in the hills of West '
#          'Virginia. Being pulled in opposite directions, Luke a retired police '
#          'officer dedicating his life to serving his community, ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg3NTI4MDIyM15BMl5BanBnXkFtZTgwNzQwNzkwMTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.7/10'}],
#  'Released': '18 Oct 2014',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': 'ReZistance',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Carey Clevenger, Jaime Colombo, Mark Colombo, Renee Lear',
#  'Year': '2014',
#  'imdbID': 'tt3173562',
#  'imdbRating': '6.7',
#  'imdbVotes': '18'}
# -------------------
# movie id tt0959306
# -------------------
# {'Actors': 'Lauren Cohan, Kyra Sedgwick, Thomas Jane, Kevin Connolly',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '30 Dec 2014',
#  'Director': 'John Herzfeld',
#  'Genre': 'Comedy, Crime, Drama',
#  'Language': 'English',
#  'Metascore': '21',
#  'Plot': 'A self-help book changes the lives of different people in the LA '
#          'area. Who is the reclusive writer?',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTU4ODEwMjAzOF5BMl5BanBnXkFtZTgwMjk4ODY3MjE@._V1_SX300.jpg',
#  'Production': 'Millennium Entertainment',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.9/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '4%'},
#              {'Source': 'Metacritic', 'Value': '21/100'}],
#  'Released': '21 Nov 2014',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': 'Reach Me',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'John Herzfeld',
#  'Year': '2014',
#  'imdbID': 'tt0959306',
#  'imdbRating': '4.9',
#  'imdbVotes': '2,383'}
# -------------------
# movie id tt1290475
# -------------------
# {'Actors': 'Pablo Santiago, Jacob Martinez, John Azpilicueta, Bless May',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'John Azpilicueta',
#  'Genre': 'Crime, Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'After a violent bank robbery, the trio of hoods make their way '
#          'across East L.A. carrying a blood-soaked bag of money. When word '
#          'gets out, they must fend off gangs and crooked cops alike as they '
#          'strive to keep the loot and stay alive.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQzMDU5OTkzM15BMl5BanBnXkFtZTgwMjg2NTgwMTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'TV-14',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.4/10'}],
#  'Released': '18 Mar 2014',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'Ready 2 Die',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'John Azpilicueta, Ted Grau',
#  'Year': '2014',
#  'imdbID': 'tt1290475',
#  'imdbRating': '4.4',
#  'imdbVotes': '793'}
# -------------------
# movie id tt3389144
# -------------------
# {'Actors': 'Joanna Going, Laraine Newman, Emily Tarver, Cody Lindquist',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Michael Kuell',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "When Zoe turns down Jack's marriage proposal in front of friends and "
#          'family, their relationship falters, they break up and Jack moves '
#          "out. But now that they're free and single, why are they...",
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '96 min',
#  'Title': 'Ready or Knot',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jennifer Cobb, Michael Kuell',
#  'Year': '2013',
#  'imdbID': 'tt3389144',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2245172
# -------------------
# {'Actors': 'Hunter Smit, Keila Hamilton, Melissa Jobe, Ilona Kulinska',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '02 Oct 2014',
#  'Director': 'Keith Hartman',
#  'Genre': 'Adventure, Comedy, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A group of B-string superheroes go on a reality show in hopes of '
#          'hitting the big time.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTUyNDc2NzAyNF5BMl5BanBnXkFtZTgwODg1Mzk1MDE@._V1_SX300.jpg',
#  'Production': 'Waltzing Penguins',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'}],
#  'Released': '07 Nov 2014',
#  'Response': 'True',
#  'Runtime': '84 min',
#  'Title': 'Real Heroes',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Keith Hartman',
#  'Year': '2014',
#  'imdbID': 'tt2245172',
#  'imdbRating': '6.3',
#  'imdbVotes': '12'}
# -------------------
# movie id tt2107764
# -------------------
# {'Actors': 'Tytus Bergstrom, Li Wen Ang, David Weise, Joanna Siekierska',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tytus Bergstrom',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A shy nerd, Bergie Barnsworth, wants to audition for the new realty '
#          'TV show, Chance Of Your Life, in hopes of dancing with the Asian pop '
#          'star, Lolli Pop. With little talent, and a painfully...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ3NjExODUxM15BMl5BanBnXkFtZTgwMTE3Nzc2MjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.2/10'}],
#  'Released': '13 Nov 2014',
#  'Response': 'True',
#  'Runtime': '89 min',
#  'Title': 'Reality TV Movie',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tytus Bergstrom (screenplay), Tytus Bergstrom, Daniel Will-Harris',
#  'Year': '2014',
#  'imdbID': 'tt2107764',
#  'imdbRating': '7.2',
#  'imdbVotes': '25'}
# -------------------
# movie id tt2859862
# -------------------
# {'Actors': 'Corey Klinefelter, Elizabeth Saint, Johnna Leary, Brittney Hawley',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Brian Larrimore',
#  'Genre': 'Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A wrongfully accused fugitive is chosen by the Angel of Death to '
#          'become a Grim Reaper.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjA4MTc0NTI2OF5BMl5BanBnXkFtZTcwMzM5Mjk0OQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '14 May 2014',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'Reaper',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Brian Larrimore',
#  'Year': '2014',
#  'imdbID': 'tt2859862',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3081268
# -------------------
# {'Actors': 'Danny Trejo, Vinnie Jones, Jake Busey, Shayla Beesley',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Wen-Han Shih',
#  'Genre': 'Crime, Horror, Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Criminals and a beautiful but cunning hitchhiker battle a '
#          'supernatural force known as the Reaper.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTY0NzQxNzUzN15BMl5BanBnXkFtZTgwNzU2NjI2OTE@._V1_SX300.jpg',
#  'Production': 'Helios Productions',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.0/10'}],
#  'Released': '06 Jun 2015',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Reaper',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Mark James, James Jurdi',
#  'Year': '2014',
#  'imdbID': 'tt3081268',
#  'imdbRating': '5.0',
#  'imdbVotes': '2,828'}
# -------------------
# movie id tt3359594
# -------------------
# {'Actors': "Heather Brittain O'Scanlon, Edward Crawford, Cole Johnston, "
#            'Jonathan Marc Lipp',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jonathan Marc Lipp',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ5MTc3MTc3MV5BMl5BanBnXkFtZTgwOTI1MTYxMzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Oct 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Rearview Mirrors',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jonathan Marc Lipp',
#  'Year': '2014',
#  'imdbID': 'tt3359594',
# ...
#  'Director': 'Ron Petronicolos',
#  'Genre': 'Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Rook Crenshaw is a man with a gift. Blessed with the uncanny ability '
#          'to heal others, he and his friend Christian are drifters living a '
#          'life of wandering solitude. That life comes to a ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTkwNTc4Nzc1MF5BMl5BanBnXkFtZTcwMDc1OTM0OA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.4/10'}],
#  'Released': '30 Dec 2014',
#  'Response': 'True',
#  'Runtime': '81 min',
#  'Title': 'The Miracle Man',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dave Michael Beaudrie (story), Dave Michael Beaudrie',
#  'Year': '2014',
#  'imdbID': 'tt2364722',
#  'imdbRating': '7.4',
#  'imdbVotes': '16'}
# -------------------
# movie id tt3710424
# -------------------
# {'Actors': 'Tom Badal, Michael Drayer, Masayuki Imai, Brittani Noel',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Donald Spottingsworth',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Miracle Man',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Donald Spottingsworth',
#  'Year': '2014',
#  'imdbID': 'tt3710424',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7764590
# -------------------
# {'Actors': 'David Hesseltine, Christina Slocum, Zack Gold, Dave Reimer',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Darren Knapp',
#  'Genre': 'Mystery',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When Emily (Christina Slocum) goes missing in a rural town, Zack '
#          '(Zack Gold) enlists the help of Detective Lark (David Hesseltine) to '
#          'track her down. But the mystery soon deepens and takes stranger '
#          'turns than anyone involved has ever seen.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '09 Feb 2014',
#  'Response': 'True',
#  'Runtime': '51 min',
#  'Title': 'The Missing',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Darren Knapp, James Miller',
#  'Year': '2014',
#  'imdbID': 'tt7764590',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3391692
# -------------------
# {'Actors': 'Deb Kirkby, Greg Steele, Mike Vamos, Pauline Nowakowski',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Randall Wagner, Evie Neal(co-director)',
#  'Genre': 'Comedy, Fantasy, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "A curious father makes a wish on a cursed monkey's paw only to "
#          'suffer the consequences at the expense of his family.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTU1NzMwMTgwMF5BMl5BanBnXkFtZTgwNzQ0MjMwNDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'}],
#  'Released': '07 Nov 2014',
#  'Response': 'True',
#  'Runtime': '45 min',
#  'Title': "The Monkey's Paw",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Evie Neal, Randall Wagner (story), Randall Wagner',
#  'Year': '2014',
#  'imdbID': 'tt3391692',
#  'imdbRating': '6.1',
#  'imdbVotes': '9'}
# -------------------
# movie id tt2177771
# -------------------
# {'Actors': 'George Clooney, Matt Damon, Bill Murray, Cate Blanchett',
#  'Awards': '3 wins & 3 nominations.',
#  'BoxOffice': '$67,239,378',
#  'Country': 'USA, Germany',
#  'DVD': '20 May 2014',
#  'Director': 'George Clooney',
#  'Genre': 'Comedy, Drama, History, War',
#  'Language': 'English, German, Russian, French, Flemish, Dutch',
#  'Metascore': '52',
#  'Plot': 'An unlikely World War II platoon is tasked to rescue art '
#          'masterpieces from Nazi thieves and return them to their owners.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjMxMjk4NTM1M15BMl5BanBnXkFtZTgwNjg0MjQ3MDE@._V1_SX300.jpg',
#  'Production': 'Sony Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '31%'},
#              {'Source': 'Metacritic', 'Value': '52/100'}],
#  'Released': '07 Feb 2014',
#  'Response': 'True',
#  'Runtime': '118 min',
#  'Title': 'The Monuments Men',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'George Clooney (screenplay), Grant Heslov (screenplay), Robert M. '
#            'Edsel (book), Bret Witter (book)',
#  'Year': '2014',
#  'imdbID': 'tt2177771',
#  'imdbRating': '6.1',
#  'imdbVotes': '119,491'}
# -------------------
# movie id tt3079150
# -------------------
# {'Actors': 'Kevin Atkins, Don Bowie, Merida Childress, Chantell Christopher',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Cetre Pegues',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A happy family finally has a chance to take a long awaited vacation. '
#          'Tragedy strikes changing three lives forever.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Jul 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Morning After',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jacqueline Posey-Hilton',
#  'Year': '2014',
#  'imdbID': 'tt3079150',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2308606
# -------------------
# {'Actors': 'Nicholas Brendon, Catherine Taber, April Bogenschutz, Tiffany '
#            'Shepis',
#  'Awards': '6 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '20 Jan 2015',
#  'Director': 'Chris Ethridge',
#  'Genre': 'Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When a body is found in the woods outside the quiet town of '
#          'Morningside, NJ, Sheriff Tom Haulk and Deputy Klara Austin embark on '
#          'a desperate race against time to catch the killer, pitting them '
#          'against friends, enemies and even each other.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTUwMTYxMjU2OF5BMl5BanBnXkFtZTgwMjA0MDIwMzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.6/10'}],
#  'Released': '14 Jan 2014',
#  'Response': 'True',
#  'Runtime': '93 min',
#  'Title': 'Attack of the Morningside Monster',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Stacey Palmer',
#  'Year': '2014',
#  'imdbID': 'tt2308606',
#  'imdbRating': '4.6',
#  'imdbVotes': '176'}
# -------------------
# movie id tt2270718
# -------------------
# {'Actors': 'Chelsea Bryan, Joe Fredo, Eric Gebhardt, Isabella Handley',
#  'Awards': '3 wins.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'R. Todd Campbell',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Two runaway sisters find themselves lost in a notorious wilderness, '
#          'known as a place where people come to end their own lives. Here they '
#          'must contend with nature, with man, and with their own naivety about '
#          'the world.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYTRlZGZkMDktNjdlNC00ZGMzLWJkMWQtNTg5Y2U3ZmE0OTBiXkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.2/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '81 min',
#  'Title': 'The Mourning Hills',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'R. Todd Campbell, R. Todd Campbell',
#  'Year': '2014',
#  'imdbID': 'tt2270718',
#  'imdbRating': '7.2',
#  'imdbVotes': '12'}
# -------------------
# movie id tt3957726
# -------------------
# {'Actors': 'Ben Heath, Sebastian Pihan, Alex Lonati, Marissa Lenti',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ben Heath',
#  'Genre': 'Comedy, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Three friends attempt to make a horror movie together, and '
#          'complications arise when they find themselves within a horror movie.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '100 min',
#  'Title': 'The Mouth',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Brian Cowe, Ben Heath (story), Gabe Nelson',
#  'Year': '2014',
#  'imdbID': 'tt3957726',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3382842
# -------------------
# {'Actors': 'Lauren Bronleewe, Elizabeth Friedman, Bailey Gaddis, Iyad Hajjaj',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '10 Jun 2014',
#  'Director': 'Patrick McManus',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A team of archaeologists discover an ancient mummy, unleashing a '
#          'deadly curse from its eternal tomb.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ5Njg5ODg0M15BMl5BanBnXkFtZTgwNTA0NTAxMjE@._V1_SX300.jpg',
#  'Production': 'Phase 4 Films',
#  'Rated': 'TV-14',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '1.8/10'}],
#  'Released': '01 Mar 2014',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'The Mummy Resurrected',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joanne Spring',
#  'Year': '2014',
#  'imdbID': 'tt3382842',
#  'imdbRating': '1.8',
#  'imdbVotes': '1,308'}
# -------------------
# movie id tt6784906
# -------------------
# {'Actors': 'Dawn Beckman, Michael Leo Centi, Ben Eckstrom, Lena Flores',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A mother\'s love has never been so deadly in this follow up to "The '
#          'Murderous Rampage of Malachi Stitch". This time a killer is '
#          "resurrected during the aftermath of Malachi's capture by a ...",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzc3Nzk0MDYtMDQzNy00MzM0LTg0NTMtMDgyZDJmYTc4Y2FkXkEyXkFqcGdeQXVyNjU3NDA4Mjg@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 May 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Murderous Revenge of Lizzie Stillborn',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2014',
#  'imdbID': 'tt6784906',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2629936
# -------------------
# {'Actors': 'Dian Bachar, Danielle Lozeau, Martin Klebba, Dallas Page',
#  'Awards': '2 wins.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '15 Dec 2015',
#  'Director': 'Larry Longstreth',
#  'Genre': 'Drama, Fantasy, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A depressed, small-town ventriloquist named Henry (Dian Bachar of '
#          'Southpark, Baseketball) finally comes out of his shell when his '
#          "puppet 'Moxxy' (voiced by Les Claypool of Primus fame) ...",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzYzNzM1Mzc1M15BMl5BanBnXkFtZTgwOTExNTkzMTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'}],
#  'Released': '16 Oct 2015',
#  'Response': 'True',
#  'Runtime': '71 min',
#  'Title': 'The Murders of Brandywine Theater',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Larry Longstreth',
#  'Year': '2014',
#  'imdbID': 'tt2629936',
#  'imdbRating': '5.8',
#  'imdbVotes': '48'}
# -------------------
# movie id tt2076954
# -------------------
# {'Actors': 'Isaac Simons, Marguerite Insolia, Mike Pfaff, Christine Altan',
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '25 Nov 2014',
#  'Director': 'Rufus Chaffee',
#  'Genre': 'Horror, Music, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A one-hit-wonder musician battles writers block and a strange '
#          'inspirational force at a secluded lake house.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTUyNzkzNTI5OV5BMl5BanBnXkFtZTcwMjY5MjkwNw@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'}],
#  'Released': '25 Nov 2014',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'The Muse',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Rufus Chaffee',
#  'Year': '2014',
#  'imdbID': 'tt2076954',
#  'imdbRating': '5.8',
#  'imdbVotes': '61'}
# -------------------
# movie id tt3182898
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'L.S. Graye',
#  'Genre': 'Drama, History, War',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The film takes place in the winter of 1944 in a Nazi occupied '
#          'concentration camp in Poland. Three survivors- Eli, Yaduik, and '
#          'Zigney have managed to escape the madness of the concentration ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTkwNDQ1MTM5MV5BMl5BanBnXkFtZTgwNjYwMjIzMDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '76 min',
#  'Title': 'The Muselmann',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jeffery Dillinger',
#  'Year': '2014',
#  'imdbID': 'tt3182898',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3590960
# -------------------
# {'Actors': 'Alexander Eduardo Hernandez, Raina Semivan',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Sarah Zucker',
#  'Genre': 'Music',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '17 Feb 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Mystery Language of the Initiates',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Sarah Zucker',
#  'Year': '2014',
#  'imdbID': 'tt3590960',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2966858
# -------------------
# {'Actors': 'Bianca Isabel, Allison Lind',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Stephen Cone',
#  'Genre': 'Comedy, Drama, Mystery',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Actors audition for a film project, out of which infinite narratives '
#          'emerge.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '60 min',
#  'Title': 'The Mystery of Life',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Stephen Cone',
#  'Year': '2014',
#  'imdbID': 'tt2966858',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-5-80a40b876943> in <module>
#       3     url = "http://www.omdbapi.com/?i=" + movie + "&apikey=" + API_KEY
#       4     response = (requests.get(url).text)
# ----> 5     response_json = json.loads(response)
#       6     print('-------------------')
#       7     print(f'movie id {movie}')
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     351         """
#     352         try:
# --> 353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
#     355             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Invalid control character at: line 1 column 259 (char 258)

# %%
len(title_list)
# Out:
# 810

# %%
print(title_id)

# %%
# if title_list and title_id are the same length run the cell below. 
# if they are not equal take out 'title_id': title_id

# %%
df = pd.DataFrame({'title_id': title_id, 'title': title_list, 'box_office': box_office_list, 'country': country_list, 
                   'genre': genre_list, 'director': director_list, 'metascore': metascore_list, 'production': production_list, 
                   'rating': rating_list, 'IMDB_rating': IMDB_rating_list, 'rotten_tomatoes_rating': rotten_tomatoes_rating_list, 
                  'runtime': runtime_list, 'type': type_list, 'IMDB_votes': imdb_votes_list})

# %%
df = df.drop_duplicates()
df.head()

# %%
df.count()

# %%
df.to_csv('../data/2014_data_batch_3.csv', index=False)
