# %%
import pandas as pd
import requests
import json
import time
from pprint import pprint
from config import API_KEY

# %%
data = pd.read_csv('../data/titles_2014_batch4.csv')
df =  data.count()
df
# Out:
# title    323
# dtype: int64

# %%
title_id = []
box_office_list = []
country_list = []
genre_list = []
director_list = []
metascore_list = []
production_list = []
rating_list = []
IMDB_rating_list = [] 
rotten_tomatoes_rating_list = []
runtime_list = []
title_list = []
type_list = []
imdb_votes_list = []

# %%
movies = data['title']
total_movies = len(movies)

# %%
for i in range(total_movies):
    movie = movies[i]
    url = "http://www.omdbapi.com/?i=" + movie + "&apikey=" + API_KEY
    response = (requests.get(url).text)
    response_json = json.loads(response)
    print('-------------------')
    print(f'movie id {movie}')
    print('-------------------')
    pprint(response_json)
    
    try:
        box_office_list.append(response_json['BoxOffice'])
        country_list.append(response_json['Country'])
        genre_list.append(response_json['Genre'])
        director_list.append(response_json['Director'])
        metascore_list.append(response_json['Metascore'])
        production_list.append(response_json['Production'])
        rating_list.append(response_json['Rated'])
        IMDB_rating_list.append(response_json['imdbRating'])
        try:
            if not response_json['Ratings']:
                rotten_tomatoes_rating_list.append('NA')
            elif response_json['Ratings'][0]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][0]['Value'])
            elif response_json['Ratings'][1]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][1]['Value'])
            else:
                rotten_tomatoes_rating_list.append('NA')
        except IndexError:
            rotten_tomatoes_rating_list.append('NA')
        runtime_list.append(response_json['Runtime'])
        title_list.append(response_json['Title'])
        type_list.append(response_json['Type'])
        imdb_votes_list.append(response_json['imdbVotes'])
        title_id.append(response_json['imdbID'])
    except KeyError:
        pass
    time.sleep(1)
# Out:
# -------------------
# movie id tt4286208
# -------------------
# {'Actors': 'Peter Johnson, Monique Webb, Barry Williams',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Phillip Davis, Peter Johnson',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'Before he was stunning audiences all over the world with his '
#          'flawless looks, quick wit and signature walk, the fierce model Peter '
#          'Damn Williams was known as Little Petey; a sensitive, ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '72 min',
#  'Title': 'The Wonderful World of Peter Williams',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Phillip Davis',
#  'Year': '2014',
#  'imdbID': 'tt4286208',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3961536
# -------------------
# {'Actors': 'Joe Edwards, Antonio Campelli, Steve Larson, Tom Upjohn',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Abram Hammer',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'After being hunted down by the police and captured, a young man '
#          'named Jack Roberts escapes jail only to be blamed for the crimes of '
#          'a monster called "The Harrower." (From Website)',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Nov 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Woods',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Abram Hammer',
#  'Year': '2014',
#  'imdbID': 'tt3961536',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3539514
# -------------------
# {'Actors': 'Tyler Riley, Tori Ahr, Jon Kovach, Clay Orem',
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Brandon Prewitt',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Eight high school teenagers go to the woods to have a party before '
#          'graduation. They have one hell of a great time until one of their '
#          'own is found dead the next morning. Tempers flare and ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTYwODg0NDIyOV5BMl5BanBnXkFtZTgwOTA3ODExNDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.7/10'}],
#  'Released': '16 Oct 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Woods Within',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Brandon Prewitt',
#  'Year': '2014',
#  'imdbID': 'tt3539514',
#  'imdbRating': '4.7',
#  'imdbVotes': '49'}
# -------------------
# movie id tt4442764
# -------------------
# {'Actors': 'Francesca Faridany, Carman Lacivita, Kristin Villanueva',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jessica Bauman',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Sep 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': "The Wordplay Shakespeare a Midsummer Night's Dream",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'William Shakespeare',
#  'Year': '2014',
#  'imdbID': 'tt4442764',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4046882
# -------------------
# {'Actors': 'Donovan Korzen, Marley Korzen, Shelby Korzen',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Donovan Korzen, Marley Korzen, Shelby Korzen',
#  'Genre': 'Biography, Comedy, Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'In Santa Barbara California, join Sly Richardson, a sixteen year old '
#          'boy who just wants to be a rock star. Along with his family and '
#          'offbeat friends, on a great adventure through his life, ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '62 min',
#  'Title': 'The World According to Sly',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Marley Korzen',
#  'Year': '2014',
#  'imdbID': 'tt4046882',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2713440
# -------------------
# {'Actors': 'Nick King, Patricia Reynolds, Matthew G. King, Lillian Almohajer',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tim Kelly',
#  'Genre': 'Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "He's a kid named Stanley Kid, owner of the world famous Kid "
#          "Detective Agency. He must stop a devastating crime wave that's "
#          'spreading across his island home while keeping himself and his ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOGI2ZGVlMjctMDAzOS00ZjdiLTkwZDQtZTY0MzQxNDZiMjVjXkEyXkFqcGdeQXVyMzMwMjI2NA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'}],
#  'Released': '13 Jun 2014',
#  'Response': 'True',
#  'Runtime': '63 min',
#  'Title': 'The World Famous Kid Detective',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Margaret Langendorf',
#  'Year': '2014',
#  'imdbID': 'tt2713440',
#  'imdbRating': '7.0',
#  'imdbVotes': '46'}
# -------------------
# movie id tt2189978
# -------------------
# {'Actors': 'Colm Meaney, Fred Willard, Kevin P. Farley, Martin Maloney',
#  'Awards': '1 win.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Sean Lackey',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Irish American Tom Murphy hasn't a clue about Ireland or love. He "
#          'eventually learns about the country of his heritage and that he '
#          'should listen to his own heart concerning love.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjM0MzYyNjgxOF5BMl5BanBnXkFtZTgwNjIwNzQxOTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'TV-14',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.4/10'}],
#  'Released': '19 Mar 2014',
#  'Response': 'True',
#  'Runtime': '89 min',
#  'Title': 'The Yank',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Sean Lackey',
#  'Year': '2014',
#  'imdbID': 'tt2189978',
#  'imdbRating': '4.4',
#  'imdbVotes': '85'}
# -------------------
# movie id tt4260530
# -------------------
# {'Actors': 'Kate Berg, Lana Furn, Matt Holbert, Russell Kohlmann',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Anna Paone',
#  'Genre': 'Mystery',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Iris is a discontent acting major and resident advisor at a college '
#          'in New Jersey. When a rape is committed at the dorm where she works, '
#          'she becomes determined to solve the crime at all ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '17 Jan 2014',
#  'Response': 'True',
#  'Runtime': '81 min',
#  'Title': 'The Year of the Phoenix',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Anna Paone',
#  'Year': '2014',
#  'imdbID': 'tt4260530',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2912120
# -------------------
# {'Actors': 'Ryan Malgarini, Haley Lu Richardson, Joshua Malina, Melora Walters',
#  'Awards': '2 wins & 3 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kerem Sanga',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'English',
#  'Metascore': '52',
#  'Plot': 'Two nerdy Caltech students hook up and end up on a journey '
#          'throughout California after they find out one is pregnant with the '
#          "other's twins.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjMzNjk5OTA0MV5BMl5BanBnXkFtZTgwNzE1NDg5NTE@._V1_SX300.jpg',
#  'Production': 'Mance Media',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '56%'},
#              {'Source': 'Metacritic', 'Value': '52/100'}],
#  'Released': '24 Jul 2015',
#  'Response': 'True',
#  'Runtime': '94 min',
#  'Title': 'The Young Kieslowski',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kerem Sanga',
#  'Year': '2014',
#  'imdbID': 'tt2912120',
#  'imdbRating': '6.6',
#  'imdbVotes': '650'}
# -------------------
# movie id tt3452760
# -------------------
# {'Actors': 'Aliya Abrams, Robert Linden, Tamara Mack, Jaime Conteras II',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Scott Kenyon Barker',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMDg0YTU1ZDctNzA5Mi00NzE1LTliM2ItMmExMzZlMTM0NTZhXkEyXkFqcGdeQXVyMTQ4Nzk0MDc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Jun 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Z',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Scott Kenyon Barker',
#  'Year': '2014',
#  'imdbID': 'tt3452760',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3598850
# -------------------
# {'Actors': 'Keith Nagel, Sam Cohen, Sophie Sabatini, Arden Belle',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Steve Royall',
#  'Genre': 'Comedy, Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A group of kids realizing there is strength in numbers, band '
#          'together to take on the neighborhood bullies.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzM0ODE0OTE2M15BMl5BanBnXkFtZTgwNzkyOTE3MjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.9/10'}],
#  'Released': '09 Mar 2014',
#  'Response': 'True',
#  'Runtime': '72 min',
#  'Title': 'The Zeroes',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Steve Royall',
#  'Year': '2014',
#  'imdbID': 'tt3598850',
#  'imdbRating': '8.9',
#  'imdbVotes': '30'}
# -------------------
# movie id tt2361551
# -------------------
# {'Actors': 'Jason Crowe, Roni Jonah, Jason Saint, Claude Miles',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Roni Jonah',
#  'Genre': 'Action, Comedy, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc4MDk1MzA3Nl5BMl5BanBnXkFtZTcwMzE3OTk2Nw@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.9/10'}],
#  'Released': '01 Dec 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Zombie Movie',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Roni Jonah, Jason Crowe',
#  'Year': '2014',
#  'imdbID': 'tt2361551',
#  'imdbRating': '4.9',
#  'imdbVotes': '32'}
# -------------------
# movie id tt3820124
# -------------------
# {'Actors': 'Kelly Piliouras Brown, Matthew J. Dennis, Rich Little, Victoria '
#            'Mullen',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Robert Roblin',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTUwNzEwODYyNF5BMl5BanBnXkFtZTgwNTQzNDEwMzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '106 min',
#  'Title': 'Then Their Eyes Were Opened',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ted Bufkin',
#  'Year': '2014',
#  'imdbID': 'tt3820124',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3145008
# -------------------
# {'Actors': 'Joseph D. Reitman, Abraham Benrubi, Grant Harvey, Costas Mandylor',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Louis Mandylor',
#  'Genre': 'Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Then There Was is an ensemble thriller which tells the story of four '
#          'college students, an expectant couple, and a lone survival expert '
#          'who are confronted by a global blackout that forces ...',
#  'Poster': 'https://ia.media-imdb.com/images/M/MV5BMTcyMzA1NDU5NV5BMl5BanBnXkFtZTgwOTcwODI0NDE@._V1_SX300.jpg',
#  'Production': 'EchoWolf Productions',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.2/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '88 min',
#  'Title': 'The Blackout',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jordan Marder (story), Steve Yoon (screenplay), Steve Yoon (story)',
#  'Year': '2014',
#  'imdbID': 'tt3145008',
#  'imdbRating': '5.2',
#  'imdbVotes': '365'}
# -------------------
# movie id tt1995477
# -------------------
# {'Actors': 'Allison Miller, James Wolk, Rumer Willis, Jason Ritter',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '27 Apr 2015',
#  'Director': 'Rita Merson',
#  'Genre': 'Comedy, Music, Romance',
#  'Language': 'English',
#  'Metascore': '30',
#  'Plot': "When Neurotic, struggling songwriter, Catherine Brown's life in New "
#          'York City falls apart, she is forced to confront her past when she '
#          'spends the summer at her childhood home in Woodstock, ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjIzNzI2NDA3Ml5BMl5BanBnXkFtZTgwNDkyNDUwMzE@._V1_SX300.jpg',
#  'Production': 'Gravitas Ventures',
#  'Rated': 'TV-14',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.3/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '8%'},
#              {'Source': 'Metacritic', 'Value': '30/100'}],
#  'Released': '14 Nov 2014',
#  'Response': 'True',
#  'Runtime': '97 min',
#  'Title': 'Always Woodstock',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Rita Merson',
#  'Year': '2014',
#  'imdbID': 'tt1995477',
#  'imdbRating': '5.3',
#  'imdbVotes': '667'}
# -------------------
# movie id tt3108260
# -------------------
# {'Actors': 'Matt Dellapina, Sean Christopher Lewis, MacKenzie Meehan, Maria '
#            'Vorhis',
#  'Awards': '1 win.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kaitlyn Busbee(co-director), Sean Christopher Lewis(co-director)',
#  'Genre': 'Comedy, Drama, Musical',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Based on an original screenplay, THESE HOPELESS SAVAGES stars Matt '
#          "Dellapina ('Safe', 'The Quitter') alongside Sean Christopher Lewis "
#          "('God's Country'), MacKenzie Meehan ('The Wolf Of Wall ...",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTI5ODQzMjcyMV5BMl5BanBnXkFtZTgwNzM4NTg2MjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.8/10'}],
#  'Released': '05 Mar 2015',
#  'Response': 'True',
#  'Runtime': '88 min',
#  'Title': 'These Hopeless Savages',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Matt Dellapina, Sean Christopher Lewis',
#  'Year': '2014',
#  'imdbID': 'tt3108260',
#  'imdbRating': '6.8',
#  'imdbVotes': '24'}
# -------------------
# movie id tt3978706
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Thomas Roman struggles to figure out why he doesn't know anything "
#          "about his family. It isn't until his family invites a couple to live "
#          'in his basement apartment that they help him to see ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTZlMDU4ZWUtMjdlNS00ZDdjLWI3MmQtODg1NmUxMTEzMWNmXkEyXkFqcGdeQXVyMTY1NTU3NjY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.1/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '69 min',
#  'Title': 'These Words Must Be on Your Heart',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2014',
#  'imdbID': 'tt3978706',
#  'imdbRating': '8.1',
#  'imdbVotes': '90'}
# -------------------
# movie id tt2398249
# -------------------
# {'Actors': 'Paul Rudd, Amy Poehler, Bill Hader, Ellie Kemper',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '02 Sep 2014',
#  'Director': 'David Wain',
#  'Genre': 'Comedy, Romance',
#  'Language': 'English',
#  'Metascore': '60',
#  'Plot': 'A small business owner is about to lose her shop to a major '
#          'corporate development.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTkzNzA2Nzc1Ml5BMl5BanBnXkFtZTgwNzcwNzk3MTE@._V1_SX300.jpg',
#  'Production': 'Lionsgate',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.5/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '68%'},
#              {'Source': 'Metacritic', 'Value': '60/100'}],
#  'Released': '05 Sep 2014',
#  'Response': 'True',
#  'Runtime': '83 min',
#  'Title': 'They Came Together',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Showalter, David Wain',
#  'Year': '2014',
#  'imdbID': 'tt2398249',
#  'imdbRating': '5.5',
#  'imdbVotes': '20,134'}
# -------------------
# movie id tt3283802
# -------------------
# {'Actors': 'Tavis L. Baker, Lindsey Bullen, Jack Byrd, Rusty Cage',
#  'Awards': '2 wins & 4 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'James Pronath',
#  'Genre': 'Fantasy, Horror, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'John Henry, a down on his luck salesman, is given a chance at '
#          'success by an alien visitor, trading technology for help in human '
#          'experimentation. Blinded by his ambition, the salesman open a...',
#  'Poster': 'https://ia.media-imdb.com/images/M/MV5BNGY1YjdiNDAtZDE3YS00NjdiLTgzYWYtODYwMDM2YzFkZDY2XkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.7/10'}],
#  'Released': '01 Aug 2014',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'They Came from the Ether',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'James Pronath',
#  'Year': '2014',
#  'imdbID': 'tt3283802',
#  'imdbRating': '5.7',
#  'imdbVotes': '21'}
# -------------------
# movie id tt4049520
# -------------------
# {'Actors': 'Catalina Ceballos, BuAli Shah, John Stegmaier',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'BuAli Shah',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'After losing his brother, a young film maker in the midst of putting '
#          'his life back together when an old rival in need brings a '
#          'documentary project to his attention; real-life supernatural ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'They Exist',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ibne Naqvi',
#  'Year': '2014',
#  'imdbID': 'tt4049520',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2887966
# -------------------
# {'Actors': 'Jamyra Alexander Jordan, Demaria Anissa, Ronald Benson-El, Bonita '
#            'Bridges',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'A.M. Greene, Cheryl Brown',
#  'Genre': 'Crime, Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'THICK is a tale about a burgeoning apartment complex magnate, '
#          'THERESA JAMES, who runs illegal businesses in her neighborhoods for '
#          'added financial gain. Feeling the aftermath of the 2010 ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk2NTE1MzQyM15BMl5BanBnXkFtZTgwNjkzOTEyMTE@._V1_SX300.jpg',
#  'Production': 'Skyrocket Productions',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.5/10'}],
#  'Released': '01 Aug 2014',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Thick',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Cheryl Brown, A.M. Greene (story), A.M. Greene',
#  'Year': '2014',
#  'imdbID': 'tt2887966',
#  'imdbRating': '7.5',
#  'imdbVotes': '16'}
# -------------------
# movie id tt2239832
# -------------------
# {'Actors': 'Adam Brody, Michael Ealy, Jerry Ferrara, Meagan Good',
#  'Awards': '2 wins & 4 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '16 Sep 2014',
#  'Director': 'Tim Story',
#  'Genre': 'Comedy, Romance',
#  'Language': 'English',
#  'Metascore': '38',
#  'Plot': 'All the couples are back for a wedding in Las Vegas, but plans for a '
#          'romantic weekend go awry when their various misadventures get them '
#          'into some compromising situations that threaten to derail the big '
#          'event.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjE2NjMxNjU1OF5BMl5BanBnXkFtZTgwMTI1OTgxMTE@._V1_SX300.jpg',
#  'Production': 'Sony Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '23%'},
#              {'Source': 'Metacritic', 'Value': '38/100'}],
#  'Released': '20 Jun 2014',
#  'Response': 'True',
#  'Runtime': '106 min',
#  'Title': 'Think Like a Man Too',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Keith Merryman (screenplay), David A. Newman (screenplay), Steve '
#            'Harvey (book)',
#  'Year': '2014',
#  'imdbID': 'tt2239832',
#  'imdbRating': '5.8',
#  'imdbVotes': '18,969'}
# -------------------
# movie id tt1675315
# -------------------
# {'Actors': 'Lisa Menzel, Pat Doran, Adam Fallon, Nick Doetsch',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Lisa Menzel',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A Reader becomes trapped in an evolving autobiography of an executed '
#          'killer.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc1NjQ4NDk1MV5BMl5BanBnXkFtZTgwMDgwNjM5MTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'UNRATED',
#  'Ratings': [],
#  'Released': '05 Jul 2014',
#  'Response': 'True',
#  'Runtime': '111 min',
#  'Title': 'Thinking Speed',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Lisa Menzel',
#  'Year': '2014',
#  'imdbID': 'tt1675315',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6588290
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '22 Dec 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Thinking of You',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2014',
#  'imdbID': 'tt6588290',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3257692
# -------------------
# {'Actors': 'Laura Wiggins, Izabella Miko, Callie Thorne, Marcus Giamatti',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tara Miele',
#  'Genre': 'Biography, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A 17-year-old dancer joins a "thinspiration" website and devotes '
#          'herself to the almost religious glorification of "thin", until she '
#          'becomes completely possessed by the dark world of anorexia.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTU2Njk4NzMwOV5BMl5BanBnXkFtZTgwNjQzNjM3MTE@._V1_SX300.jpg',
#  'Production': 'Indy Entertainment',
#  'Rated': 'TV-14',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'}],
#  'Released': '26 Apr 2014',
#  'Response': 'True',
#  'Runtime': '84 min',
#  'Title': 'Starving in Suburbia',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tara Miele',
#  'Year': '2014',
#  'imdbID': 'tt3257692',
#  'imdbRating': '6.2',
#  'imdbVotes': '1,107'}
# -------------------
# movie id tt10490492
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt3483588
# -------------------
# {'Actors': 'Stephen Cefalu, Sean Gallagher, Roni Geva, Bryan Hart',
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Stephen Cone',
#  'Genre': 'Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A young seminary student seeking self-knowledge inadvertently finds '
#          'himself attending a sex addiction support group. It is there that he '
#          'meets Hilary, an unhappy young mother taken to ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.4/10'}],
#  'Released': '10 Oct 2014',
#  'Response': 'True',
#  'Runtime': '66 min',
#  'Title': 'This Afternoon',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Stephen Cefalu, Stephen Cone, Nikki Pierce',
#  'Year': '2014',
#  'imdbID': 'tt3483588',
#  'imdbRating': '6.4',
#  'imdbVotes': '8'}
# -------------------
# movie id tt1371150
# -------------------
# {'Actors': 'Jason Bateman, Tina Fey, Jane Fonda, Adam Driver',
#  'Awards': '1 nomination.',
#  'BoxOffice': '$26,730,317',
#  'Country': 'USA',
#  'DVD': '16 Dec 2014',
#  'Director': 'Shawn Levy',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English, Hebrew',
#  'Metascore': '44',
#  'Plot': 'When their father passes away, four grown siblings are forced to '
#          'return to their childhood home and live under the same roof together '
#          'for a week, along with their over-sharing mother and an assortment '
#          'of spouses, exes and might-have-beens.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjkzNzQ2NDMyNl5BMl5BanBnXkFtZTgwMTY3MTcxMjE@._V1_SX300.jpg',
#  'Production': 'Warner Bros. Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '43%'},
#              {'Source': 'Metacritic', 'Value': '44/100'}],
#  'Released': '19 Sep 2014',
#  'Response': 'True',
#  'Runtime': '103 min',
#  'Title': 'This Is Where I Leave You',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jonathan Tropper (screenplay), Jonathan Tropper (novel)',
#  'Year': '2014',
#  'imdbID': 'tt1371150',
#  'imdbRating': '6.6',
#  'imdbVotes': '67,220'}
# -------------------
# movie id tt2422276
# -------------------
# {'Actors': 'Rhys Coiro, Xander Berkeley, Carly Pope, Richard Portnow',
#  'Awards': '1 win.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Steve Anderson',
#  'Genre': 'Crime, Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'On his last night on the job, an unsuspecting Los Angeles cab driver '
#          'gets roped into helping a wealthy investment banker cover up a '
#          'brutal crime.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjMwNjE2NjA4M15BMl5BanBnXkFtZTgwNzM5Mjc2OTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.8/10'}],
#  'Released': '26 Apr 2014',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': 'This Last Lonely Place',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Steve Anderson',
#  'Year': '2014',
#  'imdbID': 'tt2422276',
#  'imdbRating': '7.8',
#  'imdbVotes': '67'}
# -------------------
# movie id tt3643828
# -------------------
# {'Actors': 'John Lee Ames, Christopher Angel Brannan, Dennis Hatch Christen, '
#            'Pat Colbert',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tom Marshall',
#  'Genre': 'Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Thom and Dusty have tried everything to make it, but when they find '
#          'a single piece of paper, a treasure map, they travel to Mexico to '
#          'find the treasure. They find it but lose it and not until they get '
#          'home do they find the real treasure.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZTYxZThhYzUtZTYxNS00M2RiLThiNjktZDlhMjU0YTQ4YzVjL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjk3MjkzNjI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.4/10'}],
#  'Released': '15 Mar 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Thom & Dusty Go to Mexico: The Lost Treasure',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dusty Huber',
#  'Year': '2014',
#  'imdbID': 'tt3643828',
#  'imdbRating': '4.4',
#  'imdbVotes': '7'}
# -------------------
# movie id tt4421844
# -------------------
# {'Actors': 'Charity Buckbee, Daniel Carroll, David Goldberg',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'After the sudden death of a mutual love, two estranged, thoroughly '
#          'broken people reunite for an alcohol-addled evening of '
#          'reminiscences. Fuzzy, scuzzy, boozy, woozy - Those That Know '
#          'Before...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '59 min',
#  'Title': 'Those That Know Before It Happens',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2014',
#  'imdbID': 'tt4421844',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3165238
# -------------------
# {'Actors': 'Grace Serrano, Al Coronel, Anthony L. Fernandez, Ivan Basso',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kenneth Castillo',
#  'Genre': 'Crime, Drama, Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The setting is any small urban Latino neighborhood in the U.S. where '
#          'everyone is only a degree of separation from each other. Where '
#          'loyalty to family is the utmost importance. The main ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTEwNjI3Nzg5NzJeQTJeQWpwZ15BbWU4MDM1OTY5MjAx._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '9.2/10'}],
#  'Released': '18 Mar 2014',
#  'Response': 'True',
#  'Runtime': '105 min',
#  'Title': 'Thou Shalt Not Kill',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kenneth Castillo',
#  'Year': '2014',
#  'imdbID': 'tt3165238',
#  'imdbRating': '9.2',
#  'imdbVotes': '6'}
# -------------------
# movie id tt2481276
# -------------------
# {'Actors': 'Joe Swanberg, Sophie Traub, Robert Longstreet, Kristin Slaysman',
#  'Awards': '3 wins & 5 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Josephine Decker',
#  'Genre': 'Comedy, Mystery, Romance, Thriller',
#  'Language': 'English',
#  'Metascore': '66',
#  'Plot': 'There are places you go, where the things you do will matter to a '
#          'lot of people. Then there are places you will go, where the things '
#          'you will do matter only to a very few. But to those few, they will '
#          'matter - a lot.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjI0MjI1NzI1N15BMl5BanBnXkFtZTgwNDQ1MjExMTE@._V1_SX300.jpg',
#  'Production': 'Cinelicious Pictures',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.0/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '74%'},
#              {'Source': 'Metacritic', 'Value': '66/100'}],
#  'Released': '13 Nov 2014',
#  'Response': 'True',
#  'Runtime': '78 min',
#  'Title': 'Thou Wast Mild and Lovely',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Josephine Decker (story), Josephine Decker, David Barker',
#  'Year': '2014',
#  'imdbID': 'tt2481276',
#  'imdbRating': '6.0',
#  'imdbVotes': '550'}
# -------------------
# movie id tt3751116
# -------------------
# {'Actors': 'Cici Lau, Sam Aotaki, Anthony Pu, Lee Chen',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jimmy Cuong Duong',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "In 1930, at aged16, the newlywed Young Amah's life is forever "
#          'transformed when she met a mysterious man on a steamship traveling '
#          'from Amoy City, China to the Philippines. They hid their ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '19 Dec 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Thoughts Afar in Moonlight',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jimmy Cuong Duong, Percival Gonzaga, Cici Lau, Johnson Liv, Derek '
#            'Tran, Mack Wei',
#  'Year': '2014',
#  'imdbID': 'tt3751116',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2693076
# -------------------
# {'Actors': 'Bryan Boylen, Gary A. Carreker, Ben Farley, Joseph N. Griffin',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'John M. Ware',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Patrick, Jeff, and Justin go to the lake to fish, and their day is '
#          'ruined when zombies overtake the city.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYzE1OWQ3NTktNzU1YS00ZjhlLWIxMDktNjNiOTBjNDUzMzY5XkEyXkFqcGdeQXVyMzU0NzkwMDg@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.6/10'}],
#  'Released': '11 Nov 2014',
#  'Response': 'True',
#  'Runtime': '83 min',
#  'Title': 'Thr33 Days Dead',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2014',
#  'imdbID': 'tt2693076',
#  'imdbRating': '3.6',
#  'imdbVotes': '79'}
# -------------------
# movie id tt2917572
# -------------------
# {'Actors': "Leah Gabriel, Michael Broadhurst, Blaire O'Leary",
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Lloyd Griffin',
#  'Genre': 'Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'In a north eastern college town, the husband and wife team of Andrew '
#          'and Marie Petit have made a breakthrough of historic proportions. '
#          'The two young physicists are set for global notoriety ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTY1ODUzOTY1MF5BMl5BanBnXkFtZTcwODI3ODc2OQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Sep 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Three Generations of Matter',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Lloyd Griffin',
#  'Year': '2014',
#  'imdbID': 'tt2917572',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt1907688
# -------------------
# {'Actors': 'Zuher Khan, James Wilder, Joaquim de Almeida, Rudolf Martin',
#  'Awards': '9 wins & 6 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '19 May 2015',
#  'Director': 'Hilarion Banks',
#  'Genre': 'Crime, Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An ex-Hollywood screenwriter, now teaching an evening class in New '
#          'York, finds himself in a battle of wits with a devious screen '
#          'writing student.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjA2ODcxMTUyNl5BMl5BanBnXkFtZTgwMTYxMTQ3NDE@._V1_SX300.jpg',
#  'Production': 'Cave of Time Pictures',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.5/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '40%'}],
#  'Released': '20 Mar 2015',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': '3 Holes and a Smoking Gun',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Scott Fivelson',
#  'Year': '2014',
#  'imdbID': 'tt1907688',
#  'imdbRating': '4.5',
#  'imdbVotes': '127'}
# -------------------
# movie id tt2112308
# -------------------
# {'Actors': 'Bill Gobin, Jim Dougherty, Kayla Crance, Angela Steele',
#  'Awards': '1 win.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jakob Bilinski',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'THREE TEARS ON BLOODSTAINED FLESH is a modern, Midwesternized spin '
#          'on the Giallo. This is the tale of Dominic, a man with a dark past '
#          "who returns to the small town he's long since abandoned...",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg4NTIwNTI4N15BMl5BanBnXkFtZTgwMjU1MDE1MjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'}],
#  'Released': '05 Sep 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Three Tears on Bloodstained Flesh',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jakob Bilinski',
#  'Year': '2014',
#  'imdbID': 'tt2112308',
#  'imdbRating': '6.5',
#  'imdbVotes': '19'}
# -------------------
# movie id tt3377658
# -------------------
# {'Actors': 'Michael Avatar, Sage Backstrom, Robert Bovill, Kelly Lou Dennis',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Marco Saverio',
#  'Genre': 'Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Coming of age...with a gun.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjE5MTM3NTQzMl5BMl5BanBnXkFtZTgwNTk5MDA4MTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '28 Oct 2014',
#  'Response': 'True',
#  'Runtime': '46 min',
#  'Title': 'Three Tutus and a Gun',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Grace Francisca, Deb Fujiwara (screenplay), Deb Fujiwara, Marco '
#            'Saverio (created by)',
#  'Year': '2014',
#  'imdbID': 'tt3377658',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3161308
# -------------------
# {'Actors': 'James Andre, Gyana Lua, Hannah Tippit, Tristan S. Bradford',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'RJ Cusyk',
#  'Genre': 'Horror, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A mentally unhinged young man moves into a halfway house and one of '
#          'the house mates is brutally murdered the same day. He sets out to '
#          'prove his innocence by discovering the real killer.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg0MDQ3MTEzMF5BMl5BanBnXkFtZTgwNjAxNzY4MTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'NOT RATED',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.2/10'}],
#  'Released': '10 Oct 2014',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': "Through the Devil's Eyes",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'RJ Cusyk',
#  'Year': '2014',
#  'imdbID': 'tt3161308',
#  'imdbRating': '5.2',
#  'imdbVotes': '10'}
# -------------------
# movie id tt3668222
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Laura Ann Heaton Gray',
#  'Genre': 'Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Through the Rainbow',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Laura Ann Heaton Gray',
#  'Year': '2014',
#  'imdbID': 'tt3668222',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2555520
# -------------------
# {'Actors': 'Kelly Venn',
#  'Awards': '1 win.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'P.R. Tooke',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'What would you do if the man who ruined your life, smashed your '
#          'dreams, derailed your career, and chased you out of the city showed '
#          'up in the middle of the night at your secluded cabin in ...',
#  'Poster': 'https://ia.media-imdb.com/images/M/MV5BODQ3Njk3NjkwMl5BMl5BanBnXkFtZTgwMDkxNTYxNjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'NOT RATED',
#  'Ratings': [],
#  'Released': '16 Oct 2014',
#  'Response': 'True',
#  'Runtime': '98 min',
#  'Title': 'Thru the Woods',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'P.R. Tooke',
#  'Year': '2014',
#  'imdbID': 'tt2555520',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2858344
# -------------------
# {'Actors': 'Scott BeLew, Taylor Hayden, Belmarie Huynh, Tamara Paige McClure',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Taylor Hayden',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '31 Jan 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Thug-Ocracy',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2014',
#  'imdbID': 'tt2858344',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3228104
# -------------------
# {'Actors': 'Chris Gallo, Tyler Hanley, Alex Hollingshead, Tim Hanley',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Chris Gallo',
#  'Genre': 'Action, Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Three best friends are out of school for summer vacation and are '
#          'bored to death. So Stan, Drake, and Nick decide to create a gang of '
#          'their own and try to learn the ways of surviving on the streets - '
#          'But that turns out to be a bad idea.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '16 Dec 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Tie Gang: The Movie',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Chris Gallo, Jess Gallo, Tyler Hanley, Alex Hollingshead',
#  'Year': '2014',
#  'imdbID': 'tt3228104',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2866824
# -------------------
# {'Actors': 'Mark Strano, Frankie Valenti, Gregory Marcel, Ty Parker',
#  'Awards': '1 win & 1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '06 Jul 2015',
#  'Director': 'Wade Gasque',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'In the small Central California town where they grew up, two '
#          'estranged gay brothers struggle to reconnect after the recent death '
#          'of their father.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzQyMDIyMTg3MF5BMl5BanBnXkFtZTgwNzgxNzkxNjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Unrated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '100%'}],
#  'Released': '01 Jul 2014',
#  'Response': 'True',
#  'Runtime': '75 min',
#  'Title': 'Tiger Orange',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Wade Gasque, Mark Strano',
#  'Year': '2014',
#  'imdbID': 'tt2866824',
#  'imdbRating': '6.6',
#  'imdbVotes': '1,071'}
# -------------------
# movie id tt3501702
# -------------------
# {'Actors': 'Paige Ball, William Conklin, Benisha Dorris, Joe Hammerstone',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Marcus J. Mosley',
#  'Genre': 'Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Meg Alexander and her groom to be Derrick Logan prepare for their '
#          'wedding day, but as their big day gets closer, paranormal activities '
#          "soon start when Meg brings her dead mother's wedding dress into "
#          'their home.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg2MzQwMDc3Ml5BMl5BanBnXkFtZTgwODM5NTk0MTE@._V1_SX300.jpg',
#  'Production': 'Odyssey Media',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.4/10'}],
#  'Released': '30 Oct 2014',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Til Death Do Us Part',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Marcus J. Mosley',
#  'Year': '2014',
#  'imdbID': 'tt3501702',
#  'imdbRating': '6.4',
#  'imdbVotes': '7'}
# -------------------
# movie id tt3859336
# -------------------
# {'Actors': 'Jim Round, Nellie Sciutto',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Matt Boatright-Simon',
#  'Genre': 'Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Ray Steppin, a small-town sheriff in the mountains of Syzygy County '
#          'Alaska is awakened early one morning with a hangover of steep '
#          "proportions. He's summoned to the gruesome crime scene ...",
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '83 min',
#  'Title': 'Til Night Redux',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Matt Boatright-Simon',
#  'Year': '2014',
#  'imdbID': 'tt3859336',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3632922
# -------------------
# {'Actors': 'Levi Robinson, Jordan Howard, Chet Watson, Taiya Kirk',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Levi Robinson',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'From the team that brought you "Headsmash", comes a new feature '
#          'length, coming of age comedy. When Patrick (Levi Robinson), and '
#          'Ethan (Jordan Howard), write "Till Blood Do Us Part", the ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'NOT RATED',
#  'Ratings': [],
#  'Released': '27 Mar 2014',
#  'Response': 'True',
#  'Runtime': '82 min',
#  'Title': 'Till Blood Do Us Part',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'David Passey, Levi Robinson',
#  'Year': '2014',
#  'imdbID': 'tt3632922',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3171476
# -------------------
# {'Actors': 'Sheri Davis, Nicole Holt, Carl Bailey, Paula Marcenaro Solinger',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Diana Bigham',
#  'Genre': 'Adventure',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An ex-wife takes her wedding vows to the extreme and plots an '
#          'extravagant revenge against her philandering ex-husband by making '
#          'him relive his honeymoon road trip one painful mile at a time.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjU0MjIxNDU3OV5BMl5BanBnXkFtZTgwMjY5MTMyNjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.5/10'}],
#  'Released': '10 May 2014',
#  'Response': 'True',
#  'Runtime': '120 min',
#  'Title': 'Till Death',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Diana Bigham',
#  'Year': '2014',
#  'imdbID': 'tt3171476',
#  'imdbRating': '7.5',
#  'imdbVotes': '8'}
# -------------------
# movie id tt4329358
# -------------------
# {'Actors': 'Jack Sochet, Karl Dominik, Sara Malia Hatfield, Meeni Naqvi',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Genia Starcev',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When David returns home from a long day at work... he is faced with '
#          'the news that his wife Lisa wants a divorce.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '60 min',
#  'Title': 'Till Death Do Us Part',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Nathan F. Lunsford',
#  'Year': '2014',
#  'imdbID': 'tt4329358',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt1857921
# -------------------
# {'Actors': 'Andrew Laquintano, Peter Patrikios, Joyce Mitchell, Jerry Lyden',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Rob Horwitz',
#  'Genre': 'Drama',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'Journey through the lives of ten strangers on the ultimate collision '
#          'course. All of them from different places, together, waiting their '
#          'turn in the hospital. Conversations of life, loss, ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '105 min',
#  'Title': 'Time',
#  'Type': 'movie',
#  'Website': 'http://www.timeishere.com/',
#  'Writer': 'Craig Nachsin (story), Rob Horwitz (screenplay)',
#  'Year': '2011',
#  'imdbID': 'tt1857921',
#  'imdbRating': '6.3',
#  'imdbVotes': '18'}
# -------------------
# movie id tt2669336
# -------------------
# {'Actors': "Danielle Panabaker, Matt O'Leary, George Finn, John Rhys-Davies",
#  'Awards': '18 wins & 5 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '16 Jun 2015',
#  'Director': 'Bradley King',
#  'Genre': 'Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': '50',
#  'Plot': 'Three friends discover a mysterious machine that takes pictures '
#          'twenty-four hours into the future, and conspire to use it for '
# ...
#  'Genre': 'Drama, Music',
#  'Language': 'English',
#  'Metascore': '88',
#  'Plot': 'A promising young drummer enrolls at a cut-throat music conservatory '
#          'where his dreams of greatness are mentored by an instructor who will '
#          "stop at nothing to realize a student's potential.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTA5NDZlZGUtMjAxOS00YTRkLTkwYmMtYWQ0NWEwZDZiNjEzXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg',
#  'Production': 'Sony Pictures Classics',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.5/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '93%'},
#              {'Source': 'Metacritic', 'Value': '88/100'}],
#  'Released': '15 Oct 2014',
#  'Response': 'True',
#  'Runtime': '106 min',
#  'Title': 'Whiplash',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Damien Chazelle',
#  'Year': '2014',
#  'imdbID': 'tt2582802',
#  'imdbRating': '8.5',
#  'imdbVotes': '651,730'}
# -------------------
# movie id tt1899305
# -------------------
# {'Actors': 'Fernanda Urrejola, Tiago Correa, Paulo Brunetti, Nicolás Allendes',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Chile',
#  'DVD': 'N/A',
#  'Director': 'Jorge Olguín',
#  'Genre': 'Fantasy, Horror',
#  'Language': 'English, Spanish',
#  'Metascore': 'N/A',
#  'Plot': 'Two sisters of Mapuche descent, are hired as guides for a '
#          'northamerican geologist, who works for an enterprise which want to '
#          "build a dam, through an unexplored wood in Chile's south. Legend...",
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.4/10'}],
#  'Released': '05 Sep 2014',
#  'Response': 'True',
#  'Runtime': '100 min',
#  'Title': 'Whispers of the Forest',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Carolina García, Jorge Olguín',
#  'Year': '2014',
#  'imdbID': 'tt1899305',
#  'imdbRating': '4.4',
#  'imdbVotes': '9'}
# -------------------
# movie id tt2238050
# -------------------
# {'Actors': 'Shailene Woodley, Eva Green, Christopher Meloni, Shiloh Fernandez',
#  'Awards': '4 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'France, USA',
#  'DVD': '20 Jan 2015',
#  'Director': 'Gregg Araki',
#  'Genre': 'Drama, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': '51',
#  'Plot': "In 1988, a teenage girl's life is thrown into chaos when her mother "
#          'disappears.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTEwOTY0MjY4MjBeQTJeQWpwZ15BbWU4MDg4OTQ5NDIx._V1_SX300.jpg',
#  'Production': 'Magnolia Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.4/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '54%'},
#              {'Source': 'Metacritic', 'Value': '51/100'}],
#  'Released': '25 Sep 2014',
#  'Response': 'True',
#  'Runtime': '91 min',
#  'Title': 'White Bird in a Blizzard',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Gregg Araki (screenplay by), Laura Kasischke (based on the novel '
#            'by)',
#  'Year': '2014',
#  'imdbID': 'tt2238050',
#  'imdbRating': '6.4',
#  'imdbVotes': '25,923'}
# -------------------
# movie id tt4180650
# -------------------
# {'Actors': 'Ben Kobold, David Liebe Hart, Liz Harvey, Jason Folks',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jake Myers',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Officer Kip White is on a one-man mission to take down the European '
#          "Cartel. After witnessing one of the cartel's thugs murder his best "
#          "friend, White goes on a vengeance quest. He'll stop at...",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjM2MjM3NjgxMF5BMl5BanBnXkFtZTgwMDQ4NTM0MzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.8/10'}],
#  'Released': '06 Nov 2014',
#  'Response': 'True',
#  'Runtime': '82 min',
#  'Title': 'White Cop',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Lara Unnerstall (screenplay), Jake Myers (story), Lara Unnerstall '
#            '(story), Ben Kobold (story), Katie Rife (story), Nick Moore '
#            '(story)',
#  'Year': '2014',
#  'imdbID': 'tt4180650',
#  'imdbRating': '7.8',
#  'imdbVotes': '54'}
# -------------------
# movie id tt2697586
# -------------------
# {'Actors': 'Frank Mosley, Katie Hawthorne, Josh Wick, Ryan Harper Gray',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'John W. Yost',
#  'Genre': 'Drama, Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'White Creek is a place from another universe. A place where '
#          'feudalism remains intact and people struggle to break free from '
#          'debt. One family must escape the dangers of this decaying society, '
#          'as the power in their valley changes hands. In the end they are left '
#          'to decide how to move forward in this universe and the next.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ4NjczMzUzN15BMl5BanBnXkFtZTgwNzU4MjE2MTE@._V1_SX300.jpg',
#  'Production': 'Fifth Column Features',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.9/10'}],
#  'Released': '02 Feb 2015',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'White Creek',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Randall Meehl, John W. Yost',
#  'Year': '2014',
#  'imdbID': 'tt2697586',
#  'imdbRating': '4.9',
#  'imdbVotes': '45'}
# -------------------
# movie id tt1691928
# -------------------
# {'Actors': 'Gregory Thomas, Anil Raman, Heather Ankeny, Brock Kelly',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ryan Fox',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "'White Dwarf' is a blend of story, documentary, of cinéma and vérité "
#          'that examines the culture of Hollywood when shooting stars '
#          'eventually lose their luster. The film chronicles a day (and ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTYyOTczODE3OF5BMl5BanBnXkFtZTgwMTgyMDU0MjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': 'White Dwarf',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ryan Fox',
#  'Year': '2014',
#  'imdbID': 'tt1691928',
#  'imdbRating': '7.0',
#  'imdbVotes': '9'}
# -------------------
# movie id tt4203666
# -------------------
# {'Actors': 'Gerardo Moctezuma, Victor Manso, Damian Diaz, Carlos Flores',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Hector Felix, Jon Primo',
#  'Genre': 'Biography, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A young Latin man, raised from a dysfunctional family, faith is '
#          'tested when he chooses to live life in the fast lane and crashes '
#          'head on with its consequences.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.0/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '133 min',
#  'Title': 'White Lines',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Fernando Calderon-Villanueva (story), Hector Felix, Jon Primo',
#  'Year': '2014',
#  'imdbID': 'tt4203666',
#  'imdbRating': '6.0',
#  'imdbVotes': '5'}
# -------------------
# movie id tt3996710
# -------------------
# {'Actors': 'Nissa Von Reiter, Emme Watkins, Ellen Ranson, Lynne Jordan',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Alex Amadei',
#  'Genre': 'Comedy, Fantasy, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'After an otherworldly attack sends a teenage-girl deep into an '
#          'impenetrable sleep, her desperate mother searches for a cure. But '
#          'her search takes a sinister detour with the discovery of a ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ2MzA0MTE4MF5BMl5BanBnXkFtZTgwNjg1NDE5MzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.6/10'}],
#  'Released': '30 Aug 2014',
#  'Response': 'True',
#  'Runtime': '105 min',
#  'Title': 'White Orb',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Alex Amadei',
#  'Year': '2014',
#  'imdbID': 'tt3996710',
#  'imdbRating': '7.6',
#  'imdbVotes': '20'}
# -------------------
# movie id tt2890588
# -------------------
# {'Actors': 'Aaron Bennett, Elizabeth Boltz, Chase Christiensen, Sabrina '
#            'Groenig',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Josh Hodgins',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A gunshot in the middle of the night. A man caught holding a smoking '
#          "gun. The answers aren't as clear as they seem. The answer lies in "
#          'the White Roses that sit on the nearby nightstand.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjQ0ODk0OTQwM15BMl5BanBnXkFtZTgwNzgzOTEyMTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '22 Feb 2014',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'White Roses',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Josh Hodgins (story), Josh Hodgins',
#  'Year': '2014',
#  'imdbID': 'tt2890588',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3159258
# -------------------
# {'Actors': 'Scarlet Sheppard, Isaac Eastwood, Joey Madia, Eric Vasbinder',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Arthur Leo Collins',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A wealthy plantation owner enlists the help of a voodoo witch doctor '
#          'to win the heart (and soul) of a beautiful young woman.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk2NTAyOTA2MF5BMl5BanBnXkFtZTgwMTYwMzk4MjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.9/10'}],
#  'Released': '12 Jul 2014',
#  'Response': 'True',
#  'Runtime': '120 min',
#  'Title': 'White Zombie',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Susan Sheppard',
#  'Year': '2014',
#  'imdbID': 'tt3159258',
#  'imdbRating': '6.9',
#  'imdbVotes': '14'}
# -------------------
# movie id tt3315284
# -------------------
# {'Actors': "Marvin Sapp, Lil' Mo, Tasha Page Lockhart, Jessica Reedy",
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '13 Oct 2014',
#  'Director': 'Paul D. Hannah',
#  'Genre': 'Musical',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Monica is the former lead singer of the three-girl group "Illicit" '
#          'who were once an R&B powerhouse. She went on to have a less than '
#          'stellar solo career but now feels there is something ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjE0Njc5OTYwNF5BMl5BanBnXkFtZTgwMzI1MTk2NjE@._V1_SX300.jpg',
#  'Production': 'Overflow Entertainment',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'}],
#  'Released': '14 Oct 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Who Can I Run To',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Paul D. Hannah',
#  'Year': '2014',
#  'imdbID': 'tt3315284',
#  'imdbRating': '6.5',
#  'imdbVotes': '17'}
# -------------------
# movie id tt3727804
# -------------------
# {'Actors': 'Brittany Square, Christopher Harris, Erick Lindsey, Maalik Shakoor',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Brittany Larimore',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When Maria sees her attacker in public, she must decide to either '
#          'contribute to the never-ending cycle of violence, or to fight '
#          'against what is expected from her.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '10 May 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Whole World Blind',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Brittany Larimore',
#  'Year': '2014',
#  'imdbID': 'tt3727804',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt1579256
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'John Meredith',
#  'Genre': 'Crime, Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Complications caused by a stranger lead to dire consequences and '
#          "ultimately the collapse of Natalie's world but with the help of a "
#          'close friend Natalie seeks revenge.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Why Do I Cry?',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'John Meredith',
#  'Year': '2015',
#  'imdbID': 'tt1579256',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2522956
# -------------------
# {'Actors': 'Bethany Aline, Miriam Arenas, Balkas L. Berry, Naimah Beyah',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Christopher W. Hurst',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Dr. Julius M. Jordan is a bachelor from Philly. After breaking up '
#          'with his ex, he decides to take his chances on the dating scene. He '
#          'soon realizes that it may not be his cup of tea.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTYyNTM0NDkyMF5BMl5BanBnXkFtZTgwOTg4NjQxMDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '31 Dec 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': "Why I Don't Date",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Christopher W. Hurst',
#  'Year': '2014',
#  'imdbID': 'tt2522956',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3485704
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Anthony Commodore',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A troubled married couple trying to piece their marriage back '
#          'together whose lives suddenly change after an unexpected encounter '
#          'on the road with the demonic past of their parents.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Why US?',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Anthony Commodore',
#  'Year': '2014',
#  'imdbID': 'tt3485704',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-5-8126779ff96a> in <module>
#       3     url = "http://www.omdbapi.com/?i=" + movie + "&apikey=" + API_KEY
#       4     response = (requests.get(url).text)
# ----> 5     response_json = json.loads(response)
#       6     print('-------------------')
#       7     print(f'movie id {movie}')
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
len(title_list)
# Out:
# 263

# %%
len(title_id)
# Out:
# 263

# %%
# if title_list and title_id are the same length run the cell below. 
# if they are not equal take out 'title_id': title_id

# %%
df = pd.DataFrame({'title_id': title_id, 'title': title_list, 'box_office': box_office_list, 'country': country_list, 
                   'genre': genre_list, 'director': director_list, 'metascore': metascore_list, 'production': production_list, 
                   'rating': rating_list, 'IMDB_rating': IMDB_rating_list, 'rotten_tomatoes_rating': rotten_tomatoes_rating_list, 
                  'runtime': runtime_list, 'type': type_list, 'IMDB_votes': imdb_votes_list})

# %%
df = df.drop_duplicates()
df.head()
# Out:
#     title_id                                              title box_office  \
# 0  tt4286208              The Wonderful World of Peter Williams        N/A
# 1  tt3961536                                          The Woods        N/A
# 2  tt3539514                                   The Woods Within        N/A
# 3  tt4442764  The Wordplay Shakespeare a Midsummer Night's D...        N/A
# 4  tt4046882                         The World According to Sly        N/A
#
#   country                      genre  \
# 0     USA     Comedy, Drama, Romance
# 1     USA                   Thriller
# 2     USA                     Horror
# 3     USA                     Comedy
# 4     USA  Biography, Comedy, Family
#
#                                        director metascore production rating  \
# 0                  Phillip Davis, Peter Johnson       N/A        N/A    N/A
# 1                                  Abram Hammer       N/A        N/A    N/A
# 2                               Brandon Prewitt       N/A        N/A    N/A
# 3                                Jessica Bauman       N/A        N/A    N/A
# 4  Donovan Korzen, Marley Korzen, Shelby Korzen       N/A        N/A    N/A
#
#   IMDB_rating rotten_tomatoes_rating runtime   type IMDB_votes
# 0         N/A                     NA  72 min  movie        N/A
# 1         N/A                     NA     N/A  movie        N/A
# 2         4.7                     NA     N/A  movie         49
# 3         N/A                     NA     N/A  movie        N/A
# 4         N/A                     NA  62 min  movie        N/A

# %%
df.count()
# Out:
# title_id                  263
# title                     263
# box_office                263
# country                   263
# genre                     263
# director                  263
# metascore                 263
# production                263
# rating                    263
# IMDB_rating               263
# rotten_tomatoes_rating    263
# runtime                   263
# type                      263
# IMDB_votes                263
# dtype: int64

# %%
df.to_csv('../data/2014_data_batch_4.csv', index=False)
