# %%
import pandas as pd
import requests
import json
import time
from pprint import pprint
from config import API_KEY

# %%
data = pd.read_csv('../data/titles_2014_batch2.csv')
df =  data.count()
df
# Out:
# title    1000
# dtype: int64

# %%
title_id = []
box_office_list = []
country_list = []
genre_list = []
director_list = []
metascore_list = []
production_list = []
rating_list = []
IMDB_rating_list = [] 
rotten_tomatoes_rating_list = []
runtime_list = []
title_list = []
type_list = []
imdb_votes_list = []

# %%
movies = data['title']
total_movies = len(movies)

# %%
for i in range(total_movies):
    movie = movies[i]
    url = "http://www.omdbapi.com/?i=" + movie + "&apikey=" + API_KEY
    response = (requests.get(url).text)
    response_json = json.loads(response)
    print('-------------------')
    print(f'movie id {movie}')
    print('-------------------')
    pprint(response_json)
    
    try:
        box_office_list.append(response_json['BoxOffice'])
        country_list.append(response_json['Country'])
        genre_list.append(response_json['Genre'])
        director_list.append(response_json['Director'])
        metascore_list.append(response_json['Metascore'])
        production_list.append(response_json['Production'])
        rating_list.append(response_json['Rated'])
        IMDB_rating_list.append(response_json['imdbRating'])
        try:
            if not response_json['Ratings']:
                rotten_tomatoes_rating_list.append('NA')
            elif response_json['Ratings'][0]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][0]['Value'])
            elif response_json['Ratings'][1]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][1]['Value'])
            else:
                rotten_tomatoes_rating_list.append('NA')
        except IndexError:
            rotten_tomatoes_rating_list.append('NA')
        runtime_list.append(response_json['Runtime'])
        title_list.append(response_json['Title'])
        type_list.append(response_json['Type'])
        imdb_votes_list.append(response_json['imdbVotes'])
        title_id.append(response_json['imdbID'])
    except KeyError:
        pass
    time.sleep(1)
# Out:
# -------------------
# movie id tt4470336
# -------------------
# {'Actors': 'Heidi Azaro, Antonio Barrios, Sonia Bishop, Anthony H. Brown',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Joddy Eric Matthews',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': '#50Fathers is an American Dramatic Comedy. Dominique Hathaway is the '
#          'best high school athlete in the nation. "Nique"Â\x9d is a three '
#          'sport All-American and a Blue Chip MLB or NFL draft ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Jul 2015',
#  'Response': 'True',
#  'Runtime': '132 min',
#  'Title': '#50Fathers',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joddy Eric Matthews',
#  'Year': '2015',
#  'imdbID': 'tt4470336',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5460468
# -------------------
# {'Actors': 'Jake Rotger, Mark Boyd, Dave Kilgore, Alexa Moffo',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Miranda Ferguson',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '11 Dec 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '#Enough',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2015',
#  'imdbID': 'tt5460468',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3526286
# -------------------
# {'Actors': 'Emma Adler, Jessica Blank, Ted Christensen, Annabelle Dexter-Jones',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tara Subkoff',
#  'Genre': 'Crime, Drama, Horror, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': '42',
#  'Plot': 'Six preadolescent girls face a night of terror when the compulsive '
#          'addiction of an online social media game turns a moment of cyber '
#          'bullying into a night of insanity.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjM5ODg2NjU2Nl5BMl5BanBnXkFtZTgwMTY0NTIwMDI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.0/10'},
#              {'Source': 'Metacritic', 'Value': '42/100'}],
#  'Released': '20 Nov 2015',
#  'Response': 'True',
#  'Runtime': '101 min',
#  'Title': '#Horror',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tara Subkoff',
#  'Year': '2015',
#  'imdbID': 'tt3526286',
#  'imdbRating': '3.0',
#  'imdbVotes': '3,218'}
# -------------------
# movie id tt2538204
# -------------------
# {'Actors': 'Tom Pelphrey, Natalie Hall, Method Man, Malcolm Goodwin',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Brendan Gabriel Murphy',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Based on a true story, an aspiring New York City sportscaster's life "
#          'is on the slow track until he serendipitously gets the old cell '
#          'phone number of a basketball superstar. Will the number ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BM2E3ODc4YjAtMGMxMi00YWU1LWEzZTMtZTNiZGQ5NDkzNDZhXkEyXkFqcGdeQXVyMDc3ODUxNg@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'TV-14',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.0/10'}],
#  'Released': '01 Sep 2015',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': '#Lucky Number',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'David Cornue, Michael Cuccolo',
#  'Year': '2015',
#  'imdbID': 'tt2538204',
#  'imdbRating': '5.0',
#  'imdbVotes': '435'}
# -------------------
# movie id tt5466780
# -------------------
# {'Actors': 'Amanda Carroll, Zsane Fleming, Joseph J.I Johnson, Jessica Smith',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Melanie Page',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '10 Oct 2015',
#  'Response': 'True',
#  'Runtime': '50 min',
#  'Title': '#Standards',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Melanie Page',
#  'Year': '2015',
#  'imdbID': 'tt5466780',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4444974
# -------------------
# {'Actors': 'Dallas Mapleshade, Rich Costales, Saskia Maarleveld, Chris '
#            'Bramante',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Rich Costales, Kailee McGee',
#  'Genre': 'Documentary, Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Dallas Mapleshade, a struggling actress, dancer, and singer in New '
#          'York City, decides she must take success in her own hands by paying '
#          'a filmmaker to make a feature documentary about her life.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTYzNjQxODgzMF5BMl5BanBnXkFtZTgwNDEwODc0NDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '83 min',
#  'Title': '#blessed',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Rich Costales (story)',
#  'Year': '2015',
#  'imdbID': 'tt4444974',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4397606
# -------------------
# {'Actors': 'Krystal Pixie Adams, Joe Makowski, David A. Jackson, John Miller',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'John Miller',
#  'Genre': 'Crime, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.6/10'}],
#  'Released': '02 Mar 2015',
#  'Response': 'True',
#  'Runtime': '71 min',
#  'Title': '$kumbagz',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'John Miller',
#  'Year': '2015',
#  'imdbID': 'tt4397606',
#  'imdbRating': '7.6',
#  'imdbVotes': '9'}
# -------------------
# movie id tt3234822
# -------------------
# {'Actors': 'Nine Blackmon, Curtis Hopkins',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Nine Blackmon',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'We Should Have This Conversation After Dinner',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Nine Blackmon',
#  'Year': '2015',
#  'imdbID': 'tt3234822',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3556238
# -------------------
# {'Actors': 'Mike Ratterman, Walter Peña, Kevin Burge, Tad Sisler',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kevin Burge, Tad Sisler',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "It's Christmas Eve and Ben is supposed to propose to his girlfriend. "
#          'He seeks the help of his friend Otis and unwillingly breaks into a '
#          'house. He soon discovers that breaking and entering is the least of '
#          'his problems.',
#  'Poster': 'N/A',
#  'Production': 'Main Road Productions, LTD.',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': "'Tis the Season",
#  'Type': 'movie',
#  'Website': 'http://www.hallmarkchannel.com/tis-the-season-for-love/about-tis-the-season-for-love',
#  'Writer': 'Kevin Burge, Tad Sisler',
#  'Year': '2015',
#  'imdbID': 'tt3556238',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4872362
# -------------------
# {'Actors': 'Beau Bielski, Marley Boone, Andrew Buck, Laura Chall',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tyler Clifton, Brock Lewandowski, Sarah R. Matthews, Sam Rector, '
#              'Austin Schuld, Keenan Wetzel',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '29 Jul 2015',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': '(313) Choices',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Cj Valle (story)',
#  'Year': '2015',
#  'imdbID': 'tt4872362',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7122468
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jaume Collet-Serra',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '31 Aug 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '1 Chisper',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2015',
#  'imdbID': 'tt7122468',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4152210
# -------------------
# {'Actors': 'Lara Heller, Farah Mokrani, Robert Murphy, Kendall Carroll',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Brian McGuire',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Brian McGuire's five part movie series, 1 World 100 Lonely, a "
#          'brazenly dark, yet deeply human drama that presents audiences with '
#          'one of the most striking portrayals of the complexities of ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '116 min',
#  'Title': '1 world 100 lonely',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kendall Carroll, Mark E. Fletcher, Lara Heller, Brian McGuire, '
#            'Farah Mokrani, Robert Murphy',
#  'Year': '2014',
#  'imdbID': 'tt4152210',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4418268
# -------------------
# {'Actors': 'Sebastian Stimman, Amy Londyn, Richard Meiman, Jacqueline Delibes',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Quanah Jay Hicks',
#  'Genre': 'Drama, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'With her social life seemingly at a crossroads, a young woman seeks '
#          "solace in her new friend's peculiar perspective of the world they "
#          'live in.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk0MzcyNjQyNF5BMl5BanBnXkFtZTgwMjIxNTE1NDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.4/10'}],
#  'Released': '30 May 2015',
#  'Response': 'True',
#  'Runtime': '97 min',
#  'Title': '1.7 Alpha',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Quanah Jay Hicks',
#  'Year': '2015',
#  'imdbID': 'tt4418268',
#  'imdbRating': '7.4',
#  'imdbVotes': '14'}
# -------------------
# movie id tt5282238
# -------------------
# {'Actors': 'Patrick Burnett, James J. Coker, Lance Davis, Thomas Doolittle',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jeff Morris',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': '10 friends gather to mourn the loss of a friend at a lake house in '
#          'the Fall of 1979. However, a killer is among them, and they must '
#          'figure out who it is before they start getting killed '
#          'one.....by......one.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZWY4NWE1MzktZjY0NS00ZGJkLTlhODktYTk4OWUxNDMyYmIwXkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.7/10'}],
#  'Released': '31 Dec 2015',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': '10',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jeff Morris, Blake Opperman, Alex Powers',
#  'Year': '2015',
#  'imdbID': 'tt5282238',
#  'imdbRating': '4.7',
#  'imdbVotes': '7'}
# -------------------
# movie id tt3453052
# -------------------
# {'Actors': 'Caroline Barry, Christopher Lambert, Kelly LeBrock, Julia Chantrey',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Timothy Hines',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'In 1887, at age 23, reporter Nellie Bly, working for Joseph '
#          'Pulitzer, feigns mental illness to go undercover in notorious '
#          "Blackwell's Island a woman's insane asylum to expose corruption, "
#          'abuse and murder.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTI3MDU4ODc2OF5BMl5BanBnXkFtZTgwNzYwMjY1NjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.7/10'}],
#  'Released': '11 Nov 2015',
#  'Response': 'True',
#  'Runtime': '111 min',
#  'Title': '10 Days in a Madhouse',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Timothy Hines',
#  'Year': '2015',
#  'imdbID': 'tt3453052',
#  'imdbRating': '6.7',
#  'imdbVotes': '1,165'}
# -------------------
# movie id tt4562630
# -------------------
# {'Actors': 'Lamar K. Cheston, Elijah Coleman, Maya Rose De Lucia, Shadner '
#            'Ifrene',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Saquan Jones',
#  'Genre': 'Action, Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Two men are locked in a room with 60 minutes to find out why they '
#          'are in the room with a mad man coming to torture them every 10 '
#          'minutes.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTU2MzY0MDAzM15BMl5BanBnXkFtZTgwMjQwMjQxNTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '15 Apr 2015',
#  'Response': 'True',
#  'Runtime': '67 min',
#  'Title': '10 Minutes',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Saquan Jones, Saquan Jones',
#  'Year': '2015',
#  'imdbID': 'tt4562630',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3397754
# -------------------
# {'Actors': 'Henry Kelemen, Julianne Nicholson, Ethan Hawke, Asa Butterfield',
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '06 Oct 2015',
#  'Director': 'Shari Springer Berman, Robert Pulcini',
#  'Genre': 'Comedy, Drama, Music',
#  'Language': 'English',
#  'Metascore': '62',
#  'Plot': 'Set in the 1980s, a teenager from Vermont moves to New York City to '
#          'live with his father in East Village.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjM1NTgwODEyOV5BMl5BanBnXkFtZTgwNzM1ODM1NjE@._V1_SX300.jpg',
#  'Production': 'Screen Media Ventures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.9/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '58%'},
#              {'Source': 'Metacritic', 'Value': '62/100'}],
#  'Released': '14 Aug 2015',
#  'Response': 'True',
#  'Runtime': '113 min',
#  'Title': 'Ten Thousand Saints',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Robert Pulcini (screenplay), Shari Springer Berman (screenplay), '
#            'Eleanor Henderson (based on the novel by)',
#  'Year': '2015',
#  'imdbID': 'tt3397754',
#  'imdbRating': '5.9',
#  'imdbVotes': '5,028'}
# -------------------
# movie id tt5116930
# -------------------
# {'Actors': 'Tom Curren, Taylor Knox, Bobby Martinez, Kelly Slater',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Josh Pomer',
#  'Genre': 'N/A',
#  'Language': 'Spanish',
#  'Metascore': 'N/A',
#  'Plot': 'This special edition travel film has pop up bubbles containing '
#          'trivia and witticisms throughout the movie. Explore your surfing '
#          'dreams in Fiji, Mexico and Chile and learn new and interesting facts '
#          'about the places and surfers.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjI3MDI2OTIzNV5BMl5BanBnXkFtZTgwNjg5OTkwNzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'G',
#  'Ratings': [],
#  'Released': '01 Oct 2015',
#  'Response': 'True',
#  'Runtime': '49 min',
#  'Title': '1000 Waves to Surfing Glory: Pop up Edition',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2015',
#  'imdbID': 'tt5116930',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3219396
# -------------------
# {'Actors': 'Morgan Mishelle Boutilier, Tophy Cho, Michelle Dubose, Roth Farrar',
#  'Awards': '1 win & 1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tophy Cho',
#  'Genre': 'Adventure, Drama, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A Buddhist Hobo, trapped inside a video game, must journey through '
#          'psychotic realms of existence in order to reverse his karma, achieve '
#          'enlightenment, and save the Princess.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjhiZTg3MDktODc4Zi00MTk0LWE1MzktMGQ0NWEzYTllMzBjXkEyXkFqcGdeQXVyNzgwNzUyNjY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'}],
#  'Released': '01 Sep 2015',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': '101 Secrets',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tophy Cho',
#  'Year': '2015',
#  'imdbID': 'tt3219396',
#  'imdbRating': '6.2',
#  'imdbVotes': '6'}
# -------------------
# movie id tt3957956
# -------------------
# {'Actors': 'Jonathan Good, Roger Cross, Daniel Cudmore, Lochlyn Munro',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '22 Dec 2015',
#  'Director': 'Stephen Reynolds',
#  'Genre': 'Action, Crime, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Upon returning to work after recovering from an injury, a police '
#          'officer discovers and attempts to turn in incriminating evidence of '
#          'illegal activities against his fellow cops.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjAxNzYyNjE3M15BMl5BanBnXkFtZTgwOTA2NDUzNjE@._V1_SX300.jpg',
#  'Production': 'Lionsgate Films',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.2/10'}],
#  'Released': '11 Sep 2015',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': '12 Rounds 3: Lockdown',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Nathan Brookes, Bobby Lee Darby',
#  'Year': '2015',
#  'imdbID': 'tt3957956',
#  'imdbRating': '5.2',
#  'imdbVotes': '3,433'}
# -------------------
# movie id tt7096318
# -------------------
# {'Actors': 'Hope Matherly, Allison Aho, Nick Yasi, Johnathan Schofield',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Micah Thompson',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZGY0ZmVlODMtMGY4ZS00NzlkLThhYWYtMTQ2ZDI0ZWIxMGU4XkEyXkFqcGdeQXVyMjU3MjA5NDk@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '28 May 2015',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': '12th Night',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2015',
#  'imdbID': 'tt7096318',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3781762
# -------------------
# {'Actors': 'Simon Abkarian, Angela Sarafyan, Sam Page, Nikolai Kinski',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Garin Hovannisian, Alec Mouhibian',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Exactly 100 years after the Armenian Genocide, a theatre director '
#          'stages a play to bring the ghosts of the past back to life.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTMxNDczNDQyM15BMl5BanBnXkFtZTgwMzE3NjkwNTE@._V1_SX300.jpg',
#  'Production': 'Bloodvine Media',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.3/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '40%'}],
#  'Released': '23 Apr 2015',
#  'Response': 'True',
#  'Runtime': '82 min',
#  'Title': '1915',
#  'Type': 'movie',
#  'Website': 'http://www.1915themovie.com/',
#  'Writer': 'Garin Hovannisian, Alec Mouhibian',
#  'Year': '2015',
#  'imdbID': 'tt3781762',
#  'imdbRating': '4.3',
#  'imdbVotes': '4,462'}
# -------------------
# movie id tt5085766
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Stefan Kristinkov',
#  'Genre': 'Adventure, Drama, Sci-Fi',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BM2JlYzI1ZDYtMDQwMy00ODRjLWJhODktNDJmZmNmZmYxMDQ1XkEyXkFqcGdeQXVyNTM2MTkxNDM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '94 min',
#  'Title': '1:31 Am',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Stefan Kristinkov',
#  'Year': '2015',
#  'imdbID': 'tt5085766',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3798912
# -------------------
# {'Actors': 'Jeff Bowser, Elaine Kao, Judith Cubas Jones, Elizabeth Sandy',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'James Huang, Elizabeth Sandy',
#  'Genre': 'Comedy, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A hopeless romantic and enthusiastic documentary filmmaker creates a '
#          "new T.V. show called '1st Date' to usher more love into the world by "
#          'merging the art of Cinema Verite with the popular ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTgwMzI2NzY2NV5BMl5BanBnXkFtZTgwMDQwOTI0MzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.0/10'}],
#  'Released': '11 Jan 2015',
#  'Response': 'True',
#  'Runtime': '89 min',
#  'Title': '1st Date',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'James Huang (story)',
#  'Year': '2015',
#  'imdbID': 'tt3798912',
#  'imdbRating': '4.0',
#  'imdbVotes': '9'}
# -------------------
# movie id tt4926610
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Brian J. Leitten',
#  'Genre': 'Sport',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The Gold Rush Expedition Race is one of the foremost expedition '
#          'races in the world. This documentary features an international field '
#          'of 20 elite athletes tackling a grueling 125-mile course...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '66 min',
#  'Title': '2014 Gold Rush Expedition Race',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2015',
#  'imdbID': 'tt4926610',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6361988
# -------------------
# {'Actors': 'Olivia Hussey, Charon Aldredge, Anthony Cheeks, Amanda LaCount',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Charon Aldredge',
#  'Genre': 'Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '15 Jan 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '2015 Dancing Dolls a Christmas Story',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Charon Aldredge',
#  'Year': '2015',
#  'imdbID': 'tt6361988',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4423458
# -------------------
# {'Actors': "'Bee One Boyefio Borketey, Massiel Checo, Gary Davis, Divendre "
#            'Hernandez',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Gary Davis',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '25 Feb 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '2053 More Girls, a Dragon & a Fisherman',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Gary Davis, Chin Li',
#  'Year': '2015',
#  'imdbID': 'tt4423458',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4460384
# -------------------
# {'Actors': "'Bee One Boyefio Borketey, Massiel Checo, Gary Davis, Divendre "
#            'Hernandez',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Gary Davis',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Two deadly enemies are back from the dead: Viejo-The old man and '
#          'General Lee. Once again they face off for an epic battle between '
#          'good and evil. meanwhile... the military is back as well, ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '26 Feb 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '2053 Viejo the Black Samurai',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Gary Davis, Chin Li',
#  'Year': '2015',
#  'imdbID': 'tt4460384',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4714278
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Angeline Walsh',
#  'Genre': 'Comedy, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'After the death of her filmmaker grandfather, a modern-day girl '
#          'discovers a mysterious old film reel which magically transports her '
#          'into a silent-era film where she discovers that the events within '
#          'the film mirror her life in reality.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '21st Century Spectacle',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Angeline Walsh',
#  'Year': '2015',
#  'imdbID': 'tt4714278',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3515632
# -------------------
# {'Actors': 'Tom Sizemore, Mischa Barton, Timothy Woodward Jr., Michael Paré',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '29 Sep 2015',
#  'Director': 'Timothy Woodward Jr.',
#  'Genre': 'Action, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A non-stop, race against time action packed thriller that follows an '
#          'elite SWAT Team as they try to stop a domestic terrorist from '
#          'killing innocent hostages and destroying the city of Los ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzAyMTg3MjQ3OF5BMl5BanBnXkFtZTgwMzc3MDQzNTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.0/10'}],
#  'Released': '29 Sep 2015',
#  'Response': 'True',
#  'Runtime': '96 min',
#  'Title': 'SWAT: Unit 887',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Lauren De Normandie (screenplay)',
#  'Year': '2015',
#  'imdbID': 'tt3515632',
#  'imdbRating': '3.0',
#  'imdbVotes': '593'}
# -------------------
# movie id tt5588416
# -------------------
# {'Actors': 'Vince Arians, Chamar Avery, Delores Harris, Martell Lane',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Derek Scott',
#  'Genre': 'Action',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': '2ELEVEN IS THE TALE OF TWO BROTHERS HUSTLING TO SURVIVE IN THE '
#          'STREETS OF DETROIT. ZO, THE CALM, AMBITIOUS BROTHER WANTS NOTHING '
#          'MORE THAN TO GIVE HIS DAUGHTER, NATTY, A BETTER LIFE WHILE ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMmRmMDdjMTctMjFhYi00MTVkLTk5MjEtM2JhZmVhMDk1NjdmXkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.2/10'}],
#  'Released': '08 Aug 2015',
#  'Response': 'True',
#  'Runtime': '107 min',
#  'Title': '2Eleven',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2015',
#  'imdbID': 'tt5588416',
#  'imdbRating': '7.2',
#  'imdbVotes': '32'}
# -------------------
# movie id tt3559570
# -------------------
# {'Actors': 'Sam Bearpaw, Madison Brightwell, Jonathan Camp, Erik Estrada',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tom Seidman',
#  'Genre': 'Action, Adventure, Drama, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A desert survival reality show goes horribly wrong.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTExMzcwNTI2NTFeQTJeQWpwZ15BbWU4MDE2NzgxNzUx._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.1/10'}],
#  'Released': '05 May 2015',
#  'Response': 'True',
#  'Runtime': '94 min',
#  'Title': '2Survive',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tom Seidman',
#  'Year': '2015',
#  'imdbID': 'tt3559570',
#  'imdbRating': '5.1',
#  'imdbVotes': '178'}
# -------------------
# movie id tt5785598
# -------------------
# {'Actors': 'Jon Pupillo',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Duane Gaines, Jon Pupillo',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Directed by famed hip-hop director DGainz (Chief Keef, King Louie, '
#          "Timbaland and Tink, Kevin Gates, Lil' Durk, Spenzo, Katy Got Bands "
#          "and many more...) and originator ('Godfather') of ...",
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '57 min',
#  'Title': '3',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jon Pupillo',
#  'Year': '2015',
#  'imdbID': 'tt5785598',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4174536
# -------------------
# {'Actors': 'Johnny Walter, LeMarc Johnson, Natalie Makenna, Dave Pantano',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '21 Mar 2017',
#  'Director': 'Julian Beltran',
#  'Genre': 'Crime, Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A man has died. He must now re-live his last three days on earth '
#          'devoid of his personal memories to determine his place in the after '
#          'life.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTM1YWQyODctZjA1Yy00ZjRlLWFiMWQtYzdmZDI1ZDcwNzVmXkEyXkFqcGdeQXVyMjU1NzExODA@._V1_SX300.jpg',
#  'Production': 'Placid Entertainment',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.6/10'}],
#  'Released': '11 Apr 2015',
#  'Response': 'True',
#  'Runtime': '99 min',
#  'Title': '3 Days',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Julian Beltran, Julian Beltran',
#  'Year': '2015',
#  'imdbID': 'tt4174536',
#  'imdbRating': '5.6',
#  'imdbVotes': '32'}
# -------------------
# movie id tt3554002
# -------------------
# {'Actors': 'Matt License, Jason Gerbay, Brigitte Wilcox, Julia Meyer',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jason Gerbay',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "A new couple's relationship takes a turn for the worst when they "
#          'both love bagels a little too much.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '51 min',
#  'Title': '3 Days Without a Bagel',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jason Gerbay, Matt License',
#  'Year': '2014',
#  'imdbID': 'tt3554002',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4158624
# -------------------
# {'Actors': 'Elle Fanning, Linda Emond, Susan Sarandon, Naomi Watts',
#  'Awards': '1 nomination.',
#  'BoxOffice': '$66,371',
#  'Country': 'USA',
#  'DVD': '13 Jun 2017',
#  'Director': 'Gaby Dellal',
#  'Genre': 'Drama',
#  'Language': 'English, Spanish',
#  'Metascore': '47',
#  'Plot': "After Ray decides to transition from female to male, Ray's mother, "
#          'Maggie, must come to terms with the decision while tracking down '
#          "Ray's biological father to get his legal consent.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk1MTIwOTMwNl5BMl5BanBnXkFtZTgwODQzNjY5MTI@._V1_SX300.jpg',
#  'Production': 'The Weinstein Company',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.9/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '32%'},
#              {'Source': 'Metacritic', 'Value': '47/100'}],
#  'Released': '29 Sep 2016',
#  'Response': 'True',
#  'Runtime': '92 min',
#  'Title': '3 Generations',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Nikole Beckwith, Gaby Dellal',
#  'Year': '2015',
#  'imdbID': 'tt4158624',
#  'imdbRating': '5.9',
#  'imdbVotes': '5,250'}
# -------------------
# movie id tt4074286
# -------------------
# {'Actors': 'Lou Santini, Kristi Slager, Christy Williams, Caitlin Rose '
#            'Williams',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Rob Salerno',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjEwMzI0MDM0NF5BMl5BanBnXkFtZTgwOTU3NzQ5MjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '30 Dates on Craigslist',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ken Napzok, Lou Santini',
#  'Year': '2015',
#  'imdbID': 'tt4074286',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4827758
# -------------------
# {'Actors': 'Stacey Travis, Rick Overton, Joe Alaskey, Greg Travis',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tamas Birinyi',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '02 Dec 2015',
#  'Response': 'True',
#  'Runtime': '50 min',
#  'Title': '30 Years Os Dark Seduction',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2015',
#  'imdbID': 'tt4827758',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4663708
# -------------------
# {'Actors': 'Amir Aghaee, Naser Aghaee, Alireza Ara, Habib Esmaeeli',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'Iran, USA',
#  'DVD': 'N/A',
#  'Director': 'Sam Gharibian',
#  'Genre': 'Crime, Mystery, Thriller',
#  'Language': 'Persian',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'}],
#  'Released': '01 May 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '360 Degree',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Sam Gharibian',
#  'Year': '2015',
#  'imdbID': 'tt4663708',
#  'imdbRating': '6.2',
#  'imdbVotes': '13'}
# -------------------
# movie id tt4546704
# -------------------
# {'Actors': 'Matthew J. Dennis, Scott Baisden, Chris Kotcher, Sheri Beth Dusek',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Daniel Falicki',
#  'Genre': 'Comedy, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'After two years in prison, John Spinelli is a free man. But as he '
#          'grapples with his mad mix of macabre neighbors, John realizes '
#          'something evil governs his new neighborhood. Can he convince ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk0MjgzMTgxMV5BMl5BanBnXkFtZTgwNTgzMTczNjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.2/10'}],
#  'Released': '22 Jun 2015',
#  'Response': 'True',
#  'Runtime': '139 min',
#  'Title': '3:33 a.m.',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Sheri Beth Dusek, Daniel Falicki, Anthony E. Griffin',
#  'Year': '2015',
#  'imdbID': 'tt4546704',
#  'imdbRating': '3.2',
#  'imdbVotes': '61'}
# -------------------
# movie id tt7131618
# -------------------
# {'Actors': 'Felton Young, Neoteric Body Fitness',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tengah Nguyen',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOWVhZTdlZTUtYTFiMi00ODY1LTg5YTgtNzBkMWQ2ZDAyYjA0XkEyXkFqcGdeQXVyNTkxMjIyMzM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '30 Nov 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '3X3 Xcelerate: Burn Outs DVD',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2015',
#  'imdbID': 'tt7131618',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3520008
# -------------------
# {'Actors': 'Janeane Garofalo, Devin Ratray, Henry Zebrowski, Sunita Mani',
#  'Awards': '2 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Negin Farsad, Jeremy Redleaf',
#  'Genre': 'Comedy, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A technology-obsessed couple is forced to examine their relationship '
#          'during a blackout',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYTVhYmVjYTctNWM5MS00ZDUzLWI1NzAtYzlkMzkxOTZlZGQzXkEyXkFqcGdeQXVyNzg2NDkwMw@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.9/10'}],
#  'Released': '13 Jun 2015',
#  'Response': 'True',
#  'Runtime': '87 min',
#  'Title': '3rd Street Blackout',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Negin Farsad, Jeremy Redleaf',
#  'Year': '2015',
#  'imdbID': 'tt3520008',
#  'imdbRating': '6.9',
#  'imdbVotes': '34'}
# -------------------
# movie id tt3774790
# -------------------
# {'Actors': 'Brandon Routh, Dane Cook, Caity Lotz, Ben Feldman',
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Matt Osterman',
#  'Genre': 'Mystery, Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'With their 400-day mission simulation nearing completion, 4 '
#          "astronauts begin to feel something's amiss.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzk5NzM3MDM3OF5BMl5BanBnXkFtZTgwODczNjkxODE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Unrated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.4/10'}],
#  'Released': '15 Jan 2016',
#  'Response': 'True',
#  'Runtime': '91 min',
#  'Title': '400 Days',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Matt Osterman',
#  'Year': '2015',
#  'imdbID': 'tt3774790',
#  'imdbRating': '4.4',
#  'imdbVotes': '9,744'}
# -------------------
# movie id tt2400098
# -------------------
# {'Actors': 'Mercedes Manning, Bruce Lemon, Mashari Laila Bain, Wes Hubbard',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Rashad Humphrey',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A greedy, real estate investor becomes the hostage and blackmail '
#          'victim of a seemingly innocent police man.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc2OTczMDI3Ml5BMl5BanBnXkFtZTcwNTg4MTU0OQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '25 Oct 2015',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': '400 Will Kill You! :)',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Rashad Humphrey (screenplay)',
#  'Year': '2015',
#  'imdbID': 'tt2400098',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4861048
# -------------------
# {'Actors': 'Valentine, Jennifer Copeland, Neb Chupin',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Valentine',
#  'Genre': 'Action',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A female CIA operative seduces a bounty hunter to protect her '
#          "undercover Interpol partner/boyfriend who's infiltrated an Al Qaeda "
#          'terrorist cell in Miami and has a bounty on his head. She ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk0NjM3MzA0NV5BMl5BanBnXkFtZTgwNzM5MzMzNjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.0/10'}],
#  'Released': '15 Jul 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '411',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Valentine',
#  'Year': '2015',
#  'imdbID': 'tt4861048',
#  'imdbRating': '6.0',
#  'imdbVotes': '172'}
# -------------------
# movie id tt4510398
# -------------------
# {'Actors': 'Johnny Messner, Dolph Lundgren, Danny Trejo, Vivica A. Fox',
#  'Awards': '1 win & 1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '06 Oct 2015',
#  'Director': 'Timothy Woodward Jr.',
#  'Genre': 'Action, Thriller, Western',
#  'Language': 'English, Spanish',
#  'Metascore': 'N/A',
#  'Plot': 'A drug deal goes bad, leaving bodies. A sheriff shoots his deputy '
#          'for the money and a wounded amnesiac shoots the sheriff and escapes '
#          'with $3,000,000. DEA investigates as does the drug lord dad of the '
#          'dead deputy.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTY4ODk3MDMzMl5BMl5BanBnXkFtZTgwNzk5MDg3NjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.1/10'}],
#  'Released': '05 Nov 2015',
#  'Response': 'True',
#  'Runtime': '84 min',
#  'Title': '4Got10',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Sean Ryan',
#  'Year': '2015',
#  'imdbID': 'tt4510398',
#  'imdbRating': '4.1',
#  'imdbVotes': '1,910'}
# -------------------
# movie id tt3861124
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Anwar Jamison',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When an immature, underachieving 30-year old man is forced to grow '
#          'up and get a job or risk losing his family, he dives headfirst into '
#          'a job with a cult-like atmosphere and an office full of deceptive '
#          'characters.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '102 min',
#  'Title': '5 Steps to a Conversation',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Anwar Jamison, Anwar Jamison',
#  'Year': '2014',
#  'imdbID': 'tt3861124',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7594322
# -------------------
# {'Actors': 'Wm. Berger, Vanna Blondelle, Rich Carucci, Michael Cucciniello',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Bill Zebub',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYWM5N2ZiODYtYjcxMy00MzQzLWJhMGYtMmQxMWUxN2I2MjM1XkEyXkFqcGdeQXVyMjAwMzU2MDY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.5/10'}],
#  'Released': '27 Oct 2015',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': '50 Shades of Scarlett',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Bill Zebub',
#  'Year': '2015',
#  'imdbID': 'tt7594322',
#  'imdbRating': '3.5',
#  'imdbVotes': '13'}
# -------------------
# movie id tt6426768
# -------------------
# {'Actors': 'Vernon Snoop Robinson, Raison Thompson, Autumn Cannon, Danielle '
#            'Roberson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jomae Scott',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '06 Apr 2015',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': '57',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jomae Scott',
#  'Year': '2015',
#  'imdbID': 'tt6426768',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3550902
# -------------------
# {'Actors': 'Vinnie Jones, Vivica A. Fox, Dominique Swain, Bai Ling',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '25 Aug 2015',
#  'Director': 'Nadeem Soumah',
#  'Genre': 'Crime, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Mystery man John Doe wants 6 things taken from the top North '
#          'American narcotics distributor Sunny "Sundown" Garcia: his freedom, '
#          'his love, his reputation, his most valuable possession, his money '
#          'and his life.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTA3ODQ1MDAzNzZeQTJeQWpwZ15BbWU4MDE1NzU1OTkx._V1_SX300.jpg',
#  'Production': 'Entertainment One',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.0/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '40%'}],
#  'Released': '31 Jul 2015',
#  'Response': 'True',
#  'Runtime': '103 min',
#  'Title': '6 Ways to Die',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Nadeem Soumah',
#  'Year': '2015',
#  'imdbID': 'tt3550902',
#  'imdbRating': '4.0',
#  'imdbVotes': '816'}
# -------------------
# movie id tt3799372
# -------------------
# {'Actors': 'Taissa Farmiga, Ben Rosenfield, Lindsay Burdge, Joshua Leonard',
#  'Awards': '4 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '12 Apr 2016',
#  'Director': 'Hannah Fidell',
#  'Genre': 'Drama, Romance',
#  'Language': 'English',
#  'Metascore': '53',
#  'Plot': 'A young couple, bound by a seemingly ideal love, begin to unravel as '
#          'unexpected opportunities spin them down a volatile and violent path '
#          'and threaten the future they had always imagined.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTYzMTMwMDMzMF5BMl5BanBnXkFtZTgwNDc4MjUzNjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '69%'},
#              {'Source': 'Metacritic', 'Value': '53/100'}],
#  'Released': '18 Aug 2015',
#  'Response': 'True',
#  'Runtime': '79 min',
#  'Title': '6 Years',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Hannah Fidell',
#  'Year': '2015',
#  'imdbID': 'tt3799372',
#  'imdbRating': '5.6',
#  'imdbVotes': '10,487'}
# -------------------
# movie id tt3685622
# -------------------
# {'Actors': 'Tim Roth, Kristyan Ferrer, Alan Carlson, Mónica Del Carmen',
#  'Awards': '9 wins & 21 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'Mexico, USA',
#  'DVD': '05 Jul 2016',
#  'Director': 'Gabriel Ripstein',
#  'Genre': 'Drama, Thriller',
#  'Language': 'Spanish, English',
#  'Metascore': 'N/A',
#  'Plot': 'Arnulfo Rubio smuggles weapons for a deadly Mexican cartel. ATF '
#          'agent Hank Harris attempts to apprehend him, but gets kidnapped by '
#          'Rubio, instead. Rubio takes him to his bosses, but during the '
#          '600-miles-long drive, they slowly befriend.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjEzNTgxMDQ0NF5BMl5BanBnXkFtZTgwNzM2NzkyNzE@._V1_SX300.jpg',
#  'Production': 'Lucia Films',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.5/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '94%'}],
#  'Released': '05 Jul 2016',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': '600 Miles',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Gabriel Ripstein, Gabriel Ripstein (screenplay), Issa López '
#            '(screenplay)',
#  'Year': '2015',
#  'imdbID': 'tt3685622',
#  'imdbRating': '5.5',
#  'imdbVotes': '2,079'}
# -------------------
# movie id tt4685626
# -------------------
# {'Actors': 'Rosebud Baker, Matt Riker, Ben Samuels, Montana Marks',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'Canada, USA',
#  'DVD': 'N/A',
#  'Director': 'Ben Samuels',
#  'Genre': 'Action, Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An emotionally damaged couple try to survive a viral outbreak on an '
#          'isolated farm in this innovative, immersive one-shot, real-time POV '
#          'zombie thriller.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTA0ODA4NjQ1OV5BMl5BanBnXkFtZTgwNjY0MTc2NjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '83 min',
#  'Title': '6:15',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ben Samuels',
#  'Year': '2015',
#  'imdbID': 'tt4685626',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5379194
# -------------------
# {'Actors': 'Alyson Danielczuk',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kseniya V. Crespo',
#  'Genre': 'Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
# ...
#  'Released': '01 May 2015',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Elixir',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Erin Lynn Doyle (screenplay), Erin Lynn Doyle, Alyssa Hingre, '
#            'Alyssa Hingre (screenplay), Alyssa Hingre, Matthew Keim '
#            '(screenplay), Matthew Keim, Matthew Lipke (screenplay), Matthew '
#            'Lipke',
#  'Year': '2015',
#  'imdbID': 'tt4332794',
#  'imdbRating': '8.5',
#  'imdbVotes': '6'}
# -------------------
# movie id tt4526858
# -------------------
# {'Actors': 'Sophia Hubert, Suzette Brown, Shannon Brown, Jennifer Lenius',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Brad Scriffiano',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjE0MDcwNTE3OF5BMl5BanBnXkFtZTgwOTA3ODE5NDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Elizabeth',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Brad Scriffiano',
#  'Year': '2015',
#  'imdbID': 'tt4526858',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3503460
# -------------------
# {'Actors': 'Jason Ritter, Iva Gocheva, Greta Fernández, Tucker Smallwood',
#  'Awards': '18 wins & 10 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'Poland, USA',
#  'DVD': 'N/A',
#  'Director': 'Claire Carré',
#  'Genre': 'Drama, Sci-Fi',
#  'Language': 'English',
#  'Metascore': '55',
#  'Plot': 'After a global neurological epidemic, those who remain search for '
#          'meaning and connection in a world without memory.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjEzMzcwNTI5OF5BMl5BanBnXkFtZTgwMzY1NzE2OTE@._V1_SX300.jpg',
#  'Production': 'Chaotic Good',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '86%'},
#              {'Source': 'Metacritic', 'Value': '55/100'}],
#  'Released': '16 Oct 2015',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': 'Embers',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Charles Spano, Claire Carré',
#  'Year': '2015',
#  'imdbID': 'tt3503460',
#  'imdbRating': '5.4',
#  'imdbVotes': '1,858'}
# -------------------
# movie id tt4503598
# -------------------
# {'Actors': 'Carly Adams, Elisha Ali, Tyler Aser, Carl Bailey',
#  'Awards': '3 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '03 May 2016',
#  'Director': 'Michael Thelin',
#  'Genre': 'Horror, Thriller',
#  'Language': 'English',
#  'Metascore': '62',
#  'Plot': "A couple's replacement babysitter turns out to be more than they "
#          'bargained for when she subjects their kids to a series of twisted '
#          'activities.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjIwNzUzOTY1MV5BMl5BanBnXkFtZTgwODU2NzYxNzE@._V1_SX300.jpg',
#  'Production': 'Uncorked Productions',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '88%'},
#              {'Source': 'Metacritic', 'Value': '62/100'}],
#  'Released': '04 Mar 2016',
#  'Response': 'True',
#  'Runtime': '82 min',
#  'Title': 'Emelie',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Richard Raymond Harry Herbeck (screenplay by), Richard Raymond '
#            'Harry Herbeck (story by), Michael Thelin (story by)',
#  'Year': '2015',
#  'imdbID': 'tt4503598',
#  'imdbRating': '5.4',
#  'imdbVotes': '12,468'}
# -------------------
# movie id tt3000308
# -------------------
# {'Actors': 'Kathleen Turner, Zosia Mamet, Thomas Mann, Jeremy Jordan',
#  'Awards': '1 win & 1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Eric Weber, Sean Devaney(co-director)',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A look at the tumultuous marriage of Tim and Emily Hanratty over '
#          'half a century.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYjE2ODM5YTctOWUzYS00OGJkLWEyYzgtZDg4MTgwZDUwMzdmXkEyXkFqcGdeQXVyMjA4MzM2NzQ@._V1_SX300.jpg',
#  'Production': 'Marvista Entertainment',
#  'Rated': 'Unrated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.0/10'}],
#  'Released': '12 Aug 2016',
#  'Response': 'True',
#  'Runtime': '87 min',
#  'Title': 'Emily & Tim',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Eric Weber, Eric Weber',
#  'Year': '2015',
#  'imdbID': 'tt3000308',
#  'imdbRating': '6.0',
#  'imdbVotes': '205'}
# -------------------
# movie id tt3176586
# -------------------
# {'Actors': "Kelsey O'Brien, Cat Cabral, Kevin Brown, Ronn Burton",
#  'Awards': '1 win.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': "Kelsey O'Brien",
#  'Genre': 'Comedy, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Enchantments is a romantic comedy loosely based on Jane Austen's "
#          '1815 novel Emma. Emma is now a pop culture loving, rom com obsessed, '
#          'Zen seeking Wiccan lesbian living in New York City and working in a '
#          'magic shop called Enchantments.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjA0NDMwODI1M15BMl5BanBnXkFtZTgwNjM2Nzc4NTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '77 min',
#  'Title': 'Enchantments',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': "Kelsey O'Brien",
#  'Year': '2015',
#  'imdbID': 'tt3176586',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2941396
# -------------------
# {'Actors': 'Dimitri Agado, Cassie Brennan, Ivan Cisneros, Ivonne Coll',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '05 Jan 2016',
#  'Director': 'Carmen Marrón',
#  'Genre': 'Biography, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Since he was 5 yrs old, Jose's abuelita taught him to play chess "
#          'like his grandfather who was a champion in Mexico. Now as part of '
#          'the Brownsville school team, Jose has the chance to use ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODkyMDk1MTk0OV5BMl5BanBnXkFtZTgwOTI1NjU4NjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '50%'}],
#  'Released': '25 Sep 2015',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Endgame',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Carmen Marrón, Hector Salinas (story), Hector Salinas',
#  'Year': '2015',
#  'imdbID': 'tt2941396',
#  'imdbRating': '5.4',
#  'imdbVotes': '297'}
# -------------------
# movie id tt4122788
# -------------------
# {'Actors': 'Bojesse Christopher, Nick Daly, Suzanne Didonna, Gabe Fazio',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Scott Beardslee',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '10 Apr 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Endless',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Todd Jeffery',
#  'Year': '2015',
#  'imdbID': 'tt4122788',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5207964
# -------------------
# {'Actors': 'Gabriel Michael, Andrew Nathaneal',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'G.M. Whiting',
#  'Genre': 'Drama, Fantasy, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When Adam (Gabriel Michael, The Nether Experiment) a history '
#          'teacher, finds a DVD he received from UPS Shipping, to discover that '
#          "there's an actor that looks exactly like him. When he comes...",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjk1MDQzYzEtNDE1Mi00MTI3LTgwZGEtM2U0NzI2NzQzZDExXkEyXkFqcGdeQXVyNTU2NDc0NDc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.9/10'}],
#  'Released': '26 May 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Enemy',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'G.M. Whiting',
#  'Year': '2015',
#  'imdbID': 'tt5207964',
#  'imdbRating': '5.9',
#  'imdbVotes': '16'}
# -------------------
# movie id tt3601848
# -------------------
# {'Actors': "Morgan Nichols, Adam Ginsberg, Reanna Armellino, Donna O'Rourke",
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ron Scott Smith',
#  'Genre': 'Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A bible sales man scours a local neighborhood in an attempt to '
#          'cleanse the world of sin.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjAwOTE1MTM2OF5BMl5BanBnXkFtZTgwMTkxMDQ3MjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '08 Jan 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Enlightened',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ron Scott Smith',
#  'Year': '2015',
#  'imdbID': 'tt3601848',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3343784
# -------------------
# {'Actors': 'Gregg Turkington, John C. Reilly, Tye Sheridan, Lotte Verbeek',
#  'Awards': '1 win & 3 nominations.',
#  'BoxOffice': '$55,506',
#  'Country': 'USA',
#  'DVD': '23 Feb 2016',
#  'Director': 'Rick Alverson',
#  'Genre': 'Drama',
#  'Language': 'English, Spanish',
#  'Metascore': '65',
#  'Plot': 'En route to meet his estranged daughter and attempting to revive his '
#          'dwindling career, a broken, middle-aged comedian plays a string of '
#          'dead-end shows in the Mojave desert.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTA5OTEyMTQwODFeQTJeQWpwZ15BbWU4MDA0MzMyNDYx._V1_SX300.jpg',
#  'Production': 'Magnolia Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '83%'},
#              {'Source': 'Metacritic', 'Value': '65/100'}],
#  'Released': '13 Nov 2015',
#  'Response': 'True',
#  'Runtime': '103 min',
#  'Title': 'Entertainment',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Rick Alverson, Gregg Turkington, Tim Heidecker',
#  'Year': '2015',
#  'imdbID': 'tt3343784',
#  'imdbRating': '5.6',
#  'imdbVotes': '2,537'}
# -------------------
# movie id tt1674771
# -------------------
# {'Actors': 'Kevin Connolly, Adrian Grenier, Kevin Dillon, Jerry Ferrara',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '29 Sep 2015',
#  'Director': 'Doug Ellin',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': '38',
#  'Plot': 'Movie star Vincent Chase, together with his boys Eric, Turtle, and '
#          'Johnny, are back - and back in business with super '
#          'agent-turned-studio head Ari Gold on a risky project that will serve '
#          "as Vince's directorial debut.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMGY5ZmE4ZWItYzU0YS00ZDczLThiMzctMzQyYjJkNGYzNGQ2XkEyXkFqcGdeQXVyMzI2MTMxNTM@._V1_SX300.jpg',
#  'Production': 'Warner Bros. Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '33%'},
#              {'Source': 'Metacritic', 'Value': '38/100'}],
#  'Released': '03 Jun 2015',
#  'Response': 'True',
#  'Runtime': '104 min',
#  'Title': 'Entourage',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Doug Ellin (screenplay), Doug Ellin (story), Rob Weiss (story), '
#            'Doug Ellin (based on characters created by)',
#  'Year': '2015',
#  'imdbID': 'tt1674771',
#  'imdbRating': '6.6',
#  'imdbVotes': '73,154'}
# -------------------
# movie id tt3289728
# -------------------
# {'Actors': 'Nicholas Hoult, Vernetta Lopez, Scott Lawrence, Kate Lyn Sheil',
#  'Awards': '1 win & 5 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Indonesia',
#  'DVD': '06 Sep 2016',
#  'Director': 'Drake Doremus',
#  'Genre': 'Drama, Romance, Sci-Fi',
#  'Language': 'English',
#  'Metascore': '43',
#  'Plot': 'In an emotionless utopia, two people fall in love when they regain '
#          'their feelings from a mysterious disease, causing tensions between '
#          'them and their society.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg3NTQ5MDU3OF5BMl5BanBnXkFtZTgwODc2Mzk5NzE@._V1_SX300.jpg',
#  'Production': 'A24 and DIRECTV',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '35%'},
#              {'Source': 'Metacritic', 'Value': '43/100'}],
#  'Released': '26 May 2016',
#  'Response': 'True',
#  'Runtime': '101 min',
#  'Title': 'Equals',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Nathan Parker (screenplay by), Drake Doremus (story by)',
#  'Year': '2015',
#  'imdbID': 'tt3289728',
#  'imdbRating': '6.1',
#  'imdbVotes': '25,172'}
# -------------------
# movie id tt4666748
# -------------------
# {'Actors': 'Addison Graham, Grayson Lange, Cory Tyndall, Clay Yearwood',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Steven Vasquez',
#  'Genre': 'Drama, Horror, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Follows the lives of several gay youths and adults as they discover '
#          'a world of the odd, the erotic and the supernatural.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg0NDU2MjcyN15BMl5BanBnXkFtZTgwNDY4NTc2NTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Unrated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.7/10'}],
#  'Released': '24 Nov 2015',
#  'Response': 'True',
#  'Runtime': '94 min',
#  'Title': 'ErOddity(s) 2',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Steven Vasquez',
#  'Year': '2015',
#  'imdbID': 'tt4666748',
#  'imdbRating': '4.7',
#  'imdbVotes': '56'}
# -------------------
# movie id tt6315550
# -------------------
# {'Actors': 'Maria Alexandra, Estrella Almada Cervantes, Pablo Esparza, Favian '
#            'Flores',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Carlos Quintanilla',
#  'Genre': 'Action',
#  'Language': 'English, Spanish',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNGJkYWE3ZjctYmU0ZS00YzkwLThjMWUtNjcwYzRhOThiZGIyL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNTMyNzEwNzk@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Oct 2015',
#  'Response': 'True',
#  'Runtime': '120 min',
#  'Title': 'Errores de Adolescencia',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Victor H. Mexicano',
#  'Year': '2015',
#  'imdbID': 'tt6315550',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5509726
# -------------------
# {'Actors': 'Ben Anderson, Chris Arrowood, Don Atkinson, Michael Banks',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Daniel Brown',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzhiMTc3YjUtODdiOC00NDI2LWI0NDMtNDU1MGRlMTdlMTI4XkEyXkFqcGdeQXVyMjczNzk0MTc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '18 Sep 2015',
#  'Response': 'True',
#  'Runtime': '113 min',
#  'Title': 'Escape from the Dead V2',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Daniel Brown, Joshua Brown',
#  'Year': '2015',
#  'imdbID': 'tt5509726',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4809298
# -------------------
# {'Actors': 'Kalyar Khin Nwe, Tie Richards, Soungoo Thazin',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kevin L. Swann',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Sep 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Eternal Tears',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Sam Tong',
#  'Year': '2015',
#  'imdbID': 'tt4809298',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}

# %%
len(title_list)
# Out:
# 999

# %%
len(title_id)
# Out:
# 999

# %%
# if title_list and title_id are the same length run the cell below. 
# if they are not equal take out 'title_id': title_id

# %%
df = pd.DataFrame({'title_id': title_id, 'title': title_list, 'box_office': box_office_list, 'country': country_list, 
                   'genre': genre_list, 'director': director_list, 'metascore': metascore_list, 'production': production_list, 
                   'rating': rating_list, 'IMDB_rating': IMDB_rating_list, 'rotten_tomatoes_rating': rotten_tomatoes_rating_list, 
                  'runtime': runtime_list, 'type': type_list, 'IMDB_votes': imdb_votes_list})

# %%
df = df.drop_duplicates()
df.head()
# Out:
#     title_id          title box_office country  \
# 0  tt4470336     #50Fathers        N/A     USA
# 1  tt5460468        #Enough        N/A     USA
# 2  tt3526286        #Horror        N/A     USA
# 3  tt2538204  #Lucky Number        N/A     USA
# 4  tt5466780     #Standards        N/A     USA
#
#                                      genre                director metascore  \
# 0                                   Comedy     Joddy Eric Matthews       N/A
# 1                                    Drama        Miranda Ferguson       N/A
# 2  Crime, Drama, Horror, Mystery, Thriller            Tara Subkoff        42
# 3                                   Comedy  Brendan Gabriel Murphy       N/A
# 4                                    Drama            Melanie Page       N/A
#
#   production     rating IMDB_rating rotten_tomatoes_rating  runtime   type  \
# 0        N/A        N/A         N/A                     NA  132 min  movie
# 1        N/A        N/A         N/A                     NA      N/A  movie
# 2        N/A  Not Rated         3.0                     NA  101 min  movie
# 3        N/A      TV-14         5.0                     NA   80 min  movie
# 4        N/A        N/A         N/A                     NA   50 min  movie
#
#   IMDB_votes
# 0        N/A
# 1        N/A
# 2      3,218
# 3        435
# 4        N/A

# %%
df.count()
# Out:
# title_id                  999
# title                     999
# box_office                999
# country                   999
# genre                     999
# director                  999
# metascore                 999
# production                999
# rating                    999
# IMDB_rating               999
# rotten_tomatoes_rating    999
# runtime                   999
# type                      999
# IMDB_votes                999
# dtype: int64

# %%
df.to_csv('../data/2014_data_batch_2.csv', index=False)
