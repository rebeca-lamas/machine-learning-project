# %%
import pandas as pd
import requests
import json
import time
from pprint import pprint
from config import API_KEY

# %%
data = pd.read_csv('../data/titles_2014_batch2.csv')
df =  data.count()
df
# Out:
# title    1000
# dtype: int64

# %%
title_id = []
box_office_list = []
country_list = []
genre_list = []
director_list = []
metascore_list = []
production_list = []
rating_list = []
IMDB_rating_list = [] 
rotten_tomatoes_rating_list = []
runtime_list = []
title_list = []
type_list = []
imdb_votes_list = []

# %%
movies = data['title']
total_movies = len(movies)

# %%
for i in range(total_movies):
    movie = movies[i]
    url = "http://www.omdbapi.com/?i=" + movie + "&apikey=" + API_KEY
    response = (requests.get(url).text)
    response_json = json.loads(response)
    print('-------------------')
    print(f'movie id {movie}')
    print('-------------------')
    pprint(response_json)
    
    try:
        box_office_list.append(response_json['BoxOffice'])
        country_list.append(response_json['Country'])
        genre_list.append(response_json['Genre'])
        director_list.append(response_json['Director'])
        metascore_list.append(response_json['Metascore'])
        production_list.append(response_json['Production'])
        rating_list.append(response_json['Rated'])
        IMDB_rating_list.append(response_json['imdbRating'])
        try:
            if not response_json['Ratings']:
                rotten_tomatoes_rating_list.append('NA')
            elif response_json['Ratings'][0]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][0]['Value'])
            elif response_json['Ratings'][1]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][1]['Value'])
            else:
                rotten_tomatoes_rating_list.append('NA')
        except IndexError:
            rotten_tomatoes_rating_list.append('NA')
        runtime_list.append(response_json['Runtime'])
        title_list.append(response_json['Title'])
        type_list.append(response_json['Type'])
        imdb_votes_list.append(response_json['imdbVotes'])
        title_id.append(response_json['imdbID'])
    except KeyError:
        pass
    time.sleep(1)
# Out:
# -------------------
# movie id tt3907106
# -------------------
# {'Actors': 'Brady Klopfer, Christopher Lee Page, Anna Clols, Harvey Q. Johnson',
#  'Awards': '1 win.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Michael Yates',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Ambitious students Marcel and Andre travel to California's Channel "
#          'Islands to investigate a mysterious environmental threat. Cut off '
#          'from society and entranced by an enigmatic woman also ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODc2OTE2MzQ1Ml5BMl5BanBnXkFtZTgwMDE1MDczMjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Sep 2014',
#  'Response': 'True',
#  'Runtime': '112 min',
#  'Title': 'Floreana',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Travis Blue',
#  'Year': '2014',
#  'imdbID': 'tt3907106',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3657522
# -------------------
# {'Actors': 'Kara Camden, Catherine Jean Elder, Brie Linn',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Peggy Walkush',
#  'Genre': 'Short',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'Excited to give her teacher a special flower on Teacher Appreciation '
#          'Day, 11 year old Mia (Brie Linn) meets with an unexpected disaster '
#          'that threatens to derail her plan and ruin her day.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjI2MDgwNTQyNF5BMl5BanBnXkFtZTgwMjM5MTc4MTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Flower Power',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'R. Lin',
#  'Year': '2014',
#  'imdbID': 'tt3657522',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2409812
# -------------------
# {'Actors': 'Lindsay Pulsipher, Glenn Morshower, Charles Baker, Clem Beard',
#  'Awards': '2 wins.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '12 Jan 2016',
#  'Director': 'Eric Hueber',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'With her husband away indefinitely, a young mother struggles to '
#          'nurture her son in the face of poverty, isolation and incarceration. '
#          'FLUTTER explores the truest love on earth-the love of a mother and '
#          'child.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjE1MjY0Nzc4Nl5BMl5BanBnXkFtZTgwOTY5NjkyMDE@._V1_SX300.jpg',
#  'Production': 'Xlrator Media',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.9/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '60%'}],
#  'Released': '04 Apr 2014',
#  'Response': 'True',
#  'Runtime': '96 min',
#  'Title': 'Flutter',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tony Franklin Jr. (story), Eric Hueber (story), Eric Hueber',
#  'Year': '2014',
#  'imdbID': 'tt2409812',
#  'imdbRating': '5.9',
#  'imdbVotes': '340'}
# -------------------
# movie id tt4073764
# -------------------
# {'Actors': 'Mike Dell, Chris Doubek, Matthew Grathwol, Kaylee Grossman',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jonny Mars',
#  'Genre': 'Comedy, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'After an accident involving a gun on the set of a B-movie leaves the '
#          '1ST AC position vacant, 2ND AC and boy-next-door Charlie Dunlap gets '
#          'promoted. This places him squarely in the sights of...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Focus Puller',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jonny Mars, Joshua Weber',
#  'Year': '2014',
#  'imdbID': 'tt4073764',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4355544
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Nick Sung',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '11 Jun 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Footnotes of an Ornament',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Nick Sung',
#  'Year': '2014',
#  'imdbID': 'tt4355544',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7714448
# -------------------
# {'Actors': 'Anne Campbell, Jack Caulkins, Clara Dunham, Michael Sean Erickson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Lois Reed',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'DVD of a theatrical performance in San Miguel de Allende, Mexico.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOWNiNjBkN2YtZGRhNC00MWIxLTk3ZTUtNDE2YjdkZGQzYzFmXkEyXkFqcGdeQXVyNjU0NTY4MDY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '06 Mar 2014',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'For Better',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2014',
#  'imdbID': 'tt7714448',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3130598
# -------------------
# {'Actors': 'Denise Boutte, Lavell Crawford, Brely Evans, Thomas Mikal Ford',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Roger Melvin',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Tina seems to have it all: booming business, lots of money, and a '
#          'great man, Russell, that loves her. So it was no surprised when she '
#          "was nominated for Mocha Magazine's Woman of year. But ...",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODQwOTc0NzkzMl5BMl5BanBnXkFtZTgwMzM1NzUzMTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'NOT RATED',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.7/10'}],
#  'Released': '01 Apr 2014',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'For Love or Money',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': "Je'Caryous Johnson",
#  'Year': '2014',
#  'imdbID': 'tt3130598',
#  'imdbRating': '5.7',
#  'imdbVotes': '15'}
# -------------------
# movie id tt2258130
# -------------------
# {'Actors': 'B.K-McKee, Patrick Bannister, Thomas Blank, Lindsay Denman',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'John Sheehan',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An unemployed lawyer attempts to make a movie in an effort to get '
#          'closer to his new crush--an independent film actress.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzcxMTI4MTE0NV5BMl5BanBnXkFtZTgwNTQ4NTg2MjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': 'For Serious',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'John Sheehan',
#  'Year': '2014',
#  'imdbID': 'tt2258130',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3717236
# -------------------
# {'Actors': 'James Han, Erica Jennifer Hill, Ryohei Hoshi, Anabelle LeMieux',
#  'Awards': '2 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Bingham Bryant, Kyle Molzan',
#  'Genre': 'Comedy, Drama, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A digital-pastoral drama of friendship, landscape and technology, '
#          '"For the Plasma" begins as the story of two young women (Anabelle '
#          'LeMieux and Rosalie Lowe) employed as forest-fire ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTU3OTk1Njc1MF5BMl5BanBnXkFtZTgwMDc1MjQzNzE@._V1_SX300.jpg',
#  'Production': 'Artists Public Domain',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '59%'}],
#  'Released': '21 Jun 2014',
#  'Response': 'True',
#  'Runtime': '94 min',
#  'Title': 'For the Plasma',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Bingham Bryant',
#  'Year': '2014',
#  'imdbID': 'tt3717236',
#  'imdbRating': '6.1',
#  'imdbVotes': '37'}
# -------------------
# movie id tt5509844
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tony Picciotti',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Gay, Christian, Muslim, and bigotry don't mix",
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Oct 2014',
#  'Response': 'True',
#  'Runtime': '98 min',
#  'Title': 'Forbidden',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2014',
#  'imdbID': 'tt5509844',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt1651123
# -------------------
# {'Actors': 'Michael Imperioli, Wendell Pierce, Bill Raymond, Meital Dohan',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '10 Feb 2015',
#  'Director': 'Richard Ledes',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The story of a broken family striving to stay together while a curse '
#          'and the ghosts of a haunted house try to tear them apart.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQzNTE4MzU0MV5BMl5BanBnXkFtZTgwMTU0NjIzNDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'NOT RATED',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'}],
#  'Released': '03 Feb 2014',
#  'Response': 'True',
#  'Runtime': '86 min',
#  'Title': 'Foreclosure',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Richard Ledes (screenplay)',
#  'Year': '2014',
#  'imdbID': 'tt1651123',
#  'imdbRating': '5.4',
#  'imdbVotes': '36'}
# -------------------
# movie id tt3453790
# -------------------
# {'Actors': 'Bayliss Grove, Haley Parker, Nadia Rochelle Pfarr, Marie Reyes',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Christopher Michael Roybal',
#  'Genre': 'Drama, Family, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Chapter 1 of the Beautiful Things trilogy introduces us to The Man '
#          "and his young daughter. A daughter he didn't know existed. A "
#          'daughter who claims that he killed her, and then disappears. ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '06 Jun 2014',
#  'Response': 'True',
#  'Runtime': '86 min',
#  'Title': 'Forever Your Love',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Christopher Michael Roybal',
#  'Year': '2014',
#  'imdbID': 'tt3453790',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3089954
# -------------------
# {'Actors': 'Kirt Kishita, Glenn Zhang, Sherry C. Brown, Zhou Jie',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, China',
#  'DVD': 'N/A',
#  'Director': 'Cici Zhu',
#  'Genre': 'Comedy, Drama, Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "A story about a young Chinese immigrant woman's life after placing a "
#          'personal ad for marriage and marrying an older Chinese man to get '
#          'into the States. Things get complicated when she meets...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Forget Me Not',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Cici Zhu',
#  'Year': '2013',
#  'imdbID': 'tt3089954',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4134856
# -------------------
# {'Actors': 'Yannis Stankoglou, Aliki Danezi-Knutsen, Elias Moraitis, Bria '
#            'Hobgood',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'Greece, USA',
#  'DVD': 'N/A',
#  'Director': 'Yannis Fagras',
#  'Genre': 'Adventure, Drama',
#  'Language': 'English, Greek, Russian',
#  'Metascore': 'N/A',
#  'Plot': 'A road movie at sea and a love adventure. The story of two lovers at '
#          "the world's edge. Shot on location in the North Pacific, the Bering "
#          'Sea, Alaska and New Orleans. A myth that knows no borders, handmade '
#          'on 35mm film.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.3/10'}],
#  'Released': '29 Oct 2015',
#  'Response': 'True',
#  'Runtime': '102 min',
#  'Title': 'Forget Me Not',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Yannis Fagras',
#  'Year': '2014',
#  'imdbID': 'tt4134856',
#  'imdbRating': '5.3',
#  'imdbVotes': '29'}
# -------------------
# movie id tt2672326
# -------------------
# {'Actors': 'Jasmin Savoy Brown, Paul Bright, Patrick D. Green, Mathew Bostrom',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Paul Bright',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Based on the true story of an Iraq War vet's tragic attempt to "
#          'rebuild a life back in the U.S. Hungry, homeless, and plagued by '
#          'traumatic flashbacks, he needs a place to recover, somewhere he can '
#          'feel safe.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQxNTEwNDY3Nl5BMl5BanBnXkFtZTcwMDQwMDgwOQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'}],
#  'Released': '01 Jun 2014',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': 'Forgotten Hero',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Paul Bright',
#  'Year': '2014',
#  'imdbID': 'tt2672326',
#  'imdbRating': '5.8',
#  'imdbVotes': '8'}
# -------------------
# movie id tt3295088
# -------------------
# {'Actors': 'Anissa Smith, Jamal Blair, Khadijjah Mote, Gloria Chung',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jamal Blair',
#  'Genre': 'Action, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Mankind's forgotten past is affecting its future as one young man "
#          'finds himself caught in the middle of a war between descendants of '
#          'the original humans.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '98 min',
#  'Title': 'Forgotten Kingdom',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jamal Blair',
#  'Year': '2013',
#  'imdbID': 'tt3295088',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4401170
# -------------------
# {'Actors': 'Nadeer Bacchus, Anna Bissesar, Paul Budnah, Sean Budnah',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Mahadeo Shivraj',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '26 Jul 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Forgotten Promise',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Somnauth Narine',
#  'Year': '2014',
#  'imdbID': 'tt4401170',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2093995
# -------------------
# {'Actors': 'Michelle Monaghan, Emmanuelle Chriqui, Pablo Schreiber, Ron '
#            'Livingston',
#  'Awards': '4 wins.',
#  'BoxOffice': 'N/A',
#  'Country': 'Turkey, USA',
#  'DVD': '14 Oct 2014',
#  'Director': 'Claudia Myers',
#  'Genre': 'Drama, War',
#  'Language': 'English',
#  'Metascore': '68',
#  'Plot': 'After returning home from an extended tour in Afghanistan, a '
#          'decorated U.S. Army medic and single mother struggles to rebuild her '
#          'relationship with her young son.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ5OTE3MDA2OF5BMl5BanBnXkFtZTgwNzM4OTE5MDE@._V1_SX300.jpg',
#  'Production': 'Phase 4 Films',
#  'Rated': 'TV-14',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.4/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '75%'},
#              {'Source': 'Metacritic', 'Value': '68/100'}],
#  'Released': '01 Oct 2015',
#  'Response': 'True',
#  'Runtime': '116 min',
#  'Title': 'Fort Bliss',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Claudia Myers (screenplay), Claudia Myers',
#  'Year': '2014',
#  'imdbID': 'tt2093995',
#  'imdbRating': '6.4',
#  'imdbVotes': '2,852'}
# -------------------
# movie id tt3457734
# -------------------
# {'Actors': 'Bridey Elliott, Clare McNulty, Neil Casey, Alysia Reiner',
#  'Awards': '2 wins & 3 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '15 Nov 2016',
#  'Director': 'Sarah-Violet Bliss, Charles Rogers',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': '70',
#  'Plot': 'A comedy about Allie and Harper and their needlessly difficult '
#          'journey to the beach.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjEwODMzMzkxN15BMl5BanBnXkFtZTgwNzY3NDgyNjE@._V1_SX300.jpg',
#  'Production': 'Orion Releasing LLC.',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '88%'},
#              {'Source': 'Metacritic', 'Value': '70/100'}],
#  'Released': '14 Aug 2015',
#  'Response': 'True',
#  'Runtime': '98 min',
#  'Title': 'Fort Tilden',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Sarah-Violet Bliss (story), Sarah-Violet Bliss, Brian Lannin '
#            '(story), Charles Rogers (story), Charles Rogers',
#  'Year': '2014',
#  'imdbID': 'tt3457734',
#  'imdbRating': '5.4',
#  'imdbVotes': '1,227'}
# -------------------
# movie id tt3793744
# -------------------
# {'Actors': 'Jean Paul San Pedro, Allen Rueckert, Ron Irwin, Somaya Isis',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ron Irwin',
#  'Genre': 'Biography',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQzOTM1NzA1OF5BMl5BanBnXkFtZTgwODUyMzIwMjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '10 Jul 2014',
#  'Response': 'True',
#  'Runtime': '60 min',
#  'Title': 'Fortius',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Allen Rueckert',
#  'Year': '2014',
#  'imdbID': 'tt3793744',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3469330
# -------------------
# {'Actors': 'Jared Bess, Willy J. Sasso, Drew Byerly, Gabe Retalia',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Drew Byerly',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Three teens set out to fix their schools bullying problem by staging '
#          'their own hunger games and documenting the whole process.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQxODUxNjYyOV5BMl5BanBnXkFtZTgwNTQyMzk3MTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.4/10'}],
#  'Released': '22 Oct 2014',
#  'Response': 'True',
#  'Runtime': '93 min',
#  'Title': 'Found Footage',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Drew Byerly, Travis M. Riggs, Willy J. Sasso',
#  'Year': '2014',
#  'imdbID': 'tt3469330',
#  'imdbRating': '8.4',
#  'imdbVotes': '5'}
# -------------------
# movie id tt3606486
# -------------------
# {'Actors': 'Christopher Boucher, Caroline Franklin, Jordan Crenshaw, David '
#            'Bolus',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Spencer Simpson',
#  'Genre': 'Drama, Fantasy, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Olivia, Darren, and Jackie go to the woods to bring their friend '
#          "Frankie back to life. Jackie, an acquaintance of Olivia's, briefly "
#          'became involved with Frankie shortly before his suicide. ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '86 min',
#  'Title': 'Four Magpies',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Spencer Simpson',
#  'Year': '2014',
#  'imdbID': 'tt3606486',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4227128
# -------------------
# {'Actors': 'Jaisey Bates, Jennifer Bobiwash, Adrian Brown, Azie Mira Dungey',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Diane Glancy, James Lujan',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Education that is meant to help the Native American also has its '
#          "cost. Two men discover the distance they've come from their "
#          'tradition and past. The two men, Timbisha Shoshone from Furnace ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '15 Nov 2014',
#  'Response': 'True',
#  'Runtime': '55 min',
#  'Title': 'Four Quarters',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Diane Glancy',
#  'Year': '2014',
#  'imdbID': 'tt4227128',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3099300
# -------------------
# {'Actors': 'Keith Robinson, Christian Keyes, Robin Givens, Jazsmin Lewis',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Christopher Nolen',
#  'Genre': 'Comedy, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Christopher Nolen\'s "Four Seasons" is a story about Xavier Lamar '
#          '(Keith Robinson), a 35 year old man who is "almost" ready to settle '
#          'down with one woman and get married. Xavier has decided ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTM5OTM1NzEyOV5BMl5BanBnXkFtZTgwMTgzNzQ1MTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'}],
#  'Released': '01 Apr 2014',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Four Seasons',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Mark Harris (screenplay), Christopher Nolen (screenplay), '
#            'Christopher Nolen (story), Christopher Nolen, Melinda Nolen',
#  'Year': '2014',
#  'imdbID': 'tt3099300',
#  'imdbRating': '5.8',
#  'imdbVotes': '68'}
# -------------------
# movie id tt4211694
# -------------------
# {'Actors': 'Casey Cantrell, Weston Cantrell, Christin Champlin, Andrew Corl',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Joshua J. Cordero',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Following a tragic event, a young woman consumed by fear and guilt '
#          'is forced to confront the manifestations of her fears to determine '
#          'if they are real or the result of a mind turning against itself.',
#  'Poster': 'https://ia.media-imdb.com/images/M/MV5BMTQyMzc1MDUwNl5BMl5BanBnXkFtZTgwNDk3NjI1MzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.3/10'}],
#  'Released': '26 Oct 2014',
#  'Response': 'True',
#  'Runtime': '64 min',
#  'Title': 'Fovos',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joshua J. Cordero',
#  'Year': '2014',
#  'imdbID': 'tt4211694',
#  'imdbRating': '4.3',
#  'imdbVotes': '11'}
# -------------------
# movie id tt1100089
# -------------------
# {'Actors': 'Steve Carell, Channing Tatum, Mark Ruffalo, Sienna Miller',
#  'Awards': 'Nominated for 5 Oscars. Another 12 wins & 75 nominations.',
#  'BoxOffice': '$9,744,477',
#  'Country': 'USA',
#  'DVD': '03 Mar 2015',
#  'Director': 'Bennett Miller',
#  'Genre': 'Biography, Drama, Sport',
#  'Language': 'English, French',
#  'Metascore': '81',
#  'Plot': 'U.S. Olympic wrestling champions and brothers Mark Schultz and Dave '
#          'Schultz join "Team Foxcatcher", led by eccentric multi-millionaire '
#          'John du Pont, as they train for the 1988 Olympic Games in Seoul, '
#          "South Korea, but John's self-destructive behavior threatens to "
#          'consume them all.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ2MjQxNjYxOV5BMl5BanBnXkFtZTgwMzIwODUxMzE@._V1_SX300.jpg',
#  'Production': 'Sony Pictures Classics',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '88%'},
#              {'Source': 'Metacritic', 'Value': '81/100'}],
#  'Released': '16 Jan 2015',
#  'Response': 'True',
#  'Runtime': '134 min',
#  'Title': 'Foxcatcher',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'E. Max Frye, Dan Futterman',
#  'Year': '2014',
#  'imdbID': 'tt1100089',
#  'imdbRating': '7.0',
#  'imdbVotes': '128,241'}
# -------------------
# movie id tt2355808
# -------------------
# {'Actors': 'Chloe Russell, Noelle Perris, Benjamin Keepers, Marco Aiello',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Sandy Boikian',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A lonely interior decorator with a history of delusions falls for a '
#          'dashing stranger who may or may not be real. The film ponders the '
#          'depths of human loss, the fragile framework of the ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQxNDI1MTg1MV5BMl5BanBnXkFtZTgwMTYxMzk3MTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.2/10'}],
#  'Released': '20 Nov 2014',
#  'Response': 'True',
#  'Runtime': '81 min',
#  'Title': 'Fragile World',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Sandy Boikian (screenplay)',
#  'Year': '2014',
#  'imdbID': 'tt2355808',
#  'imdbRating': '8.2',
#  'imdbVotes': '12'}
# -------------------
# movie id tt2406602
# -------------------
# {'Actors': 'Josef Cannon, Roy Eisenstein, Xander Farrell, Adam Karst',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Josef Cannon',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Undercover agents Israel Gutierrez (Adam Karst) and Miami Lane '
#          '(Josef Cannon) sent to Sofia Bulgaria on what was believed to be a '
#          'simple training mission only to find themselves at the center of '
#          'high stakes corruption.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTgyMjI3NzU3NF5BMl5BanBnXkFtZTcwODA3NzM1OA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.8/10'}],
#  'Released': '09 Nov 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Fragmented Truth',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Josef Cannon',
#  'Year': '2014',
#  'imdbID': 'tt2406602',
#  'imdbRating': '3.8',
#  'imdbVotes': '6'}
# -------------------
# movie id tt4027978
# -------------------
# {'Actors': 'Ross Weber, Alex Gilbert',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Maximilien Proctor',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "In the wake of a friend's passing, Alex must make due as best he can "
#          'and turns to art as a means of self-expression through which he may '
#          'better understand the world.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '62 min',
#  'Title': 'Fragments of a Memory',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Juan Bruno, Juan Bruno (story), Maximilien Proctor',
#  'Year': '2014',
#  'imdbID': 'tt4027978',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3659296
# -------------------
# {'Actors': 'Joe Hammerstone, Benisha Dorris, William Conklin, Andrew Hardebeck',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Alyson Brilliant, Adam Hardebeck',
#  'Genre': 'Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Cameron, under house arrest for a crime he didn't commit, battles "
#          'depression and sickness while seeking the person who framed him.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '08 May 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Framed',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Alyson Brilliant, Adam Hardebeck',
#  'Year': '2014',
#  'imdbID': 'tt3659296',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2259318
# -------------------
# {'Actors': 'Henry Ian Cusick, Ever Carradine, Natalya Oliver, Brian Brightman',
#  'Awards': '5 wins.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '07 Mar 2017',
#  'Director': 'Stewart Schill',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'After his house is destroyed by a tornado (what his insurance '
#          'company deems an "act of God"), former hotshot lawyer David Frank is '
#          'determined that someone must pay. He decides to serve God...with a '
#          'lawsuit.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg5NTYzMjkzMV5BMl5BanBnXkFtZTgwNjMyNjQ4MTE@._V1_SX300.jpg',
#  'Production': 'Random Media',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '100 min',
#  'Title': 'Frank vs. God',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Stewart Schill',
#  'Year': '2014',
#  'imdbID': 'tt2259318',
#  'imdbRating': '6.2',
#  'imdbVotes': '134'}
# -------------------
# movie id tt2952488
# -------------------
# {'Actors': 'Matt Risoldi, Dustin Sturgill, Tim Ashby, Megan Beard',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Syd Lance',
#  'Genre': 'Drama, History, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "A steampunk film adaptation of Mary Shelley's masterpiece. In his "
#          "obsession over the Prometheus' flame, Victor Frankenstein abandons "
#          'those he loves to create a living being. Leaving behind ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzM5OTM5Nzc0NV5BMl5BanBnXkFtZTcwODE3NTU3OQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.8/10'}],
#  'Released': '03 Oct 2014',
#  'Response': 'True',
#  'Runtime': '86 min',
#  'Title': "Frankenstein's Monster",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Judith B. Shields',
#  'Year': '2014',
#  'imdbID': 'tt2952488',
#  'imdbRating': '3.8',
#  'imdbVotes': '5'}
# -------------------
# movie id tt3615040
# -------------------
# {'Actors': 'Kaiser Johnson, Mary Alice Calhoun, Nikki Brower, Ashley Ahlquist',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Joey Odendahl',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'On Halloween, a film crew journeys to the town of Frankenstein, home '
#          'of Momo, the infamous "Missouri Monster.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '31 Oct 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Frankenstein, Missouri',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joey Odendahl',
#  'Year': '2014',
#  'imdbID': 'tt3615040',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt10043150
# -------------------
# {'Actors': 'Alan Keith, Megan Meyers, Tyler Rose, Katherine Gibson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Josh Gibson',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'After the untimely demise of his father, Victor becomes more and '
#          'more obsessed with reanimating the dead.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '18 Oct 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Frankenstein: Presented by the 4th Wall Players',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Becca Bartley (story by), Josh Gibson (stageplay by), Alan Keith '
#            '(stageplay by)',
#  'Year': '2014',
#  'imdbID': 'tt10043150',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3259178
# -------------------
# {'Actors': 'D.B. Sweeney, Sarah Butler, Malcolm McDowell, Ian Gomez',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '28 Oct 2014',
#  'Director': 'Malek Akkad',
#  'Genre': 'Action, Crime, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An employee, working for Gault Capital in L.A, gets targeted by a '
#          'ruthless assassin and locked in the elevator after she uncovers a '
#          'chilling secret.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjI0MjQ1MDMxNV5BMl5BanBnXkFtZTgwNjAwNTk0MjE@._V1_SX300.jpg',
#  'Production': 'Anchor Bay Entertainment',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.4/10'}],
#  'Released': '17 Oct 2014',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Free Fall',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dwayne Alexander Smith',
#  'Year': '2014',
#  'imdbID': 'tt3259178',
#  'imdbRating': '4.4',
#  'imdbVotes': '1,799'}
# -------------------
# movie id tt4298898
# -------------------
# {'Actors': 'Jas Abramowitz, Lance Asbury, Sheenan Cole, Sara Glass',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'William Peck',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Thomas Gideon has the heart of an artist, but he has the life of a '
#          'cog, turning endlessly through days of a hostile marriage and a '
#          'thankless, stalled career. Then, just as it appears things...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '110 min',
#  'Title': 'Free Verse',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'William Peck',
#  'Year': '2014',
#  'imdbID': 'tt4298898',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2298394
# -------------------
# {'Actors': 'Lina Esco, Lola Kirke, Casey LaBow, Monique Coleman',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '09 Jun 2015',
#  'Director': 'Lina Esco',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': '33',
#  'Plot': "A group of women launch a movement to remove the censor of women's "
#          'breasts all over America.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ3MTA4NzE2MF5BMl5BanBnXkFtZTgwMjA4ODI2MzE@._V1_SX300.jpg',
#  'Production': 'IFC Films',
#  'Rated': 'Unrated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.9/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '18%'},
#              {'Source': 'Metacritic', 'Value': '33/100'}],
#  'Released': '12 Dec 2014',
#  'Response': 'True',
#  'Runtime': '78 min',
#  'Title': 'Free the Nipple',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Lina Esco (story), Hunter Richards (story), Hunter Richards, '
#            'Sarabeth Stroller (story)',
#  'Year': '2014',
#  'imdbID': 'tt2298394',
#  'imdbRating': '3.9',
#  'imdbVotes': '1,589'}
# -------------------
# movie id tt2584018
# -------------------
# {'Actors': 'Cuba Gooding Jr., Sharon Leal, David Rasche, Kimberly Nichole',
#  'Awards': 'N/A',
#  'BoxOffice': '$124,356',
#  'Country': 'USA',
#  'DVD': '14 Jul 2015',
#  'Director': 'Peter Cousens',
#  'Genre': 'Drama, Music',
#  'Language': 'English',
#  'Metascore': '30',
#  'Plot': 'Two men separated by 100 years are united in their search for '
#          'freedom. In 1856 a slave, Samuel Woodward and his family, escape '
#          'from the Monroe Plantation near Richmond, Virginia. A secret ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjExNDgzNzM2Ml5BMl5BanBnXkFtZTgwMTIwNzM3NTE@._V1_SX300.jpg',
#  'Production': 'Arc Entertainment',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '0%'},
#              {'Source': 'Metacritic', 'Value': '30/100'}],
#  'Released': '05 Apr 2015',
#  'Response': 'True',
#  'Runtime': '94 min',
#  'Title': 'Freedom',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Timothy A. Chey, Peter Cousens (story editor), Douglas Nyback '
#            '(story editor), John Senczuk (executive story editor)',
#  'Year': '2014',
#  'imdbID': 'tt2584018',
#  'imdbRating': '6.3',
#  'imdbVotes': '1,572'}
# -------------------
# movie id tt3612004
# -------------------
# {'Actors': 'Jacob Hashem, Matt Conde, Anthony Olmos, Cassandra Cade',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Mark Schaefer',
#  'Genre': 'Short, Action, Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'After Zach is dumped by his girlfriend, he is reunited with his '
#          'former best friend Pete who vows to cheer him up. After a night of '
#          "drinking, breaking into his ex's house and accidentally ...",
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '48 min',
#  'Title': 'Freedom',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'David Steen',
#  'Year': '2014',
#  'imdbID': 'tt3612004',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2325002
# -------------------
# {'Actors': 'Dylan McDermott, Yulia Snigir, Peter Facinelli, Andrey Ivchenko',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '21 Jan 2014',
#  'Director': 'Mikael Salomon',
#  'Genre': 'Action, Thriller',
#  'Language': 'English',
#  'Metascore': '40',
#  'Plot': 'Robert is an ordinary man who is faced with extraordinary '
#          'circumstances. He is locked in a meat freezer by Russian thugs who '
#          'believe that he owes them 8 million dollars. Robert, who is in ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTgxMzY4MDA4M15BMl5BanBnXkFtZTgwNzE4MzU2MDE@._V1_SX300.jpg',
#  'Production': 'Anchor Bay Entertainment',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.2/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '33%'},
#              {'Source': 'Metacritic', 'Value': '40/100'}],
#  'Released': '19 Jun 2014',
#  'Response': 'True',
#  'Runtime': '83 min',
#  'Title': 'Freezer',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tom Doganoglu, Shane Weisfeld',
#  'Year': '2014',
#  'imdbID': 'tt2325002',
#  'imdbRating': '5.2',
#  'imdbVotes': '3,119'}
# -------------------
# movie id tt3971092
# -------------------
# {'Actors': 'Meredith Sause, Thaddaeus Edwards, Eryk Pruitt',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Piper Kessler',
#  'Genre': 'Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'In the sci-fi world of Frequency, individuals have the ability to '
#          'tune in to a frequency gaining them different skills, i.e. '
#          'Clairvoyance, Telepathy, Time-travel, Healing, and Mental ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'}],
#  'Released': '23 Aug 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Frequency',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Piper Kessler',
#  'Year': '2014',
#  'imdbID': 'tt3971092',
#  'imdbRating': '6.5',
#  'imdbVotes': '27'}
# -------------------
# movie id tt2265510
# -------------------
# {'Actors': 'Andy Goldenberg, Zach Kanner, Megan Stogner, Clifton Williams',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Daniel Bernstein',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'This 3D comedy tells the wildly unauthorized story of legendary film '
#          'producer Louis B. Mayer. From his early days as a giant ape on Skull '
#          'Island, to his epic rise and fall, this ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Fried',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Daniel Bernstein',
#  'Year': '2015',
#  'imdbID': 'tt2265510',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2298186
# -------------------
# {'Actors': 'Ryan Hansen, James Immekus, Zach McGowan, Sarah Smick',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Sarah Smick',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': '26',
#  'Plot': 'A dark comedy about a social media junkie who fakes his own death '
#          'via social media just to see which of his "friends" will show up to '
#          'the funeral.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjM3NjM5MTEwOF5BMl5BanBnXkFtZTgwNjQwOTI2MTE@._V1._CR50,49,1313,1949_SX89_AL_.jpg_V1_SX300.jpg',
#  'Production': 'Green Step Productions',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.8/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '42%'},
#              {'Source': 'Metacritic', 'Value': '26/100'}],
#  'Released': '02 May 2014',
#  'Response': 'True',
#  'Runtime': '94 min',
#  'Title': 'Friended to Death',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ian Michaels, Sarah Smick',
#  'Year': '2014',
#  'imdbID': 'tt2298186',
#  'imdbRating': '4.8',
#  'imdbVotes': '436'}
# -------------------
# movie id tt4303966
# -------------------
# {'Actors': 'Amelia Favata, Adam S. Dixson, Erin Stamp, Casey Litzenberger',
#  'Awards': '1 win & 4 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Rhonda Parker',
#  'Genre': 'Comedy, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A sarcastic tomboy becomes caught in the middle as her friends fall '
#          'in and out of love with each other.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg1NTA5NTU1NV5BMl5BanBnXkFtZTgwOTk3MTY4MzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.0/10'}],
#  'Released': '07 Nov 2014',
#  'Response': 'True',
#  'Runtime': '97 min',
#  'Title': "Friends Don't Let Friends Date Friends",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Rhonda Parker',
#  'Year': '2014',
#  'imdbID': 'tt4303966',
#  'imdbRating': '8.0',
#  'imdbVotes': '87'}
# -------------------
# movie id tt3480942
# -------------------
# {'Actors': 'Michael Rispoli, Annabella Sciorra, Paul Ben-Victor, Katie Stevens',
#  'Awards': '3 wins & 2 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Christopher Kublan',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A group of lifelong mob movie extras mount a production of '
#          "Shakespeare's Julius Caesar in their local Staten Island theater in "
#          'order to finally get some speaking roles. But the theater is ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc2ODg2MDgxMF5BMl5BanBnXkFtZTgwMzc2NzYxNzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.9/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '97 min',
#  'Title': 'Friends and Romans',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Gregg Greenberg, Christopher Kublan, Michael Rispoli',
#  'Year': '2014',
#  'imdbID': 'tt3480942',
#  'imdbRating': '7.9',
#  'imdbVotes': '88'}
# -------------------
# movie id tt3127560
# -------------------
# {'Actors': 'John DiRenzo, Guy Wellman, Jason Boyle, Jeff Profitt',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jeff Profitt',
#  'Genre': 'Action, Crime, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An undercover police detective infiltrates an organized crime '
#          'operation. Once inside he discovers the boss of the operation is a '
#          'childhood friend from the neighborhood.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ3NTc2NjY4NF5BMl5BanBnXkFtZTgwMTAzODk4MDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '18 Apr 2014',
#  'Response': 'True',
#  'Runtime': '91 min',
#  'Title': 'Friends from the Neighborhood',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jeff Profitt',
#  'Year': '2014',
#  'imdbID': 'tt3127560',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3763244
# -------------------
# {'Actors': 'Shayla Hale, Rhonda Morman, Kwesiu Jones, Destiny Collins',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Akpomo Aburime-Prewitt',
#  'Genre': 'Short, Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A story about the wounds that cancer causes a young couple after her '
#          'mother is diagnosed and eventually succumbs to breast cancer.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '45 min',
#  'Title': 'From Pieces to Peace',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Akpomo Aburime-Prewitt, Jason Sims-Prewitt, Jason Sims-Prewitt',
#  'Year': '2014',
#  'imdbID': 'tt3763244',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2510028
# -------------------
# {'Actors': 'Ed Harris, Michael Peña, Eva Longoria, Amy Madigan',
#  'Awards': '1 win.',
#  'BoxOffice': '$59,306',
#  'Country': 'USA',
#  'DVD': '04 Nov 2014',
#  'Director': 'Michael Berry',
#  'Genre': 'Drama, Thriller, Western',
#  'Language': 'English, Spanish, Persian',
#  'Metascore': '58',
#  'Plot': "A former Arizona sheriff's wife is killed while riding on their "
#          'ranch property. It would appear a Mexican man illegally crossing '
#          'into the US is at fault. As the former and the current sheriff '
#          'search for answers, lives are changed forever.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQwOTA2NTM3OV5BMl5BanBnXkFtZTgwMDY1OTU5MTE@._V1_SX300.jpg',
#  'Production': 'Magnolia Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '54%'},
#              {'Source': 'Metacritic', 'Value': '58/100'}],
#  'Released': '31 Jul 2014',
#  'Response': 'True',
#  'Runtime': '103 min',
#  'Title': 'Frontera',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Berry, Louis Moulinet',
#  'Year': '2014',
#  'imdbID': 'tt2510028',
#  'imdbRating': '6.6',
#  'imdbVotes': '7,064'}
# -------------------
# movie id tt4422958
# -------------------
# {'Actors': 'Héctor Soberón, Esteban Franco, Vicky Contreras, Humberto '
#            'Plancarte',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Mateo Gutierrez',
#  'Genre': 'Drama',
#  'Language': 'Spanish',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '28 Aug 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Frontera camino al infierno',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Vicky Contreras (script)',
#  'Year': '2014',
#  'imdbID': 'tt4422958',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4150316
# -------------------
# {'Actors': 'Edward Asner, Drake Bell, Colin Murdock, Richard Newman',
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Alex Leung',
#  'Genre': 'Animation, Adventure, Family',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'Patty and Eric Purtle visit their Grandfather for Christmas. After '
#          'accidentally breaking a clock in his workshop, they then find '
#          'themselves repeating Christmas Eve. together they must fix time and '
#          'make Christmas enjoyable for their family.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ0OTA2NDg3OV5BMl5BanBnXkFtZTgwMDY1MjE0MzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'G',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'}],
#  'Released': '01 Nov 2014',
#  'Response': 'True',
#  'Runtime': '46 min',
#  'Title': 'Frozen in Time',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Melissa Rundle',
#  'Year': '2014',
#  'imdbID': 'tt4150316',
#  'imdbRating': '5.8',
#  'imdbVotes': '64'}
# -------------------
# movie id tt6369728
# -------------------
# {'Actors': 'Maria Alexandra, James Cantu, Rey Cantu, Pablo Esparza',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Thailand',
#  'DVD': 'N/A',
#  'Director': 'Marcos N Suarez',
#  'Genre': 'N/A',
#  'Language': 'English, Spanish, Thai',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
# ...
# {'Actors': 'Matthew King, Sarah Shawgo, Wes Wojtowicz, Paul Schermerhorn',
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Matt Croyle',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Declan Holmes is graduating college, a hard enough time as it is, '
#          'and heading out into the real world. The loss he experiences is like '
#          "nothing he has ever known before. 'Potential Inertia' ...",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjM4MzU0MjA1MV5BMl5BanBnXkFtZTgwMzgwNzU2MTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.9/10'}],
#  'Released': '27 Dec 2014',
#  'Response': 'True',
#  'Runtime': '79 min',
#  'Title': 'Potential Inertia',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Matt Croyle',
#  'Year': '2014',
#  'imdbID': 'tt2283160',
#  'imdbRating': '7.9',
#  'imdbVotes': '30'}
# -------------------
# movie id tt3896284
# -------------------
# {'Actors': 'Alexis Anderson, Eva Cotton, Jennifer Cotton, JP DeStefano',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '23 Jun 2015',
#  'Director': 'Don Okolo',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'On their way home from the concert, an accident happens and Nelo is '
#          "trapped in the family's burning car. She dies from a single gunshot "
#          '- But, how?',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTYzMDY3MDEwNF5BMl5BanBnXkFtZTgwNjcxNzU0MjE@._V1_SX300.jpg',
#  'Production': 'eOne Entertainment',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.8/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '15%'}],
#  'Released': '23 Aug 2015',
#  'Response': 'True',
#  'Runtime': '145 min',
#  'Title': 'Pound of Flesh',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Don Okolo',
#  'Year': '2015',
#  'imdbID': 'tt3896284',
#  'imdbRating': '8.8',
#  'imdbVotes': '5'}
# -------------------
# movie id tt3169334
# -------------------
# {'Actors': 'Daniel Adams, Hennsey, Jacob D. Johnston, Aidan Keyes',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Remington Keyes',
#  'Genre': 'Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Aliens are taking over planet Earth and it's up to the Power Rangers "
#          'to get it back. Its going to be a challenge when Lord Zedd comes '
#          'back to destroy the morphing Grid.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '30 Jul 2016',
#  'Response': 'True',
#  'Runtime': '45 min',
#  'Title': 'Power Rangers Annihilation',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Aidan Keyes (dialogue), Remington Keyes (screenplay), Cody Thomas '
#            '(supervising writer)',
#  'Year': '2014',
#  'imdbID': 'tt3169334',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3303148
# -------------------
# {'Actors': 'Chris Rex, Cody Burns, Brandon Burns, Brittany Warner',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Cody Burns, Chris Rex',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The quirky, fun improvisational game is here with its complete 50 '
#          'call collection. Over the course of 8 years, Chris Rex and friends '
#          'have come up with schemes for an array of subjects, from...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTc5MjQ4NTQyOF5BMl5BanBnXkFtZTgwODM2MzI2MDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.9/10'}],
#  'Released': '01 Jan 2014',
#  'Response': 'True',
#  'Runtime': '133 min',
#  'Title': 'Prank Calls: 50th Call Anniversary',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2014',
#  'imdbID': 'tt3303148',
#  'imdbRating': '7.9',
#  'imdbVotes': '37'}
# -------------------
# movie id tt2608232
# -------------------
# {'Actors': 'Vikas Ahuja, Shakuntala Ray Banerji, Arlene Barshinger, Veronica '
#            'Castro',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Evertis S. Wright',
#  'Genre': 'Crime, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Predatory Lender is a dark thriller that follows the exploits of a '
#          'psychopathic real estate agent who is as cold and deceptive in '
#          'business as he is in the pursuit of his beautiful young prey.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjEyMzUxMTYyM15BMl5BanBnXkFtZTgwMTIxMDY0NzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'}],
#  'Released': '01 Nov 2014',
#  'Response': 'True',
#  'Runtime': '81 min',
#  'Title': 'Predatory Lender',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'James E. Meyer',
#  'Year': '2014',
#  'imdbID': 'tt2608232',
#  'imdbRating': '6.6',
#  'imdbVotes': '21'}
# -------------------
# movie id tt2397535
# -------------------
# {'Actors': 'Ethan Hawke, Sarah Snook, Christopher Kirby, Christopher Sommers',
#  'Awards': '12 wins & 19 nominations.',
#  'BoxOffice': '$201,560',
#  'Country': 'Australia, USA',
#  'DVD': '10 Feb 2015',
#  'Director': 'Michael Spierig, Peter Spierig',
#  'Genre': 'Action, Drama, Mystery, Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': '69',
#  'Plot': 'For his final assignment, a top temporal agent must pursue the one '
#          'criminal that has eluded him throughout time. The chase turns into a '
#          'unique, surprising and mind-bending exploration of love, fate, '
#          'identity and time travel taboos.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTAzODc3NjU1NzNeQTJeQWpwZ15BbWU4MDk5NTQ4NTMx._V1_SX300.jpg',
#  'Production': 'Sony Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.5/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '83%'},
#              {'Source': 'Metacritic', 'Value': '69/100'}],
#  'Released': '09 Jan 2015',
#  'Response': 'True',
#  'Runtime': '97 min',
#  'Title': 'Predestination',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Spierig, Peter Spierig, Robert A. Heinlein (based on the '
#            'short story "All You Zombies" by)',
#  'Year': '2014',
#  'imdbID': 'tt2397535',
#  'imdbRating': '7.5',
#  'imdbVotes': '232,777'}
# -------------------
# movie id tt3417314
# -------------------
# {'Actors': 'Toochukwu T.C. Anyachonkeya, Hunter Bolton, Bryan Chassereau, '
#            'Hannah Chassereau',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ebony Wilson',
#  'Genre': 'Action, Drama, Sci-Fi, Thriller, War',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Six rebel figures have taken refuge in an abandoned sector against a '
#          'genetically enhanced superhuman race.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDIzNDczMzI3OV5BMl5BanBnXkFtZTgwMTEzMzQ0MjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.1/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '148 min',
#  'Title': 'Prelude to Infusco',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ebony Wilson (story & screenplay)',
#  'Year': '2014',
#  'imdbID': 'tt3417314',
#  'imdbRating': '5.1',
#  'imdbVotes': '15'}
# -------------------
# movie id tt2182256
# -------------------
# {'Actors': 'John Karna, Caroline Traywick, Kate Kneeland, Steve Coulter',
#  'Awards': '2 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '04 Nov 2014',
#  'Director': 'Dan Beers',
#  'Genre': 'Comedy, Fantasy',
#  'Language': 'English, French',
#  'Metascore': '34',
#  'Plot': 'A high school senior has to re-live losing his virginity over and '
#          'over again until he gets it right, with the right girl.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjE2OTQ2NDEzMF5BMl5BanBnXkFtZTgwMjA3MjAwMjE@._V1_SX300.jpg',
#  'Production': 'Morningwood Productions',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '50%'},
#              {'Source': 'Metacritic', 'Value': '34/100'}],
#  'Released': '02 Jul 2014',
#  'Response': 'True',
#  'Runtime': '93 min',
#  'Title': 'Premature',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dan Beers (screenplay), Mathew Harawitz (screenplay)',
#  'Year': '2014',
#  'imdbID': 'tt2182256',
#  'imdbRating': '5.8',
#  'imdbVotes': '9,223'}
# -------------------
# movie id tt3737996
# -------------------
# {'Actors': 'Jason Selvig, Davram Stiefler, John Anderson, Julia Collier',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Brendan Gibbons',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'As the 2011 Occupy Wall Street movement rages, Robert and John, two '
#          'New York investment bankers who are angered by the noise, smell and '
#          'hassle of the protests venture into the park to let ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjI1NDE4NDkyNV5BMl5BanBnXkFtZTgwODIxODk4MTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.2/10'}],
#  'Released': '31 May 2014',
#  'Response': 'True',
#  'Runtime': '83 min',
#  'Title': 'Preoccupied',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Brendan Gibbons',
#  'Year': '2014',
#  'imdbID': 'tt3737996',
#  'imdbRating': '5.2',
#  'imdbVotes': '13'}
# -------------------
# movie id tt3481242
# -------------------
# {'Actors': 'Joanna Kalafatis, Julius Vladimir Francisco, Jerome, Krys Mach',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Julius Vladimir Francisco',
#  'Genre': 'Drama, Fantasy, Sci-Fi',
#  'Language': 'English, Greek',
#  'Metascore': 'N/A',
#  'Plot': 'A man is given the power of omnipresence.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQyNDU3NzQ0NF5BMl5BanBnXkFtZTgwNTkwMTI1MTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '92 min',
#  'Title': 'Present Light',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Julius Vladimir Francisco, Teodoro Francisco (story)',
#  'Year': '2014',
#  'imdbID': 'tt3481242',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3138558
# -------------------
# {'Actors': 'Wrenn Schmidt, Pablo Schreiber, Aaron Staton, Cody Saintgnue',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '06 Apr 2015',
#  'Director': 'Christopher Denham',
#  'Genre': 'Horror, Thriller',
#  'Language': 'English',
#  'Metascore': '44',
#  'Plot': 'An anesthesiologist must awaken her animal instincts when she, her '
#          'husband and her brother-in-law become the quarry of unseen hunters '
#          'who want to turn them all into trophies.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMDNjMmM5OTYtYmY0Ny00ZTNjLWEyNGYtYTBiYWEwMTRkZDFlXkEyXkFqcGdeQXVyMTMxMTY0OTQ@._V1_SX300.jpg',
#  'Production': 'The Orchard',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.7/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '58%'},
#              {'Source': 'Metacritic', 'Value': '44/100'}],
#  'Released': '09 Jan 2015',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Preservation',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Christopher Denham',
#  'Year': '2014',
#  'imdbID': 'tt3138558',
#  'imdbRating': '4.7',
#  'imdbVotes': '5,135'}
# -------------------
# movie id tt2521436
# -------------------
# {'Actors': 'Mackenzie Firgens, Jake White, Heather Tocquigny, Cody Morris',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '07 Oct 2014',
#  'Director': 'Martin Rosenberg',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When LIZ (Mackenzie Firgens) returns home on a college break with a '
#          'broken heart, all she wants to do is hibernate and heal. But her '
#          'best friend ASHLEY (Heather Tocquigny) coaxes her out of...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjI5MzY5NTU0OV5BMl5BanBnXkFtZTgwMzA2NTU5MjE@._V1_SX300.jpg',
#  'Production': 'Inception Media Group',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'}],
#  'Released': '07 Oct 2014',
#  'Response': 'True',
#  'Runtime': '83 min',
#  'Title': 'Preston Castle',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Peter Bailey, Martin Rosenberg',
#  'Year': '2014',
#  'imdbID': 'tt2521436',
#  'imdbRating': '6.2',
#  'imdbVotes': '1,109'}
# -------------------
# movie id tt3587376
# -------------------
# {'Actors': 'John Tyler',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'John Tyler',
#  'Genre': 'Short',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '07 Mar 2014',
#  'Response': 'True',
#  'Runtime': '67 min',
#  'Title': 'Pretentiousness',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'John Tyler',
#  'Year': '2014',
#  'imdbID': 'tt3587376',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2118707
# -------------------
# {'Actors': 'Christopher McDonald, Sara Malakul Lane, Noel Gugliemi, Sarah '
#            'Sutherland',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'York Alec Shackleton',
#  'Genre': 'Drama, Romance, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTA0MzM0MzE3MDdeQTJeQWpwZ15BbWU4MDY1NzQ4MDcx._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.5/10'}],
#  'Released': '01 Sep 2014',
#  'Response': 'True',
#  'Runtime': '98 min',
#  'Title': 'Pretty Perfect',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Christopher Beaton, York Alec Shackleton',
#  'Year': '2014',
#  'imdbID': 'tt2118707',
#  'imdbRating': '7.5',
#  'imdbVotes': '8'}
# -------------------
# movie id tt1977892
# -------------------
# {'Actors': 'Chuti Tiu, Kipp Shiotani, Dana Lee, Bel Hernandez',
#  'Awards': '9 wins & 3 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Oscar Torre',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A career woman stuck in an unhappy marriage struggles to find '
#          'happiness living in a fishbowl, where cultural and religious '
#          'traditions are smothering a woman dying to be free.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk2NjQ5ODE1OV5BMl5BanBnXkFtZTgwMDk1MDk4MDE@._V1_SX300.jpg',
#  'Production': 'Indie Rights',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'}],
#  'Released': '16 Jan 2015',
#  'Response': 'True',
#  'Runtime': '81 min',
#  'Title': 'Pretty Rosebud',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Chuti Tiu',
#  'Year': '2014',
#  'imdbID': 'tt1977892',
#  'imdbRating': '6.5',
#  'imdbVotes': '417'}
# -------------------
# movie id tt3511974
# -------------------
# {'Actors': 'Athena Reddy, Nikki McGee, Christine De La Rosa, Therese Panetta',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'David Paritsky',
#  'Genre': 'Animation, Action, Adventure',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When the forces of the Dark Kingdom threaten to destroy the peace, '
#          'four guardian warriors will awaken.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZDM2ZWFiMzItMjNkYy00YmYwLTg5NTEtZmFiMjdjOGM0MmRhXkEyXkFqcGdeQXVyMzYzNzc1NjY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.7/10'}],
#  'Released': '07 Jun 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Pretty Soldier Sailor Moon: The Movie',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'David Paritsky (adaptation), Naoko Takeuchi (manga series)',
#  'Year': '2014',
#  'imdbID': 'tt3511974',
#  'imdbRating': '6.7',
#  'imdbVotes': '20'}

# %%
len(title_list)
# Out:
# 997

# %%
len(title_id)
# Out:
# 997

# %%
# if title_list and title_id are the same length run the cell below. 
# if they are not equal take out 'title_id': title_id

# %%
df = pd.DataFrame({'title_id': title_id, 'title': title_list, 'box_office': box_office_list, 'country': country_list, 
                   'genre': genre_list, 'director': director_list, 'metascore': metascore_list, 'production': production_list, 
                   'rating': rating_list, 'IMDB_rating': IMDB_rating_list, 'rotten_tomatoes_rating': rotten_tomatoes_rating_list, 
                  'runtime': runtime_list, 'type': type_list, 'IMDB_votes': imdb_votes_list})

# %%
df = df.drop_duplicates()
df.head()
# Out:
#     title_id                     title box_office country  \
# 0  tt3907106                  Floreana        N/A     USA
# 1  tt3657522              Flower Power        N/A     USA
# 2  tt2409812                   Flutter        N/A     USA
# 3  tt4073764              Focus Puller        N/A     USA
# 4  tt4355544  Footnotes of an Ornament        N/A     USA
#
#                        genre       director metascore     production  \
# 0                      Drama  Michael Yates       N/A            N/A
# 1                      Short  Peggy Walkush       N/A            N/A
# 2                      Drama    Eric Hueber       N/A  Xlrator Media
# 3  Comedy, Mystery, Thriller     Jonny Mars       N/A            N/A
# 4                      Drama      Nick Sung       N/A            N/A
#
#       rating IMDB_rating rotten_tomatoes_rating  runtime   type IMDB_votes
# 0        N/A         N/A                     NA  112 min  movie        N/A
# 1        N/A         N/A                     NA      N/A  movie        N/A
# 2  Not Rated         5.9                    60%   96 min  movie        340
# 3        N/A         N/A                     NA   90 min  movie        N/A
# 4        N/A         N/A                     NA      N/A  movie        N/A

# %%
df.count()
# Out:
# title_id                  997
# title                     997
# box_office                997
# country                   997
# genre                     997
# director                  997
# metascore                 997
# production                997
# rating                    997
# IMDB_rating               997
# rotten_tomatoes_rating    997
# runtime                   997
# type                      997
# IMDB_votes                997
# dtype: int64

# %%
df.to_csv('../data/2014_data_batch_2.csv', index=False)
