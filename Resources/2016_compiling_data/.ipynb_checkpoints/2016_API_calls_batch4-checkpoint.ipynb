# %%
import pandas as pd
import requests
import json
import time
from pprint import pprint
from config import API_KEY

# %%
data = pd.read_csv('../data/titles_2016_batch4.csv')
df =  data.count()
df
# Out:
# title    724
# dtype: int64

# %%
title_id = []
box_office_list = []
country_list = []
genre_list = []
director_list = []
metascore_list = []
production_list = []
rating_list = []
IMDB_rating_list = [] 
rotten_tomatoes_rating_list = []
runtime_list = []
title_list = []
type_list = []
imdb_votes_list = []

# %%
movies = data['title']
total_movies = len(movies)

# %%
for i in range(total_movies):
    movie = movies[i]
    url = "http://www.omdbapi.com/?i=" + movie + "&apikey=" + API_KEY
    response = (requests.get(url).text)
    response_json = json.loads(response)
    print('-------------------')
    print(f'movie id {movie}')
    print('-------------------')
    pprint(response_json)
    
    try:
        title_id.append(response_json['imdbID'])
        box_office_list.append(response_json['BoxOffice'])
        country_list.append(response_json['Country'])
        genre_list.append(response_json['Genre'])
        director_list.append(response_json['Director'])
        metascore_list.append(response_json['Metascore'])
        production_list.append(response_json['Production'])
        rating_list.append(response_json['Rated'])
        IMDB_rating_list.append(response_json['imdbRating'])
        try:
            if not response_json['Ratings']:
                rotten_tomatoes_rating_list.append('NA')
            elif response_json['Ratings'][0]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][0]['Value'])
            elif response_json['Ratings'][1]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][1]['Value'])
            else:
                rotten_tomatoes_rating_list.append('NA')
        except IndexError:
            rotten_tomatoes_rating_list.append('NA')
        runtime_list.append(response_json['Runtime'])
        title_list.append(response_json['Title'])
        type_list.append(response_json['Type'])
        imdb_votes_list.append(response_json['imdbVotes']) 
    except KeyError:
        pass
# Out:
# movie id tt6158254
# {'Actors': "Tim Manley, Cindy O'Neill, Peter Aguero, Vinny DiSpigno",
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Naje Lataillade, Tim Manley',
#  'Genre': 'Comedy, Drama',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'In a series of linked moments, one awkward New Yorker searches for '
#          'love with men, women, and himself.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '63 min',
#  'Title': 'The Feels',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tim Manley (story), Tim Manley',
#  'Year': '2016',
#  'imdbID': 'tt6158254',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt4159698
# {'Actors': 'Carrie Keagan, Douglas Tait, Danni DanDan Gadigan, Staci Layne '
#            'Wilson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '29 Nov 2016',
#  'Director': 'Mark Allen Michaels',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When a beautiful bride-to-be is bitten by the legendary creature, '
#          'Bigfoot, she becomes a brutal force of nature hellbent on breaking '
#          'her engagement - and her fiancé.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzMxOTAxMzUyNF5BMl5BanBnXkFtZTgwMzc1OTIyMDI@._V1_SX300.jpg',
#  'Production': 'Firebreathing Films',
#  'Rated': 'UNRATED',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.5/10'}],
#  'Released': '11 Nov 2016',
#  'Response': 'True',
#  'Runtime': '79 min',
#  'Title': 'The Fiancé',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Mark Allen Michaels',
#  'Year': '2016',
#  'imdbID': 'tt4159698',
#  'imdbRating': '3.5',
#  'imdbVotes': '91'}
# movie id tt4838334
# {'Actors': 'John Major Davis, Lelia Symington, Matt Leddo, Mike H. Taylor',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Michael William Gordon',
#  'Genre': 'Action, Romance, Sport',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Logan Chandler, a young MMA fighter seeks to overcome a troubled '
#          'past and build a new life based on a new faith and a new found love, '
#          'but is forced back into the fighting world by Hayden Dressler, a '
#          'local MMA professional.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYTY3Y2VkMWItOTU2Yi00NzhjLThmNGMtYTRmM2YwOWI5MjI2XkEyXkFqcGdeQXVyNjEyNjY2ODY@._V1_SX300.jpg',
#  'Production': 'New Life Cinema',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.7/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '40%'}],
#  'Released': '12 Aug 2016',
#  'Response': 'True',
#  'Runtime': '94 min',
#  'Title': 'The Fight Within',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jim Davis (screenplay), Jim Davis (story)',
#  'Year': '2016',
#  'imdbID': 'tt4838334',
#  'imdbRating': '5.7',
#  'imdbVotes': '245'}
# movie id tt3758334
# {'Actors': 'Benjamin Anderson, Amber Erwin, Tiffany Ford, Teal Haddock',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': "Taylor Ri'chard",
#  'Genre': 'Horror, Thriller',
#  'Language': 'English',
#  'Metascore': '11',
#  'Plot': 'Six eager students strike out to explore and record live footage of '
#          'supernatural activity at an abandoned plantation, but one unsettled '
#          'spirit gives them more than they asked for.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjM4ODQyMzYwMF5BMl5BanBnXkFtZTgwMTgzODc3NzE@._V1_SX300.jpg',
#  'Production': 'Cavu Pictures',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.8/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '38%'},
#              {'Source': 'Metacritic', 'Value': '11/100'}],
#  'Released': '04 Mar 2016',
#  'Response': 'True',
#  'Runtime': '82 min',
#  'Title': 'The Final Project',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': "Zachary Davis, Taylor Ri'chard (story), Taylor Ri'chard, Taylor "
#            "Ri'chard",
#  'Year': '2016',
#  'imdbID': 'tt3758334',
#  'imdbRating': '2.8',
#  'imdbVotes': '259'}
# movie id tt5828388
# {'Actors': 'Johnny Solo',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ari Taub',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '22 Aug 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Final Sacrifice',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ari Taub',
#  'Year': '2016',
#  'imdbID': 'tt5828388',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt5936356
# {'Actors': 'Sarah Dewey, Katie Stahl, Tracy Lucca, Tom McCarthy',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tracy Lucca, Anthony Berenato Jr.',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "When the beloved Mayor's son is almost kidnapped, she finds the very "
#          'institutions she thought were there to help and protect her - are '
#          'now out to get her.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '75 min',
#  'Title': 'The Finders',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tracy Lucca (story), Tracy Lucca',
#  'Year': '2016',
#  'imdbID': 'tt5936356',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt2025690
# {'Actors': 'Chris Pine, Casey Affleck, Ben Foster, Eric Bana',
#  'Awards': '2 wins.',
#  'BoxOffice': '$20,278,493',
#  'Country': 'USA',
#  'DVD': '24 May 2016',
#  'Director': 'Craig Gillespie',
#  'Genre': 'Drama, History, Thriller',
#  'Language': 'English',
#  'Metascore': '58',
#  'Plot': 'The Coast Guard makes a daring rescue attempt off the coast of Cape '
#          'Cod after a pair of oil tankers are destroyed during a blizzard in '
#          '1952.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTY1MDU1NzYzN15BMl5BanBnXkFtZTgwOTA0MDQyNzE@._V1_SX300.jpg',
#  'Production': 'Walt Disney Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.7/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '64%'},
#              {'Source': 'Metacritic', 'Value': '58/100'}],
#  'Released': '29 Jan 2016',
#  'Response': 'True',
#  'Runtime': '117 min',
#  'Title': 'The Finest Hours',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Scott Silver (screenplay), Paul Tamasy (screenplay), Eric Johnson '
#            '(screenplay), Casey Sherman (book), Michael J. Tougias (book)',
#  'Year': '2016',
#  'imdbID': 'tt2025690',
#  'imdbRating': '6.7',
#  'imdbVotes': '57,484'}
# movie id tt5505986
# {'Actors': 'Kevin Held, Elizabeth Lamboy-Wilson, Derek Efrain Villanueva, '
#            'Raymond-Kym Suttle',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Derek Efrain Villanueva',
#  'Genre': 'Crime, Drama, Mystery',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "A detective's past begins to haunt him once learning of his lover's "
#          'mysterious disappearance.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '50 min',
#  'Title': 'The First 24',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Derek Efrain Villanueva',
#  'Year': '2016',
#  'imdbID': 'tt5505986',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt5563192
# {'Actors': 'Newt Gingrich, Callista Gingrich, Robert Lyons, Beverley Simmons',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kevin Knoblock',
#  'Genre': 'Biography, History',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "George Washington is central to understanding America's founding. He "
#          'was the crucial figure in winning the American Revolution, in '
#          'creating the Constitution, and in establishing the ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOWQ3YmUyYTEtZjVkZC00ODcxLTkyZjEtMWI5NWMzODBiYzA4XkEyXkFqcGdeQXVyMTIwNjU1NDA@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.8/10'}],
#  'Released': '20 May 2016',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': 'The First American',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kevin Knoblock',
#  'Year': '2016',
#  'imdbID': 'tt5563192',
#  'imdbRating': '7.8',
#  'imdbVotes': '64'}
# movie id tt4992054
# {'Actors': 'Chris Holliday, Sarah Mezzanotte, Sydney Farley, Teo Rapp-Olsson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Julia Kennelly, Charlotte Martin',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Attending their friends' wedding, a group of twentysomethings must "
#          "confront what it means to 'be adult' in their relationships, "
#          'friendships, and personal identities.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '93 min',
#  'Title': 'The First of Our Friends to Get Married',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Charlotte Martin',
#  'Year': '2015',
#  'imdbID': 'tt4992054',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt4694134
# {'Actors': 'Jason Best, Mark Cohen, Joanna Oullette, Eddie Frat',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Derek Klanfer',
#  'Genre': 'Action, Adventure, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Jan 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Fisher: Rampage',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Derek Klanfer',
#  'Year': '2016',
#  'imdbID': 'tt4694134',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt7140974
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Eric Breaux',
#  'Genre': 'History',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The story of Dr. Louis Leonpacher, pilot, veterinarian, '
#          'photographer, adventurer and pioneer.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '13 Nov 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Flying Vet of Lafayette, the Story of Dr. Louis Leonpacher',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Eric Breaux',
#  'Year': '2016',
#  'imdbID': 'tt7140974',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt6014668
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Dorian Cleavenger',
#  'Genre': 'Fantasy, Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "'Some Stories Are Better Left Untold'",
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': 'The Forbidden Fables',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dorian Cleavenger',
#  'Year': '2016',
#  'imdbID': 'tt6014668',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt3387542
# {'Actors': 'Natalie Dormer, Eoin Macken, Stephanie Vogt, Osamu Tanpopo',
#  'Awards': '1 win & 1 nomination.',
#  'BoxOffice': '$21,818,536',
#  'Country': 'USA',
#  'DVD': '12 Apr 2016',
#  'Director': 'Jason Zada',
#  'Genre': 'Horror, Mystery, Thriller',
#  'Language': 'English, Japanese',
#  'Metascore': '34',
#  'Plot': "A woman goes into Japan's Suicide Forest to find her twin sister, "
#          'and confronts supernatural terror.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjAwMzQzNTc5OV5BMl5BanBnXkFtZTgwNDgyMTU2NzE@._V1_SX300.jpg',
#  'Production': 'Gramercy Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.8/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '10%'},
#              {'Source': 'Metacritic', 'Value': '34/100'}],
#  'Released': '08 Jan 2016',
#  'Response': 'True',
#  'Runtime': '93 min',
#  'Title': 'The Forest',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Nick Antosca, Sarah Cornwell, Ben Ketai',
#  'Year': '2016',
#  'imdbID': 'tt3387542',
#  'imdbRating': '4.8',
#  'imdbVotes': '37,474'}
# movie id tt5479924
# {'Actors': 'Donna Adja, Zion Akande, Michael Sean Erickson, Sahndra Fon Dufe',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Stonz Walters',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Twenty years after the horrors of a West African civil war, Reverend '
#          'Brian William confronts his past when his wife and daughter are '
#          'kidnapped.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZDc5MWI3YjEtNjBlYS00ZDhjLWIwNWEtM2E5NzlkMmFmYjE1XkEyXkFqcGdeQXVyNjU0NTY4MDY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '98 min',
#  'Title': 'The Forgiven',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Sean Erickson, Stonz Walters',
#  'Year': '2016',
#  'imdbID': 'tt5479924',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt4276820
# {'Actors': 'Michael Keaton, Nick Offerman, John Carroll Lynch, Linda '
#            'Cardellini',
#  'Awards': '1 win & 4 nominations.',
#  'BoxOffice': '$12,785,093',
#  'Country': 'USA',
#  'DVD': '18 Apr 2017',
#  'Director': 'John Lee Hancock',
#  'Genre': 'Biography, Drama, History',
#  'Language': 'English, Yiddish',
#  'Metascore': '66',
#  'Plot': "The story of Ray Kroc, a salesman who turned two brothers' "
#          "innovative fast food eatery, McDonald's, into the biggest restaurant "
#          'business in the world, with a combination of ambition, persistence, '
#          'and ruthlessness.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzExNDg0MDk1M15BMl5BanBnXkFtZTgwNzE1Mjg0MDI@._V1_SX300.jpg',
#  'Production': 'The Weinstein Company',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.2/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '81%'},
#              {'Source': 'Metacritic', 'Value': '66/100'}],
#  'Released': '20 Jan 2017',
#  'Response': 'True',
#  'Runtime': '115 min',
#  'Title': 'The Founder',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Robert Siegel',
#  'Year': '2016',
#  'imdbID': 'tt4276820',
#  'imdbRating': '7.2',
#  'imdbVotes': '104,779'}
# movie id tt3517044
# {'Actors': 'Elisabeth Moss, Boyd Holbrook, Octavia Spencer, Sung Kang',
#  'Awards': '2 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '17 Jan 2017',
#  'Director': 'Jason Lew',
#  'Genre': 'Drama, Romance',
#  'Language': 'English',
#  'Metascore': '46',
#  'Plot': 'A recently released former convict becomes involved with a married '
#          'woman with an abusive husband.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTY4MzU2NDg5Nl5BMl5BanBnXkFtZTgwNzA3MjgxMDI@._V1_SX300.jpg',
#  'Production': 'Revelstoke Productions',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '47%'},
#              {'Source': 'Metacritic', 'Value': '46/100'}],
#  'Released': '23 Sep 2016',
#  'Response': 'True',
#  'Runtime': '100 min',
#  'Title': 'The Free World',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jason Lew',
#  'Year': '2016',
#  'imdbID': 'tt3517044',
#  'imdbRating': '6.1',
#  'imdbVotes': '1,425'}
# movie id tt3895248
# {'Actors': 'Ashe Parker, Katie Stewart, James Tackett, Rae Hunt',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Devin Hylton',
#  'Genre': 'Crime, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'On an otherwise mundane morning, Shelly McKenzie wakes up in a '
#          'cabin, on the outskirts of Lexington Ky. Suffering from temporary '
#          'amnesia, she notices she is surrounded by EKG patches ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNGVlY2VkNmYtMjdhOS00NTk1LWExMTYtNDBiOWQ2MjE4ZDA2XkEyXkFqcGdeQXVyNDQ1NzAyMTg@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Freeze',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Devin Hylton',
#  'Year': '2016',
#  'imdbID': 'tt3895248',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt3228196
# {'Actors': 'Zachary Bucholtz',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Zachary Bucholtz',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Oct 2014',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Friend Zone',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Zachary Bucholtz (screenplay)',
#  'Year': '2014',
#  'imdbID': 'tt3228196',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt6448084
# {'Actors': 'Anthony Padilla, Ian Hecox, Ambyr Childers, Jon Lovitz',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'China, USA',
#  'DVD': 'N/A',
#  'Director': 'Guangxi Chang',
#  'Genre': 'Animation',
#  'Language': 'Mandarin',
#  'Metascore': 'N/A',
#  'Plot': 'When One-Eye (Ian Hecox) decides to take over the kingdom, Freddy '
#          '(Anthony Padilla) and',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYTQ2ZjIyOTYtMjcxZC00Y2UxLWIwNmUtNjg1OWM5YmIxMmYwXkEyXkFqcGdeQXVyMTIzNjE0MA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.5/10'}],
#  'Released': '19 Feb 2016',
#  'Response': 'True',
#  'Runtime': '87 min',
#  'Title': 'Arctic Adventure: On Frozen Pond',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Peng Fei, Zheng Liguo, Fei Peng',
#  'Year': '2016',
#  'imdbID': 'tt6448084',
#  'imdbRating': '5.5',
#  'imdbVotes': '47'}
# movie id tt2452386
# {'Actors': 'Alex Huff, Donna Biscoe, Paul Rudd, Julia Denton',
#  'Awards': '3 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '24 Jun 2016',
#  'Director': 'Rob Burnett',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': '55',
#  'Plot': 'A man suffering a family loss enrolls in a class about care-giving '
#          'that changes his perspective on life.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTA1Mjc4ODI0NzReQTJeQWpwZ15BbWU4MDQ3MzAwMjkx._V1_SX300.jpg',
#  'Production': 'Netflix',
#  'Rated': 'TV-MA',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.3/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '77%'},
#              {'Source': 'Metacritic', 'Value': '55/100'}],
#  'Released': '24 Jun 2016',
#  'Response': 'True',
#  'Runtime': '97 min',
#  'Title': 'The Fundamentals of Caring',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Rob Burnett (screenplay), Jonathan Evison (novel)',
#  'Year': '2016',
#  'imdbID': 'tt2452386',
#  'imdbRating': '7.3',
#  'imdbVotes': '51,359'}
# movie id tt6558518
# {'Actors': 'Jesse Baget, Stefania Moscato, April Rose, Neno Stevens',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Evan Tramel',
#  'Genre': 'Animation',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Catnip Everdeen and Ryan Fleacrest take you on a crazy ride into the '
#          'funny lives of pets. Meet the funniest dogs and cats in the world in '
#          'this collection of pet video clips that will leave you rolling on '
#          'the floor laughing.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMWUzMTllZTMtZGM3MC00MTFhLWExNDMtMDZkMWZjYWEwNGRmXkEyXkFqcGdeQXVyMDI2NTc3Mg@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.4/10'}],
#  'Released': '11 Oct 2016',
#  'Response': 'True',
#  'Runtime': '83 min',
#  'Title': 'The Funny Life of Pets',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Evan Tramel',
#  'Year': '2016',
#  'imdbID': 'tt6558518',
#  'imdbRating': '2.4',
#  'imdbVotes': '13'}
# movie id tt11332934
# {'Error': 'Error getting data.', 'Response': 'False'}
# movie id tt5786556
# {'Actors': 'Brit MacRae',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Josh Klaasen',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '10 Oct 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Game',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Josh Klaasen',
#  'Year': '2016',
#  'imdbID': 'tt5786556',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt5615410
# {'Actors': 'Gwendelynn Martindale, Johnick Petry, Justin Rhoe, Matthew Rhoe',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Nathaniel Schexnayder',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Skylar, an avid video game enthusiast, plays games on a daily basis; '
#          "often with his best friend Kihal. However, when Kihal's crush, "
#          'Christy, decides to participate in an annual scavenger ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '18 Mar 2016',
#  'Response': 'True',
#  'Runtime': '45 min',
#  'Title': "The Gamer's Guide to Surviving the Camping Apocalypse",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Nathaniel Schexnayder',
#  'Year': '2016',
#  'imdbID': 'tt5615410',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt5342372
# {'Actors': 'Rory Ogden, Remaz Sharief, Free Spirit, Destiny Brose',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Randa Wise',
#  'Genre': 'Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '15 Oct 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Gifts',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Randa Wise',
#  'Year': '2016',
#  'imdbID': 'tt5342372',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt2833580
# {'Actors': 'Michael Biehn, Tia Carrere, Evie Thompson, Tristan DeVan',
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jennifer Blanc-Biehn',
#  'Genre': 'Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A kidnapped girl is rescued by a young boy, and in return is '
#          'compelled to save him from the horrors that lie in his home.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTgzMzM3OTYyOV5BMl5BanBnXkFtZTgwNTA5NjkzMDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.5/10'}],
#  'Released': '09 Sep 2016',
#  'Response': 'True',
#  'Runtime': '79 min',
#  'Title': 'The Girl',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kevin Marcus, Bradley Marcus, Lony Ruhmann (story)',
#  'Year': '2016',
#  'imdbID': 'tt2833580',
#  'imdbRating': '3.5',
#  'imdbVotes': '170'}
# movie id tt5034082
# {'Actors': 'Briana Aceti, Madeline Lupi, Tina Duong, Victoria Guthrie',
#  'Awards': '2 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '13 May 2016',
#  'Director': 'Ryan Callaway',
#  'Genre': 'Horror, Mystery',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Three young women traveling along a dark country road encounter a '
#          'mysterious girl in a white dress who turns out to be far more than '
#          'she seems.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYjZjMDZlZGUtOWM3OS00N2UxLTllZjYtNTU4MmFiNzNhMzc4XkEyXkFqcGdeQXVyODk5MjQ1Nw@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.2/10'}],
#  'Released': '13 May 2016',
#  'Response': 'True',
#  'Runtime': '81 min',
#  'Title': 'The Girl in the Cornfield',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Amy Callaway (concept), Ryan Callaway',
#  'Year': '2016',
#  'imdbID': 'tt5034082',
#  'imdbRating': '4.2',
#  'imdbVotes': '171'}
# movie id tt2387589
# {'Actors': 'Henry Ian Cusick, Nicki Aycox, Stephen Lang, David Margulies',
#  'Awards': '1 win.',
#  'BoxOffice': '$2,874',
#  'Country': 'USA',
#  'DVD': '11 Aug 2014',
#  'Director': 'Larry Brand',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A chance encounter with a mysterious young woman leads a documentary '
#          'filmmaker down a very different road than he intended as he works on '
#          'his latest project.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTY1NTY3ODc2N15BMl5BanBnXkFtZTgwNTAwNjQzMTE@._V1_SX300.jpg',
#  'Production': 'Monterey Media',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.3/10'}],
#  'Released': '25 Feb 2016',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'The Girl on the Train',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Larry Brand',
#  'Year': '2016',
#  'imdbID': 'tt2387589',
#  'imdbRating': '4.3',
#  'imdbVotes': '849'}
# movie id tt3631112
# {'Actors': 'Emily Blunt, Haley Bennett, Rebecca Ferguson, Justin Theroux',
#  'Awards': 'Nominated for 1 BAFTA Film Award. Another 4 wins & 10 nominations.',
#  'BoxOffice': '$75,311,445',
#  'Country': 'USA, India',
#  'DVD': '17 Jan 2017',
#  'Director': 'Tate Taylor',
#  'Genre': 'Crime, Drama, Mystery, Thriller',
#  'Language': 'English, Spanish',
#  'Metascore': '48',
#  'Plot': 'A divorcee becomes entangled in a missing persons investigation that '
#          'promises to send shockwaves throughout her life.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzFlMjA0ZmUtZWI0Mi00ZGJkLTlmMmYtZmE1ODZiMjhjMGM0XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg',
#  'Production': 'Universal Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '44%'},
#              {'Source': 'Metacritic', 'Value': '48/100'}],
#  'Released': '07 Oct 2016',
#  'Response': 'True',
#  'Runtime': '112 min',
#  'Title': 'The Girl on the Train',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Erin Cressida Wilson (screenplay by), Paula Hawkins (based on the '
#            'novel by)',
#  'Year': '2016',
#  'imdbID': 'tt3631112',
#  'imdbRating': '6.5',
#  'imdbVotes': '156,803'}
# movie id tt7588802
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Christina Rosati',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BN2JkYWY3YzQtNDQ1YS00NzJiLThjNDEtMmQzZjhkOGQ4MzI1XkEyXkFqcGdeQXVyMjYxMzY2NDk@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '75 min',
#  'Title': 'The Gods Obscure',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Christina Rosati',
#  'Year': '2016',
#  'imdbID': 'tt7588802',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt4184054
# {'Actors': 'Tara-Nicole Azarian, Nicholas Azarian, Josh Feldman, Laci Kay',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tara-Nicole Azarian',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': '1 Housecall, 2 Mormons, 3 Hipsters...What could possibly go wrong?',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTExNTM4ODgxODdeQTJeQWpwZ15BbWU4MDA4NzE1NDMx._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Golden Plates',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tara-Nicole Azarian',
#  'Year': '2015',
#  'imdbID': 'tt4184054',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt5025254
# {'Actors': 'Josh Ashy Holden, Laura Flannery, Nick Holden, Marco Perella',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Josh Ashy Holden, Nick Holden',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Opposites attract when a broke, bohemian playboy actor falls for a '
#          'sweet natured, career driven entrepreneur with a sexy identical twin '
#          'sister.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg0YTU2NWUtZjRhZi00MDFiLTg5MTgtOTFmMTBkZmQ1MTk4XkEyXkFqcGdeQXVyMjExMjcwMDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.7/10'}],
#  'Released': '16 Oct 2016',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'The Golden Rut',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Josh Ashy Holden, Nick Holden',
#  'Year': '2016',
#  'imdbID': 'tt5025254',
#  'imdbRating': '7.7',
#  'imdbVotes': '7'}
# movie id tt2262315
# {'Actors': 'James Caan, Logan Miller, Keir Gilchrist, Laura Innes',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '16 Sep 2016',
#  'Director': 'Kasra Farahani',
#  'Genre': 'Crime, Drama, Horror, Thriller',
#  'Language': 'English',
#  'Metascore': '32',
#  'Plot': 'A pair of mischievous high school kids create the illusion of a '
#          'haunting on an unsuspecting elderly neighbor while keeping his every '
#          'reaction under surveillance. A series of coincidences leads to '
#          'tragedy.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjI0NTA5ODc4NV5BMl5BanBnXkFtZTgwNjUzOTc2OTE@._V1_SX300.jpg',
#  'Production': 'Ball &amp; Chain Productions',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '29%'},
#              {'Source': 'Metacritic', 'Value': '32/100'}],
#  'Released': '14 Aug 2017',
#  'Response': 'True',
#  'Runtime': '98 min',
#  'Title': 'The Good Neighbor',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Mark Bianculli, Jeff Richard',
#  'Year': '2016',
#  'imdbID': 'tt2262315',
#  'imdbRating': '6.3',
#  'imdbVotes': '14,671'}
# movie id tt6102114
# {'Actors': 'Andy Baratta, Matthew Chin-Quee, Dalia Kirshshenblat, Cassandra '
#            'Lozano',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Cassandra Lozano, Mason Rader',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Rick and Ruby are an entitled and wildly eccentric couple that exist '
#          'in inheritance and isolation in a New York Park Avenue penthouse. It '
#          'is the summer of 1959. Their long-suffering servant...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYzI5ZTBhNDAtZmI1ZS00YjM4LWJkMTEtNzUwZmU2N2VmMGVlXkEyXkFqcGdeQXVyNjkwMjU2NDI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '97 min',
#  'Title': 'The Grandeur of Delusions',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Mason Rader',
#  'Year': '2016',
#  'imdbID': 'tt6102114',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt4381236
# {'Actors': 'Michael St. Michaels, Sky Elobar, Elizabeth De Razzo, Gil Gex',
#  'Awards': '2 wins & 1 nomination.',
#  'BoxOffice': '$43,580',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jim Hosking',
#  'Genre': 'Comedy, Horror',
#  'Language': 'English',
#  'Metascore': '58',
#  'Plot': 'Ronnie runs a Disco walking tour with his son, Brayden. When a sexy '
#          'woman takes the tour, it begins a competition between father and son '
#          'for her love. It also signals the arrival of an oily strangler who '
#          'stalks the streets at night.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjAyMzkwMzc0M15BMl5BanBnXkFtZTgwMTQwMDg2OTE@._V1_SX300.jpg',
#  'Production': 'Rook Films',
#  'Rated': 'Unrated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.7/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '63%'},
#              {'Source': 'Metacritic', 'Value': '58/100'}],
#  'Released': '07 Oct 2016',
#  'Response': 'True',
#  'Runtime': '93 min',
#  'Title': 'The Greasy Strangler',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Toby Harvard, Jim Hosking',
#  'Year': '2016',
#  'imdbID': 'tt4381236',
#  'imdbRating': '5.7',
#  'imdbVotes': '5,704'}
# movie id tt4794754
# {'Actors': 'Nick Fink, Ritchie Coster, Melanie Lynskey, Louisa Krause',
#  'Awards': '3 wins & 1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Dusty Bias',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Twenty-six year old Scott is living on the streets and trying to '
#          'find his way back into society while on probation for petty crimes. '
#          'He attempts to navigate his relationship with his two ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZjQ4NzFjNTQtN2ExMC00N2Y0LTgxZDUtMWY1NWQ1ZTI0MmRmL2ltYWdlXkEyXkFqcGdeQXVyNjg0ODE1ODE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'}],
#  'Released': '31 Mar 2016',
#  'Response': 'True',
#  'Runtime': '104 min',
#  'Title': 'The Great & The Small',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dusty Bias',
#  'Year': '2016',
#  'imdbID': 'tt4794754',
#  'imdbRating': '5.4',
#  'imdbVotes': '234'}
# movie id tt4550498
# {'Actors': 'Michael Monsour, Michael Anton, Daniel James, Melinda Neyman',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Michael Anton',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Filmmaker Michael Anton and actor Michael Monsour join comedic '
#          'forces as they attempt to make an epic cinematic movie about making '
#          'an epic cinematic movie.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Great American Movie Hustle',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Anton, Michael Monsour',
#  'Year': '2016',
#  'imdbID': 'tt4550498',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt5354364
# {'Actors': 'Suzy Jackson, Sweet Van Loan, Lizzy Jackson, Michael Rodriguez',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Annita Milovich',
#  'Genre': 'Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '10 Jun 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Great Crusader',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Rodriguez, Sweet Van Loan',
#  'Year': '2016',
#  'imdbID': 'tt5354364',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt6053696
# {'Actors': 'David Allen, Maya Arima, Elise Becker, Bob Bolyard',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Nick Patyk',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'John Labell and Mary Fletcher were once in love, or so they thought, '
#          "until they left one another's arms to explore the world and "
#          'experience being with other people. In the miles between ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Nov 2016',
#  'Response': 'True',
#  'Runtime': '93 min',
#  'Title': 'The Great Divide',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Nick Patyk',
#  'Year': '2016',
#  'imdbID': 'tt6053696',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt5903680
# {'Actors': 'Kexin Bao, Alesia Barry, Arianna Barry, Xunjin Bi',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'China, USA',
#  'DVD': 'N/A',
#  'Director': 'Jin Zhang',
#  'Genre': 'Drama, Family, Sci-Fi',
#  'Language': 'Chinese',
#  'Metascore': 'N/A',
#  'Plot': 'One fairy comes to earth to look for the greatest kid to keep her '
#          'home, which is in a fairy tale world. She meets eight kids and hears '
#          'eight different stories. At the end of the story, she ...',
#  'Poster': 'https://ia.media-imdb.com/images/M/MV5BZWQwMTY5MTEtNzk3ZS00YWQ5LWI1YTAtOTZjNTQ4YjczZTVhL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjA4OTc4NDQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.1/10'}],
#  'Released': '01 Aug 2016',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'The Great Guys',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ting Zhang',
#  'Year': '2016',
#  'imdbID': 'tt5903680',
#  'imdbRating': '5.1',
#  'imdbVotes': '9'}
# movie id tt2034800
# {'Actors': 'Matt Damon, Tian Jing, Willem Dafoe, Andy Lau',
#  'Awards': '1 win & 1 nomination.',
#  'BoxOffice': '$45,125,480',
#  'Country': 'USA, China, Hong Kong, Australia, Canada',
#  'DVD': '23 May 2017',
#  'Director': 'Yimou Zhang',
#  'Genre': 'Action, Adventure, Fantasy, Thriller',
#  'Language': 'English, Mandarin, Spanish',
#  'Metascore': '42',
#  'Plot': 'In ancient China, a group of European mercenaries encounters a '
#          'secret army that maintains and defends the Great Wall of China '
#          'against a horde of monstrous creatures.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjA3MjAzOTQxNF5BMl5BanBnXkFtZTgwOTc5OTY1OTE@._V1_SX300.jpg',
#  'Production': 'Universal Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.9/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '36%'},
#              {'Source': 'Metacritic', 'Value': '42/100'}],
#  'Released': '17 Feb 2017',
#  'Response': 'True',
#  'Runtime': '103 min',
#  'Title': 'The Great Wall',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Carlo Bernard (screenplay), Doug Miro (screenplay), Tony Gilroy '
#            '(screenplay), Max Brooks (story), Edward Zwick (story), Marshall '
#            'Herskovitz (story)',
#  'Year': '2016',
#  'imdbID': 'tt2034800',
#  'imdbRating': '5.9',
#  'imdbVotes': '116,228'}
# movie id tt5428922
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kenneth l Hobbs',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'the green lady is a Midwest urban legend of a green female demon who '
#          'is after the children.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '05 May 2016',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'The Green Lady the Emma Green Story',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kenneth l Hobbs',
#  'Year': '2016',
#  'imdbID': 'tt5428922',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt5594956
# {'Actors': 'Trevor Lawson, Veronica Seguin, Mason Girvin, Zach Echols',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Logan Taaffe',
#  'Genre': 'Action, Mystery, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'After an attack in Cavalier, California, Mitch Chase suffers a '
#          'tragedy that puts him on a dangerous track. Will he be able to move '
#          'on or will his symbol die with his humanity?',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjE3NDQ0NTUzNV5BMl5BanBnXkFtZTgwNTczNjc1ODE@._V1_SX300.jpg',
#  'Production': 'Score G Productions',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Rotten Tomatoes', 'Value': '100%'}],
#  'Released': '12 Jun 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Guardian',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Logan Taaffe',
#  'Year': '2016',
#  'imdbID': 'tt5594956',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt5198512
# {'Actors': 'Sonny Castillo, David Lee Hess, Mariana Perez, CJ Legare',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Richard H. Perry',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Gulf',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Wes Martin, Richard H. Perry',
#  'Year': '2016',
#  'imdbID': 'tt5198512',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt5241920
# {'Actors': 'Ian Delaney, Will Holbrook, Ryan Moriarty, Jordan Charles',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Paulette Victor-Lifton',
#  'Genre': 'Western',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Gunman',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2016',
#  'imdbID': 'tt5241920',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt2061841
# {'Actors': 'Devon Gummersall, Sarah Carter, Kevin Ryan, Philippe Caland',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Philippe Caland',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'The Guru & the Gypsy',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Philippe Caland',
#  'Year': '2016',
#  'imdbID': 'tt2061841',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt4112940
# {'Actors': 'John Delony, Amanda Varcelotti, Dean Hollis, Jessica Willis',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Victoria Sutton',
#  'Genre': 'Comedy, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A zombie wedding party gets locked inside a Halloween Store on '
#          'Halloween night and faces the wrath of the return of the legendary, '
#          'possessed cowboy, Ole Jeremiah, who means to make sure nobody gets '
#          'out alive.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk5NDQyODEyNF5BMl5BanBnXkFtZTgwNjQ5MzgxMzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.3/10'}],
#  'Released': '09 Oct 2016',
#  'Response': 'True',
#  'Runtime': '92 min',
#  'Title': 'The Halloween Store Zombie Wedding Movie',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Victoria Sutton, Victoria Sutton',
#  'Year': '2016',
#  'imdbID': 'tt4112940',
#  'imdbRating': '5.3',
#  'imdbVotes': '14'}
# movie id tt5156556
# {'Actors': 'Mara Stopyak, Trevor Norkey, Daniel Crow Jr., Ella Heavy',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Trevor Norkey',
#  'Genre': 'Action, Family, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Young superhero Mara must fight to protect Earth one more time when '
#          'the cosmic being Annihilus vows to destroy everything she loves.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODg5NzYyODAtYTA5ZS00YjUzLWE1N2ItODkzOWE4MGM0MTJiXkEyXkFqcGdeQXVyNjA3OTE2ODk@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Hammer of Mara: Annihilation',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Trevor Norkey',
#  'Year': '2016',
#  'imdbID': 'tt5156556',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt4799826
# {'Actors': 'Natalie Kim, Nancy Sun, Daniel Park, Jun Kim',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Nora Jacobson',
#  'Genre': 'Short, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A recently divorced woman is downsizing. Her adopted Korean daughter '
#          'is helping her pack. When a treasured Korean cultural item is '
#          "broken, the woman travels to New York's Koreatown to see if she can "
#          'get it fixed. An adventure awaits her.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'NOT RATED',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '35 min',
#  'Title': 'The Hanji Box',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Nora Jacobson',
#  'Year': '2015',
#  'imdbID': 'tt4799826',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt4910718
# {'Actors': 'Amanda Bauer, Jack DePew, Janeane Garofalo, Melissa McBride',
#  'Awards': '3 wins & 1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tom Gould, John Serpe',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Twenty-one year old Tracy walks in on her boyfriend Mark having sex '
#          'with a man and decides to leave him. After assessing her limited '
#          'options, she returns to Mark with a deal-if he agrees to...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODNkZTMwNGUtZGY4Mi00NDkyLWJkZmYtMzY5MGU0M2MxODU0XkEyXkFqcGdeQXVyMTExMTgxNw@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.5/10'}],
#  'Released': '14 Aug 2016',
#  'Response': 'True',
#  'Runtime': '87 min',
#  'Title': 'The Happys',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tom Gould, John Serpe',
#  'Year': '2016',
#  'imdbID': 'tt4910718',
#  'imdbRating': '7.5',
#  'imdbVotes': '62'}
# movie id tt4161396
# {'Actors': 'Annabel Bloom, Geneva Carr, Patch Darragh, Daniel Dorrian',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kevin Stocklin',
#  'Genre': 'Crime, Drama, Mystery, Romance, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Miller lives alone in an abandoned Alabama slaughterhouse. His '
#          'memory and sanity are shattered and his only company is the spirit '
#          'of his lover, who was murdered a decade ago. Ruth arrives, ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjA4MjMxNDc2Ml5BMl5BanBnXkFtZTgwMjI4Nzc3MDI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.6/10'}],
#  'Released': '03 Nov 2016',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': 'The Harrow',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kevin Stocklin, Kevin Stocklin',
#  'Year': '2016',
#  'imdbID': 'tt4161396',
#  'imdbRating': '4.6',
#  'imdbVotes': '258'}
# movie id tt8092608
# {'Error': 'Error getting data.', 'Response': 'False'}
# movie id tt5421146
# {'Actors': 'Alexander Vlahos, Jessica Henwick, Jack Hawkins, Freddie Thorp',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tom Keeling',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'In 1972 the tranquility of a coastal town in California is broken as '
#          'hitch-hiking girls begin to go missing and corpses start showing up. '
#          'Welcome to Murder City.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '26 Feb 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Head Hunter',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2016',
#  'imdbID': 'tt5421146',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt4861366
# {'Actors': 'Andrew Willis, Elizabeth Brooks, Miles Snow, Jeff Kidd',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Michael Pearce',
#  'Genre': 'Drama, Mystery',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNWFmYmIyNmYtOGMzMC00ZGViLTgzOTQtZjlmZDg0ZmI5NTliXkEyXkFqcGdeQXVyMjM4NzMzNjY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Healer',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Pearce',
#  'Year': '2016',
#  'imdbID': 'tt4861366',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt4047456
# {'Actors': 'Brad Makarowski, Jessica Medoff, Josh Rowan, Mark Medoff',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ross Kagan Marks',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'In the first act, subtitled THE DIRTY PICTURE MAN (1976), Stephen '
#          '(Red) Ryder, the reluctant nineteen-year-old hero of the original '
#          "play (When You Comin' Back, Red Ryder?), is now a ...",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzE3Nzk5NDA5MF5BMl5BanBnXkFtZTgwNzI2MDY4MjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Heart Outright',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Mark Medoff',
#  'Year': '2015',
#  'imdbID': 'tt4047456',
# ...
#  'Title': "You're Fuck'n Dead!",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jay Spence',
#  'Year': '2015',
#  'imdbID': 'tt2243784',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt5789870
# {'Actors': 'Shelley Starrett, Franco Fox, Brian Woods, Colter Carlbom-Mann',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Alek Dutoit',
#  'Genre': 'Drama, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A mysterious young boy has to fulfill a dark destiny he barely '
#          'understands that could change the world forever.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '88 min',
#  'Title': 'Young Coconut',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Alek Dutoit',
#  'Year': '2016',
#  'imdbID': 'tt5789870',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt5116340
# {'Actors': 'Mark Landon Smith, Victoria Fox, Tyler Dunivan, Tim Gilster',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tyler Dunivan',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '15 Apr 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Your Local News',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jerry Clinton',
#  'Year': '2016',
#  'imdbID': 'tt5116340',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt3687316
# {'Actors': 'Frank Langella, Billy Crudup, Christina Applegate, Mary Kay Place',
#  'Awards': '1 win & 1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '04 Apr 2017',
#  'Director': 'Joel David Moore',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': '38',
#  'Plot': 'A man is tasked with driving his embittered 80-year-old '
#          'father-in-law cross country to be legally euthanized in Oregon, '
#          'while along the way helping him rediscover a reason for living.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjQyMjYyNjUzNl5BMl5BanBnXkFtZTgwNjI0ODAxMTI@._V1_SX300.jpg',
#  'Production': 'Samuel Goldwyn Films',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '45%'},
#              {'Source': 'Metacritic', 'Value': '38/100'}],
#  'Released': '03 Feb 2017',
#  'Response': 'True',
#  'Runtime': '105 min',
#  'Title': 'Youth in Oregon',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Andrew Eisen',
#  'Year': '2016',
#  'imdbID': 'tt3687316',
#  'imdbRating': '5.6',
#  'imdbVotes': '1,006'}
# movie id tt3295180
# {'Actors': 'Kyle Gallner, Adam Herschman, Celia Diane, Clea DuVall',
#  'Awards': '4 wins.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '22 Jun 2018',
#  'Director': 'Rick Darge',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Trapped by daily routine, a man experiences complete freedom by '
#          'dreaming himself across the country in a psychedelic Volkswagen with '
#          'the guiding words of philosopher Alan Watts.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZWE0NTEyZTMtNDdhZS00NzZlLThiNTItMzQ0NjFiYzQ1N2M0XkEyXkFqcGdeQXVyNjYxNDYwNDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.6/10'}],
#  'Released': '21 Apr 2017',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': 'Zen Dog',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Rick Darge',
#  'Year': '2016',
#  'imdbID': 'tt3295180',
#  'imdbRating': '8.6',
#  'imdbVotes': '15'}
# movie id tt5515086
# {'Actors': 'Diego Rosende, Katie Pintado, Eve Smith, Leo Manzari',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': "Liam O'Connor-Genereaux, Gabriel Ciaffone",
#  'Genre': 'Action, Adventure, Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The gang of thieves who became a rock band to escape the mob',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '79 min',
#  'Title': 'Zephyr',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': "Liam O'Connor-Genereaux",
#  'Year': '2016',
#  'imdbID': 'tt5515086',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt10827036
# {'Error': 'Error getting data.', 'Response': 'False'}
# movie id tt6038258
# {'Actors': 'Tedros Berhane, Mereb Estifanos, Sidona Redie, Feven Sahle',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'Eritrea, USA',
#  'DVD': 'N/A',
#  'Director': 'Zerisennay Tesfay',
#  'Genre': 'Drama, Romance',
#  'Language': 'Tigrigna',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzBkZDY0YzctZWViNy00YTkyLThiN2QtNjU2YmRjNzBlZTE5XkEyXkFqcGdeQXVyNjg1NTA4NTU@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '11 May 2016',
#  'Response': 'True',
#  'Runtime': '107 min',
#  'Title': 'Zeyregefet Embaba',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tadese Ukbazghi',
#  'Year': '2016',
#  'imdbID': 'tt6038258',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt5336076
# {'Actors': 'Eric Lee Huffman, Eric Olsson, Jetta Juriansz, Mariano '
#            'González-Guerineau',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Nicholas Tolkien',
#  'Genre': 'Action, Drama, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A dying girl is summoned to Zion National Park with her girlfriend '
#          'to be healed by a mystical shaman',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '101 min',
#  'Title': 'Zion',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Anne Steinberg, Nicholas Tolkien',
#  'Year': '2016',
#  'imdbID': 'tt5336076',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt2250026
# {'Actors': 'Warren Speed, Pete Bennett, Kathy Paul, Caroline Elyssia',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'UK, USA',
#  'DVD': 'N/A',
#  'Director': 'Chris Greenwood, Warren Speed',
#  'Genre': 'Comedy, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Following the release of Zombie Women of Satan, the movie about the '
#          "events of the first film, Pervo's career hasn't quite gone to plan. "
#          "Shunned and unwanted, he's a fading star. But not to ...",
#  'Poster': 'https://ia.media-imdb.com/images/M/MV5BMjAwNDg4NjAzMF5BMl5BanBnXkFtZTgwMjA0NDQzNjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.9/10'}],
#  'Released': '11 Apr 2017',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': 'Female Zombie Riot',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Chris Greenwood, Warren Speed, Warren Speed',
#  'Year': '2016',
#  'imdbID': 'tt2250026',
#  'imdbRating': '2.9',
#  'imdbVotes': '38'}
# movie id tt1608290
# {'Actors': 'Justin Bieber, Jon Daly, Penélope Cruz, Ben Stiller',
#  'Awards': '7 wins & 17 nominations.',
#  'BoxOffice': '$29,782,560',
#  'Country': 'USA, Italy',
#  'DVD': '24 May 2016',
#  'Director': 'Ben Stiller',
#  'Genre': 'Action, Comedy',
#  'Language': 'English, Italian, Spanish',
#  'Metascore': '34',
#  'Plot': 'Derek and Hansel are lured into modelling again, in Rome, where they '
#          'find themselves the target of a sinister conspiracy.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjI2MjQxNTQzOV5BMl5BanBnXkFtZTgwMDE2MTY2NzE@._V1_SX300.jpg',
#  'Production': 'Paramount Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.7/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '22%'},
#              {'Source': 'Metacritic', 'Value': '34/100'}],
#  'Released': '12 Feb 2016',
#  'Response': 'True',
#  'Runtime': '101 min',
#  'Title': 'Zoolander 2',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Justin Theroux, Ben Stiller, Nicholas Stoller, John Hamburg, Drake '
#            'Sather (character Derek Zoolander), Ben Stiller (character Derek '
#            'Zoolander)',
#  'Year': '2016',
#  'imdbID': 'tt1608290',
#  'imdbRating': '4.7',
#  'imdbVotes': '61,308'}
# movie id tt5340882
# {'Actors': 'Ione Butler, Andrew Asper, LaLa Nestor, Kim Nielsen',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '01 Mar 2016',
#  'Director': 'Glenn Miller',
#  'Genre': 'Action, Adventure, Comedy, Horror, Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When a strange virus quickly spreads through a safari park and turns '
#          'all the zoo animals undead, those left in the park must stop the '
#          'creatures before they escape and zombify the whole city.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMDZiMTU0ZmUtY2U1Ni00MzY3LWI4NjMtNzY4ZDFkYmQ5OGM3XkEyXkFqcGdeQXVyNjUyNjMzMzU@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'TV-14',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.3/10'}],
#  'Released': '01 Mar 2016',
#  'Response': 'True',
#  'Runtime': '87 min',
#  'Title': 'Zoombies',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Scotty Mullen (screenplay by)',
#  'Year': '2016',
#  'imdbID': 'tt5340882',
#  'imdbRating': '3.3',
#  'imdbVotes': '2,020'}
# movie id tt2948356
# {'Actors': 'Ginnifer Goodwin, Jason Bateman, Idris Elba, Jenny Slate',
#  'Awards': 'Won 1 Oscar. Another 46 wins & 70 nominations.',
#  'BoxOffice': '$341,264,012',
#  'Country': 'USA',
#  'DVD': '07 Jun 2016',
#  'Director': 'Byron Howard, Rich Moore, Jared Bush(co-director)',
#  'Genre': 'Animation, Adventure, Comedy, Crime, Family, Mystery',
#  'Language': 'English',
#  'Metascore': '78',
#  'Plot': 'In a city of anthropomorphic animals, a rookie bunny cop and a '
#          'cynical con artist fox must work together to uncover a conspiracy.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTMyMjEyNzIzMV5BMl5BanBnXkFtZTgwNzIyNjU0NzE@._V1_SX300.jpg',
#  'Production': 'Walt Disney Animation Studios',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.0/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '97%'},
#              {'Source': 'Metacritic', 'Value': '78/100'}],
#  'Released': '04 Mar 2016',
#  'Response': 'True',
#  'Runtime': '108 min',
#  'Title': 'Zootopia',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Byron Howard (story by), Rich Moore (story by), Jared Bush (story '
#            'by), Jim Reardon (story by), Josie Trinidad (story by), Phil '
#            'Johnston (story by), Jennifer Lee (story by), Jared Bush '
#            '(screenplay by), Phil Johnston (screenplay by)',
#  'Year': '2016',
#  'imdbID': 'tt2948356',
#  'imdbRating': '8.0',
#  'imdbVotes': '398,097'}
# movie id tt3565054
# {'Actors': 'Christina Sadeh, Hossein Mardani, Beka Sikharulidze, Tigran '
#            'Mutafyan',
#  'Awards': '2 wins & 4 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Saeed Khoze',
#  'Genre': 'Drama, War',
#  'Language': 'Arabic, English',
#  'Metascore': 'N/A',
#  'Plot': 'A vividly poetic avant-garde story about abduction, unlawful '
#          "imprisonment, and execution of human rights' activists in countries "
#          'with corrupt governments.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Jul 2016',
#  'Response': 'True',
#  'Runtime': '82 min',
#  'Title': 'Zoya',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Saeed Khoze, Saeed Khoze',
#  'Year': '2016',
#  'imdbID': 'tt3565054',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt8772520
# {'Error': 'Error getting data.', 'Response': 'False'}
# movie id tt4589516
# {'Actors': "Anthony Rapp, De'Adre Aziza, Jermaine Rowe, Drew Allen",
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'John G. Young',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': '64',
#  'Plot': "Following the death of his young son, Brad O'Connor becomes obsessed "
#          'with a young Jamaican man online, eventually leading to a '
#          'confrontation he and his wife can no longer avoid.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjNlOGZmNTktNTYyNS00YTQ0LWEyMzQtYmYxMzVmMDRmODRlXkEyXkFqcGdeQXVyNjg0ODE1ODE@._V1_SX300.jpg',
#  'Production': 'Beachwood Park Films',
#  'Rated': 'Unrated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '67%'},
#              {'Source': 'Metacritic', 'Value': '64/100'}],
#  'Released': '26 Sep 2016',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': 'bwoy',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'John G. Young',
#  'Year': '2016',
#  'imdbID': 'tt4589516',
#  'imdbRating': '5.1',
#  'imdbVotes': '118'}
# movie id tt4587508
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'Reality-TV',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'famiLIES',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2016',
#  'imdbID': 'tt4587508',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt7639448
# {'Actors': 'Zach Strum, Raven Bradley, Zach Laws, Sydney Shepherd',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ian McClerin',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '12 Nov 2016',
#  'Response': 'True',
#  'Runtime': '81 min',
#  'Title': 'i****you',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ian McClerin',
#  'Year': '2016',
#  'imdbID': 'tt7639448',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt5812530
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Lance Linett',
#  'Genre': 'Biography',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'The real on the road movie',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'kero u a c s on the road',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2016',
#  'imdbID': 'tt5812530',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt6072078
# {'Actors': 'Jason Simon',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Mina Monsha Davis-Harrison',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'sTelth is a coming of age film about a young woman who is running '
#          'from herself. The film depicts a fictitious story about a 20 '
#          'something Erin whose beauty will captivate the audience. Erin ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZmIyZDY5NGMtOWY1OS00YzUyLTk1ZmQtZTU5ZTQzNTViMWYzXkEyXkFqcGdeQXVyNjg5MTAwODE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '18 Mar 2016',
#  'Response': 'True',
#  'Runtime': '77 min',
#  'Title': 'sTelth',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Mina Monsha Davis-Harrison',
#  'Year': '2016',
#  'imdbID': 'tt6072078',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# movie id tt1340697
# {'Actors': 'Katrina Lenk, Matt Ritchey, Rebecca Lane, Michael Onofri',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jason J. Loya',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "A woman's pain takes her on a dark journey where she must find new "
#          'hope or be lost forever.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTI0MDU2Mjg2N15BMl5BanBnXkFtZTcwNDkyMjMzMg@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '11 Jan 2009',
#  'Response': 'True',
#  'Runtime': '48 min',
#  'Title': 'Élan Vital',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ryan DeRamos (story), Jason J. Loya (story), Jason J. Loya',
#  'Year': '2009',
#  'imdbID': 'tt1340697',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}

# %%
len(title)
# Out:
# 756

# %%
df = pd.DataFrame({'title_id': title_id, 'title': title_list, 'box_office': box_office_list, 'country': country_list, 
                   'genre': genre_list, 'director': director_list, 'metascore': metascore_list, 'production': production_list, 
                   'rating': rating_list, 'IMDB_rating': IMDB_rating_list, 'rotten_tomatoes_rating': rotten_tomatoes_rating_list, 
                  'runtime': runtime_list, 'type': type_list, 'IMDB_votes': imdb_votes_list})

# %%
df = df.drop_duplicates()
df.head()
# Out:
#                title box_office country                   genre  \
# 0          The Feels        N/A     USA           Comedy, Drama
# 1         The Fiancé        N/A     USA                  Horror
# 2   The Fight Within        N/A     USA  Action, Romance, Sport
# 3  The Final Project        N/A     USA        Horror, Thriller
# 4    Final Sacrifice        N/A     USA                   Drama
#
#                       director metascore           production   rating  \
# 0  Naje Lataillade, Tim Manley       N/A                  N/A      N/A
# 1          Mark Allen Michaels       N/A  Firebreathing Films  UNRATED
# 2       Michael William Gordon       N/A      New Life Cinema    PG-13
# 3              Taylor Ri'chard        11        Cavu Pictures      N/A
# 4                     Ari Taub       N/A                  N/A      N/A
#
#   IMDB_rating rotten_tomatoes_rating runtime   type IMDB_votes
# 0         N/A                     NA  63 min  movie        N/A
# 1         3.5                     NA  79 min  movie         91
# 2         5.7                    40%  94 min  movie        245
# 3         2.8                    38%  82 min  movie        259
# 4         N/A                     NA     N/A  movie        N/A

# %%
df.count()
# Out:
# title                     756
# box_office                756
# country                   756
# genre                     756
# director                  756
# metascore                 756
# production                756
# rating                    756
# IMDB_rating               756
# rotten_tomatoes_rating    756
# runtime                   756
# type                      756
# IMDB_votes                756
# dtype: int64

# %%
df.to_csv('../data/2016_data_batch_4.csv', index=False)
