# %%
import pandas as pd
import requests
import json
import time
from pprint import pprint
from config import API_KEY

# %%
data = pd.read_csv('../title_webscraped/titles_2018_batch3.csv')
df =  data.count()
df
# Out:
# title    1000
# dtype: int64

# %%
title_id = []
box_office_list = []
country_list = []
genre_list = []
director_list = []
metascore_list = []
production_list = []
rating_list = []
IMDB_rating_list = [] 
rotten_tomatoes_rating_list = []
runtime_list = []
title_list = []
type_list = []
imdb_votes_list = []

# %%
movies = data['title']
total_movies = len(movies)

# %%
for i in range(total_movies):
    movie = movies[i]
    url = "http://www.omdbapi.com/?i=" + movie + "&apikey=" + API_KEY
    response = (requests.get(url).text)
    response_json = json.loads(response)
    print('-------------------')
    print(f'movie id {movie}')
    print('-------------------')
    pprint(response_json)
    
    try:
        box_office_list.append(response_json['BoxOffice'])
        country_list.append(response_json['Country'])
        genre_list.append(response_json['Genre'])
        director_list.append(response_json['Director'])
        metascore_list.append(response_json['Metascore'])
        production_list.append(response_json['Production'])
        rating_list.append(response_json['Rated'])
        IMDB_rating_list.append(response_json['imdbRating'])
        try:
            if not response_json['Ratings']:
                rotten_tomatoes_rating_list.append('NA')
            elif response_json['Ratings'][0]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][0]['Value'])
            elif response_json['Ratings'][1]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][1]['Value'])
            else:
                rotten_tomatoes_rating_list.append('NA')
        except IndexError:
            rotten_tomatoes_rating_list.append('NA')
        runtime_list.append(response_json['Runtime'])
        title_list.append(response_json['Title'])
        type_list.append(response_json['Type'])
        imdb_votes_list.append(response_json['imdbVotes'])
        title_id.append(response_json['imdbID'])
    except KeyError:
        pass
    time.sleep(1)
# Out:
# -------------------
# movie id tt6856718
# -------------------
# {'Actors': 'Chloe Catherine Kim, Grace McCullough, Nadia Mohebban, Paige '
#            'Conroy',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jonathan Zuck',
#  'Genre': 'Action',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Harvey has led a cautious and conscientious life until he gets fired '
#          'and finds out he has one month to live. Throwing caution to the '
#          "wind, he meets Luke at a bar and confesses he's never ...",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZGVkOWIyMjctODg2My00NDMzLWE1MjUtYzI0NDE0Y2Q1NGVkXkEyXkFqcGdeQXVyMjA1ODY2NA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Meant to Be Broken',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joe Leone, Jenna St. John, Jonathan Zuck',
#  'Year': '2018',
#  'imdbID': 'tt6856718',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2670882
# -------------------
# {'Actors': 'Judy Greer, Liana Liberato, Donald Sutherland, Luke Wilson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jim Loach',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': '53',
#  'Plot': 'A bullied teen experiences a turning point summer in which he learns '
#          'to stand up for himself.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDIxNjQwOTEyOV5BMl5BanBnXkFtZTgwMjI2OTMxNTM@._V1_SX300.jpg',
#  'Production': 'Great Point Media',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '52%'},
#              {'Source': 'Metacritic', 'Value': '53/100'}],
#  'Released': '11 May 2018',
#  'Response': 'True',
#  'Runtime': '100 min',
#  'Title': 'Measure of a Man',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'David Scearce (screenplay), Robert Lipsyte (based on the novel '
#            '"One Fat Summer" by)',
#  'Year': '2018',
#  'imdbID': 'tt2670882',
#  'imdbRating': '6.3',
#  'imdbVotes': '859'}
# -------------------
# movie id tt7664772
# -------------------
# {'Actors': 'Liane Langford, Robert Lankford, Ken May',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'John Ward',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk0MmU1M2UtMGExNi00MjRiLWE4MmMtMmMxYWVhNTdkYzcyXkEyXkFqcGdeQXVyNjkyNTA2ODU@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Meathook Massacre 4',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'John Ward',
#  'Year': '2018',
#  'imdbID': 'tt7664772',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt10544554
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt7891964
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt5607324
# -------------------
# {'Actors': 'Precilia Kinsley, Ester T. Ferman, Layla Hale, Jim Hoover',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Matt Oyler',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Flatline Productions presents: Medic ZerØ After facing their own '
#          "personal tragedies, three peoples' lives intersect with deadly "
#          'ramifications. Jaded paramedic Chance LeCroix (Matt Oyler) is...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzQ0MWQwYzAtYzNlMS00YmExLWFjZmYtODBkOTU2ZmFmNTY0XkEyXkFqcGdeQXVyMzc1NjMwNjA@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '31 Oct 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Medic ZerØ',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Brittany Feazell (script supervisor), Matt Oyler',
#  'Year': '2018',
#  'imdbID': 'tt5607324',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7779230
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt10387748
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt8329540
# -------------------
# {'Actors': 'Anthony Fort, Deborah Kay Hooker, Dawson Jackson, Larry D. Johnson '
#            'Jr.',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Fred T.',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Jason is about to meet his girlfriend's parents for the first time. "
#          'Thinking that everything is going to be cool and easy. He soon finds '
#          'out that meeting the family sometimes brings out the worst in you.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDE2MjMyMGQtNTJmMy00MWI0LWJlOTItMGIwZTRmYzEzZDgyXkEyXkFqcGdeQXVyNTA2Mjg1NDg@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'}],
#  'Released': '28 Feb 2018',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'Meeting the Folks',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Fred T.',
#  'Year': '2018',
#  'imdbID': 'tt8329540',
#  'imdbRating': '6.6',
#  'imdbVotes': '7'}
# -------------------
# movie id tt6594244
# -------------------
# {'Actors': 'Deven Bromme, Gant Montgomery, Timothy E. Goodwin, Davis Osborne',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Deven Bromme',
#  'Genre': 'Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': "Megan's Christmas Miracle",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jason Campbell',
#  'Year': '2018',
#  'imdbID': 'tt6594244',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4807398
# -------------------
# {'Actors': 'Terri J. Vaughn, Earthquake, Sandra Reaves-Phillips, Jennifer '
#            'Williams',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Marishka Phillips',
#  'Genre': 'Drama',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'When the wife of the DA of New Orleans learns of her husbands '
#          'infidelity, she stops at nothing to keep her family together. When '
#          "that doesn't work, things turn tragic.",
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Melinda',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2015',
#  'imdbID': 'tt4807398',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8617064
# -------------------
# {'Actors': 'Kristin Mellian, Robert William Ford, Beverly Courtade, Kara Joy '
#            'Reed',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Joshua Courtade',
#  'Genre': 'Comedy, Drama, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Upon returning to earth, a withdrawn woman named Melody hires an '
#          'oddball private eye to track down the man who helped her escape from '
#          'an alien zoo on Neptune. Or maybe it was Pluto.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOWUxY2ZiMjEtYmVmYi00ZjQ4LWExZWEtZjI1ZDdhZjcyNTZhXkEyXkFqcGdeQXVyMjMwMjQ0Nzg@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.1/10'}],
#  'Released': '28 Sep 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Melody on Earth',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joshua Courtade',
#  'Year': '2018',
#  'imdbID': 'tt8617064',
#  'imdbRating': '8.1',
#  'imdbVotes': '11'}
# -------------------
# movie id tt5273284
# -------------------
# {'Actors': 'Sarah Schoofs, Shivantha Wijesinha, Lauren A. Kennedy, Kitty '
#            'Ostapowicz',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Sean Mannion',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A mysterious VHS tape sends a young woman on quest to discover its '
#          'maker, but she finds herself instead.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzA4MTVhYmEtOWNjZi00ZjY0LWE4OGUtNmJjOGJiMWQ2M2NmXkEyXkFqcGdeQXVyMjIwNzg4NzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '9.1/10'}],
#  'Released': '09 Jun 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Meme',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Sean Mannion',
#  'Year': '2018',
#  'imdbID': 'tt5273284',
#  'imdbRating': '9.1',
#  'imdbVotes': '9'}
# -------------------
# movie id tt8602902
# -------------------
# {'Actors': 'Amy Seimetz, David Nordstrom, Jan Johnson, Suanne Spoke',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Gary Mairs',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Made over the course of ten years, Memory/Lies is a feature '
#          'comprised of five interrelated short films all written by different '
#          'screenwriters that tell the stories of two people as they move from '
#          'their mid twenties towards forty.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOGI2M2RlNWEtNWEwYy00YjE4LTg0OGMtM2QyMTgxNzQyYTQ5XkEyXkFqcGdeQXVyODA5Njk0Nzk@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.8/10'}],
#  'Released': '01 Jan 2018',
#  'Response': 'True',
#  'Runtime': '94 min',
#  'Title': 'Memory/Lies',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'James Benning, Tom Block, Theron Patterson, Lee Anne Schmitt',
#  'Year': '2018',
#  'imdbID': 'tt8602902',
#  'imdbRating': '7.8',
#  'imdbVotes': '5'}
# -------------------
# movie id tt7173784
# -------------------
# {'Actors': 'Robyn Babina, Jen Elyse Feldy, Christina Shea-Wright, Sarah Martin',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Sarah Martin',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A real life serial killer who murders call girls and surgically '
#          'removes their eyeballs which would later be sewn into taxidermy '
#          'projects of various kinds. This chilling horror thriller will leave '
#          'you wanting more.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzNiNTMyMGYtYzIzYi00MGIzLThjYTItOTI4MTYzYTJhOTc3XkEyXkFqcGdeQXVyNTk2MjM3MjM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Sep 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Menagerie',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Sarah Martin',
#  'Year': '2018',
#  'imdbID': 'tt7173784',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5804846
# -------------------
# {'Actors': 'Lauren Elizabeth Hirsch, Catherine Tapling, Emily Lape, Melissa '
#            'Gin',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Emily Lape',
#  'Genre': 'Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A closeted gay woman, Mercy (Emily Lape), meets an attractive, '
#          'sexual and loving college student named Jesse (Alison Hixon) that '
#          'challenges her to explore her own beliefs on sexuality and religion.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDM5M2YzMDEtY2QxMC00NGYzLWJjMTQtZjQ3Y2YyYzY3NDEwXkEyXkFqcGdeQXVyMjEwNzUyNTM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '123 min',
#  'Title': "Mercy's Girl",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Emily Lape',
#  'Year': '2016',
#  'imdbID': 'tt5804846',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8865872
# -------------------
# {'Actors': 'Yuliya Leybyuk',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Babak Mansouri',
#  'Genre': 'Short, Musical',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Mermaids is a documentary about the transformative power of a '
#          'universal myth as seen through the eyes of five tail-donning women '
#          'who beckon us into their eccentric yet deeply poetic underwater '
#          'worlds.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '23 Mar 2018',
#  'Response': 'True',
#  'Runtime': '76 min',
#  'Title': 'Mermaids',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2018',
#  'imdbID': 'tt8865872',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt9150394
# -------------------
# {'Actors': 'Julian Alexander, Towanda Braxton, Kim Fields, Renell Gibbs',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Terri J. Vaughn',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Kenni, who has avoided the annual holiday trip to her hometown of '
#          'Columbia, South Carolina for years. While she is hoping for the '
#          'best, as with any family, there are unresolved issues lingering that '
#          'could make the holiday not so bright.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZjcwYTc5NTQtOGZmMS00NWUwLTk2ZTQtYTEwYTVkZTYzNTc0XkEyXkFqcGdeQXVyODU4NTYwMDA@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.8/10'}],
#  'Released': '02 Dec 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Merry Wish-Mas',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2018',
#  'imdbID': 'tt9150394',
#  'imdbRating': '6.8',
#  'imdbVotes': '6'}
# -------------------
# movie id tt8149240
# -------------------
# {'Actors': 'Shouvik Ramgir',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Mayur Ramgir',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': '"Magic is surreal. Only a few get the chance to experience the '
#          'nectar of magical spells. Meet Vanessa and Nick they are the best '
#          "friends. On one hand Nick doesn't believes in magic. On the ...",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODU3YTAxMDYtZDNmOC00MDYwLThjNTctOTVmYWNhODVhMWU3XkEyXkFqcGdeQXVyODQ4MTY3NzQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '31 Dec 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Merryland',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Mayur Ramgir, Shayan Sengupta',
#  'Year': '2018',
#  'imdbID': 'tt8149240',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt10911666
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt7914308
# -------------------
# {'Actors': 'Jimmy Dempster, Benjamin Bernard, Raul Colon, Audrey Dempster',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'D.J. Rivera',
#  'Genre': 'Action, Horror, Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A fallen hero, with the power to resurrect the undead, must save the '
#          "world from a deadly infection that has turned the world's population "
#          'into undead savages.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzk5MTY0NGEtMmE1ZC00ODU3LWI1MDEtYzJhNDUzYWU3MTk5XkEyXkFqcGdeQXVyODI4MTY2MTI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '62 min',
#  'Title': 'Messiah',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'D.J. Rivera',
#  'Year': '2018',
#  'imdbID': 'tt7914308',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8097932
# -------------------
# {'Actors': 'Matthew Farmer, Steven Farmer, Samad Abedi, Alex Ansel',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Steven Farmer',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A massage therapist that wants to be a metal guitarist finds himself '
#          'deep in the world of competitive fighting games.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Dec 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Metal Gamer',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Steven Farmer',
#  'Year': '2018',
#  'imdbID': 'tt8097932',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6385016
# -------------------
# {'Actors': "Ryan Durante, Tammy O'Neal, Jordan Peralta, Stefan Castro",
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Chase Diedrich',
#  'Genre': 'Action, Comedy, Sci-Fi',
#  'Language': 'English, Spanish, French',
#  'Metascore': 'N/A',
#  'Plot': 'High-schooler Finnigan Greed has found a stone that gives him '
#          'superpowers. As he tries to hide his powers and new identity, he '
#          'meets a new friend, Jordan Peralta, who just so happens to have '
#          'similar powers.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODc0YWRiN2EtZjZkOC00NTlkLWI4MzctODc0OGZkYzhjZjI2XkEyXkFqcGdeQXVyNjUwNzY0Nzc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '20 Jul 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Metalloid: Freshman',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Chase Diedrich (San Luis Obispo)',
#  'Year': '2018',
#  'imdbID': 'tt6385016',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8299862
# -------------------
# {'Actors': 'Michael Yo',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Devon Shepard',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Family first comedian and bonafide Blasian, Michael Yo, brings his '
#          'uniquely personal blend of comedy to his debut stand up special. '
#          'Born and raised in Houston, TX, Michael talks about the ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZGRkZGJlZmQtNjNlMi00MjdmLWE4MmQtMjY5Yzc5N2M1MWMxXkEyXkFqcGdeQXVyMzcwMjcwNQ@@._V1_SX300.jpg',
#  'Production': 'Comedy Dynamics',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '27 Nov 2018',
#  'Response': 'True',
#  'Runtime': '56 min',
#  'Title': 'Michael Yo: Blasian',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Yo',
#  'Year': '2018',
#  'imdbID': 'tt8299862',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5613484
# -------------------
# {'Actors': 'Sunny Suljic, Katherine Waterston, Lucas Hedges, Na-kel Smith',
#  'Awards': '4 wins & 9 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '08 Jan 2019',
#  'Director': 'Jonah Hill',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': '66',
#  'Plot': 'Follows Stevie, a thirteen-year-old in 1990s-era Los Angeles who '
#          'spends his summer navigating between his troubled home life and a '
#          'group of new friends that he meets at a Motor Avenue skate shop.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZDhjNDQ0MjEtNWZhMy00ZTY1LWFkYmQtMWYwNDliNGQ1MWU2XkEyXkFqcGdeQXVyNTAzMTY4MDA@._V1_SX300.jpg',
#  'Production': 'A24',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.4/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '81%'},
#              {'Source': 'Metacritic', 'Value': '66/100'}],
#  'Released': '26 Oct 2018',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': 'Mid90s',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jonah Hill',
#  'Year': '2018',
#  'imdbID': 'tt5613484',
#  'imdbRating': '7.4',
#  'imdbVotes': '33,092'}
# -------------------
# movie id tt9455028
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt3060342
# -------------------
# {'Actors': 'Erika Othen, Shelly Martinez, Derek Easley, Adeana Lane',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'David Scheinbaum',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Cast members of a new reality TV show find themselves trapped in an '
#          'old murder house with a sledge hammer wielding psychopath.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTM1YjVkZGYtYzc0YS00MDg2LTlmMTctZjA5ZWM1MmY4NDg5XkEyXkFqcGdeQXVyMTAxNTIzOTQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '77 min',
#  'Title': 'Middle of the Night',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'David Scheinbaum',
#  'Year': '2017',
#  'imdbID': 'tt3060342',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8220288
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt4275214
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'Germany, USA, Canada',
#  'DVD': 'N/A',
#  'Director': 'Ludovic Bernard',
#  'Genre': 'Comedy, Thriller',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'A dark comedy about Johnny and Shelly, two young alcoholics in love. '
#          'It\'s a modern spin on the age-old "road-trip buddy-movie." Their '
#          'lives have spiraled completely out of control. While society has '
#          "written them off, fate hasn't.",
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Midnight Detour',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Carey Borth (screenplay), Thomas Heatley (screenplay)',
#  'Year': '2015',
#  'imdbID': 'tt4275214',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4372572
# -------------------
# {'Actors': 'Susie Feldman, Linda Harrison, Don Pedro Colley, Byron Cherry',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Travis Bowen, Byron Cherry, Don Pedro Colley, Linda Harrison',
#  'Genre': 'Action, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An outlaw terrorist organization led by Cleopatra, Mark Antony, and '
#          'Julius Caesar plot to create a new government after WWIII. Only '
#          'three men will stand in their way at all costs with the fate of the '
#          'future of humanity depending on them.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTgwODI4NjU3MV5BMl5BanBnXkFtZTgwNDk5ODA4NDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '12 Dec 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Midnight Massacre',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Travis Bowen',
#  'Year': '2015',
#  'imdbID': 'tt4372572',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4799066
# -------------------
# {'Actors': 'Bella Thorne, Patrick Schwarzenegger, Rob Riggle, Quinn Shephard',
#  'Awards': '6 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '19 Jun 2018',
#  'Director': 'Scott Speer',
#  'Genre': 'Drama, Romance',
#  'Language': 'English',
#  'Metascore': '38',
#  'Plot': 'A 17-year-old girl suffers from a condition that prevents her from '
#          'being out in the sunlight.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjg0NjU1MjgyNF5BMl5BanBnXkFtZTgwNzc5NjYyNDM@._V1_SX300.jpg',
#  'Production': 'Open Road Films',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '22%'},
#              {'Source': 'Metacritic', 'Value': '38/100'}],
#  'Released': '23 Mar 2018',
#  'Response': 'True',
#  'Runtime': '91 min',
#  'Title': 'Midnight Sun',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kenji Bando (based on the motion picture screenplay "Taiyô no uta" '
#            'by), Eric Kirsten',
#  'Year': '2018',
#  'imdbID': 'tt4799066',
#  'imdbRating': '6.6',
#  'imdbVotes': '18,538'}
# -------------------
# movie id tt4560436
# -------------------
# {'Actors': 'Mark Wahlberg, Lauren Cohan, Iko Uwais, John Malkovich',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'China, USA, Colombia',
#  'DVD': '30 Oct 2018',
#  'Director': 'Peter Berg',
#  'Genre': 'Action, Thriller',
#  'Language': 'Filipino, English, Russian, Indonesian',
#  'Metascore': '38',
#  'Plot': 'A small team of elite American intelligence officers, part of a '
#          'top-secret tactical command unit, try to smuggle a mysterious police '
#          'officer with sensitive information out of Indonesia.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzUyODk4OTkxNF5BMl5BanBnXkFtZTgwMzY0MDgzNTM@._V1_SX300.jpg',
#  'Production': 'STXfilms',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '23%'},
#              {'Source': 'Metacritic', 'Value': '38/100'}],
#  'Released': '17 Aug 2018',
#  'Response': 'True',
#  'Runtime': '94 min',
#  'Title': 'Mile 22',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Lea Carpenter (screenplay by), Graham Roland (story by), Lea '
#            'Carpenter (story by)',
#  'Year': '2018',
#  'imdbID': 'tt4560436',
#  'imdbRating': '6.1',
#  'imdbVotes': '55,125'}
# -------------------
# movie id tt9023974
# -------------------
# {'Actors': 'Charlie Moore, Erynn Mitchell, Sean K. Forrest, Felicity Childs '
#            'Smith',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Erynn Mitchell',
#  'Genre': 'Mystery',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYjRjNGEwNWItMzNmYi00MjY5LTk3OTctNTViOTZhNGU5Y2NiXkEyXkFqcGdeQXVyNzQ3NjQyNDI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Milk and Strawberries',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Erynn Mitchell, Charlie Moore',
#  'Year': '2018',
#  'imdbID': 'tt9023974',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6131232
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Douglas Schulze',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Mimesis: A Symphony of Horror',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jeff Meyers (screenplay)',
#  'Year': '2017',
#  'imdbID': 'tt6131232',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8751530
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt7646806
# -------------------
# {'Actors': 'Austin Manley, Lucy Morningstar, Michael Blaine',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Lucy Morningstar',
#  'Genre': 'Short, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A woman on a dangerous path struggles to face reality while her '
#          'family, shelter and well-being crumble. The life she once knew has '
#          'become a faint memory as she drives far and wide in search for '
#          'humanity.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOWY1YjZkMGUtY2JjOS00Njk3LThlMzEtZTQwMDc3ZThiNzQzXkEyXkFqcGdeQXVyNTk3MjgyNjM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '05 Feb 2018',
#  'Response': 'True',
#  'Runtime': '15 min',
#  'Title': 'Mindstate',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Blaine, Lucy Morningstar',
#  'Year': '2018',
#  'imdbID': 'tt7646806',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3312552
# -------------------
# {'Actors': "Alexandra Turshen, Kelsey O'Brien, Ryan O'Callaghan, Bobby Kruger",
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Justin Ho',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Minor Motion Picture',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Justin Ho',
#  'Year': '2015',
#  'imdbID': 'tt3312552',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3079568
# -------------------
# {'Actors': 'William Baldwin, Richard Grieco, Bill Moseley, Viva Bianca',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Christopher Ray',
#  'Genre': 'Action, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "On the cusp of New Year's Eve, seven friends and a mysterious "
#          'backpacker converge at a desolate ski lodge in the mountains when '
#          'they are systematically hunted down by ruthless masked men with a '
#          'cryptic agenda.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTY3NTUzNTgzNV5BMl5BanBnXkFtZTgwOTk2MDUxNzE@._V1_SX300.jpg',
#  'Production': 'DeInstitutionalized LLC',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.4/10'}],
#  'Released': '03 Jul 2018',
#  'Response': 'True',
#  'Runtime': '91 min',
#  'Title': 'Minutes to Midnight',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Victoria Dadi, Christopher M. Don',
#  'Year': '2018',
#  'imdbID': 'tt3079568',
#  'imdbRating': '3.4',
#  'imdbVotes': '186'}
# -------------------
# movie id tt7883448
# -------------------
# {'Actors': 'Hannah Kleeman, Steven J. Klaszky, Hanh Nguyen, Paul Weaver',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Michael Wellenreiter',
#  'Genre': 'Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'As the year 1982 ends, World War III rages on. When a murderous '
#          'defector and his clones plot final global annihilation, the assassin '
#          'Dezmon and pacifist rebel Xuefang team up to take them down in this '
#          'surreal sci-fi thriller.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYjQ4N2VkMDEtYzQzZC00NTU2LWE0NDQtYzc0NTc5MjQ0NzFmXkEyXkFqcGdeQXVyMjEwMzUxNTg@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '92 min',
#  'Title': 'Mirrors',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Wellenreiter',
#  'Year': '2018',
#  'imdbID': 'tt7883448',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7593582
# -------------------
# {'Actors': 'Brooke Bradshaw, Dani Colleen, Kathleen Marich, Donald Michael '
#            'Smith',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Dutch Marich',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Cleone, a homeless woman living on the streets of Los Angeles, '
#          'recounts tales from when she worked for a mysterious evil.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYWJkYTYwNjAtNGQzMS00NTQ2LWFkNDQtNDMyOGViZTMxOTJmXkEyXkFqcGdeQXVyOTUxOTk0Nw@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Miserable Sinners',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dutch Marich',
#  'Year': '2018',
#  'imdbID': 'tt7593582',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8516398
# -------------------
# {'Actors': 'Sierra Collins, Vivi Devereaux, Kenneth Thomas Fisher, Sam '
#            'Krumrine',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Halle Capone',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A kinky love letter to suspense masters like Alfred Hitchcock, Carol '
#          'Reed, and Billy Wilder, Misfits of the Profane is a hypnotic descent '
#          'into a kaleidoscopic fever dream. A sensory ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzMyMjUzMmEtN2YyMi00MmM3LWI2MTItODdjYjVlMzdiOWZiXkEyXkFqcGdeQXVyMTY1MTgwMzc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '20 Dec 2018',
#  'Response': 'True',
#  'Runtime': '100 min',
#  'Title': 'Misfits of the Profane',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Halle Capone, Gabriel Hans Durst',
#  'Year': '2018',
#  'imdbID': 'tt8516398',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8111654
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt7356166
# -------------------
# {'Actors': 'Johanna Braddy, Kyle Howard, Blake McAlpin, Missi Pyle',
#  'Awards': '3 wins & 2 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Autumn McAlpin',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Rose Raynes was crowned Miss Arizona - 15 years ago. Now a bored '
#          'housewife trapped in a less-than-ideal-marriage , and mourning the '
#          'independence of her 10-year-old-son, Rose accepts an ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMDU3NDFjZjQtNDlkMi00ZDljLTk1OGQtNGY4N2RjNzBjODNhXkEyXkFqcGdeQXVyNDU5NTk1MA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.9/10'}],
#  'Released': '10 Jun 2018',
#  'Response': 'True',
#  'Runtime': '94 min',
#  'Title': 'Miss Arizona',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Autumn McAlpin',
#  'Year': '2018',
#  'imdbID': 'tt7356166',
#  'imdbRating': '4.9',
#  'imdbVotes': '135'}
# -------------------
# movie id tt8759976
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt10383096
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt7554880
# -------------------
# {'Actors': 'Maggie Knoedelseder, Nate Schaefer, Michael Watterson, Alex Tolar',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'Crime, Horror, Mystery',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': '"There\'s a secret within every group" Missed Take is a feature film '
#          'about footage found on a crime scene after a group of film makers go '
#          'to an abandoned barn to film a short film. The case is still open.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMDcwZTUyNTItNjFkMy00NGU3LTllMjMtYmI2ZjdjYjFiNGVlXkEyXkFqcGdeQXVyODE2OTkzNTk@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '83 min',
#  'Title': 'Missed Take',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2018',
#  'imdbID': 'tt7554880',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3918784
# -------------------
# {'Actors': 'John Archer Lundgren, Tony Demil, Mihui Hall, Zadya Lundgren',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Memekiyaye Deneke',
#  'Genre': 'Drama',
#  'Language': 'English, Amharic, Spanish',
#  'Metascore': 'N/A',
#  'Plot': 'Infamous for his long career smuggling weapons, drugs and diamonds '
#          'throughout Africa, an elderly international gangster has initiated a '
#          'new business enterprise focused on Ethiopia. Anonymous.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Mission',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Memekiyaye Deneke, John Archer Lundgren (narrations written by), '
#            'Faven Ressom (narration editor), Joshua Schnose (narration editor)',
#  'Year': '2016',
#  'imdbID': 'tt3918784',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4912910
# -------------------
# {'Actors': 'Tom Cruise, Henry Cavill, Ving Rhames, Simon Pegg',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, China, France, Norway, UK',
#  'DVD': '04 Dec 2018',
#  'Director': 'Christopher McQuarrie',
#  'Genre': 'Action, Adventure, Thriller',
#  'Language': 'English, French',
#  'Metascore': '86',
#  'Plot': 'Ethan Hunt and his IMF team, along with some familiar allies, race '
#          'against time after a mission gone wrong.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjRlZmM0ODktY2RjNS00ZDdjLWJhZGYtNDljNWZkMGM5MTg0XkEyXkFqcGdeQXVyNjAwMjI5MDk@._V1_SX300.jpg',
#  'Production': 'Paramount Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.8/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '97%'},
#              {'Source': 'Metacritic', 'Value': '86/100'}],
#  'Released': '27 Jul 2018',
#  'Response': 'True',
#  'Runtime': '147 min',
#  'Title': 'Mission: Impossible - Fallout',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Bruce Geller (based on the television series created by), '
#            'Christopher McQuarrie',
#  'Year': '2018',
#  'imdbID': 'tt4912910',
#  'imdbRating': '7.8',
#  'imdbVotes': '253,475'}
# -------------------
# movie id tt5699180
# -------------------
# {'Actors': 'James Franco, Marianna Palka, Topher Grace, Amy Smart',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Arkesh Ajay, Kelly Pike, Jerell Rosales, Marta Savina',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A collection of four short films based on stories written by William '
#          'Faulkner.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZmMzN2ZiZmMtMGZlZi00ZWRhLWEwYWUtYmI5YTNhZjhiNGMxXkEyXkFqcGdeQXVyMTA4Mjg5MDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.4/10'}],
#  'Released': '17 May 2018',
#  'Response': 'True',
#  'Runtime': '88 min',
#  'Title': 'Mississippi Requiem',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jessica Dube, Mia Farmer, William Faulkner (based on the short '
#            'stories by), James Franco (developed by), Paige Gresty, Ben Reider',
#  'Year': '2018',
#  'imdbID': 'tt5699180',
#  'imdbRating': '7.4',
#  'imdbVotes': '14'}
# -------------------
# movie id tt6823894
# -------------------
# {'Actors': 'Larry Biela, Lori Marshall, Valoria Robinson, Steve Pavlik',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Aaron Hawkins',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Jody sees her husband, John with his friends at a bar and gets '
#          'increasingly mad at him for appearing to hit on the bartender when '
#          'he is trying to get her to work with him in his movie. Jody gets '
#          'payback on John.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMGY3OWRjZDUtYTgwMC00NjI0LWE0MjgtZGRiYTc4ZWU1NDFjXkEyXkFqcGdeQXVyNjc0MTczMTQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '02 Nov 2018',
#  'Response': 'True',
#  'Runtime': '105 min',
#  'Title': 'Mistaken Identity: A Love Story',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Aaron Hawkins',
#  'Year': '2018',
#  'imdbID': 'tt6823894',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6868606
# -------------------
# {'Actors': 'Aaron Nicholas Brakefield, Lauren Paige Wilson, Merritt Vann, '
#            'Benjamin Augusta',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Dean Ferreira',
#  'Genre': 'Comedy',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'Jack, an almost famous musician, who loses his band, his wife, and '
#          'his job, enrolls in a school for men to learn how to get his wife '
#          'back.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZjhlNTZlNzgtM2EzNS00MTg0LTk5YjQtN2ZhOTc4MDQxYTEwXkEyXkFqcGdeQXVyODAxNDAxNDg@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.3/10'}],
#  'Released': '01 Jun 2019',
#  'Response': 'True',
#  'Runtime': '99 min',
#  'Title': 'Mister Academy',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dean Ferreira (screenplay), Dean Ferreira (story)',
#  'Year': '2018',
#  'imdbID': 'tt6868606',
#  'imdbRating': '2.3',
#  'imdbVotes': '15'}
# -------------------
# movie id tt5817056
# -------------------
# {'Actors': 'Frank Piciullo, Brooke Hartnett, Owen Virgin, Cameron Mahai',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Wade Shields',
#  'Genre': 'Comedy, Drama, Mystery',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When a peculiar vandal terrorizes Gladwater High with sad poetry, a '
#          'guidance counselor competes with a newspaper student to solve the '
#          'mystery.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Mister Sadpants',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Wade Shields',
#  'Year': '2017',
#  'imdbID': 'tt5817056',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4103470
# -------------------
# {'Actors': 'Jane Seymour, Nia Peeples, Parker Stevenson, Ellen Travolta',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Shane Stanley',
#  'Genre': 'Drama, Romance',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'Having no commitments and never being vulnerable, Veronica enjoys '
#          'being a mistress. She comes to realize her best friend holds the key '
#          'to her heart and is the only one capable of extracting her emotions.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTA4OWNhNzEtYTVmMC00ZTQxLTliY2QtM2NlNGJiZjNjNTkyXkEyXkFqcGdeQXVyMzg1ODQ4OQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'TV-14',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.7/10'}],
#  'Released': '01 Jun 2018',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Mistrust',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tiffany Johnson, Shane Stanley',
#  'Year': '2018',
#  'imdbID': 'tt4103470',
#  'imdbRating': '5.7',
#  'imdbVotes': '927'}
# -------------------
# movie id tt8058918
# -------------------
# {'Actors': 'Matthew Abaya, Rachael Adiah, Shlomo Cohn, Anne Heit',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'William Cardoza',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Misunderstood Sadie is about a girl from San Francisco diagnosed '
#          'with the indigo mindset having set to be admitted to an academy '
#          'filled with other indigo children . She at first is in ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjBkOWVmMzUtOTJlYy00ZTgwLWI4MDQtMWM4NmQ4MTMxZTNmXkEyXkFqcGdeQXVyNzE5Njg1OTk@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '25 Feb 2018',
#  'Response': 'True',
#  'Runtime': '66 min',
#  'Title': 'Misunderstood Sadie',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2018',
#  'imdbID': 'tt8058918',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6843694
# -------------------
# {'Actors': 'Darren W. Conrad, Davis Osborne, Kayleigh Stover, Tina Murphy',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tim Ross',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BY2E5MTMzN2YtODY5My00ZmM5LWIyZDctYWQ4MTI0NDAzZDEzXkEyXkFqcGdeQXVyMzYxOTk0MA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Oct 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Mockingbird',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Brad Hord',
#  'Year': '2018',
#  'imdbID': 'tt6843694',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2205762
# -------------------
# {'Actors': 'Monique Gabriela Curnen, Kathy Baker, Luke Ganalon, Jon Jon '
#            'Briones',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Patrick Cunningham',
#  'Genre': 'Drama, Horror, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "A single mother entertains a dangerous fantasy after she's recruited "
#          'to live in an unsold property in an empty development.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTcwNWFkZDMtOGZkMS00Y2RkLTkwNDItZDc2ODYzYzljOTAwXkEyXkFqcGdeQXVyNjU0NTI0Nw@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.9/10'}],
#  'Released': '25 Aug 2018',
#  'Response': 'True',
#  'Runtime': '82 min',
#  'Title': 'Model Home',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Patrick Cunningham, William Day Frank',
#  'Year': '2018',
#  'imdbID': 'tt2205762',
#  'imdbRating': '3.9',
#  'imdbVotes': '72'}
# -------------------
# movie id tt5773864
# -------------------
# {'Actors': "Ben Solenberger, Jake O'Flaherty, Nick Burr, Maya Bowman",
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Mojave Mile',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2016',
#  'imdbID': 'tt5773864',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8093660
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt4203788
# -------------------
# {'Actors': 'A. Michelle Harleston, Benjamin Lewis, Robert L. Parker III, '
#            'Everett Anderson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Robert L. Parker III',
#  'Genre': 'Action, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A horror film starring Michelle Harleston from Olympus Has Fallen',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYjViMTMwNDEtNzdkZC00MjRlLTllNDEtOTQxYTI1NTRiZTYxXkEyXkFqcGdeQXVyNTIwMjY1NjY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.0/10'}],
#  'Released': '03 Mar 2018',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': "Moma's Spirit",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Robert L. Parker III',
#  'Year': '2018',
#  'imdbID': 'tt4203788',
#  'imdbRating': '3.0',
#  'imdbVotes': '21'}
# -------------------
# movie id tt6470464
# -------------------
# {'Actors': 'Alan Rachins, Stephanie Pearson, James Babson, Tyler Steelman',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jeremy Vineyard',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Our hero discovers a device that everyone wants. When faced with '
#          'moral uncertainties he is forced to make choices that will affect '
#          'not only him, but the rest of the world.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Momentum',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jeremy Vineyard',
#  'Year': '2018',
#  'imdbID': 'tt6470464',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6138262
# -------------------
# {'Actors': 'Lester Greene, Eugene N. Walker, Andrée M Harris, Shauntay S. '
#            'Cherry',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Antoine Allen',
#  'Genre': 'Drama, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "A son's undying love for his mother will force him to make the "
#          'ultimate sacrifice.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZDlmMzA5ODktZjAzYS00MmUyLWIwYjEtNmE4ZTU5MzYyY2Y2XkEyXkFqcGdeQXVyMjY4NTM1MDk@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Mar 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
# ...
# -------------------
# movie id tt6170804
# -------------------
# {'Actors': 'Justin Chatwin, Peter Stormare, Mark Thompson, Robin Thomas',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Canada',
#  'DVD': '11 May 2018',
#  'Director': 'David A. Armstrong',
#  'Genre': 'Action, Crime, Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A rookie detective, son of a dead disgraced cop, works to solve his '
#          'first major case while under the watchful eye of a ghost-like '
#          'assassin.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYTZiYmUyNWUtYzQ1Yy00MDJjLTkyYzItNGJjYzQ4MzVlOGEwXkEyXkFqcGdeQXVyMjQ3ODAxNw@@._V1_SX300.jpg',
#  'Production': 'Gravitas Ventures',
#  'Rated': 'TV-MA',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.0/10'}],
#  'Released': '03 May 2019',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': "The Assassin's Code",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Edward Lee Cornett, Valerie Grant',
#  'Year': '2018',
#  'imdbID': 'tt6170804',
#  'imdbRating': '5.0',
#  'imdbVotes': '865'}
# -------------------
# movie id tt6423012
# -------------------
# {'Actors': 'Pennan Brae, Kiran Cash, Tim Cash, Brittany Dixon',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tim Cash',
#  'Genre': 'Drama, History',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Daniel was a recluse who shut out the world yet longed to touch the '
#          'moon. Sandy was a light whose warmth melted his heart and propelled '
#          'him to the stars.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOWVhZGFkZDUtNTVjMC00Nzk5LWFhNWItZjE3NjljNWFlZDQ4XkEyXkFqcGdeQXVyNjU3OTQwNTA@._V1_SX300.jpg',
#  'Production': 'Far From Earth Films',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.3/10'}],
#  'Released': '18 May 2018',
#  'Response': 'True',
#  'Runtime': '72 min',
#  'Title': 'The Astronot',
#  'Type': 'movie',
#  'Website': 'http://www.theastronot.com/',
#  'Writer': 'Pennan Brae',
#  'Year': '2018',
#  'imdbID': 'tt6423012',
#  'imdbRating': '5.3',
#  'imdbVotes': '9'}
# -------------------
# movie id tt6222288
# -------------------
# {'Actors': 'Dayana Bailey, Hilary Becker, Arthur Bloberger, Cody Bradley',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Darlene Dalmaceda, Alex Kersting',
#  'Genre': 'Short, Action, Adventure',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'After the doors of the legendary Riviera are closed for good, real '
#          'estate developer Paul Christopher has decided to open the '
#          'hotel/casino to the public to sell off what remaining items are ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '20 Jan 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Auction',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Alex Kersting',
#  'Year': '2018',
#  'imdbID': 'tt6222288',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6051096
# -------------------
# {'Actors': 'Hattie Smith, Zac Titus, Nicole Dambro, Michael Peter Harrison',
#  'Awards': '1 win.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Nicholas Woods',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "At the risk of her group's safety, a young woman travels into a "
#          'National Forest where her sister has become trapped in a '
#          'multi-dimensional world of monsters.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTk1YmU1ODgtZTdmMS00MWVkLTg0MmUtZDBjYzY4ZjI3YWQyXkEyXkFqcGdeQXVyMTQ3MDIwMDQ@._V1_SX300.jpg',
#  'Production': 'Axiom Movie Production Company',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'}],
#  'Released': '07 Dec 2018',
#  'Response': 'True',
#  'Runtime': '98 min',
#  'Title': 'The Axiom',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Nicholas Woods',
#  'Year': '2018',
#  'imdbID': 'tt6051096',
#  'imdbRating': '6.5',
#  'imdbVotes': '5,164'}
# -------------------
# movie id tt5433470
# -------------------
# {'Actors': 'Gabe Alba, Mark Mears, Tim Goodell, Alexandra Bibby',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tim Goodell',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A small group of destitute filmmakers sets out to make a '
#          'prize-winning short with the last of their savings.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '24 Jun 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The BTS Cam',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tim Goodell, Mark Mears',
#  'Year': '2016',
#  'imdbID': 'tt5433470',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8923800
# -------------------
# {'Actors': 'Shelly Martinez, Denise Poole, Galina Slavova, Psalms',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tremain Hayhoe',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Mr. Playboy Hugh Hefner has passed away. In shock over his hero's "
#          'passing, the most famous bachelor in the galaxy, The Showstopper '
#          'Shawn Valentino is considering leaving the playboy ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYzQzMTNiYWItNjg2NS00YzE2LWJkZDEtOTJmZmY0Yzc5NjI5XkEyXkFqcGdeQXVyMjA4NDcxMjQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Dec 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Bachelor Party',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Brian Fire',
#  'Year': '2018',
#  'imdbID': 'tt8923800',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3103254
# -------------------
# {'Actors': 'Justin Marshall Elias, Atlee Feingold, Ron Ramsey, Beau Dawson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Adam LeHouillier',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A failed romance between a meter maid and a fanny pack designer gets '
#          'a second chance when the single life in Los Angeles becomes too much '
#          'to bear alone. But can a relationship already proven to be a mistake '
#          'work the second time around?',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'R',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': 'The Backslide',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Adam LeHouillier',
#  'Year': '2015',
#  'imdbID': 'tt3103254',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7672852
# -------------------
# {'Actors': 'Sameera Aditham, Michael Brzezinski, Lincoln Carpenter, Dilruk De '
#            'Silva',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Austin Sheeley',
#  'Genre': 'Comedy, Fantasy, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Mike, a bored guardian angel, falls in love with Abby, an '
#          'enthusiastic young demon, and joins her side, leading to disastrous '
#          "consequences in his assigned human Sally's life. Now Mike and ...",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTMyNTZkOTktMGEyOS00ODBiLWJlNTktZTdiMTM1MjVhZGI0XkEyXkFqcGdeQXVyMjIxOTQ3MzA@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '20 May 2018',
#  'Response': 'True',
#  'Runtime': '78 min',
#  'Title': 'The Bad Angel',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Austin Sheeley',
#  'Year': '2018',
#  'imdbID': 'tt7672852',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2690634
# -------------------
# {'Actors': 'Glen Powell, Mekenna Melvin, Erik Stocklin, Paul Iacono',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Carlos Rincones',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'During a fleeting return trip to his childhood home, a budding '
#          'filmmaker is confronted by the now-grown ensemble of his old '
#          'hometown friends - none of whom are aware that he intends to make...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTExNTEzMzM3OTNeQTJeQWpwZ15BbWU4MDY2OTI1OTYx._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'}],
#  'Released': '16 Feb 2018',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'The Bad Guys',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Rock Shaink Jr., Alena Smith, Carlos Rincones',
#  'Year': '2018',
#  'imdbID': 'tt2690634',
#  'imdbRating': '6.5',
#  'imdbVotes': '837'}
# -------------------
# movie id tt5372620
# -------------------
# {'Actors': 'Ellie Church, Arthur Cullipher, Jason Crowe, Jason Crowe',
#  'Awards': '1 win & 2 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Scott Schirmer',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Mary and PJ are kidnapped and tortured by a sadistic clown bent on '
#          "transforming them into a 'doll' and a 'dog' -- servile sex slaves "
#          'that will be sold to the highest bidders. When PJ goes ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjczMmM1NDMtMGVhZS00OTlhLWI4ZDgtNTRjMzljZjNjN2FmXkEyXkFqcGdeQXVyMjk0NTY5NjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.6/10'}],
#  'Released': '19 Oct 2018',
#  'Response': 'True',
#  'Runtime': '106 min',
#  'Title': 'The Bad Man',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Scott Schirmer',
#  'Year': '2018',
#  'imdbID': 'tt5372620',
#  'imdbRating': '3.6',
#  'imdbVotes': '191'}
# -------------------
# movie id tt6412452
# -------------------
# {'Actors': 'Tim Blake Nelson, Willie Watson, Clancy Brown, Danny McCarthy',
#  'Awards': 'Nominated for 3 Oscars. Another 8 wins & 35 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '16 Nov 2018',
#  'Director': 'Ethan Coen, Joel Coen',
#  'Genre': 'Comedy, Drama, Musical, Mystery, Romance, Western',
#  'Language': 'English',
#  'Metascore': '79',
#  'Plot': 'Six tales of life and violence in the Old West, following a singing '
#          'gunslinger, a bank robber, a traveling impresario, an elderly '
#          'prospector, a wagon train, and a perverse pair of bounty hunters.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYjRkYTI3M2EtZWQ4Ny00OTA2LWFmMTMtY2E4MTEyZmNjOTMxXkEyXkFqcGdeQXVyNDg4NjY5OTQ@._V1_SX300.jpg',
#  'Production': 'Netflix',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.3/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '91%'},
#              {'Source': 'Metacritic', 'Value': '79/100'}],
#  'Released': '09 Nov 2018',
#  'Response': 'True',
#  'Runtime': '133 min',
#  'Title': 'The Ballad of Buster Scruggs',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joel Coen, Ethan Coen, Jack London (based on a story by), Stewart '
#            'Edward White (inspired by a story by)',
#  'Year': '2018',
#  'imdbID': 'tt6412452',
#  'imdbRating': '7.3',
#  'imdbVotes': '99,976'}
# -------------------
# movie id tt9489714
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt6539470
# -------------------
# {'Actors': 'Guillaume Faure, Ken Samuels, Auregan, Piper Lincoln',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, France',
#  'DVD': '04 Sep 2018',
#  'Director': 'Matt Beurois',
#  'Genre': 'Crime, Horror, Mystery',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A serial killer strikes Sugar Grove, Virginia. A rising journalist '
#          'comes to town to cover the story : her investigation will soon lead '
#          "her to the town's darkest secret, at her own risks.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODM3NzQ0NGYtYTE2ZS00MDVlLWE1OTMtNzE5NGRjMTlhOThiXkEyXkFqcGdeQXVyNDkwNTA3Njg@._V1_SX300.jpg',
#  'Production': 'Yucca Prime',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.5/10'}],
#  'Released': '04 Sep 2018',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'The Barn',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Auregan, Matt Beurois',
#  'Year': '2018',
#  'imdbID': 'tt6539470',
#  'imdbRating': '4.5',
#  'imdbVotes': '96'}
# -------------------
# movie id tt7723902
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt6118340
# -------------------
# {'Actors': 'Jackson Davis, Cayleb Long, Mischa Barton, Bailey Anne Borders',
#  'Awards': '1 win & 1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Brian M. Conley, Nathan Ives',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': '27',
#  'Plot': 'A seemingly innocent man is abducted by a notorious L.A. serial '
#          'killer, who forces his victims to role-play with him so that he can '
#          'enact his capture, torture and murder fantasies.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTEwNTUwMDItYTI0MC00MDFlLWJlZmQtOTk0ODA1NTMxNWQ1XkEyXkFqcGdeQXVyMTMyMjI0MjQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'TV-MA',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.2/10'},
#              {'Source': 'Metacritic', 'Value': '27/100'}],
#  'Released': '14 Sep 2018',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'The Basement',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Nathan Ives, Brian M. Conley, Sean Decker (additional scenes by)',
#  'Year': '2018',
#  'imdbID': 'tt6118340',
#  'imdbRating': '5.2',
#  'imdbVotes': '3,367'}
# -------------------
# movie id tt7554372
# -------------------
# {'Actors': 'Alexander G. Eckert, Sabrina Morris, John Rogers, Eric Gable',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'John Rogers',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Kelli reluctantly gives her husband Rhett a second chance after an '
#          'adulterous affair. In search of a fresh start, the couple and their '
#          'two children move to a fixer-upper in a new town. But,...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '14 Feb 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Basement Man',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Eric Gable, John Rogers',
#  'Year': '2018',
#  'imdbID': 'tt7554372',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7953652
# -------------------
# {'Actors': 'Carlos Manuel Aguilar, Ileana Ruberté, James Adams, Carlos Garcia',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Carlos Manuel Aguilar',
#  'Genre': 'Comedy, Crime, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Judas Levi, a famous film director, who has recently busted out of '
#          'the closet and traumatized by financial ruin, takes scalpel to '
#          'Hollywood sleaze filming a group of homeless people on the ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '105 min',
#  'Title': 'The Bastard Son of Hollywood',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Carlos Manuel Aguilar',
#  'Year': '2018',
#  'imdbID': 'tt7953652',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4352538
# -------------------
# {'Actors': 'Joe Hammerstone, Kyle Lee, Mary Louise Edwards, Natasha Laws Mick',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tim Becker',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Beast of Calvary Creek',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Aaron Majewski (screenplay)',
#  'Year': '2016',
#  'imdbID': 'tt4352538',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}

# %%
len(title_list)
# Out:
# 860

# %%
len(title_id)
# Out:
# 860

# %%
# if title_list and title_id are the same length run the cell below. 
# if they are not equal take out 'title_id': title_id

# %%
df = pd.DataFrame({'title_id': title_id, 'title': title_list, 'box_office': box_office_list, 'country': country_list, 
                   'genre': genre_list, 'director': director_list, 'metascore': metascore_list, 'production': production_list, 
                   'rating': rating_list, 'IMDB_rating': IMDB_rating_list, 'rotten_tomatoes_rating': rotten_tomatoes_rating_list, 
                  'runtime': runtime_list, 'type': type_list, 'IMDB_votes': imdb_votes_list})

# %%
df = df.drop_duplicates()
df.head()
# Out:
#     title_id                title box_office country          genre  \
# 0  tt6856718   Meant to Be Broken        N/A     USA         Action
# 1  tt2670882     Measure of a Man        N/A     USA  Comedy, Drama
# 2  tt7664772  Meathook Massacre 4        N/A     USA         Horror
# 3  tt5607324           Medic ZerØ        N/A     USA          Drama
# 4  tt8329540    Meeting the Folks        N/A     USA            N/A
#
#         director metascore         production rating IMDB_rating  \
# 0  Jonathan Zuck       N/A                N/A    N/A         N/A
# 1      Jim Loach        53  Great Point Media  PG-13         6.3
# 2      John Ward       N/A                N/A    N/A         N/A
# 3     Matt Oyler       N/A                N/A    N/A         N/A
# 4        Fred T.       N/A                N/A    N/A         6.6
#
#   rotten_tomatoes_rating  runtime   type IMDB_votes
# 0                     NA      N/A  movie        N/A
# 1                    52%  100 min  movie        859
# 2                     NA      N/A  movie        N/A
# 3                     NA      N/A  movie        N/A
# 4                     NA   80 min  movie          7

# %%
df.count()
# Out:
# title_id                  860
# title                     860
# box_office                860
# country                   860
# genre                     860
# director                  860
# metascore                 860
# production                860
# rating                    860
# IMDB_rating               860
# rotten_tomatoes_rating    860
# runtime                   860
# type                      860
# IMDB_votes                860
# dtype: int64

# %%
df.to_csv('../data/2018_data_batch_3.csv', index=False)
