# %%
import pandas as pd

# %%
batch_1 = pd.read_csv('../data/2018_data_batch_1.csv')
batch_2 = pd.read_csv('../data/2018_data_batch_2.csv')
batch_3 = pd.read_csv('../data/2018_data_batch_3.csv')
batch_4 = pd.read_csv('../data/2018_data_batch_4.csv')

# %%
len(batch_1)
# Out:
# 864

# %%
len(batch_2)
# Out:
# 844

# %%
len(batch_3)
# Out:
# 860

# %%
len(batch_4)
# Out:
# 752

# %%
df = pd.DataFrame()

# %%
df = pd.concat([batch_1, batch_2, batch_3, batch_4], ignore_index=True)

# %%
len(df)
# Out:
# 3320

# %%
df.head(100)
# Out:
#      title_id                                  title box_office  \
# 0   tt6540984                            #SquadGoals        NaN
# 1   tt3743246                              #Victoria        NaN
# 2   tt6871174                            #truehomies        NaN
# 3   tt6877520                            #wanderlust        NaN
# 4   tt9025208                      1 Angry Black Man        NaN
# 5   tt7856404    1 Dead man, 6 Suspects, $65 Million        NaN
# 6   tt3445702                                    1/1        NaN
# 7   tt7374492                                  10-56        NaN
# 8   tt8364714                              11 Henrys        NaN
# 9   tt7549092                      111: The Sunriser        NaN
# 10  tt1413492                              12 Strong        NaN
# 11  tt7476438                             14 Cameras        NaN
# 12  tt6411590                                   1985        NaN
# 13  tt7153134                               1st Born        NaN
# ...

# %%
df = df[df.box_office.notnull()]

# %%
len(df)
# Out:
# 27

# %%
df.to_csv('../data/compiled_2018_data.csv', index=False)
