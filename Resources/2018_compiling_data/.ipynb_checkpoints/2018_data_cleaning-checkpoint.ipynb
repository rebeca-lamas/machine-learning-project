# %%
import pandas as pd

# %%
batch_1 = pd.read_csv('../data/2018_data_batch_1.csv')
batch_2 = pd.read_csv('../data/2018_data_batch_2.csv')
batch_3 = pd.read_csv('../data/2018_data_batch_3.csv')
batch_4 = pd.read_csv('../data/2018_data_batch_4.csv')

# %%
len(batch_1)
# Out:
# 864

# %%
len(batch_2)
# Out:
# 844

# %%
len(batch_3)
# Out:
# 860

# %%
len(batch_4)
# Out:
# 752

# %%
df = pd.DataFrame()

# %%
df = pd.concat([batch_1, batch_2, batch_3, batch_4], ignore_index=True)

# %%
len(df)
# Out:
# 3320

# %%
df.head(100)
# Out:
#      title_id                   title box_office      country  \
# 0   tt6540984             #SquadGoals        NaN          USA
# 1   tt3743246               #Victoria        NaN          USA
# 2   tt6871174             #truehomies        NaN          USA
# 3   tt6877520             #wanderlust        NaN          USA
# 4   tt9025208       1 Angry Black Man        NaN          USA
# ..        ...                     ...        ...          ...
# 95  tt7040874          A Simple Favor        NaN  Canada, USA
# 96  tt6328242        A Simple Wedding        NaN          USA
# 97  tt9274824  A Snow White Christmas        NaN          USA
# 98  tt7039326        The Wolf Catcher        NaN          USA
# 99  tt1517451          A Star Is Born        NaN          USA
#
#                                       genre             director  metascore  \
# 0                           Drama, Thriller       Danny J. Boyle        NaN
# 1                                     Drama   Mark K. Buddington        NaN
# 2                                       NaN          Tino Duvick        NaN
# 3                  Adventure, Comedy, Drama  Maggie VandenBerghe        NaN
# 4                                       NaN      Menelek Lumumba        NaN
# ..                                      ...                  ...        ...
# 95  Comedy, Crime, Drama, Mystery, Thriller            Paul Feig       67.0
# 96                          Comedy, Romance         Sara Zandieh        NaN
# 97           Comedy, Drama, Family, Romance  Kristin Fairweather        NaN
# 98                                   Action           Juan Salas        NaN
# 99                    Drama, Music, Romance       Bradley Cooper       88.0
#
#                production   rating  IMDB_rating rotten_tomatoes_rating  \
# 0                     NaN  Unrated          4.0                    NaN
# 1                     NaN      NaN          NaN                    NaN
# 2                     NaN      NaN          NaN                    NaN
# 3                     NaN      NaN          NaN                    NaN
# 4                     NaN        R          7.9                    NaN
# ..                    ...      ...          ...                    ...
# 95              Lionsgate        R          6.8                    85%
# 96                    NaN      NaN          5.5                    NaN
# 97                    NaN      NaN          5.1                    NaN
# 98                    NaN      NaN          3.4                    NaN
# 99  Warner Bros. Pictures        R          7.7                    90%
#
#     runtime   type IMDB_votes
# 0    90 min  movie        346
# 1       NaN  movie        NaN
# 2       NaN  movie        NaN
# 3    76 min  movie        NaN
# 4    92 min  movie          9
# ..      ...    ...        ...
# 95  117 min  movie    102,679
# 96   88 min  movie         50
# 97   90 min  movie        297
# 98   80 min  movie         35
# 99  136 min  movie    286,900
#
# [100 rows x 14 columns]

# %%
df = df[df.box_office.notnull()]

# %%
len(df)
# Out:
# 27

# %%
df.to_csv('../data/cleaned_2018_data.csv', index=False)
