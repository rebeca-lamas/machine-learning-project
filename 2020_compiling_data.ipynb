# %%
import pandas as pd
import requests
import json
import time
from pprint import pprint
from config import API_KEY

# %%
data = pd.read_csv('Resources/movies_titles_2020.csv')
df =  data.groupby('2020_movies').nunique().count()
df
# Out:
# 2020_movies    44
# dtype: int64

# %%
box_office_list = []
country_list = []
genre_list = []
director_list = []
metascore_list = []
production_list = []
rating_list = []
IMDB_rating_list = [] 
rotten_tomatoes_rating_list = []
runtime_list = []
title_list = []
type_list = []
imdb_votes_list = []

# %%
movies = data['2020_movies']
total_movies = len(movies)

# %%
for i in range(total_movies):
    movie = movies[i]
    url = "http://www.omdbapi.com/?i=" + movie + "&apikey=" + API_KEY
    response = (requests.get(url).text)
    response_json = json.loads(response)
    
    pprint(response_json)
    
    box_office_list.append(response_json['BoxOffice'])
    country_list.append(response_json['Country'])
    genre_list.append(response_json['Genre'])
    director_list.append(response_json['Director'])
    metascore_list.append(response_json['Metascore'])
    production_list.append(response_json['Production'])
    rating_list.append(response_json['Rated'])
    IMDB_rating_list.append(response_json['imdbRating'])
    try:
        if not response_json['Ratings']:
            rotten_tomatoes_rating_list.append('NA')
        elif response_json['Ratings'][0]['Source'] == 'Rotten Tomatoes':
            rotten_tomatoes_rating_list.append(response_json['Ratings'][0]['Value'])
        elif response_json['Ratings'][1]['Source'] == 'Rotten Tomatoes':
            rotten_tomatoes_rating_list.append(response_json['Ratings'][1]['Value'])
        else:
            rotten_tomatoes_rating_list.append('NA')
    except IndexError:
        rotten_tomatoes_rating_list.append('NA')
    runtime_list.append(response_json['Runtime'])
    title_list.append(response_json['Title'])
    type_list.append(response_json['Type'])
    imdb_votes_list.append(response_json['imdbVotes'])
# Out:
# {'Actors': 'Pedro Pascal, Gal Gadot, Connie Nielsen, Chris Pine',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Patty Jenkins',
#  'Genre': 'Action, Adventure, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Plot unknown. A sequel to the 2017 superhero film 'Wonder Woman.'",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYzAyOGJkMzUtMmRjYS00NGJmLWExNGEtYzI2YjVmMmQzMzFiXkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_SX300.jpg',
#  'Production': 'Warner Bros. Pictures',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '05 Jun 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Wonder Woman 1984',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Geoff Johns (story), Patty Jenkins (story), Dave Callaham '
#            '(screenplay), Geoff Johns (screenplay), Patty Jenkins '
#            '(screenplay), William Moulton Marston (Wonder Woman created by)',
#  'Year': '2020',
#  'imdbID': 'tt7126948',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Millie Bobby Brown, Alexander Skarsgård, Eiza González, Jessica '
#            'Henwick',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Adam Wingard',
#  'Genre': 'Action, Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'As the gigantic Kong meets the unstoppable Godzilla, the world '
#          'watches to see which one of them will become King of the Monsters.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOWI5MWVkMGUtYTVkYS00NGVlLTgwYWItYjkzMjJkNzZhZmE3XkEyXkFqcGdeQXVyOTExNDEzNDY@._V1_SX300.jpg',
#  'Production': 'Warner Bros. Pictures',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '20 Nov 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Godzilla vs. Kong',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Eric Pearson (screenplay), Max Borenstein (screenplay), Terry '
#            'Rossio (story), Michael Dougherty (story), Zach Shields (story)',
#  'Year': '2020',
#  'imdbID': 'tt5034838',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Adria Arjona, Jared Leto, Matt Smith, J.K. Simmons',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Daniel Espinosa',
#  'Genre': 'Action, Adventure, Drama, Horror, Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Biochemist Michael Morbius tries to cure himself of a rare blood '
#          'disease, but he inadvertently infects himself with a form of '
#          'vampirism instead.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMWUyMWM5YjctNzgxNy00NDEwLTkwMGItYWE3ZmFiNTY1MDA2XkEyXkFqcGdeQXVyNTU3Njk4NTU@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '31 Jul 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Morbius',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Gil Kane (comic book & character), Matt Sazama (screenplay), Burk '
#            'Sharpless (screenplay), Roy Thomas (comic book & character)',
#  'Year': '2020',
#  'imdbID': 'tt5108870',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Awkwafina, Cassie Steele',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Paul Briggs, Dean Wellins',
#  'Genre': 'Animation, Adventure, Comedy, Family, Fantasy, Musical',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'In a realm known as Lumandra, a re-imagined Earth inhabited by an '
#          'ancient civilization, a warrior named Raya is determined to find the '
#          'last dragon.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOWQwYmM4ZjktODlkMi00ZTAyLWI5NWYtOTU4ODI5MjBlOWM2XkEyXkFqcGdeQXVyODQ0MjEzMTA@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '25 Nov 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Raya and the Last Dragon',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Adele Lim',
#  'Year': '2020',
#  'imdbID': 'tt5109280',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Steve Carell, Pierre Coffin',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kyle Balda, Brad Ableson(co-director)',
#  'Genre': 'Animation, Adventure, Comedy, Family',
#  'Language': 'English, Vietnamese',
#  'Metascore': 'N/A',
#  'Plot': 'The continuation of the adventures of the Minions, always in search '
#          'of a tyrannical leader.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDFjMDNjODEtZjBhYy00YjU3LTlmM2YtZmU5NjY4NWQ2ZDIwXkEyXkFqcGdeQXVyMzY3MDEzMTA@._V1_SX300.jpg',
#  'Production': 'Illumination Entertainment',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '03 Jul 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Minions: The Rise of Gru',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Cinco Paul (characters)',
#  'Year': '2020',
#  'imdbID': 'tt5113044',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Anna Kendrick, Sam Rockwell, Jamie Dornan, James Corden',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Walt Dohrn, David P. Smith(co-director)',
#  'Genre': 'Animation, Adventure, Comedy, Family, Fantasy, Musical',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Sequel to the 2016 animated hit.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjIwNjg1NmUtMGE5Yi00YmQxLTg0M2QtMGQyNDVlZWUwOGUwXkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'PG',
#  'Ratings': [],
#  'Released': '17 Apr 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Trolls World Tour',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jonathan Aibel, Glenn Berger',
#  'Year': '2020',
#  'imdbID': 'tt6587640',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Tom Hardy, Woody Harrelson, Michelle Williams, Naomie Harris',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Andy Serkis',
#  'Genre': 'Action, Comedy, Horror, Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Plot unknown. Sequel to the 2018 film 'Venom'.",
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '02 Oct 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Venom 2',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kelly Marcel',
#  'Year': '2020',
#  'imdbID': 'tt7097896',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Charlize Theron, Helen Mirren, Finn Cole, Vin Diesel',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Justin Lin',
#  'Genre': 'Action, Adventure, Crime, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Plot unknown. The ninth installment of the 'Fast and Furious' "
#          'franchise.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZjZhYTkyMjgtNjFkZi00NDAyLTk5ZDgtMDYwZTBkYTI1ODllXkEyXkFqcGdeQXVyNTc5OTMwOTQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '22 May 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Fast & Furious 9',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Daniel Casey (screenplay), Chris Morgan, Gary Scott Thompson '
#            '(characters)',
#  'Year': '2020',
#  'imdbID': 'tt5433138',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Nicolas Cage, Ryan Reynolds, Emma Stone, Peter Dinklage',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Joel Crawford',
#  'Genre': 'Animation, Adventure, Comedy, Family, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The prehistoric family the Croods are challenged by a rival family '
#          'the Bettermans, who claim to be better and more evolved.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTc1M2YxNjUtYzc3ZS00Mjc2LThlMzEtOTVjYmEyNDE4YWQwXkEyXkFqcGdeQXVyNzgzMjAzNzc@._V1_SX300.jpg',
#  'Production': '20th Century Fox',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '23 Dec 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Croods 2',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kirk DeMicco (creator), Dan Hageman (screenplay), Kevin Hageman '
#            '(screenplay), Chris Sanders (creator)',
#  'Year': '2020',
#  'imdbID': 'tt2850386',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'D.J. Caruso',
#  'Genre': 'Action, Adventure, Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The GI Joe force is reinstated for a confrontation when the Cobra '
#          'terrorists acquire a deadly new weapon.',
#  'Poster': 'N/A',
#  'Production': 'Paramount Pictures',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '27 Mar 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'G.I. Joe: Ever Vigilant',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Josh Appelbaum, Aaron Berg (screenplay), André Nemec',
#  'Year': '2020',
#  'imdbID': 'tt2813796',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Clancy Brown, Awkwafina, Keanu Reeves, Tom Kenny',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'South Korea, USA',
#  'DVD': 'N/A',
#  'Director': 'Tim Hill',
#  'Genre': 'Animation, Adventure, Comedy, Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "After SpongeBob's beloved pet snail Gary is snail-napped, he and "
#          'Patrick embark on an epic adventure to The Lost City of Atlantic '
#          'City to bring Gary home.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzI5MGM2OTQtYTQ5MC00MTQyLWE5NDUtNWFlYzUwYjU1NjcxXkEyXkFqcGdeQXVyMTAxNTcyMTc1._V1_SX300.jpg',
#  'Production': 'Paramount Pictures',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '22 May 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The SpongeBob Movie: Sponge on the Run',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jonathan Aibel (screenplay), Glenn Berger (screenplay), Jordan '
#            'Dunn, Tim Hill, Stephen Hillenburg (character created by), Michael '
#            'Kvamme (screenplay), Kyle McCulloch (story), Paul Tibbitt (story)',
#  'Year': '2020',
#  'imdbID': 'tt4823776',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Yifei Liu, Donnie Yen, Jet Li, Li Gong',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Niki Caro',
#  'Genre': 'Action, Adventure, Drama, Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A young Chinese maiden disguises herself as a male warrior in order '
#          "to save her father. A live-action feature film based on Disney's "
#          "'Mulan.'",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjFlZjZkMTYtODM2Zi00OTM4LWIwYTktOTFjMmQzZDEzZDc4XkEyXkFqcGdeQXVyNDg4NjY5OTQ@._V1_SX300.jpg',
#  'Production': 'Walt Disney Pictures',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '27 Mar 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Mulan',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Rick Jaffa (screenplay by), Amanda Silver (screenplay by), '
#            'Elizabeth Martin (screenplay by), Lauren Hynek (screenplay by)',
#  'Year': '2020',
#  'imdbID': 'tt4566758',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Vanessa Hudgens, Will Smith, Jennifer Badger, Alexander Ludwig',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Adil El Arbi, Bilall Fallah',
#  'Genre': 'Action, Comedy, Crime, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Marcus Burnett is now a police inspector and Mike Lowery is in a '
#          'midlife crisis. They unite again when an Albanian mercenary, whose '
#          'brother they killed, promises them an important bonus.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZjI1ZWYyMTYtZGYyNS00ODdhLWFmNGMtODZiYzgxOGNmNjZjXkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_SX300.jpg',
#  'Production': 'Sony Pictures',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '17 Jan 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Bad Boys for Life',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joe Carnahan, Chris Bremner, George Gallo (characters)',
#  'Year': '2020',
#  'imdbID': 'tt1502397',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Cillian Murphy, Emily Blunt, Noah Jupe, Djimon Hounsou',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'John Krasinski',
#  'Genre': 'Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Plot unknown. Sequel to the 2018 film, 'A Quiet Place'.",
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '20 Mar 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'A Quiet Place 2',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Scott Beck (characters), John Krasinski, Bryan Woods (characters)',
#  'Year': '2020',
#  'imdbID': 'tt8332922',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Margot Robbie, Daisy Ridley, Elizabeth Debicki, Rose Byrne',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'Australia, USA',
#  'DVD': 'N/A',
#  'Director': 'Will Gluck',
#  'Genre': 'Animation, Adventure, Comedy, Family, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Plot unknown. Follow-up to the 2018 film, 'Peter Rabbit'.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTQwOThjZTEtNDNhZS00YmYzLWFkNWMtNWRjN2RmOWI5ZmU1XkEyXkFqcGdeQXVyODk4OTc3MTY@._V1_SX300.jpg',
#  'Production': 'Sony Pictures',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '03 Apr 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Peter Rabbit 2: The Runaway',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Beatrix Potter (based on the characters and tales of "Peter '
#            'Rabbit" by), Will Gluck (screenplay), Patrick Burleigh (screenplay '
#            'by)',
#  'Year': '2020',
#  'imdbID': 'tt8376234',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Ryan Reynolds, Dwayne Johnson, Gal Gadot',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Rawson Marshall Thurber',
#  'Genre': 'Action, Adventure, Comedy, Crime, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "An Interpol agent tracks the world's most wanted art thief.",
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '13 Nov 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Red Notice',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Rawson Marshall Thurber',
#  'Year': '2020',
#  'imdbID': 'tt7991608',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Jennifer Connelly, Tom Cruise, Monica Barbaro, Val Kilmer',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Hong Kong',
#  'DVD': 'N/A',
#  'Director': 'Joseph Kosinski',
#  'Genre': 'Action, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "After more than thirty years of service as one of the Navy's top "
#          'aviators, Pete Mitchell is where he belongs, pushing the envelope as '
#          'a courageous test pilot and dodging the advancement in rank that '
#          'would ground him.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTEyYTA5YWYtYmIxYS00NWRlLWExNjMtNjliZmVlZDgxNTBlXkEyXkFqcGdeQXVyODk4OTc3MTY@._V1_SX300.jpg',
#  'Production': 'Paramount Pictures',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '26 Jun 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Top Gun: Maverick',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jim Cash (characters), Peter Craig, Jack Epps Jr. (characters), '
#            'Ehren Kruger, Justin Marks, Christopher McQuarrie, Eric Warren '
#            'Singer',
#  'Year': '2020',
#  'imdbID': 'tt1745960',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Margot Robbie',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'United Arab Emirates, USA',
#  'DVD': 'N/A',
#  'Director': 'Greta Gerwig',
#  'Genre': 'Adventure, Comedy, Drama, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "A doll living in 'Barbieland' is expelled for not being perfect "
#          'enough and sets off on an adventure in the real world. A Live-action '
#          'feature film based on the popular line of Barbie toys.',
#  'Poster': 'N/A',
#  'Production': 'Sony Pictures',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '08 May 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Barbie',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Noah Baumbach (screenplay), Noah Baumbach, Greta Gerwig '
#            '(screenplay), Greta Gerwig, Olivia Milch (earlier screenplay)',
#  'Year': '2020',
#  'imdbID': 'tt1517268',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Margot Robbie, Ewan McGregor, Mary Elizabeth Winstead, Jenelle '
#            'McKee',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Cathy Yan',
#  'Genre': 'Action, Adventure, Crime',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'After splitting with the Joker, Harley Quinn joins superheroes Black '
#          'Canary, Huntress and Renee Montoya to save a young girl from an evil '
#          'crime lord.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZjJmYmFmZGQtYWYzYS00N2UzLTkzYjktYmNkYzQ0MTJlN2M4XkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_SX300.jpg',
#  'Production': 'Warner Bros. Pictures',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '07 Feb 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Birds of Prey: And the Fantabulous Emancipation of One Harley Quinn',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Christina Hodson',
#  'Year': '2020',
#  'imdbID': 'tt7713068',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Ana de Armas, Daniel Craig, Léa Seydoux, Rami Malek',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'UK, USA',
#  'DVD': 'N/A',
#  'Director': 'Cary Joji Fukunaga',
#  'Genre': 'Action, Adventure, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Bond has left active service. His peace is short-lived when his old '
#          'friend Felix Leiter from the CIA turns up asking for help, leading '
#          'Bond onto the trail of a mysterious villain armed with dangerous new '
#          'technology.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZWI1ZmJkMTItMzYyOC00YjRlLTkxNjktMjhiOGQzNDgxYmI2XkEyXkFqcGdeQXVyODk2NDQ3MTA@._V1_SX300.jpg',
#  'Production': 'MGM',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '08 Apr 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'No Time to Die',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Neal Purvis, Robert Wade, Scott Z. Burns, Cary Joji Fukunaga, '
#            'Phoebe Waller-Bridge, Ian Fleming (based on characters created by)',
#  'Year': '2020',
#  'imdbID': 'tt2382320',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Jesse Plemons, Dwayne Johnson, Emily Blunt, Edgar Ramírez',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jaume Collet-Serra',
#  'Genre': 'Adventure, Family, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Based on Disneyland's theme park ride where a small riverboat takes "
#          'a group of travelers through a jungle filled with dangerous animals '
#          'and reptiles, but with a supernatural element.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BY2QxNmVjZTAtOTg3Zi00ZTMxLWJiODAtZDQ3OGEwOGI4MGY3XkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_SX300.jpg',
#  'Production': 'Walt Disney Pictures',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '24 Jul 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Jungle Cruise',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Glenn Ficarra (screenplay), Michael Green, John Requa (screenplay)',
#  'Year': '2020',
#  'imdbID': 'tt0870154',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Kumail Nanjiani, Robert Downey Jr., Tom Holland, Emma Thompson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Stephen Gaghan',
#  'Genre': 'Adventure, Comedy, Family, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A physician discovers that he can talk to animals.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMDNkODA5ZGQtODczOS00OTQxLThhMTItMjk0ZmNhMDM0YjNmXkEyXkFqcGdeQXVyMDM2NDM2MQ@@._V1_SX300.jpg',
#  'Production': 'Universal Pictures',
#  'Rated': 'PG',
#  'Ratings': [],
#  'Released': '17 Jan 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Dolittle',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Stephen Gaghan (screenplay), Hugh Lofting (character created by), '
#            'Thomas Shepherd (screen story)',
#  'Year': '2020',
#  'imdbID': 'tt6673612',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Carrie Coon, Mckenna Grace, Paul Rudd, Bill Murray',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jason Reitman',
#  'Genre': 'Action, Comedy, Drama, Fantasy, Horror, Sci-Fi',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'When a single mom and her two kids arrive in a small town, they '
#          'begin to discover their connection to the original Ghostbusters and '
#          'the secret legacy their grandfather left behind.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMGZmOGJjYjYtMWFkZi00NTE2LTk5NjktOGZiNDM2ZjBiMjk5XkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '10 Jul 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Ghostbusters: Afterlife',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dan Aykroyd (based on characters created by), Gil Kenan, Harold '
#            'Ramis (based on characters created by), Jason Reitman',
#  'Year': '2020',
#  'imdbID': 'tt4513678',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Tom Holland, Chris Pratt, Julia Louis-Dreyfus, Octavia Spencer',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Dan Scanlon',
#  'Genre': 'Animation, Adventure, Comedy, Family, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Set in a suburban fantasy world, two teenage elf brothers embark on '
#          'a quest to discover if there is still magic out there.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODQ0NjM2MjQtNjkyMS00ZDNjLThlMWQtMGVlZTAxZmRlNjhkXkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_SX300.jpg',
#  'Production': 'Disney/Pixar',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '06 Mar 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Onward',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dan Scanlon',
#  'Year': '2020',
#  'imdbID': 'tt7146812',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Daisy Ridley, Tom Holland, Mads Mikkelsen, Ray McKinnon',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Doug Liman',
#  'Genre': 'Adventure, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A dystopian world where there are no women and all living creatures '
#          "can hear each others' thoughts in a stream of images, words, and "
#          'sounds called Noise.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTY5ODQ0NDc0N15BMl5BanBnXkFtZTgwNTE4NzQ3MzI@._V1_SX300.jpg',
#  'Production': 'Lionsgate',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Mar 2019',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Chaos Walking',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Charlie Kaufman (screenplay by), Lindsey Beer (screenplay by), '
#            'John Lee Hancock (screenplay by), Gary Spinelli (screenplay by), '
#            'Patrick Ness (screenplay by), Patrick Ness (based on the novel '
#            'by), Andrew Gottlieb, David Rosen',
#  'Year': '2020',
#  'imdbID': 'tt2076822',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Rebecca Ferguson, Timothée Chalamet, Zendaya, Jason Momoa',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Hungary, Canada',
#  'DVD': 'N/A',
#  'Director': 'Denis Villeneuve',
#  'Genre': 'Adventure, Drama, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Feature adaptation of Frank Herbert's science fiction novel, about "
#          'the son of a noble family entrusted with the protection of the most '
#          'valuable asset and most vital element in the galaxy.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZTBmMmVhYmMtNmI4MC00MGIzLWJhNmEtZDAyZjFiNjU5NzYzXkEyXkFqcGdeQXVyNTQ5OTI3MzM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '18 Dec 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Dune',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Frank Herbert (novel), Eric Roth (screenplay), Denis Villeneuve '
#            '(screenplay), Jon Spaihts (screenplay)',
#  'Year': '2020',
#  'imdbID': 'tt1160419',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Indya Moore, Taylor Russell, Isabelle Fuhrman, Holland Roden',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'N/A',
#  'DVD': 'N/A',
#  'Director': 'Adam Robitel',
#  'Genre': 'Horror, Mystery, Thriller',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'Plot Unknown.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '14 Aug 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Escape Room 2',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Fritz Böhm, Will Honley, Christine Lavaf, Maria Melnik, Bragi F. '
#            'Schut, Daniel Tuch',
#  'Year': '2020',
#  'imdbID': 'tt9844522',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Ryan Reynolds, Samuel L. Jackson, Morgan Freeman, Salma Hayek',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, UK',
#  'DVD': 'N/A',
#  'Director': 'Patrick Hughes',
#  'Genre': 'Action, Comedy, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Sequel to the 2017 action/comedy.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': "The Hitman's Wife's Bodyguard",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': "Tom O'Connor",
#  'Year': '2020',
#  'imdbID': 'tt8385148',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'UK, France, USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'Animation, Comedy, Family, Fantasy',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'Plot undisclosed. The third installment of the Paddington films.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '16 Jan 2021',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Paddington 3',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Bond (characters), Mark Burton (screenplay), Simon Farnaby '
#            '(screenplay), Paul King (story)',
#  'Year': '2020',
#  'imdbID': 'tt5822536',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Patrick Wilson, Vera Farmiga, Charlene Amoia, Sterling Jerins',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Michael Chaves',
#  'Genre': 'Horror, Mystery, Thriller',
#  'Language': 'English, Portuguese',
#  'Metascore': 'N/A',
#  'Plot': 'Plot unknown. Third installment of the Conjuring franchise.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNWEyODg1NzktMGZkNS00MjZlLTlmOTAtZTIzNzdhZmIwNzE5XkEyXkFqcGdeQXVyNjIzNzM4NzA@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '11 Sep 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Conjuring 3',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'David Leslie Johnson-McGoldrick (screenplay)',
#  'Year': '2020',
#  'imdbID': 'tt7069210',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Matthew Goode, Charles Dance, Gemma Arterton, Aaron Taylor-Johnson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'UK, USA',
#  'DVD': 'N/A',
#  'Director': 'Matthew Vaughn',
#  'Genre': 'Action, Adventure, Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "As a collection of history's worst tyrants and criminal masterminds "
#          'gather to plot a war to wipe out millions, one man must race against '
#          'time to stop them.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYTQwNTgxOWUtMjRhYy00N2IyLWJlNzEtOWZkNGY2NWNjYjc2XkEyXkFqcGdeQXVyMDM2NDM2MQ@@._V1_SX300.jpg',
#  'Production': '20th Century Fox',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '18 Sep 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': "The King's Man",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Matthew Vaughn (screenplay by), Karl Gajdusek (screenplay by), '
#            'Matthew Vaughn (story by), Mark Millar (based on the comic book '
#            '"The Secret Service" by), Dave Gibbons (based on the comic book '
#            '"The Secret Service" by)',
#  'Year': '2020',
#  'imdbID': 'tt6856242',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Angelina Jolie, Richard Madden, Salma Hayek, Gemma Chan',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Chloé Zhao',
#  'Genre': 'Action, Adventure, Drama, Fantasy, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The saga of the Eternals, a race of immortal beings who lived on '
#          'Earth and shaped its history and civilizations.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTYzMTlhM2ItMmFkYi00ZTJhLTg3MWQtNzM1NTRkM2NiNzRjXkEyXkFqcGdeQXVyNTE1NjY5Mg@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '06 Nov 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Eternals',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Matthew K. Firpo (screenplay), Ryan Firpo (screenplay), Jack Kirby '
#            '(based on the Marvel comics by)',
#  'Year': '2020',
#  'imdbID': 'tt9032400',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Elisabeth Moss, Oliver Jackson-Cohen, Aldis Hodge, Storm Reid',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'Australia, USA',
#  'DVD': 'N/A',
#  'Director': 'Leigh Whannell',
#  'Genre': 'Horror, Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "When Cecilia's abusive ex commits suicide and leaves her fortune, "
#          'she suspects his death was a hoax. As a series of coincidences turn '
#          "lethal, Cecilia's works to prove that she is being hunted by someone "
#          'nobody can see.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZjFhM2I4ZDYtZWMwNC00NTYzLWE3MDgtNjgxYmM3ZWMxYmVmXkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_SX300.jpg',
#  'Production': 'Indie Rights',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '28 Feb 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Invisible Man',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'H.G. Wells (novel), Leigh Whannell',
#  'Year': '2020',
#  'imdbID': 'tt1051906',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Anya Taylor-Joy, Antonio Banderas, Maisie Williams, Alice Braga',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Josh Boone',
#  'Genre': 'Action, Horror, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Five young mutants, just discovering their abilities while held in a '
#          'secret facility against their will, fight to escape their past sins '
#          'and save themselves.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTgxNzM1NzExM15BMl5BanBnXkFtZTgwODMwMDIzNDM@._V1_SX300.jpg',
#  'Production': '20th Century Fox',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '03 Apr 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The New Mutants',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Josh Boone, Knate Lee, Chris Claremont (based on the Marvel comics '
#            'by), Bob McLeod (based on the Marvel comics by), Len Wein '
#            '(character created by: Magik), Dave Cockrum (character created by: '
#            'Magik)',
#  'Year': '2020',
#  'imdbID': 'tt4682266',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Jim Carrey, Tika Sumpter, James Marsden, Neal McDonough',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'Canada, Japan, USA',
#  'DVD': 'N/A',
#  'Director': 'Jeff Fowler',
#  'Genre': 'Action, Adventure, Family, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A cop in the rural town of Green Hills will help Sonic escape from '
#          'the government who is looking to capture him.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDc1ZTlmOWUtNDY2YS00OGU5LTg2MTYtYTk2MmQzMGE2NzUwXkEyXkFqcGdeQXVyODkzNTgxMDg@._V1_SX300.jpg',
#  'Production': 'Paramount Pictures',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '14 Feb 2020',
#  'Response': 'True',
#  'Runtime': '100 min',
#  'Title': 'Sonic the Hedgehog',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Van Robichaux (story by), Evan Susser (story by), Josh Miller '
#            '(screenplay by), Patrick Casey (screenplay by), Oren Uziel '
#            '(screenplay by), Yuji Naka (characters), Naoto Ohshima '
#            '(characters), Hirokazu Yasuhara (characters)',
#  'Year': '2020',
#  'imdbID': 'tt3794354',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Scarlett Johansson, Florence Pugh, Robert Downey Jr., David '
#            'Harbour',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Cate Shortland',
#  'Genre': 'Action, Adventure, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A film about Natasha Romanoff in her quests between the films Civil '
#          'War and Infinity War.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYTU4NmRhNTctMjI2ZS00ZTUyLWI1ZjEtZWU1ODAxMjM5MzlmXkEyXkFqcGdeQXVyNDQxNjcxNQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 May 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Black Widow',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ned Benson (screenplay), Don Heck (comic book & character), Stan '
#            'Lee (characters), Stan Lee (comic book & character), Don Rico '
#            '(comic book & character), Jac Schaeffer (screenplay)',
#  'Year': '2020',
#  'imdbID': 'tt3480822',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Taika Waititi, Ryan Reynolds, Jodie Comer, Utkarsh Ambudkar',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Shawn Levy',
#  'Genre': 'Action, Adventure, Comedy, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "A bank teller discovers that he's actually an NPC inside a brutal, "
#          'open world video game.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzE5YzVjZmEtNGYwZi00YjljLWExMzYtZjlkYTk4NDc0MmI5XkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '03 Jul 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Free Guy',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Matt Lieberman (screenplay by), Matt Lieberman (story by), Zak '
#            'Penn (screenplay by)',
#  'Year': '2020',
#  'imdbID': 'tt6264654',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Amanda Seyfried, Mark Wahlberg, Mckenna Grace, Zac Efron',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tony Cervone',
#  'Genre': 'Animation, Adventure, Comedy, Family, Horror, Mystery',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Scooby and the gang face their most challenging mystery ever: a plot '
#          'to unleash the ghost dog Cerberus upon the world. As they race to '
#          'stop this dogpocalypse, the gang discovers that Scooby has an epic '
#          'destiny greater than anyone imagined.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTY3NTQ5MjEtMjU5Mi00MmVjLTg0ZDAtNTJjYzk3YzUzYjgwXkEyXkFqcGdeQXVyMDA4NzMyOA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '15 May 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Scoob!',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kelly Fremon Craig (screenplay by), Matt Lieberman (story by), Joe '
#            'Ruby (based on characters created by), Ken Spears (based on '
#            'characters created by)',
#  'Year': '2020',
#  'imdbID': 'tt3152592',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Anne Hathaway, Octavia Spencer, Codie-Lei Eastick, Jahzir Bruno',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Robert Zemeckis',
#  'Genre': 'Adventure, Comedy, Family, Fantasy, Horror, Mystery',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Based on Roald Dahl's 1973 classic book 'The Witches', the story "
#          'tells the scary, funny and imaginative tale of a seven year old boy '
#          'who has a run in with some real life witches!',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '16 Oct 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Witches',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Roald Dahl (novel), Robert Zemeckis (screenplay), Allan Scott '
#            '(based on the 1990 film "The Witches" screenplay by), Kenya Barris '
#            '(screenplay)',
#  'Year': '2020',
#  'imdbID': 'tt0805647',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Kristen Stewart, T.J. Miller, Jessica Henwick, Vincent Cassel',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'William Eubank',
#  'Genre': 'Action, Drama, Horror, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A crew of aquatic researchers work to get to safety after an '
#          'earthquake devastates their subterranean laboratory. But the crew '
#          'has more than the ocean seabed to fear.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BM2JiNzA2ODAtMTgxMy00ODBjLTkwYWItZTJjNTRjYjcyMTQxXkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'PG-13',
#  'Ratings': [],
#  'Released': '10 Jan 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Underwater',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Brian Duffield (screenplay by), Adam Cozad (screenplay by), Brian '
#            'Duffield (story by)',
#  'Year': '2020',
#  'imdbID': 'tt5774060',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Dave Bautista, Kristen Schaal, Ken Jeong, Greg Bryk',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Peter Segal',
#  'Genre': 'Action, Comedy, Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A hardened CIA operative finds himself at the mercy of a precocious '
#          '9-year-old girl, having been sent undercover to surveil her family.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjI4YzA0NTMtMWYxZi00NmQ2LTkwZDYtZGFiNjFmN2FlNjQ3XkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_SX300.jpg',
#  'Production': 'STXfilms',
#  'Rated': 'PG-13',
#  'Ratings': [],
#  'Released': '10 Jan 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'My Spy',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Erich Hoeber, Jon Hoeber',
#  'Year': '2020',
#  'imdbID': 'tt8242084',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Tom Holland, Mark Wahlberg',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Travis Knight',
#  'Genre': 'Action, Adventure',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The story is a prequel to the games, starring Holland as a younger '
#          'Drake, showing us details of how he came to meet and befriend Sully.',
#  'Poster': 'N/A',
#  'Production': 'Columbia Pictures',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '18 Dec 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Uncharted',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joe Carnahan (screenplay), Joe Carnahan, Rafe Judkins (screenplay)',
#  'Year': '2020',
#  'imdbID': 'tt1464335',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Benedict Cumberbatch',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jon M. Chu, David Gould',
#  'Genre': 'Crime, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "A third installment of the 'Now You See Me' franchise. Plot "
#          'undisclosed.',
#  'Poster': 'N/A',
#  'Production': 'Lionsgate',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Now You See Me 3',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Gavin James, Ed Solomon (characters), Ed Solomon (story), Neil '
#            'Widener',
#  'Year': '2020',
#  'imdbID': 'tt4712810',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Bonnie Aarons',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'Horror, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Sequel to the 2018 hit film --- The Nun.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '31 Oct 2020',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Nun 2',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Akela Cooper (screenplay)',
#  'Year': '2020',
#  'imdbID': 'tt10160976',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}

# %%
len(title_list)
# Out:
# 44

# %%
data['title'] = title_list
data['box_office'] = box_office_list
data['country'] = country_list
data['genre'] = genre_list
data['director'] = director_list
data['metascore'] = metascore_list
data['production'] = production_list
data['rating'] = rating_list
data['IMDB_rating'] = IMDB_rating_list 
data['rotten_tomatoes_rating'] = rotten_tomatoes_rating_list
data['runtime'] = runtime_list
data['type'] = type_list
data['IMDB_votes'] = imdb_votes_list

# %%
#drop any movies that ddo not include USA for country: 1) N/A 
data['country'].value_counts()
# Out:
# USA                          32
# Australia, USA                2
# UK, USA                       2
# USA, Hong Kong                1
# United Arab Emirates, USA     1
# South Korea, USA              1
# USA, Hungary, Canada          1
# UK, France, USA               1
# N/A                           1
# Canada, Japan, USA            1
# USA, UK                       1
# Name: country, dtype: int64

# %%
data = data[data.country != 'N/A']

# %%
data.to_csv('Resources/2020_movie_data.csv', index=False)
