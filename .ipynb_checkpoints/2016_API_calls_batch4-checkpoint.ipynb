# %%
import pandas as pd
import requests
import json
import time
from pprint import pprint
from config import API_KEY

# %%
data = pd.read_csv('Resources/movies_titles_2018.csv')
df =  data.groupby('2018_movies').nunique().count()
df
# Out:
# 2018_movies    103
# dtype: int64

# %%
box_office_list = []
country_list = []
genre_list = []
director_list = []
metascore_list = []
production_list = []
rating_list = []
IMDB_rating_list = [] 
rotten_tomatoes_rating_list = []
runtime_list = []
title_list = []
type_list = []
imdb_votes_list = []

# %%
movies = data['2018_movies']
total_movies = len(movies)

# %%
for i in range(total_movies):
    movie = movies[i]
    url = "http://www.omdbapi.com/?i=" + movie + "&apikey=" + API_KEY
    response = (requests.get(url).text)
    response_json = json.loads(response)
    
    pprint(response_json)
    
    box_office_list.append(response_json['BoxOffice'])
    country_list.append(response_json['Country'])
    genre_list.append(response_json['Genre'])
    director_list.append(response_json['Director'])
    metascore_list.append(response_json['Metascore'])
    production_list.append(response_json['Production'])
    rating_list.append(response_json['Rated'])
    IMDB_rating_list.append(response_json['imdbRating'])
    try:
        if not response_json['Ratings']:
            rotten_tomatoes_rating_list.append('NA')
        elif response_json['Ratings'][0]['Source'] == 'Rotten Tomatoes':
            rotten_tomatoes_rating_list.append(response_json['Ratings'][0]['Value'])
        elif response_json['Ratings'][1]['Source'] == 'Rotten Tomatoes':
            rotten_tomatoes_rating_list.append(response_json['Ratings'][1]['Value'])
        else:
            rotten_tomatoes_rating_list.append('NA')
    except IndexError:
        rotten_tomatoes_rating_list.append('NA')
    runtime_list.append(response_json['Runtime'])
    title_list.append(response_json['Title'])
    type_list.append(response_json['Type'])
    imdb_votes_list.append(response_json['imdbVotes'])
# Out:
# {'Actors': 'Robert Downey Jr., Chris Hemsworth, Mark Ruffalo, Chris Evans',
#  'Awards': 'Nominated for 1 Oscar. Another 44 wins & 64 nominations.',
#  'BoxOffice': '$664,987,816',
#  'Country': 'USA',
#  'DVD': '14 Aug 2018',
#  'Director': 'Anthony Russo, Joe Russo',
#  'Genre': 'Action, Adventure, Sci-Fi',
#  'Language': 'English',
#  'Metascore': '68',
#  'Plot': 'The Avengers and their allies must be willing to sacrifice all in an '
#          'attempt to defeat the powerful Thanos before his blitz of '
#          'devastation and ruin puts an end to the universe.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjMxNjY2MDU1OV5BMl5BanBnXkFtZTgwNzY1MTUwNTM@._V1_SX300.jpg',
#  'Production': 'Walt Disney Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.5/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '85%'},
#              {'Source': 'Metacritic', 'Value': '68/100'}],
#  'Released': '27 Apr 2018',
#  'Response': 'True',
#  'Runtime': '149 min',
#  'Title': 'Avengers: Infinity War',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Christopher Markus (screenplay by), Stephen McFeely (screenplay '
#            'by), Stan Lee (based on the Marvel comics by), Jack Kirby (based '
#            'on the Marvel comics by), Joe Simon (Captain America created by), '
#            'Jack Kirby (Captain America created by), Steve Englehart '
#            '(Star-Lord created by), Steve Gan (Star-Lord created by), Bill '
#            'Mantlo (Rocket Raccoon created by), Keith Giffen (Rocket Raccoon '
#            'created by), Jim Starlin (Thanos,  Gamora and Drax created by), '
#            'Stan Lee (Groot created by), Larry Lieber (Groot created by), Jack '
#            'Kirby (Groot created by), Steve Englehart (Mantis created by), Don '
#            'Heck (Mantis created by)',
#  'Year': '2018',
#  'imdbID': 'tt4154756',
#  'imdbRating': '8.5',
#  'imdbVotes': '732,619'}
# {'Actors': 'Jason Momoa, Amber Heard, Willem Dafoe, Patrick Wilson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Australia',
#  'DVD': 'N/A',
#  'Director': 'James Wan',
#  'Genre': 'Action, Adventure, Fantasy, Sci-Fi',
#  'Language': 'English, Russian, Maori, Italian',
#  'Metascore': '55',
#  'Plot': 'Arthur Curry, the human-born heir to the underwater kingdom of '
#          'Atlantis, goes on a quest to prevent a war between the worlds of '
#          'ocean and land.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTk5ODg0OTU5M15BMl5BanBnXkFtZTgwMDQ3MDY3NjM@._V1_SX300.jpg',
#  'Production': 'Warner Bros. Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '66%'},
#              {'Source': 'Metacritic', 'Value': '55/100'}],
#  'Released': '21 Dec 2018',
#  'Response': 'True',
#  'Runtime': '143 min',
#  'Title': 'Aquaman',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'David Leslie Johnson-McGoldrick (screenplay by), Will Beall '
#            '(screenplay by), Geoff Johns (story by), James Wan (story by), '
#            'Will Beall (story by), Paul Norris (Aquaman created by), Mort '
#            'Weisinger (Aquaman created by)',
#  'Year': '2018',
#  'imdbID': 'tt1477834',
#  'imdbRating': '7.0',
#  'imdbVotes': '313,995'}
# {'Actors': 'Alden Ehrenreich, Joonas Suotamo, Woody Harrelson, Emilia Clarke',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '14 Sep 2018',
#  'Director': 'Ron Howard',
#  'Genre': 'Action, Adventure, Sci-Fi',
#  'Language': 'English',
#  'Metascore': '62',
#  'Plot': 'During an adventure into the criminal underworld, Han Solo meets his '
#          'future co-pilot Chewbacca and encounters Lando Calrissian years '
#          'before joining the Rebellion.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTM2NTI3NTc3Nl5BMl5BanBnXkFtZTgwNzM1OTQyNTM@._V1_SX300.jpg',
#  'Production': 'Walt Disney Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.9/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '70%'},
#              {'Source': 'Metacritic', 'Value': '62/100'}],
#  'Released': '25 May 2018',
#  'Response': 'True',
#  'Runtime': '135 min',
#  'Title': 'Solo: A Star Wars Story',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jonathan Kasdan, Lawrence Kasdan, George Lucas (based on '
#            'characters created by)',
#  'Year': '2018',
#  'imdbID': 'tt3778644',
#  'imdbRating': '6.9',
#  'imdbVotes': '244,965'}
# {'Actors': 'Johnny Depp, Kevin Guthrie, Carmen Ejogo, Wolf Roth',
#  'Awards': 'Nominated for 2 BAFTA Film Awards. Another 2 wins & 16 '
#            'nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'UK, USA',
#  'DVD': '12 Mar 2019',
#  'Director': 'David Yates',
#  'Genre': 'Adventure, Family, Fantasy',
#  'Language': 'English, French',
#  'Metascore': '52',
#  'Plot': 'The second installment of the "Fantastic Beasts" series featuring '
#          'the adventures of Magizoologist Newt Scamander.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZjFiMGUzMTAtNDAwMC00ZjRhLTk0OTUtMmJiMzM5ZmVjODQxXkEyXkFqcGdeQXVyMDM2NDM2MQ@@._V1_SX300.jpg',
#  'Production': 'Warner Bros. Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '37%'},
#              {'Source': 'Metacritic', 'Value': '52/100'}],
#  'Released': '16 Nov 2018',
#  'Response': 'True',
#  'Runtime': '134 min',
#  'Title': 'Fantastic Beasts: The Crimes of Grindelwald',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'J.K. Rowling, J.K. Rowling (based upon characters created by)',
#  'Year': '2018',
#  'imdbID': 'tt4123430',
#  'imdbRating': '6.6',
#  'imdbVotes': '187,555'}
# {'Actors': "Chadwick Boseman, Michael B. Jordan, Lupita Nyong'o, Danai Gurira",
#  'Awards': 'Won 3 Oscars. Another 101 wins & 246 nominations.',
#  'BoxOffice': '$501,105,037',
#  'Country': 'USA',
#  'DVD': '15 May 2018',
#  'Director': 'Ryan Coogler',
#  'Genre': 'Action, Adventure, Sci-Fi',
#  'Language': 'English, Swahili, Nama, Xhosa, Korean',
#  'Metascore': '88',
#  'Plot': "T'Challa, heir to the hidden but advanced kingdom of Wakanda, must "
#          'step forward to lead his people into a new future and must confront '
#          "a challenger from his country's past.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg1MTY2MjYzNV5BMl5BanBnXkFtZTgwMTc4NTMwNDI@._V1_SX300.jpg',
#  'Production': 'Marvel Studios',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.3/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '97%'},
#              {'Source': 'Metacritic', 'Value': '88/100'}],
#  'Released': '16 Feb 2018',
#  'Response': 'True',
#  'Runtime': '134 min',
#  'Title': 'Black Panther',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ryan Coogler, Joe Robert Cole, Stan Lee (based on the Marvel '
#            'comics by), Jack Kirby (based on the Marvel Comics by)',
#  'Year': '2018',
#  'imdbID': 'tt1825683',
#  'imdbRating': '7.3',
#  'imdbVotes': '555,834'}
# {'Actors': 'Dakota Johnson, Jamie Dornan, Eric Johnson, Eloise Mumford',
#  'Awards': '6 wins & 10 nominations.',
#  'BoxOffice': '$95,599,460',
#  'Country': 'USA',
#  'DVD': '08 May 2018',
#  'Director': 'James Foley',
#  'Genre': 'Drama, Romance, Thriller',
#  'Language': 'English',
#  'Metascore': '31',
#  'Plot': 'Anastasia and Christian get married, but Jack Hyde continues to '
#          'threaten their relationship.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTYxOTQ1MzI0Nl5BMl5BanBnXkFtZTgwMzgwMzIxNDM@._V1_SX300.jpg',
#  'Production': 'Universal Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.5/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '12%'},
#              {'Source': 'Metacritic', 'Value': '31/100'}],
#  'Released': '09 Feb 2018',
#  'Response': 'True',
#  'Runtime': '105 min',
#  'Title': 'Fifty Shades Freed',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Niall Leonard (screenplay by), E.L. James (based on the novel by)',
#  'Year': '2018',
#  'imdbID': 'tt4477536',
#  'imdbRating': '4.5',
#  'imdbVotes': '47,205'}
# {'Actors': 'Shameik Moore, Jake Johnson, Hailee Steinfeld, Mahershala Ali',
#  'Awards': 'Won 1 Oscar. Another 69 wins & 52 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '26 Feb 2019',
#  'Director': 'Bob Persichetti, Peter Ramsey, Rodney Rothman',
#  'Genre': 'Animation, Action, Adventure, Family, Sci-Fi',
#  'Language': 'English, Spanish',
#  'Metascore': '87',
#  'Plot': 'Teen Miles Morales becomes Spider-Man of his reality, crossing his '
#          'path with five counterparts from other dimensions to stop a threat '
#          'for all realities.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjMwNDkxMTgzOF5BMl5BanBnXkFtZTgwNTkwNTQ3NjM@._V1_SX300.jpg',
#  'Production': 'Sony Pictures',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.4/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '97%'},
#              {'Source': 'Metacritic', 'Value': '87/100'}],
#  'Released': '14 Dec 2018',
#  'Response': 'True',
#  'Runtime': '117 min',
#  'Title': 'Spider-Man: Into the Spider-Verse',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Phil Lord (screenplay by), Rodney Rothman (screenplay by), Phil '
#            'Lord (story by)',
#  'Year': '2018',
#  'imdbID': 'tt4633694',
#  'imdbRating': '8.4',
#  'imdbVotes': '282,011'}
# {'Actors': 'Chris Pratt, Bryce Dallas Howard, Rafe Spall, Justice Smith',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '18 Sep 2018',
#  'Director': 'J.A. Bayona',
#  'Genre': 'Action, Adventure, Sci-Fi',
#  'Language': 'English, Russian',
#  'Metascore': '51',
#  'Plot': "When the island's dormant volcano begins roaring to life, Owen and "
#          'Claire mount a campaign to rescue the remaining dinosaurs from this '
#          'extinction-level event.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzIxMjYwNDEwN15BMl5BanBnXkFtZTgwMzk5MDI3NTM@._V1_SX300.jpg',
#  'Production': 'Universal Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '48%'},
#              {'Source': 'Metacritic', 'Value': '51/100'}],
#  'Released': '22 Jun 2018',
#  'Response': 'True',
#  'Runtime': '128 min',
#  'Title': 'Jurassic World: Fallen Kingdom',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Derek Connolly, Colin Trevorrow, Michael Crichton (based on '
#            'characters created by)',
#  'Year': '2018',
#  'imdbID': 'tt4881806',
#  'imdbRating': '6.2',
#  'imdbVotes': '234,437'}
# {'Actors': 'Paul Rudd, Evangeline Lilly, Michael Peña, Walton Goggins',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '16 Oct 2018',
#  'Director': 'Peyton Reed',
#  'Genre': 'Action, Adventure, Comedy, Sci-Fi',
#  'Language': 'English, Spanish',
#  'Metascore': '70',
#  'Plot': 'As Scott Lang balances being both a superhero and a father, Hope van '
#          'Dyne and Dr. Hank Pym present an urgent new mission that finds the '
#          'Ant-Man fighting alongside The Wasp to uncover secrets from their '
#          'past.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYjcyYTk0N2YtMzc4ZC00Y2E0LWFkNDgtNjE1MzZmMGE1YjY1XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg',
#  'Production': 'Walt Disney Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '88%'},
#              {'Source': 'Metacritic', 'Value': '70/100'}],
#  'Released': '06 Jul 2018',
#  'Response': 'True',
#  'Runtime': '118 min',
#  'Title': 'Ant-Man and the Wasp',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Chris McKenna, Erik Sommers, Paul Rudd, Andrew Barrer, Gabriel '
#            'Ferrari, Stan Lee (based on the Marvel Comics by), Larry Lieber '
#            '(based on the Marvel Comics by), Jack Kirby (based on the Marvel '
#            'Comics by)',
#  'Year': '2018',
#  'imdbID': 'tt5095030',
#  'imdbRating': '7.1',
#  'imdbVotes': '268,549'}
# {'Actors': 'Adam Sandler, Andy Samberg, Selena Gomez, Kevin James',
#  'Awards': '2 wins & 8 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, South Korea',
#  'DVD': '25 Sep 2018',
#  'Director': 'Genndy Tartakovsky',
#  'Genre': 'Animation, Adventure, Comedy, Family, Fantasy',
#  'Language': 'English, Spanish, German, Russian',
#  'Metascore': '54',
#  'Plot': 'Count Dracula and company participate in a cruise for sea-loving '
#          'monsters, unaware that their boat is being commandeered by the '
#          'monster-hating Van Helsing family.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjA1MzU5MTY3OF5BMl5BanBnXkFtZTgwNTU5MDA3NTM@._V1_SX300.jpg',
#  'Production': 'Columbia Pictures / Sony Pictures Animation',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '62%'},
#              {'Source': 'Metacritic', 'Value': '54/100'}],
#  'Released': '13 Jul 2018',
#  'Response': 'True',
#  'Runtime': '97 min',
#  'Title': 'Hotel Transylvania 3: Summer Vacation',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Genndy Tartakovsky, Michael McCullers',
#  'Year': '2018',
#  'imdbID': 'tt5220122',
#  'imdbRating': '6.3',
#  'imdbVotes': '47,484'}
# {'Actors': 'Kelly Asbury, Mary J. Blige, Emily Blunt, Julio Bonet',
#  'Awards': '1 win & 5 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'UK, USA, India, Canada, France, Belgium',
#  'DVD': '12 Jun 2018',
#  'Director': 'John Stevenson',
#  'Genre': 'Animation, Adventure, Comedy, Family, Fantasy, Mystery, Romance',
#  'Language': 'English, Mandarin',
#  'Metascore': '36',
#  'Plot': 'Garden gnomes, Gnomeo (James McAvoy) and Juliet (Emily Blunt), '
#          'recruit renowned detective Sherlock Gnomes (Johnny Depp) to '
#          'investigate the mysterious disappearance of other garden ornaments.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk4NzU3NzU2NV5BMl5BanBnXkFtZTgwNDc4NTI3NDM@._V1_SX300.jpg',
#  'Production': 'Paramount Pictures',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '27%'},
#              {'Source': 'Metacritic', 'Value': '36/100'}],
#  'Released': '23 Mar 2018',
#  'Response': 'True',
#  'Runtime': '86 min',
#  'Title': 'Sherlock Gnomes',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ben Zazove (screenplay by), Andy Riley (story by), Kevin Cecil '
#            '(story by), Emily Cook (story by), Kathy Greenberg (story by), Rob '
#            'Sprackling (based on characters by), Johnny Smith (based on '
#            'characters by), Andy Riley (based on characters by), Kevin Cecil '
#            '(based on characters by), Kelly Asbury (based on characters by), '
#            'Steve Hamilton Shaw',
#  'Year': '2018',
#  'imdbID': 'tt2296777',
#  'imdbRating': '5.1',
#  'imdbVotes': '8,802'}
# {'Actors': 'Hailee Steinfeld, Jorge Lendeborg Jr., John Cena, Jason Drucker',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'China, USA',
#  'DVD': '02 Apr 2019',
#  'Director': 'Travis Knight',
#  'Genre': 'Action, Adventure, Sci-Fi',
#  'Language': 'English',
#  'Metascore': '66',
#  'Plot': 'On the run in the year 1987, Bumblebee finds refuge in a junkyard in '
#          'a small California beach town. On the cusp of turning 18 and trying '
#          'to find her place in the world, Charlie Watson discovers Bumblebee, '
#          'battle-scarred and broken.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjUwNjU5NDMyNF5BMl5BanBnXkFtZTgwNzgxNjM2NzM@._V1_SX300.jpg',
#  'Production': 'Paramount Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.8/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '92%'},
#              {'Source': 'Metacritic', 'Value': '66/100'}],
#  'Released': '21 Dec 2018',
#  'Response': 'True',
#  'Runtime': '114 min',
#  'Title': 'Bumblebee',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Christina Hodson',
#  'Year': '2018',
#  'imdbID': 'tt4701182',
#  'imdbRating': '6.8',
#  'imdbVotes': '111,895'}
# {'Actors': 'Benedict Cumberbatch, Cameron Seely, Rashida Jones, Pharrell '
#            'Williams',
#  'Awards': '15 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'France, Japan, USA',
#  'DVD': '05 Feb 2019',
#  'Director': 'Yarrow Cheney, Scott Mosier',
#  'Genre': 'Animation, Family, Fantasy',
#  'Language': 'English',
#  'Metascore': '51',
#  'Plot': 'A grumpy Grinch plots to ruin Christmas for the village of Whoville.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYmE5Yjg0MzktYzgzMi00YTFiLWJjYTItY2M5MmI1ODI4MDY3XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg',
#  'Production': 'Universal Pictures',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '59%'},
#              {'Source': 'Metacritic', 'Value': '51/100'}],
#  'Released': '09 Nov 2018',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': "Dr. Seuss' The Grinch",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael LeSieur (screenplay by), Tommy Swerdlow (screenplay by), '
#            'Dr. Seuss (based on the book "How The Grinch Stole Christmas" by)',
#  'Year': '2018',
#  'imdbID': 'tt2709692',
#  'imdbRating': '6.3',
#  'imdbVotes': '36,198'}
# {'Actors': 'John C. Reilly, Sarah Silverman, Gal Gadot, Taraji P. Henson',
#  'Awards': 'Nominated for 1 Oscar. Another 3 wins & 57 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '12 Feb 2019',
#  'Director': 'Phil Johnston, Rich Moore',
#  'Genre': 'Animation, Adventure, Comedy, Family, Fantasy',
#  'Language': 'English',
#  'Metascore': '71',
#  'Plot': 'Six years after the events of "Wreck-It Ralph," Ralph and Vanellope, '
#          'now friends, discover a wi-fi router in their arcade, leading them '
#          'into a new adventure.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTYyNzEyNDAzOV5BMl5BanBnXkFtZTgwNTk3NDczNjM@._V1_SX300.jpg',
#  'Production': 'Walt Disney Animation Studios',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '88%'},
#              {'Source': 'Metacritic', 'Value': '71/100'}],
#  'Released': '21 Nov 2018',
#  'Response': 'True',
#  'Runtime': '112 min',
#  'Title': 'Ralph Breaks the Internet',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Phil Johnston (screenplay by), Pamela Ribon (screenplay by), Rich '
#            'Moore (story by), Phil Johnston (story by), Jim Reardon (story '
#            'by), Pamela Ribon (story by), Josie Trinidad (story by)',
#  'Year': '2018',
#  'imdbID': 'tt5848272',
#  'imdbRating': '7.1',
#  'imdbVotes': '107,571'}
# {'Actors': 'John Boyega, Scott Eastwood, Cailee Spaeny, Burn Gorman',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'UK, China, Japan, USA',
#  'DVD': '19 Jun 2018',
#  'Director': 'Steven S. DeKnight',
#  'Genre': 'Action, Adventure, Sci-Fi',
#  'Language': 'English, Mandarin, Russian',
#  'Metascore': '44',
#  'Plot': 'Jake Pentecost, son of Stacker Pentecost, reunites with Mako Mori to '
#          'lead a new generation of Jaeger pilots, including rival Lambert and '
#          '15-year-old hacker Amara, against a new Kaiju threat.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjI3Nzg0MTM5NF5BMl5BanBnXkFtZTgwOTE2MTgwNTM@._V1_SX300.jpg',
#  'Production': 'Universal Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '44%'},
#              {'Source': 'Metacritic', 'Value': '44/100'}],
#  'Released': '23 Mar 2018',
#  'Response': 'True',
#  'Runtime': '111 min',
#  'Title': 'Pacific Rim: Uprising',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Steven S. DeKnight, Emily Carmichael, Kira Snyder, T.S. Nowlin, '
#            'Travis Beacham (based on characters created by)',
#  'Year': '2018',
#  'imdbID': 'tt2557478',
#  'imdbRating': '5.6',
#  'imdbVotes': '94,920'}
# {'Actors': "Dylan O'Brien, Ki Hong Lee, Kaya Scodelario, Thomas "
#            'Brodie-Sangster',
#  'Awards': 'N/A',
#  'BoxOffice': '$57,074,211',
#  'Country': 'USA',
#  'DVD': '24 Apr 2018',
#  'Director': 'Wes Ball',
#  'Genre': 'Action, Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': '50',
#  'Plot': 'Young hero Thomas embarks on a mission to find a cure for a deadly '
#          'disease known as "The Flare".',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTYyNzk3MDc2NF5BMl5BanBnXkFtZTgwMDk3OTM1NDM@._V1_SX300.jpg',
#  'Production': '20th Century Fox',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '43%'},
#              {'Source': 'Metacritic', 'Value': '50/100'}],
#  'Released': '26 Jan 2018',
#  'Response': 'True',
#  'Runtime': '143 min',
#  'Title': 'Maze Runner: The Death Cure',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'T.S. Nowlin (screenplay by), James Dashner (based upon the novel '
#            'by)',
#  'Year': '2018',
#  'imdbID': 'tt4500922',
#  'imdbRating': '6.2',
#  'imdbVotes': '97,460'}
# {'Actors': 'Alicia Vikander, Dominic West, Walton Goggins, Daniel Wu',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'UK, USA',
#  'DVD': '12 Jun 2018',
#  'Director': 'Roar Uthaug',
#  'Genre': 'Action, Adventure, Fantasy, Thriller',
#  'Language': 'English, Cantonese, Hindi',
#  'Metascore': '48',
#  'Plot': 'Lara Croft, the fiercely independent daughter of a missing '
#          'adventurer, must push herself beyond her limits when she discovers '
#          'the island where her father disappeared.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTY4NDcyZGQtYmVlNy00ODgwLTljYTMtYzQ2OTE3NDhjODMwXkEyXkFqcGdeQXVyNzYzODM3Mzg@._V1_SX300.jpg',
#  'Production': 'Warner Bros. Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '52%'},
#              {'Source': 'Metacritic', 'Value': '48/100'}],
#  'Released': '16 Mar 2018',
#  'Response': 'True',
#  'Runtime': '119 min',
#  'Title': 'Tomb Raider',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Geneva Robertson-Dworet (screenplay by), Alastair Siddons '
#            '(screenplay by), Evan Daugherty (story by), Geneva '
#            'Robertson-Dworet (story by)',
#  'Year': '2018',
#  'imdbID': 'tt1365519',
#  'imdbRating': '6.3',
#  'imdbVotes': '172,945'}
# {'Actors': 'Ryan Reynolds, Josh Brolin, Morena Baccarin, Julian Dennison',
#  'Awards': '6 wins & 47 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '21 Aug 2018',
#  'Director': 'David Leitch',
#  'Genre': 'Action, Adventure, Comedy, Sci-Fi',
#  'Language': 'English, Cantonese, Spanish, Russian',
#  'Metascore': '66',
#  'Plot': 'Foul-mouthed mutant mercenary Wade Wilson (a.k.a. Deadpool), brings '
#          'together a team of fellow mutant rogues to protect a young boy with '
#          'supernatural abilities from the brutal, time-traveling cyborg Cable.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjk1Njk3YjctMmMyYS00Y2I4LThhMzktN2U0MTMyZTFlYWQ5XkEyXkFqcGdeQXVyODM2ODEzMDA@._V1_SX300.jpg',
#  'Production': '20th Century Fox',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.7/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '84%'},
#              {'Source': 'Metacritic', 'Value': '66/100'}],
#  'Released': '18 May 2018',
#  'Response': 'True',
#  'Runtime': '119 min',
#  'Title': 'Deadpool 2',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Rhett Reese, Paul Wernick, Ryan Reynolds',
#  'Year': '2018',
#  'imdbID': 'tt5463162',
#  'imdbRating': '7.7',
#  'imdbVotes': '427,381'}
# {'Actors': 'Tye Sheridan, Olivia Cooke, Ben Mendelsohn, Lena Waithe',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, India',
#  'DVD': '03 Jul 2018',
#  'Director': 'Steven Spielberg',
#  'Genre': 'Action, Adventure, Sci-Fi',
#  'Language': 'English',
#  'Metascore': '64',
#  'Plot': 'When the creator of a virtual reality called the OASIS dies, he '
#          'makes a posthumous challenge to all OASIS users to find his Easter '
#          'Egg, which will give the finder his fortune and control of his '
#          'world.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BY2JiYTNmZTctYTQ1OC00YjU4LWEwMjYtZjkwY2Y5MDI0OTU3XkEyXkFqcGdeQXVyNTI4MzE4MDU@._V1_SX300.jpg',
#  'Production': 'Warner Bros. Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.5/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '72%'},
#              {'Source': 'Metacritic', 'Value': '64/100'}],
#  'Released': '29 Mar 2018',
#  'Response': 'True',
#  'Runtime': '140 min',
#  'Title': 'Ready Player One',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Zak Penn (screenplay by), Ernest Cline (screenplay by), Ernest '
#            'Cline (based on the novel by)',
#  'Year': '2018',
#  'imdbID': 'tt1677720',
#  'imdbRating': '7.5',
#  'imdbVotes': '321,505'}
# {'Actors': 'Boyd Holbrook, Trevante Rhodes, Jacob Tremblay, Keegan-Michael Key',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Canada',
#  'DVD': '18 Dec 2018',
#  'Director': 'Shane Black',
#  'Genre': 'Action, Adventure, Sci-Fi, Thriller',
#  'Language': 'English, Spanish',
#  'Metascore': '48',
#  'Plot': "When a young boy accidentally triggers the universe's most lethal "
#          "hunters' return to Earth, only a ragtag crew of ex-soldiers and a "
#          'disgruntled scientist can prevent the end of the human race.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjM5MDk2NDIxMF5BMl5BanBnXkFtZTgwNjU5NDk3NTM@._V1_SX300.jpg',
#  'Production': '20th Century Fox',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '32%'},
#              {'Source': 'Metacritic', 'Value': '48/100'}],
#  'Released': '14 Sep 2018',
#  'Response': 'True',
#  'Runtime': '107 min',
#  'Title': 'The Predator',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Fred Dekker, Shane Black, Jim Thomas (based on characters created '
#            'by), John Thomas (based on characters created by)',
#  'Year': '2018',
#  'imdbID': 'tt3829266',
#  'imdbRating': '5.4',
#  'imdbVotes': '104,464'}
# {'Actors': 'Emily Blunt, Lin-Manuel Miranda, Ben Whishaw, Emily Mortimer',
#  'Awards': 'Nominated for 4 Oscars. Another 18 wins & 90 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, UK',
#  'DVD': 'N/A',
#  'Director': 'Rob Marshall',
#  'Genre': 'Comedy, Family, Fantasy, Musical',
#  'Language': 'English',
#  'Metascore': '66',
#  'Plot': 'Decades after her original visit, the magical nanny returns to help '
#          "the Banks siblings and Michael's children through a difficult time "
#          'in their lives.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjQxNjE3NjYxN15BMl5BanBnXkFtZTgwMTk2NDQ3NjM@._V1_SX300.jpg',
#  'Production': 'Walt Disney Pictures',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.8/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '79%'},
#              {'Source': 'Metacritic', 'Value': '66/100'}],
#  'Released': '19 Dec 2018',
#  'Response': 'True',
#  'Runtime': '130 min',
#  'Title': 'Mary Poppins Returns',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'P.L. Travers (based upon the "Mary Poppins" stories by), David '
#            'Magee (screen story by), Rob Marshall (screen story by), John '
#            'DeLuca (screen story by), David Magee (screenplay by)',
#  'Year': '2018',
#  'imdbID': 'tt5028340',
#  'imdbRating': '6.8',
#  'imdbVotes': '64,106'}
# {'Actors': 'Mackenzie Foy, Tom Sweet, Meera Syal, Ellie Bamber',
#  'Awards': '8 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '29 Jan 2019',
#  'Director': 'Lasse Hallström, Joe Johnston',
#  'Genre': 'Adventure, Family, Fantasy',
#  'Language': 'English, French',
#  'Metascore': '39',
#  'Plot': 'A young girl is transported into a magical world of gingerbread '
#          'soldiers and an army of mice.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTg1NDI1MjEyMl5BMl5BanBnXkFtZTgwOTA5MTgwNjM@._V1_SX300.jpg',
#  'Production': 'Walt Disney Pictures',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.5/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '33%'},
#              {'Source': 'Metacritic', 'Value': '39/100'}],
#  'Released': '02 Nov 2018',
#  'Response': 'True',
#  'Runtime': '99 min',
#  'Title': 'The Nutcracker and the Four Realms',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ashleigh Powell (screen story by), Ashleigh Powell (screenplay '
#            'by), E.T.A. Hoffmann (suggested by the short story "The Nutcracker '
#            'and the Mouse King" written by), Marius Petipa (suggested by the '
#            '"Nutcracker Ballet" by)',
#  'Year': '2018',
#  'imdbID': 'tt5523010',
#  'imdbRating': '5.5',
#  'imdbVotes': '23,624'}
# {'Actors': 'Sandra Bullock, Griffin Dunne, Deidre Goodwin, Daniella Rabbani',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '11 Sep 2018',
#  'Director': 'Gary Ross',
#  'Genre': 'Action, Comedy, Crime, Thriller',
#  'Language': 'English, Hindi, French, German, Mandarin',
#  'Metascore': '61',
#  'Plot': 'Debbie Ocean gathers an all-female crew to attempt an impossible '
#          "heist at New York City's yearly Met Gala.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjAyNDEyMzc4Ml5BMl5BanBnXkFtZTgwMjEzNjM0NTM@._V1_SX300.jpg',
#  'Production': 'Warner Bros. Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '69%'},
#              {'Source': 'Metacritic', 'Value': '61/100'}],
#  'Released': '08 Jun 2018',
#  'Response': 'True',
#  'Runtime': '110 min',
#  'Title': "Ocean's Eight",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Gary Ross (screenplay by), Olivia Milch (screenplay by), Gary Ross '
#            '(story by), George Clayton Johnson (based upon characters created '
#            'by), Jack Golden Russell (based upon characters created by)',
#  'Year': '2018',
#  'imdbID': 'tt5164214',
#  'imdbRating': '6.2',
#  'imdbVotes': '156,767'}
# {'Actors': 'Craig T. Nelson, Holly Hunter, Sarah Vowell, Huck Milner',
#  'Awards': 'Nominated for 1 Oscar. Another 12 wins & 67 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '23 Oct 2018',
#  'Director': 'Brad Bird',
#  'Genre': 'Animation, Action, Adventure, Comedy, Family, Sci-Fi',
#  'Language': 'English',
#  'Metascore': '80',
#  'Plot': 'The Incredibles hero family takes on a new mission, which involves a '
#          'change in family roles: Bob Parr (Mr Incredible) must manage the '
#          'house while his wife Helen (Elastigirl) goes out to save the world.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTEzNzY0OTg0NTdeQTJeQWpwZ15BbWU4MDU3OTg3MjUz._V1_SX300.jpg',
#  'Production': 'Disney/Pixar',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.7/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '94%'},
#              {'Source': 'Metacritic', 'Value': '80/100'}],
#  'Released': '15 Jun 2018',
#  'Response': 'True',
#  'Runtime': '118 min',
#  'Title': 'Incredibles 2',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Brad Bird',
#  'Year': '2018',
#  'imdbID': 'tt3606756',
#  'imdbRating': '7.7',
#  'imdbVotes': '220,721'}
# {'Actors': 'Tom Cruise, Henry Cavill, Ving Rhames, Simon Pegg',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, China, France, Norway, UK',
#  'DVD': '04 Dec 2018',
#  'Director': 'Christopher McQuarrie',
#  'Genre': 'Action, Adventure, Thriller',
#  'Language': 'English, French',
#  'Metascore': '86',
#  'Plot': 'Ethan Hunt and his IMF team, along with some familiar allies, race '
#          'against time after a mission gone wrong.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjRlZmM0ODktY2RjNS00ZDdjLWJhZGYtNDljNWZkMGM5MTg0XkEyXkFqcGdeQXVyNjAwMjI5MDk@._V1_SX300.jpg',
#  'Production': 'Paramount Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.8/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '97%'},
#              {'Source': 'Metacritic', 'Value': '86/100'}],
#  'Released': '27 Jul 2018',
#  'Response': 'True',
#  'Runtime': '147 min',
#  'Title': 'Mission: Impossible - Fallout',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Bruce Geller (based on the television series created by), '
#            'Christopher McQuarrie',
#  'Year': '2018',
#  'imdbID': 'tt4912910',
#  'imdbRating': '7.8',
#  'imdbVotes': '253,475'}
# {'Actors': 'Denzel Washington, Pedro Pascal, Ashton Sanders, Orson Bean',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '11 Dec 2018',
#  'Director': 'Antoine Fuqua',
#  'Genre': 'Action, Crime, Thriller',
#  'Language': 'English, French, Turkish, Hebrew, Arabic, Spanish',
#  'Metascore': '50',
#  'Plot': 'Robert McCall serves an unflinching justice for the exploited and '
#          'oppressed, but how far will he go when that is someone he loves?',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTU2OTYzODQyMF5BMl5BanBnXkFtZTgwNjU3Njk5NTM@._V1_SX300.jpg',
#  'Production': 'Columbia Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.7/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '52%'},
#              {'Source': 'Metacritic', 'Value': '50/100'}],
#  'Released': '20 Jul 2018',
#  'Response': 'True',
#  'Runtime': '121 min',
#  'Title': 'The Equalizer 2',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Richard Wenk, Michael Sloan (based on the television series '
#            'created by), Richard Lindheim (based on the television series '
#            'created by)',
#  'Year': '2018',
#  'imdbID': 'tt3766354',
#  'imdbRating': '6.7',
#  'imdbVotes': '109,586'}
# {'Actors': 'Dwayne Johnson, Naomie Harris, Malin Akerman, Jeffrey Dean Morgan',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '26 Jun 2018',
#  'Director': 'Brad Peyton',
#  'Genre': 'Action, Adventure, Sci-Fi',
#  'Language': 'English, American Sign Language',
#  'Metascore': '45',
#  'Plot': 'When three different animals become infected with a dangerous '
#          'pathogen, a primatologist and a geneticist team up to stop them from '
#          'destroying Chicago.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDA1NjA3ODU3OV5BMl5BanBnXkFtZTgwOTg3MTIwNTM@._V1_SX300.jpg',
#  'Production': 'Warner Bros. Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '51%'},
#              {'Source': 'Metacritic', 'Value': '45/100'}],
#  'Released': '13 Apr 2018',
#  'Response': 'True',
#  'Runtime': '107 min',
#  'Title': 'Rampage',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ryan Engle (screenplay by), Carlton Cuse (screenplay by), Ryan J. '
#            'Condal (screenplay by), Adam Sztykiel (screenplay by), Ryan Engle '
#            '(story by)',
#  'Year': '2018',
#  'imdbID': 'tt2231461',
#  'imdbRating': '6.1',
#  'imdbVotes': '124,258'}
# {'Actors': 'Tom Hardy, Michelle Williams, Riz Ahmed, Scott Haze',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'China, USA',
#  'DVD': '18 Jun 2013',
#  'Director': 'Ruben Fleischer',
#  'Genre': 'Action, Sci-Fi, Thriller',
#  'Language': 'English, Mandarin, Malay',
#  'Metascore': '35',
#  'Plot': 'A failed reporter is bonded to an alien entity, one of many '
#          'symbiotes who have invaded Earth. But the being takes a liking to '
#          'Earth and decides to protect it.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzAwNzUzNjY4MV5BMl5BanBnXkFtZTgwMTQ5MzM0NjM@._V1_SX300.jpg',
#  'Production': 'Vis',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.7/10'},
#              {'Source': 'Metacritic', 'Value': '35/100'}],
#  'Released': '05 Oct 2018',
#  'Response': 'True',
#  'Runtime': '112 min',
#  'Title': 'Venom',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jeff Pinkner (screenplay by), Scott Rosenberg (screenplay by), '
#            'Kelly Marcel (screenplay by), Jeff Pinkner (screen story by), '
#            "Scott Rosenberg (screen story by), Todd McFarlane (Marvel's Venom "
#            "Character created by), David Michelinie (Marvel's Venom Character "
#            'created by)',
#  'Year': '2018',
#  'imdbID': 'tt1270797',
#  'imdbRating': '6.7',
#  'imdbVotes': '314,223'}
# {'Actors': 'Sylvester Stallone, Dave Bautista, Xiaoming Huang, Jesse Metcalfe',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'China, USA',
#  'DVD': '29 Jun 2018',
#  'Director': 'Steven C. Miller',
#  'Genre': 'Action, Crime, Mystery, Sci-Fi, Thriller',
#  'Language': 'English, Chinese, Arabic',
#  'Metascore': 'N/A',
#  'Plot': 'Years after he fought his way out of an inescapable prison, Ray '
#          'Breslin has organized a new top-notch security force. But when one '
#          'of his team members goes missing, Breslin must return to the hell he '
#          'once escaped from.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk4NjA0MjUyMF5BMl5BanBnXkFtZTgwMTEzNDQ1NTM@._V1_SX300.jpg',
#  'Production': 'Summit Entertainment',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.8/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '8%'}],
#  'Released': '29 Jun 2018',
#  'Response': 'True',
#  'Runtime': '96 min',
#  'Title': 'Escape Plan 2: Hades',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Miles Chapman, Miles Chapman (based on characters created by)',
#  'Year': '2018',
#  'imdbID': 'tt6513656',
#  'imdbRating': '3.8',
#  'imdbVotes': '23,562'}
# {'Actors': 'Demián Bichir, Taissa Farmiga, Jonas Bloquet, Bonnie Aarons',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '04 Dec 2018',
#  'Director': 'Corin Hardy',
#  'Genre': 'Horror, Mystery, Thriller',
#  'Language': 'English, French, Romanian, Latin',
#  'Metascore': '46',
#  'Plot': 'A priest with a haunted past and a novice on the threshold of her '
#          'final vows are sent by the Vatican to investigate the death of a '
#          'young nun in Romania and confront a malevolent force in the form of '
#          'a demonic nun.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjM3NzQ5NDcxOF5BMl5BanBnXkFtZTgwNzM4MTQ5NTM@._V1_SX300.jpg',
#  'Production': 'Warner Bros. Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.3/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '26%'},
#              {'Source': 'Metacritic', 'Value': '46/100'}],
#  'Released': '07 Sep 2018',
#  'Response': 'True',
#  'Runtime': '96 min',
#  'Title': 'The Nun',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Gary Dauberman (screenplay by), James Wan (story by), Gary '
#            'Dauberman (story by)',
#  'Year': '2018',
#  'imdbID': 'tt5814060',
#  'imdbRating': '5.3',
#  'imdbVotes': '102,151'}
# {'Actors': "Y'lan Noel, Lex Scott Davis, Joivan Wade, Mugga",
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '18 Sep 2018',
#  'Director': 'Gerard McMurray',
#  'Genre': 'Action, Horror, Sci-Fi, Thriller',
#  'Language': 'English, French, Spanish',
#  'Metascore': '54',
#  'Plot': "America's third political party, the New Founding Fathers of "
#          'America, comes to power and conducts an experiment: no laws for 12 '
#          'hours on Staten Island. No one has to stay on the island, but $5,000 '
#          'is given to anyone who does.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYmVjMWJhMTYtMzUxMC00ODdhLTk3YzMtZDFhNGUyOGFhYTY0XkEyXkFqcGdeQXVyNDIzMzcwNjc@._V1_SX300.jpg',
#  'Production': 'Universal Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '54%'},
#              {'Source': 'Metacritic', 'Value': '54/100'}],
#  'Released': '04 Jul 2018',
#  'Response': 'True',
#  'Runtime': '98 min',
#  'Title': 'The First Purge',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'James DeMonaco',
#  'Year': '2018',
#  'imdbID': 'tt6133466',
#  'imdbRating': '5.1',
#  'imdbVotes': '46,032'}
# {'Actors': 'Michael B. Jordan, Sylvester Stallone, Tessa Thompson, Phylicia '
#            'Rashad',
#  'Awards': '1 win & 12 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '12 Feb 2019',
#  'Director': 'Steven Caple Jr.',
#  'Genre': 'Drama, Sport',
#  'Language': 'English, Russian, Sign Languages',
#  'Metascore': '66',
#  'Plot': 'Under the tutelage of Rocky Balboa, newly crowned heavyweight '
#          'champion Adonis Creed faces off against Viktor Drago, the son of '
#          'Ivan Drago.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTcxMjUwNjQ5N15BMl5BanBnXkFtZTgwNjk4MzI4NjM@._V1_SX300.jpg',
#  'Production': 'MGM',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.2/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '84%'},
#              {'Source': 'Metacritic', 'Value': '66/100'}],
#  'Released': '21 Nov 2018',
#  'Response': 'True',
#  'Runtime': '130 min',
#  'Title': 'Creed II',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Juel Taylor (screenplay by), Sylvester Stallone (screenplay by), '
#            'Sascha Penn (story by), Cheo Hodari Coker (story by), Ryan Coogler '
#            '(characters)',
#  'Year': '2018',
#  'imdbID': 'tt6343314',
#  'imdbRating': '7.2',
#  'imdbVotes': '87,743'}
# {'Actors': 'Lin Shaye, Leigh Whannell, Angus Sampson, Kirk Acevedo',
#  'Awards': '6 nominations.',
#  'BoxOffice': '$29,581,355',
#  'Country': 'Canada, USA',
#  'DVD': '03 Apr 2018',
#  'Director': 'Adam Robitel',
#  'Genre': 'Horror, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': '49',
#  'Plot': 'Parapsychologist Dr. Elise Rainier faces her most fearsome and '
#          'personal haunting yet, as she is drawn back to her ghostly childhood '
#          'home, where the terror began.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjQ3NTgzNjk4MF5BMl5BanBnXkFtZTgwNDE0MTUxNDM@._V1_SX300.jpg',
#  'Production': 'Universal Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.7/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '33%'},
#              {'Source': 'Metacritic', 'Value': '49/100'}],
#  'Released': '05 Jan 2018',
#  'Response': 'True',
#  'Runtime': '103 min',
#  'Title': 'Insidious: The Last Key',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Leigh Whannell, Leigh Whannell (based on characters created by)',
#  'Year': '2018',
#  'imdbID': 'tt5726086',
#  'imdbRating': '5.7',
#  'imdbVotes': '46,257'}
# {'Actors': 'Natalie Portman, Benedict Wong, Sonoya Mizuno, David Gyasi',
#  'Awards': 'N/A',
#  'BoxOffice': '$20,636,742',
#  'Country': 'UK, USA',
#  'DVD': '29 May 2018',
#  'Director': 'Alex Garland',
#  'Genre': 'Adventure, Drama, Horror, Mystery, Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': '79',
#  'Plot': 'A biologist signs up for a dangerous, secret expedition into a '
#          "mysterious zone where the laws of nature don't apply.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk2Mjc2NzYxNl5BMl5BanBnXkFtZTgwMTA2OTA1NDM@._V1_SX300.jpg',
#  'Production': 'Paramount Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.9/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '88%'},
#              {'Source': 'Metacritic', 'Value': '79/100'}],
#  'Released': '23 Feb 2018',
#  'Response': 'True',
#  'Runtime': '115 min',
#  'Title': 'Annihilation',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Alex Garland (written for the screen by), Jeff VanderMeer (based '
#            'on the novel by)',
#  'Year': '2018',
#  'imdbID': 'tt2798920',
#  'imdbRating': '6.9',
#  'imdbVotes': '246,241'}
# {'Actors': 'Benicio Del Toro, Josh Brolin, Isabela Merced, Jeffrey Donovan',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Mexico',
#  'DVD': '18 Sep 2018',
#  'Director': 'Stefano Sollima',
#  'Genre': 'Action, Crime, Drama, Thriller',
#  'Language': 'English, Spanish, American Sign Language, Arabic, Somali',
#  'Metascore': '61',
#  'Plot': 'The drug war on the U.S.-Mexico border has escalated as the cartels '
#          'have begun trafficking terrorists across the US border. To fight the '
#          'war, federal agent Matt Graver re-teams with the mercurial '
#          'Alejandro.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjgyOWRhMDctZTZlNC00M2I1LWI0NDQtYzlmODdmYjY2MThiXkEyXkFqcGdeQXVyMzY0MTE3NzU@._V1_SX300.jpg',
#  'Production': 'Columbia Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '63%'},
#              {'Source': 'Metacritic', 'Value': '61/100'}],
#  'Released': '29 Jun 2018',
#  'Response': 'True',
#  'Runtime': '122 min',
#  'Title': 'Sicario: Day of the Soldado',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Taylor Sheridan',
#  'Year': '2018',
#  'imdbID': 'tt5052474',
#  'imdbRating': '7.1',
#  'imdbVotes': '106,019'}
# {'Actors': 'Amanda Seyfried, Andy Garcia, Celia Imrie, Lily James',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'UK, USA, Japan',
#  'DVD': '09 Oct 2018',
#  'Director': 'Ol Parker',
#  'Genre': 'Comedy, Musical, Romance',
#  'Language': 'English, French, Greek',
#  'Metascore': '60',
#  'Plot': 'Five years after the events of Mamma Mia! (2008), Sophie prepares '
#          'for the grand reopening of the Hotel Bella Donna as she learns more '
#          "about her mother's past.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjEwMTM3OTI1NV5BMl5BanBnXkFtZTgwNDk5NTY0NTM@._V1_SX300.jpg',
#  'Production': 'Universal Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.7/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '80%'},
#              {'Source': 'Metacritic', 'Value': '60/100'}],
#  'Released': '20 Jul 2018',
#  'Response': 'True',
#  'Runtime': '114 min',
#  'Title': 'Mamma Mia! Here We Go Again',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ol Parker, Richard Curtis (story by), Ol Parker (story by), '
#            'Catherine Johnson (story by), Catherine Johnson (based on the '
#            'original musical "Mama Mia!" written by), Judy Craymer (originally '
#            'conceived by), ABBA (based on the songs of)',
#  'Year': '2018',
#  'imdbID': 'tt6911608',
#  'imdbRating': '6.7',
#  'imdbVotes': '66,581'}
# {'Actors': 'Storm Reid, Oprah Winfrey, Reese Witherspoon, Mindy Kaling',
#  'Awards': '4 wins & 14 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '05 Jun 2018',
#  'Director': 'Ava DuVernay',
#  'Genre': 'Adventure, Family, Fantasy, Sci-Fi',
#  'Language': 'English',
#  'Metascore': '53',
#  'Plot': 'After the disappearance of her scientist father, three peculiar '
#          'beings send Meg, her brother, and her friend to space in order to '
#          'find him.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjMxNjQ5MTI3MV5BMl5BanBnXkFtZTgwMjQ2MTAyNDM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.2/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '42%'},
#              {'Source': 'Metacritic', 'Value': '53/100'}],
#  'Released': '09 Mar 2018',
#  'Response': 'True',
#  'Runtime': '109 min',
#  'Title': 'A Wrinkle in Time',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jennifer Lee (screenplay by), Jeff Stockwell (screenplay by), '
#            "Madeleine L'Engle (based upon the novel by)",
#  'Year': '2018',
#  'imdbID': 'tt1620680',
#  'imdbRating': '4.2',
#  'imdbVotes': '37,215'}
# {'Actors': 'Chris Hemsworth, Michael Shannon, Michael Peña, Navid Negahban',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '01 May 2018',
#  'Director': 'Nicolai Fuglsig',
#  'Genre': 'Action, Drama, History, War',
#  'Language': 'English, Dari, Russian, Spanish, Uzbek',
#  'Metascore': '54',
#  'Plot': '12 Strong tells the story of the first Special Forces team deployed '
#          'to Afghanistan after 9/11; under the leadership of a new captain, '
#          'the team must work with an Afghan warlord to take down the Taliban.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTEzMjk3NzkxMV5BMl5BanBnXkFtZTgwNjY2NDczNDM@._V1_SX300.jpg',
#  'Production': 'Warner Bros. Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '51%'},
#              {'Source': 'Metacritic', 'Value': '54/100'}],
#  'Released': '19 Jan 2018',
#  'Response': 'True',
#  'Runtime': '130 min',
#  'Title': '12 Strong',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ted Tally, Peter Craig, Doug Stanton (based on the book,  "Horse '
#            'Soldiers" by)',
#  'Year': '2018',
#  'imdbID': 'tt1413492',
#  'imdbRating': '6.6',
#  'imdbVotes': '54,554'}
# ...
#  'Title': 'The Darkest Minds',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Chad Hodge (screenplay by), Alexandra Bracken (based upon the '
#            'novel by)',
#  'Year': '2018',
#  'imdbID': 'tt4073790',
#  'imdbRating': '5.7',
#  'imdbVotes': '24,568'}
# {'Actors': 'Danny McBride, Rosemarie DeWitt, Lolli Sorenson, Luke Wilson',
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '16 Oct 2018',
#  'Director': 'Jonathan Watson',
#  'Genre': 'Comedy, Thriller',
#  'Language': 'English',
#  'Metascore': '41',
#  'Plot': 'Set in the midst of the 2009 housing crisis, this darkly comedic '
#          'story follows Cassie Fowler, a single mom and struggling realtor '
#          'whose life goes off the rails when she witnesses a murder.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTRkNjQyMWEtN2YwYy00MzVkLWEyMTEtN2Y3MWZiOGFkZWY2XkEyXkFqcGdeQXVyMzQwMTY2Nzk@._V1_SX300.jpg',
#  'Production': 'RLJ Entertainment',
#  'Rated': 'TV-MA',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.7/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '40%'},
#              {'Source': 'Metacritic', 'Value': '41/100'}],
#  'Released': '24 Aug 2018',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': 'Arizona',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Luke Del Tredici',
#  'Year': '2018',
#  'imdbID': 'tt2140629',
#  'imdbRating': '5.7',
#  'imdbVotes': '5,542'}
# {'Actors': 'Lady Gaga, Bradley Cooper, Sam Elliott, Andrew Dice Clay',
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '19 Feb 2019',
#  'Director': 'Bradley Cooper',
#  'Genre': 'Drama, Music, Romance',
#  'Language': 'English',
#  'Metascore': '88',
#  'Plot': 'A musician helps a young singer find fame as age and alcoholism send '
#          'his own career into a downward spiral.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNmE5ZmE3OGItNTdlNC00YmMxLWEzNjctYzAwOGQ5ODg0OTI0XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg',
#  'Production': 'Warner Bros. Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.7/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '90%'},
#              {'Source': 'Metacritic', 'Value': '88/100'}],
#  'Released': '05 Oct 2018',
#  'Response': 'True',
#  'Runtime': '136 min',
#  'Title': 'A Star Is Born',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Eric Roth (screenplay by), Bradley Cooper (screenplay by), Will '
#            'Fetters (screenplay by), Moss Hart (based on the 1954 screenplay '
#            'by), John Gregory Dunne (based on the 1976 screenplay by), Joan '
#            'Didion (based on the 1976 screenplay by), Frank Pierson (based on '
#            'the 1976 screenplay by), William A. Wellman (based on a story by), '
#            'Robert Carson (based on a story by)',
#  'Year': '2018',
#  'imdbID': 'tt1517451',
#  'imdbRating': '7.7',
#  'imdbVotes': '286,900'}
# {'Actors': 'Christian Bale, Cate Blanchett, Benedict Cumberbatch, Naomie '
#            'Harris',
#  'Awards': '7 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'UK, USA',
#  'DVD': '07 Dec 2018',
#  'Director': 'Andy Serkis',
#  'Genre': 'Adventure, Drama, Fantasy',
#  'Language': 'English, Hindi',
#  'Metascore': '51',
#  'Plot': 'A human child raised by wolves must face off against a menacing '
#          'tiger named Shere Khan, as well as his own origins.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjMzODc2NzU5MV5BMl5BanBnXkFtZTgwNTMwMTE3NjM@._V1_SX300.jpg',
#  'Production': 'Netflix',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '52%'},
#              {'Source': 'Metacritic', 'Value': '51/100'}],
#  'Released': '07 Dec 2018',
#  'Response': 'True',
#  'Runtime': '104 min',
#  'Title': 'Mowgli: Legend of the Jungle',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Callie Kloves (screenplay by), Rudyard Kipling (based on the '
#            'stories of)',
#  'Year': '2018',
#  'imdbID': 'tt2388771',
#  'imdbRating': '6.5',
#  'imdbVotes': '49,979'}
# {'Actors': 'Dave Bautista, Pierce Brosnan, Ray Stevenson, Martyn Ford',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'UK',
#  'DVD': '13 Nov 2018',
#  'Director': 'Scott Mann',
#  'Genre': 'Action, Drama, Thriller',
#  'Language': 'English',
#  'Metascore': '53',
#  'Plot': 'After deadly terrorists abduct his niece at a soccer match, an '
#          'ex-soldier with lethal fighting skills wages a one-man war to save '
#          'her and prevent mass destruction.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZGEwODczZjYtZTU2MS00YzQ2LWJjMTUtMjQ4NjEwMTNkYmE4XkEyXkFqcGdeQXVyMzQwMTY2Nzk@._V1_SX300.jpg',
#  'Production': 'Saban Films',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.7/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '69%'},
#              {'Source': 'Metacritic', 'Value': '53/100'}],
#  'Released': '14 Sep 2018',
#  'Response': 'True',
#  'Runtime': '104 min',
#  'Title': 'Final Score',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'David T. Lynch (screenplay by), Keith Lynch (screenplay by), '
#            'Jonathan Frank (screenplay by)',
#  'Year': '2018',
#  'imdbID': 'tt5254610',
#  'imdbRating': '5.7',
#  'imdbVotes': '7,731'}
# {'Actors': 'Daveed Diggs, Rafael Casal, Janina Gavankar, Jasmine Cephas Jones',
#  'Awards': '6 wins & 18 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '20 Nov 2018',
#  'Director': 'Carlos López Estrada',
#  'Genre': 'Comedy, Crime, Drama',
#  'Language': 'English',
#  'Metascore': '77',
#  'Plot': 'While on probation, a man begins to re-evaluate his relationship '
#          'with his volatile best friend.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjgwYTQ4YmEtOTcwYy00NjBlLWI0ZjYtNDM0YmI1OGM0MWY0XkEyXkFqcGdeQXVyMjMxOTE0ODA@._V1_SX300.jpg',
#  'Production': 'Foley Walkers Studio',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.4/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '94%'},
#              {'Source': 'Metacritic', 'Value': '77/100'}],
#  'Released': '27 Jul 2018',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': 'Blindspotting',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Rafael Casal, Daveed Diggs',
#  'Year': '2018',
#  'imdbID': 'tt7242142',
#  'imdbRating': '7.4',
#  'imdbVotes': '20,815'}
# {'Actors': 'Anna Kendrick, Ian Ho, Joshua Satine, Glenda Braganza',
#  'Awards': '1 win & 4 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'Canada, USA',
#  'DVD': '18 Dec 2018',
#  'Director': 'Paul Feig',
#  'Genre': 'Comedy, Crime, Drama, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': '67',
#  'Plot': 'Stephanie is a single mother with a parenting vlog who befriends '
#          'Emily, a secretive upper-class woman who has a child at the same '
#          'elementary school. When Emily goes missing, Stephanie takes it upon '
#          'herself to investigate.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZjFiMGNiNmItMzNiNi00Mjc1LTg1N2YtNWE2NTE5N2VlZTQ3XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg',
#  'Production': 'Lionsgate',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.8/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '85%'},
#              {'Source': 'Metacritic', 'Value': '67/100'}],
#  'Released': '14 Sep 2018',
#  'Response': 'True',
#  'Runtime': '117 min',
#  'Title': 'A Simple Favor',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Darcey Bell (based upon the novel by), Jessica Sharzer (screenplay '
#            'by)',
#  'Year': '2018',
#  'imdbID': 'tt7040874',
#  'imdbRating': '6.8',
#  'imdbVotes': '102,679'}
# {'Actors': 'Oliver Hudson, Kimberly Williams-Paisley, Jesse Gervasi, David '
#            'Kohlsmith',
#  'Awards': '2 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '22 Nov 2018',
#  'Director': 'Clay Kaytis',
#  'Genre': 'Adventure, Comedy, Family, Fantasy',
#  'Language': 'English, Spanish, French, Romanian',
#  'Metascore': '52',
#  'Plot': 'The story of sister and brother, Kate and Teddy Pierce, whose '
#          'Christmas Eve plan to catch Santa Claus on camera turns into an '
#          'unexpected journey that most kids could only dream about.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTA3NjU3OTM2MV5BMl5BanBnXkFtZTgwNjQ2MzE1NjM@._V1_SX300.jpg',
#  'Production': 'Netflix',
#  'Rated': 'TV-PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '64%'},
#              {'Source': 'Metacritic', 'Value': '52/100'}],
#  'Released': '22 Nov 2018',
#  'Response': 'True',
#  'Runtime': '104 min',
#  'Title': 'The Christmas Chronicles',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Matt Lieberman (screenplay by), David Guggenheim (story by), Matt '
#            'Lieberman (story by)',
#  'Year': '2018',
#  'imdbID': 'tt2990140',
#  'imdbRating': '7.1',
#  'imdbVotes': '38,036'}
# {'Actors': 'Sandra Bullock, Trevante Rhodes, John Malkovich, Sarah Paulson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '21 Dec 2018',
#  'Director': 'Susanne Bier',
#  'Genre': 'Drama, Horror, Sci-Fi',
#  'Language': 'English',
#  'Metascore': '51',
#  'Plot': 'Five years after an ominous unseen presence drives most of society '
#          'to suicide, a mother and her two children make a desperate bid to '
#          'reach safety.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjAzMTI1MjMyN15BMl5BanBnXkFtZTgwNzU5MTE2NjM@._V1_SX300.jpg',
#  'Production': 'Netflix',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '63%'},
#              {'Source': 'Metacritic', 'Value': '51/100'}],
#  'Released': '21 Dec 2018',
#  'Response': 'True',
#  'Runtime': '124 min',
#  'Title': 'Bird Box',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Eric Heisserer (screenplay), Josh Malerman (novel)',
#  'Year': '2018',
#  'imdbID': 'tt2737304',
#  'imdbRating': '6.6',
#  'imdbVotes': '239,268'}
# {'Actors': 'Joey King, Paul Scheer, Andrea Savage, Jack Kilmer',
#  'Awards': '2 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Becca Gleason',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'English',
#  'Metascore': '45',
#  'Plot': 'A 16-year-old girl and her extended family are left reeling after '
#          'her calculating grandmother unveils an array of secrets on her '
#          'deathbed.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZjhjYjVmZmYtMzBiNi00OWYxLWEwNjUtNjQ1NWEzOTgxODc4XkEyXkFqcGdeQXVyNzc0MTgzMzU@._V1_SX300.jpg',
#  'Production': 'Blue Fox Entertainment',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '61%'},
#              {'Source': 'Metacritic', 'Value': '45/100'}],
#  'Released': '20 Dec 2018',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': "Summer '03",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Becca Gleason',
#  'Year': '2018',
#  'imdbID': 'tt7284204',
#  'imdbRating': '5.4',
#  'imdbVotes': '1,954'}
# {'Actors': 'Janine Turner, Dean Cain, Michael Beach, Nick Searcy',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Nick Searcy',
#  'Genre': 'Crime, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A movie about the horrific crimes and trial of Kermit Gosnell, '
#          "America's biggest serial killer.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzE1Mjg2MjItNWQ5Yi00Zjk1LThhMDktYWE1YmE3ZDE2YmFmXkEyXkFqcGdeQXVyMTg3MTIzMjk@._V1_SX300.jpg',
#  'Production': 'GVN Releasing',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.7/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '60%'}],
#  'Released': '12 Oct 2018',
#  'Response': 'True',
#  'Runtime': '93 min',
#  'Title': "Gosnell: The Trial of America's Biggest Serial Killer",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Andrew Klavan (screenplay by), Ann McElhinney (screenplay by), '
#            'Phelim McAleer (screenplay by), Andrew Klavan (story by), Phelim '
#            "McAleer (based on the book 'Gosnell' by), Ann McElhinney (based on "
#            "the book 'Gosnell' by)",
#  'Year': '2018',
#  'imdbID': 'tt3722234',
#  'imdbRating': '6.7',
#  'imdbVotes': '3,908'}
# {'Actors': 'Viola Davis, Liam Neeson, Jon Bernthal, Manuel Garcia-Rulfo',
#  'Awards': 'Nominated for 1 BAFTA Film Award. Another 16 wins & 87 '
#            'nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'UK, USA',
#  'DVD': '05 Feb 2019',
#  'Director': 'Steve McQueen',
#  'Genre': 'Crime, Drama, Thriller',
#  'Language': 'English, Spanish, Polish',
#  'Metascore': '84',
#  'Plot': 'Set in contemporary Chicago, amid a time of turmoil, four women with '
#          "nothing in common except a debt left behind by their dead husbands' "
#          'criminal activities, take fate into their own hands, and conspire to '
#          'forge a future on their own terms.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjM3ODc5NDEyOF5BMl5BanBnXkFtZTgwMTI4MDcxNjM@._V1_SX300.jpg',
#  'Production': '20th Century Fox',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.9/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '91%'},
#              {'Source': 'Metacritic', 'Value': '84/100'}],
#  'Released': '16 Nov 2018',
#  'Response': 'True',
#  'Runtime': '129 min',
#  'Title': 'Widows',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Gillian Flynn (screenplay by), Steve McQueen (screenplay by), '
#            'Lynda La Plante (based on "Widows" by)',
#  'Year': '2018',
#  'imdbID': 'tt4218572',
#  'imdbRating': '6.9',
#  'imdbVotes': '74,082'}
# {'Actors': 'Amandeep Singh, Suhail Nayyar, Manoj Mehra, Dinesh Kumar',
#  'Awards': '6 wins & 13 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'Australia, USA, UK, India, Singapore',
#  'DVD': '18 Jun 2019',
#  'Director': 'Anthony Maras',
#  'Genre': 'Drama, History, Thriller',
#  'Language': 'English, Hindi, Punjabi, Marathi, Greek, Russian, Arabic, Urdu, '
#              'Persian',
#  'Metascore': '62',
#  'Plot': 'The true story of the Taj Hotel terrorist attack in Mumbai. Hotel '
#          'staff risk their lives to keep everyone safe as people make '
#          'unthinkable sacrifices to protect themselves and their families.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYTJlZWY2YjYtZGIxMy00MDEwLTliNzMtZGM3MDQ1NzlmNDY1XkEyXkFqcGdeQXVyNDY2MjcyOTQ@._V1_SX300.jpg',
#  'Production': 'Bleecker Street',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '76%'},
#              {'Source': 'Metacritic', 'Value': '62/100'}],
#  'Released': '29 Mar 2019',
#  'Response': 'True',
#  'Runtime': '123 min',
#  'Title': 'Hotel Mumbai',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'John Collee, Anthony Maras',
#  'Year': '2018',
#  'imdbID': 'tt5461944',
#  'imdbRating': '7.6',
#  'imdbVotes': '36,527'}
# {'Actors': 'Constance Wu, Henry Golding, Michelle Yeoh, Gemma Chan',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '20 Nov 2018',
#  'Director': 'Jon M. Chu',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'English, Mandarin, Cantonese, Hokkien, French, Malay',
#  'Metascore': '74',
#  'Plot': 'This contemporary romantic comedy, based on a global bestseller, '
#          'follows native New Yorker Rachel Chu to Singapore to meet her '
#          "boyfriend's family.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTYxNDMyOTAxN15BMl5BanBnXkFtZTgwMDg1ODYzNTM@._V1_SX300.jpg',
#  'Production': 'Warner Bros. Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.9/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '91%'},
#              {'Source': 'Metacritic', 'Value': '74/100'}],
#  'Released': '15 Aug 2018',
#  'Response': 'True',
#  'Runtime': '120 min',
#  'Title': 'Crazy Rich Asians',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Peter Chiarelli (screenplay by), Adele Lim (screenplay by), Kevin '
#            'Kwan (based on the novel "Crazy Rich Asians" by)',
#  'Year': '2018',
#  'imdbID': 'tt3104988',
#  'imdbRating': '6.9',
#  'imdbVotes': '112,471'}

# %%
len(rotten_tomatoes_rating_list)
# Out:
# 103

# %%
data['title'] = title_list
data['box_office'] = box_office_list
data['country'] = country_list
data['genre'] = genre_list
data['director'] = director_list
data['metascore'] = metascore_list
data['production'] = production_list
data['rating'] = rating_list
data['IMDB_rating'] = IMDB_rating_list
data['rotten_tomatoes_rating'] = rotten_tomatoes_rating_list
data['runtime'] = runtime_list
data['type'] = type_list
data['IMDB_votes'] = imdb_votes_list

# %%
#drop any movies that ddo not include USA for country: 1) Australia 2) UK, 3) Canada
data['country'].value_counts()
# Out:
# USA                                        53
# UK, USA                                     8
# China, USA                                  4
# Canada, USA                                 3
# USA, Mexico                                 2
# USA, Australia                              2
# USA, Canada                                 2
# Hong Kong, USA                              2
# USA, South Korea                            1
# UK, China, Japan, USA                       1
# Germany, USA, Canada                        1
# USA, India                                  1
# USA, Canada, India                          1
# UK, USA, India, Canada, France, Belgium     1
# France, USA                                 1
# UK                                          1
# USA, Japan                                  1
# Australia, USA                              1
# USA, New Zealand                            1
# UK, USA, Japan                              1
# Canada                                      1
# Ireland, UK, Hong Kong, Hungary, USA        1
# China, USA, Colombia                        1
# USA, China, France, Norway, UK              1
# USA, UK, France                             1
# Germany, Sweden, USA                        1
# UK, USA, France, Malta                      1
# USA, China                                  1
# Australia, USA, UK, India, Singapore        1
# UK, France, USA, China                      1
# Germany, USA                                1
# USA, UK                                     1
# Australia                                   1
# South Africa, USA                           1
# France, Japan, USA                          1
# Name: country, dtype: int64

# %%
data = data[data.country != 'Australia']
data = data[data.country != 'UK']
data = data[data.country != 'Canada']

# %%
data.to_csv('Resources/2018_movie_data.csv', index=False)
