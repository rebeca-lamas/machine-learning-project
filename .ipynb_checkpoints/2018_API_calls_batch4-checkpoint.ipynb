# %%
import pandas as pd
import requests
import json
import time
from pprint import pprint
from config import API_KEY

# %%
data = pd.read_csv('Resources/title_webscraped/titles_2018_batch4.csv')
df =  data.count()
df
# Out:
# title    879
# dtype: int64

# %%
title_id = []
box_office_list = []
country_list = []
genre_list = []
director_list = []
metascore_list = []
production_list = []
rating_list = []
IMDB_rating_list = [] 
rotten_tomatoes_rating_list = []
runtime_list = []
title_list = []
type_list = []
imdb_votes_list = []

# %%
movies = data['title']
total_movies = len(movies)

# %%
for i in range(total_movies):
    movie = movies[i]
    url = "http://www.omdbapi.com/?i=" + movie + "&apikey=" + API_KEY
    response = (requests.get(url).text)
    response_json = json.loads(response)
    print('-------------------')
    print(f'movie id {movie}')
    print('-------------------')
    pprint(response_json)
    
    try:
        box_office_list.append(response_json['BoxOffice'])
        country_list.append(response_json['Country'])
        genre_list.append(response_json['Genre'])
        director_list.append(response_json['Director'])
        metascore_list.append(response_json['Metascore'])
        production_list.append(response_json['Production'])
        rating_list.append(response_json['Rated'])
        IMDB_rating_list.append(response_json['imdbRating'])
        try:
            if not response_json['Ratings']:
                rotten_tomatoes_rating_list.append('NA')
            elif response_json['Ratings'][0]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][0]['Value'])
            elif response_json['Ratings'][1]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][1]['Value'])
            else:
                rotten_tomatoes_rating_list.append('NA')
        except IndexError:
            rotten_tomatoes_rating_list.append('NA')
        runtime_list.append(response_json['Runtime'])
        title_list.append(response_json['Title'])
        type_list.append(response_json['Type'])
        imdb_votes_list.append(response_json['imdbVotes'])
        title_id.append(response_json['imdbID'])
    except KeyError:
        pass
    time.sleep(1)
# Out:
# -------------------
# movie id tt7549782
# -------------------
# {'Actors': 'George Standing Bear, Ali Currier, Kayli Currier, Maureen Downs',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jamie Sharps',
#  'Genre': 'Comedy, Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A family of vampires moves into a small town and tries to fit in. '
#          "All goes well until Count Beaumont's children start to feed on the "
#          'locals. Vampire hunter Abe recruits average guy Joe to help him '
#          'vanquish the Beaumonts once and for all.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjEyYTNiNDktZWFhMy00YTRjLTlhNDctY2VjZjY0ODFmY2NlXkEyXkFqcGdeQXVyMTM2NTMyNTY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.5/10'}],
#  'Released': '07 Apr 2018',
#  'Response': 'True',
#  'Runtime': '79 min',
#  'Title': 'The Beaumonts',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jamie Sharps',
#  'Year': '2018',
#  'imdbID': 'tt7549782',
#  'imdbRating': '7.5',
#  'imdbVotes': '65'}
# -------------------
# movie id tt9908448
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt8837492
# -------------------
# {'Actors': 'Erik Barnhart Jr., Erik A. Barnhart, Joshua Barnhart, Dan Dressel',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Chris Ramos, Chris Woods',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'After years of protecting our freedoms, Velasquez and Dutch are back '
#          'for one last mission. This time, the fate of the very Agency they '
#          'serve is at stake.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BN2IyNTY4MzMtYjczNi00YzIzLTllN2QtZGViYzlkMGRlMTY0XkEyXkFqcGdeQXVyNzgyMTk5MTU@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Sep 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Best Movie Ever 4ever',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2018',
#  'imdbID': 'tt8837492',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7978752
# -------------------
# {'Actors': 'Sam Brittan, Sharmita Bhattacharya',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Andrew de Burgh',
#  'Genre': 'Drama, Romance, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A suicidal businessman is visited by an inter-dimensional being who '
#          'appears in the form of a beautiful woman.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTBhMjBhNGItZDBhMC00YzAwLThhZjctMmRhYTViNTE1NjZjXkEyXkFqcGdeQXVyMjE2MTkzOTg@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.4/10'}],
#  'Released': '01 Dec 2018',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'The Bestowal',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Andrew de Burgh',
#  'Year': '2018',
#  'imdbID': 'tt7978752',
#  'imdbRating': '7.4',
#  'imdbVotes': '21'}
# -------------------
# movie id tt5090094
# -------------------
# {'Actors': 'Hunter C. Smith, Madeline Johnson, Brian Gilleece, Alexandra '
#            'Johnston',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Arian Harandi',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "When an uptight groom's best friends accidentally hire a hooker for "
#          'his bachelor party they must hide her from his bride and her '
#          'eccentric bridesmaids before the pimp ruins his wedding and any hope '
#          'he has of happily ever after.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Big Day',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Arian Harandi, Austin Sheeley',
#  'Year': '2016',
#  'imdbID': 'tt5090094',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8947544
# -------------------
# {'Actors': 'Cameron Arnett, Brooke Mucci, Jody Mitchell, Elisha McNamara',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Micah Caronna',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYWQ2MzYxNzYtNzJkNC00YjAyLWE0Y2UtYTFhYWQzOTdmYzUzXkEyXkFqcGdeQXVyNzI5MzU0NTg@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Big Fix',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jenn Tobler',
#  'Year': '2018',
#  'imdbID': 'tt8947544',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4847296
# -------------------
# {'Actors': 'Gregg Goldsbury, Braden Bullard, Daniella Mason, Beverly '
#            'Blanchette',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kat Wilson',
#  'Genre': 'Comedy, Mystery',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Detective Dick is a 1940's private investigator who is frozen by a "
#          'mysterious stranger for sixty-nine years. He defrosts in the modern '
#          'world where he has to solve the case that put him on ice.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTU4MzM4OTYxN15BMl5BanBnXkFtZTgwNDcxOTkzNjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Big Frozen Gumshoe',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Josh Brady, Kat Wilson',
#  'Year': '2016',
#  'imdbID': 'tt4847296',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8173868
# -------------------
# {'Actors': 'Batsheba, Stephen Beal, Grace Bosley, Christine Carol',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Steve Oakley',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODFmNGMxOGQtM2YyZC00OTc4LWEwN2EtNDZmYjk0ODcwZmZmXkEyXkFqcGdeQXVyMTU5NzUzMTk@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Jun 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Big Noir',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Steve Oakley',
#  'Year': '2018',
#  'imdbID': 'tt8173868',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2619512
# -------------------
# {'Actors': 'James McCaffrey, Ebon Moss-Bachrach, Zoë Bell, Robert Forster',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '04 Sep 2018',
#  'Director': 'Justin Daly',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Douglas Brown is a movie star who wakes up to find he is being '
#          "blackmailed by someone he doesn't know. He calls his agent Jack "
#          'Girardi who calls Hollywood private detective Frank Manascalpo...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMWJkNWZlMjgtNmZlOC00ZDZlLTk3MzYtZTcxNDNlZmFhZDBlXkEyXkFqcGdeQXVyOTg4MDYyNw@@._V1_SX300.jpg',
#  'Production': 'Archstone Distribution',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'}],
#  'Released': '07 Sep 2018',
#  'Response': 'True',
#  'Runtime': '83 min',
#  'Title': 'The Big Take',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Justin Daly',
#  'Year': '2018',
#  'imdbID': 'tt2619512',
#  'imdbRating': '6.2',
#  'imdbVotes': '1,602'}
# -------------------
# movie id tt6141334
# -------------------
# {'Actors': 'Frankie Muniz, Blake Webb, Chelsea Edmundson, Richard Handley',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Brian Hanson',
#  'Genre': 'Horror, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Jonathan is a lonely twenty-something, stuck in his home town '
#          'working night shifts at the local convenience store. When an '
#          'unexpected encounter with a mysterious woman turns his life '
#          'upside...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMmQ2ZmQ0NzktZTQyNS00MWQ1LWJiYjktY2U3NGFiMWI2N2Y3XkEyXkFqcGdeQXVyOTg4MDYyNw@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.1/10'}],
#  'Released': '25 Oct 2018',
#  'Response': 'True',
#  'Runtime': '93 min',
#  'Title': 'The Black String',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Richard Handley, Brian Hanson, Andy Warrener (story by)',
#  'Year': '2018',
#  'imdbID': 'tt6141334',
#  'imdbRating': '5.1',
#  'imdbVotes': '176'}
# -------------------
# movie id tt9046068
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt8947488
# -------------------
# {'Actors': 'Turner Clay, Terri Czapleski',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Turner Clay',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A filmmaker decides to turn the camera back on and returns to his '
#          'investigation of the Blackwell Ghost in this sequel documentary. '
#          'After being provided with new information from someone who...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZDFkMTU4ZTctMTgzNi00YjY0LThkMTAtMTY0NDNmMjE1NmFhXkEyXkFqcGdeQXVyNjIyMjMwMjU@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.7/10'}],
#  'Released': '04 Aug 2018',
#  'Response': 'True',
#  'Runtime': '68 min',
#  'Title': 'The Blackwell Ghost 2',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2018',
#  'imdbID': 'tt8947488',
#  'imdbRating': '5.7',
#  'imdbVotes': '99'}
# -------------------
# movie id tt7740342
# -------------------
# {'Actors': 'Samantha Marie Cook, Cody Epling, Jason Reynolds, Tamara A. Alba',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jason Hawkins',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'In 1999 a single movie changed the course of the horror genre '
#          'forever. The Blair Witch Project was a brilliant hoax -or was it? A '
#          'documentary film team heads to Burkittsville, Maryland to find out '
#          'the truth behind the Blair Witch Project.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZGUyNDlhODQtZDlhMC00OWMzLWE3YjMtMTBkYmY2M2VhNzBjXkEyXkFqcGdeQXVyMjcxMzM1NzM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Mar 2018',
#  'Response': 'True',
#  'Runtime': '98 min',
#  'Title': 'The Blair Witch Legacy',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jason Hawkins',
#  'Year': '2018',
#  'imdbID': 'tt7740342',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8447824
# -------------------
# {'Actors': 'Sean-Michael Argo, Shey Bland, C. Jason Bolton, Imro Burnett',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ian Argo',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When an ambitious sorcerer summons three eldritch spirits from the '
#          'darkness between the stars and they mistakenly transform into '
#          "vampires straight from the 1980's, it's up to three ...",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZWUxZjE0ZWYtNGE2Yy00ZjhlLWE3ZGQtN2M1NDU3NTBhNjg0XkEyXkFqcGdeQXVyNzQ0MjM4NDM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.9/10'}],
#  'Released': '31 May 2018',
#  'Response': 'True',
#  'Runtime': '77 min',
#  'Title': 'The Bleeding Game',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ian Argo (story), Matt Yeager',
#  'Year': '2018',
#  'imdbID': 'tt8447824',
#  'imdbRating': '2.9',
#  'imdbVotes': '53'}
# -------------------
# movie id tt8809978
# -------------------
# {'Actors': 'Jaron Myers, Reagan Drake',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jaron Myers',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'In this creatively fun show, comedian Jaron Myers asks a girl he has '
#          'never met (Reagan Drake) to be his date to a comedy show. And then '
#          "to her surprise, and also the audiences' surprise, ...",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYzM5OWQwNDItMDkyNC00NDllLWExMjItYTVhYjI4Y2U2NzhmXkEyXkFqcGdeQXVyOTA5NjkxMTg@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '9.6/10'}],
#  'Released': '03 Aug 2018',
#  'Response': 'True',
#  'Runtime': '55 min',
#  'Title': 'The Blind Date',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2018',
#  'imdbID': 'tt8809978',
#  'imdbRating': '9.6',
#  'imdbVotes': '17'}
# -------------------
# movie id tt7374798
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt7491970
# -------------------
# {'Actors': 'Zo Johnson, Jimmy Lee, Troy Pearce, Andrew Sloey',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Steve Wheeler',
#  'Genre': 'Action, Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A Scottish cop is seconded to the LAPD, on an active officer '
#          'exchange program, to help track down a known criminal and bring down '
#          'an international drugs ring. Buddy Cop, Action, comedy.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzA3ZmRlMDMtYWVkMS00M2YzLTgzMDgtYWYwMmQ4MzQ3ZTlhXkEyXkFqcGdeQXVyNzI4MzcyOTc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '09 Mar 2018',
#  'Response': 'True',
#  'Runtime': '87 min',
#  'Title': 'The Blue Exchange',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Amy Pearce',
#  'Year': '2018',
#  'imdbID': 'tt7491970',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7913120
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt6087672
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Andrew Napier',
#  'Genre': 'Comedy',
#  'Language': 'English, Japanese',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Jul 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Untitled Aquatic Wildlife Mockumentary',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Andrew Napier',
#  'Year': '2017',
#  'imdbID': 'tt6087672',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5934474
# -------------------
# {'Actors': 'Eric Roberts, Jaleel White, Fred Willard, Chris Kattan',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Brett Hudson, Tom Wilbeck',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Mockumentary that chronicles the ignorant (fictitious) son of Eric '
#          'Roberts as he attempts to direct an "epic" biopic on the life of '
#          'George Washington.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZGJkZjU1NTMtNjRkNS00NzI0LTg3YWEtMjkyNDkyZDczOTQ1XkEyXkFqcGdeQXVyNjIwODU3ODY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '15 Dec 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Bobby Roberts Project',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tom Wilbeck',
#  'Year': '2017',
#  'imdbID': 'tt5934474',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8525338
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'José Luis R. Cortés',
#  'Genre': 'Musical',
#  'Language': 'Italian',
#  'Metascore': 'N/A',
#  'Plot': 'Maybe love is just not enough.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '115 min',
#  'Title': 'The Bohemians',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2018',
#  'imdbID': 'tt8525338',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5024048
# -------------------
# {'Actors': 'Brittany Sparkles, Clayton Bowman, Christopher Leigh, Matthew R. '
#            'Horton',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Scott McEntire',
#  'Genre': 'Drama, Horror, Thriller',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'The Boo is a Southern-gothic thriller about a bereaved small town '
#          'sheriff and his recently widowed, estranged, sister-in-law who must '
#          'acknowledge the external forces they must extinguish to overcome the '
#          'internal loss of their spouses.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYTQ4YWRlMjAtNzMwZC00YzI5LTgzZWMtOTQxNjYxNjIzNjhhXkEyXkFqcGdeQXVyMjMxNDc1NjA@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.1/10'}],
#  'Released': '01 Mar 2018',
#  'Response': 'True',
#  'Runtime': '88 min',
#  'Title': 'The Boo',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Scott McEntire',
#  'Year': '2018',
#  'imdbID': 'tt5024048',
#  'imdbRating': '4.1',
#  'imdbVotes': '77'}
# -------------------
# movie id tt9805162
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt6427528
# -------------------
# {'Actors': 'Kenichi Iwabuchi, Devon Deshaun Stewart, Iyad Hajjaj, Sonny P. '
#            'Louis',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Sonny P. Louis',
#  'Genre': 'Action, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'After finding a mysterious book, a young man (Dave) suddenly develop '
#          'supernatural abilities. But all Magic comes with a cost. Dave has to '
#          'fight to free his soul from an ultimate reality, where the human '
#          'souls are damned for eternity.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZDk5MzUxMWMtN2QxNi00ZWYxLWExNzktYTFlMjM0YTlhNDJhL2ltYWdlXkEyXkFqcGdeQXVyNTAyNzMxOTM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Book of the Damned',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Sonny P. Louis',
#  'Year': '2018',
#  'imdbID': 'tt6427528',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3209242
# -------------------
# {'Actors': 'Antonio Mayans, Crispian Belfrage, Aaron Stielstra, Russell Quinn '
#            'Cummings',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'Spain',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'Action, Western',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Armed with his Colt and Bible, a former preacher known as The '
#          'Reverend hunts down outlaws in the wild frontier using his faith and '
#          'brutality. But this time, he faces his archenemy... the ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg0NzYxMTc1NV5BMl5BanBnXkFtZTgwMDA1NjAzMTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '24 Dec 2016',
#  'Response': 'True',
#  'Runtime': '79 min',
#  'Title': 'Reverend Colt',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Chip Baker (story), Danny Garcia (screenplay), Jose L. Villanueva '
#            '(screenplay)',
#  'Year': '2016',
#  'imdbID': 'tt3209242',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6241390
# -------------------
# {'Actors': 'Joey King, J.K. Simmons, Dane DeHaan, Martin Sheen',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Anna Chi, Daniel Chuba, Mark A.Z. Dippé, Wonjae Lee',
#  'Genre': 'Animation',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The continuing adventures of Henry, Jessie, Violet, and Benny as '
#          "they spend the summer on their grandfather's private island.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDQ3NjkyMWItYTkyZS00ZDY2LWI3M2QtMWY4Yjc3YzEzY2NiXkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.7/10'}],
#  'Released': '08 May 2018',
#  'Response': 'True',
#  'Runtime': '81 min',
#  'Title': 'The Boxcar Children - Surprise Island',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Daniel Chuba',
#  'Year': '2018',
#  'imdbID': 'tt6241390',
#  'imdbRating': '5.7',
#  'imdbVotes': '86'}
# -------------------
# movie id tt9116546
# -------------------
# {'Actors': 'Jon Wesley Hopkins, Tom Oldcroft, Steve Marino, Dan Mers',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Dan Steadman',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Writer/director Dan Steadman got his start on public access TV in '
#          '1988. This is the partially true mockumentary that recalls his time '
#          'as a TV clown in West Michigan on "Danny The Clown Show."',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYzk1MGMwYjAtOTY0Yi00ZWRiLTllNDMtMTczMDc4ZjJiZjE3XkEyXkFqcGdeQXVyMzM4MDkwNTg@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '06 Oct 2018',
#  'Response': 'True',
#  'Runtime': '88 min',
#  'Title': 'The Boy With The Nose',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dan Steadman',
#  'Year': '2018',
#  'imdbID': 'tt9116546',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8593814
# -------------------
# {'Actors': 'Carleigh Bettiol, Mary Callanan, Joe Carroll, Max Clayton',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Lorenzo Thione, Matt Hoffman',
#  'Genre': 'Musical',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': '1945: The boys are back. With American soldiers returning home, '
#          'singer-songwriter Private First Class Donny Novitski dreams of '
#          'rebuilding his life, forgetting his demons, and for everything...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODljM2Q2OTgtYzNiYi00NWRmLTlkZWUtNDQ4ZDBlMjAwMWI1XkEyXkFqcGdeQXVyNDU2MDAyNTU@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '9.2/10'}],
#  'Released': '25 Jun 2018',
#  'Response': 'True',
#  'Runtime': '130 min',
#  'Title': 'The Boys Are Back - Bandstand: The Broadway Musical',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Greg Anthony Rassen (Music Supervisior), Robert Taylor (book)',
#  'Year': '2018',
#  'imdbID': 'tt8593814',
#  'imdbRating': '9.2',
#  'imdbVotes': '22'}
# -------------------
# movie id tt8151344
# -------------------
# {'Actors': 'Erik Cram, Mandy Dollar, Dante Dumas, Cean Houston',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Bart Cameron',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjdlNTRmYWQtMzkxOS00Yzk2LTkwNmMtZDdkMjJlODk5NjAyXkEyXkFqcGdeQXVyMjIwMTUxMzk@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '16 Mar 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Branch Report',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Lawrence A. Herbert, Brandon Montoya, Phil Roberts',
#  'Year': '2018',
#  'imdbID': 'tt8151344',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7989520
# -------------------
# {'Actors': 'Shelby Minogue, Ali Martin, Alecia Hickman, Kassie Puckett',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jesse Carter, Shelby Minogue',
#  'Genre': 'Drama, Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': '10 years ago, a girl was abducted and forced to watch heinous acts. '
#          'Now, the crimes starts over again when a group of young adults '
#          'descend to the crime scene from years ago. Their signature? A '
#          'branded "X" on the wrist of their victims.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYTI0YWJjMjItZjc1MC00N2JkLWEzYmUtNzAxZWQ2YTIxMTVjXkEyXkFqcGdeQXVyNjA1OTYxNTA@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.2/10'}],
#  'Released': '09 Oct 2018',
#  'Response': 'True',
#  'Runtime': '99 min',
#  'Title': 'The Branded: Initiation',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jesse Carter, Cody Powers',
#  'Year': '2018',
#  'imdbID': 'tt7989520',
#  'imdbRating': '7.2',
#  'imdbVotes': '6'}
# -------------------
# movie id tt5471472
# -------------------
# {'Actors': 'Zach McGowan, Amy Smart, Joe Pantoliano, Taryn Manning',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '18 Jan 2019',
#  'Director': 'Ken Kushner',
#  'Genre': 'Biography, Crime, Drama, History, Romance, Sport',
#  'Language': 'English',
#  'Metascore': '46',
#  'Plot': 'In 1975, a Bayonne, New Jersey underdog boxer gets a shot to fight '
#          'the champ.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOGU1MDg0NTYtM2RlMy00ODFlLWE4YmMtODA5YWU0ZTA5NjRmXkEyXkFqcGdeQXVyMjMwMDI5Ng@@._V1_SX300.jpg',
#  'Production': 'Vertical Entertainment',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.7/10'},
#              {'Source': 'Metacritic', 'Value': '46/100'}],
#  'Released': '18 Jan 2019',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': 'The Brawler',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Robert Dibella (screenplay), Ken Kushner (screenplay), Ken Kushner '
#            '(story by)',
#  'Year': '2018',
#  'imdbID': 'tt5471472',
#  'imdbRating': '4.7',
#  'imdbVotes': '318'}
# -------------------
# movie id tt7390090
# -------------------
# {'Actors': 'Marcus Bellamy, Patrick Kuzara, Joe MacDougal, David J. Cork',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Daniel Armando',
#  'Genre': 'Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An erotic thriller about a young artist whose obsession with a taboo '
#          'fetish leads to life altering consequences.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZGEzYjRkMDYtZTRkZi00NGRmLWFiMGUtOTc5MDAzOTZmMWI4XkEyXkFqcGdeQXVyMTk5OTE1MDI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.0/10'}],
#  'Released': '11 Sep 2018',
#  'Response': 'True',
#  'Runtime': '83 min',
#  'Title': 'The Breeding',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dane Harrington Joseph',
#  'Year': '2018',
#  'imdbID': 'tt7390090',
#  'imdbRating': '5.0',
#  'imdbVotes': '37'}
# -------------------
# movie id tt9792940
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt6670116
# -------------------
# {'Actors': 'Jeff Lipary, Renee Moncada-McElroy, Monee Brehaut, Johnny Gilligan',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Matt McClelland',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Rose is a young girl who has grown up in foster care. Desperate to '
#          'escape an abusive situation, she is saved by an older man named '
#          'Shaka, but at what price?',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOWViMGRmZTYtZmIwOC00NmEyLWI0YTEtYzk3MTQ3MDhjNTc1XkEyXkFqcGdeQXVyNTI4NjQzNDQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Broken Rose',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tyrone Dangerfield, William Uschold',
#  'Year': '2018',
#  'imdbID': 'tt6670116',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7304212
# -------------------
# {'Actors': 'Jeff Feringa, Cal Gibson, Jane Casserly, Maria Olsen',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Michael K. Feinstein',
#  'Genre': 'Comedy, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The seemingly endless possibilities of dating apps send a group of '
#          'friends into a whirlwind of sex, jealousy, and self-doubt in this '
#          'ensemble comedy that examines dating culture in the age of swiping.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BN2JmZjAyZTQtNmIwMi00MzhlLWFlMDQtZTk4ODk2OTI2YWE2XkEyXkFqcGdeQXVyMzQwMTY2Nzk@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.5/10'}],
#  'Released': '09 Apr 2019',
#  'Response': 'True',
#  'Runtime': '100 min',
#  'Title': 'The Browsing Effect',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael K. Feinstein',
#  'Year': '2018',
#  'imdbID': 'tt7304212',
#  'imdbRating': '4.5',
#  'imdbVotes': '101'}
# -------------------
# movie id tt8633834
# -------------------
# {'Actors': 'Parker Jones, Chad Platt, Micah Jaeger, Michael Potter',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Riley Rutter',
#  'Genre': 'Adventure, Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Ralph Andersen urges his friend group to do everything on their '
#          'Bucket List after finding out the end of the world was tomorrow. '
#          "However, things don't go as planned.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzA5NjU3ODgtYmU3ZS00NWU2LTk3Y2EtNGVhNWQ4MzNlZjIwXkEyXkFqcGdeQXVyNjA1NzU2OTI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '29 Jul 2018',
#  'Response': 'True',
#  'Runtime': '60 min',
#  'Title': 'The Bucket List',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Riley Rutter',
#  'Year': '2018',
#  'imdbID': 'tt8633834',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7383678
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt8865220
# -------------------
# {'Actors': 'Adam Weber, Oscar Benjamin, Michael Scordakis, Sherill J Snyder',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Leo Omar, Michael Scordakis',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '20 Nov 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Bullet Chronicles Lands End',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Scordakis',
#  'Year': '2018',
#  'imdbID': 'tt8865220',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7497366
# -------------------
# {'Actors': 'Ama K. Abebrese, Joe Addo, Henry Adofo, Kobina Amissah-Sam',
#  'Awards': '1 win & 1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'Ghana, USA',
#  'DVD': 'N/A',
#  'Director': 'Blitz Bazawule',
#  'Genre': 'Drama, Thriller',
#  'Language': 'Akan, English',
#  'Metascore': '93',
#  'Plot': 'A man is trapped in a mine shaft by his vengeful brother while his '
#          'daughter embarks on a magical journey to rescue him.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZGNlYTEyZmMtYWUzZC00MzIwLTliYjYtZmQyN2UyYzNkMzVjXkEyXkFqcGdeQXVyNzI5MjEwMTc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'},
#              {'Source': 'Metacritic', 'Value': '93/100'}],
#  'Released': '29 Mar 2019',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'The Burial of Kojo',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Blitz Bazawule',
#  'Year': '2018',
#  'imdbID': 'tt7497366',
#  'imdbRating': '6.3',
#  'imdbVotes': '369'}
# -------------------
# movie id tt8502616
# -------------------
# {'Actors': 'Goria Cunningham',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'Animation',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Its a story about a man in food service and him learning the views '
#          'of other people in the food service indusry and how it is',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYmUzYzhkMGUtYWM0Mi00NTZjLTllNGItNjIxM2UyNzdiYjIzXkEyXkFqcGdeQXVyNzcxMDUxODc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Business of Food Service',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Goria Cunningham',
#  'Year': '2018',
#  'imdbID': 'tt8502616',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5963066
# -------------------
# {'Actors': 'Christopher Lee Page, Caitlin Crommett, Erik Kammerland, Thomas '
#            'Hedengran',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Sweden',
#  'DVD': 'N/A',
#  'Director': 'Johan Bodell',
#  'Genre': 'Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A young couple visit a remote cabin in the woods but on the way meet '
#          'a suspicious stranger who holds a murderous secret.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMWIyZGFiM2UtNTgxZi00NDYwLTkwODQtYjdiODU4MDM5NzgwXkEyXkFqcGdeQXVyMzg0MzA2Nzc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.0/10'}],
#  'Released': '04 Dec 2018',
#  'Response': 'True',
#  'Runtime': '86 min',
#  'Title': 'The Cabin',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Erik Kammerland',
#  'Year': '2018',
#  'imdbID': 'tt5963066',
#  'imdbRating': '3.0',
#  'imdbVotes': '324'}
# -------------------
# movie id tt8619682
# -------------------
# {'Actors': 'Courtney B Turk, Brett Zimmerman, Time Winters, Cameron Tagge',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Chadwick Hopson',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An Interactive Virtual Reality film. A group of childhood friends '
#          'barricade themselves in a strangers cabin while escaping a killer. '
#          'During the course of the night, it seems a more elaborate plot is at '
#          'play.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYWNhZGE2Y2UtODVhMi00MTU2LTk3ZWUtNWFkNDRlMWY1OTIxXkEyXkFqcGdeQXVyMjQ0NDUwODc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Cabin Stay',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Brian Flaccus, Chadwick Hopson, Jeffrey Larson',
#  'Year': '2018',
#  'imdbID': 'tt8619682',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5441464
# -------------------
# {'Actors': 'Noah Segan, Jordan Hinson, Ursula Mills, Jesse Bradford',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '04 Dec 2018',
#  'Director': 'Ned Ehrbar',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "A man finds out he's in an open marriage.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZmI5MWVjZDEtMDQxZi00NTk3LWFhMGQtZGQ3Yzg0NGU4NzdmXkEyXkFqcGdeQXVyMTY2NzQ5MDQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.1/10'}],
#  'Released': '10 Feb 2018',
#  'Response': 'True',
#  'Runtime': '84 min',
#  'Title': 'California No',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ned Ehrbar',
#  'Year': '2018',
#  'imdbID': 'tt5441464',
#  'imdbRating': '4.1',
#  'imdbVotes': '158'}
# -------------------
# movie id tt8716236
# -------------------
# {'Actors': 'Joshua Marble, Belle Adams, Karenssa LeGear, Marco Kengott',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Rich Varville',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "It's 1989 and Miles Bodzin, a young college-aged man about to "
#          'graduate is frustrated with the direction of his life, drops out to '
#          'go after his newly discovered calling in life. The true ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZWNkMTU2YzUtZWRiZi00ZTk1LWI1MmUtYzJhMWE3YmI5MzNlXkEyXkFqcGdeQXVyNTg5NTA1NTA@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.4/10'}],
#  'Released': '08 Nov 2018',
#  'Response': 'True',
#  'Runtime': '46 min',
#  'Title': 'The Calling',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Miles Bodzin, Rich Varville',
#  'Year': '2018',
#  'imdbID': 'tt8716236',
#  'imdbRating': '6.4',
#  'imdbVotes': '5'}
# -------------------
# movie id tt7948108
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt6772946
# -------------------
# {'Actors': 'Rachel Amanda Bryant, Brit Sheridan, Scott Menville, Mohamed '
#            'Hakeemshady',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'J. Horton',
#  'Genre': 'Fantasy, Horror, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Robert Wainwright dies after breaking his deal with the Devil, '
#          'passing that debt onto his estranged daughter Morgan. She soon finds '
#          'herself in a never-ending cycle of terror as she is ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYTE4NjU3MzctNzNiNy00YzkzLWIwNmQtYTQ5NWNmMTNlZDdhXkEyXkFqcGdeQXVyODc2MjA4Mg@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'TV-MA',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.5/10'}],
#  'Released': '01 Feb 2018',
#  'Response': 'True',
#  'Runtime': '84 min',
#  'Title': 'The Campus',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'J. Horton',
#  'Year': '2018',
#  'imdbID': 'tt6772946',
#  'imdbRating': '5.5',
#  'imdbVotes': '1,164'}
# -------------------
# movie id tt4602066
# -------------------
# {'Actors': 'Paul Rudd, Pierfrancesco Favino, Tom Wilkinson, Connie Nielsen',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '02 Oct 2018',
#  'Director': 'Ben Lewin',
#  'Genre': 'Biography, Drama, War',
#  'Language': 'English',
#  'Metascore': '49',
#  'Plot': 'A major league baseball player, Moe Berg, lives a double life '
#          'working for the Office of Strategic Services.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODhlNDc0ZTQtN2FiOS00OGRiLWE2YmYtZmI2ZmU1NzM5MmJlXkEyXkFqcGdeQXVyODY3Nzc0OTk@._V1_SX300.jpg',
#  'Production': 'IFC Films',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '32%'},
#              {'Source': 'Metacritic', 'Value': '49/100'}],
#  'Released': '22 Jun 2018',
#  'Response': 'True',
#  'Runtime': '98 min',
#  'Title': 'The Catcher Was a Spy',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Robert Rodat, Nicholas Dawidoff (based upon the book: Catcher Was '
#            'a Spy: The Mysterious Life of Moe Berg by)',
#  'Year': '2018',
#  'imdbID': 'tt4602066',
#  'imdbRating': '6.2',
#  'imdbVotes': '5,746'}
# -------------------
# movie id tt2690226
# -------------------
# {'Actors': 'Elizabeth McGovern, Haley Lu Richardson, Géza Röhrig, Victoria '
#            'Hill',
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'UK, Australia, USA',
#  'DVD': 'N/A',
#  'Director': 'Michael Engler',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': '48',
#  'Plot': 'In the early 1920s, a Kansas woman finds her life forever changed '
#          'when she accompanies a young dancer on her fame-seeking journey to '
#          'New York City.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjM2NDM1NDY4Ml5BMl5BanBnXkFtZTgwMDc3MzA0NzM@._V1_SX300.jpg',
#  'Production': 'PBS Distribution',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '44%'},
#              {'Source': 'Metacritic', 'Value': '48/100'}],
#  'Released': '29 Mar 2019',
#  'Response': 'True',
#  'Runtime': '103 min',
#  'Title': 'The Chaperone',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Julian Fellowes (screenplay by), Laura Moriarty (based on the book '
#            'by)',
#  'Year': '2018',
#  'imdbID': 'tt2690226',
#  'imdbRating': '6.5',
#  'imdbVotes': '763'}
# -------------------
# movie id tt7423450
# -------------------
# {'Actors': 'Megumi Kabe, Ami Shimada, Schafer Bourne, Kathy M. Freeman Johnson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Carlos R. Valencia',
#  'Genre': 'Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Two Japanese sisters come to Los Angeles for the first time, during '
#          'their travels they are invited to a Chicken Party, a place to make '
#          'international friends. At first the party is nice and ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTE5MzA3N2QtNTJkNC00Nzk1LWEyMmYtOWYyNTk0MmRjYjEyXkEyXkFqcGdeQXVyMTkzODM2MzQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '18 Apr 2018',
#  'Response': 'True',
#  'Runtime': '103 min',
#  'Title': 'The Chicken Party',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Carlos R. Valencia',
#  'Year': '2018',
#  'imdbID': 'tt7423450',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3729980
# -------------------
# {'Actors': 'Darrin Dewitt Henson, Christian Keyes, Clifton Powell, Valarie '
#            'Pettiford',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Trey Haley',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Bishop T.K. Wilson has done all he can to make First Jamaica '
#          'Ministries a success, but after his first choir director is caught '
#          'in a scandal, attendance and cash flow are down. The Bishop is '
#          'counting on a new choir director to revive the church. Little does '
#          'he know, this decision may also put his job as the Bishop, as well '
#          'as his family, in jeopardy.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '26 Aug 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Choir Director',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2016',
#  'imdbID': 'tt3729980',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2990140
# -------------------
# {'Actors': 'Oliver Hudson, Kimberly Williams-Paisley, Jesse Gervasi, David '
#            'Kohlsmith',
#  'Awards': '2 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '22 Nov 2018',
#  'Director': 'Clay Kaytis',
#  'Genre': 'Adventure, Comedy, Family, Fantasy',
#  'Language': 'English, Spanish, French, Romanian',
#  'Metascore': '52',
#  'Plot': 'The story of sister and brother, Kate and Teddy Pierce, whose '
#          'Christmas Eve plan to catch Santa Claus on camera turns into an '
#          'unexpected journey that most kids could only dream about.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTA3NjU3OTM2MV5BMl5BanBnXkFtZTgwNjQ2MzE1NjM@._V1_SX300.jpg',
#  'Production': 'Netflix',
#  'Rated': 'TV-PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '64%'},
#              {'Source': 'Metacritic', 'Value': '52/100'}],
#  'Released': '22 Nov 2018',
#  'Response': 'True',
#  'Runtime': '104 min',
#  'Title': 'The Christmas Chronicles',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Matt Lieberman (screenplay by), David Guggenheim (story by), Matt '
#            'Lieberman (story by)',
#  'Year': '2018',
#  'imdbID': 'tt2990140',
#  'imdbRating': '7.1',
#  'imdbVotes': '38,036'}
# -------------------
# movie id tt2482856
# -------------------
# {'Actors': 'Clint Howard, Bill Moseley, Lisa Wilcox, Ashley C. Williams',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Dom Frank',
#  'Genre': 'Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The pastor of a landmark church is the sole hold-out in a '
#          'Philadelphia neighborhood earmarked for gentrification. But soon, '
#          'the spirits of congregational members past begin to make their '
#          'displeasure known. Who are the righteous among them?',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMmQ3MTFmZGUtZjExZi00ZTk1LWExMzctYzJhZGQ5Yjg4NDc5XkEyXkFqcGdeQXVyMTQ2OTU2OTQ@._V1_SX300.jpg',
#  'Production': 'Indican Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.9/10'}],
#  'Released': '09 Jul 2019',
#  'Response': 'True',
#  'Runtime': '81 min',
#  'Title': 'The Church',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dom Frank, Dom Frank',
#  'Year': '2018',
#  'imdbID': 'tt2482856',
#  'imdbRating': '3.9',
#  'imdbVotes': '86'}
# -------------------
# movie id tt10427768
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt4113346
# -------------------
# {'Actors': 'Vernon Wells, Christopher Atkins, Branscombe Richmond, John '
#            'Charles Meyer',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Harry Locke IV',
#  'Genre': 'Action, Adventure, Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An anguished media magnate, Jonathan Davenport, accompanies his '
#          'estranged lover to the Peruvian Amazon in pursuit of a reclusive '
#          'artist living in rebel occupation. Despite their philanthropic '
#          'intentions, the mission proves to be the harbinger of something dark '
#          'and ominous rooted deep within Jonathan.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ2YmE5NTUtYjU4ZS00OTQ0LWFmNGYtYzE0N2Y4NzA4ZDQxXkEyXkFqcGdeQXVyMjc4MjEwNzY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.3/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '99 min',
#  'Title': 'The City of Gold',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ronald A. Blum',
#  'Year': '2018',
#  'imdbID': 'tt4113346',
#  'imdbRating': '3.3',
#  'imdbVotes': '145'}
# -------------------
# movie id tt8256306
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jon Silver',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Historical deniers, conspiracy theorists, and other idiots serve up '
#          'interviews and meet to discuss their mission to spread rumors, '
#          'denial, and alternative facts about the U.S. Civil War.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYWE4YWI3YTUtYmU1OC00OTFhLThiYzEtZGFmNDA0ODIwM2QwXkEyXkFqcGdeQXVyNzQ3MjI4NjQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '05 May 2018',
#  'Response': 'True',
#  'Runtime': '52 min',
#  'Title': 'The Civil Hoax: Civil War Deniers',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joseph Gartner, Jon Silver',
#  'Year': '2018',
#  'imdbID': 'tt8256306',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8615108
# -------------------
# {'Actors': 'Ben Escobar, Azara Seek, Kolbe Boudreaux, Sophia Vega',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ben Escobar',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A film about graduating college students, made by actual graduating '
#          'college students, "The Class of 2018 B.C." blurs the line between '
#          'narrative and documentary as an indie drama that ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYjJlMjY5YWEtNDNhZi00NjQ1LTg2OWMtMzJlNjRkMmU2NGQ0XkEyXkFqcGdeQXVyNjgzMjI2NjQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Class of 2018 B.C.',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ben Escobar',
#  'Year': '2018',
#  'imdbID': 'tt8615108',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7044076
# -------------------
# {'Actors': 'Alexis Kendra, Stelio Savante, Rachel Alig, Elizabeth Sandy',
#  'Awards': '2 wins.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jon Knautz',
#  'Genre': 'Horror, Thriller',
# ...
#  'Year': '2018',
#  'imdbID': 'tt7339762',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8889718
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt8011654
# -------------------
# {'Actors': 'W. Keith Scott, Kazarr',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kazarr',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjMwZjk5Y2MtNjkxZC00NjI4LTllNmEtN2ZlMjliODlkNWI4XkEyXkFqcGdeQXVyMjMzNTExMDM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '14 Sep 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'ZEKE',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kazarr',
#  'Year': '2018',
#  'imdbID': 'tt8011654',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7054386
# -------------------
# {'Actors': 'Darin Ferraro, Scott Engrotti, Vincent Rivera, Wilfred Lopez',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tim Newhouse',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZTg0Zjk2ZjAtN2ViMS00NWNlLWJlMzQtNjIwNzEwMjQzNDk1XkEyXkFqcGdeQXVyMjczMjc2MzQ@._V1_SX300.jpg',
#  'Production': 'Yash Raj Films USA Inc.',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Rotten Tomatoes', 'Value': '31%'}],
#  'Released': '31 Dec 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Zero',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tim Newhouse, John Nickol, Vincent Rivera',
#  'Year': '2018',
#  'imdbID': 'tt7054386',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7143770
# -------------------
# {'Actors': 'Shea Madison, Lindsay Ashcroft, Lyndsey Wurch, Jack Sharkey',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Colon Foxworth',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Daphne Rhodes is a down-on-her-luck California girl just off the bus '
#          'in a Midwestern city is starting completely over. She has no friends '
#          'there and dim prospects until she meets Rex English...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMmQ3NWU5NjQtNWViYy00ZTEyLTk1NGEtZjY0YjU2NTMwMWI4XkEyXkFqcGdeQXVyMjc4Mzk4MTM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '23 Feb 2018',
#  'Response': 'True',
#  'Runtime': '120 min',
#  'Title': 'Zero Absolution',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Colon Foxworth',
#  'Year': '2018',
#  'imdbID': 'tt7143770',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7954100
# -------------------
# {'Actors': 'Maralynn Adams, Michael Fredianelli, Michael Nosé, Brian Marquez',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Michael Fredianelli',
#  'Genre': 'Action, Comedy, Fantasy, Music',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'In an altered reality, a group of characters try to gain control of '
#          'their own actions from their vengeful writer.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BM2FiYWM1YWItNzZkMy00YTcyLTljYjktYTUxNjk4NjVhM2RiXkEyXkFqcGdeQXVyMDY0NjA1MA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'}],
#  'Released': '05 Mar 2018',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Zero to Heaven',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Fredianelli',
#  'Year': '2018',
#  'imdbID': 'tt7954100',
#  'imdbRating': '6.5',
#  'imdbVotes': '10'}
# -------------------
# movie id tt10980016
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt6010628
# -------------------
# {'Actors': 'Ewan McGregor, Léa Seydoux, Theo James, Rashida Jones',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '20 Jul 2018',
#  'Director': 'Drake Doremus',
#  'Genre': 'Romance, Sci-Fi',
#  'Language': 'English',
#  'Metascore': '39',
#  'Plot': 'A story about how synthetic humans can feel and even love and how '
#          'the people they are involved with react to this concept.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTA5Nzg2MjEzNjleQTJeQWpwZ15BbWU4MDk2MTE2NzUz._V1_SX300.jpg',
#  'Production': 'Amazon Studios',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '32%'},
#              {'Source': 'Metacritic', 'Value': '39/100'}],
#  'Released': '20 Jul 2018',
#  'Response': 'True',
#  'Runtime': '104 min',
#  'Title': 'Zoe',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Richard Greenberg (screenplay by), Richard Greenberg (story by), '
#            'Drake Doremus (story by)',
#  'Year': '2018',
#  'imdbID': 'tt6010628',
#  'imdbRating': '6.1',
#  'imdbVotes': '6,264'}
# -------------------
# movie id tt7792746
# -------------------
# {'Actors': 'Stanley Alcime, Paul Antoine, Preston Antoine, James Ashworth',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Blademil Grullon',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Mr. Jean a security guard is dealing financial issues. Issues if not '
#          'dealt with will cause him to lose more than just his family. During '
#          'his lunch break, he meets Chelo an immigrant that ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZmE0NWU4YjUtMDQ2YS00ZDc4LTlhNjEtMzg2OGVlOWRiZjM0XkEyXkFqcGdeQXVyNjQ3MTg4NjQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Jun 2018',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Zoe911',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Paul Antoine',
#  'Year': '2018',
#  'imdbID': 'tt7792746',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8016004
# -------------------
# {'Actors': 'Carmen Anello, Matt Briden, Cisco Carmargo, Daniel Gilchrist',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Gary Piland',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'In the future there will be beautiful girls, strong men and - '
#          'ZOMBIES. What could possibly go wrong?',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOWU2MTRmMjAtOGM0NS00ZTM3LTlhMTktYTU0M2VjNjM5YWEyXkEyXkFqcGdeQXVyODAwMzc3NzY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'}],
#  'Released': '02 Feb 2018',
#  'Response': 'True',
#  'Runtime': '82 min',
#  'Title': 'Zombie Beauty Pageant: Drop Dead Gorgeous',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Gary Piland',
#  'Year': '2018',
#  'imdbID': 'tt8016004',
#  'imdbRating': '6.2',
#  'imdbVotes': '6'}
# -------------------
# movie id tt7256326
# -------------------
# {'Actors': 'Michelle Lang, Danielle Petty, Angelica Sin, Mike Dusi',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '75 min',
#  'Title': 'Zombie TV',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Micheal Cuomo',
#  'Year': '2018',
#  'imdbID': 'tt7256326',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7575400
# -------------------
# {'Actors': 'Gilly Conklin, Tracey Coppedge, Edgar Coronel, Leanne Curran',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Fernando González Gómez, Christopher G. Moore, Aaron McCann, '
#              'Stefan Androv Radanovich',
#  'Genre': 'Comedy, Horror',
#  'Language': 'English, Italian',
#  'Metascore': 'N/A',
#  'Plot': "Zombies are back in this highly anticipated sequel to 2015's popular "
#          'Zombieworld. In the wake of a terrible virus that claimed most of '
#          'the human population, zombies have risen.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjQyNmFlZGMtZjRkZi00ZWEyLWIwY2QtMmY0MjkxYjFkNzlkXkEyXkFqcGdeQXVyMjM3NDgxNw@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.7/10'}],
#  'Released': '17 Oct 2018',
#  'Response': 'True',
#  'Runtime': '83 min',
#  'Title': 'Zombie World 2',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Eryk Pruitt, Evan Tramel',
#  'Year': '2018',
#  'imdbID': 'tt7575400',
#  'imdbRating': '2.7',
#  'imdbVotes': '58'}
# -------------------
# movie id tt5821764
# -------------------
# {'Actors': 'J. Michael Trautmann, Nichole McAuley, Melissa Jane Rodriguez, '
#            'Erin Áine Smith',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kyle Valle',
#  'Genre': 'Action',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'ZombieCON',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Manny Luke, Kyle Valle',
#  'Year': '2016',
#  'imdbID': 'tt5821764',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3211248
# -------------------
# {'Actors': 'MYC Agnew, Kirra Klein, Julian DeWitt, Kimberly Nordstrom',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ray Klein',
#  'Genre': 'Action, Comedy, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Can an ordinary man with unlimited ammo, stop an extraordinary '
#          'madman with a zombie army?',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg2ODM4OTkxOV5BMl5BanBnXkFtZTgwMjkwOTgwMTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '86 min',
#  'Title': 'Zombieapocalyptica',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kristine G. Bottone, Ray Klein',
#  'Year': '2015',
#  'imdbID': 'tt3211248',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7575410
# -------------------
# {'Actors': 'Bobbi Maxwell, Bill Oberst Jr., Kj Schrock',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Evan Tramel',
#  'Genre': 'Animation, Comedy, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Nuke is a regular city elephant with a boring desk job yearning for '
#          'great space adventures. When Nuke joins forces with rogue warrior '
#          'Squeeze Whistle, a fearless space squirrel, they set ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYTU3YTUzMGItZWJkNS00OGRkLTgwNzUtYzFjZGI3YTYxZjlhXkEyXkFqcGdeQXVyMjM3NDgxNw@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.6/10'}],
#  'Released': '27 Apr 2018',
#  'Response': 'True',
#  'Runtime': '70 min',
#  'Title': 'Zoo Wars',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Evan Tramel',
#  'Year': '2018',
#  'imdbID': 'tt7575410',
#  'imdbRating': '4.6',
#  'imdbVotes': '88'}
# -------------------
# movie id tt6068554
# -------------------
# {'Actors': 'Eliot, Danika Fields, J.C. Maçek III, Jose Rosete',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'James Dylan',
#  'Genre': 'Crime, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A man wakes trapped inside a cargo container with only a cell phone '
#          'and is given 24 hours by his kidnappers to raise ten million dollars '
#          'in ransom or die.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZGQ4NTdjMjctZDdhZC00YjllLWEzOTUtZDI1ODhlZjBjN2NjXkEyXkFqcGdeQXVyMDk5NDkzOQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.5/10'}],
#  'Released': '13 Nov 2018',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': '[Cargo]',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'James Dylan',
#  'Year': '2018',
#  'imdbID': 'tt6068554',
#  'imdbRating': '2.5',
#  'imdbVotes': '340'}
# -------------------
# movie id tt10129872
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt6154710
# -------------------
# {'Actors': 'Lloyd Sparsi, Hailey Giles, Martin Kaps, Ana Semedo',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jasmin S. Greene, Martinique Hines',
#  'Genre': 'Drama',
#  'Language': 'English, German',
#  'Metascore': 'N/A',
#  'Plot': 'DIE EXPATS explores love, loss and lust, identity and modern '
#          'relationships. It is a story of four people in search of reclaiming '
#          'a sense of self while navigating the knotted, overlapping ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzIxZDUzOTAtOGY4YS00MGEyLTgyZTEtNjZmY2Q2NWZkMzY3L2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNTQ2NDgxOTU@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '22 Jan 2017',
#  'Response': 'True',
#  'Runtime': '93 min',
#  'Title': 'die Expats',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jasmin S. Greene, Vaughn J. Richardson',
#  'Year': '2017',
#  'imdbID': 'tt6154710',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8693422
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt6277342
# -------------------
# {'Actors': 'Dudley Beene, Jules Bernstein, Cannon Ball Buckley, John Cantwell',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Dean Littner',
#  'Genre': 'Comedy, Fantasy, Horror, Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'No one is safe from the most disturbing and terrifying friEnD ADd of '
#          'them all, friEnD ADd 6 will attack you. On August 5th, 2010, the '
#          'short film that started it all, friEnD ADd, ripped its ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZjA1ZWYwMDctOWY1Yi00NTcyLTk5NzMtZmYyNjg2ZmRkZTljL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMjc1MjYwOTU@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '14 Feb 2018',
#  'Response': 'True',
#  'Runtime': '67 min',
#  'Title': 'friEnD ADd 6',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dean Littner, Eli Rarey',
#  'Year': '2018',
#  'imdbID': 'tt6277342',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8515442
# -------------------
# {'Actors': 'Fnu Aruna, Aurora OuYang, Will Roberts, Jian Yu',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Dmitry Kharchuk',
#  'Genre': 'Action',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Nov 2018',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'iBOT',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dmitry Kharchuk',
#  'Year': '2018',
#  'imdbID': 'tt8515442',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7787666
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt4930292
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'Comedy',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'A desperate woman murders her unfaithful husband the morning of a '
#          'big party honoring his recent Pritzker Prize, now she must survive '
#          'the pain of heartbreak and a night of celebration, without being '
#          'found out.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': '¡He matado a mi marido!',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Francisco Lupini-Basagoiti',
#  'Year': '2016',
#  'imdbID': 'tt4930292',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}

# %%
len(title_list)
# Out:
# 752

# %%
len(title_id)
# Out:
# 752

# %%
# if title_list and title_id are the same length run the cell below. 
# if they are not equal take out 'title_id': title_id

# %%
df = pd.DataFrame({'title_id': title_id, 'title': title_list, 'box_office': box_office_list, 'country': country_list, 
                   'genre': genre_list, 'director': director_list, 'metascore': metascore_list, 'production': production_list, 
                   'rating': rating_list, 'IMDB_rating': IMDB_rating_list, 'rotten_tomatoes_rating': rotten_tomatoes_rating_list, 
                  'runtime': runtime_list, 'type': type_list, 'IMDB_votes': imdb_votes_list})

# %%
df = df.drop_duplicates()
df.head()
# Out:
#     title_id                      title box_office country  \
# 0  tt7549782              The Beaumonts        N/A     USA
# 1  tt8837492  The Best Movie Ever 4ever        N/A     USA
# 2  tt7978752               The Bestowal        N/A     USA
# 3  tt5090094                The Big Day        N/A     USA
# 4  tt8947544                The Big Fix        N/A     USA
#
#                       genre                  director metascore production  \
# 0  Comedy, Horror, Thriller              Jamie Sharps       N/A        N/A
# 1                       N/A  Chris Ramos, Chris Woods       N/A        N/A
# 2    Drama, Romance, Sci-Fi           Andrew de Burgh       N/A        N/A
# 3                    Comedy             Arian Harandi       N/A        N/A
# 4                       N/A             Micah Caronna       N/A        N/A
#
#   rating IMDB_rating rotten_tomatoes_rating runtime   type IMDB_votes
# 0    N/A         7.5                     NA  79 min  movie         65
# 1    N/A         N/A                     NA     N/A  movie        N/A
# 2    N/A         7.4                     NA  90 min  movie         21
# 3    N/A         N/A                     NA     N/A  movie        N/A
# 4    N/A         N/A                     NA     N/A  movie        N/A

# %%
df.count()
# Out:
# title_id                  752
# title                     752
# box_office                752
# country                   752
# genre                     752
# director                  752
# metascore                 752
# production                752
# rating                    752
# IMDB_rating               752
# rotten_tomatoes_rating    752
# runtime                   752
# type                      752
# IMDB_votes                752
# dtype: int64

# %%
df.to_csv('Resources/data/2018_data_batch_4.csv', index=False)
