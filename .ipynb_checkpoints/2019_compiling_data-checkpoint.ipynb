# %%
import pandas as pd
import requests
import json
import time
from pprint import pprint
from config import API_KEY

# %%
data = pd.read_csv('Resources/movies_titles_2019.csv')
df =  data.groupby('2019_movies').nunique().count()
df
# Out:
# 2019_movies    81
# dtype: int64

# %%
box_office_list = []
country_list = []
genre_list = []
director_list = []
metascore_list = []
production_list = []
rating_list = []
IMDB_rating_list = [] 
rotten_tomatoes_rating_list = []
runtime_list = []
title_list = []
type_list = []
imdb_votes_list = []

# %%
movies = data['2019_movies']
total_movies = len(movies)

# %%
for i in range(total_movies):
    movie = movies[i]
    url = "http://www.omdbapi.com/?i=" + movie + "&apikey=" + API_KEY
    response = (requests.get(url).text)
    response_json = json.loads(response)
    
    pprint(response_json)
    
    box_office_list.append(response_json['BoxOffice'])
    country_list.append(response_json['Country'])
    genre_list.append(response_json['Genre'])
    director_list.append(response_json['Director'])
    metascore_list.append(response_json['Metascore'])
    production_list.append(response_json['Production'])
    rating_list.append(response_json['Rated'])
    IMDB_rating_list.append(response_json['imdbRating'])
    try:
        if not response_json['Ratings']:
            rotten_tomatoes_rating_list.append('NA')
        elif response_json['Ratings'][0]['Source'] == 'Rotten Tomatoes':
            rotten_tomatoes_rating_list.append(response_json['Ratings'][0]['Value'])
        elif response_json['Ratings'][1]['Source'] == 'Rotten Tomatoes':
            rotten_tomatoes_rating_list.append(response_json['Ratings'][1]['Value'])
        else:
            rotten_tomatoes_rating_list.append('NA')
    except IndexError:
        rotten_tomatoes_rating_list.append('NA')
    runtime_list.append(response_json['Runtime'])
    title_list.append(response_json['Title'])
    type_list.append(response_json['Type'])
    imdb_votes_list.append(response_json['imdbVotes'])
# Out:
# {'Actors': 'Robert Downey Jr., Chris Evans, Mark Ruffalo, Chris Hemsworth',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '30 Jul 2019',
#  'Director': 'Anthony Russo, Joe Russo',
#  'Genre': 'Action, Adventure, Drama, Sci-Fi',
#  'Language': 'English, Japanese, Xhosa, German',
#  'Metascore': '78',
#  'Plot': 'After the devastating events of Avengers: Infinity War (2018), the '
#          'universe is in ruins. With the help of remaining allies, the '
#          "Avengers assemble once more in order to reverse Thanos' actions and "
#          'restore balance to the universe.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc5MDE2ODcwNV5BMl5BanBnXkFtZTgwMzI2NzQ2NzM@._V1_SX300.jpg',
#  'Production': 'Marvel Studios',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.5/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '94%'},
#              {'Source': 'Metacritic', 'Value': '78/100'}],
#  'Released': '26 Apr 2019',
#  'Response': 'True',
#  'Runtime': '181 min',
#  'Title': 'Avengers: Endgame',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Christopher Markus (screenplay by), Stephen McFeely (screenplay '
#            'by), Stan Lee (based on the Marvel comics by), Jack Kirby (based '
#            'on the Marvel comics by), Joe Simon (Captain America created by), '
#            'Jack Kirby (Captain America created by), Steve Englehart '
#            '(Star-Lord created by), Steve Gan (Star-Lord created by), Bill '
#            'Mantlo (Rocket Raccoon created by), Keith Giffen (Rocket Raccoon '
#            'created by), Jim Starlin (Thanos,  Gamora & Drax created by), Stan '
#            'Lee (Groot created by), Larry Lieber (Groot created by), Jack '
#            'Kirby (Groot created by), Steve Englehart (Mantis created by), Don '
#            'Heck (Mantis created by)',
#  'Year': '2019',
#  'imdbID': 'tt4154796',
#  'imdbRating': '8.5',
#  'imdbVotes': '613,329'}
# {'Actors': 'Daisy Ridley, Adam Driver, Billie Lourd, Carrie Fisher',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'J.J. Abrams',
#  'Genre': 'Action, Adventure, Fantasy, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The surviving Resistance faces the First Order once more in the '
#          'final chapter of the Skywalker saga.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMDljNTQ5ODItZmQwMy00M2ExLTljOTQtZTVjNGE2NTg0NGIxXkEyXkFqcGdeQXVyODkzNTgxMDg@._V1_SX300.jpg',
#  'Production': 'Walt Disney Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Rotten Tomatoes', 'Value': '55%'}],
#  'Released': '20 Dec 2019',
#  'Response': 'True',
#  'Runtime': '142 min',
#  'Title': 'Star Wars: The Rise of Skywalker',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Chris Terrio (screenplay by), J.J. Abrams (screenplay by), Derek '
#            'Connolly (story by), Colin Trevorrow (story by), Chris Terrio '
#            '(story by), J.J. Abrams (story by), George Lucas (based on '
#            'characters created by)',
#  'Year': '2019',
#  'imdbID': 'tt2527338',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Brie Larson, Samuel L. Jackson, Ben Mendelsohn, Jude Law',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Australia',
#  'DVD': '11 Jun 2019',
#  'Director': 'Anna Boden, Ryan Fleck',
#  'Genre': 'Action, Adventure, Sci-Fi',
#  'Language': 'English',
#  'Metascore': '64',
#  'Plot': "Carol Danvers becomes one of the universe's most powerful heroes "
#          'when Earth is caught in the middle of a galactic war between two '
#          'alien races.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTE0YWFmOTMtYTU2ZS00ZTIxLWE3OTEtYTNiYzBkZjViZThiXkEyXkFqcGdeQXVyODMzMzQ4OTI@._V1_SX300.jpg',
#  'Production': 'Marvel Studios',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.9/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '78%'},
#              {'Source': 'Metacritic', 'Value': '64/100'}],
#  'Released': '08 Mar 2019',
#  'Response': 'True',
#  'Runtime': '123 min',
#  'Title': 'Captain Marvel',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Anna Boden (screenplay by), Ryan Fleck (screenplay by), Geneva '
#            'Robertson-Dworet (screenplay by), Nicole Perlman (story by), Meg '
#            'LeFauve (story by), Anna Boden (story by), Ryan Fleck (story by), '
#            'Geneva Robertson-Dworet (story by)',
#  'Year': '2019',
#  'imdbID': 'tt4154664',
#  'imdbRating': '6.9',
#  'imdbVotes': '380,206'}
# {'Actors': 'Zachary Levi, Mark Strong, Asher Angel, Jack Dylan Grazer',
#  'Awards': '16 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Canada',
#  'DVD': '02 Jul 2019',
#  'Director': 'David F. Sandberg',
#  'Genre': 'Action, Adventure, Comedy, Fantasy',
#  'Language': 'English, Spanish',
#  'Metascore': '71',
#  'Plot': 'A newly fostered young boy in search of his mother instead finds '
#          'unexpected super powers and soon gains a powerful enemy.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYTE0Yjc1NzUtMjFjMC00Y2I3LTg3NGYtNGRlMGJhYThjMTJmXkEyXkFqcGdeQXVyNTI4MzE4MDU@._V1_SX300.jpg',
#  'Production': 'New Line Cinema',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '90%'},
#              {'Source': 'Metacritic', 'Value': '71/100'}],
#  'Released': '05 Apr 2019',
#  'Response': 'True',
#  'Runtime': '132 min',
#  'Title': 'Shazam!',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Henry Gayden (screenplay by), Henry Gayden (story by), Darren '
#            'Lemke (story by), Bill Parker (Shazam created by), C.C. Beck '
#            '(Shazam created by)',
#  'Year': '2019',
#  'imdbID': 'tt0448115',
#  'imdbRating': '7.1',
#  'imdbVotes': '199,841'}
# {'Actors': 'Colin Farrell, Michael Keaton, Danny DeVito, Eva Green',
#  'Awards': '8 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, UK, Australia, Canada',
#  'DVD': '25 Jun 2019',
#  'Director': 'Tim Burton',
#  'Genre': 'Adventure, Family, Fantasy',
#  'Language': 'English, French',
#  'Metascore': '51',
#  'Plot': 'A young elephant, whose oversized ears enable him to fly, helps save '
#          'a struggling circus, but when the circus plans a new venture, Dumbo '
#          'and his friends discover dark secrets beneath its shiny veneer.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjMxMDE0MDI1Ml5BMl5BanBnXkFtZTgwMzExNTU3NjM@._V1_SX300.jpg',
#  'Production': 'Walt Disney Pictures',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '47%'},
#              {'Source': 'Metacritic', 'Value': '51/100'}],
#  'Released': '29 Mar 2019',
#  'Response': 'True',
#  'Runtime': '112 min',
#  'Title': 'Dumbo',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ehren Kruger (screenplay by), Helen Aberson (novel), Harold Pearl '
#            '(novel)',
#  'Year': '2019',
#  'imdbID': 'tt3861390',
#  'imdbRating': '6.3',
#  'imdbVotes': '51,436'}
# {'Actors': 'Kyle Chandler, Vera Farmiga, Millie Bobby Brown, Ken Watanabe',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'Japan, Canada, USA',
#  'DVD': '06 Aug 2019',
#  'Director': 'Michael Dougherty',
#  'Genre': 'Action, Adventure, Fantasy, Sci-Fi',
#  'Language': 'English, Japanese, Chinese, Spanish',
#  'Metascore': '48',
#  'Plot': 'The crypto-zoological agency Monarch faces off against a battery of '
#          'god-sized monsters, including the mighty Godzilla, who collides with '
#          'Mothra, Rodan, and his ultimate nemesis, the three-headed King '
#          'Ghidorah.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOGFjYWNkMTMtMTg1ZC00Y2I4LTg0ZTYtN2ZlMzI4MGQwNzg4XkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_SX300.jpg',
#  'Production': 'Warner Bros. Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '42%'},
#              {'Source': 'Metacritic', 'Value': '48/100'}],
#  'Released': '31 May 2019',
#  'Response': 'True',
#  'Runtime': '132 min',
#  'Title': 'Godzilla: King of the Monsters',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Dougherty (screenplay by), Zach Shields (screenplay by), '
#            'Max Borenstein (story by), Michael Dougherty (story by), Zach '
#            'Shields (story by)',
#  'Year': '2019',
#  'imdbID': 'tt3741700',
#  'imdbRating': '6.1',
#  'imdbVotes': '100,328'}
# {'Actors': 'Chris Pratt, Elizabeth Banks, Will Arnett, Tiffany Haddish',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'Denmark, Norway, Australia, USA',
#  'DVD': '07 May 2019',
#  'Director': 'Mike Mitchell',
#  'Genre': 'Animation, Action, Adventure, Comedy, Family, Fantasy, Musical',
#  'Language': 'English',
#  'Metascore': '65',
#  'Plot': "It's been five years since everything was awesome and the citizens "
#          'are facing a huge new threat: Lego Duplo invaders from outer space, '
#          'wrecking everything faster than they can rebuild.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTkyOTkwNDc1N15BMl5BanBnXkFtZTgwNzkyMzk3NjM@._V1_SX300.jpg',
#  'Production': 'Warner Bros. Pictures',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.7/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '85%'},
#              {'Source': 'Metacritic', 'Value': '65/100'}],
#  'Released': '08 Feb 2019',
#  'Response': 'True',
#  'Runtime': '107 min',
#  'Title': 'The Lego Movie 2: The Second Part',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Phil Lord (screenplay by), Christopher Miller (screenplay by), '
#            'Phil Lord (story by), Christopher Miller (story by), Matthew Fogel '
#            '(story by), Jerry Siegel (created by: Superman), Joe Shuster '
#            '(created by: Superman), Bob Kane (created by: Batman), Bill Finger '
#            '(created by: Batman), William Moulton Marston (created by: Wonder '
#            'Woman)',
#  'Year': '2019',
#  'imdbID': 'tt3513498',
#  'imdbRating': '6.7',
#  'imdbVotes': '41,571'}
# {'Actors': 'Tom Holland, Samuel L. Jackson, Jake Gyllenhaal, Marisa Tomei',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '17 Sep 2019',
#  'Director': 'Jon Watts',
#  'Genre': 'Action, Adventure, Sci-Fi',
#  'Language': 'Italian, Czech, English',
#  'Metascore': '69',
#  'Plot': 'Following the events of Avengers: Endgame (2019), Spider-Man must '
#          'step up to take on new threats in a world that has changed forever.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMGZlNTY1ZWUtYTMzNC00ZjUyLWE0MjQtMTMxN2E3ODYxMWVmXkEyXkFqcGdeQXVyMDM2NDM2MQ@@._V1_SX300.jpg',
#  'Production': 'Sony Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '90%'},
#              {'Source': 'Metacritic', 'Value': '69/100'}],
#  'Released': '02 Jul 2019',
#  'Response': 'True',
#  'Runtime': '129 min',
#  'Title': 'Spider-Man: Far from Home',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Chris McKenna, Erik Sommers, Stan Lee (based on the Marvel comic '
#            'book by), Steve Ditko (based on the Marvel comic book by)',
#  'Year': '2019',
#  'imdbID': 'tt6320628',
#  'imdbRating': '7.6',
#  'imdbVotes': '238,917'}
# {'Actors': 'Jay Baruchel, America Ferrera, F. Murray Abraham, Cate Blanchett',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Japan',
#  'DVD': '21 May 2019',
#  'Director': 'Dean DeBlois',
#  'Genre': 'Animation, Action, Adventure, Family, Fantasy',
#  'Language': 'English',
#  'Metascore': '71',
#  'Plot': "When Hiccup discovers Toothless isn't the only Night Fury, he must "
#          'seek "The Hidden World", a secret Dragon Utopia before a hired '
#          'tyrant named Grimmel finds it first.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjIwMDIwNjAyOF5BMl5BanBnXkFtZTgwNDE1MDc2NTM@._V1_SX300.jpg',
#  'Production': 'Universal Pictures',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.5/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '90%'},
#              {'Source': 'Metacritic', 'Value': '71/100'}],
#  'Released': '22 Feb 2019',
#  'Response': 'True',
#  'Runtime': '104 min',
#  'Title': 'How to Train Your Dragon: The Hidden World',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dean DeBlois, Cressida Cowell (based upon the "How to Train Your '
#            'Dragon" book series by)',
#  'Year': '2019',
#  'imdbID': 'tt2386490',
#  'imdbRating': '7.5',
#  'imdbVotes': '80,386'}
# {'Actors': 'Tom Hanks, Tim Allen, Annie Potts, Tony Hale',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '01 Oct 2019',
#  'Director': 'Josh Cooley',
#  'Genre': 'Animation, Adventure, Comedy, Family, Fantasy',
#  'Language': 'English',
#  'Metascore': '84',
#  'Plot': 'When a new toy called "Forky" joins Woody and the gang, a road trip '
#          'alongside old and new friends reveals how big the world can be for a '
#          'toy.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTYzMDM4NzkxOV5BMl5BanBnXkFtZTgwNzM1Mzg2NzM@._V1_SX300.jpg',
#  'Production': 'Disney/Pixar',
#  'Rated': 'G',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.9/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '97%'},
#              {'Source': 'Metacritic', 'Value': '84/100'}],
#  'Released': '21 Jun 2019',
#  'Response': 'True',
#  'Runtime': '100 min',
#  'Title': 'Toy Story 4',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'John Lasseter (original story by), Andrew Stanton (original story '
#            'by), Josh Cooley (original story by), Valerie LaPointe (original '
#            'story by), Rashida Jones (original story by), Will McCormack '
#            '(original story by), Martin Hynes (original story by), Stephany '
#            'Folsom (original story by), Andrew Stanton (screenplay by), '
#            'Stephany Folsom (screenplay by), Josh Cooley (additional '
#            'screenplay material by)',
#  'Year': '2019',
#  'imdbID': 'tt1979376',
#  'imdbRating': '7.9',
#  'imdbVotes': '135,006'}
# {'Actors': 'Patton Oswalt, Kevin Hart, Harrison Ford, Eric Stonestreet',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, France, Japan',
#  'DVD': '13 Aug 2019',
#  'Director': 'Chris Renaud, Jonathan del Val(co-director)',
#  'Genre': 'Animation, Adventure, Comedy, Family',
#  'Language': 'English',
#  'Metascore': '55',
#  'Plot': 'Continuing the story of Max and his pet friends, following their '
#          'secret lives after their owners leave them for work or school each '
#          'day.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzdlMWQzZmItMDA5Ny00MGFjLTk0MDAtYjgzMmMyNTEwMzdhXkEyXkFqcGdeQXVyODQzNTE3ODc@._V1_SX300.jpg',
#  'Production': 'Universal Pictures',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '59%'},
#              {'Source': 'Metacritic', 'Value': '55/100'}],
#  'Released': '07 Jun 2019',
#  'Response': 'True',
#  'Runtime': '86 min',
#  'Title': 'The Secret Life of Pets 2',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Brian Lynch',
#  'Year': '2019',
#  'imdbID': 'tt5113040',
#  'imdbRating': '6.5',
#  'imdbVotes': '31,612'}
# {'Actors': 'Kristen Bell, Idina Menzel, Josh Gad, Jonathan Groff',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '25 Feb 2020',
#  'Director': 'Chris Buck, Jennifer Lee',
#  'Genre': 'Animation, Adventure, Comedy, Family, Fantasy, Musical',
#  'Language': 'English',
#  'Metascore': '64',
#  'Plot': 'Anna, Elsa, Kristoff, Olaf and Sven leave Arendelle to travel to an '
#          'ancient, autumn-bound forest of an enchanted land. They set out to '
#          "find the origin of Elsa's powers in order to save their kingdom.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjA0YjYyZGMtN2U0Ni00YmY4LWJkZTItYTMyMjY3NGYyMTJkXkEyXkFqcGdeQXVyNDg4NjY5OTQ@._V1_SX300.jpg',
#  'Production': 'Walt Disney Pictures',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.3/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '77%'},
#              {'Source': 'Metacritic', 'Value': '64/100'}],
#  'Released': '22 Nov 2019',
#  'Response': 'True',
#  'Runtime': '103 min',
#  'Title': 'Frozen II',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jennifer Lee (screenplay by), Jennifer Lee (story by), Chris Buck '
#            '(story by), Marc Smith (story by), Kristen Anderson-Lopez (story '
#            'by), Robert Lopez (story by)',
#  'Year': '2019',
#  'imdbID': 'tt4520988',
#  'imdbRating': '7.3',
#  'imdbVotes': '12,874'}
# {'Actors': 'Jason Sudeikis, Josh Gad, Leslie Jones, Bill Hader',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'Finland, USA',
#  'DVD': '29 Oct 2019',
#  'Director': 'Thurop Van Orman, John Rice(co-director)',
#  'Genre': 'Animation, Adventure, Comedy, Family',
#  'Language': 'English',
#  'Metascore': '60',
#  'Plot': 'The flightless birds and scheming green pigs take their feud to the '
#          'next level.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYzdkNGJhNzQtMjY1OC00MDI3LTk0ZDUtNzU0MGZiY2YwZGUxXkEyXkFqcGdeQXVyNzMxNjQxMTk@._V1_SX300.jpg',
#  'Production': 'Columbia Pictures',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.4/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '73%'},
#              {'Source': 'Metacritic', 'Value': '60/100'}],
#  'Released': '14 Aug 2019',
#  'Response': 'True',
#  'Runtime': '97 min',
#  'Title': 'The Angry Birds Movie 2',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Peter Ackerman (screenplay by), Eyal Podell (screenplay by), '
#            'Jonathon E. Stewart (screenplay by)',
#  'Year': '2019',
#  'imdbID': 'tt6095472',
#  'imdbRating': '6.4',
#  'imdbVotes': '10,015'}
# {'Actors': 'Linda Hamilton, Arnold Schwarzenegger, Mackenzie Davis, Natalia '
#            'Reyes',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Spain, Hungary',
#  'DVD': 'N/A',
#  'Director': 'Tim Miller',
#  'Genre': 'Action, Adventure, Sci-Fi',
#  'Language': 'English, Spanish',
#  'Metascore': '54',
#  'Plot': 'An augmented human and Sarah Connor must stop an advanced liquid '
#          "Terminator, from hunting down a young girl, who's fate is critical "
#          'to the human race.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzhlYjE5MjMtZDJmYy00MGZmLTgwN2MtZGM0NTk2ZTczNmU5XkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_SX300.jpg',
#  'Production': 'Paramount Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '70%'},
#              {'Source': 'Metacritic', 'Value': '54/100'}],
#  'Released': '01 Nov 2019',
#  'Response': 'True',
#  'Runtime': '128 min',
#  'Title': 'Terminator: Dark Fate',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'James Cameron (story by), Charles H. Eglee (story by), Josh '
#            'Friedman (story by), David S. Goyer (story by), Justin Rhodes '
#            '(story by), David S. Goyer (screenplay by), Justin Rhodes '
#            '(screenplay by), Billy Ray (screenplay by), James Cameron (based '
#            'on characters created by), Gale Anne Hurd (based on characters '
#            'created by)',
#  'Year': '2019',
#  'imdbID': 'tt6450804',
#  'imdbRating': '6.5',
#  'imdbVotes': '50,506'}
# {'Actors': 'Keanu Reeves, Halle Berry, Ian McShane, Laurence Fishburne',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '23 Aug 2019',
#  'Director': 'Chad Stahelski',
#  'Genre': 'Action, Crime, Thriller',
#  'Language': 'English, Russian, Japanese, Indonesian, Mandarin, Italian, '
#              'Arabic, Latin',
#  'Metascore': '73',
#  'Plot': 'John Wick is on the run after killing a member of the international '
#          "assassin's guild, and with a $14 million price tag on his head, he "
#          'is the target of hit men and women everywhere.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMDg2YzI0ODctYjliMy00NTU0LTkxODYtYTNkNjQwMzVmOTcxXkEyXkFqcGdeQXVyNjg2NjQwMDQ@._V1_SX300.jpg',
#  'Production': 'Lionsgate',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '90%'},
#              {'Source': 'Metacritic', 'Value': '73/100'}],
#  'Released': '17 May 2019',
#  'Response': 'True',
#  'Runtime': '131 min',
#  'Title': 'John Wick: Chapter 3 - Parabellum',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Derek Kolstad (screenplay by), Shay Hatten (screenplay by), Chris '
#            'Collins (screenplay by), Marc Abrams (screenplay by), Derek '
#            'Kolstad (story by), Derek Kolstad (based on characters created by)',
#  'Year': '2019',
#  'imdbID': 'tt6146586',
#  'imdbRating': '7.6',
#  'imdbVotes': '197,479'}
# {'Actors': 'Jessica Chastain, James McAvoy, Bill Hader, Isaiah Mustafa',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'Canada, USA',
#  'DVD': '19 Nov 2019',
#  'Director': 'Andy Muschietti',
#  'Genre': 'Drama, Fantasy, Horror',
#  'Language': 'English',
#  'Metascore': '58',
#  'Plot': 'Twenty-seven years after their first encounter with the terrifying '
#          'Pennywise, the Losers Club have grown up and moved away, until a '
#          'devastating phone call brings them back.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYTJlNjlkZTktNjEwOS00NzI5LTlkNDAtZmEwZDFmYmM2MjU2XkEyXkFqcGdeQXVyNjg2NjQwMDQ@._V1_SX300.jpg',
#  'Production': 'New Line Cinema',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.7/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '63%'},
#              {'Source': 'Metacritic', 'Value': '58/100'}],
#  'Released': '06 Sep 2019',
#  'Response': 'True',
#  'Runtime': '169 min',
#  'Title': 'It Chapter Two',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Gary Dauberman (screenplay by), Stephen King (based on the novel '
#            'by)',
#  'Year': '2019',
#  'imdbID': 'tt7349950',
#  'imdbRating': '6.7',
#  'imdbVotes': '127,076'}
# {'Actors': 'Chris Hemsworth, Tessa Thompson, Kumail Nanjiani, Rebecca Ferguson',
#  'Awards': '6 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '20 Aug 2019',
#  'Director': 'F. Gary Gray',
#  'Genre': 'Action, Adventure, Comedy, Sci-Fi',
#  'Language': 'English, French, Chinese',
#  'Metascore': '38',
#  'Plot': 'The Men in Black have always protected the Earth from the scum of '
#          'the universe. In this new adventure, they tackle their biggest '
#          'threat to date: a mole in the Men in Black organization.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMDZkODI2ZGItYTY5Yi00MTA4LWExY2ItM2ZmNjczYjM0NDg1XkEyXkFqcGdeQXVyMzY0MTE3NzU@._V1_SX300.jpg',
#  'Production': 'Columbia Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '23%'},
#              {'Source': 'Metacritic', 'Value': '38/100'}],
#  'Released': '14 Jun 2019',
#  'Response': 'True',
#  'Runtime': '114 min',
#  'Title': 'Men in Black: International',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Matt Holloway, Art Marcum, Lowell Cunningham (characters)',
#  'Year': '2019',
#  'imdbID': 'tt2283336',
#  'imdbRating': '5.6',
#  'imdbVotes': '77,164'}
# {'Actors': "Charlize Theron, Seth Rogen, June Diane Raphael, O'Shea Jackson "
#            'Jr.',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '16 Jul 2019',
#  'Director': 'Jonathan Levine',
#  'Genre': 'Comedy, Romance',
#  'Language': 'English, Swedish, French, Vietnamese, Russian, Hebrew',
#  'Metascore': '67',
#  'Plot': 'Journalist Fred Flarsky reunites with his childhood crush, Charlotte '
#          'Field, now one of the most influential women in the world. As she '
#          'prepares to make a run for the Presidency, Charlotte hires Fred as '
#          'her speechwriter and sparks fly.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMmE4Mzk0OWQtMDI1OS00NDU3LWI2M2YtNzc1MGMxZGI3ZTE1XkEyXkFqcGdeQXVyMjMxOTE0ODA@._V1_SX300.jpg',
#  'Production': 'Summit Entertainment',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.9/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '81%'},
#              {'Source': 'Metacritic', 'Value': '67/100'}],
#  'Released': '03 May 2019',
#  'Response': 'True',
#  'Runtime': '125 min',
#  'Title': 'Long Shot',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dan Sterling (screenplay by), Liz Hannah (screenplay by), Dan '
#            'Sterling (story by)',
#  'Year': '2019',
#  'imdbID': 'tt2139881',
#  'imdbRating': '6.9',
#  'imdbVotes': '56,821'}
# {'Actors': 'Sophie Nélisse, Corinne Foxx, Brianne Tju, Sistine Rose Stallone',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'UK, USA',
#  'DVD': '29 Oct 2019',
#  'Director': 'Johannes Roberts',
#  'Genre': 'Adventure, Drama, Horror, Thriller',
#  'Language': 'English',
#  'Metascore': '43',
#  'Plot': 'Four teen girls diving in a ruined underwater city quickly learn '
#          "they've entered the territory of the deadliest shark species in the "
#          'claustrophobic labyrinth of submerged caves.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMDc1MmVjMDQtOGU3OS00OTJkLWJmOGQtNDMzMWRjNDAzY2Y2XkEyXkFqcGdeQXVyMTk5MzE1MTY@._V1_SX300.jpg',
#  'Production': 'Entertainment Studios Motion Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.0/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '42%'},
#              {'Source': 'Metacritic', 'Value': '43/100'}],
#  'Released': '16 Aug 2019',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': '47 Meters Down: Uncaged',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ernest Riera, Johannes Roberts',
#  'Year': '2019',
#  'imdbID': 'tt7329656',
#  'imdbRating': '5.0',
#  'imdbVotes': '9,384'}
# {'Actors': 'Leonardo DiCaprio, Brad Pitt, Margot Robbie, Emile Hirsch',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, UK, China',
#  'DVD': '22 Nov 2019',
#  'Director': 'Quentin Tarantino',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English, Italian, Spanish',
#  'Metascore': '83',
#  'Plot': 'A faded television actor and his stunt double strive to achieve fame '
#          'and success in the film industry during the final years of '
#          "Hollywood's Golden Age in 1969 Los Angeles.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTg4ZTNkZmUtMzNlZi00YmFjLTk1MmUtNWQwNTM0YjcyNTNkXkEyXkFqcGdeQXVyNjg2NjQwMDQ@._V1_SX300.jpg',
#  'Production': 'Columbia Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.9/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '85%'},
#              {'Source': 'Metacritic', 'Value': '83/100'}],
#  'Released': '26 Jul 2019',
#  'Response': 'True',
#  'Runtime': '161 min',
#  'Title': 'Once Upon a Time ... in Hollywood',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Quentin Tarantino',
#  'Year': '2019',
#  'imdbID': 'tt7131622',
#  'imdbRating': '7.9',
#  'imdbVotes': '260,183'}
# {'Actors': 'Will Smith, Mena Massoud, Naomi Scott, Marwan Kenzari',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Guy Ritchie',
#  'Genre': 'Adventure, Family, Fantasy, Musical, Romance',
#  'Language': 'Arabic, English',
#  'Metascore': '53',
#  'Plot': 'A kind-hearted street urchin and a power-hungry Grand Vizier vie for '
#          'a magic lamp that has the power to make their deepest wishes come '
#          'true.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjQ2ODIyMjY4MF5BMl5BanBnXkFtZTgwNzY4ODI2NzM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.1/10'},
#              {'Source': 'Metacritic', 'Value': '53/100'}],
#  'Released': '24 May 2019',
#  'Response': 'True',
#  'Runtime': '128 min',
#  'Title': 'Aladdin',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'John August (screenplay by), Guy Ritchie (screenplay by)',
#  'Year': '2019',
#  'imdbID': 'tt6139732',
#  'imdbRating': '7.1',
#  'imdbVotes': '160,305'}
# {'Actors': 'Ryan Reynolds, Justice Smith, Kathryn Newton, Bill Nighy',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Japan, UK, Canada',
#  'DVD': '23 Jul 2019',
#  'Director': 'Rob Letterman',
#  'Genre': 'Action, Adventure, Comedy, Family, Mystery, Sci-Fi',
#  'Language': 'English',
#  'Metascore': '53',
#  'Plot': 'In a world where people collect Pokémon to do battle, a boy comes '
#          'across an intelligent talking Pikachu who seeks to be a detective.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDU4Mzc3NzE5NV5BMl5BanBnXkFtZTgwMzE1NzI1NzM@._V1_SX300.jpg',
#  'Production': 'Warner Bros. Pictures',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.7/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '68%'},
#              {'Source': 'Metacritic', 'Value': '53/100'}],
#  'Released': '10 May 2019',
#  'Response': 'True',
#  'Runtime': '104 min',
#  'Title': 'Pokémon Detective Pikachu',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dan Hernandez (screenplay by), Benji Samit (screenplay by), Rob '
#            'Letterman (screenplay by), Derek Connolly (screenplay by), Dan '
#            'Hernandez (story by), Benji Samit (story by), Nicole Perlman '
#            '(story by), Satoshi Tajiri (based on "Pokémon" created by), Ken '
#            'Sugimori (based on "Pokémon" created by), Junichi Masuda (based on '
#            '"Pokémon" created by), Atsuko Nishida (characters), Tomokazu Ohara '
#            '(original story), Haruka Utsui (original story)',
#  'Year': '2019',
#  'imdbID': 'tt5884052',
#  'imdbRating': '6.7',
#  'imdbVotes': '105,639'}
# {'Actors': 'Mark Stanley, Brian Gleeson, Nadya Keranova, Maria Tepavicharova',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, UK, Bulgaria, Canada',
#  'DVD': '09 Jul 2019',
#  'Director': 'Neil Marshall',
#  'Genre': 'Action, Adventure, Fantasy, Horror, Sci-Fi',
#  'Language': 'English, Spanish, German, Russian',
#  'Metascore': '31',
#  'Plot': 'Based on the graphic novels by Mike Mignola, Hellboy, caught between '
#          'the worlds of the supernatural and human, battles an ancient '
#          'sorceress bent on revenge.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODdkMDQzMzItZDc4YS00OGM4LTkxNTQtNjUzNzU0ZmJkMWY2XkEyXkFqcGdeQXVyMjMxOTE0ODA@._V1_SX300.jpg',
#  'Production': 'Summit Entertainment',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.2/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '17%'},
#              {'Source': 'Metacritic', 'Value': '31/100'}],
#  'Released': '12 Apr 2019',
#  'Response': 'True',
#  'Runtime': '120 min',
#  'Title': 'Hellboy',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Andrew Cosby (screenplay by), Mike Mignola (based on the Dark '
#            'Horse Comic Book "Hellboy" created by)',
#  'Year': '2019',
#  'imdbID': 'tt2274648',
#  'imdbRating': '5.2',
#  'imdbVotes': '58,883'}
# {'Actors': 'Chiwetel Ejiofor, John Oliver, James Earl Jones, John Kani',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '11 Oct 2019',
#  'Director': 'Jon Favreau',
#  'Genre': 'Animation, Adventure, Drama, Family, Musical',
#  'Language': 'English',
#  'Metascore': '55',
#  'Plot': 'After the murder of his father, a young lion prince flees his '
#          'kingdom only to learn the true meaning of responsibility and '
#          'bravery.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjIwMjE1Nzc4NV5BMl5BanBnXkFtZTgwNDg4OTA1NzM@._V1_SX300.jpg',
#  'Production': 'Walt Disney Pictures',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '53%'},
#              {'Source': 'Metacritic', 'Value': '55/100'}],
#  'Released': '19 Jul 2019',
#  'Response': 'True',
#  'Runtime': '118 min',
#  'Title': 'The Lion King',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jeff Nathanson (screenplay by), Irene Mecchi (based on: "The Lion '
#            'King",  screenplay by), Jonathan Roberts (based on: "The Lion '
#            'King",  screenplay by), Linda Woolverton (based on: "The Lion '
#            'King",  screenplay by)',
#  'Year': '2019',
#  'imdbID': 'tt6105098',
#  'imdbRating': '7.0',
#  'imdbVotes': '142,549'}
# {'Actors': 'James McAvoy, Michael Fassbender, Jennifer Lawrence, Nicholas '
#            'Hoult',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Canada',
#  'DVD': '03 Sep 2019',
#  'Director': 'Simon Kinberg',
#  'Genre': 'Action, Adventure, Sci-Fi',
#  'Language': 'English, French',
#  'Metascore': '43',
#  'Plot': 'Jean Grey begins to develop incredible powers that corrupt and turn '
#          'her into a Dark Phoenix, causing the X-Men to decide if her life is '
#          'worth more than all of humanity.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMmZmYTgwZGItNDIxMS00MmRkLWEzODQtYTllNzM0ZWE1NmQ5XkEyXkFqcGdeQXVyODQzNTE3ODc@._V1_SX300.jpg',
#  'Production': '20th Century Fox',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '23%'},
#              {'Source': 'Metacritic', 'Value': '43/100'}],
#  'Released': '07 Jun 2019',
#  'Response': 'True',
#  'Runtime': '113 min',
#  'Title': 'Dark Phoenix',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Simon Kinberg, Stan Lee (comic book created by), Jack Kirby (comic '
#            'book created by), Chris Claremont (story "The Dark Phoenix Saga"), '
#            'John Byrne (story "The Dark Phoenix Saga"), Dave Cockrum (story '
#            '"The Dark Phoenix Saga")',
#  'Year': '2019',
#  'imdbID': 'tt6565702',
#  'imdbRating': '5.8',
#  'imdbVotes': '113,234'}
# {'Actors': 'Karen Gillan, Marin Hinkle, Dwayne Johnson, Madison Iseman',
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jake Kasdan',
#  'Genre': 'Action, Adventure, Comedy, Fantasy',
#  'Language': 'English',
#  'Metascore': '58',
#  'Plot': 'In Jumanji: The Next Level, the gang is back but the game has '
#          'changed. As they return to rescue one of their own, the players will '
#          'have to brave parts unknown from arid deserts to snowy mountains, to '
#          "escape the world's most dangerous game.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTVjMmFiMDUtOWQ4My00YzhmLWE3MzEtODM1NDFjMWEwZTRkXkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_SX300.jpg',
#  'Production': 'Sony Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '66%'},
#              {'Source': 'Metacritic', 'Value': '58/100'}],
#  'Released': '13 Dec 2019',
#  'Response': 'True',
#  'Runtime': '123 min',
#  'Title': 'Jumanji: The Next Level',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jake Kasdan, Jeff Pinkner, Scott Rosenberg, Chris Van Allsburg '
#            '(based on the book "Jumanji" by)',
#  'Year': '2019',
#  'imdbID': 'tt7975244',
#  'imdbRating': '7.0',
#  'imdbVotes': '18,512'}
# {'Actors': 'James McAvoy, Bruce Willis, Samuel L. Jackson, Anya Taylor-Joy',
#  'Awards': '1 win & 7 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, China',
#  'DVD': '16 Apr 2019',
#  'Director': 'M. Night Shyamalan',
#  'Genre': 'Drama, Sci-Fi, Thriller',
#  'Language': 'English, Spanish',
#  'Metascore': '43',
#  'Plot': 'Security guard David Dunn uses his supernatural abilities to track '
#          'Kevin Wendell Crumb, a disturbed man who has twenty-four '
#          'personalities.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTY1OTA2MjI5OV5BMl5BanBnXkFtZTgwNzkxMjU4NjM@._V1_SX300.jpg',
#  'Production': 'Universal Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.7/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '37%'},
#              {'Source': 'Metacritic', 'Value': '43/100'}],
#  'Released': '18 Jan 2019',
#  'Response': 'True',
#  'Runtime': '129 min',
#  'Title': 'Glass',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'M. Night Shyamalan',
#  'Year': '2019',
#  'imdbID': 'tt6823368',
#  'imdbRating': '6.7',
#  'imdbVotes': '171,937'}
# {'Actors': 'Dwayne Johnson, Thomas Whilley, Tori Ellen Ross, Nick Frost',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'UK, USA',
#  'DVD': '14 May 2019',
#  'Director': 'Stephen Merchant',
#  'Genre': 'Biography, Comedy, Drama, Sport',
#  'Language': 'English',
#  'Metascore': '68',
#  'Plot': 'A former wrestler and his family make a living performing at small '
#          'venues around the country while his kids dream of joining World '
#          'Wrestling Entertainment.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNWM0NGUxMzUtMjRlZS00OWZlLTlkZDMtMzJhOWVmZDY2ODczXkEyXkFqcGdeQXVyOTQxNzM2MjY@._V1_SX300.jpg',
#  'Production': 'MGM',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '92%'},
#              {'Source': 'Metacritic', 'Value': '68/100'}],
#  'Released': '22 Feb 2019',
#  'Response': 'True',
#  'Runtime': '108 min',
#  'Title': 'Fighting with My Family',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Stephen Merchant',
#  'Year': '2019',
#  'imdbID': 'tt6513120',
#  'imdbRating': '7.1',
#  'imdbVotes': '43,257'}
# {'Actors': 'Sylvester Stallone, Paz Vega, Sergio Peris-Mencheta, Adriana '
#            'Barraza',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Spain, Bulgaria',
#  'DVD': 'N/A',
#  'Director': 'Adrian Grunberg',
#  'Genre': 'Action, Adventure, Thriller',
#  'Language': 'English, Spanish',
#  'Metascore': '26',
#  'Plot': 'Rambo must confront his past and unearth his ruthless combat skills '
#          'to exact revenge in a final mission.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTAxZWM2OTgtOTQzOC00ZTI5LTgyYjktZTRhYWM4YWQxNWI0XkEyXkFqcGdeQXVyMjMwNDgzNjc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.4/10'},
#              {'Source': 'Metacritic', 'Value': '26/100'}],
#  'Released': '20 Sep 2019',
#  'Response': 'True',
#  'Runtime': '89 min',
#  'Title': 'Rambo: Last Blood',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Matthew Cirulnick (screenplay by), Sylvester Stallone (screenplay '
#            'by), Dan Gordon (story by), Sylvester Stallone (story by), David '
#            'Morrell (based on the character created by)',
#  'Year': '2019',
#  'imdbID': 'tt1206885',
#  'imdbRating': '6.4',
#  'imdbVotes': '32,541'}
# {'Actors': 'Taraji P. Henson, Kristen Ledlow, Josh Brener, Kellan Lutz',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '07 May 2019',
#  'Director': 'Adam Shankman',
#  'Genre': 'Comedy, Fantasy, Romance',
#  'Language': 'English, Mandarin',
#  'Metascore': '49',
#  'Plot': 'A woman is boxed out by the male sports agents in her profession, '
#          'but gains an unexpected edge over them when she develops the ability '
#          "to hear men's thoughts.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTYxNjE2NjIwOF5BMl5BanBnXkFtZTgwMjE0MzkxNzM@._V1_SX300.jpg',
#  'Production': 'Paramount Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.1/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '43%'},
#              {'Source': 'Metacritic', 'Value': '49/100'}],
#  'Released': '08 Feb 2019',
#  'Response': 'True',
#  'Runtime': '117 min',
#  'Title': 'What Men Want',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tina Gordon (screenplay by), Peter Huyck (screenplay by), Alex '
#            'Gregory (screenplay by), Jas Waters (story by), Tina Gordon (story '
#            'by), Josh Goldsmith (based on "What Women Want" screenplay by), '
#            'Cathy Yuspa (based on "What Women Want" screenplay by), Josh '
#            'Goldsmith (based on "What Women Want" story by), Cathy Yuspa '
#            '(based on "What Women Want" story by), Diane Drake (based on "What '
#            'Women Want" story by)',
#  'Year': '2019',
#  'imdbID': 'tt7634968',
#  'imdbRating': '5.1',
#  'imdbVotes': '14,832'}
# {'Actors': 'Woody Harrelson, Jesse Eisenberg, Emma Stone, Abigail Breslin',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Canada',
#  'DVD': 'N/A',
#  'Director': 'Ruben Fleischer',
#  'Genre': 'Action, Comedy, Horror',
#  'Language': 'English',
#  'Metascore': '56',
#  'Plot': 'Columbus, Tallahassee, Wichita, and Little Rock move to the American '
#          'heartland as they face off against evolved zombies, fellow '
#          'survivors, and the growing pains of the snarky makeshift family.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYjcwNjZhNGYtOGNlNy00NGI3LTlmODMtMGZlMjA3YjA0Njg0XkEyXkFqcGdeQXVyMDM2NDM2MQ@@._V1_SX300.jpg',
#  'Production': 'Columbia Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.2/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '69%'},
#              {'Source': 'Metacritic', 'Value': '56/100'}],
#  'Released': '18 Oct 2019',
#  'Response': 'True',
#  'Runtime': '99 min',
#  'Title': 'Zombieland: Double Tap',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Dave Callaham (screenplay), Rhett Reese (screenplay), Paul Wernick '
#            '(screenplay)',
#  'Year': '2019',
#  'imdbID': 'tt1560220',
#  'imdbRating': '7.2',
#  'imdbVotes': '33,435'}
# {'Actors': 'Kristen Stewart, Naomi Scott, Ella Balinska, Elizabeth Banks',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Elizabeth Banks',
#  'Genre': 'Action, Adventure, Comedy',
#  'Language': 'English',
#  'Metascore': '52',
#  'Plot': 'When a young systems engineer blows the whistle on a dangerous '
#          "technology, Charlie's Angels are called into action, putting their "
#          'lives on the line to protect us all.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BN2VkMjQwZWMtMzc1NC00ZjJiLWJlNTMtNmRjOTE2ZTJmYzUwXkEyXkFqcGdeQXVyMjUxMTY3ODM@._V1_SX300.jpg',
#  'Production': 'Sony Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.9/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '52%'},
#              {'Source': 'Metacritic', 'Value': '52/100'}],
#  'Released': '15 Nov 2019',
#  'Response': 'True',
#  'Runtime': '118 min',
#  'Title': "Charlie's Angels",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Elizabeth Banks (screenplay), Evan Spiliotopoulos (story by), '
#            'David Auburn (story by)',
#  'Year': '2019',
#  'imdbID': 'tt5033998',
#  'imdbRating': '3.9',
#  'imdbVotes': '10,241'}
# {'Actors': 'Dwayne Johnson, Jason Statham, Idris Elba, Vanessa Kirby',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '15 Oct 2019',
#  'Director': 'David Leitch',
#  'Genre': 'Action, Adventure',
#  'Language': 'English, Samoan, Russian',
#  'Metascore': '60',
#  'Plot': 'Lawman Luke Hobbs and outcast Deckard Shaw form an unlikely alliance '
#          'when a cyber-genetically enhanced villain threatens the future of '
#          'humanity.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTIzYmUyMmEtMWQzNC00YzExLTk3MzYtZTUzYjMyMmRiYzIwXkEyXkFqcGdeQXVyMDM2NDM2MQ@@._V1_SX300.jpg',
#  'Production': 'Universal Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '67%'},
#              {'Source': 'Metacritic', 'Value': '60/100'}],
#  'Released': '02 Aug 2019',
#  'Response': 'True',
#  'Runtime': '137 min',
#  'Title': 'Fast & Furious Presents: Hobbs & Shaw',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Chris Morgan (screenplay by), Drew Pearce (screenplay by), Chris '
#            'Morgan (story by), Gary Scott Thompson (based on characters '
#            'created by)',
#  'Year': '2019',
#  'imdbID': 'tt6806448',
#  'imdbRating': '6.5',
#  'imdbVotes': '116,265'}
# {'Actors': 'Jessica Rothe, Israel Broussard, Phi Vu, Suraj Sharma',
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Japan',
#  'DVD': '14 May 2019',
#  'Director': 'Christopher Landon',
#  'Genre': 'Comedy, Horror, Mystery, Sci-Fi, Thriller',
#  'Language': 'English, French',
#  'Metascore': '57',
#  'Plot': 'Tree Gelbman discovers that dying over and over was surprisingly '
#          'easier than the dangers that lie ahead.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg0NzkwMzQyMV5BMl5BanBnXkFtZTgwNDcxMTMyNzM@._V1_SX300.jpg',
#  'Production': 'Universal Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '70%'},
#              {'Source': 'Metacritic', 'Value': '57/100'}],
#  'Released': '13 Feb 2019',
#  'Response': 'True',
#  'Runtime': '100 min',
#  'Title': 'Happy Death Day 2U',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Christopher Landon, Scott Lobdell (based on characters created by)',
#  'Year': '2019',
#  'imdbID': 'tt8155288',
#  'imdbRating': '6.2',
#  'imdbVotes': '41,804'}
# {'Actors': 'Joaquin Phoenix, Robert De Niro, Zazie Beetz, Frances Conroy',
#  'Awards': 'Nominated for 4 Golden Globes. Another 11 wins & 37 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Canada',
#  'DVD': '17 Dec 2019',
#  'Director': 'Todd Phillips',
#  'Genre': 'Crime, Drama, Thriller',
#  'Language': 'English',
#  'Metascore': '59',
#  'Plot': 'In Gotham City, mentally troubled comedian Arthur Fleck is '
#          'disregarded and mistreated by society. He then embarks on a downward '
#          'spiral of revolution and bloody crime. This path brings him '
#          'face-to-face with his alter-ego: the Joker.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNGVjNWI4ZGUtNzE0MS00YTJmLWE0ZDctN2ZiYTk2YmI3NTYyXkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_SX300.jpg',
#  'Production': 'Warner Bros. Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.7/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '69%'},
#              {'Source': 'Metacritic', 'Value': '59/100'}],
#  'Released': '04 Oct 2019',
#  'Response': 'True',
#  'Runtime': '122 min',
#  'Title': 'Joker',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Todd Phillips, Scott Silver, Bob Kane (based on characters created '
#            'by), Bill Finger (based on characters created by), Jerry Robinson '
#            '(based on characters created by)',
#  'Year': '2019',
#  'imdbID': 'tt7286456',
#  'imdbRating': '8.7',
#  'imdbVotes': '513,667'}
# {'Actors': 'Rosa Salazar, Christoph Waltz, Jennifer Connelly, Mahershala Ali',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '09 Jul 2019',
#  'Director': 'Robert Rodriguez',
#  'Genre': 'Action, Adventure, Sci-Fi, Thriller',
#  'Language': 'English, Spanish',
#  'Metascore': '53',
#  'Plot': 'A deactivated cyborg is revived, but cannot remember anything of her '
#          'past life and goes on a quest to find out who she is.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzVhMjcxYjYtOTVhOS00MzQ1LWFiNTAtZmY2ZmJjNjIxMjllXkEyXkFqcGdeQXVyNTc5OTMwOTQ@._V1_SX300.jpg',
#  'Production': '20th Century Fox',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.4/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '61%'},
#              {'Source': 'Metacritic', 'Value': '53/100'}],
#  'Released': '14 Feb 2019',
#  'Response': 'True',
#  'Runtime': '122 min',
#  'Title': 'Alita: Battle Angel',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'James Cameron (screenplay by), Laeta Kalogridis (screenplay by), '
#            'Yukito Kishiro (based on the graphic novel series "Gunnm" by)',
#  'Year': '2019',
#  'imdbID': 'tt0437086',
#  'imdbRating': '7.4',
#  'imdbVotes': '174,971'}
# {'Actors': 'Brad Pitt, Tommy Lee Jones, Ruth Negga, Donald Sutherland',
#  'Awards': '6 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, China',
#  'DVD': '03 Dec 2019',
#  'Director': 'James Gray',
#  'Genre': 'Adventure, Drama, Mystery, Sci-Fi, Thriller',
#  'Language': 'English, Japanese, Russian, Norwegian',
#  'Metascore': '80',
#  'Plot': 'Astronaut Roy McBride undertakes a mission across an unforgiving '
#          'solar system to uncover the truth about his missing father and his '
#          'doomed expedition that now, 30 years later, threatens the universe.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZTllZTdlOGEtZTBmMi00MGQ5LWFjN2MtOGEyZTliNGY1MzFiXkEyXkFqcGdeQXVyODk4OTc3MTY@._V1_SX300.jpg',
#  'Production': '20th Century Fox',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.8/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '84%'},
#              {'Source': 'Metacritic', 'Value': '80/100'}],
#  'Released': '20 Sep 2019',
#  'Response': 'True',
#  'Runtime': '123 min',
#  'Title': 'Ad Astra',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'James Gray, Ethan Gross',
#  'Year': '2019',
#  'imdbID': 'tt2935510',
#  'imdbRating': '6.8',
#  'imdbVotes': '86,453'}
# ...
#              {'Source': 'Rotten Tomatoes', 'Value': '54%'},
#              {'Source': 'Metacritic', 'Value': '53/100'}],
#  'Released': '31 May 2019',
#  'Response': 'True',
#  'Runtime': '99 min',
#  'Title': 'Ma',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Scotty Landes',
#  'Year': '2019',
#  'imdbID': 'tt7958736',
#  'imdbRating': '5.6',
#  'imdbVotes': '23,727'}
# {'Actors': 'Nicholas Hoult, Al Bollands, Kallum Tolkien, Craig Roberts',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '23 Jul 2019',
#  'Director': 'Dome Karukoski',
#  'Genre': 'Biography, Drama, War',
#  'Language': 'English, Latin, Middle English',
#  'Metascore': '48',
#  'Plot': 'The formative years of the orphaned author J.R.R. Tolkien as he '
#          'finds friendship, love and artistic inspiration among a group of '
#          'fellow outcasts at school.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjUzNzA1MDczOF5BMl5BanBnXkFtZTgwODY5OTI2NzM@._V1_SX300.jpg',
#  'Production': 'Fox Searchlight Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.8/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '51%'},
#              {'Source': 'Metacritic', 'Value': '48/100'}],
#  'Released': '10 May 2019',
#  'Response': 'True',
#  'Runtime': '112 min',
#  'Title': 'Tolkien',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'David Gleeson, Stephen Beresford',
#  'Year': '2019',
#  'imdbID': 'tt3361792',
#  'imdbRating': '6.8',
#  'imdbVotes': '18,922'}
# {'Actors': 'Anna Kendrick, Shirley MacLaine, Bill Hader, Kingsley Ben-Adir',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Marc Lawrence',
#  'Genre': 'Comedy, Family, Fantasy',
#  'Language': 'English',
#  'Metascore': '48',
#  'Plot': "Santa's daughter finds herself having to take over the family "
#          'business.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjM2MTIxYTAtYWM3MC00OWI4LWJmMjMtYzBhMWFlMzU0NTdhXkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'G',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'},
#              {'Source': 'Metacritic', 'Value': '48/100'}],
#  'Released': '12 Nov 2019',
#  'Response': 'True',
#  'Runtime': '100 min',
#  'Title': 'Noelle',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Marc Lawrence (script)',
#  'Year': '2019',
#  'imdbID': 'tt5097410',
#  'imdbRating': '6.3',
#  'imdbVotes': '4,506'}
# {'Actors': 'Aaron Paul, Jonathan Banks, Matt Jones, Charles Baker',
#  'Awards': '6 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '11 Oct 2019',
#  'Director': 'Vince Gilligan',
#  'Genre': 'Action, Drama',
#  'Language': 'English',
#  'Metascore': '72',
#  'Plot': 'El Camino: A Breaking Bad Movie follows fugitive Jesse Pinkman as he '
#          'runs from his captors, the law and his past.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjk4MzVlM2UtZGM0ZC00M2M1LThkMWEtZjUyN2U2ZTc0NmM5XkEyXkFqcGdeQXVyOTAzMTc2MjA@._V1_SX300.jpg',
#  'Production': 'Netflix',
#  'Rated': 'TV-MA',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.4/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '91%'},
#              {'Source': 'Metacritic', 'Value': '72/100'}],
#  'Released': '11 Oct 2019',
#  'Response': 'True',
#  'Runtime': '122 min',
#  'Title': 'El Camino: A Breaking Bad Movie',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Vince Gilligan, Vince Gilligan (based on "Breaking Bad" by)',
#  'Year': '2019',
#  'imdbID': 'tt9243946',
#  'imdbRating': '7.4',
#  'imdbVotes': '138,741'}
# {'Actors': 'Liam Neeson, Laura Dern, Micheál Richardson, Michael Eklund',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'UK, Norway, Canada, USA, France, Germany',
#  'DVD': '14 May 2019',
#  'Director': 'Hans Petter Moland',
#  'Genre': 'Action, Crime, Drama, Thriller',
#  'Language': 'English, Vietnamese, Shoshoni',
#  'Metascore': '57',
#  'Plot': 'A grieving snowplow driver seeks out revenge against the drug '
#          'dealers who killed his son.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BM2YyYWI3NjItMWEwZS00MzhkLWJmZTMtZDAzYjRhODM0OTMzXkEyXkFqcGdeQXVyMjM4NTM5NDY@._V1_SX300.jpg',
#  'Production': 'Summit Entertainment',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '70%'},
#              {'Source': 'Metacritic', 'Value': '57/100'}],
#  'Released': '08 Feb 2019',
#  'Response': 'True',
#  'Runtime': '119 min',
#  'Title': 'Cold Pursuit',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Frank Baldwin (screenplay by), Kim Fupz Aakeson (based on the '
#            "movie 'Kraftidioten' written by)",
#  'Year': '2019',
#  'imdbID': 'tt5719748',
#  'imdbRating': '6.2',
#  'imdbVotes': '43,117'}
# {'Actors': 'Isabela Merced, Shameik Moore, Odeya Rush, Liv Hewson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '08 Nov 2019',
#  'Director': 'Luke Snellin',
#  'Genre': 'Comedy, Romance',
#  'Language': 'English',
#  'Metascore': '51',
#  'Plot': 'In a small town on Christmas Eve, a snowstorm brings together a '
#          'group of young people.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYmM0NzRiODEtMTIzNS00MTgwLWFjZDQtNjUxZjI0MDdjZWQ4XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg',
#  'Production': 'Netflix',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '83%'},
#              {'Source': 'Metacritic', 'Value': '51/100'}],
#  'Released': '08 Nov 2019',
#  'Response': 'True',
#  'Runtime': '92 min',
#  'Title': 'Let It Snow',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Laura Solon (screenplay by), Victoria Strouse (screenplay by), Kay '
#            'Cannon (screenplay by), John Green (based on the book by), Lauren '
#            'Myracle (based on the book by), Maureen Johnson (based on the book '
#            'by)',
#  'Year': '2019',
#  'imdbID': 'tt1950235',
#  'imdbRating': '5.8',
#  'imdbVotes': '11,028'}
# {'Actors': 'Ewan McGregor, Rebecca Ferguson, Kyliegh Curran, Cliff Curtis',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, UK',
#  'DVD': 'N/A',
#  'Director': 'Mike Flanagan',
#  'Genre': 'Drama, Fantasy, Horror, Thriller',
#  'Language': 'English',
#  'Metascore': '59',
#  'Plot': 'Years following the events of "The Shining," a now-adult Dan '
#          'Torrance must protect a young girl with similar powers from a cult '
#          'known as The True Knot, who prey on children with powers to remain '
#          'immortal.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYmY3NGJlYTItYmQ4OS00ZTEwLWIzODItMjMzNWU2MDE0NjZhXkEyXkFqcGdeQXVyMzQzMDA3MTI@._V1_SX300.jpg',
#  'Production': 'Warner Bros. Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '76%'},
#              {'Source': 'Metacritic', 'Value': '59/100'}],
#  'Released': '08 Nov 2019',
#  'Response': 'True',
#  'Runtime': '152 min',
#  'Title': 'Doctor Sleep',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Stephen King (based on the novel by), Mike Flanagan (screenplay)',
#  'Year': '2019',
#  'imdbID': 'tt5606664',
#  'imdbRating': '7.6',
#  'imdbVotes': '36,389'}
# {'Actors': 'Madison Ingoldsby, Emma Thompson, Boris Isakovic, Lucy Miller',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'UK, USA',
#  'DVD': 'N/A',
#  'Director': 'Paul Feig',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'English, Serbian',
#  'Metascore': '50',
#  'Plot': 'Kate is a young woman subscribed to bad decisions. Working as an elf '
#          'in a year round Christmas store is not good for the wannabe singer. '
#          'However, she meets Tom there. Her life takes a new turn. For Kate, '
#          'it seems too good to be true.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTQ4ZmY0NjgtYzVhNy00NzhiLTk3YTYtNzM1MTdjM2VhZDA3XkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_SX300.jpg',
#  'Production': 'Universal Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '47%'},
#              {'Source': 'Metacritic', 'Value': '50/100'}],
#  'Released': '08 Nov 2019',
#  'Response': 'True',
#  'Runtime': '103 min',
#  'Title': 'Last Christmas',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'George Michael (inspired by: the song "Last Christmas",  written '
#            'and composed by), Emma Thompson (story by), Greg Wise (story by), '
#            'Emma Thompson (screenplay by), Bryony Kimmings (screenplay by)',
#  'Year': '2019',
#  'imdbID': 'tt8623904',
#  'imdbRating': '6.6',
#  'imdbVotes': '14,450'}
# {'Actors': "Samara Weaving, Adam Brody, Mark O'Brien, Henry Czerny",
#  'Awards': '7 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'Canada, USA',
#  'DVD': '26 Nov 2019',
#  'Director': 'Matt Bettinelli-Olpin, Tyler Gillett',
#  'Genre': 'Comedy, Horror, Mystery, Thriller',
#  'Language': 'English, Latin',
#  'Metascore': '64',
#  'Plot': "A bride's wedding night takes a sinister turn when her eccentric new "
#          'in-laws force her to take part in a terrifying game.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYzBkMzAyMDUtZTFkZS00OWUyLTgwM2ItNGI3MTQ5NzA3NTVkXkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_SX300.jpg',
#  'Production': 'Fox Searchlight Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.9/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '88%'},
#              {'Source': 'Metacritic', 'Value': '64/100'}],
#  'Released': '21 Aug 2019',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': 'Ready or Not',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Guy Busick, Ryan Murphy',
#  'Year': '2019',
#  'imdbID': 'tt7798634',
#  'imdbRating': '6.9',
#  'imdbVotes': '43,120'}
# {'Actors': 'Jason Schwartzman, Rashida Jones, Joan Cusack, J.K. Simmons',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'Spain',
#  'DVD': 'N/A',
#  'Director': 'Sergio Pablos',
#  'Genre': 'Animation, Adventure, Comedy, Family',
#  'Language': 'English',
#  'Metascore': '62',
#  'Plot': 'A simple act of kindness always sparks another, even in a frozen, '
#          "faraway place. When Smeerensburg's new postman, Jesper, befriends "
#          'toymaker Klaus, their gifts melt an age-old feud and deliver a '
#          'sleigh full of holiday traditions.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMWYwOThjM2ItZGYxNy00NTQwLWFlZWEtM2MzM2Q5MmY3NDU5XkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.4/10'},
#              {'Source': 'Metacritic', 'Value': '62/100'}],
#  'Released': '08 Nov 2019',
#  'Response': 'True',
#  'Runtime': '96 min',
#  'Title': 'Klaus',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Zach Lewis, Jim Mahoney, Sergio Pablos (story by)',
#  'Year': '2019',
#  'imdbID': 'tt4729430',
#  'imdbRating': '8.4',
#  'imdbVotes': '11,671'}
# {'Actors': 'Robert De Niro, Al Pacino, Joe Pesci, Harvey Keitel',
#  'Awards': 'Nominated for 5 Golden Globes. Another 35 wins & 159 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '27 Nov 2019',
#  'Director': 'Martin Scorsese',
#  'Genre': 'Biography, Crime, Drama',
#  'Language': 'English, Italian, Latin, Spanish',
#  'Metascore': '94',
#  'Plot': 'A mob hitman recalls his possible involvement with the slaying of '
#          'Jimmy Hoffa.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMGUyM2ZiZmUtMWY0OC00NTQ4LThkOGUtNjY2NjkzMDJiMWMwXkEyXkFqcGdeQXVyMzY0MTE3NzU@._V1_SX300.jpg',
#  'Production': 'Netflix',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.2/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '96%'},
#              {'Source': 'Metacritic', 'Value': '94/100'}],
#  'Released': '27 Nov 2019',
#  'Response': 'True',
#  'Runtime': '209 min',
#  'Title': 'The Irishman',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Steven Zaillian (screenplay), Charles Brandt (book)',
#  'Year': '2019',
#  'imdbID': 'tt1302006',
#  'imdbRating': '8.2',
#  'imdbVotes': '144,536'}
# {'Actors': 'Ed Skrein, Patrick Wilson, Woody Harrelson, Luke Evans',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, China',
#  'DVD': 'N/A',
#  'Director': 'Roland Emmerich',
#  'Genre': 'Action, Drama, History, War',
#  'Language': 'English, Japanese, Mandarin',
#  'Metascore': '47',
#  'Plot': 'The story of the Battle of Midway, told by the leaders and the '
#          'sailors who fought it.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMGVkNGMyMGEtMDNmOC00ZGYyLWEzOTItODdjMzRlZTk4MzUwXkEyXkFqcGdeQXVyODM2Njg2OTg@._V1_SX300.jpg',
#  'Production': 'Summit Entertainment',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.9/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '43%'},
#              {'Source': 'Metacritic', 'Value': '47/100'}],
#  'Released': '08 Nov 2019',
#  'Response': 'True',
#  'Runtime': '138 min',
#  'Title': 'Midway',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Wes Tooke',
#  'Year': '2019',
#  'imdbID': 'tt6924650',
#  'imdbRating': '6.9',
#  'imdbVotes': '16,178'}
# {'Actors': 'Idris Elba, Francesca Hayward, Taylor Swift, Ian McKellen',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'UK, USA',
#  'DVD': 'N/A',
#  'Director': 'Tom Hooper',
#  'Genre': 'Comedy, Drama, Family, Fantasy, Musical',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A tribe of cats called the Jellicles must decide yearly which one '
#          'will ascend to the Heaviside Layer and come back to a new Jellicle '
#          'life.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTE4NWRhYmQtOTY4YS00OWMwLWEwYWUtZjVjNDhhODc5YzNmXkEyXkFqcGdeQXVyODkzNTgxMDg@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'PG',
#  'Ratings': [],
#  'Released': '20 Dec 2019',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Cats',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'T.S. Eliot (poetry collection "Old Possum\'s Books of Practical '
#            'Cats"), Lee Hall (screenplay), Tom Hooper (screenplay), Andrew '
#            'Lloyd Webber (musical)',
#  'Year': '2019',
#  'imdbID': 'tt5697572',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# {'Actors': 'Tessa Thompson, Justin Theroux, Sam Elliott, Ashley Jensen',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Charlie Bean',
#  'Genre': 'Adventure, Comedy, Drama, Family, Musical, Romance',
#  'Language': 'English',
#  'Metascore': '48',
#  'Plot': 'CGI and live-action re-imagining of the 1955 Disney classic.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BM2U3ZDBkYWUtNDY3Ny00OTliLTgxNTAtY2QwZTQxMmEwOTQ1XkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'},
#              {'Source': 'Metacritic', 'Value': '48/100'}],
#  'Released': '12 Nov 2019',
#  'Response': 'True',
#  'Runtime': '103 min',
#  'Title': 'Lady and the Tramp',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Andrew Bujalski (screenplay by), Kari Granlund',
#  'Year': '2019',
#  'imdbID': 'tt8096832',
#  'imdbRating': '6.5',
#  'imdbVotes': '2,766'}
# {'Actors': 'Ryan Reynolds, Mélanie Laurent, Manuel Garcia-Rulfo, Ben Hardy',
#  'Awards': '2 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '13 Dec 2019',
#  'Director': 'Michael Bay',
#  'Genre': 'Action, Thriller',
#  'Language': 'English',
#  'Metascore': '41',
#  'Plot': 'Meet a new kind of action hero. Six untraceable agents, totally off '
#          "the grid. They've buried their pasts so they can change the future.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzE2ZjQxNjEtNmI2ZS00ZmU0LTg4M2YtYzVhYmRiYWU0YzI1XkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_SX300.jpg',
#  'Production': 'Netflix',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '32%'},
#              {'Source': 'Metacritic', 'Value': '41/100'}],
#  'Released': '13 Dec 2019',
#  'Response': 'True',
#  'Runtime': '127 min',
#  'Title': '6 Underground',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Paul Wernick, Rhett Reese',
#  'Year': '2019',
#  'imdbID': 'tt8106534',
#  'imdbRating': '6.2',
#  'imdbVotes': '34,632'}

# %%
len(title_list)
# Out:
# 81

# %%
data['title'] = title_list
data['box_office'] = box_office_list
data['country'] = country_list
data['genre'] = genre_list
data['director'] = director_list
data['metascore'] = metascore_list
data['production'] = production_list
data['rating'] = rating_list
data['IMDB_rating'] = IMDB_rating_list 
data['rotten_tomatoes_rating'] = rotten_tomatoes_rating_list
data['runtime'] = runtime_list
data['type'] = type_list
data['IMDB_votes'] = imdb_votes_list

# %%
#drop any movies that ddo not include USA for country: 1) Canada 2) Spain 3) France 4) Ireland, UK, Belgium, Finland 
data['country'].value_counts()
# Out:
# USA                                         35
# UK, USA                                      6
# USA, Canada                                  5
# USA, China                                   5
# Canada, USA                                  3
# USA, Japan                                   2
# USA, UK                                      2
# Canada                                       2
# Japan, USA                                   1
# USA, France, Japan                           1
# UK, Norway, Canada, USA, France, Germany     1
# USA, UK, Bulgaria, Canada                    1
# Denmark, Norway, Australia, USA              1
# USA, Serbia, Canada                          1
# Finland, USA                                 1
# USA, Spain, Bulgaria                         1
# Canada, Norway, USA                          1
# Japan, Canada, USA                           1
# Spain                                        1
# France                                       1
# USA, UK, China                               1
# USA, UK, Australia, Canada                   1
# USA, South Africa                            1
# France, USA                                  1
# Ireland, UK, Belgium, Finland                1
# USA, Japan, UK, Canada                       1
# USA, Spain, Hungary                          1
# USA, Australia                               1
# France, Canada, USA                          1
# Name: country, dtype: int64

# %%
data = data[data.country != 'Canada']
data = data[data.country != 'Spain']
data = data[data.country != 'France']
data = data[data.country != 'Ireland, UK, Belgium, Finland']

# %%
data.to_csv('Resources/2019_movie_data.csv', index=False)
