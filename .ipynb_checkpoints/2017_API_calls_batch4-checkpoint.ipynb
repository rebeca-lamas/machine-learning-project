# %%
import pandas as pd
import requests
import json
import time
from pprint import pprint
from config import API_KEY

# %%
data = pd.read_csv('Resources/title_webscraped/titles_2017_batch4.csv')
df =  data.count()
df
# Out:
# title    848
# dtype: int64

# %%
title_id = []
box_office_list = []
country_list = []
genre_list = []
director_list = []
metascore_list = []
production_list = []
rating_list = []
IMDB_rating_list = [] 
rotten_tomatoes_rating_list = []
runtime_list = []
title_list = []
type_list = []
imdb_votes_list = []

# %%
movies = data['title']
total_movies = len(movies)

# %%
for i in range(total_movies):
    movie = movies[i]
    url = "http://www.omdbapi.com/?i=" + movie + "&apikey=" + API_KEY
    response = (requests.get(url).text)
    response_json = json.loads(response)
    print('-------------------')
    print(f'movie id {movie}')
    print('-------------------')
    pprint(response_json)
    
    try:
        box_office_list.append(response_json['BoxOffice'])
        country_list.append(response_json['Country'])
        genre_list.append(response_json['Genre'])
        director_list.append(response_json['Director'])
        metascore_list.append(response_json['Metascore'])
        production_list.append(response_json['Production'])
        rating_list.append(response_json['Rated'])
        IMDB_rating_list.append(response_json['imdbRating'])
        try:
            if not response_json['Ratings']:
                rotten_tomatoes_rating_list.append('NA')
            elif response_json['Ratings'][0]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][0]['Value'])
            elif response_json['Ratings'][1]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][1]['Value'])
            else:
                rotten_tomatoes_rating_list.append('NA')
        except IndexError:
            rotten_tomatoes_rating_list.append('NA')
        runtime_list.append(response_json['Runtime'])
        title_list.append(response_json['Title'])
        type_list.append(response_json['Type'])
        imdb_votes_list.append(response_json['imdbVotes'])
        title_id.append(response_json['imdbID'])
    except KeyError:
        pass
    time.sleep(1)
# Out:
# -------------------
# movie id tt2140507
# -------------------
# {'Actors': 'Tom Holland, Michael Shannon, Benedict Cumberbatch, Katherine '
#            'Waterston',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Alfonso Gomez-Rejon',
#  'Genre': 'Biography, Drama, History',
#  'Language': 'English',
#  'Metascore': '55',
#  'Plot': 'The dramatic story of the cutthroat race between electricity titans '
#          'Thomas Edison and George Westinghouse to determine whose electrical '
#          'system would power the modern world.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYWIxOWU4OGUtMTY1Ny00YmY3LWFhOTgtNzk3NmExYjUwMTFmXkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_SX300.jpg',
#  'Production': '101 Studios',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.4/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '29%'},
#              {'Source': 'Metacritic', 'Value': '55/100'}],
#  'Released': '25 Oct 2019',
#  'Response': 'True',
#  'Runtime': '102 min',
#  'Title': "The Current War: Director's Cut",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Mitnick',
#  'Year': '2017',
#  'imdbID': 'tt2140507',
#  'imdbRating': '6.4',
#  'imdbVotes': '7,477'}
# -------------------
# movie id tt3228450
# -------------------
# {'Actors': 'Vanessa Coleman, Sean Morelli, Marilyn Weinmann, Jean Sulli',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Guy Bodart',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "On All Hallows' Eve 1457, A dark secret society of priests led by "
#          'the Evil Countess Victoria (Vanessa Coleman) and Ambrus (Stephen '
#          'Manley) are conducting diabolical ceremonies in which ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BN2QyZWNkYTYtOWMzMS00YzczLTllNWUtOGRjNDRkYTE1ZTFjXkEyXkFqcGdeQXVyNDcwMjE2MzU@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': "The Curse of All Hallows' Eve",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Lorelei Lanford',
#  'Year': '2017',
#  'imdbID': 'tt3228450',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5816936
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jason Phelps',
#  'Genre': 'Action, Adventure, Comedy',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'Alex Cox presents, a Kung Fu adventure following the mythic Dragon '
#          'Sword and the path of destruction it leaves through the land until a '
#          'hero will rise to stop it.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZTdlM2NiZDQtOWI3OS00MGIzLTllZDAtNjE4ZjQ0MjE2YzBjXkEyXkFqcGdeQXVyMjEzNjQ3ODQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Curse of the Dragon Sword',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jason Phelps',
#  'Year': '2017',
#  'imdbID': 'tt5816936',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4864442
# -------------------
# {'Actors': 'Daniel Felix de Weldon',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Michael Arabian',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Custodian',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Arabian, Allen Nalasco, Daniel Felix de Weldon',
#  'Year': '2016',
#  'imdbID': 'tt4864442',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6517046
# -------------------
# {'Actors': 'Wolf Lee Counsel, Rebecca Teresia, Jenn Boneza, Jason Lee Hoy',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Michael S. McClafferty',
#  'Genre': 'Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': '"The Cutting Truth" - a Drama/Suspense highlighting the comparison '
#          'of actual thoughts versus real-time reaction. Denise Armstrong and '
#          'her husband Ronald, host a dinner party with some of ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzk4YzYyNjYtZmY1YS00OTFiLTg5MGItMzExYjcyZjdiYTE3XkEyXkFqcGdeQXVyNDc1Njg4ODA@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.3/10'}],
#  'Released': '15 Jun 2017',
#  'Response': 'True',
#  'Runtime': '49 min',
#  'Title': 'The Cutting Truth',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael S. McClafferty',
#  'Year': '2017',
#  'imdbID': 'tt6517046',
#  'imdbRating': '8.3',
#  'imdbVotes': '7'}
# -------------------
# movie id tt6149282
# -------------------
# {'Actors': 'Doug Jones, Cassie Meder, John Soares',
#  'Awards': '1 win.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'John Soares',
#  'Genre': 'Action',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A member of a secret order of knights and his estranged sister take '
#          'on the mob and a troubled scientist in pursuit of the stolen Danger '
#          'Element, which they believe has the power to bring their father back '
#          'from the dead.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMWI0NjhiMDQtOTZlNi00YTFmLWIyODQtYTAyZTdhZDk1YzM1XkEyXkFqcGdeQXVyMTQ0NTQ1MzQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.8/10'}],
#  'Released': '01 Aug 2017',
#  'Response': 'True',
#  'Runtime': '100 min',
#  'Title': 'The Danger Element',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'John Soares',
#  'Year': '2017',
#  'imdbID': 'tt6149282',
#  'imdbRating': '3.8',
#  'imdbVotes': '59'}
# -------------------
# movie id tt6813056
# -------------------
# {'Actors': 'Wee Matt, Fay Lytle, Josh Connor, Art Roberts',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Sam Salerno',
#  'Genre': 'Comedy, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A dwarf named Ed falls in love with a big woman named Linda. The '
#          "world doesn't think they belong together, but they believe they do. "
#          'He climbs into her womb to be "born again."',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZjQ0NDY4OGQtMmNmMS00ZmFlLWEzOTEtNDVjMDQ1M2NjODU0XkEyXkFqcGdeQXVyMjg0OTAyMTY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'}],
#  'Released': '29 Oct 2017',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'The Dark Side of the Womb',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Sam Salerno',
#  'Year': '2017',
#  'imdbID': 'tt6813056',
#  'imdbRating': '5.8',
#  'imdbVotes': '29'}
# -------------------
# movie id tt1648190
# -------------------
# {'Actors': 'Matthew McConaughey, Idris Elba, Tom Taylor, Dennis Haysbert',
#  'Awards': '3 nominations.',
#  'BoxOffice': '$50,644,837',
#  'Country': 'USA',
#  'DVD': '31 Oct 2017',
#  'Director': 'Nikolaj Arcel',
#  'Genre': 'Action, Adventure, Fantasy, Horror, Sci-Fi, Western',
#  'Language': 'English',
#  'Metascore': '34',
#  'Plot': 'A boy haunted by visions of a dark tower from a parallel reality '
#          "teams up with the tower's disillusioned guardian to stop an evil "
#          'warlock known as the Man in Black who plans to use the boy to '
#          'destroy the tower and open the gates of Hell.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTU3MjUwMzQ3MF5BMl5BanBnXkFtZTgwMjcwNjkxMjI@._V1_SX300.jpg',
#  'Production': 'Sony Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '16%'},
#              {'Source': 'Metacritic', 'Value': '34/100'}],
#  'Released': '04 Aug 2017',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': 'The Dark Tower',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Akiva Goldsman (screenplay by), Jeff Pinkner (screenplay by), '
#            'Anders Thomas Jensen (screenplay by), Nikolaj Arcel (screenplay '
#            'by), Stephen King (based on "The Dark Tower" novels by)',
#  'Year': '2017',
#  'imdbID': 'tt1648190',
#  'imdbRating': '5.6',
#  'imdbVotes': '116,221'}
# -------------------
# movie id tt6254344
# -------------------
# {'Actors': 'Jet Ainsworth, Noelle Anderson, Danielle Brower, K.D. Gardner',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jet Ainsworth',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Jan 2017',
#  'Response': 'True',
#  'Runtime': '52 min',
#  'Title': 'The Dash',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jet Ainsworth, K.D. Gardner',
#  'Year': '2017',
#  'imdbID': 'tt6254344',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6893214
# -------------------
# {'Actors': 'Bennett Duckworth, Bekah Beran, Brandon Ingram, Rocko Jerome',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jimmy Humphrey',
#  'Genre': 'Comedy, Romance, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Cinematic theories of fate, future, and dip-n-dots are put to the '
#          'test as a lovelorn thirty something is suddenly thrown back into the '
#          'past to relive a relationship over and over in an never-ending '
#          'anomaly he can never escape.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjE2NWYxMDQtMWFjZS00OTE3LWI1NzUtMWE0MDMxNmIzNGUwXkEyXkFqcGdeQXVyMTk0OTkxNzU@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '20 Mar 2017',
#  'Response': 'True',
#  'Runtime': '120 min',
#  'Title': 'The Day I Met Her',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jimmy Humphrey',
#  'Year': '2017',
#  'imdbID': 'tt6893214',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6784770
# -------------------
# {'Actors': 'David Irwin, Austin Jolly, Lindsay Marquino, Gabriel Paal',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Michael J. Saul',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An anthology of seven short, experimental films.The films reflect '
#          "the filmmaker's obsession with daydreaming in the work he's created "
#          'over 40 years.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOWQwMDIxZWQtYTMzMi00NGI5LWEyMzYtZWYyOTA2YzkyZGJkXkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '18 Apr 2017',
#  'Response': 'True',
#  'Runtime': '75 min',
#  'Title': "The Daydreamer's Notebook",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael J. Saul',
#  'Year': '2017',
#  'imdbID': 'tt6784770',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5966246
# -------------------
# {'Actors': 'Matthew Sunderland, Brandie Sylfae, Theora Moench, John Branch',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Edward Martin III',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'None of us ever really know how we affected the world around us '
#          "until it's too late. The Dead explores that space, focusing on the "
#          'personal, private, and disturbingly intimate confessions ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMDAxOTRkOGMtNmMzNy00MTkyLTlmMGMtY2MxMTJmNTBlMGFhXkEyXkFqcGdeQXVyMDY4OTE3Mg@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '87 min',
#  'Title': 'The Dead',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Amber Bariaktari, Edward Martin III',
#  'Year': '2016',
#  'imdbID': 'tt5966246',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7329916
# -------------------
# {'Actors': 'Ellie Church, Nate Coulombe, Dustin Wade Hoke, Frankie McKay',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jason Hoover, Bobby Easley(co-director)',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://ia.media-imdb.com/images/M/MV5BMTRjZDE4NzQtNTIwOC00MGY5LWJlMWYtZWJjZjkzZWMwNjgyXkEyXkFqcGdeQXVyMjcyMjUwMjA@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.8/10'}],
#  'Released': '30 Jun 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Dead Bodies in #223',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jason Hoover',
#  'Year': '2017',
#  'imdbID': 'tt7329916',
#  'imdbRating': '6.8',
#  'imdbVotes': '6'}
# -------------------
# movie id tt5646616
# -------------------
# {'Actors': 'Patrick C. Johnson, Sean Johnson, Noah Talavera-Greenberg, Chryso '
#            'Tsoumpelis',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Sean Johnson, Douglas Weiss(co-director)',
#  'Genre': 'Action, Adventure, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An operative with the CIA and a new recruit finds himself in a '
#          'larger situation than he realizes after his mission goes awry.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDYxMjYxMzUtYWRlYS00ODczLWE4MmQtMGQyMDQyNjk0OTg3XkEyXkFqcGdeQXVyMzEyMDc3MjU@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '22 Mar 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': "The Dead Don't Care for Vengeance",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Patrick C. Johnson (story), Sean Johnson (screenplay), Sean '
#            'Johnson (story), Douglas Weiss (screenplay), Douglas Weiss (story)',
#  'Year': '2017',
#  'imdbID': 'tt5646616',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6572748
# -------------------
# {'Actors': 'Jessica Awh, Elijah Wallace, Johnna McCarthy, Connor Weaver',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'David Van Hooser',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A different kind of haunted house suspense thriller movie - about '
#          'four young filmmakers making a haunted house suspense thriller '
#          'movie.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': 'The Dead Half',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Craig Anderson (screenwriter), David Van Hooser (screenwriter)',
#  'Year': '2017',
#  'imdbID': 'tt6572748',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7012616
# -------------------
# {'Actors': 'Fortune Belisle, Larry Biela, Joe Chazaray, Joseph Chazaray',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Andre Boyd',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYzFmMDM0MjYtNmE1Ni00YWE4LTlmZjAtZDlkMjNkNDM5ZDUxXkEyXkFqcGdeQXVyNjQ0MzI5MDQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '16 Nov 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Deadly Drug',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Andre Boyd',
#  'Year': '2017',
#  'imdbID': 'tt7012616',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7713690
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt7275856
# -------------------
# {'Actors': 'Debbie Hartner, Joy White, Tom Maseth, Katrina Wiskup',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Stephen Mitchell',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The Dearly Departed, an ensemble comedy dealing with the aftermath '
#          'of the passing of a family matriarch and the proliferation of '
#          'schemes and conniving plots on the part of family members as well as '
#          'a ragtag group of total strangers.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTk5NjlhZGQtOTlhZS00ZThhLWEwNWYtOWQ5NzU5ZTMzYWFlXkEyXkFqcGdeQXVyODE1MzQzNA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '15 Aug 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Dearly Departed',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Stephen Mitchell',
#  'Year': '2017',
#  'imdbID': 'tt7275856',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4686844
# -------------------
# {'Actors': 'Olga Kurylenko, Tom Brooke, Paddy Considine, Justin Edwards',
#  'Awards': 'Nominated for 2 BAFTA Film Awards. Another 18 wins & 33 '
#            'nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'UK, France, Belgium, Canada, USA',
#  'DVD': '19 Jun 2018',
#  'Director': 'Armando Iannucci',
#  'Genre': 'Comedy, Drama, History',
#  'Language': 'English',
#  'Metascore': '88',
#  'Plot': 'Moscow, 1953. After being in power for nearly 30 years, Soviet '
#          'dictator Josef Stalin takes ill and quickly dies. Now the members of '
#          'the Council of Ministers scramble for power.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTcxMDc1NjcyNl5BMl5BanBnXkFtZTgwNDU0NDYxMzI@._V1_SX300.jpg',
#  'Production': 'IFC Films',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.2/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '96%'},
#              {'Source': 'Metacritic', 'Value': '88/100'}],
#  'Released': '09 Mar 2018',
#  'Response': 'True',
#  'Runtime': '107 min',
#  'Title': 'The Death of Stalin',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Armando Iannucci, David Schneider, Ian Martin, Peter Fellows '
#            '(additional material by), Fabien Nury (based on the comic book '
#            '"The Death of Stalin" by), Thierry Robin (based on the comic book '
#            '"The Death of Stalin" by), Fabien Nury (original screenplay by)',
#  'Year': '2017',
#  'imdbID': 'tt4686844',
#  'imdbRating': '7.2',
#  'imdbVotes': '69,404'}
# -------------------
# movie id tt7069672
# -------------------
# {'Actors': 'Pete Perez, Oliver Burbage, Shaieynne Ruffin, Tommy Leonard',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Delia Ruffin, Nicolas Wood',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A Military squad without a command and band of survivors group '
#          'together in hopes of finding salvation.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNzM0Y2Y1YWUtNGY0MC00YjhhLTkzM2YtNWI2MGJmNTZmYjFiXkEyXkFqcGdeQXVyNDU0MTkyNDI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.3/10'}],
#  'Released': '27 Aug 2017',
#  'Response': 'True',
#  'Runtime': '109 min',
#  'Title': 'The Decayed',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Delia Ruffin',
#  'Year': '2017',
#  'imdbID': 'tt7069672',
#  'imdbRating': '3.3',
#  'imdbVotes': '28'}
# -------------------
# movie id tt6320860
# -------------------
# {'Actors': 'Luise Helm, Amani Dorn, Sarah Rose Butler, Kelechi Nwadibia',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Frazer Bradshaw',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Deep Sky',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Frazer Bradshaw',
#  'Year': '2017',
#  'imdbID': 'tt6320860',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4458946
# -------------------
# {'Actors': 'Joseph Rene, Madeline Thelton, Chloe Lee, Timothy Talbott',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '02 Nov 2018',
#  'Director': 'Joey Moran',
#  'Genre': 'Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Years after his release from jail, Sam Parsons is trying to rebuild '
#          'his life with his wife Courtney and their young daughter Harper. He '
#          'works hard to provide for his family and afford their...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMDkwYjhmMmUtYzlkMS00ZWRjLWIwNGMtNTk4NzE0MDFmOWRmXkEyXkFqcGdeQXVyNTY0MzIyNTk@._V1_SX300.jpg',
#  'Production': 'Skeleton Kreek Film',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.8/10'}],
#  'Released': '16 May 2017',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': 'The Demon Inside',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joey Moran',
#  'Year': '2017',
#  'imdbID': 'tt4458946',
#  'imdbRating': '4.8',
#  'imdbVotes': '48'}
# -------------------
# movie id tt6069336
# -------------------
# {'Actors': 'Johnny Ray Gibbs, Adriana Herrera, Jacob Kyle Young, Kai Valerius',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Rick Vargas',
#  'Genre': 'Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjdmMmFkMGYtMjRiZS00NzYyLWI4OTgtNWZiZjUxNzgzNDYzL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNTA4OTQ1NzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '17 Nov 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Demonic Dead',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Rick Vargas',
#  'Year': '2017',
#  'imdbID': 'tt6069336',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4301112
# -------------------
# {'Actors': 'Michael Rispoli, Charlotte Kirk, Patch Darragh, Hampton Fluker',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'N/A',
#  'DVD': 'N/A',
#  'Director': 'Jamison M. LoCascio',
#  'Genre': 'Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Down on their luck and desperate for a measure of success, two '
#          'wannabe screenwriters decide to fully explore the depths of murder '
#          'and crime within their story only to discover their obsession with '
#          'their work has made it all too real.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Depths',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jamison M. LoCascio, Robert Spat',
#  'Year': '2016',
#  'imdbID': 'tt4301112',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5810368
# -------------------
# {'Actors': 'Alex Frnka, Sarah Davenport, Henry Zaga, Coy Stewart',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Blair Hayes',
#  'Genre': 'Comedy, Horror, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Five high school students are having Saturday detention in a former '
#          'Correctional Facility, and must find a way to outsmart an unseen '
#          'menace out to kill them.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BN2IyNDM5YzUtMTgyZS00YzFlLTlmYzMtZTUzM2QxOWRhOWVmXkEyXkFqcGdeQXVyMDUwNjI2Mg@@._V1_SX300.jpg',
#  'Production': 'Fancy Pants Films',
#  'Rated': 'Unrated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.4/10'}],
#  'Released': '12 Sep 2017',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Deadly Detention',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Casie Tabanou, Alison Spuck McNeeley',
#  'Year': '2017',
#  'imdbID': 'tt5810368',
#  'imdbRating': '3.4',
#  'imdbVotes': '1,049'}
# -------------------
# movie id tt6968306
# -------------------
# {'Actors': 'Graham Abraham, Allan Alexander, Amanda C., Brandon Atk Cepeda',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Graham Abraham',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A state police officer named Andrew must protect his young daughter '
#          'Carrie while searching for a serial killer called Nathan.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '16 Jun 2019',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': "The Detective's Daughter",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Graham Abraham (screenplay), Graham Abraham (story)',
#  'Year': '2017',
#  'imdbID': 'tt6968306',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4596052
# -------------------
# {'Actors': 'Allen Kellogg, Meredith Kochan, Spencer Jay Kim, Ashley Bossard',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Allen Kellogg',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Cynthia O'Neil enters a haunted asylum known as the Madison Seminary "
#          'in search of her father who went missing in the asylum while '
#          'shooting a reality television show.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTQzODY5MzQ3M15BMl5BanBnXkFtZTgwMzg1NTQ0NjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.7/10'}],
#  'Released': '16 Jan 2017',
#  'Response': 'True',
#  'Runtime': '96 min',
#  'Title': "The Devil's Toy Box",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Allen Kellogg, Spencer Jay Kim',
#  'Year': '2017',
#  'imdbID': 'tt4596052',
#  'imdbRating': '3.7',
#  'imdbVotes': '211'}
# -------------------
# movie id tt7458072
# -------------------
# {'Actors': 'Justin Frey, Caleb Murray, Jayden Townsend, The Real Mael',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Justin Frey',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When a group of kids are being targeted by an evil ancient demon '
#          'called, "The Devourer." They must stick together and find out why '
#          "he's targeting them.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMDhlYWM0ZDAtMmRiOC00ZmU2LWI5YWUtNTUwNGMxYmVhMTllXkEyXkFqcGdeQXVyODA5Nzc3NjQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '07 Nov 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Devourer',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2017',
#  'imdbID': 'tt7458072',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6624190
# -------------------
# {'Actors': 'Brianna Jerina, Ryan Roberson, Mateo Santos, Victoria Zombo',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Steven Potter',
#  'Genre': 'Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Emily is a girl trying to outrun a troubling past. She starts to '
#          'loose that race when she is ready to leave for college where she '
#          'will find herself trying to control murderous urges. She is...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZGZhY2UzMWYtZDdiYi00MzA0LWIzYTktY2VkMGM5N2IzNTkwXkEyXkFqcGdeQXVyNTgwMDk4Njk@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Diary of Emily',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jamie Atwater-Chiappetta',
#  'Year': '2017',
#  'imdbID': 'tt6624190',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3203620
# -------------------
# {'Actors': 'Michael Chernus, Taylor Rae Almonte, Steve Coogan, Charlie Plummer',
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '08 Aug 2017',
#  'Director': 'Oren Moverman',
#  'Genre': 'Crime, Drama, Thriller',
#  'Language': 'English',
#  'Metascore': '57',
#  'Plot': 'Two sets of wealthy parents meet for dinner to decide what to do '
#          'about a crime their sons have committed.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjM0ODg1NTMzMV5BMl5BanBnXkFtZTgwMjczMzA2MTI@._V1_SX300.jpg',
#  'Production': 'Chubbco Film Co.',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.5/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '46%'},
#              {'Source': 'Metacritic', 'Value': '57/100'}],
#  'Released': '05 May 2017',
#  'Response': 'True',
#  'Runtime': '120 min',
#  'Title': 'The Dinner',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Herman Koch (based on the novel by), Oren Moverman (screenplay by)',
#  'Year': '2017',
#  'imdbID': 'tt3203620',
#  'imdbRating': '4.5',
#  'imdbVotes': '6,888'}
# -------------------
# movie id tt7580708
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt3521126
# -------------------
# {'Actors': 'Dave Franco, James Franco, Seth Rogen, Ari Graynor',
#  'Awards': 'Nominated for 1 Oscar. Another 30 wins & 80 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '13 Mar 2018',
#  'Director': 'James Franco',
#  'Genre': 'Biography, Comedy, Drama',
#  'Language': 'English',
#  'Metascore': '76',
#  'Plot': 'When Greg Sestero, an aspiring film actor, meets the weird and '
#          'mysterious Tommy Wiseau in an acting class, they form a unique '
#          'friendship and travel to Hollywood to make their dreams come true.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOGNkMzliMGMtMDI5Ni00OTZkLTgyMTYtNzk5ZTY1NjVhYjVmXkEyXkFqcGdeQXVyNTAzMTY4MDA@._V1_SX300.jpg',
#  'Production': 'A24',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.4/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '91%'},
#              {'Source': 'Metacritic', 'Value': '76/100'}],
#  'Released': '08 Dec 2017',
#  'Response': 'True',
#  'Runtime': '104 min',
#  'Title': 'The Disaster Artist',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Scott Neustadter (screenplay by), Michael H. Weber (screenplay '
#            'by), Greg Sestero (based on the book "The Disaster Artist: My Life '
#            'Inside The Room,  the Greatest Bad Movie Ever Made" by), Tom '
#            'Bissell (based on the book "The Disaster Artist: My Life Inside '
#            'The Room,  the Greatest Bad Movie Ever Made" by)',
#  'Year': '2017',
#  'imdbID': 'tt3521126',
#  'imdbRating': '7.4',
#  'imdbVotes': '120,373'}
# -------------------
# movie id tt4721230
# -------------------
# {'Actors': 'Lily Morris, Matthew Scislowski, Kevin Manning, Kelly Gray',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kevin Manning',
#  'Genre': 'Mystery',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjkzMDk0OTkzNV5BMl5BanBnXkFtZTgwODUxMDQwNjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '20 Dec 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Discarded',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kevin Manning',
#  'Year': '2015',
#  'imdbID': 'tt4721230',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5155780
# -------------------
# {'Actors': 'Robert Redford, Mary Steenburgen, Brian McCarthy, Jason Segel',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '31 Mar 2017',
#  'Director': 'Charlie McDowell',
#  'Genre': 'Drama, Romance, Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': '54',
#  'Plot': 'Two years after the afterlife is scientifically proven, a man '
#          'attempts to help a young woman break away from her dark past.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTUzNjE5ODYwN15BMl5BanBnXkFtZTgwMTY4MjQ1MTI@._V1_SX300.jpg',
#  'Production': 'Netflix',
#  'Rated': 'TV-MA',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '45%'},
#              {'Source': 'Metacritic', 'Value': '54/100'}],
#  'Released': '31 Mar 2017',
#  'Response': 'True',
#  'Runtime': '102 min',
#  'Title': 'The Discovery',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Charlie McDowell, Justin Lader',
#  'Year': '2017',
#  'imdbID': 'tt5155780',
#  'imdbRating': '6.3',
#  'imdbVotes': '26,146'}
# -------------------
# movie id tt5746464
# -------------------
# {'Actors': 'Chelsea Tavares, Spoken Reasons, Artrial Clark, Delano Holmes',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Mike Cunliffe',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A med student, Micah sets out to obtain independence from his '
#          'parents when he moves in with his aloof best friend (Duo) only to '
#          "find out it moving out wasn't what is was cracked up to be. ...",
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Roomies',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Camara Davis',
#  'Year': '2016',
#  'imdbID': 'tt5746464',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7078938
# -------------------
# {'Actors': 'Michael Carr, Jason Lane Fenton, Kate Ashlynn, Marty Seeger',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jason Lane Fenton',
#  'Genre': 'Comedy, Romance, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An eccentric dog walker finds himself in the dog house when he '
#          'becomes obsessed with one of his clients.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODAxMGVlNTYtN2YzNC00MDhiLWIwNzUtOTQ4OTJhYTc2ZjkwXkEyXkFqcGdeQXVyMjM1NzkzNTU@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '46 min',
#  'Title': 'The Dog Stalker',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jason Lane Fenton',
#  'Year': '2017',
#  'imdbID': 'tt7078938',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5883990
# -------------------
# {'Actors': 'Antonette Bracks, Matt DeHaven, Collin Lee Ellis, Tyler Guillory',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'James Elza Domine',
#  'Genre': 'Comedy, Drama, Musical',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Part of a combined stage/film project, this tale of gang warfare and '
#          'romantic intrigue comprises imaginative and colorful language '
#          'creating a mysterious reality which unfolds with continuously '
#          'evolving waves of rhyme in rap poetry.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzYzODhjMWQtOWJhZC00Zjc1LWI2MTItODE1YjM2N2I3MDMyXkEyXkFqcGdeQXVyNTUxNzcwOTI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '13 Jul 2016',
#  'Response': 'True',
#  'Runtime': '107 min',
#  'Title': "The Dogs of War or That's What Friends Are For",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'James Elza Domine',
#  'Year': '2016',
#  'imdbID': 'tt5883990',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5176832
# -------------------
# {'Actors': 'Mindy Robinson, Ron Jeremy, Anthony Del Negro, Valeria Lukyanova',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': "Susannah O'Brien",
#  'Genre': 'Fantasy, Horror, Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When Chris and Andy order a model from an escort service, they find '
#          'that something is unnaturally wrong with Natasha, something deadly '
#          'wrong.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMDk5NzUwOTYtZjA2Ny00Zjk3LTk0OTMtNGQ3Y2M5MjllODlmXkEyXkFqcGdeQXVyMTU2ODA1MzI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'TV-MA',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.5/10'}],
#  'Released': '08 Dec 2017',
#  'Response': 'True',
#  'Runtime': '81 min',
#  'Title': 'The Doll',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': "Susannah O'Brien",
#  'Year': '2017',
#  'imdbID': 'tt5176832',
#  'imdbRating': '2.5',
#  'imdbVotes': '294'}
# -------------------
# movie id tt6929280
# -------------------
# {'Actors': 'Richàrd A. LaBon, Alen Rios, Alex Velazquez, Manny Velazquez',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Manny Velazquez',
#  'Genre': 'Fantasy, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A young man is having repeated nightmares about dolls trying to kill '
#          'him. The dreams continues and the nightmares starts to escalate.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjNiNGVkN2UtZTU2MS00MWQ3LThjMTctNjJhMGQ3MmQyZGQ5XkEyXkFqcGdeQXVyMjk4MzgyMjU@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'NOT RATED',
#  'Ratings': [],
#  'Released': '17 May 2017',
#  'Response': 'True',
#  'Runtime': '77 min',
#  'Title': 'The Dolls',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Manny Velazquez',
#  'Year': '2017',
#  'imdbID': 'tt6929280',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5585662
# -------------------
# {'Actors': 'Steve Richard Harris, Demetrius Stear, Katherine Flannery, Sara '
#            'Malakul Lane',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '22 Aug 2017',
#  'Director': 'Jared Cohn',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Russel Brody, a one-time successful playwright, works diligently on '
#          'a follow-up play that could land him back in the spotlight he so '
#          'early craves. With a baby on the way, however, and a ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZDVmYmQyMzQtZjhkOC00MGI3LWExYjgtMjRlMmE0YzE5OGM1XkEyXkFqcGdeQXVyMTYxOTg0Mjg@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.5/10'}],
#  'Released': '08 Aug 2017',
#  'Response': 'True',
#  'Runtime': '82 min',
#  'Title': 'The Domicile',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jared Cohn',
#  'Year': '2017',
#  'imdbID': 'tt5585662',
#  'imdbRating': '2.5',
#  'imdbVotes': '82'}
# -------------------
# movie id tt0874268
# -------------------
# {'Actors': 'David Arrow, Steven Berkoff, Claudia Christian, Maria Dinulescu',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'UK, USA',
#  'DVD': 'N/A',
#  'Director': 'Bruno Coppola',
#  'Genre': 'Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A highly decorated officer is betrayed by his own government after '
#          'years of dedicated service to his country. A hero in the "war on '
#          'terror" becomes imprisoned by the very policies put in place to '
#          'combat the terrorists.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTgwNTI1MzIzNl5BMl5BanBnXkFtZTcwNjAxMTU1MQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.4/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Dot Man',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'John Goodman',
#  'Year': '2017',
#  'imdbID': 'tt0874268',
#  'imdbRating': '7.4',
#  'imdbVotes': '44'}
# -------------------
# movie id tt5189772
# -------------------
# {'Actors': 'Dane Bowman, Chris Ciccarelli, Barry Finnegan, Mike Kopera',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Joe McClean',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'In a twisted maze of ex-lovers, old grudges, and new spouses, '
#          "friends who haven't seen each other in 20 years fall down a rabbit "
#          'hole of alcohol-fueled bad decisions.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDU3M2M1YjctMGM4ZC00MjkxLTljYTAtNzFmZWFjNDQ5NDVmXkEyXkFqcGdeQXVyMTM2NjI1NzM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '87 min',
#  'Title': 'The Drama Club',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joe McClean, Joe McClean',
#  'Year': '2017',
#  'imdbID': 'tt5189772',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4877488
# -------------------
# {'Actors': 'James Carpinello, Kirsten Grace Hoge, Scott Oakley, Jeff Rose',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Michael Clayton',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Jan 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Dunning Man',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Clayton',
#  'Year': '2016',
#  'imdbID': 'tt4877488',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6947684
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Michael Clayton',
#  'Genre': 'Action, Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Original music for The Dunning Man feature film.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'The Dunning Man Soundtrack',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2017',
#  'imdbID': 'tt6947684',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7193122
# -------------------
# {'Actors': 'Jayson Atz, Darryl Barton, Donna Beckham, David Broer',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Joel David Taylor',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Comedy about a middle aged good-ole-boy that just wants to go '
#          'fishing (beer-n-boom) with his daddy on his birthday. Mishaps and '
#          'misunderstandings get him arrested and investigated by P.O.T.U.S. '
#          'for terrorist activities.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '25 Dec 2017',
#  'Response': 'True',
#  'Runtime': '96 min',
#  'Title': 'The Edger Project',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Darrell Derbin, Joel David Taylor',
#  'Year': '2017',
#  'imdbID': 'tt7193122',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5482752
# -------------------
# {'Actors': 'Dionysius Akeem, Jessica David, Cindy Fernandez-Nixon, Marquita '
#            'Hefflin',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Mark Cross',
#  'Genre': 'Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A woman suffers from debilitating psychotic depression. Something '
#          'sinister is trying to communicate with her. Will she find out what '
#          'it is or will it kill her first?',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTM3NDU5NGQtNGQ4Ni00ZTE4LTllNjktMWYxMGJhNTBjYmE3XkEyXkFqcGdeQXVyMjA0NDY5ODI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.5/10'}],
#  'Released': '01 Sep 2017',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': 'The Edict',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Mark Cross',
#  'Year': '2017',
#  'imdbID': 'tt5482752',
#  'imdbRating': '4.5',
#  'imdbVotes': '79'}
# -------------------
# movie id tt4813442
# -------------------
# {'Actors': 'Martin Doordan',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Christopher Carson Emmons',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'James, a veteran who has lived mostly in isolation for 2 years, '
#          'except for his weekly baseball coaching job, starts receiving a free '
#          'trial from a local newspaper, and notices that his ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Jul 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Eighth House',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Martin Doordan, Christopher Carson Emmons',
#  'Year': '2016',
#  'imdbID': 'tt4813442',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6054098
# -------------------
# {'Actors': 'Gian Keys, Sarah Brown Carter, Johnny Alexander, Amber Wegner',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ritchie Greer',
#  'Genre': 'Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Mike Wilder, an electrician by trade, married the woman of his '
#          'dreams. Life was great until a terrible tragedy revealed that his '
#          'wife was really an evil witch whose sole purpose was to ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Jan 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Electrician',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ritchie Greer',
#  'Year': '2017',
#  'imdbID': 'tt6054098',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7136736
# -------------------
# {'Actors': 'Natassia Halabi, Gabriel Miller, Lassiter Holmes, Lisa May',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Justin Price',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Nick is haunted by night terrors stemming from a tragic murder he '
#          'saw when he was young. After inheriting an old toy shop, he '
#          'discovers a cursed elf doll sealed inside an ancient chest with...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjhmOGIzNjQtODU1YS00ODMxLWI4ZDktMGZkNmMxZThhMjY2XkEyXkFqcGdeQXVyMTM5ODAyMjc@._V1_SX300.jpg',
#  'Production': 'Pikchure Zero Entertainment',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.6/10'}],
#  'Released': '07 Nov 2017',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'The Elf',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Justin Price',
#  'Year': '2017',
#  'imdbID': 'tt7136736',
#  'imdbRating': '5.6',
#  'imdbVotes': '2,065'}
# -------------------
# movie id tt7260928
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tom Davenport',
#  'Genre': 'Comedy, Drama, Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "A modern live-action version of 'Snow White', set in early Twentieth "
#          'Century America.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': 'The Elixir of Life',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2017',
#  'imdbID': 'tt7260928',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3956186
# -------------------
# {'Actors': 'Rick Borgia, Al Burgo, Ray Capuana, Thomas J. Churchill',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Thomas J. Churchill',
#  'Genre': 'Horror, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Murder and mayhem surround Queens, New York photographer Pamela '
#          'Garret after she is discovered taking life-altering pictures of '
#          'ritualistic sacrifice. Her world suddenly becomes a jigsaw ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMWFiZDQ2Y2UtMWE5MC00MGU4LWI4NWMtODMxOWEyNjQ0ZmMwXkEyXkFqcGdeQXVyMjA1MTk4Ng@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.5/10'}],
#  'Released': '28 Mar 2017',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': "The Emerging Past Director's Cut",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Thomas J. Churchill',
#  'Year': '2017',
#  'imdbID': 'tt3956186',
#  'imdbRating': '3.5',
#  'imdbVotes': '31'}
# -------------------
# movie id tt4877122
# -------------------
# {'Actors': 'T.J. Miller, James Corden, Anna Faris, Maya Rudolph',
#  'Awards': '5 wins & 3 nominations.',
#  'BoxOffice': '$86,053,485',
#  'Country': 'USA',
#  'DVD': '24 Oct 2017',
#  'Director': 'Tony Leondis',
#  'Genre': 'Animation, Adventure, Comedy, Family, Fantasy',
#  'Language': 'English, Spanish',
#  'Metascore': '12',
#  'Plot': 'Gene, a multi-expressional emoji, sets out on a journey to become a '
#          'normal emoji.',
# ...
#  'Year': '2017',
#  'imdbID': 'tt5871320',
#  'imdbRating': '6.8',
#  'imdbVotes': '12'}
# -------------------
# movie id tt6011302
# -------------------
# {'Actors': 'Alysse Fozmark, Cami Marie, Tabitha Knight, Kate Holdaway',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'A.J. Brooks',
#  'Genre': 'Horror, Sci-Fi, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The female inhabitants of "The City" discover they are being drugged '
#          'and replaced by clones. The clones hunt the last man alive who has '
#          'escaped the city to find his lost love.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BN2ZlNzI4NDYtMTdkOS00ZTM0LWJkYmItMWY5MmJiYTVkZDQ5XkEyXkFqcGdeQXVyMjIzNzg3NzM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '110 min',
#  'Title': 'Zero City',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'A.J. Brooks',
#  'Year': '2016',
#  'imdbID': 'tt6011302',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6846750
# -------------------
# {'Actors': 'Sam Doane, Carol Cardenas, Adam Paul, J. Patrick Ohlde',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Peter Leon',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Randall Bentley is forced by the evil Cerberus Corporation to go '
#          'back in time to the 1920s to retrieve a lost chest of gold. There he '
#          'finds himself neck deep in trouble with mobsters and in way over his '
#          'head with a gorgeous flapper.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzJkMzY4NWItNGQ1Yi00YjllLWEwZDYtMjY2MjY2M2U0MWMxXkEyXkFqcGdeQXVyMTg4MjQ1NTA@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '03 May 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Zero Point Theory',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Peter Leon, J. Patrick Ohlde',
#  'Year': '2017',
#  'imdbID': 'tt6846750',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5971220
# -------------------
# {'Actors': 'Jaime Gallagher, Matthew Tompkins, Maurice Moore, Amy Leigh '
#            'Edwards',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Alan Ray',
#  'Genre': 'Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Zero World',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Alan Ray',
#  'Year': '2017',
#  'imdbID': 'tt5971220',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7626082
# -------------------
# {'Actors': 'Ibrahim Affi, Zara Alhassane, Habiba Almoustapha, Rhissa Elryin',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Christopher Kirkley',
#  'Genre': 'Western',
#  'Language': 'Tamashek',
#  'Metascore': 'N/A',
#  'Plot': 'Zerzura is a feature-length ethnofiction shot in the Sahara desert. '
#          'Mixing folktales and documentary, the film follows a young man from '
#          'Niger who leaves home in search of an enchanted oasis.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZTZiYjExYjgtZjU5MS00Y2M1LTlkNDMtMjg3ZjI2YTZkY2Y0XkEyXkFqcGdeQXVyNjQxNzY5MjI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.6/10'}],
#  'Released': '19 Jul 2017',
#  'Response': 'True',
#  'Runtime': '87 min',
#  'Title': 'Zerzura',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Christopher Kirkley, Rhissa Koutata, Ahmoudou Madassane, Guichene '
#            'Mohamed',
#  'Year': '2017',
#  'imdbID': 'tt7626082',
#  'imdbRating': '7.6',
#  'imdbVotes': '5'}
# -------------------
# movie id tt4817466
# -------------------
# {'Actors': 'Brian Sutherland, Greg James, Kurt Conroyd, Brynn Baron',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jessica Scalise',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Jul 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Zilla and Zoe',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2016',
#  'imdbID': 'tt4817466',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6366268
# -------------------
# {'Actors': 'Artem Bagdasaryan, Richard J. Burt, Coleman Crenshaw, Ellen Deshon',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Lolo Loren, Patrick Poe',
#  'Genre': 'Comedy, Family, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "There's something not quite right about Tommy's little brother "
#          "Tyler, but no one else seems to see it. When Tommy's parents leave "
#          'him and his brother alone with a babysitter for the weekend...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Zoink',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Lolo Loren, Patrick Poe',
#  'Year': '2017',
#  'imdbID': 'tt6366268',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4333132
# -------------------
# {'Actors': 'Gorio, Chuck Hollins, King Jeff, Mayaba Liebenthal',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'King Jeff',
#  'Genre': 'Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'During a zombie pandemic, security consultant Jack Romero is bitten '
#          'by a Zombie and has 3 days before he either turns into one or not, '
#          "depending on his blood type, which he doesn't know. ...",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMmIyYjI1ZWUtMmRmOC00MDdlLWE0OWEtNDFlOGNjMzhlMjVlXkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.4/10'}],
#  'Released': '23 Oct 2017',
#  'Response': 'True',
#  'Runtime': '86 min',
#  'Title': 'Zombie Bite',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'King Jeff (story), King Jeff',
#  'Year': '2017',
#  'imdbID': 'tt4333132',
#  'imdbRating': '3.4',
#  'imdbVotes': '21'}
# -------------------
# movie id tt3793632
# -------------------
# {'Actors': 'Katherine Flannery, Alexander Kaminer, Matthew McCurdy, José André '
#            'Sibaja',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Mike Dudko',
#  'Genre': 'Comedy, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'After losing his father, a teenage boy decides to continue the '
#          'family business and deliver pizza by bicycle during the zombie '
#          'apocalypse.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTUyOTM1MjI4Ml5BMl5BanBnXkFtZTgwOTQ1OTA1MzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.1/10'}],
#  'Released': '01 Apr 2017',
#  'Response': 'True',
#  'Runtime': '94 min',
#  'Title': 'Zombie Pizza',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Mike Dudko',
#  'Year': '2017',
#  'imdbID': 'tt3793632',
#  'imdbRating': '5.1',
#  'imdbVotes': '24'}
# -------------------
# movie id tt4969672
# -------------------
# {'Actors': 'Tony Todd, Steven Luke, Raina Hein, Amanda Day',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '14 Nov 2017',
#  'Director': 'Hamid Torabpour',
#  'Genre': 'Action, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When the world is in shambles, plagued by a zombie outbreak, only '
#          'the strong will survive, but just how much determination will it '
#          'take? Will Luke and his crew have enough ambition and ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODY4YTJlYjktYzE4Ni00NGU2LThjODgtMDYyYTg1ODczZDFjXkEyXkFqcGdeQXVyMjIxODA2MTA@._V1_SX300.jpg',
#  'Production': 'Schuetzle Company Productions',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.9/10'}],
#  'Released': '14 Nov 2017',
#  'Response': 'True',
#  'Runtime': '82 min',
#  'Title': 'Zombies',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Hamid Torabpour',
#  'Year': '2017',
#  'imdbID': 'tt4969672',
#  'imdbRating': '2.9',
#  'imdbVotes': '700'}
# -------------------
# movie id tt3626214
# -------------------
# {'Actors': 'Alex Knapp, Siena Tickle, Amandine Thomas, Patrick Cooley',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Rocco Nisivoccia',
#  'Genre': 'Adventure, Comedy, Horror, Mystery',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Joe Alien fulfills a dream of coming to Earth to find that it's "
#          'overrun by zombies. Finding an ally in young Parker, he attempts to '
#          'save the world!',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYmRjMzkwNzItMDhjNi00OGMxLWIwOTEtYmQxMWRjNjE2ZDU4L2ltYWdlXkEyXkFqcGdeQXVyMTg0MTI3Mg@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.9/10'}],
#  'Released': '04 Feb 2017',
#  'Response': 'True',
#  'Runtime': '70 min',
#  'Title': 'Alien Vs. Zombies',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Matthew G. Hill, Rocco Nisivoccia',
#  'Year': '2017',
#  'imdbID': 'tt3626214',
#  'imdbRating': '3.9',
#  'imdbVotes': '76'}
# -------------------
# movie id tt6742344
# -------------------
# {'Actors': 'Liane Angus Whinfield, Cary Barnes, David Heron, Charles Clyburn',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'Barbados, USA',
#  'DVD': 'N/A',
#  'Director': 'Andrew Millington',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A young woman struggling to care for her Grandfather suffering from '
#          "Alzheimer's Disease discovers some haunting details about his past",
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': "Zora's Dream",
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2017',
#  'imdbID': 'tt6742344',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt10117046
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt7472110
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Riles Styles',
#  'Genre': 'War',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'alksjdhfldfhd',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '60 min',
#  'Title': 'a new test',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2017',
#  'imdbID': 'tt7472110',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8692590
# -------------------
# {'Actors': 'Corbi Nicole, Toni Fields, Angelique Valentine, Onyx Keesha',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Onyx Keesha',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Giselle is beautiful, successful, and chronically single. She spends '
#          'her time dreaming about what her "one" will be. While at work '
#          'Giselle meets Xy, an international model, and well known ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZWYwMjc3ZmItMGNkNi00YzI0LTg4ZjktZmI5ZGE2MGY3NDQzXkEyXkFqcGdeQXVyNTgwNjM0MzU@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '47 min',
#  'Title': 'her HER',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Onyx Keesha, B. Danielle Watkins',
#  'Year': '2017',
#  'imdbID': 'tt8692590',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7234406
# -------------------
# {'Actors': 'Rachelle Henry, Kelsi Umeko, Bryce Earhart, Araceli Meagher-Reyes',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kris Flink',
#  'Genre': 'N/A',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOGVhM2UyZjMtNTRhMi00MzM0LWIyNWMtNTE5Y2JkNTVmNzM1XkEyXkFqcGdeQXVyMzYzNjcxODQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '19 Aug 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'hitched',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Rachelle Henry, Mark Stoecklein, Tanya Stoecklein, Kelsi Umeko, '
#            'Kris Flink',
#  'Year': '2017',
#  'imdbID': 'tt7234406',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4994992
# -------------------
# {'Actors': 'Dalton Edward Phillips, Tony Vespe, Kelsey Pribilski, Gabriella '
#            'Biziou',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Scott Coones',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A teen comedy about a nerdy teenager who creates an iPhone app to be '
#          'his girlfriend. When she miraculously comes to life, things go '
#          'hilariously wrong, and she tries to kill him.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYjA2Y2E4MmMtOTRkZC00YTZhLWFlNzEtNDhmNDM5ZjBjZGZjXkEyXkFqcGdeQXVyNTM0MDc1ODE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.7/10'}],
#  'Released': '15 Jan 2017',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': 'iGirlfriend',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Scott Coones',
#  'Year': '2017',
#  'imdbID': 'tt4994992',
#  'imdbRating': '2.7',
#  'imdbVotes': '215'}
# -------------------
# movie id tt1293847
# -------------------
# {'Actors': 'Vin Diesel, Donnie Yen, Deepika Padukone, Kris Wu',
#  'Awards': '1 win & 6 nominations.',
#  'BoxOffice': '$44,850,317',
#  'Country': 'China, Canada, USA',
#  'DVD': '16 May 2017',
#  'Director': 'D.J. Caruso',
#  'Genre': 'Action, Adventure, Thriller',
#  'Language': 'English, Spanish, Portuguese, Mandarin, Tagalog, Russian',
#  'Metascore': '42',
#  'Plot': 'Xander Cage is left for dead after an incident, though he secretly '
#          'returns to action for a new, tough assignment with his handler '
#          'Augustus Gibbons.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzcwMjkxMzQ3NV5BMl5BanBnXkFtZTgwMzgyNDA5MDI@._V1_SX300.jpg',
#  'Production': 'Paramount Pictures',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.2/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '45%'},
#              {'Source': 'Metacritic', 'Value': '42/100'}],
#  'Released': '20 Jan 2017',
#  'Response': 'True',
#  'Runtime': '107 min',
#  'Title': 'xXx: Return of Xander Cage',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Rich Wilkes (based on characters created by), F. Scott Frazier',
#  'Year': '2017',
#  'imdbID': 'tt1293847',
#  'imdbRating': '5.2',
#  'imdbVotes': '80,309'}
# -------------------
# movie id tt7928396
# -------------------
# {'Actors': 'Caroline Burns, Sam Baesler, Cory Ackerman, Sean Miles',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Sweden',
#  'DVD': 'N/A',
#  'Director': 'Joe Davies',
#  'Genre': 'N/A',
#  'Language': 'English, Swedish',
#  'Metascore': 'N/A',
#  'Plot': 'Sweden 1974, The country is gripped by anti-Swiss paranoia. Not the '
#          'ideal political climate for young immigrant Elaine. Her luck seems '
#          'to take a turn for the better when she moves in with ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTljNDMxNGEtMThjNS00ZWJhLTgwN2EtZTBkYmI0YjFiMGRmXkEyXkFqcGdeQXVyODQ4MjgzNDI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '09 Jun 2017',
#  'Response': 'True',
#  'Runtime': '78 min',
#  'Title': 'Äntligen Krig',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joe Davies',
#  'Year': '2017',
#  'imdbID': 'tt7928396',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}

# %%
len(title_list)
# Out:
# 805

# %%
len(title_id)
# Out:
# 805

# %%
# if title_list and title_id are the same length run the cell below. 
# if they are not equal take out 'title_id': title_id

# %%
df = pd.DataFrame({'title_id': title_id, 'title': title_list, 'box_office': box_office_list, 'country': country_list, 
                   'genre': genre_list, 'director': director_list, 'metascore': metascore_list, 'production': production_list, 
                   'rating': rating_list, 'IMDB_rating': IMDB_rating_list, 'rotten_tomatoes_rating': rotten_tomatoes_rating_list, 
                  'runtime': runtime_list, 'type': type_list, 'IMDB_votes': imdb_votes_list})

# %%
df = df.drop_duplicates()
df.head()
# Out:
#     title_id                            title box_office country  \
# 0  tt2140507  The Current War: Director's Cut        N/A     USA
# 1  tt3228450    The Curse of All Hallows' Eve        N/A     USA
# 2  tt5816936    The Curse of the Dragon Sword        N/A     USA
# 3  tt4864442                    The Custodian        N/A     USA
# 4  tt6517046                The Cutting Truth        N/A     USA
#
#                        genre                director metascore   production  \
# 0  Biography, Drama, History     Alfonso Gomez-Rejon        55  101 Studios
# 1                     Horror              Guy Bodart       N/A          N/A
# 2  Action, Adventure, Comedy            Jason Phelps       N/A          N/A
# 3                   Thriller         Michael Arabian       N/A          N/A
# 4            Drama, Thriller  Michael S. McClafferty       N/A          N/A
#
#   rating IMDB_rating rotten_tomatoes_rating  runtime   type IMDB_votes
# 0  PG-13         6.4                    29%  102 min  movie      7,477
# 1    N/A         N/A                     NA      N/A  movie        N/A
# 2    N/A         N/A                     NA      N/A  movie        N/A
# 3    N/A         N/A                     NA      N/A  movie        N/A
# 4      R         8.3                     NA   49 min  movie          7

# %%
df.count()
# Out:
# title_id                  805
# title                     805
# box_office                805
# country                   805
# genre                     805
# director                  805
# metascore                 805
# production                805
# rating                    805
# IMDB_rating               805
# rotten_tomatoes_rating    805
# runtime                   805
# type                      805
# IMDB_votes                805
# dtype: int64

# %%
df.to_csv('Resources/data/2017_data_batch_4.csv', index=False)
