# %%
import pandas as pd
import requests
import json
import time
from pprint import pprint
from config import API_KEY

# %%
data = pd.read_csv('Resources/title_webscraped/titles_2017_batch1.csv')
df =  data.count()
df
# Out:
# title    1000
# dtype: int64

# %%
title_id = []
box_office_list = []
country_list = []
genre_list = []
director_list = []
metascore_list = []
production_list = []
rating_list = []
IMDB_rating_list = [] 
rotten_tomatoes_rating_list = []
runtime_list = []
title_list = []
type_list = []
imdb_votes_list = []

# %%
movies = data['title']
total_movies = len(movies)

# %%
for i in range(total_movies):
    movie = movies[i]
    url = "http://www.omdbapi.com/?i=" + movie + "&apikey=" + API_KEY
    response = (requests.get(url).text)
    response_json = json.loads(response)
    print('-------------------')
    print(f'movie id {movie}')
    print('-------------------')
    pprint(response_json)
    
    try:
        box_office_list.append(response_json['BoxOffice'])
        country_list.append(response_json['Country'])
        genre_list.append(response_json['Genre'])
        director_list.append(response_json['Director'])
        metascore_list.append(response_json['Metascore'])
        production_list.append(response_json['Production'])
        rating_list.append(response_json['Rated'])
        IMDB_rating_list.append(response_json['imdbRating'])
        try:
            if not response_json['Ratings']:
                rotten_tomatoes_rating_list.append('NA')
            elif response_json['Ratings'][0]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][0]['Value'])
            elif response_json['Ratings'][1]['Source'] == 'Rotten Tomatoes':
                rotten_tomatoes_rating_list.append(response_json['Ratings'][1]['Value'])
            else:
                rotten_tomatoes_rating_list.append('NA')
        except IndexError:
            rotten_tomatoes_rating_list.append('NA')
        runtime_list.append(response_json['Runtime'])
        title_list.append(response_json['Title'])
        type_list.append(response_json['Type'])
        imdb_votes_list.append(response_json['imdbVotes'])
        title_id.append(response_json['imdbID'])
    except KeyError:
        pass
    time.sleep(1)
# Out:
# -------------------
# movie id tt5571972
# -------------------
# {'Actors': 'Erika J. Wood, Foxy Squire, Nicholas Catucci',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Esther Lev',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': '2 Sisters are forced to get along when their parents get mixed up in '
#          'the Civil War, and leave them in charge.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjY1Y2ZlMzMtYjQ3Ny00YTFlLTkwMDgtMjYxZDIxNmNkYmFkXkEyXkFqcGdeQXVyNjEwODA4Nzc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '24 Apr 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'My Sister, My Keeper',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2016',
#  'imdbID': 'tt5571972',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7470666
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'N/A',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '10 Jan 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'My Stories',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2016',
#  'imdbID': 'tt7470666',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4601830
# -------------------
# {'Actors': 'Jeanne Anderson, Haley Barker, Matthew Binger, Mckenzie Bishop',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Alex Greenlee',
#  'Genre': 'Drama, Family, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Despite his father's opposition, a Native American teen working at a "
#          'local fair pursues his dream of filmmaking and meets the girl who '
#          'changes his life forever.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTA3NjI2MTc5OTVeQTJeQWpwZ15BbWU4MDMwNTE3NjYx._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '17 May 2015',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'My Sunset Girl',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Alex Greenlee',
#  'Year': '2015',
#  'imdbID': 'tt4601830',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5009208
# -------------------
# {'Actors': 'Debbie Rochon, John A. Russo, Gary Lee Vincent, Cy-Fi',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'John A. Russo',
#  'Genre': 'Comedy, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'My Uncle John Is a Zombie!',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'John A. Russo',
#  'Year': '2016',
#  'imdbID': 'tt5009208',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5817252
# -------------------
# {'Actors': 'Sydney Cavalli, Josh Gonzalez, Lillie Guichard, Ardara Harris',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Courtnie Sheikh, Farrukh Sheikh',
#  'Genre': 'Mystery',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An ink was created, then put on the street and opened up at a tattoo '
#          'parlor run by the mysterious Dr. V and curious assistant Maria. It '
#          'not only gives one of a kind art but actually reads ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYWRlMWY3NGEtMGU0Zi00MzQ1LWFlZmEtNGIyM2RmMzY2YWNiXkEyXkFqcGdeQXVyNTc3NTc4NzM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '23 Aug 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Mysterink',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Farrukh Sheikh',
#  'Year': '2016',
#  'imdbID': 'tt5817252',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5327922
# -------------------
# {'Actors': 'Melanie Stone, Adam Johnson, Matthew Mercer, Jake Stormoen',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'John Lyde',
#  'Genre': 'Action, Adventure, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "As the Lich King's zombie legions ravage the world, Marek, a cursed "
#          'young sorceress, embarks on a quest to obtain a weapon from the '
#          'gods, with her friend Dagen, a self-serving half-elf ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BN2VkMDI1N2QtNTljOC00N2U1LTgxZTctZTZjMzBlYzc2NmY3XkEyXkFqcGdeQXVyNDUxNjc5NjY@._V1_SX300.jpg',
#  'Production': 'Arrowstorm Entertainment',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.5/10'}],
#  'Released': '19 Nov 2016',
#  'Response': 'True',
#  'Runtime': '118 min',
#  'Title': 'Mythica: The Godslayer',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jason Faller, Kynan Griffin',
#  'Year': '2016',
#  'imdbID': 'tt5327922',
#  'imdbRating': '5.5',
#  'imdbVotes': '969'}
# -------------------
# movie id tt5456798
# -------------------
# {'Actors': 'Melanie Stone, Adam Johnson, Jake Stormoen, Nicola Posener',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '06 Dec 2016',
#  'Director': 'John Lyde',
#  'Genre': 'Action, Adventure, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When a team of unlikely heroes hijacks a steam-powered battle wagon, '
#          'a daring young wizard (Marek) steals the final piece of the '
#          'all-powerful Darkspore and embarks on a desperate quest to ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMmY0YjQwOTQtYzYwMy00NDFiLTkwY2UtNjA4YTkwMWI3YmYzXkEyXkFqcGdeQXVyNDUxNjc5NjY@._V1_SX300.jpg',
#  'Production': 'Arrowstorm Entertainment',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'}],
#  'Released': '14 May 2016',
#  'Response': 'True',
#  'Runtime': '93 min',
#  'Title': 'Mythica: The Iron Crown',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jason Faller (created by), Jason Faller (screenplay), Kynan '
#            'Griffin (created by)',
#  'Year': '2016',
#  'imdbID': 'tt5456798',
#  'imdbRating': '5.4',
#  'imdbVotes': '1,173'}
# -------------------
# movie id tt3952614
# -------------------
# {'Actors': 'Sam Quartin, Chris Schellenger, Davy J. Marr, Ray Field',
#  'Awards': '1 win & 2 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'France, USA',
#  'DVD': 'N/A',
#  'Director': 'Cyril Morin',
#  'Genre': 'Drama, Music, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'NY84 follows the adventures of three young artists in the downtown '
#          "art scene in the early 1980's. We gain an intimate glimpse into the "
#          'creative and emotional life of Kate, Anton, and Keith....',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTFlNzlhNjQtNjc3Ni00YzFjLWIyMWMtZjY5NmE1M2QwMTA0XkEyXkFqcGdeQXVyMTk0NTgyMTY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'NY84',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Cyril Morin',
#  'Year': '2016',
#  'imdbID': 'tt3952614',
#  'imdbRating': '6.2',
#  'imdbVotes': '18'}
# -------------------
# movie id tt2184296
# -------------------
# {'Actors': 'Wesley Hinkle, Kenn Parks, Christie Troxell, Elijah Malone',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Harley David Morris',
#  'Genre': 'Drama, Horror, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "'One man's journey into a realm of his personality that he never "
#          "knew existed...'",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTYxODU2Mzk0NF5BMl5BanBnXkFtZTcwMzE3NzQ4OQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.8/10'}],
#  'Released': '02 Mar 2016',
#  'Response': 'True',
#  'Runtime': '67 min',
#  'Title': 'Nailed Down',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Harley David Morris',
#  'Year': '2016',
#  'imdbID': 'tt2184296',
#  'imdbRating': '4.8',
#  'imdbVotes': '9'}
# -------------------
# movie id tt4210112
# -------------------
# {'Actors': 'Jacob Ayanaba, Grace Ayariga, Justina Kulidu, Shetu Musah',
#  'Awards': '1 win & 6 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'Ghana, USA',
#  'DVD': 'N/A',
#  'Director': 'Kelly Daniela Norris, T.W. Pittman',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': '70',
#  'Plot': "Upon his father's sudden death, a talented medical student must "
#          "return to his home village in Ghana to fight for his family's "
#          'survival.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTkwOTc4NDU5NF5BMl5BanBnXkFtZTgwNjE5MTMyNjE@._V1_SX300.jpg',
#  'Production': 'Corinth Films',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.8/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '86%'},
#              {'Source': 'Metacritic', 'Value': '70/100'}],
#  'Released': '03 Mar 2017',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Nakom',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Isaac Adakudugu, Isaac Adakudugu (dialogue), T.W. Pittman',
#  'Year': '2016',
#  'imdbID': 'tt4210112',
#  'imdbRating': '6.8',
#  'imdbVotes': '139'}
# -------------------
# movie id tt3752896
# -------------------
# {'Actors': 'Karim Saleh, Waleed Zuaiter, Nicole Haddad, Mona Hala',
#  'Awards': '2 wins.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '15 Mar 2017',
#  'Director': 'Heidi Saman',
#  'Genre': 'Drama',
#  'Language': 'Arabic, English',
#  'Metascore': 'N/A',
#  'Plot': 'In a post-college rut, a Los Angeles valet driver unravels.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZmViZGIzMGMtNGEzZC00YWQ0LTkzYmMtY2E1NTI4ZTJhZDZiXkEyXkFqcGdeQXVyMTc2Njc5NzY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'}],
#  'Released': '06 Mar 2017',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Namour',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Heidi Saman',
#  'Year': '2016',
#  'imdbID': 'tt3752896',
#  'imdbRating': '6.6',
#  'imdbVotes': '37'}
# -------------------
# movie id tt5804768
# -------------------
# {'Actors': 'Alex Stout, Josh Buel, Dexter Morgenstern, Tony Gasperetti',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tony Gasperetti, Alex Stout',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Nanobots have infected everyone and taken over the world! A select '
#          'few can harness the power of the nanobots for good. Most become '
#          'crazed zombie like monsters.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYzllMzBhZTUtNDIwNS00Y2I1LThlYjQtM2MwZDBjMjk3ZjBkXkEyXkFqcGdeQXVyNjc0MzE0NDc@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Nano Z',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Tony Gasperetti, Geoff Hulten (lead writer)',
#  'Year': '2016',
#  'imdbID': 'tt5804768',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt7354394
# -------------------
# {'Actors': 'Michael Bendall',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Becky Hobbs',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYTQxNWUwZDktMGRiYi00MDVhLThhODgtMjJjOTNkODQ2MmI0XkEyXkFqcGdeQXVyMjU5MDA5MjA@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Jul 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Nanyehi: the Story of Nancy Ward',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2016',
#  'imdbID': 'tt7354394',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3983694
# -------------------
# {'Actors': "Celestino Cornielle, Sam Aotaki, Raffaela O'Neill, Eric Dean",
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'James Ursini, Haesun Woo',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Nasty Piece of Work is a neo-noir thriller set in the fetish '
#          'underworld of Los Angeles. The story is told from the point of view '
#          'of three characters: a lifestyle dominatrix, a Buddhist '
#          'stripper/saint, and a conflicted private investigator.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTUxODAwMTM2MV5BMl5BanBnXkFtZTgwNzczMTAxNjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.0/10'}],
#  'Released': '01 Jun 2016',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'Nasty Piece of Work',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'David Rhodes (novel), James Ursini (screenplay)',
#  'Year': '2016',
#  'imdbID': 'tt3983694',
#  'imdbRating': '6.0',
#  'imdbVotes': '14'}
# -------------------
# movie id tt3250576
# -------------------
# {'Actors': 'Domiziano Arcangeli, Dawna Lee Heising, Gregory Blair, Jack E. '
#            'Curenton',
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Domiziano Arcangeli, Steve Oakley',
#  'Genre': 'Action, Comedy, Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Distributors and their various relationships with independent '
#          'film-makers.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjM4NDgxNjkwNl5BMl5BanBnXkFtZTgwNDM1MzY0MjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.7/10'}],
#  'Released': '01 Feb 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Natural Born Filmmakers',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Gregory Blair (additional scenes and dialogue), Melanie Grunder, '
#            'Debra Lamb (additional scenes written by), Steve Oakley',
#  'Year': '2016',
#  'imdbID': 'tt3250576',
#  'imdbRating': '6.7',
#  'imdbVotes': '11'}
# -------------------
# movie id tt3671086
# -------------------
# {'Actors': 'Roman Atwood, Vitaly Zdorovetskiy, Dennis Roady, Kevin Brueck',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '01 Apr 2016',
#  'Director': 'Roman Atwood, Ben Pluimer',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "YouTube's best pranksters, Roman Atwood, Vitaly Z, and Dennis Roady "
#          'make the leap to the big screen.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjE4NDkyMTU1Nl5BMl5BanBnXkFtZTgwMzg5OTYwODE@._V1_SX300.jpg',
#  'Production': 'Collective Digital Studios',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.6/10'}],
#  'Released': '01 Apr 2016',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Natural Born Pranksters',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Roman Atwood, Dennis Roady, Vitaly Zdorovetskiy',
#  'Year': '2016',
#  'imdbID': 'tt3671086',
#  'imdbRating': '3.6',
#  'imdbVotes': '3,528'}
# -------------------
# movie id tt4755444
# -------------------
# {'Actors': 'Ana Jimenez McMillan, Troy Ignacio, Theo Coumbis, Tiffany Rose '
#            'Brown',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jon Brekke',
#  'Genre': 'Action, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Enraged that the law cannot keep the killer of her sister behind '
#          'bars, a woman lures him onto a hiking trail at night and proceeds to '
#          'exact her revenge.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjI4ODgxNDQwM15BMl5BanBnXkFtZTgwOTE0NDA4MDI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.6/10'}],
#  'Released': '15 Jun 2016',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'Natural Reaction',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Eric Nemoto',
#  'Year': '2016',
#  'imdbID': 'tt4755444',
#  'imdbRating': '4.6',
#  'imdbVotes': '18'}
# -------------------
# movie id tt3667792
# -------------------
# {'Actors': 'Mason Dye, Ryan Munzert, Anthony Michael Hall, Katherine McNamara',
#  'Awards': '1 win.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '26 Aug 2016',
#  'Director': 'Chad L. Scheifele',
#  'Genre': 'Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'As the new kid, a shy high school senior finds himself tormented by '
#          'all his peers except one, but his new friend has a dark, infectious '
#          'outlook.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTY5NDQ0OTQ4OV5BMl5BanBnXkFtZTgwMTA5MTg1OTE@._V1_SX300.jpg',
#  'Production': 'ITN Distribution',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.1/10'}],
#  'Released': '01 Dec 2016',
#  'Response': 'True',
#  'Runtime': '101 min',
#  'Title': 'Natural Selection',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Chad L. Scheifele',
#  'Year': '2016',
#  'imdbID': 'tt3667792',
#  'imdbRating': '5.1',
#  'imdbVotes': '1,697'}
# -------------------
# movie id tt6096242
# -------------------
# {'Actors': 'Amy Shore, Timothy Michael Waschitz, Donald Masterson, Jarrod '
#            'Hagadorn',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jacob Dodd',
#  'Genre': 'Adventure, Family, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'During the international conflicts of the 1950s, a modest crop '
#          'dusting pilot searches for his heroic brother after he vanishes at '
#          "the hands of a masked villain obsessed with bringing the world's "
#          'superpowers to their knees.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzJkODdlYTMtOGM1Yi00OGVhLWIyNjQtOWFkZjQ1YTk4MzM5L2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMjAyNTczNDg@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '51 min',
#  'Title': 'Navigators of the Shadow Ring: Chapter 1',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jacob Dodd (story), Jacob Dodd',
#  'Year': '2016',
#  'imdbID': 'tt6096242',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt10549012
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt2511254
# -------------------
# {'Actors': "Lenny von Dohlen, Margaret O'Brien, Joaquim de Almeida, Julianna "
#            'Guill',
#  'Awards': '3 wins.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Scott Fivelson',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'This unique Hollywood story is the life-and-times chronicle of one '
#          'of our greatest directors, Oskar Knight.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk0MDk1NzY4OF5BMl5BanBnXkFtZTcwODA2Mzc4OQ@@._V1_SX300.jpg',
#  'Production': 'Sunscope Entertainment',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': 'Near Myth: The Oskar Knight Story',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Scott Fivelson',
#  'Year': '2017',
#  'imdbID': 'tt2511254',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4438848
# -------------------
# {'Actors': 'Seth Rogen, Zac Efron, Rose Byrne, Chloë Grace Moretz',
#  'Awards': '3 wins & 5 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, China',
#  'DVD': '20 Sep 2016',
#  'Director': 'Nicholas Stoller',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': '58',
#  'Plot': 'When their new next-door neighbors turn out to be a sorority even '
#          'more debaucherous than the fraternity previously living there, Mac '
#          'and Kelly team with their former enemy, Teddy, to bring the girls '
#          'down.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTY0NzUxMDUzN15BMl5BanBnXkFtZTgwNzI2MTY4ODE@._V1_SX300.jpg',
#  'Production': 'Universal Pictures',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.7/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '63%'},
#              {'Source': 'Metacritic', 'Value': '58/100'}],
#  'Released': '20 May 2016',
#  'Response': 'True',
#  'Runtime': '92 min',
#  'Title': 'Neighbors 2: Sorority Rising',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': "Andrew Jay Cohen, Brendan O'Brien, Nicholas Stoller, Evan "
#            'Goldberg, Seth Rogen, Andrew Jay Cohen (based on characters '
#            "created by), Brendan O'Brien (based on characters created by)",
#  'Year': '2016',
#  'imdbID': 'tt4438848',
#  'imdbRating': '5.7',
#  'imdbVotes': '106,540'}
# -------------------
# movie id tt3951908
# -------------------
# {'Actors': 'Dave Bald Eagle, Christopher Sweeney, Richard Ray Whitman, '
#            'Roseanne Supernault',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'UK, USA',
#  'DVD': 'N/A',
#  'Director': 'Steven Lewis Simpson',
#  'Genre': 'Drama',
#  'Language': 'English, Sioux',
#  'Metascore': '57',
#  'Plot': 'A Lakota elder summons a white writer to visit him and help him '
#          'write a book about his people.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMWQwYmM0ZjEtODQ0Yy00MWUwLTlkYjUtNGE2MDI3OTQzMWQ4XkEyXkFqcGdeQXVyNjc0Mzc3MDM@._V1_SX300.jpg',
#  'Production': 'Inyo Entertainment',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.7/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '82%'},
#              {'Source': 'Metacritic', 'Value': '57/100'}],
#  'Released': '01 Oct 2016',
#  'Response': 'True',
#  'Runtime': '110 min',
#  'Title': 'Neither Wolf Nor Dog',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kent Nerburn (novel), Kent Nerburn (screenplay), Kent Nerburn, '
#            'Steven Lewis Simpson',
#  'Year': '2016',
#  'imdbID': 'tt3951908',
#  'imdbRating': '7.7',
#  'imdbVotes': '323'}
# -------------------
# movie id tt5574372
# -------------------
# {'Actors': 'Paul Rudd, Patton Oswalt, Hannibal Buress, Kate Micucci',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '07 Feb 2017',
#  'Director': 'Chris Prynoski',
#  'Genre': 'Animation, Comedy',
#  'Language': 'English',
#  'Metascore': '46',
#  'Plot': 'The story of two best friends whose dreams of success and stardom '
#          'have fizzled, so they decide to become famous in one day - at all '
#          'costs.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTUwMzg1MzA5MV5BMl5BanBnXkFtZTgwNTA0OTgyMDI@._V1_SX300.jpg',
#  'Production': 'AKW Worldwide',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.3/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '23%'},
#              {'Source': 'Metacritic', 'Value': '46/100'}],
#  'Released': '14 Apr 2016',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': 'Nerdland',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Andrew Kevin Walker',
#  'Year': '2016',
#  'imdbID': 'tt5574372',
#  'imdbRating': '5.3',
#  'imdbVotes': '900'}
# -------------------
# movie id tt2268018
# -------------------
# {'Actors': 'Eric Roberts, Caite Upton, Mykel Shannon Jenkins, Yves Bright',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Mitesh Kumar Patel, Sam Son',
#  'Genre': 'Action, Drama, Horror, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'New mom battles the evil lurking within as her adulterous husband '
#          'hides a dark secret that may lead to the human extinction.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzYwOTIxNzM5OV5BMl5BanBnXkFtZTcwNjg4NjI0OA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.0/10'}],
#  'Released': '06 Mar 2018',
#  'Response': 'True',
#  'Runtime': '100 min',
#  'Title': 'Neron',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Julian Jay Burton, Lekhraj Patel',
#  'Year': '2018',
#  'imdbID': 'tt2268018',
#  'imdbRating': '3.0',
#  'imdbVotes': '459'}
# -------------------
# movie id tt4698584
# -------------------
# {'Actors': 'Luis Gnecco, Gael García Bernal, Mercedes Morán, Emilio Gutiérrez '
#            'Caba',
#  'Awards': 'Nominated for 1 Golden Globe. Another 11 wins & 32 nominations.',
#  'BoxOffice': '$938,875',
#  'Country': 'Chile, Argentina, France, Spain, USA',
#  'DVD': 'N/A',
#  'Director': 'Pablo Larraín',
#  'Genre': 'Biography, Crime, Drama, History',
#  'Language': 'Spanish, French, Dutch, Mapudungun',
#  'Metascore': '82',
#  'Plot': 'An inspector hunts down Nobel Prize-winning Chilean poet, Pablo '
#          'Neruda, who becomes a fugitive in his home country in the late 1940s '
#          'for joining the Communist Party.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzM0NDI4Mjc5NV5BMl5BanBnXkFtZTgwMTM0NzQ0MDI@._V1_SX300.jpg',
#  'Production': 'The Orchard',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.9/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '93%'},
#              {'Source': 'Metacritic', 'Value': '82/100'}],
#  'Released': '11 Aug 2016',
#  'Response': 'True',
#  'Runtime': '107 min',
#  'Title': 'Neruda',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Guillermo Calderón',
#  'Year': '2016',
#  'imdbID': 'tt4698584',
#  'imdbRating': '6.9',
#  'imdbVotes': '8,367'}
# -------------------
# movie id tt3531824
# -------------------
# {'Actors': 'Emma Roberts, Dave Franco, Emily Meade, Miles Heizer',
#  'Awards': '5 nominations.',
#  'BoxOffice': '$38,562,379',
#  'Country': 'USA',
#  'DVD': '25 Oct 2016',
#  'Director': 'Henry Joost, Ariel Schulman',
#  'Genre': 'Adventure, Crime, Drama, Mystery, Thriller',
#  'Language': 'English',
#  'Metascore': '58',
#  'Plot': 'A high school senior finds herself immersed in an online game of '
#          'truth or dare, where her every move starts to become manipulated by '
#          'an anonymous community of "watchers."',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTUzOTg1OTM4NV5BMl5BanBnXkFtZTgwMTg2Mjg0OTE@._V1_SX300.jpg',
#  'Production': 'Keep Your Head',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '67%'},
#              {'Source': 'Metacritic', 'Value': '58/100'}],
#  'Released': '27 Jul 2016',
#  'Response': 'True',
#  'Runtime': '96 min',
#  'Title': 'Nerve',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jessica Sharzer (screenplay by), Jeanne Ryan (based on the novel '
#            'by)',
#  'Year': '2016',
#  'imdbID': 'tt3531824',
#  'imdbRating': '6.5',
#  'imdbVotes': '106,536'}
# -------------------
# movie id tt2274158
# -------------------
# {'Actors': 'Shoshanna Chagall, Erin Dinsmore, Vishwanath Iyer, Michael Geretz',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Tommy Friedman',
#  'Genre': 'Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Warring tribes desperately seek the fragments of a sacred crystal '
#          'key, but when one piece is stolen, Princess Lakshmi must fulfill an '
#          'ancient prophesy by leaving her tribe, reuniting the crystal, and '
#          'opening the portal to Neshima.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMzI0MTczNTI4NF5BMl5BanBnXkFtZTgwOTQ2NjU1NTE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Neshima',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Mike Tenenberg (screenplay), Tommy Friedman (screenplay), Mike '
#            'Tenenberg (story), Tommy Friedman (story), Cory Wess (story), Cory '
#            'Wess (additional writing), Jim Murray (additional writing)',
#  'Year': '2016',
#  'imdbID': 'tt2274158',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5442626
# -------------------
# {'Actors': 'Michael Paré, Toni Hudson, Paul Wallace, Shay Dickerhoff',
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '18 Oct 2016',
#  'Director': 'Jim Wynorski',
#  'Genre': 'Adventure, Family',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A 10-year-old boy moves to a lakeside town and meets an elderly '
#          'sailor who claims that the stories of a monster named Nessie in the '
#          'lake is true. Could the monster hold the key to saving the town from '
#          'a ruthless businessman?',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYjNjYTM5NGEtMDM2Ny00OTVlLTg5YzUtN2RlNWIzNmQ1ZDA4XkEyXkFqcGdeQXVyMjMyMTA0MzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.4/10'}],
#  'Released': '14 Jul 2017',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Nessie & Me',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Carl Salminen, Jim Wynorski',
#  'Year': '2017',
#  'imdbID': 'tt5442626',
#  'imdbRating': '3.4',
#  'imdbVotes': '108'}
# -------------------
# movie id tt5317724
# -------------------
# {'Actors': 'Kim Green, Coleman Whiting, Juan Aleman, Cedric Wade',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Chraci Littlejohn',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When a young woman hides out in a quiet town, she only escapes from '
#          'one deadly situation to wind up in another. Who can she trust: The '
#          'landlord with a secret, the charming stranger who ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Nevermind the Knife',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Chraci Littlejohn',
#  'Year': '2016',
#  'imdbID': 'tt5317724',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3645926
# -------------------
# {'Actors': 'Roger Conners, Jeanine Visuue, Kayla Elizabeth, KateLynn E. '
#            'Newberry',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Chad Zuver',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '18 Dec 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'New Blood Awakening',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Thomas Sloan, Chad Zuver',
#  'Year': '2016',
#  'imdbID': 'tt3645926',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3147070
# -------------------
# {'Actors': 'Taylor Rabow, Christopher Kile, Christi Berlane, David Ausem',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Michael Seminerio',
#  'Genre': 'Comedy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "On Jake's first day of work at the comic book store he finds out "
#          'that he has entered a strange new world where anything is possible. '
#          'He becomes embroiled in a power struggle of comic book ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTcwNDQ5NzY3NF5BMl5BanBnXkFtZTgwOTI4OTYxMjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Oct 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'New Comic Day',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Seminerio',
#  'Year': '2015',
#  'imdbID': 'tt3147070',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5214110
# -------------------
# {'Actors': 'Jimmy Kustes, David Maloney, Timothy Morton, Johanna Sims',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Timothy Morton',
#  'Genre': 'Mystery',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'An ordinary man (played by Tim Morton) lives a dull life till his '
#          'friend Chet (played by Jimmy Kustes) comes over to stay for a few '
#          'days. His friend ropes him to various schemes and ...',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Jan 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'New Cops',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jimmy Kustes (story), Timothy Morton (story)',
#  'Year': '2016',
#  'imdbID': 'tt5214110',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt2931140
# -------------------
# {'Actors': "James Marsters, Terry O'Quinn, Barry Corbin, Bill Cobbs",
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': '07 Mar 2017',
#  'Director': 'Drew Waters',
#  'Genre': 'Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Ben met Ava at age seven standing in his driveway. As the two '
#          'journey together through the seasons of life, a tragedy occurs that '
#          'leaves their entire future in jeopardy.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTIzYmNkOGUtZDVmOS00MjgyLThjMzktODBjNzg0MmZiNDA4XkEyXkFqcGdeQXVyNDI1MTIwNw@@._V1_SX300.jpg',
#  'Production': 'Circle 4 Entertainment',
#  'Rated': 'PG',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.9/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '29%'}],
#  'Released': '19 Oct 2017',
#  'Response': 'True',
#  'Runtime': '88 min',
#  'Title': 'New Life',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Erin Bethea, Candice Irion, Josh Spake, Drew Waters',
#  'Year': '2016',
#  'imdbID': 'tt2931140',
#  'imdbRating': '5.9',
#  'imdbVotes': '626'}
# -------------------
# movie id tt10889420
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt5321846
# -------------------
# {'Actors': 'Ajani Abraham, Aisha Adam, Wilson Anacreon, Darwin Ashby',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Richie Cerda',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A low end New York City talent manager struggles to survive as his '
#          'dark past comes back to haunt him.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '141 min',
#  'Title': 'New York State of Mind',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Richie Cerda',
#  'Year': '2016',
#  'imdbID': 'tt5321846',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3576858
# -------------------
# {'Actors': 'Paul Brittain, Adam Herschman, Christine Bently, Neil Flynn',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Drew Hall',
#  'Genre': 'Comedy',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'Uber geeks Nigel and Oscar want nothing more than to capture '
#          'definitive evidence of a Sasquatch. When their guide bails on them, '
#          'they must resort to using a mis-matched group of outdoor ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODljN2Q2ZjQtYjQ2Yy00NzJkLWIxMGEtYTg3Njk2Mjc2ODFmXkEyXkFqcGdeQXVyMTE3Njc1NQ@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '9.7/10'}],
#  'Released': '27 Aug 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Nigel and Oscar Vs. The Sasquatch',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'James Weldon',
#  'Year': '2016',
#  'imdbID': 'tt3576858',
#  'imdbRating': '9.7',
#  'imdbVotes': '6'}
# -------------------
# movie id tt5918088
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'China, USA, Guatemala, Japan, Mexico',
#  'DVD': 'N/A',
#  'Director': 'Sandy Ding',
#  'Genre': 'N/A',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'AN ADVENTURER AND AWAKENING IN BOTH PHYSICAL AND PSYCHOLOGICAL '
#          'SPACE/TIME.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Jul 2016',
#  'Response': 'True',
#  'Runtime': '90 min',
#  'Title': 'Night Awake',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2016',
#  'imdbID': 'tt5918088',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5761812
# -------------------
# {'Actors': 'Adriana Lt, Paul Antoine, Nelson A. Ballester, Randy Barco',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Bruny Telfort',
#  'Genre': 'Crime',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A man is caught up in a web of crimes while trying to complete a '
#          '40-hour shift; he conniving keeps murdering innocent people in order '
#          'to keep his job.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '06 Feb 2016',
#  'Response': 'True',
#  'Runtime': '50 min',
#  'Title': 'Night Crimes Story # 2',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Bruny Telfort',
#  'Year': '2016',
#  'imdbID': 'tt5761812',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5868900
# -------------------
# {'Actors': 'Christina Kirkman, Andrea Sweeney-Blanco, Josephine Cooper, Kai '
#            'Freyleue',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kai Freyleue',
#  'Genre': 'Action, Crime, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Open to interpretation and completely out of order, this nonlinear '
#          'film chronicles the days leading up to a school shooting - and the '
#          'masked vigilante behind it all',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '70 min',
#  'Title': 'Night Shadow',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kai Freyleue',
#  'Year': '2016',
#  'imdbID': 'tt5868900',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3315380
# -------------------
# {'Actors': 'Trey Harrison, Rebecca C. Kasek, Wayne W. Johnson, Michael '
#            'Merchant',
#  'Awards': '9 wins & 15 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Canada',
#  'DVD': 'N/A',
#  'Director': 'Jonathan Straiton',
#  'Genre': 'Comedy, Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Teenage friends out for beach week get unexpectedly detoured to a '
#          'isolated motel where a deadly STD virus now runs rampant, turning '
#          'those infected into the living dead.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjQ2Y2UyNWEtZGJlYy00YWEyLWI3ZWUtNmM5MmU1NzQyODhlXkEyXkFqcGdeQXVyNTcwMzkyNDE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Unrated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.1/10'}],
#  'Released': '22 Nov 2016',
#  'Response': 'True',
#  'Runtime': '94 min',
#  'Title': 'Night of Something Strange',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jonathan Straiton, Ron Bonk, Mean Gene, Jonathan Straiton (story)',
#  'Year': '2016',
#  'imdbID': 'tt3315380',
#  'imdbRating': '5.1',
#  'imdbVotes': '1,634'}
# -------------------
# movie id tt6029746
# -------------------
# {'Actors': 'Jennii Caroline, Breana Mitchell, Dan Peters, Kerrie Waybright '
#            'Smith',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Dustin Ferguson',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODVkNTY1OGQtOTdmMS00ZjYxLWI4MDktNzk3NWVkMzJjOTQ0XkEyXkFqcGdeQXVyMjY5MDIzMjQ@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '19 Aug 2016',
#  'Response': 'True',
#  'Runtime': '60 min',
#  'Title': 'Night of the Clown',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2016',
#  'imdbID': 'tt6029746',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5338600
# -------------------
# {'Actors': "Jim O'Rear, Scott Tepperman, Todd Bridges, Betsy Rue",
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': "Jim O'Rear, Scott Tepperman",
#  'Genre': 'Crime',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When three childhood friends are brought back together after years '
#          'apart, a string of mysterious and brutal "Jack The Ripper" inspired '
#          "murders erupt, pitting friends against foe in this 80's-style police "
#          'thriller.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjcyMjU0NjI4OF5BMl5BanBnXkFtZTgwMzA3Mjk5MDI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.6/10'}],
#  'Released': '01 Oct 2016',
#  'Response': 'True',
#  'Runtime': '86 min',
#  'Title': 'Nightblade',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': "Jim O'Rear, Scott Tepperman",
#  'Year': '2016',
#  'imdbID': 'tt5338600',
#  'imdbRating': '5.6',
#  'imdbVotes': '191'}
# -------------------
# movie id tt4741380
# -------------------
# {'Actors': 'Joshua Berduo, Ainsley Emrys, Malia Miglino',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Rudy Ruiz',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Sep 2015',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Nightlife',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Joshua Berduo, Ainsley Emrys, Malia Miglino, Rudy Ruiz',
#  'Year': '2015',
#  'imdbID': 'tt4741380',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5176442
# -------------------
# {'Actors': 'Sarah Butler, Lindsay Hartley, Steven Good, Traci Lords',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Craig Moss',
#  'Genre': 'Crime, Drama, Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When a woman and her boyfriend are injured in a car crash, he is '
#          'left with a leg injury which requires them to hire a nurse, but the '
#          'woman they select is more trouble than she appears.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc4MjI4NzMwMV5BMl5BanBnXkFtZTgwNDkyNzMwODE@._V1_SX300.jpg',
#  'Production': 'Cartel Pictures',
#  'Rated': 'TV-14',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.6/10'}],
#  'Released': '05 Mar 2016',
#  'Response': 'True',
#  'Runtime': '84 min',
#  'Title': 'Nightmare Nurse',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jake Helgren',
#  'Year': '2016',
#  'imdbID': 'tt5176442',
#  'imdbRating': '4.6',
#  'imdbVotes': '677'}
# -------------------
# movie id tt6169854
# -------------------
# {'Actors': 'Tess Kazdin, Neil Kelly',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Maria Alvarez',
#  'Genre': 'Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When faced with the harrowing difficulty of taking care of her '
#          'alcoholic mother, Josie Levitt decides to escape it all with her '
#          'best friend, Noah Abrams, and live in the woods.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Aug 2016',
#  'Response': 'True',
#  'Runtime': '49 min',
#  'Title': 'No Bandages in Paradise',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Maria Alvarez, Tess Kazdin, Neil Kelly, Jaime Rotsky, Jaime Sara '
#            'Rotsky',
#  'Year': '2016',
#  'imdbID': 'tt6169854',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6805800
# -------------------
# {'Actors': 'N/A',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, Mexico',
#  'DVD': 'N/A',
#  'Director': 'Matt Poitras',
#  'Genre': 'Action, Comedy, War',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'When a group of international criminals from his past kidnap his '
#          "daughter, the world's greatest commando sets out for revenge in this "
#          "action-packed parody of everything you loved about the 80's.",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYzRhMDk4Y2YtZGY2Yi00Yjc5LThmZTktOWM0NmRhMzdiZmZlXkEyXkFqcGdeQXVyNjU0NDMyODY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '95 min',
#  'Title': 'No Chance',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'N/A',
#  'Year': '2016',
#  'imdbID': 'tt6805800',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5882246
# -------------------
# {'Actors': 'Michael Norwood, Trini Green, Trish Powell, Anthony Olague',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Krystal Bolden',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Teenage boy, Landen, buys recording glasses to record himself '
#          'skating. But one evening of skateboard tricks turns his life upside '
#          'down when he inadvertently records a murder being committed...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZjRlMTkwNGUtNmRjNi00MmQ3LWI2Y2YtZmJhNWRmNjc4YzMyXkEyXkFqcGdeQXVyNjYwNDU4MDM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '24 Sep 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'No Eyes Have Seen',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Krystal Bolden',
#  'Year': '2016',
#  'imdbID': 'tt5882246',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4839414
# -------------------
# {'Actors': "Tim O'Leary, Nova Gaver, Chad Crenshaw, Nathan Varnson",
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Johnny Xeno',
#  'Genre': 'Comedy, Drama, Horror, Sci-Fi, Thriller',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'After living peacefully in the caverns of a small town, a stranded '
#          'group of aliens turn deadly as they fight for their existence, '
#          'betraying the compassionate chief of police who has protected them '
#          'for 28 years.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNWI0MWFjOTEtNWQ4YS00OWI1LWJmOGQtNWY1MjEyMTlkYzVmXkEyXkFqcGdeQXVyMzkwNzkwNDA@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'TV-MA',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '3.3/10'}],
#  'Released': '24 Jul 2018',
#  'Response': 'True',
#  'Runtime': '91 min',
#  'Title': 'No Good Heroes',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Johnny Xeno (screenplay)',
#  'Year': '2016',
#  'imdbID': 'tt4839414',
#  'imdbRating': '3.3',
#  'imdbVotes': '232'}
# -------------------
# movie id tt4310688
# -------------------
# {'Actors': 'Gemma Brockis, Jennifer Lafleur, David Sullivan, Kent Osborne',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Amber Sealey',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Grieving her mother's death and her own failing marriage, Lexi "
#          'boards a plane from London to Los Angeles in search of the estranged '
#          'father who abandoned her when she was three years old. ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjg4ZjNlYzMtZWY3Yy00ZmMyLThiYWEtOTc1NmZlZjUxZTM1XkEyXkFqcGdeQXVyMjczMDYyNw@@._V1_SX300.jpg',
#  'Production': 'Factory 25',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.0/10'}],
#  'Released': '16 Mar 2018',
#  'Response': 'True',
#  'Runtime': '75 min',
#  'Title': 'No Light and No Land Anywhere',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Amber Sealey',
#  'Year': '2016',
#  'imdbID': 'tt4310688',
#  'imdbRating': '6.0',
#  'imdbVotes': '56'}
# -------------------
# movie id tt5873536
# -------------------
# {'Actors': 'Joanna Aldrigde-Wilson, Ebony Alexis, Elder Richie Beaty, Nina '
#            'Bell',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Kenneth Vanwright',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOWQ5NTA3MmMtMTM5NS00Y2EyLWJiYTItNDcyM2RjZTA5YzI0XkEyXkFqcGdeQXVyNTMzMDU0MjM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '01 Aug 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'No More',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Kenneth Vanwright',
#  'Year': '2016',
#  'imdbID': 'tt5873536',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt3079814
# -------------------
# {'Actors': 'Alex Kruz, Kristen Ruhlin, Shuhei Kinoshita, Ashley Blankenship',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
# ...
#  'imdbVotes': '163'}
# -------------------
# movie id tt2614322
# -------------------
# {'Actors': 'Amy Acker, Katie Walder, Timm Sharp, Joshua Dov',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ged Dickersin',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The Energy Specialist is about what you do after college, when you '
#          'have spent most of your college days partying. After graduating from '
#          "U. Mass Amherst, Dev Teller (Josh Dov) decides he's ...",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjA0NDk0NTU4Nl5BMl5BanBnXkFtZTcwNzc5NjU5OA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'}],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Energy Specialist',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Eric S. Page',
#  'Year': '2016',
#  'imdbID': 'tt2614322',
#  'imdbRating': '6.3',
#  'imdbVotes': '14'}
# -------------------
# movie id tt3793788
# -------------------
# {'Actors': 'Lyndsy Fonseca, Michael Doneger, Tommy Dewey, Bruce Campbell',
#  'Awards': '1 nomination.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Will Slocombe',
#  'Genre': 'Comedy, Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Desperate for a good story, a sex-addicted journalist throws himself '
#          'into the world of high-class escorts when he starts following a '
#          'Stanford-educated prostitute.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNTgzNDgzNDAyMF5BMl5BanBnXkFtZTgwMTgxOTkzNjE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.0/10'}],
#  'Released': '28 Jul 2016',
#  'Response': 'True',
#  'Runtime': '88 min',
#  'Title': 'The Escort',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Michael Doneger, Brandon Cohen, Michael Doneger (story by)',
#  'Year': '2016',
#  'imdbID': 'tt3793788',
#  'imdbRating': '6.0',
#  'imdbVotes': '10,665'}
# -------------------
# movie id tt5515374
# -------------------
# {'Actors': 'Sydney Ray, Nicholas Kolasinski, Peter Pontone, Robert Futrell',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ben Wilder',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "It's March in South Florida. The beach towns are flush with young "
#          'people looking for action and excitement. For one unlucky group of '
#          'thrill-seeking spring breakers, their adventure leads to...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMmE5ZGY4ODctMmI4Yi00NGNjLTg4OGEtNmNjYmE1YTc3ZWNlXkEyXkFqcGdeQXVyNjc4NTQxNjg@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.1/10'}],
#  'Released': '12 Nov 2016',
#  'Response': 'True',
#  'Runtime': '80 min',
#  'Title': 'Lake Fear 2: The Swamp',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ashley Billington (story by), Ben Wilder (story by), Sean Therrien '
#            '(story by), Jesus Roldan (story by)',
#  'Year': '2016',
#  'imdbID': 'tt5515374',
#  'imdbRating': '5.1',
#  'imdbVotes': '386'}
# -------------------
# movie id tt6392226
# -------------------
# {'Actors': 'Samantha Dryer, Lionel James, Amanda Jones-Freedman, Jennifer '
#            'Jillian Mayes',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Isabelle Manos',
#  'Genre': 'Horror',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '31 Oct 2016',
#  'Response': 'True',
#  'Runtime': '97 min',
#  'Title': 'The Evil in the Darkness',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Isabelle Manos',
#  'Year': '2016',
#  'imdbID': 'tt6392226',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt4721124
# -------------------
# {'Actors': 'Loïs Alessandra, Jai Courtney, Karin Leclercq, Anton Lesser',
#  'Awards': '2 nominations.',
#  'BoxOffice': 'N/A',
#  'Country': 'UK, USA',
#  'DVD': 'N/A',
#  'Director': 'David Leveaux',
#  'Genre': 'Drama, Romance, War',
#  'Language': 'English',
#  'Metascore': '60',
#  'Plot': 'A German soldier tries to determine if the Dutch resistance has '
#          'planted a spy to infiltrate the home of Kaiser Wilhelm in Holland '
#          'during the onset of World War II, but falls for a young Jewish Dutch '
#          'woman during his investigation.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZmM2YjZhN2ItNTczZS00MDc1LTg0MTktODcyMjIyZmM5YjkwXkEyXkFqcGdeQXVyMjQ3NzUxOTM@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.8/10'},
#              {'Source': 'Metacritic', 'Value': '60/100'}],
#  'Released': '02 Jun 2017',
#  'Response': 'True',
#  'Runtime': '107 min',
#  'Title': 'The Exception',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Simon Burke (screenplay by), Alan Judd (based on the novel "The '
#            'Kaiser\'s Last Kiss" by)',
#  'Year': '2016',
#  'imdbID': 'tt4721124',
#  'imdbRating': '6.8',
#  'imdbVotes': '9,287'}
# -------------------
# movie id tt3581704
# -------------------
# {'Actors': 'Massimiliano Belsito, Maryne Bertieaux, Françoise Guiol, Audrey '
#            'Krief',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA, France',
#  'DVD': 'N/A',
#  'Director': 'Robert Arnold, Audrey Krief, Cynthia Mitchell',
#  'Genre': 'Drama, Romance',
#  'Language': 'English, French',
#  'Metascore': 'N/A',
#  'Plot': 'Lydia is in anguish over her breakup with Frank. Haunted, sleepless, '
#          'and desperate, she agrees to a blind date set up by a friend. The '
#          'man she meets, a handsome actor, is used to having ...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMDYyYjY5ZjUtNGUzMC00MjMzLWEwM2YtYTFmMzQ2ZmYzYTdiXkEyXkFqcGdeQXVyMjk3MzU3MA@@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'}],
#  'Released': '16 Apr 2016',
#  'Response': 'True',
#  'Runtime': '79 min',
#  'Title': 'The Exchange',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Cynthia Mitchell',
#  'Year': '2016',
#  'imdbID': 'tt3581704',
#  'imdbRating': '6.5',
#  'imdbVotes': '11'}
# -------------------
# movie id tt10045260
# -------------------
# {'Actors': 'George C. Scott, Ed Flanders, Brad Dourif, Scott Wilson',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'William Peter Blatty',
#  'Genre': 'Horror',
#  'Language': 'N/A',
#  'Metascore': 'N/A',
#  'Plot': 'William Peter Blatty\'s director\'s cut of "The Exorcist III" which '
#          'was thought to be lost. Recovered and released in 2016 under its '
#          'original title, this is the definitive cut of the film based on his '
#          'novel "Legion".',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNDVhNjU5MjYtMGFkYi00Nzg1LWFkYjUtM2FiNzIwMjczMjJmXkEyXkFqcGdeQXVyNDIwMTk2Mjg@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.5/10'}],
#  'Released': '25 Oct 2016',
#  'Response': 'True',
#  'Runtime': '105 min',
#  'Title': 'The Exorcist III: Legion',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'William Peter Blatty (novel), William Peter Blatty (screenplay)',
#  'Year': '2016',
#  'imdbID': 'tt10045260',
#  'imdbRating': '7.5',
#  'imdbVotes': '75'}
# -------------------
# movie id tt5225338
# -------------------
# {'Actors': 'Diana Agostini, Olivia Bond, Will Brill, Joey Curtis-Green',
#  'Awards': '5 wins & 13 nominations.',
#  'BoxOffice': '$25,981',
#  'Country': 'USA',
#  'DVD': '07 Mar 2017',
#  'Director': 'Nicolas Pesce',
#  'Genre': 'Drama, Horror',
#  'Language': 'English, Portuguese',
#  'Metascore': '63',
#  'Plot': 'A young, lonely woman is consumed by her deepest and darkest desires '
#          'after tragedy strikes her quiet country life.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTcyMDkyMDA4N15BMl5BanBnXkFtZTgwMjE5MDExMDI@._V1_SX300.jpg',
#  'Production': 'Magnet Releasing',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '78%'},
#              {'Source': 'Metacritic', 'Value': '63/100'}],
#  'Released': '02 Dec 2016',
#  'Response': 'True',
#  'Runtime': '76 min',
#  'Title': 'The Eyes of My Mother',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Nicolas Pesce',
#  'Year': '2016',
#  'imdbID': 'tt5225338',
#  'imdbRating': '6.2',
#  'imdbVotes': '10,183'}
# -------------------
# movie id tt7904842
# -------------------
# {'Actors': 'Kela Kealakai, Wyatt Gaer, Dylan Saul, Rachel Millena Saul',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jonah Barrett',
#  'Genre': 'Action, Comedy, Sci-Fi',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': "Cody McGuire has just returned from an important doctor's "
#          'appointment, only to find an attractive-but-naïve artificially '
#          'created man on her doorstep named Mr. Perfect. With the help of her '
#          '...',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOTgwMDQ3NjQtNmU2Mi00YzU4LWJlODYtY2FkYjBlZDU5YzRiXkEyXkFqcGdeQXVyODQ2NDgwNDI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '08 May 2016',
#  'Response': 'True',
#  'Runtime': '76 min',
#  'Title': 'The Fabricated Partner of Cody McGuire',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jonah Barrett',
#  'Year': '2016',
#  'imdbID': 'tt7904842',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5491574
# -------------------
# {'Actors': 'Tyler Bates, Stephanie Bisono, Dustin Bragga, Shaun Downey',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Ratish Nair',
#  'Genre': 'Thriller',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'After experiencing something so traumatic and immense, she ought to '
#          'find closure by taking what is rightfully hers - "her sanity".',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYWE2NjQ0NDYtNjUxNC00MmVlLThmYzYtNDIyN2ZiMzFiNTBmXkEyXkFqcGdeQXVyMzYyODkxNzk@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.2/10'}],
#  'Released': '30 Apr 2016',
#  'Response': 'True',
#  'Runtime': '55 min',
#  'Title': 'The Face Beneath',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Ratish Nair',
#  'Year': '2016',
#  'imdbID': 'tt5491574',
#  'imdbRating': '4.2',
#  'imdbVotes': '17'}
# -------------------
# movie id tt5968620
# -------------------
# {'Actors': 'Antonio Bushell Jr., Alexionna Bushell, Antonio Bushell, Jasmine '
#            'Bushell',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Antonio Bushell',
#  'Genre': 'Animation',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'The Faith Kids in this action thriller must defeat him before he '
#          'executes his evil plans. On their journey to defeat darkness Faith '
#          "Kids uncover the truth about themselves, God's word, and ...",
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BYTVmYmUxOTAtNTllMi00ODhiLThiN2EtNWQwM2Y0ZWFmMmY3XkEyXkFqcGdeQXVyNTgwNDg3NzI@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '12 Jul 2016',
#  'Response': 'True',
#  'Runtime': '57 min',
#  'Title': 'The Faith Kids: The Image',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Antonio Bushell, Natasha Bushell',
#  'Year': '2016',
#  'imdbID': 'tt5968620',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt6048582
# -------------------
# {'Actors': 'Nick Ferrucci, Benjamin Farmer, Curtis Edward Jackson, Bruce '
#            'Jennings',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jon Garcia',
#  'Genre': 'Drama, Romance',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'This third and final film of the Falls trilogy revisits former '
#          'Mormon missionaries Chris and RJ, six years after they first fell in '
#          'love and were disciplined for it, as they formulate a plan to be '
#          'together at long last.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMGQwNjhhZDgtZjE1Ny00NDU4LTg3ZGYtOWYzYTRmZmU0YmUzXkEyXkFqcGdeQXVyNTI2Mjc2NDk@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'Not Rated',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.9/10'}],
#  'Released': '01 Sep 2016',
#  'Response': 'True',
#  'Runtime': '119 min',
#  'Title': 'The Falls: Covenant of Grace',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jon Garcia, Rodney Moore',
#  'Year': '2016',
#  'imdbID': 'tt6048582',
#  'imdbRating': '6.9',
#  'imdbVotes': '555'}
# -------------------
# movie id tt3568166
# -------------------
# {'Actors': "Jerry G. Angelo, Jolyne Lowery, Kodi Saint Angelo, Jesse D'Angelo",
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Jerry G. Angelo',
#  'Genre': 'Action, Adventure, Fantasy',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'N/A',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'Untitled Fire Born Horror II',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jerry G. Angelo (screenplay), Jerry G. Angelo, Reggie Keyohara III '
#            '(screenplay)',
#  'Year': '2015',
#  'imdbID': 'tt3568166',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt8714280
# -------------------
# {'Error': 'Error getting data.', 'Response': 'False'}
# -------------------
# movie id tt5120282
# -------------------
# {'Actors': 'Paula Lauzon, Juani Feliz, Lin Hultgren, India Pearl',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Shane Butler',
#  'Genre': 'Comedy, Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'Two star-crossed Tinder lovers meet with their friends in the hour '
#          'and a half before their date to discuss love and technology and deal '
#          'with strangers who drop in on them.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': 'N/A',
#  'Response': 'True',
#  'Runtime': '74 min',
#  'Title': 'The fastest, most romantic love yet.',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Shane Butler',
#  'Year': '2015',
#  'imdbID': 'tt5120282',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}
# -------------------
# movie id tt5047788
# -------------------
# {'Actors': 'Wil Love, David DeLuise, Dendrie Taylor, Charity Farrell',
#  'Awards': '2 wins.',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'John Putch',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A retired character actor with diagnosed dementia, longs to perform '
#          'at his beloved summer theater one last time.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjI3OTMxNzMyOF5BMl5BanBnXkFtZTgwNzM1Mjk5NzE@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '9.3/10'}],
#  'Released': '01 Jul 2016',
#  'Response': 'True',
#  'Runtime': '85 min',
#  'Title': 'The Father and the Bear',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'John Putch',
#  'Year': '2016',
#  'imdbID': 'tt5047788',
#  'imdbRating': '9.3',
#  'imdbVotes': '26'}
# -------------------
# movie id tt4949676
# -------------------
# {'Actors': 'Joe Nicolosi, Jennifer Ford, Tiana Dunham, Casey Litzenberger',
#  'Awards': 'N/A',
#  'BoxOffice': 'N/A',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Andrew Alden',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': 'N/A',
#  'Plot': 'A former World Series hero attempts to make a comeback after a '
#          'devastating 5 years.',
#  'Poster': 'N/A',
#  'Production': 'N/A',
#  'Rated': 'N/A',
#  'Ratings': [],
#  'Released': '06 Jul 2016',
#  'Response': 'True',
#  'Runtime': 'N/A',
#  'Title': 'The Fear and the Uproar',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Andrew Alden',
#  'Year': '2016',
#  'imdbID': 'tt4949676',
#  'imdbRating': 'N/A',
#  'imdbVotes': 'N/A'}

# %%
len(title_list)
# Out:
# 983

# %%
len(title_id)
# Out:
# 983

# %%
# if title_list and title_id are the same length run the cell below. 
# if they are not equal take out 'title_id': title_id

# %%
df = pd.DataFrame({'title_id': title_id, 'title': title_list, 'box_office': box_office_list, 'country': country_list, 
                   'genre': genre_list, 'director': director_list, 'metascore': metascore_list, 'production': production_list, 
                   'rating': rating_list, 'IMDB_rating': IMDB_rating_list, 'rotten_tomatoes_rating': rotten_tomatoes_rating_list, 
                  'runtime': runtime_list, 'type': type_list, 'IMDB_votes': imdb_votes_list})

# %%
df = df.drop_duplicates()
df.head()
# Out:
#     title_id                       title box_office country  \
# 0  tt5571972        My Sister, My Keeper        N/A     USA
# 1  tt7470666                  My Stories        N/A     USA
# 2  tt4601830              My Sunset Girl        N/A     USA
# 3  tt5009208  My Uncle John Is a Zombie!        N/A     USA
# 4  tt5817252                   Mysterink        N/A     USA
#
#                     genre                         director metascore  \
# 0                   Drama                       Esther Lev       N/A
# 1                   Drama                              N/A       N/A
# 2  Drama, Family, Romance                    Alex Greenlee       N/A
# 3          Comedy, Horror                    John A. Russo       N/A
# 4                 Mystery  Courtnie Sheikh, Farrukh Sheikh       N/A
#
#   production rating IMDB_rating rotten_tomatoes_rating runtime   type  \
# 0        N/A    N/A         N/A                     NA     N/A  movie
# 1        N/A    N/A         N/A                     NA     N/A  movie
# 2        N/A    N/A         N/A                     NA  80 min  movie
# 3        N/A    N/A         N/A                     NA     N/A  movie
# 4        N/A    N/A         N/A                     NA     N/A  movie
#
#   IMDB_votes
# 0        N/A
# 1        N/A
# 2        N/A
# 3        N/A
# 4        N/A

# %%
df.count()
# Out:
# title_id                  983
# title                     983
# box_office                983
# country                   983
# genre                     983
# director                  983
# metascore                 983
# production                983
# rating                    983
# IMDB_rating               983
# rotten_tomatoes_rating    983
# runtime                   983
# type                      983
# IMDB_votes                983
# dtype: int64

# %%
df.to_csv('Resources/data/2017_data_batch_1.csv', index=False)
